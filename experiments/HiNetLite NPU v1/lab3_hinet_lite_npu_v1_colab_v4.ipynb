# %% [markdown]
# # Lab 3 - hinet_lite_npu_v1 (Colab v4)
#
# - Goal: stabilize late training, improve PSNR, and keep the NPU export path clear.
# - Expected input/output: `256x256x3`
# - Default mode: `stage2_resume` from the v3 best checkpoint.

# %% [markdown]
# ## 1. Setup

# %%
try:
    import google.colab  # type: ignore
    IN_COLAB_BOOTSTRAP = True
except Exception:
    IN_COLAB_BOOTSTRAP = False

if IN_COLAB_BOOTSTRAP:
    # %pip install -q onnx onnxruntime

import csv
import json
import math
import os
import random
import shutil
import sys
import time
from contextlib import nullcontext
from dataclasses import asdict, dataclass
from datetime import datetime
from pathlib import Path
from typing import Any, Literal

import numpy as np
import onnx
import torch
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
from torch.utils.data import DataLoader, Dataset


def set_global_seed(seed: int) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


try:
    BICUBIC_RESAMPLE = Image.Resampling.BICUBIC
except AttributeError:
    BICUBIC_RESAMPLE = Image.BICUBIC

try:
    FLIP_LEFT_RIGHT = Image.Transpose.FLIP_LEFT_RIGHT
    FLIP_TOP_BOTTOM = Image.Transpose.FLIP_TOP_BOTTOM
    ROTATE_90 = Image.Transpose.ROTATE_90
    ROTATE_180 = Image.Transpose.ROTATE_180
    ROTATE_270 = Image.Transpose.ROTATE_270
except AttributeError:
    FLIP_LEFT_RIGHT = Image.FLIP_LEFT_RIGHT
    FLIP_TOP_BOTTOM = Image.FLIP_TOP_BOTTOM
    ROTATE_90 = Image.ROTATE_90
    ROTATE_180 = Image.ROTATE_180
    ROTATE_270 = Image.ROTATE_270


def now_stamp() -> str:
    return datetime.now().strftime("%H%M%S_%d%m")


def is_colab_runtime() -> bool:
    try:
        import google.colab  # type: ignore  # noqa: F401
        return True
    except Exception:
        return False


def auto_num_workers(in_colab: bool) -> int:
    if sys.platform == "darwin":
        return 0
    cpu_count = max(os.cpu_count() or 2, 2)
    if in_colab:
        return min(4, max(cpu_count - 1, 2))
    return min(2, cpu_count)


def resolve_repo_root(start: Path) -> Path:
    current = start.resolve()
    for candidate in [current, *current.parents]:
        if (candidate / "Data").exists() and (candidate / "runs").exists():
            return candidate
    for candidate in [current, *current.parents]:
        if (candidate / "Data").exists():
            return candidate
    raise FileNotFoundError(f"Could not locate repo root from {start.resolve()}")


def make_unique_run_root(runs_root: Path) -> Path:
    candidate = runs_root / now_stamp()
    while candidate.exists():
        time.sleep(1.1)
        candidate = runs_root / now_stamp()
    return candidate
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 131.2 MB/s eta 0:00:0000:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 131.1 MB/s eta 0:00:0000:010:01

# %%
IMAGE_SUFFIXES = {".png", ".jpg", ".jpeg", ".bmp"}
EXPECTED_TRAIN_PAIRS = 2217
EXPECTED_VAL_PAIRS = 110
DRIVE_ROOT = Path("/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3")
DRIVE_DATA_ROOT = DRIVE_ROOT / "Data"
DRIVE_RUNS_ROOT = DRIVE_ROOT / "runs"
DEFAULT_STAGE2_RESUME = "20260424/hinet_lite_npu_v1_colab_v3_full_20260424_004323/checkpoints/best.pth"


@dataclass
class RunConfig:
    model_id: str = "hinet_lite_npu_v1"
    training_mode: Literal["stage2_resume", "fresh"] = "stage2_resume"
    seed: int = 1337
    train_patch_size: int = 256
    eval_size: int = 256
    batch_size: int = 8
    epochs: int = 24  # Additional epochs for the current run.
    lr: float = 6e-5
    min_lr: float = 1e-6
    weight_decay: float = 1e-5
    warmup_epochs: int = 0
    grad_clip_norm: float = 1.0
    num_workers: int | None = None
    prefetch_factor: int = 2
    train_pair_limit: int | None = None
    val_pair_limit: int | None = None
    use_amp: bool = True
    use_ema: bool = True
    use_channels_last: bool = True
    use_tf32: bool = True
    ema_decay: float = 0.999
    train_eval_subset_size: int = 128
    enable_resume: bool = True
    resume_checkpoint_path: str | None = DEFAULT_STAGE2_RESUME
    selected_weight_source: Literal["ema", "raw"] = "ema"
    early_stop_patience: int = 6

    def __post_init__(self) -> None:
        if self.training_mode == "fresh":
            self.train_patch_size = 224
            self.epochs = 160
            self.lr = 3e-4
            self.min_lr = 1e-5
            self.weight_decay = 5e-5
            self.warmup_epochs = 5
            self.enable_resume = False
            self.resume_checkpoint_path = None
            self.early_stop_patience = 12


cfg = RunConfig()
assert cfg.eval_size == 256, "Lab 3 eval size must stay 256"
assert cfg.selected_weight_source in {"ema", "raw"}
if cfg.selected_weight_source == "ema" and not cfg.use_ema:
    raise ValueError("selected_weight_source='ema' requires use_ema=True")


def checkpoint_psnr_metadata(checkpoint_path: str | None) -> dict[str, Any] | None:
    if not checkpoint_path:
        return None
    path = Path(checkpoint_path)
    if not path.exists():
        return {"path": str(path), "exists": False}
    checkpoint = torch.load(path, map_location="cpu")
    last_metrics = checkpoint.get("last_metrics") or {}
    return {
        "path": str(path),
        "exists": True,
        "epoch": int(checkpoint.get("epoch", 0)),
        "last_val_psnr": last_metrics.get("val_psnr"),
        "best_val_psnr": checkpoint.get("best_val_psnr"),
        "best_epoch": checkpoint.get("best_epoch"),
        "selected_weight_source": checkpoint.get("selected_weight_source"),
    }


def read_checkpoint_identity(checkpoint_path: Path) -> dict[str, Any] | None:
    try:
        checkpoint = torch.load(checkpoint_path, map_location="cpu")
    except Exception:
        return None
    config = checkpoint.get("config") or {}
    model_id = config.get("model_id")
    if not model_id:
        return None
    return {
        "path": str(checkpoint_path),
        "model_id": model_id,
        "epoch": int(checkpoint.get("epoch", 0)),
        "best_val_psnr": float(checkpoint.get("best_val_psnr", float("-inf"))),
        "mtime": checkpoint_path.stat().st_mtime,
        "kind": checkpoint_path.name,
    }


def find_latest_model_checkpoint(runs_root: Path, model_id: str, prefer_kind: Literal["best", "last"] = "best") -> str:
    candidates: list[dict[str, Any]] = []
    for checkpoint_path in runs_root.rglob("checkpoints/*.pth"):
        if checkpoint_path.name not in {"best.pth", "last.pth", "best_ema.pth"}:
            continue
        identity = read_checkpoint_identity(checkpoint_path)
        if identity and identity["model_id"] == model_id:
            candidates.append(identity)
    if not candidates:
        raise FileNotFoundError(f"No checkpoint found under {runs_root} for model_id={model_id}")
    kind_priority = {"best.pth": 1, "best_ema.pth": 1, "last.pth": 0} if prefer_kind == "best" else {"last.pth": 1, "best.pth": 0, "best_ema.pth": 0}
    winner = max(candidates, key=lambda item: (kind_priority.get(item["kind"], 0), item["mtime"]))
    return winner["path"]


def resolve_resume_checkpoint_path(
    resume_checkpoint_path: str | None,
    runs_root: Path,
    model_id: str,
    prefer_kind: Literal["best", "last"] = "best",
) -> str | None:
    if resume_checkpoint_path is None:
        return None
    if str(resume_checkpoint_path).lower() == "auto":
        return find_latest_model_checkpoint(runs_root, model_id, prefer_kind=prefer_kind)
    path = Path(resume_checkpoint_path).expanduser()
    if not path.is_absolute():
        path = runs_root / path
    if not path.exists():
        raise FileNotFoundError(f"Resume checkpoint not found: {path}")
    return str(path)


in_colab = is_colab_runtime()
if in_colab:
    from google.colab import drive  # type: ignore

    drive.mount("/content/drive", force_remount=False)
    data_root = DRIVE_DATA_ROOT
    runs_root = DRIVE_RUNS_ROOT
    if not data_root.exists():
        raise FileNotFoundError(f"Google Drive data root not found: {data_root}")
else:
    repo_root = resolve_repo_root(Path.cwd())
    data_root = repo_root / "Data"
    runs_root = repo_root / "runs"
    if not data_root.exists():
        raise FileNotFoundError(f"Data root not found: {data_root}")

runs_root.mkdir(parents=True, exist_ok=True)
if cfg.num_workers is None:
    cfg.num_workers = auto_num_workers(in_colab)

cfg.resume_checkpoint_path = resolve_resume_checkpoint_path(
    cfg.resume_checkpoint_path if cfg.enable_resume else None,
    runs_root,
    cfg.model_id,
    prefer_kind="best",
)

run_root = make_unique_run_root(runs_root)
checkpoints_dir = run_root / "checkpoints"
exports_dir = run_root / "exports"
calibration_dir = exports_dir / "calibration"
summary_path = run_root / "summary.json"
metrics_csv_path = run_root / "metrics.csv"
epoch_logs_jsonl_path = run_root / "epoch_logs.jsonl"
history_json_path = run_root / "history.json"

for directory in [run_root, checkpoints_dir, exports_dir, calibration_dir]:
    directory.mkdir(parents=True, exist_ok=True)

set_global_seed(cfg.seed)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if device.type == "cuda":
    torch.backends.cudnn.benchmark = True
    if cfg.use_tf32:
        torch.backends.cuda.matmul.allow_tf32 = True
        torch.backends.cudnn.allow_tf32 = True
        if hasattr(torch, "set_float32_matmul_precision"):
            torch.set_float32_matmul_precision("high")

resume_info = checkpoint_psnr_metadata(cfg.resume_checkpoint_path)
print({
    "device": str(device),
    "training_mode": cfg.training_mode,
    "data_root": str(data_root),
    "runs_root": str(runs_root),
    "run_root": str(run_root),
    "num_workers": cfg.num_workers,
    "prefetch_factor": cfg.prefetch_factor,
    "enable_resume": cfg.enable_resume,
    "resume_checkpoint_path": cfg.resume_checkpoint_path,
    "selected_weight_source": cfg.selected_weight_source,
    "run_name_format": "HHMMSS_DDMM",
})
print({"resume_checkpoint": resume_info})
# Out:
# Mounted at /content/drive
# {'device': 'cuda', 'training_mode': 'stage2_resume', 'data_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/Data', 'runs_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs', 'run_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/065325_2404', 'num_workers': 4, 'prefetch_factor': 2, 'enable_resume': True, 'resume_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/20260424/hinet_lite_npu_v1_colab_v3_full_20260424_004323/checkpoints/best.pth', 'selected_weight_source': 'ema', 'run_name_format': 'HHMMSS_DDMM'}
# {'resume_checkpoint': {'path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/20260424/hinet_lite_npu_v1_colab_v3_full_20260424_004323/checkpoints/best.pth', 'exists': True, 'epoch': 39, 'last_val_psnr': 24.233901977539062, 'best_val_psnr': 24.233901977539062, 'best_epoch': 39, 'selected_weight_source': 'ema'}}

# %% [markdown]
# ## 2. Data

# %%
L3_TRAIN_SPLITS = (
    ("LR_HR/L3_HR_train1", "L3_LR/L3_L3_train1", "L3_HR_train1"),
    ("LR_HR/L3_HR_train2", "L3_LR/L3_L3_train2", "L3_HR_train2"),
    ("LR_HR/L3_HR_train3", "L3_LR/L3_LR_train3", "L3_HR_train3"),
    ("LR_HR/L3_HR_train4", "L3_LR/L3_LR_train4", "L3_HR_train4"),
    ("LR_HR/L3_HR_train", "L3_LR/L3_LR_train", "L3_HR_train"),
)
L3_VAL_DIRS = ("L3_HR_valid", "L3_LR_valid")

required_dirs = [data_root / hr_rel for hr_rel, _, _ in L3_TRAIN_SPLITS] + [
    data_root / lr_rel for _, lr_rel, _ in L3_TRAIN_SPLITS
] + [
    data_root / L3_VAL_DIRS[0],
    data_root / L3_VAL_DIRS[1],
]
missing_dirs = [path for path in required_dirs if not path.exists()]
if missing_dirs:
    print("Missing required L3 dataset directories:")
    for path in missing_dirs:
        print(f" - {path}")
else:
    print(f"L3 dataset layout looks good under: {data_root}")


def scan_image_directory(directory: Path) -> dict[str, Path]:
    if not directory.exists():
        raise FileNotFoundError(f"Missing directory: {directory}")
    return {
        path.stem: path
        for path in directory.iterdir()
        if path.is_file() and path.suffix.lower() in IMAGE_SUFFIXES
    }


def collect_split_pairs(hr_dir: Path, lr_dir: Path, split_name: str) -> list[tuple[Path, Path, str]]:
    hr_map = scan_image_directory(hr_dir)
    lr_map = scan_image_directory(lr_dir)
    pairs: list[tuple[Path, Path, str]] = []
    for stem in sorted(set(hr_map) & set(lr_map)):
        name = stem if split_name == "val" else f"{split_name}/{stem}"
        pairs.append((lr_map[stem], hr_map[stem], name))
    return pairs


def collect_all_pairs(data_root: Path) -> tuple[list[tuple[Path, Path, str]], list[tuple[Path, Path, str]]]:
    train_pairs: list[tuple[Path, Path, str]] = []
    for hr_rel, lr_rel, split_name in L3_TRAIN_SPLITS:
        train_pairs.extend(collect_split_pairs(data_root / hr_rel, data_root / lr_rel, split_name))
    val_pairs = collect_split_pairs(data_root / L3_VAL_DIRS[0], data_root / L3_VAL_DIRS[1], "val")
    return train_pairs, val_pairs


def choose_monitor_pairs(pairs: list[tuple[Path, Path, str]], subset_size: int) -> list[tuple[Path, Path, str]]:
    if len(pairs) <= subset_size:
        return pairs
    indices = np.linspace(0, len(pairs) - 1, num=subset_size, dtype=int)
    return [pairs[idx] for idx in indices.tolist()]


class PairedSRDataset(Dataset):
    def __init__(self, pairs: list[tuple[Path, Path, str]], *, train: bool, patch_size: int, eval_size: int, seed: int):
        self.pairs = pairs
        self.train = train
        self.patch_size = patch_size
        self.eval_size = eval_size
        self.seed = seed
        self.epoch = 0

    def set_epoch(self, epoch: int) -> None:
        self.epoch = epoch

    @staticmethod
    def to_tensor(img: Image.Image) -> torch.Tensor:
        arr = np.asarray(img, dtype=np.float32) / 255.0
        return torch.from_numpy(arr).permute(2, 0, 1).contiguous()

    def augment_pair(self, lr: Image.Image, hr: Image.Image, index: int) -> tuple[Image.Image, Image.Image]:
        rng = random.Random((self.seed * 1_000_003) + (self.epoch * 9_973) + index)
        width, height = lr.size
        patch = self.patch_size
        if width < patch or height < patch:
            lr = lr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            hr = hr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            width, height = lr.size
        left = rng.randint(0, width - patch)
        top = rng.randint(0, height - patch)
        box = (left, top, left + patch, top + patch)
        lr = lr.crop(box)
        hr = hr.crop(box)
        if rng.random() < 0.5:
            lr = lr.transpose(FLIP_LEFT_RIGHT)
            hr = hr.transpose(FLIP_LEFT_RIGHT)
        if rng.random() < 0.5:
            lr = lr.transpose(FLIP_TOP_BOTTOM)
            hr = hr.transpose(FLIP_TOP_BOTTOM)
        rot = rng.choice([0, 1, 2, 3])
        if rot:
            rotate_ops = [ROTATE_90, ROTATE_180, ROTATE_270]
            lr = lr.transpose(rotate_ops[rot - 1])
            hr = hr.transpose(rotate_ops[rot - 1])
        return lr, hr

    def __len__(self) -> int:
        return len(self.pairs)

    def __getitem__(self, index: int) -> dict[str, Any]:
        lr_path, hr_path, name = self.pairs[index]
        lr = Image.open(lr_path).convert("RGB")
        hr = Image.open(hr_path).convert("RGB")
        if self.train:
            lr, hr = self.augment_pair(lr, hr, index)
        elif lr.size != (self.eval_size, self.eval_size):
            lr = lr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            hr = hr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
        return {"lr": self.to_tensor(lr), "hr": self.to_tensor(hr), "name": name}


train_pairs, val_pairs = collect_all_pairs(data_root)
if cfg.train_pair_limit is not None:
    train_pairs = train_pairs[: cfg.train_pair_limit]
if cfg.val_pair_limit is not None:
    val_pairs = val_pairs[: cfg.val_pair_limit]
if not train_pairs or not val_pairs:
    raise RuntimeError(f"Expected non-empty train/val pairs, found train={len(train_pairs)} val={len(val_pairs)}")
if len(train_pairs) != EXPECTED_TRAIN_PAIRS and cfg.train_pair_limit is None:
    print(f"Warning: expected {EXPECTED_TRAIN_PAIRS} train pairs, found {len(train_pairs)}")
if len(val_pairs) != EXPECTED_VAL_PAIRS and cfg.val_pair_limit is None:
    print(f"Warning: expected {EXPECTED_VAL_PAIRS} val pairs, found {len(val_pairs)}")

train_eval_pairs = choose_monitor_pairs(train_pairs, cfg.train_eval_subset_size)
train_eval_sample_names = [name for _, _, name in train_eval_pairs]

train_ds = PairedSRDataset(train_pairs, train=True, patch_size=cfg.train_patch_size, eval_size=cfg.eval_size, seed=cfg.seed)
train_eval_ds = PairedSRDataset(train_eval_pairs, train=False, patch_size=cfg.eval_size, eval_size=cfg.eval_size, seed=cfg.seed)
val_ds = PairedSRDataset(val_pairs, train=False, patch_size=cfg.eval_size, eval_size=cfg.eval_size, seed=cfg.seed)

pin_memory = device.type == "cuda"
loader_kwargs = {"num_workers": int(cfg.num_workers), "pin_memory": pin_memory}
if cfg.num_workers > 0:
    loader_kwargs["persistent_workers"] = True
    loader_kwargs["prefetch_factor"] = cfg.prefetch_factor

train_loader = DataLoader(train_ds, batch_size=cfg.batch_size, shuffle=True, **loader_kwargs)
train_eval_loader = DataLoader(train_eval_ds, batch_size=cfg.batch_size, shuffle=False, **loader_kwargs)
val_loader = DataLoader(val_ds, batch_size=cfg.batch_size, shuffle=False, **loader_kwargs)

sample = next(iter(val_loader))
assert tuple(sample["lr"].shape[1:]) == (3, 256, 256)
assert tuple(sample["hr"].shape[1:]) == (3, 256, 256)
print({
    "train_pairs": len(train_pairs),
    "val_pairs": len(val_pairs),
    "train_eval_subset_size": len(train_eval_pairs),
    "train_eval_sample_names": train_eval_sample_names[:5],
    "train_batches_per_epoch": len(train_loader),
    "train_eval_batches": len(train_eval_loader),
    "val_batches_per_epoch": len(val_loader),
    "sample_shape": tuple(sample["lr"].shape),
    "train_patch_size": cfg.train_patch_size,
    "eval_size": cfg.eval_size,
})
# Out:
# L3 dataset layout looks good under: /content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/Data
# {'train_pairs': 2217, 'val_pairs': 110, 'train_eval_subset_size': 128, 'train_eval_sample_names': ['L3_HR_train1/0000', 'L3_HR_train1/000126', 'L3_HR_train1/000147', 'L3_HR_train1/000172', 'L3_HR_train1/000195'], 'train_batches_per_epoch': 278, 'train_eval_batches': 16, 'val_batches_per_epoch': 14, 'sample_shape': (8, 3, 256, 256), 'train_patch_size': 256, 'eval_size': 256}

# %% [markdown]
# ## 3. Model and Training

# %% [markdown]
# ### Architecture Summary
#
# The v4 notebook trains one clear architecture path: a mixed-kernel residual U-Net that predicts a residual correction over the low-resolution input.
#
# Forward path: `stem -> enc1 -> down1 -> enc2 -> down2 -> bottleneck -> up1/dec1 -> up2/dec2 -> tail -> residual add`

# %%
@dataclass
class MixedKernelUNetResidualConfig:
    channels: int = 48
    encoder_blocks: tuple[int, int] = (3, 3)
    bottleneck_blocks: int = 6
    decoder_blocks: tuple[int, int] = (3, 3)
    kernel_pattern: tuple[int, ...] = (3, 5, 3, 5, 3, 5)
    residual_scale: float = 0.2
    global_residual: bool = True


def init_tail_small(conv: nn.Conv2d, scale: float = 1e-3) -> None:
    nn.init.kaiming_normal_(conv.weight, a=0.1, mode="fan_in", nonlinearity="leaky_relu")
    conv.weight.data.mul_(scale)
    if conv.bias is not None:
        nn.init.zeros_(conv.bias)


class MixedKernelResidualBlock(nn.Module):
    def __init__(self, channels: int, kernel_size: int, residual_scale: float = 0.2):
        super().__init__()
        padding = kernel_size // 2
        self.residual_scale = residual_scale
        self.conv1 = nn.Conv2d(channels, channels, kernel_size, 1, padding)
        self.act = nn.LeakyReLU(0.1, inplace=True)
        self.conv2 = nn.Conv2d(channels, channels, kernel_size, 1, padding)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        residual = self.conv2(self.act(self.conv1(x)))
        return x + self.residual_scale * residual


class DownsampleBlock(nn.Module):
    def __init__(self, in_ch: int, out_ch: int):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.block(x)


class UpsampleBlock(nn.Module):
    def __init__(self, in_ch: int, out_ch: int):
        super().__init__()
        self.block = nn.Sequential(
            nn.ConvTranspose2d(in_ch, out_ch, 4, stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.block(x)


class MixedKernelUNetResidualSR(nn.Module):
    def __init__(self, cfg_m: MixedKernelUNetResidualConfig):
        super().__init__()
        c = cfg_m.channels
        pattern = cfg_m.kernel_pattern
        self.global_residual = cfg_m.global_residual
        self.stem = nn.Sequential(nn.Conv2d(3, c, 3, 1, 1), nn.LeakyReLU(0.1, inplace=True))
        self.enc1 = nn.Sequential(*[
            MixedKernelResidualBlock(c, pattern[idx % len(pattern)], cfg_m.residual_scale)
            for idx in range(cfg_m.encoder_blocks[0])
        ])
        self.down1 = DownsampleBlock(c, c * 2)
        self.enc2 = nn.Sequential(*[
            MixedKernelResidualBlock(c * 2, pattern[(cfg_m.encoder_blocks[0] + idx) % len(pattern)], cfg_m.residual_scale)
            for idx in range(cfg_m.encoder_blocks[1])
        ])
        self.down2 = DownsampleBlock(c * 2, c * 4)
        self.bottleneck = nn.Sequential(*[
            MixedKernelResidualBlock(c * 4, pattern[(sum(cfg_m.encoder_blocks) + idx) % len(pattern)], cfg_m.residual_scale)
            for idx in range(cfg_m.bottleneck_blocks)
        ])
        self.up1 = UpsampleBlock(c * 4, c * 2)
        self.dec1 = nn.Sequential(*[
            MixedKernelResidualBlock(c * 2, pattern[(sum(cfg_m.encoder_blocks) + cfg_m.bottleneck_blocks + idx) % len(pattern)], cfg_m.residual_scale)
            for idx in range(cfg_m.decoder_blocks[0])
        ])
        self.up2 = UpsampleBlock(c * 2, c)
        self.dec2 = nn.Sequential(*[
            MixedKernelResidualBlock(c, pattern[(sum(cfg_m.encoder_blocks) + cfg_m.bottleneck_blocks + cfg_m.decoder_blocks[0] + idx) % len(pattern)], cfg_m.residual_scale)
            for idx in range(cfg_m.decoder_blocks[1])
        ])
        self.tail = nn.Conv2d(c, 3, 3, 1, 1)
        init_tail_small(self.tail)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # stem -> enc1 -> down1 -> enc2 -> down2 -> bottleneck -> up1/dec1 -> up2/dec2 -> tail -> residual add
        stem = self.stem(x)
        enc1 = self.enc1(stem)
        down1 = self.down1(enc1)
        enc2 = self.enc2(down1)
        down2 = self.down2(enc2)
        bottleneck = self.bottleneck(down2)
        up1 = self.up1(bottleneck)
        dec1 = self.dec1(up1 + enc2)
        up2 = self.up2(dec1)
        dec2 = self.dec2(up2 + enc1)
        delta = self.tail(dec2)
        return x + delta if self.global_residual else delta


def count_parameters(module: nn.Module) -> dict[str, int]:
    total = sum(param.numel() for param in module.parameters())
    trainable = sum(param.numel() for param in module.parameters() if param.requires_grad)
    return {"total": int(total), "trainable": int(trainable)}


def load_model_config_from_checkpoint(checkpoint_path: str | None) -> MixedKernelUNetResidualConfig:
    base = asdict(MixedKernelUNetResidualConfig())
    if checkpoint_path:
        checkpoint = torch.load(checkpoint_path, map_location="cpu")
        checkpoint_model_config = checkpoint.get("model_config") or {}
        for key in base:
            if key in checkpoint_model_config:
                value = checkpoint_model_config[key]
                if key in {"encoder_blocks", "decoder_blocks", "kernel_pattern"}:
                    value = tuple(value)
                base[key] = value
        print({
            "loaded_model_config_from_checkpoint": checkpoint_path,
            "checkpoint_model_config": checkpoint_model_config,
        })
    return MixedKernelUNetResidualConfig(**base)


def architecture_summary(cfg_m: MixedKernelUNetResidualConfig, param_counts: dict[str, int]) -> dict[str, Any]:
    return {
        "stem": "3x3 conv + LeakyReLU",
        "encoder_blocks": cfg_m.encoder_blocks,
        "downsample_stages": 2,
        "bottleneck_blocks": cfg_m.bottleneck_blocks,
        "decoder_blocks": cfg_m.decoder_blocks,
        "upsample_stages": 2,
        "kernel_pattern": cfg_m.kernel_pattern,
        "residual_scale": cfg_m.residual_scale,
        "global_residual": cfg_m.global_residual,
        "parameter_count": param_counts,
    }


model_cfg = load_model_config_from_checkpoint(cfg.resume_checkpoint_path if cfg.enable_resume else None)
model = MixedKernelUNetResidualSR(model_cfg).to(device)
if cfg.use_channels_last and device.type == "cuda":
    model = model.to(memory_format=torch.channels_last)
shape_input = torch.randn(1, 3, 256, 256, device=device)
if cfg.use_channels_last and device.type == "cuda":
    shape_input = shape_input.contiguous(memory_format=torch.channels_last)
shape_check = model(shape_input).shape
assert tuple(shape_check) == (1, 3, 256, 256), f"Unexpected shape: {shape_check}"
model_num_parameters = count_parameters(model)
print({"model_name": model.__class__.__name__, "shape_check": tuple(shape_check)})
print(architecture_summary(model_cfg, model_num_parameters))
# Out:
# {'loaded_model_config_from_checkpoint': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/20260424/hinet_lite_npu_v1_colab_v3_full_20260424_004323/checkpoints/best.pth', 'checkpoint_model_config': {'channels': 48, 'encoder_blocks': (3, 3), 'bottleneck_blocks': 6, 'decoder_blocks': (3, 3), 'kernel_pattern': (3, 5, 3, 5, 3, 5), 'residual_scale': 0.2, 'global_residual': True}}
# {'model_name': 'MixedKernelUNetResidualSR', 'shape_check': (1, 3, 256, 256)}
# {'stem': '3x3 conv + LeakyReLU', 'encoder_blocks': (3, 3), 'downsample_stages': 2, 'bottleneck_blocks': 6, 'decoder_blocks': (3, 3), 'upsample_stages': 2, 'kernel_pattern': (3, 5, 3, 5, 3, 5), 'residual_scale': 0.2, 'global_residual': True, 'parameter_count': {'total': 10453443, 'trainable': 10453443}}

# %%
def psnr_from_mse(mse: torch.Tensor, eps: float = 1e-12) -> torch.Tensor:
    return 10.0 * torch.log10(1.0 / torch.clamp(mse, min=eps))


@torch.no_grad()
def batch_psnr(pred: torch.Tensor, target: torch.Tensor) -> float:
    mse = F.mse_loss(pred, target, reduction="none").mean(dim=(1, 2, 3))
    return float(psnr_from_mse(mse).mean().item())


@torch.inference_mode()
def compute_input_psnr(loader: DataLoader, device: torch.device) -> float:
    meter = 0.0
    count = 0
    for batch in loader:
        lr = move_image_batch(batch["lr"], device)
        hr = move_image_batch(batch["hr"], device)
        meter += batch_psnr(lr, hr)
        count += 1
    return meter / max(count, 1)


def charbonnier_loss(pred: torch.Tensor, target: torch.Tensor, eps: float = 1e-3) -> torch.Tensor:
    diff = pred - target
    return torch.sqrt(diff * diff + eps * eps).mean()


def compute_restoration_loss(pred: torch.Tensor, lr: torch.Tensor, hr: torch.Tensor) -> dict[str, torch.Tensor]:
    pred_res = pred - lr
    target_res = hr - lr
    if cfg.training_mode == "stage2_resume":
        loss_mse = F.mse_loss(pred_res, target_res)
        return {"loss": loss_mse, "loss_mse": loss_mse.detach()}
    loss_char = charbonnier_loss(pred_res, target_res)
    loss_l1 = F.l1_loss(pred_res, target_res)
    total = 0.7 * loss_char + 0.3 * loss_l1
    return {
        "loss": total,
        "loss_charbonnier": loss_char.detach(),
        "loss_l1": loss_l1.detach(),
    }


def loss_config_summary() -> dict[str, Any]:
    if cfg.training_mode == "stage2_resume":
        return {"type": "residual_mse", "mse_weight": 1.0}
    return {"type": "residual_charbonnier_l1", "charbonnier_weight": 0.7, "l1_weight": 0.3}


def lr_at_epoch(epoch_idx: int, *, base_lr: float, min_lr: float, warmup_epochs: int, total_epochs: int) -> float:
    step = epoch_idx + 1
    if warmup_epochs > 0 and step <= warmup_epochs:
        return base_lr * step / max(1, warmup_epochs)
    progress = max(0.0, (step - warmup_epochs) / max(1, total_epochs - warmup_epochs))
    cosine = 0.5 * (1.0 + math.cos(math.pi * min(progress, 1.0)))
    return min_lr + cosine * (base_lr - min_lr)


class EMA:
    def __init__(self, model: nn.Module, decay: float):
        self.decay = decay
        self.shadow = {k: v.detach().clone() for k, v in model.state_dict().items()}

    @torch.no_grad()
    def update(self, model: nn.Module) -> None:
        for key, value in model.state_dict().items():
            self.shadow[key].mul_(self.decay).add_(value.detach(), alpha=1.0 - self.decay)

    @torch.no_grad()
    def copy_to(self, model: nn.Module) -> None:
        model.load_state_dict(self.shadow, strict=True)


def make_grad_scaler(enabled: bool):
    if hasattr(torch, "amp") and hasattr(torch.amp, "GradScaler"):
        return torch.amp.GradScaler("cuda", enabled=enabled)
    return torch.cuda.amp.GradScaler(enabled=enabled)


def autocast_context(device_type: str, enabled: bool):
    if not enabled:
        return nullcontext()
    if hasattr(torch, "amp") and hasattr(torch.amp, "autocast"):
        return torch.amp.autocast(device_type=device_type, enabled=enabled)
    return torch.cuda.amp.autocast(enabled=enabled)


def move_image_batch(batch: torch.Tensor, device: torch.device) -> torch.Tensor:
    batch = batch.to(device, non_blocking=(device.type == "cuda"))
    if cfg.use_channels_last and device.type == "cuda":
        batch = batch.contiguous(memory_format=torch.channels_last)
    return batch


def current_lr(optimizer: torch.optim.Optimizer) -> float:
    return float(optimizer.param_groups[0]["lr"])


def infer_resume_run_root(checkpoint_path: str | None) -> Path | None:
    if not checkpoint_path:
        return None
    ckpt_path = Path(checkpoint_path)
    if ckpt_path.parent.name != "checkpoints":
        return None
    return ckpt_path.parent.parent


def normalize_history_row(row: dict[str, Any]) -> dict[str, Any]:
    train_eval_psnr = row.get("train_eval_psnr")
    val_psnr = row.get("val_psnr")
    gap = row.get("generalization_gap")
    if gap is None and train_eval_psnr not in (None, "") and val_psnr not in (None, ""):
        gap = float(train_eval_psnr) - float(val_psnr)
    return {
        "epoch": int(row["epoch"]),
        "epoch_time_sec": float(row["epoch_time_sec"]),
        "lr": float(row["lr"]),
        "train_loss_residual": float(row["train_loss_residual"]),
        "train_patch_psnr": float(row["train_patch_psnr"]),
        "train_eval_psnr": float(train_eval_psnr),
        "val_psnr": float(val_psnr),
        "input_psnr": float(row["input_psnr"]),
        "delta_psnr": float(row["delta_psnr"]),
        "generalization_gap": float(gap),
        "is_best": bool(row.get("is_best", False)),
    }


def load_resume_history_rows(checkpoint_path: str | None) -> list[dict[str, Any]]:
    run_root = infer_resume_run_root(checkpoint_path)
    if run_root is None:
        return []
    history_path = run_root / "history.json"
    if history_path.exists():
        payload = json.loads(history_path.read_text(encoding="utf-8"))
        return [normalize_history_row(row) for row in payload.get("epochs", [])]
    metrics_path = run_root / "metrics.csv"
    if not metrics_path.exists():
        return []
    with metrics_path.open("r", newline="", encoding="utf-8") as f:
        reader = csv.DictReader(f)
        return [normalize_history_row(row) for row in reader]


def write_history_json(history_path: Path, rows: list[dict[str, Any]], resume_checkpoint_path: str | None) -> None:
    payload = {
        "resume_checkpoint_path": resume_checkpoint_path,
        "epoch_count": len(rows),
        "latest_epoch": int(rows[-1]["epoch"]) if rows else 0,
        "best_val_psnr": max((float(row["val_psnr"]) for row in rows), default=None),
        "epochs": rows,
    }
    history_path.write_text(json.dumps(payload, indent=2), encoding="utf-8")


def print_epoch_row(row: dict[str, Any]) -> None:
    print(
        f"[epoch {int(row['epoch']):03d}] "
        f"time={float(row['epoch_time_sec']):.2f}s "
        f"lr={float(row['lr']):.6f} "
        f"train_patch_psnr={float(row['train_patch_psnr']):.4f} "
        f"train_eval_psnr={float(row['train_eval_psnr']):.4f} "
        f"val_psnr={float(row['val_psnr']):.4f} "
        f"generalization_gap={float(row['generalization_gap']):.4f} "
        f"is_best={bool(row.get('is_best', False))}"
    )


def carry_forward_best_checkpoint(source_checkpoint_path: str | None, destination: Path) -> str | None:
    if not source_checkpoint_path:
        return None
    source_path = Path(source_checkpoint_path)
    if source_path.parent.name == "checkpoints":
        best_candidate = source_path.parent / "best.pth"
        source_path = best_candidate if best_candidate.exists() else source_path
    if not source_path.exists():
        return None
    destination.parent.mkdir(parents=True, exist_ok=True)
    if source_path.resolve() != destination.resolve():
        shutil.copy2(source_path, destination)
    return str(source_path)


def load_resume_weights(
    checkpoint_path: str | None,
    model: nn.Module,
    ema: EMA | None,
    device: torch.device,
) -> tuple[int, float, int, dict[str, Any] | None]:
    if not checkpoint_path:
        return 0, float("-inf"), 0, None
    checkpoint = torch.load(checkpoint_path, map_location=device)
    model.load_state_dict(checkpoint["model"], strict=True)
    if ema is not None and checkpoint.get("ema_model") is not None:
        ema.shadow = {k: v.detach().clone().to(device) for k, v in checkpoint["ema_model"].items()}
    return (
        int(checkpoint.get("epoch", 0)),
        float(checkpoint.get("best_val_psnr", float("-inf"))),
        int(checkpoint.get("best_epoch", 0)),
        checkpoint.get("last_metrics"),
    )


def make_checkpoint_payload(
    *,
    epoch: int,
    model: nn.Module,
    ema: EMA | None,
    optimizer: torch.optim.Optimizer,
    scaler,
    last_metrics: dict[str, Any],
    best_val_psnr: float,
    best_epoch: int,
) -> dict[str, Any]:
    return {
        "epoch": int(epoch),
        "model": model.state_dict(),
        "ema_model": (ema.shadow if ema is not None else None),
        "optimizer": optimizer.state_dict(),
        "scaler": scaler.state_dict() if scaler.is_enabled() else None,
        "config": asdict(cfg),
        "model_config": asdict(model_cfg),
        "selected_weight_source": cfg.selected_weight_source,
        "best_metric_name": "val_psnr",
        "best_val_psnr": float(best_val_psnr),
        "best_epoch": int(best_epoch),
        "last_metrics": last_metrics,
    }


@torch.inference_mode()
def evaluate_psnr(model: nn.Module, loader: DataLoader, device: torch.device) -> dict[str, float]:
    model.eval()
    pred_meter = 0.0
    input_meter = 0.0
    count = 0
    for batch in loader:
        lr = move_image_batch(batch["lr"], device)
        hr = move_image_batch(batch["hr"], device)
        pred = model(lr).clamp(0, 1)
        pred_meter += batch_psnr(pred, hr)
        input_meter += batch_psnr(lr, hr)
        count += 1
    val_psnr = pred_meter / max(count, 1)
    input_psnr = input_meter / max(count, 1)
    return {
        "val_psnr": float(val_psnr),
        "input_psnr": float(input_psnr),
        "delta_psnr": float(val_psnr - input_psnr),
    }


def train_one_epoch(
    model: nn.Module,
    loader: DataLoader,
    optimizer: torch.optim.Optimizer,
    scaler,
    ema: EMA | None,
    device: torch.device,
) -> tuple[float, float]:
    model.train()
    amp_enabled = bool(cfg.use_amp and device.type == "cuda")
    loss_meter = 0.0
    psnr_meter = 0.0
    count = 0
    for batch in loader:
        lr = move_image_batch(batch["lr"], device)
        hr = move_image_batch(batch["hr"], device)
        optimizer.zero_grad(set_to_none=True)
        with autocast_context(device.type, amp_enabled):
            pred = model(lr)
            loss_info = compute_restoration_loss(pred, lr, hr)
            loss = loss_info["loss"]
        scaler.scale(loss).backward()
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(model.parameters(), cfg.grad_clip_norm)
        scaler.step(optimizer)
        scaler.update()
        if ema is not None:
            ema.update(model)
        with torch.no_grad():
            loss_meter += float(loss.item())
            psnr_meter += batch_psnr(pred.clamp(0, 1), hr)
            count += 1
    return loss_meter / max(count, 1), psnr_meter / max(count, 1)


def build_eval_model_from_checkpoint(checkpoint: dict[str, Any], device: torch.device, weight_source: str) -> nn.Module:
    eval_model = MixedKernelUNetResidualSR(model_cfg).to(device).eval()
    if weight_source == "ema":
        ema_state = checkpoint.get("ema_model")
        if ema_state is None:
            raise ValueError("Checkpoint is missing ema_model for selected_weight_source='ema'")
        eval_model.load_state_dict(ema_state, strict=True)
    else:
        eval_model.load_state_dict(checkpoint["model"], strict=True)
    if cfg.use_channels_last and device.type == "cuda":
        eval_model = eval_model.to(memory_format=torch.channels_last)
    return eval_model

# %%
validation_input_psnr = compute_input_psnr(val_loader, device)
print({"validation_input_psnr": validation_input_psnr, "loss_config": loss_config_summary()})

optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)
scaler = make_grad_scaler(enabled=(cfg.use_amp and device.type == "cuda"))
ema = EMA(model, decay=cfg.ema_decay) if cfg.use_ema else None
ema_eval_model = None
if ema is not None:
    ema_eval_model = MixedKernelUNetResidualSR(model_cfg).to(device)
    if cfg.use_channels_last and device.type == "cuda":
        ema_eval_model = ema_eval_model.to(memory_format=torch.channels_last)

metrics_header = [
    "epoch",
    "epoch_time_sec",
    "lr",
    "train_loss_residual",
    "train_patch_psnr",
    "train_eval_psnr",
    "val_psnr",
    "input_psnr",
    "delta_psnr",
    "generalization_gap",
    "is_best",
]

best_ckpt_path = checkpoints_dir / "best.pth"
last_ckpt_path = checkpoints_dir / "last.pth"
resume_history_rows = load_resume_history_rows(cfg.resume_checkpoint_path)
carried_best_checkpoint_path = carry_forward_best_checkpoint(cfg.resume_checkpoint_path, best_ckpt_path)
if carried_best_checkpoint_path:
    print({"carried_forward_best_checkpoint": carried_best_checkpoint_path, "new_best_checkpoint_path": str(best_ckpt_path)})

start_epoch, best_val_psnr, best_epoch, last_metrics = load_resume_weights(cfg.resume_checkpoint_path, model, ema, device)
history_rows = [dict(row) for row in resume_history_rows]
stop_reason = "completed_requested_epochs"
epochs_without_improve = 0
if history_rows and best_epoch:
    epochs_without_improve = max(0, int(history_rows[-1]["epoch"]) - int(best_epoch))

with metrics_csv_path.open("w", newline="", encoding="utf-8") as f:
    writer = csv.DictWriter(f, fieldnames=metrics_header)
    writer.writeheader()
    for row in history_rows:
        writer.writerow(row)
with epoch_logs_jsonl_path.open("w", encoding="utf-8") as f:
    for row in history_rows:
        f.write(json.dumps(row) + "\n")
write_history_json(history_json_path, history_rows, cfg.resume_checkpoint_path)

if history_rows:
    print("Replaying prior run history from history.json/metrics.csv")
    for row in history_rows:
        print_epoch_row(row)
elif last_metrics is not None:
    print("No metrics.csv found for resume run; using checkpoint last_metrics")
    print_epoch_row(normalize_history_row(last_metrics))

prev_row = history_rows[-1] if history_rows else None
dual_decline_streak = 0
run_epoch_limit = start_epoch + cfg.epochs if cfg.resume_checkpoint_path else cfg.epochs

for epoch in range(start_epoch, run_epoch_limit):
    train_ds.set_epoch(epoch)
    epoch_lr = lr_at_epoch(
        epoch - start_epoch,
        base_lr=cfg.lr,
        min_lr=cfg.min_lr,
        warmup_epochs=cfg.warmup_epochs,
        total_epochs=cfg.epochs,
    )
    for group in optimizer.param_groups:
        group["lr"] = epoch_lr

    t0 = time.perf_counter()
    train_loss_residual, train_patch_psnr = train_one_epoch(model, train_loader, optimizer, scaler, ema, device)

    eval_model = model
    if cfg.selected_weight_source == "ema":
        if ema is None or ema_eval_model is None:
            raise RuntimeError("EMA evaluation requested but EMA is disabled")
        ema.copy_to(ema_eval_model)
        eval_model = ema_eval_model

    val_metrics = evaluate_psnr(eval_model, val_loader, device)
    train_eval_metrics = evaluate_psnr(eval_model, train_eval_loader, device)
    epoch_time_sec = float(time.perf_counter() - t0)
    generalization_gap = float(train_eval_metrics["val_psnr"] - val_metrics["val_psnr"])
    is_best = bool(val_metrics["val_psnr"] > best_val_psnr)
    if is_best:
        best_val_psnr = float(val_metrics["val_psnr"])
        best_epoch = int(epoch + 1)
        epochs_without_improve = 0
    else:
        epochs_without_improve += 1

    row = {
        "epoch": int(epoch + 1),
        "epoch_time_sec": epoch_time_sec,
        "lr": current_lr(optimizer),
        "train_loss_residual": float(train_loss_residual),
        "train_patch_psnr": float(train_patch_psnr),
        "train_eval_psnr": float(train_eval_metrics["val_psnr"]),
        "val_psnr": float(val_metrics["val_psnr"]),
        "input_psnr": float(val_metrics["input_psnr"]),
        "delta_psnr": float(val_metrics["delta_psnr"]),
        "generalization_gap": generalization_gap,
        "is_best": is_best,
    }

    if cfg.training_mode == "stage2_resume" and prev_row is not None:
        if row["train_eval_psnr"] < prev_row["train_eval_psnr"] and row["val_psnr"] < prev_row["val_psnr"]:
            dual_decline_streak += 1
            if dual_decline_streak >= 2:
                print({
                    "warning": "stage2_train_eval_and_val_declining_together",
                    "decline_streak": dual_decline_streak,
                    "epoch": row["epoch"],
                    "train_eval_psnr": row["train_eval_psnr"],
                    "val_psnr": row["val_psnr"],
                })
        else:
            dual_decline_streak = 0

    payload = make_checkpoint_payload(
        epoch=row["epoch"],
        model=model,
        ema=ema,
        optimizer=optimizer,
        scaler=scaler,
        last_metrics=row,
        best_val_psnr=best_val_psnr,
        best_epoch=best_epoch,
    )
    torch.save(payload, last_ckpt_path)
    if is_best:
        torch.save(payload, best_ckpt_path)

    with metrics_csv_path.open("a", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=metrics_header)
        writer.writerow(row)
    with epoch_logs_jsonl_path.open("a", encoding="utf-8") as f:
        f.write(json.dumps(row) + "\n")
    history_rows.append(row)
    write_history_json(history_json_path, history_rows, cfg.resume_checkpoint_path)
    print_epoch_row(row)
    prev_row = row

    if epochs_without_improve >= cfg.early_stop_patience:
        stop_reason = f"early_stop_no_val_improvement_{cfg.early_stop_patience}"
        print({
            "stop_reason": stop_reason,
            "best_epoch": best_epoch,
            "best_val_psnr": best_val_psnr,
            "epochs_without_improve": epochs_without_improve,
        })
        break

latest_epoch = int(history_rows[-1]["epoch"]) if history_rows else start_epoch
print({
    "best_epoch": best_epoch,
    "best_val_psnr": best_val_psnr,
    "best_ckpt_path": str(best_ckpt_path),
    "last_ckpt_path": str(last_ckpt_path),
    "latest_epoch": latest_epoch,
    "stop_reason": stop_reason,
})
# Out:
# {'validation_input_psnr': 23.12304142543248, 'loss_config': {'type': 'residual_mse', 'mse_weight': 1.0}}
# {'carried_forward_best_checkpoint': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/20260424/hinet_lite_npu_v1_colab_v3_full_20260424_004323/checkpoints/best.pth', 'new_best_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/065325_2404/checkpoints/best.pth'}
# Replaying prior run history from history.json/metrics.csv
# [epoch 001] time=854.86s lr=0.000060 train_patch_psnr=24.3505 train_eval_psnr=24.4894 val_psnr=23.1279 generalization_gap=1.3615 is_best=True
# [epoch 002] time=37.98s lr=0.000120 train_patch_psnr=24.5605 train_eval_psnr=24.5060 val_psnr=23.1419 generalization_gap=1.3641 is_best=True
# [epoch 003] time=45.15s lr=0.000180 train_patch_psnr=24.7201 train_eval_psnr=24.5363 val_psnr=23.1678 generalization_gap=1.3685 is_best=True
# [epoch 004] time=46.11s lr=0.000240 train_patch_psnr=24.8413 train_eval_psnr=24.5827 val_psnr=23.2094 generalization_gap=1.3734 is_best=True
# [epoch 005] time=45.80s lr=0.000300 train_patch_psnr=24.9391 train_eval_psnr=24.6442 val_psnr=23.2667 generalization_gap=1.3775 is_best=True
# [epoch 006] time=45.64s lr=0.000300 train_patch_psnr=25.0297 train_eval_psnr=24.7256 val_psnr=23.3446 generalization_gap=1.3810 is_best=True
# [epoch 007] time=46.65s lr=0.000300 train_patch_psnr=25.0669 train_eval_psnr=24.8293 val_psnr=23.4442 generalization_gap=1.3851 is_best=True
# [epoch 008] time=46.32s lr=0.000300 train_patch_psnr=25.1173 train_eval_psnr=24.9477 val_psnr=23.5584 generalization_gap=1.3893 is_best=True
# [epoch 009] time=46.60s lr=0.000300 train_patch_psnr=25.2064 train_eval_psnr=25.0675 val_psnr=23.6749 generalization_gap=1.3926 is_best=True
# [epoch 010] time=45.73s lr=0.000299 train_patch_psnr=25.2592 train_eval_psnr=25.1751 val_psnr=23.7808 generalization_gap=1.3943 is_best=True
# [epoch 011] time=45.94s lr=0.000299 train_patch_psnr=25.3272 train_eval_psnr=25.2659 val_psnr=23.8721 generalization_gap=1.3938 is_best=True
# [epoch 012] time=46.66s lr=0.000299 train_patch_psnr=25.3625 train_eval_psnr=25.3376 val_psnr=23.9462 generalization_gap=1.3914 is_best=True
# [epoch 013] time=46.00s lr=0.000298 train_patch_psnr=25.4521 train_eval_psnr=25.3933 val_psnr=24.0048 generalization_gap=1.3886 is_best=True
# [epoch 014] time=46.47s lr=0.000298 train_patch_psnr=25.4950 train_eval_psnr=25.4332 val_psnr=24.0470 generalization_gap=1.3861 is_best=True
# [epoch 015] time=46.15s lr=0.000297 train_patch_psnr=25.6032 train_eval_psnr=25.4602 val_psnr=24.0762 generalization_gap=1.3840 is_best=True
# [epoch 016] time=46.66s lr=0.000296 train_patch_psnr=25.6338 train_eval_psnr=25.4718 val_psnr=24.0886 generalization_gap=1.3832 is_best=True
# [epoch 017] time=45.81s lr=0.000296 train_patch_psnr=25.7402 train_eval_psnr=25.4804 val_psnr=24.0989 generalization_gap=1.3815 is_best=True
# [epoch 018] time=46.56s lr=0.000295 train_patch_psnr=25.8274 train_eval_psnr=25.4825 val_psnr=24.1016 generalization_gap=1.3809 is_best=True
# [epoch 019] time=46.03s lr=0.000294 train_patch_psnr=25.8736 train_eval_psnr=25.4805 val_psnr=24.0990 generalization_gap=1.3815 is_best=False
# [epoch 020] time=42.68s lr=0.000293 train_patch_psnr=25.9829 train_eval_psnr=25.4714 val_psnr=24.0899 generalization_gap=1.3815 is_best=False
# [epoch 021] time=42.50s lr=0.000292 train_patch_psnr=26.0319 train_eval_psnr=25.4586 val_psnr=24.0769 generalization_gap=1.3817 is_best=False
# [epoch 022] time=42.95s lr=0.000291 train_patch_psnr=26.1109 train_eval_psnr=25.4413 val_psnr=24.0605 generalization_gap=1.3808 is_best=False
# [epoch 023] time=42.38s lr=0.000290 train_patch_psnr=26.1350 train_eval_psnr=25.4235 val_psnr=24.0418 generalization_gap=1.3817 is_best=False
# [epoch 024] time=42.88s lr=0.000289 train_patch_psnr=26.2449 train_eval_psnr=25.4026 val_psnr=24.0217 generalization_gap=1.3809 is_best=False
# [epoch 025] time=42.48s lr=0.000288 train_patch_psnr=26.3237 train_eval_psnr=25.3805 val_psnr=24.0004 generalization_gap=1.3801 is_best=False
# [epoch 026] time=42.78s lr=0.000287 train_patch_psnr=26.3683 train_eval_psnr=25.3579 val_psnr=23.9785 generalization_gap=1.3794 is_best=False
# [epoch 027] time=42.40s lr=0.000286 train_patch_psnr=26.4407 train_eval_psnr=25.3359 val_psnr=23.9571 generalization_gap=1.3787 is_best=False
# [epoch 028] time=42.43s lr=0.000285 train_patch_psnr=26.4913 train_eval_psnr=25.3124 val_psnr=23.9348 generalization_gap=1.3776 is_best=False
# [epoch 029] time=42.32s lr=0.000283 train_patch_psnr=26.5386 train_eval_psnr=25.2910 val_psnr=23.9142 generalization_gap=1.3767 is_best=False
# [epoch 030] time=42.25s lr=0.000282 train_patch_psnr=26.5897 train_eval_psnr=25.2707 val_psnr=23.8951 generalization_gap=1.3756 is_best=False
# [epoch 031] time=42.28s lr=0.000280 train_patch_psnr=26.6426 train_eval_psnr=25.2503 val_psnr=23.8758 generalization_gap=1.3745 is_best=False
# [epoch 032] time=42.40s lr=0.000279 train_patch_psnr=26.7384 train_eval_psnr=25.2259 val_psnr=23.8539 generalization_gap=1.3721 is_best=False
# [epoch 033] time=42.81s lr=0.000277 train_patch_psnr=26.7599 train_eval_psnr=25.2031 val_psnr=23.8322 generalization_gap=1.3709 is_best=False
# [epoch 034] time=843.68s lr=0.000276 train_patch_psnr=25.3018 train_eval_psnr=25.4445 val_psnr=24.0639 generalization_gap=1.3806 is_best=False
# [epoch 035] time=39.72s lr=0.000274 train_patch_psnr=25.4123 train_eval_psnr=25.5340 val_psnr=24.1499 generalization_gap=1.3840 is_best=True
# [epoch 036] time=46.36s lr=0.000272 train_patch_psnr=25.4804 train_eval_psnr=25.5795 val_psnr=24.1923 generalization_gap=1.3872 is_best=True
# [epoch 037] time=46.91s lr=0.000271 train_patch_psnr=25.5615 train_eval_psnr=25.6046 val_psnr=24.2152 generalization_gap=1.3894 is_best=True
# [epoch 038] time=47.15s lr=0.000269 train_patch_psnr=25.6372 train_eval_psnr=25.6201 val_psnr=24.2280 generalization_gap=1.3921 is_best=True
# [epoch 039] time=47.12s lr=0.000267 train_patch_psnr=25.7112 train_eval_psnr=25.6284 val_psnr=24.2339 generalization_gap=1.3945 is_best=True
# [epoch 040] time=46.47s lr=0.000265 train_patch_psnr=25.7827 train_eval_psnr=25.6316 val_psnr=24.2338 generalization_gap=1.3978 is_best=False
# [epoch 041] time=43.39s lr=0.000263 train_patch_psnr=25.8505 train_eval_psnr=25.6301 val_psnr=24.2300 generalization_gap=1.4002 is_best=False
# [epoch 042] time=42.83s lr=0.000261 train_patch_psnr=25.9499 train_eval_psnr=25.6241 val_psnr=24.2225 generalization_gap=1.4016 is_best=False
# [epoch 043] time=43.43s lr=0.000259 train_patch_psnr=26.0479 train_eval_psnr=25.6152 val_psnr=24.2122 generalization_gap=1.4030 is_best=False
# [epoch 044] time=42.82s lr=0.000257 train_patch_psnr=26.1254 train_eval_psnr=25.6032 val_psnr=24.1984 generalization_gap=1.4048 is_best=False
# [epoch 045] time=43.16s lr=0.000255 train_patch_psnr=26.1987 train_eval_psnr=25.5867 val_psnr=24.1816 generalization_gap=1.4051 is_best=False
# [epoch 046] time=42.81s lr=0.000253 train_patch_psnr=26.2857 train_eval_psnr=25.5687 val_psnr=24.1632 generalization_gap=1.4055 is_best=False
# [epoch 047] time=42.91s lr=0.000251 train_patch_psnr=26.3376 train_eval_psnr=25.5477 val_psnr=24.1427 generalization_gap=1.4051 is_best=False
# [epoch 048] time=43.37s lr=0.000248 train_patch_psnr=26.4526 train_eval_psnr=25.5251 val_psnr=24.1208 generalization_gap=1.4043 is_best=False
# [epoch 049] time=42.78s lr=0.000246 train_patch_psnr=26.5020 train_eval_psnr=25.5017 val_psnr=24.0980 generalization_gap=1.4037 is_best=False
# [epoch 050] time=43.28s lr=0.000244 train_patch_psnr=26.5602 train_eval_psnr=25.4783 val_psnr=24.0749 generalization_gap=1.4034 is_best=False
# [epoch 051] time=42.77s lr=0.000241 train_patch_psnr=26.6269 train_eval_psnr=25.4533 val_psnr=24.0509 generalization_gap=1.4024 is_best=False
# [epoch 052] time=43.52s lr=0.000239 train_patch_psnr=26.6799 train_eval_psnr=25.4309 val_psnr=24.0282 generalization_gap=1.4027 is_best=False
# [epoch 053] time=42.91s lr=0.000237 train_patch_psnr=26.7461 train_eval_psnr=25.4066 val_psnr=24.0048 generalization_gap=1.4018 is_best=False
# [epoch 054] time=43.47s lr=0.000234 train_patch_psnr=26.7994 train_eval_psnr=25.3813 val_psnr=23.9806 generalization_gap=1.4007 is_best=False
# [epoch 055] time=42.78s lr=0.000232 train_patch_psnr=26.8674 train_eval_psnr=25.3560 val_psnr=23.9562 generalization_gap=1.3998 is_best=False
# [epoch 056] time=42.93s lr=0.000229 train_patch_psnr=26.8864 train_eval_psnr=25.3310 val_psnr=23.9322 generalization_gap=1.3988 is_best=False
# [epoch 057] time=43.34s lr=0.000227 train_patch_psnr=26.9435 train_eval_psnr=25.3082 val_psnr=23.9106 generalization_gap=1.3976 is_best=False
# [epoch 058] time=42.82s lr=0.000224 train_patch_psnr=27.0049 train_eval_psnr=25.2859 val_psnr=23.8888 generalization_gap=1.3971 is_best=False
# [epoch 059] time=43.27s lr=0.000221 train_patch_psnr=27.0453 train_eval_psnr=25.2639 val_psnr=23.8674 generalization_gap=1.3965 is_best=False
# [epoch 060] time=43.03s lr=0.000219 train_patch_psnr=27.1131 train_eval_psnr=25.2397 val_psnr=23.8448 generalization_gap=1.3949 is_best=False
# [epoch 061] time=42.95s lr=0.000216 train_patch_psnr=27.1411 train_eval_psnr=25.2173 val_psnr=23.8230 generalization_gap=1.3942 is_best=False
# [epoch 062] time=43.25s lr=0.000214 train_patch_psnr=27.2050 train_eval_psnr=25.1956 val_psnr=23.8013 generalization_gap=1.3944 is_best=False
# [epoch 063] time=42.87s lr=0.000211 train_patch_psnr=27.2433 train_eval_psnr=25.1748 val_psnr=23.7808 generalization_gap=1.3940 is_best=False
# [epoch 064] time=43.20s lr=0.000208 train_patch_psnr=27.2511 train_eval_psnr=25.1551 val_psnr=23.7629 generalization_gap=1.3923 is_best=False
# [epoch 065] time=42.91s lr=0.000205 train_patch_psnr=27.3333 train_eval_psnr=25.1339 val_psnr=23.7425 generalization_gap=1.3914 is_best=False
# [epoch 066] time=42.77s lr=0.000203 train_patch_psnr=27.3359 train_eval_psnr=25.1143 val_psnr=23.7241 generalization_gap=1.3902 is_best=False
# [epoch 067] time=43.33s lr=0.000200 train_patch_psnr=27.3876 train_eval_psnr=25.0956 val_psnr=23.7055 generalization_gap=1.3901 is_best=False
# [epoch 068] time=42.80s lr=0.000197 train_patch_psnr=27.4234 train_eval_psnr=25.0771 val_psnr=23.6878 generalization_gap=1.3893 is_best=False
# [epoch 069] time=43.34s lr=0.000194 train_patch_psnr=27.4769 train_eval_psnr=25.0584 val_psnr=23.6699 generalization_gap=1.3885 is_best=False
# [epoch 070] time=42.87s lr=0.000191 train_patch_psnr=27.5161 train_eval_psnr=25.0398 val_psnr=23.6523 generalization_gap=1.3876 is_best=False
# [epoch 071] time=42.82s lr=0.000188 train_patch_psnr=27.5351 train_eval_psnr=25.0220 val_psnr=23.6345 generalization_gap=1.3875 is_best=False
# [epoch 072] time=42.81s lr=0.000186 train_patch_psnr=27.5536 train_eval_psnr=25.0058 val_psnr=23.6193 generalization_gap=1.3866 is_best=False
# [epoch 073] time=42.91s lr=0.000183 train_patch_psnr=27.6066 train_eval_psnr=24.9882 val_psnr=23.6023 generalization_gap=1.3860 is_best=False
# [epoch 074] time=43.39s lr=0.000180 train_patch_psnr=27.6209 train_eval_psnr=24.9713 val_psnr=23.5860 generalization_gap=1.3853 is_best=False
# [epoch 075] time=42.95s lr=0.000177 train_patch_psnr=27.6494 train_eval_psnr=24.9556 val_psnr=23.5709 generalization_gap=1.3847 is_best=False
# [epoch 076] time=43.56s lr=0.000174 train_patch_psnr=27.6896 train_eval_psnr=24.9402 val_psnr=23.5569 generalization_gap=1.3833 is_best=False
# [epoch 077] time=43.06s lr=0.000171 train_patch_psnr=27.7624 train_eval_psnr=24.9237 val_psnr=23.5410 generalization_gap=1.3827 is_best=False
# [epoch 078] time=42.88s lr=0.000168 train_patch_psnr=27.7726 train_eval_psnr=24.9070 val_psnr=23.5248 generalization_gap=1.3822 is_best=False
# [epoch 079] time=43.35s lr=0.000165 train_patch_psnr=27.8106 train_eval_psnr=24.8903 val_psnr=23.5082 generalization_gap=1.3821 is_best=False
# [epoch 080] time=42.94s lr=0.000162 train_patch_psnr=27.8408 train_eval_psnr=24.8755 val_psnr=23.4934 generalization_gap=1.3822 is_best=False
# [epoch 081] time=43.39s lr=0.000159 train_patch_psnr=27.8594 train_eval_psnr=24.8593 val_psnr=23.4772 generalization_gap=1.3821 is_best=False
# [epoch 082] time=42.80s lr=0.000156 train_patch_psnr=27.8791 train_eval_psnr=24.8446 val_psnr=23.4633 generalization_gap=1.3813 is_best=False
# [epoch 083] time=43.28s lr=0.000154 train_patch_psnr=27.9074 train_eval_psnr=24.8299 val_psnr=23.4492 generalization_gap=1.3807 is_best=False
# [epoch 084] time=43.08s lr=0.000151 train_patch_psnr=27.9240 train_eval_psnr=24.8155 val_psnr=23.4362 generalization_gap=1.3793 is_best=False
# [epoch 085] time=42.92s lr=0.000148 train_patch_psnr=27.9905 train_eval_psnr=24.8006 val_psnr=23.4217 generalization_gap=1.3789 is_best=False
# [epoch 086] time=43.27s lr=0.000145 train_patch_psnr=28.0005 train_eval_psnr=24.7855 val_psnr=23.4068 generalization_gap=1.3786 is_best=False
# [epoch 087] time=42.81s lr=0.000142 train_patch_psnr=28.0292 train_eval_psnr=24.7702 val_psnr=23.3920 generalization_gap=1.3782 is_best=False
# [epoch 088] time=43.37s lr=0.000139 train_patch_psnr=28.0460 train_eval_psnr=24.7548 val_psnr=23.3771 generalization_gap=1.3777 is_best=False
# [epoch 089] time=42.72s lr=0.000136 train_patch_psnr=28.0712 train_eval_psnr=24.7396 val_psnr=23.3629 generalization_gap=1.3766 is_best=False
# [epoch 090] time=43.23s lr=0.000133 train_patch_psnr=28.0726 train_eval_psnr=24.7245 val_psnr=23.3487 generalization_gap=1.3758 is_best=False
# [epoch 091] time=42.95s lr=0.000130 train_patch_psnr=28.1183 train_eval_psnr=24.7100 val_psnr=23.3352 generalization_gap=1.3748 is_best=False
# [epoch 092] time=43.31s lr=0.000127 train_patch_psnr=28.1521 train_eval_psnr=24.6955 val_psnr=23.3218 generalization_gap=1.3736 is_best=False
# [epoch 093] time=42.96s lr=0.000124 train_patch_psnr=28.1805 train_eval_psnr=24.6810 val_psnr=23.3079 generalization_gap=1.3732 is_best=False
# [epoch 094] time=43.05s lr=0.000122 train_patch_psnr=28.1873 train_eval_psnr=24.6670 val_psnr=23.2949 generalization_gap=1.3722 is_best=False
# [epoch 095] time=43.34s lr=0.000119 train_patch_psnr=28.1943 train_eval_psnr=24.6532 val_psnr=23.2815 generalization_gap=1.3717 is_best=False
# [epoch 096] time=42.92s lr=0.000116 train_patch_psnr=28.2286 train_eval_psnr=24.6399 val_psnr=23.2692 generalization_gap=1.3707 is_best=False
# [epoch 097] time=43.23s lr=0.000113 train_patch_psnr=28.2535 train_eval_psnr=24.6258 val_psnr=23.2559 generalization_gap=1.3699 is_best=False
# [epoch 098] time=42.68s lr=0.000110 train_patch_psnr=28.2573 train_eval_psnr=24.6126 val_psnr=23.2437 generalization_gap=1.3690 is_best=False
# [epoch 099] time=43.26s lr=0.000107 train_patch_psnr=28.3021 train_eval_psnr=24.5989 val_psnr=23.2302 generalization_gap=1.3687 is_best=False
# [epoch 100] time=42.76s lr=0.000105 train_patch_psnr=28.3048 train_eval_psnr=24.5856 val_psnr=23.2172 generalization_gap=1.3684 is_best=False
# [epoch 101] time=42.92s lr=0.000102 train_patch_psnr=28.3467 train_eval_psnr=24.5723 val_psnr=23.2045 generalization_gap=1.3679 is_best=False
# [epoch 102] time=43.21s lr=0.000099 train_patch_psnr=28.3513 train_eval_psnr=24.5594 val_psnr=23.1924 generalization_gap=1.3671 is_best=False
# [epoch 103] time=42.94s lr=0.000096 train_patch_psnr=28.3899 train_eval_psnr=24.5472 val_psnr=23.1805 generalization_gap=1.3667 is_best=False
# [epoch 104] time=43.29s lr=0.000094 train_patch_psnr=28.3895 train_eval_psnr=24.5343 val_psnr=23.1677 generalization_gap=1.3666 is_best=False
# [epoch 105] time=42.97s lr=0.000091 train_patch_psnr=28.4031 train_eval_psnr=24.5222 val_psnr=23.1553 generalization_gap=1.3669 is_best=False
# [epoch 106] time=43.20s lr=0.000089 train_patch_psnr=28.4433 train_eval_psnr=24.5095 val_psnr=23.1434 generalization_gap=1.3661 is_best=False
# [epoch 107] time=42.90s lr=0.000086 train_patch_psnr=28.4540 train_eval_psnr=24.4970 val_psnr=23.1316 generalization_gap=1.3654 is_best=False
# [epoch 108] time=43.29s lr=0.000083 train_patch_psnr=28.4585 train_eval_psnr=24.4847 val_psnr=23.1195 generalization_gap=1.3652 is_best=False
# [epoch 109] time=42.89s lr=0.000081 train_patch_psnr=28.4708 train_eval_psnr=24.4725 val_psnr=23.1079 generalization_gap=1.3646 is_best=False
# [epoch 110] time=43.36s lr=0.000078 train_patch_psnr=28.4858 train_eval_psnr=24.4607 val_psnr=23.0969 generalization_gap=1.3638 is_best=False
# [epoch 111] time=42.77s lr=0.000076 train_patch_psnr=28.5110 train_eval_psnr=24.4490 val_psnr=23.0859 generalization_gap=1.3631 is_best=False
# [epoch 112] time=43.27s lr=0.000073 train_patch_psnr=28.5256 train_eval_psnr=24.4373 val_psnr=23.0746 generalization_gap=1.3628 is_best=False
# [epoch 113] time=42.81s lr=0.000071 train_patch_psnr=28.5439 train_eval_psnr=24.4251 val_psnr=23.0627 generalization_gap=1.3624 is_best=False
# [epoch 114] time=43.23s lr=0.000069 train_patch_psnr=28.5696 train_eval_psnr=24.4140 val_psnr=23.0519 generalization_gap=1.3621 is_best=False
# [epoch 115] time=42.89s lr=0.000066 train_patch_psnr=28.5782 train_eval_psnr=24.4028 val_psnr=23.0408 generalization_gap=1.3620 is_best=False
# [epoch 116] time=42.93s lr=0.000064 train_patch_psnr=28.5886 train_eval_psnr=24.3915 val_psnr=23.0302 generalization_gap=1.3613 is_best=False
# [epoch 117] time=43.28s lr=0.000062 train_patch_psnr=28.6200 train_eval_psnr=24.3808 val_psnr=23.0201 generalization_gap=1.3607 is_best=False
# [epoch 118] time=42.92s lr=0.000059 train_patch_psnr=28.6126 train_eval_psnr=24.3697 val_psnr=23.0094 generalization_gap=1.3603 is_best=False
# [epoch 119] time=43.32s lr=0.000057 train_patch_psnr=28.6321 train_eval_psnr=24.3597 val_psnr=22.9992 generalization_gap=1.3606 is_best=False
# [epoch 120] time=42.77s lr=0.000055 train_patch_psnr=28.6360 train_eval_psnr=24.3494 val_psnr=22.9891 generalization_gap=1.3603 is_best=False
# [epoch 121] time=43.39s lr=0.000053 train_patch_psnr=28.6460 train_eval_psnr=24.3394 val_psnr=22.9794 generalization_gap=1.3599 is_best=False
# [epoch 122] time=42.87s lr=0.000051 train_patch_psnr=28.6631 train_eval_psnr=24.3297 val_psnr=22.9700 generalization_gap=1.3597 is_best=False
# [epoch 123] time=43.37s lr=0.000049 train_patch_psnr=28.6726 train_eval_psnr=24.3202 val_psnr=22.9605 generalization_gap=1.3597 is_best=False
# [epoch 124] time=42.92s lr=0.000047 train_patch_psnr=28.6824 train_eval_psnr=24.3106 val_psnr=22.9510 generalization_gap=1.3596 is_best=False
# [epoch 125] time=42.88s lr=0.000045 train_patch_psnr=28.6969 train_eval_psnr=24.3013 val_psnr=22.9422 generalization_gap=1.3591 is_best=False
# [epoch 126] time=43.19s lr=0.000043 train_patch_psnr=28.7078 train_eval_psnr=24.2924 val_psnr=22.9335 generalization_gap=1.3590 is_best=False
# [epoch 127] time=42.93s lr=0.000041 train_patch_psnr=28.7138 train_eval_psnr=24.2837 val_psnr=22.9247 generalization_gap=1.3590 is_best=False
# [epoch 128] time=43.10s lr=0.000039 train_patch_psnr=28.7316 train_eval_psnr=24.2758 val_psnr=22.9169 generalization_gap=1.3589 is_best=False
# [epoch 129] time=42.99s lr=0.000038 train_patch_psnr=28.7359 train_eval_psnr=24.2678 val_psnr=22.9087 generalization_gap=1.3591 is_best=False
# [epoch 130] time=43.25s lr=0.000036 train_patch_psnr=28.7354 train_eval_psnr=24.2595 val_psnr=22.9003 generalization_gap=1.3592 is_best=False
# [epoch 131] time=42.93s lr=0.000034 train_patch_psnr=28.7627 train_eval_psnr=24.2518 val_psnr=22.8924 generalization_gap=1.3594 is_best=False
# [epoch 132] time=43.16s lr=0.000033 train_patch_psnr=28.7460 train_eval_psnr=24.2437 val_psnr=22.8843 generalization_gap=1.3594 is_best=False
# [epoch 133] time=42.80s lr=0.000031 train_patch_psnr=28.7774 train_eval_psnr=24.2363 val_psnr=22.8767 generalization_gap=1.3595 is_best=False
# [epoch 134] time=43.34s lr=0.000030 train_patch_psnr=28.7635 train_eval_psnr=24.2290 val_psnr=22.8696 generalization_gap=1.3595 is_best=False
# [epoch 135] time=42.98s lr=0.000028 train_patch_psnr=28.7733 train_eval_psnr=24.2223 val_psnr=22.8627 generalization_gap=1.3597 is_best=False
# [epoch 136] time=43.28s lr=0.000027 train_patch_psnr=28.7921 train_eval_psnr=24.2156 val_psnr=22.8560 generalization_gap=1.3596 is_best=False
# [epoch 137] time=42.76s lr=0.000025 train_patch_psnr=28.7927 train_eval_psnr=24.2088 val_psnr=22.8493 generalization_gap=1.3595 is_best=False
# [epoch 138] time=43.19s lr=0.000024 train_patch_psnr=28.8177 train_eval_psnr=24.2027 val_psnr=22.8430 generalization_gap=1.3597 is_best=False
# [epoch 139] time=42.75s lr=0.000023 train_patch_psnr=28.8100 train_eval_psnr=24.1967 val_psnr=22.8371 generalization_gap=1.3597 is_best=False
# [epoch 140] time=43.00s lr=0.000022 train_patch_psnr=28.8088 train_eval_psnr=24.1910 val_psnr=22.8312 generalization_gap=1.3598 is_best=False
# [epoch 141] time=43.18s lr=0.000021 train_patch_psnr=28.8067 train_eval_psnr=24.1853 val_psnr=22.8255 generalization_gap=1.3599 is_best=False
# [epoch 142] time=43.06s lr=0.000020 train_patch_psnr=28.8140 train_eval_psnr=24.1798 val_psnr=22.8198 generalization_gap=1.3600 is_best=False
# [epoch 143] time=43.43s lr=0.000019 train_patch_psnr=28.8306 train_eval_psnr=24.1750 val_psnr=22.8150 generalization_gap=1.3600 is_best=False
# [epoch 144] time=43.04s lr=0.000018 train_patch_psnr=28.8444 train_eval_psnr=24.1701 val_psnr=22.8101 generalization_gap=1.3601 is_best=False
# [epoch 145] time=43.28s lr=0.000017 train_patch_psnr=28.8339 train_eval_psnr=24.1653 val_psnr=22.8053 generalization_gap=1.3600 is_best=False
# [epoch 146] time=42.81s lr=0.000016 train_patch_psnr=28.8557 train_eval_psnr=24.1611 val_psnr=22.8010 generalization_gap=1.3601 is_best=False
# [epoch 147] time=43.15s lr=0.000015 train_patch_psnr=28.8536 train_eval_psnr=24.1564 val_psnr=22.7963 generalization_gap=1.3601 is_best=False
# [epoch 148] time=42.90s lr=0.000014 train_patch_psnr=28.8397 train_eval_psnr=24.1523 val_psnr=22.7922 generalization_gap=1.3601 is_best=False
# [epoch 149] time=43.35s lr=0.000014 train_patch_psnr=28.8642 train_eval_psnr=24.1488 val_psnr=22.7886 generalization_gap=1.3602 is_best=False
# [epoch 150] time=42.87s lr=0.000013 train_patch_psnr=28.8541 train_eval_psnr=24.1448 val_psnr=22.7846 generalization_gap=1.3602 is_best=False
# [epoch 151] time=43.37s lr=0.000012 train_patch_psnr=28.8607 train_eval_psnr=24.1412 val_psnr=22.7809 generalization_gap=1.3604 is_best=False
# [epoch 152] time=43.34s lr=0.000012 train_patch_psnr=28.8583 train_eval_psnr=24.1379 val_psnr=22.7776 generalization_gap=1.3603 is_best=False
# [epoch 153] time=42.79s lr=0.000011 train_patch_psnr=28.8703 train_eval_psnr=24.1348 val_psnr=22.7745 generalization_gap=1.3603 is_best=False
# [epoch 154] time=43.35s lr=0.000011 train_patch_psnr=28.8871 train_eval_psnr=24.1316 val_psnr=22.7713 generalization_gap=1.3603 is_best=False
# [epoch 155] time=42.86s lr=0.000011 train_patch_psnr=28.8586 train_eval_psnr=24.1288 val_psnr=22.7684 generalization_gap=1.3604 is_best=False
# [epoch 156] time=43.28s lr=0.000010 train_patch_psnr=28.8704 train_eval_psnr=24.1259 val_psnr=22.7655 generalization_gap=1.3604 is_best=False
# [epoch 157] time=42.94s lr=0.000010 train_patch_psnr=28.8839 train_eval_psnr=24.1234 val_psnr=22.7630 generalization_gap=1.3603 is_best=False
# [epoch 158] time=43.23s lr=0.000010 train_patch_psnr=28.8732 train_eval_psnr=24.1207 val_psnr=22.7603 generalization_gap=1.3604 is_best=False
# [epoch 159] time=42.81s lr=0.000010 train_patch_psnr=28.8645 train_eval_psnr=24.1185 val_psnr=22.7581 generalization_gap=1.3604 is_best=False
# [epoch 160] time=43.30s lr=0.000010 train_patch_psnr=28.8956 train_eval_psnr=24.1158 val_psnr=22.7555 generalization_gap=1.3603 is_best=False
# [epoch 040] time=1021.89s lr=0.000060 train_patch_psnr=25.4616 train_eval_psnr=25.9306 val_psnr=24.2646 generalization_gap=1.6660 is_best=True
# [epoch 041] time=54.47s lr=0.000059 train_patch_psnr=25.5389 train_eval_psnr=25.9600 val_psnr=24.2890 generalization_gap=1.6710 is_best=True
# [epoch 042] time=57.17s lr=0.000058 train_patch_psnr=25.5734 train_eval_psnr=25.9813 val_psnr=24.3052 generalization_gap=1.6762 is_best=True
# [epoch 043] time=57.32s lr=0.000056 train_patch_psnr=25.6181 train_eval_psnr=25.9969 val_psnr=24.3160 generalization_gap=1.6809 is_best=True
# [epoch 044] time=57.87s lr=0.000054 train_patch_psnr=25.6633 train_eval_psnr=26.0090 val_psnr=24.3231 generalization_gap=1.6859 is_best=True
# [epoch 045] time=57.63s lr=0.000051 train_patch_psnr=25.7006 train_eval_psnr=26.0166 val_psnr=24.3262 generalization_gap=1.6904 is_best=True
# [epoch 046] time=57.54s lr=0.000048 train_patch_psnr=25.7098 train_eval_psnr=26.0215 val_psnr=24.3264 generalization_gap=1.6951 is_best=True
# [epoch 047] time=58.08s lr=0.000045 train_patch_psnr=25.7406 train_eval_psnr=26.0246 val_psnr=24.3243 generalization_gap=1.7003 is_best=False
# [epoch 048] time=54.24s lr=0.000042 train_patch_psnr=25.7945 train_eval_psnr=26.0248 val_psnr=24.3200 generalization_gap=1.7048 is_best=False
# [epoch 049] time=54.68s lr=0.000038 train_patch_psnr=25.8230 train_eval_psnr=26.0237 val_psnr=24.3145 generalization_gap=1.7092 is_best=False
# {'warning': 'stage2_train_eval_and_val_declining_together', 'decline_streak': 2, 'epoch': 50, 'train_eval_psnr': 26.021005034446716, 'val_psnr': 24.307277270725795}
# [epoch 050] time=54.32s lr=0.000034 train_patch_psnr=25.8544 train_eval_psnr=26.0210 val_psnr=24.3073 generalization_gap=1.7137 is_best=False
# {'warning': 'stage2_train_eval_and_val_declining_together', 'decline_streak': 3, 'epoch': 51, 'train_eval_psnr': 26.017151951789856, 'val_psnr': 24.299415043422155}
# [epoch 051] time=54.69s lr=0.000031 train_patch_psnr=25.8625 train_eval_psnr=26.0172 val_psnr=24.2994 generalization_gap=1.7177 is_best=False
# {'warning': 'stage2_train_eval_and_val_declining_together', 'decline_streak': 4, 'epoch': 52, 'train_eval_psnr': 26.012384176254272, 'val_psnr': 24.29093905857631}
# [epoch 052] time=54.25s lr=0.000027 train_patch_psnr=25.9000 train_eval_psnr=26.0124 val_psnr=24.2909 generalization_gap=1.7214 is_best=False
# {'stop_reason': 'early_stop_no_val_improvement_6', 'best_epoch': 46, 'best_val_psnr': 24.326435361589706, 'epochs_without_improve': 6}
# {'best_epoch': 46, 'best_val_psnr': 24.326435361589706, 'best_ckpt_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/065325_2404/checkpoints/best.pth', 'last_ckpt_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/065325_2404/checkpoints/last.pth', 'latest_epoch': 52, 'stop_reason': 'early_stop_no_val_improvement_6'}

# %% [markdown]
# ## 4. Validation

# %%
def tensor_to_uint8_image(x: torch.Tensor) -> Image.Image:
    x = x.detach().cpu().clamp(0, 1)
    arr = (x.permute(1, 2, 0).numpy() * 255.0).round().astype(np.uint8)
    return Image.fromarray(arr)


@torch.no_grad()
def write_val_preview(model: nn.Module, loader: DataLoader, out_dir: Path, device: torch.device) -> dict[str, str]:
    out_dir.mkdir(parents=True, exist_ok=True)
    batch = next(iter(loader))
    lr = move_image_batch(batch["lr"], device)
    hr = move_image_batch(batch["hr"], device)
    name = batch["name"][0]
    pred = model(lr).clamp(0, 1)
    lr_path = out_dir / "val_preview_input.png"
    pred_path = out_dir / "val_preview_pred.png"
    hr_path = out_dir / "val_preview_target.png"
    tensor_to_uint8_image(lr[0]).save(lr_path)
    tensor_to_uint8_image(pred[0]).save(pred_path)
    tensor_to_uint8_image(hr[0]).save(hr_path)
    return {
        "sample_name": str(name),
        "input": str(lr_path),
        "prediction": str(pred_path),
        "target": str(hr_path),
    }


checkpoint = torch.load(best_ckpt_path, map_location=device)
checkpoint_weight_source = checkpoint.get("selected_weight_source", cfg.selected_weight_source)
best_eval_model = build_eval_model_from_checkpoint(checkpoint, device, checkpoint_weight_source)
preview_info = write_val_preview(best_eval_model, val_loader, exports_dir / "val_preview", device)
validation_summary = evaluate_psnr(best_eval_model, val_loader, device)
print({
    "validation_summary": validation_summary,
    "best_epoch": best_epoch,
    "best_val_psnr": best_val_psnr,
    "preview": preview_info,
})
# Out:
# {'validation_summary': {'val_psnr': 24.326435361589706, 'input_psnr': 23.12304142543248, 'delta_psnr': 1.2033939361572266}, 'best_epoch': 46, 'best_val_psnr': 24.326435361589706, 'preview': {'sample_name': '0000', 'input': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/065325_2404/exports/val_preview/val_preview_input.png', 'prediction': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/065325_2404/exports/val_preview/val_preview_pred.png', 'target': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/065325_2404/exports/val_preview/val_preview_target.png'}}

# %% [markdown]
# ## 5. Export and Submission

# %%
onnx_path = exports_dir / f"{cfg.model_id}.onnx"
mxq_target_path = exports_dir / f"{cfg.model_id}.mxq"


dummy = torch.randn(1, 3, 256, 256, device=device)
if cfg.use_channels_last and device.type == "cuda":
    dummy = dummy.contiguous(memory_format=torch.channels_last)

torch.onnx.export(
    best_eval_model,
    dummy,
    str(onnx_path),
    input_names=["input"],
    output_names=["output"],
    opset_version=17,
    dynamo=False,
)

onnx_model = onnx.load(str(onnx_path))
onnx.checker.check_model(onnx_model)
node_ops = [node.op_type for node in onnx_model.graph.node]
node_ops_set = set(node_ops)
audit_ops = ["Add", "Sum", "Mul", "Resize", "MatMul", "InstanceNormalization"]
flagged_ops = [op for op in audit_ops if op in node_ops_set]
op_audit = {
    "graph_op_count": len(node_ops),
    "flagged_ops_found": flagged_ops,
    "selected_weight_source": checkpoint_weight_source,
    "norm_free_graph": "InstanceNormalization" not in node_ops_set,
    "model_num_parameters": model_num_parameters,
}
print({"onnx_path": str(onnx_path), **op_audit})

parity_result = {
    "attempted": False,
    "onnxruntime_available": False,
    "passed": False,
    "max_abs_diff": None,
    "selected_weight_source": checkpoint_weight_source,
}
try:
    import onnxruntime as ort

    parity_result["attempted"] = True
    parity_result["onnxruntime_available"] = True
    cpu_model = build_eval_model_from_checkpoint(checkpoint, torch.device("cpu"), checkpoint_weight_source).cpu().eval()
    parity_input = torch.randn(1, 3, 256, 256)
    with torch.no_grad():
        torch_out = cpu_model(parity_input).detach().cpu().numpy()
    ort_session = ort.InferenceSession(str(onnx_path), providers=["CPUExecutionProvider"])
    ort_out = ort_session.run(["output"], {"input": parity_input.numpy()})[0]
    max_abs_diff = float(np.max(np.abs(torch_out - ort_out)))
    parity_result["max_abs_diff"] = max_abs_diff
    parity_result["passed"] = bool(max_abs_diff < 1e-3)
    if not parity_result["passed"]:
        raise RuntimeError(f"ONNX parity failed: max_abs_diff={max_abs_diff:.6f}")
except ImportError:
    print("onnxruntime not installed; skipping CPU parity check")
print(parity_result)


def write_calibration_bundle(train_pairs: list[tuple[Path, Path, str]], out_dir: Path, max_items: int = 32) -> dict[str, Any]:
    out_dir.mkdir(parents=True, exist_ok=True)
    selected = train_pairs[: max_items]
    manifest = {"source": "train_pairs_only", "count": len(selected), "items": []}
    for idx, (lr_path, _, name) in enumerate(selected):
        dst = out_dir / f"cal_{idx:04d}.png"
        Image.open(lr_path).convert("RGB").save(dst)
        manifest["items"].append({"name": name, "lr_source": str(lr_path), "cal_path": str(dst)})
    manifest_path = out_dir / "manifest.json"
    manifest_path.write_text(json.dumps(manifest, indent=2), encoding="utf-8")
    return {"calibration_dir": str(out_dir), "manifest_path": str(manifest_path), "count": len(selected)}


cal_info = write_calibration_bundle(train_pairs, calibration_dir, max_items=32)
mxq_handoff = {
    "mxq_target_path": str(mxq_target_path),
    "conversion_script_hint": "lab3_step2_onnx_to_mxq.py",
    "onnx_input_path": str(onnx_path),
    "calibration_manifest_path": cal_info["manifest_path"],
}
summary = {
    "model_id": cfg.model_id,
    "training_mode": cfg.training_mode,
    "model_config": asdict(model_cfg),
    "model_num_parameters": model_num_parameters,
    "config": asdict(cfg),
    "pair_summary": {
        "train_pairs": len(train_pairs),
        "val_pairs": len(val_pairs),
        "train_eval_subset_size": len(train_eval_pairs),
        "train_eval_sample_names": train_eval_sample_names,
    },
    "validation_input_psnr": float(validation_input_psnr),
    "loss_config": loss_config_summary(),
    "lr_schedule": {
        "type": "warmup_cosine",
        "warmup_epochs": cfg.warmup_epochs,
        "base_lr": cfg.lr,
        "min_lr": cfg.min_lr,
    },
    "selected_weight_source": checkpoint_weight_source,
    "stop_reason": stop_reason,
    "latest_epoch": int(latest_epoch),
    "best_val_psnr": float(best_val_psnr),
    "best_epoch": int(best_epoch),
    "metrics_csv_path": str(metrics_csv_path),
    "epoch_logs_jsonl_path": str(epoch_logs_jsonl_path),
    "history_json_path": str(history_json_path),
    "best_checkpoint_path": str(best_ckpt_path),
    "last_checkpoint_path": str(last_ckpt_path),
    "onnx_path": str(onnx_path),
    "op_audit": op_audit,
    "parity_result": parity_result,
    "calibration": cal_info,
    "mxq_handoff": mxq_handoff,
    "val_preview": preview_info,
}
summary_path.write_text(json.dumps(summary, indent=2), encoding="utf-8")
print({
    "summary_path": str(summary_path),
    "best_checkpoint": str(best_ckpt_path),
    "onnx": str(onnx_path),
    "calibration_manifest": cal_info["manifest_path"],
    "mxq_target": str(mxq_target_path),
    "selected_weight_source": checkpoint_weight_source,
    "stop_reason": stop_reason,
})
# Out:
# /tmp/ipykernel_13318/2559650825.py:9: DeprecationWarning: You are using the legacy TorchScript-based ONNX export. Starting in PyTorch 2.9, the new torch.export-based ONNX exporter has become the default. Learn more about the new export logic: https://docs.pytorch.org/docs/stable/onnx_export.html. For exporting control flow: https://pytorch.org/tutorials/beginner/onnx/export_control_flow_model_to_onnx_tutorial.html
#   torch.onnx.export(
# {'onnx_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/065325_2404/exports/hinet_lite_npu_v1.onnx', 'graph_op_count': 122, 'flagged_ops_found': ['Add', 'Mul'], 'selected_weight_source': 'ema', 'norm_free_graph': True, 'model_num_parameters': {'total': 10453443, 'trainable': 10453443}}
# {'attempted': True, 'onnxruntime_available': True, 'passed': True, 'max_abs_diff': 7.748603820800781e-07, 'selected_weight_source': 'ema'}
# {'summary_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/065325_2404/summary.json', 'best_checkpoint': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/065325_2404/checkpoints/best.pth', 'onnx': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/065325_2404/exports/hinet_lite_npu_v1.onnx', 'calibration_manifest': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/065325_2404/exports/calibration/manifest.json', 'mxq_target': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/065325_2404/exports/hinet_lite_npu_v1.mxq', 'selected_weight_source': 'ema', 'stop_reason': 'early_stop_no_val_improvement_6'}
