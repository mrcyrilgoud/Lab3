# %% [markdown]
# # Lab 3 - TinySRCNNResidual (No-Add Colab)
#
# - Goal: train a TinySRCNN-style no-add super-resolution model for Lab 3.
# - Expected input/output: `256x256x3`
# - Runtime target: Google Colab with Google Drive.
# - Note: MXQ conversion is intentionally handled outside this notebook.

# %% [markdown]
# ## 1. Setup
#
# This notebook follows the Lab 3 rubric structure while keeping the implementation lean.

# %%
try:
    import google.colab  # type: ignore
    IN_COLAB_BOOTSTRAP = True
except Exception:
    IN_COLAB_BOOTSTRAP = False

if IN_COLAB_BOOTSTRAP:
    # %pip install -q onnx onnxruntime

import csv
import json
import math
import os
import random
import sys
import time
from contextlib import nullcontext
from dataclasses import asdict, dataclass
from datetime import datetime
from pathlib import Path
from typing import Any

import numpy as np
import onnx
import torch
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
from torch.utils.data import DataLoader, Dataset


IMAGE_SUFFIXES = {'.png', '.jpg', '.jpeg', '.bmp'}
DRIVE_ROOT = Path('/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3')
DRIVE_DATA_ROOT = DRIVE_ROOT / 'Data'
DRIVE_RUNS_ROOT = DRIVE_ROOT / 'runs'

try:
    BICUBIC_RESAMPLE = Image.Resampling.BICUBIC
except AttributeError:
    BICUBIC_RESAMPLE = Image.BICUBIC

try:
    FLIP_LEFT_RIGHT = Image.Transpose.FLIP_LEFT_RIGHT
    FLIP_TOP_BOTTOM = Image.Transpose.FLIP_TOP_BOTTOM
    ROTATE_90 = Image.Transpose.ROTATE_90
    ROTATE_180 = Image.Transpose.ROTATE_180
    ROTATE_270 = Image.Transpose.ROTATE_270
except AttributeError:
    FLIP_LEFT_RIGHT = Image.FLIP_LEFT_RIGHT
    FLIP_TOP_BOTTOM = Image.FLIP_TOP_BOTTOM
    ROTATE_90 = Image.ROTATE_90
    ROTATE_180 = Image.ROTATE_180
    ROTATE_270 = Image.ROTATE_270


def set_global_seed(seed: int) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


def now_stamp() -> str:
    return datetime.now().strftime('%H%M%S_%d%m')


def is_colab_runtime() -> bool:
    try:
        import google.colab  # type: ignore  # noqa: F401
        return True
    except Exception:
        return False


def auto_num_workers(in_colab: bool) -> int:
    if sys.platform == 'darwin':
        return 0
    cpu_count = max(os.cpu_count() or 2, 2)
    if in_colab:
        return min(4, max(cpu_count - 1, 2))
    return min(2, cpu_count)


def resolve_repo_root(start: Path) -> Path:
    current = start.resolve()
    for candidate in [current, *current.parents]:
        if (candidate / 'Data').exists() and (candidate / 'runs').exists():
            return candidate
    for candidate in [current, *current.parents]:
        if (candidate / 'Data').exists():
            return candidate
    raise FileNotFoundError(f'Could not locate repo root from {start.resolve()}')


def make_unique_run_root(runs_root: Path, run_slug: str = '') -> Path:
    safe_slug = ''.join(ch if ch.isalnum() or ch in '_-' else '_' for ch in run_slug).strip('_')
    suffix = f'_{safe_slug}' if safe_slug else ''
    candidate = runs_root / f'{now_stamp()}{suffix}'
    while candidate.exists():
        time.sleep(1.1)
        candidate = runs_root / f'{now_stamp()}{suffix}'
    return candidate


def read_checkpoint_identity(checkpoint_path: Path) -> dict[str, Any] | None:
    try:
        checkpoint = torch.load(checkpoint_path, map_location='cpu')
    except Exception:
        return None
    config = checkpoint.get('config') or {}
    model_id = config.get('model_id')
    if not model_id:
        return None
    return {
        'path': str(checkpoint_path),
        'model_id': model_id,
        'epoch': int(checkpoint.get('epoch', 0)),
        'kind': checkpoint_path.name,
        'mtime': checkpoint_path.stat().st_mtime,
    }


def find_latest_model_checkpoint(runs_root: Path, model_id: str, filename: str = 'last.pth') -> str | None:
    candidates: list[dict[str, Any]] = []
    for checkpoint_path in runs_root.rglob(f'checkpoints/{filename}'):
        identity = read_checkpoint_identity(checkpoint_path)
        if identity and identity['model_id'] == model_id:
            candidates.append(identity)
    if not candidates:
        return None
    winner = max(candidates, key=lambda item: item['mtime'])
    return winner['path']


def resolve_resume_checkpoint_path(resume_checkpoint_path: str | None, runs_root: Path, model_id: str) -> str | None:
    if not resume_checkpoint_path:
        return None
    if resume_checkpoint_path == 'last.pth':
        return find_latest_model_checkpoint(runs_root, model_id, filename='last.pth')
    path = Path(resume_checkpoint_path)
    if not path.is_absolute():
        path = runs_root / path
    if path.name == 'exports':
        candidate_paths = [path.parent / 'checkpoints' / 'last.pth']
    elif path.is_dir():
        candidate_paths = [path / 'last.pth']
    else:
        candidate_paths = [path]
    for candidate in candidate_paths:
        if candidate.is_file():
            return str(candidate)
    return None



def required_relative_dirs() -> list[Path]:
    paths: list[Path] = []
    for hr_rel, lr_rel, _ in (
        ('LR_HR/L3_HR_train1', 'L3_LR/L3_L3_train1', 'L3_HR_train1'),
        ('LR_HR/L3_HR_train2', 'L3_LR/L3_L3_train2', 'L3_HR_train2'),
        ('LR_HR/L3_HR_train3', 'L3_LR/L3_LR_train3', 'L3_HR_train3'),
        ('LR_HR/L3_HR_train4', 'L3_LR/L3_LR_train4', 'L3_HR_train4'),
        ('LR_HR/L3_HR_train', 'L3_LR/L3_LR_train', 'L3_HR_train'),
    ):
        paths.append(Path(hr_rel))
        paths.append(Path(lr_rel))
    paths.append(Path('L3_HR_valid'))
    paths.append(Path('L3_LR_valid'))
    return paths


def stage_data_root(source_root: Path, local_root: Path) -> Path:
    import shutil

    required = required_relative_dirs()
    if all((local_root / rel).exists() for rel in required):
        print({
            'data_staging': 'reuse_existing',
            'source_root': str(source_root),
            'local_root': str(local_root),
        })
        return local_root

    start = time.time()
    for rel in required:
        src_dir = source_root / rel
        dst_dir = local_root / rel
        dst_dir.parent.mkdir(parents=True, exist_ok=True)
        if dst_dir.exists():
            shutil.rmtree(dst_dir)
        shutil.copytree(src_dir, dst_dir)
    elapsed = time.time() - start
    print({
        'data_staging': 'copied_to_local',
        'source_root': str(source_root),
        'local_root': str(local_root),
        'elapsed_sec': round(elapsed, 2),
    })
    return local_root


@dataclass
class RunConfig:
    model_id: str = 'tinysrcnn_noadd_lrelu'
    run_slug: str = 'base'
    enable_resume: bool = True
    resume_checkpoint_path: str | None = '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/072607_2504_base/exports/'
    seed: int = 1337
    train_patch_size: int = 256
    eval_size: int = 256
    batch_size: int = 16
    epochs: int = 5000
    lr: float = 1e-4
    min_lr: float = 1e-6
    weight_decay: float = 1e-4
    warmup_epochs: int = 8
    num_workers: int | None = 2
    prefetch_factor: int = 2
    use_amp: bool = True
    use_ema: bool = True
    ema_decay: float = 0.999


cfg = RunConfig()
in_colab = is_colab_runtime()
if in_colab:
    from google.colab import drive  # type: ignore

    drive.mount('/content/drive', force_remount=False)
    data_root = DRIVE_DATA_ROOT
    runs_root = DRIVE_RUNS_ROOT
    if not data_root.exists():
        raise FileNotFoundError(f'Google Drive data root not found: {data_root}')
else:
    repo_root = resolve_repo_root(Path.cwd())
    data_root = repo_root / 'Data'
    runs_root = repo_root / 'runs'
    if not data_root.exists():
        raise FileNotFoundError(f'Data root not found: {data_root}')

runs_root.mkdir(parents=True, exist_ok=True)
if cfg.num_workers is None:
    cfg.num_workers = auto_num_workers(in_colab)
if cfg.enable_resume:
    cfg.resume_checkpoint_path = resolve_resume_checkpoint_path(cfg.resume_checkpoint_path, runs_root, cfg.model_id)
else:
    cfg.resume_checkpoint_path = None

run_root = make_unique_run_root(runs_root, cfg.run_slug)
checkpoints_dir = run_root / 'checkpoints'
exports_dir = run_root / 'exports'
preview_dir = exports_dir / 'val_preview'
summary_path = run_root / 'summary.json'
metrics_csv_path = run_root / 'metrics.csv'

for directory in [run_root, checkpoints_dir, exports_dir, preview_dir]:
    directory.mkdir(parents=True, exist_ok=True)

set_global_seed(cfg.seed)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
if device.type == 'cuda':
    torch.backends.cudnn.benchmark = True
    if hasattr(torch.backends.cuda.matmul, 'allow_tf32'):
        torch.backends.cuda.matmul.allow_tf32 = True
    if hasattr(torch.backends.cudnn, 'allow_tf32'):
        torch.backends.cudnn.allow_tf32 = True
    if hasattr(torch, 'set_float32_matmul_precision'):
        torch.set_float32_matmul_precision('high')

print({
    'device': str(device),
    'data_root': str(data_root),
    'runs_root': str(runs_root),
    'run_root': str(run_root),
    'config': asdict(cfg),
})
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# {'device': 'cuda', 'data_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/Data', 'runs_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs', 'run_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/161827_2504_base', 'config': {'model_id': 'tinysrcnn_noadd_lrelu', 'run_slug': 'base', 'enable_resume': True, 'resume_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/072607_2504_base/checkpoints/last.pth', 'seed': 1337, 'train_patch_size': 256, 'eval_size': 256, 'batch_size': 16, 'epochs': 5000, 'lr': 0.0001, 'min_lr': 1e-06, 'weight_decay': 0.0001, 'warmup_epochs': 8, 'num_workers': 2, 'prefetch_factor': 2, 'use_amp': True, 'use_ema': True, 'ema_decay': 0.999}}

# %% [markdown]
# ## 2. Data

# %%
L3_TRAIN_SPLITS = (
    ('LR_HR/L3_HR_train1', 'L3_LR/L3_L3_train1', 'L3_HR_train1'),
    ('LR_HR/L3_HR_train2', 'L3_LR/L3_L3_train2', 'L3_HR_train2'),
    ('LR_HR/L3_HR_train3', 'L3_LR/L3_LR_train3', 'L3_HR_train3'),
    ('LR_HR/L3_HR_train4', 'L3_LR/L3_LR_train4', 'L3_HR_train4'),
    ('LR_HR/L3_HR_train', 'L3_LR/L3_LR_train', 'L3_HR_train'),
)
L3_VAL_DIRS = ('L3_HR_valid', 'L3_LR_valid')


def scan_image_directory(directory: Path) -> dict[str, Path]:
    if not directory.exists():
        raise FileNotFoundError(f'Missing directory: {directory}')
    return {
        path.stem: path
        for path in directory.iterdir()
        if path.is_file() and path.suffix.lower() in IMAGE_SUFFIXES
    }


def collect_split_pairs(hr_dir: Path, lr_dir: Path, split_name: str) -> list[tuple[Path, Path, str]]:
    hr_map = scan_image_directory(hr_dir)
    lr_map = scan_image_directory(lr_dir)
    pairs: list[tuple[Path, Path, str]] = []
    for stem in sorted(set(hr_map) & set(lr_map)):
        name = stem if split_name == 'val' else f'{split_name}/{stem}'
        pairs.append((lr_map[stem], hr_map[stem], name))
    return pairs


def collect_all_pairs(data_root: Path) -> tuple[list[tuple[Path, Path, str]], list[tuple[Path, Path, str]]]:
    train_pairs: list[tuple[Path, Path, str]] = []
    for hr_rel, lr_rel, split_name in L3_TRAIN_SPLITS:
        train_pairs.extend(collect_split_pairs(data_root / hr_rel, data_root / lr_rel, split_name))
    val_pairs = collect_split_pairs(data_root / L3_VAL_DIRS[0], data_root / L3_VAL_DIRS[1], 'val')
    return train_pairs, val_pairs


class PairedSRDataset(Dataset):
    def __init__(self, pairs: list[tuple[Path, Path, str]], *, train: bool, patch_size: int, eval_size: int, seed: int):
        self.pairs = pairs
        self.train = train
        self.patch_size = patch_size
        self.eval_size = eval_size
        self.seed = seed
        self.epoch = 0

    def set_epoch(self, epoch: int) -> None:
        self.epoch = epoch

    @staticmethod
    def to_tensor(img: Image.Image) -> torch.Tensor:
        arr = np.asarray(img, dtype=np.float32) / 255.0
        return torch.from_numpy(arr).permute(2, 0, 1).contiguous()

    def augment_pair(self, lr: Image.Image, hr: Image.Image, index: int) -> tuple[Image.Image, Image.Image]:
        rng = random.Random((self.seed * 1_000_003) + (self.epoch * 9_973) + index)
        width, height = lr.size
        patch = self.patch_size
        if width < patch or height < patch:
            lr = lr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            hr = hr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            width, height = lr.size
        left = rng.randint(0, width - patch)
        top = rng.randint(0, height - patch)
        box = (left, top, left + patch, top + patch)
        lr = lr.crop(box)
        hr = hr.crop(box)
        if rng.random() < 0.5:
            lr = lr.transpose(FLIP_LEFT_RIGHT)
            hr = hr.transpose(FLIP_LEFT_RIGHT)
        if rng.random() < 0.5:
            lr = lr.transpose(FLIP_TOP_BOTTOM)
            hr = hr.transpose(FLIP_TOP_BOTTOM)
        rot = rng.choice([0, 1, 2, 3])
        if rot:
            rotate_ops = [ROTATE_90, ROTATE_180, ROTATE_270]
            lr = lr.transpose(rotate_ops[rot - 1])
            hr = hr.transpose(rotate_ops[rot - 1])
        return lr, hr

    def __len__(self) -> int:
        return len(self.pairs)

    def __getitem__(self, index: int) -> dict[str, Any]:
        lr_path, hr_path, name = self.pairs[index]
        lr = Image.open(lr_path).convert('RGB')
        hr = Image.open(hr_path).convert('RGB')
        if self.train:
            lr, hr = self.augment_pair(lr, hr, index)
        elif lr.size != (self.eval_size, self.eval_size):
            lr = lr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            hr = hr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
        return {'lr': self.to_tensor(lr), 'hr': self.to_tensor(hr), 'name': name}


train_pairs, val_pairs = collect_all_pairs(data_root)
if not train_pairs:
    raise FileNotFoundError(f'No training pairs found under {data_root}')
if not val_pairs:
    raise FileNotFoundError(f'No validation pairs found under {data_root}')
print({
    'data_root': str(data_root),
    'train_pairs': len(train_pairs),
    'val_pairs': len(val_pairs),
})

train_ds = PairedSRDataset(train_pairs, train=True, patch_size=cfg.train_patch_size, eval_size=cfg.eval_size, seed=cfg.seed)
val_ds = PairedSRDataset(val_pairs, train=False, patch_size=cfg.train_patch_size, eval_size=cfg.eval_size, seed=cfg.seed)

loader_num_workers = cfg.num_workers if cfg.num_workers is not None else auto_num_workers(in_colab)
train_loader_kwargs = {
    'dataset': train_ds,
    'batch_size': cfg.batch_size,
    'shuffle': True,
    'num_workers': loader_num_workers,
    'pin_memory': device.type == 'cuda',
}
val_loader_kwargs = {
    'dataset': val_ds,
    'batch_size': 1,
    'shuffle': False,
    'num_workers': loader_num_workers,
    'pin_memory': device.type == 'cuda',
}
if loader_num_workers > 0:
    train_loader_kwargs['prefetch_factor'] = cfg.prefetch_factor
    val_loader_kwargs['prefetch_factor'] = cfg.prefetch_factor

train_loader = DataLoader(**train_loader_kwargs)
val_loader = DataLoader(**val_loader_kwargs)

sample_batch = next(iter(val_loader))
print({
    'validation_input_shape': tuple(sample_batch['lr'].shape),
    'validation_target_shape': tuple(sample_batch['hr'].shape),
    'sample_name': sample_batch['name'][0],
})
# Out:
# {'data_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/Data', 'train_pairs': 2217, 'val_pairs': 110}
# {'validation_input_shape': (1, 3, 256, 256), 'validation_target_shape': (1, 3, 256, 256), 'sample_name': '0000'}

# %% [markdown]
# ## 3. Model and Training

# %%
class TinySRCNNNoAdd(nn.Module):
    def __init__(self, channels: int = 64, slope: float = 0.1):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(3, channels, 3, padding=1),
            nn.LeakyReLU(slope, inplace=False),
            nn.Conv2d(channels, channels, 3, padding=1),
            nn.LeakyReLU(slope, inplace=False),
            nn.Conv2d(channels, channels, 3, padding=1),
            nn.LeakyReLU(slope, inplace=False),
            nn.Conv2d(channels, channels, 3, padding=1),
            nn.LeakyReLU(slope, inplace=False),
            nn.Conv2d(channels, 3, 3, padding=1),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.net(x)


def count_parameters(module: nn.Module) -> int:
    return int(sum(param.numel() for param in module.parameters()))


class EMA:
    def __init__(self, model: nn.Module, decay: float):
        self.decay = decay
        self.shadow = {k: v.detach().clone() for k, v in model.state_dict().items()}

    @torch.no_grad()
    def update(self, model: nn.Module) -> None:
        for key, value in model.state_dict().items():
            self.shadow[key].mul_(self.decay).add_(value.detach(), alpha=1.0 - self.decay)

    @torch.no_grad()
    def copy_to(self, model: nn.Module) -> None:
        model.load_state_dict(self.shadow, strict=True)


def make_grad_scaler(enabled: bool):
    if hasattr(torch, 'amp') and hasattr(torch.amp, 'GradScaler'):
        return torch.amp.GradScaler('cuda', enabled=enabled)
    return torch.cuda.amp.GradScaler(enabled=enabled)


def autocast_context(device_type: str, enabled: bool):
    if not enabled:
        return nullcontext()
    if hasattr(torch, 'amp') and hasattr(torch.amp, 'autocast'):
        return torch.amp.autocast(device_type=device_type, enabled=enabled)
    return torch.cuda.amp.autocast(enabled=enabled)


@torch.no_grad()
def batch_psnr(pred: torch.Tensor, target: torch.Tensor) -> float:
    mse = F.mse_loss(pred, target, reduction='none').mean(dim=(1, 2, 3))
    psnr = 10.0 * torch.log10(1.0 / torch.clamp(mse, min=1e-12))
    return float(psnr.mean().item())


def compute_loss(pred: torch.Tensor, hr: torch.Tensor) -> torch.Tensor:
    loss_mse = F.mse_loss(pred, hr)
    loss_l1 = F.l1_loss(pred, hr)
    return 0.8 * loss_mse + 0.2 * loss_l1


def lr_at_epoch(epoch_idx: int, *, base_lr: float, min_lr: float, warmup_epochs: int, total_epochs: int) -> float:
    step = epoch_idx + 1
    if warmup_epochs > 0 and step <= warmup_epochs:
        return base_lr * step / max(1, warmup_epochs)
    progress = max(0.0, (step - warmup_epochs) / max(1, total_epochs - warmup_epochs))
    cosine = 0.5 * (1.0 + math.cos(math.pi * min(progress, 1.0)))
    return min_lr + cosine * (base_lr - min_lr)


@torch.inference_mode()
def evaluate_psnr(model: nn.Module, loader: DataLoader, device: torch.device) -> float:
    model.eval()
    meter = 0.0
    count = 0
    for batch in loader:
        lr = batch['lr'].to(device, non_blocking=(device.type == 'cuda'))
        hr = batch['hr'].to(device, non_blocking=(device.type == 'cuda'))
        pred = model(lr).clamp(0.0, 1.0)
        meter += batch_psnr(pred, hr)
        count += 1
    return meter / max(count, 1)


@torch.inference_mode()
def compute_input_psnr(loader: DataLoader, device: torch.device) -> float:
    meter = 0.0
    count = 0
    for batch in loader:
        lr = batch['lr'].to(device, non_blocking=(device.type == 'cuda'))
        hr = batch['hr'].to(device, non_blocking=(device.type == 'cuda'))
        meter += batch_psnr(lr, hr)
        count += 1
    return meter / max(count, 1)


def tensor_to_uint8_image(x: torch.Tensor) -> Image.Image:
    x = x.detach().cpu().clamp(0.0, 1.0)
    arr = (x.permute(1, 2, 0).numpy() * 255.0).round().astype(np.uint8)
    return Image.fromarray(arr)


@torch.no_grad()
def write_val_preview(model: nn.Module, loader: DataLoader, out_dir: Path, device: torch.device) -> dict[str, str]:
    out_dir.mkdir(parents=True, exist_ok=True)
    batch = next(iter(loader))
    lr = batch['lr'].to(device, non_blocking=(device.type == 'cuda'))
    hr = batch['hr'].to(device, non_blocking=(device.type == 'cuda'))
    pred = model(lr).clamp(0.0, 1.0)
    name = batch['name'][0]
    lr_path = out_dir / 'val_preview_input.png'
    pred_path = out_dir / 'val_preview_pred.png'
    hr_path = out_dir / 'val_preview_target.png'
    tensor_to_uint8_image(lr[0]).save(lr_path)
    tensor_to_uint8_image(pred[0]).save(pred_path)
    tensor_to_uint8_image(hr[0]).save(hr_path)
    return {
        'sample_name': str(name),
        'input': str(lr_path),
        'prediction': str(pred_path),
        'target': str(hr_path),
    }


def checkpoint_payload(model: nn.Module, ema: EMA | None, optimizer: torch.optim.Optimizer, epoch: int, best_val_psnr: float, row: dict[str, Any]) -> dict[str, Any]:
    return {
        'config': asdict(cfg),
        'epoch': int(epoch),
        'model_state_dict': model.state_dict(),
        'ema_state_dict': ema.shadow if ema is not None else None,
        'optimizer_state_dict': optimizer.state_dict(),
        'best_val_psnr': float(best_val_psnr),
        'selected_weight_source': 'ema' if ema is not None else 'raw',
        'last_metrics': row,
    }


def build_eval_model_from_checkpoint(checkpoint_path: Path, device: torch.device) -> nn.Module:
    checkpoint = torch.load(checkpoint_path, map_location=device)
    model = TinySRCNNNoAdd().to(device)
    selected = checkpoint.get('selected_weight_source', 'raw')
    ema_state = checkpoint.get('ema_state_dict')
    if selected == 'ema' and ema_state is not None:
        model.load_state_dict(ema_state, strict=True)
    else:
        model.load_state_dict(checkpoint['model_state_dict'], strict=True)
    model.eval()
    return model


model = TinySRCNNNoAdd().to(device)
eval_model = TinySRCNNNoAdd().to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)
scaler = make_grad_scaler(enabled=(cfg.use_amp and device.type == 'cuda'))
ema = EMA(model, decay=cfg.ema_decay) if cfg.use_ema else None
start_epoch = 0
best_val_psnr = float('-inf')
if cfg.enable_resume and cfg.resume_checkpoint_path:
    checkpoint = torch.load(cfg.resume_checkpoint_path, map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'], strict=True)
    optimizer_state = checkpoint.get('optimizer_state_dict')
    if optimizer_state is not None:
        optimizer.load_state_dict(optimizer_state)
    ema_state = checkpoint.get('ema_state_dict')
    if ema is not None and ema_state is not None:
        ema.shadow = {key: value.detach().clone() for key, value in ema_state.items()}
    start_epoch = int(checkpoint.get('epoch', 0))
    best_val_psnr = float(checkpoint.get('best_val_psnr', float('-inf')))
if ema is not None:
    ema.copy_to(eval_model)
else:
    eval_model.load_state_dict(model.state_dict())

model_parameter_count = count_parameters(model)
print({
    'model_id': cfg.model_id,
    'architecture': 'Conv3x3(3->64) x4 with LeakyReLU, final Conv3x3(64->3), no Add',
    'params': model_parameter_count,
    'resume_checkpoint_path': cfg.resume_checkpoint_path,
    'start_epoch': start_epoch,
})

input_psnr = compute_input_psnr(val_loader, device)
print({'baseline_input_psnr': input_psnr})
# Out:
# {'model_id': 'tinysrcnn_noadd_lrelu', 'architecture': 'Conv3x3(3->64) x4 with LeakyReLU, final Conv3x3(64->3), no Add', 'params': 114307, 'resume_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/072607_2504_base/checkpoints/last.pth', 'start_epoch': 1000}
# {'baseline_input_psnr': 23.133060299266468}

# %%
metrics_header = [
    'epoch',
    'epoch_time_sec',
    'lr',
    'train_loss',
    'train_psnr',
    'val_psnr',
    'best_val_psnr',
]

best_ckpt_path = checkpoints_dir / 'best.pth'
last_ckpt_path = checkpoints_dir / 'last.pth'

with metrics_csv_path.open('w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=metrics_header)
    writer.writeheader()

for epoch in range(start_epoch, cfg.epochs):
    train_ds.set_epoch(epoch)
    epoch_lr = lr_at_epoch(
        epoch,
        base_lr=cfg.lr,
        min_lr=cfg.min_lr,
        warmup_epochs=cfg.warmup_epochs,
        total_epochs=cfg.epochs,
    )
    for group in optimizer.param_groups:
        group['lr'] = epoch_lr

    epoch_start = time.time()
    model.train()
    train_loss_sum = 0.0
    train_psnr_sum = 0.0
    train_batches = 0

    for batch in train_loader:
        lr = batch['lr'].to(device, non_blocking=(device.type == 'cuda'))
        hr = batch['hr'].to(device, non_blocking=(device.type == 'cuda'))

        optimizer.zero_grad(set_to_none=True)
        with autocast_context(device.type, enabled=(cfg.use_amp and device.type == 'cuda')):
            pred = model(lr)
            loss = compute_loss(pred, hr)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        if ema is not None:
            ema.update(model)

        train_loss_sum += float(loss.item())
        train_psnr_sum += batch_psnr(pred.detach().clamp(0.0, 1.0), hr)
        train_batches += 1

    if ema is not None:
        ema.copy_to(eval_model)
    else:
        eval_model.load_state_dict(model.state_dict())
    eval_model.eval()

    avg_train_loss = train_loss_sum / max(train_batches, 1)
    avg_train_psnr = train_psnr_sum / max(train_batches, 1)
    val_psnr = evaluate_psnr(eval_model, val_loader, device)
    epoch_time = time.time() - epoch_start
    is_best = val_psnr > best_val_psnr
    if is_best:
        best_val_psnr = val_psnr

    row = {
        'epoch': epoch + 1,
        'epoch_time_sec': round(epoch_time, 2),
        'lr': epoch_lr,
        'train_loss': round(avg_train_loss, 6),
        'train_psnr': round(avg_train_psnr, 4),
        'val_psnr': round(val_psnr, 4),
        'best_val_psnr': round(best_val_psnr, 4),
    }
    print(row)

    with metrics_csv_path.open('a', newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=metrics_header)
        writer.writerow(row)

    payload = checkpoint_payload(model, ema, optimizer, epoch + 1, best_val_psnr, row)
    torch.save(payload, last_ckpt_path)
    if is_best:
        torch.save(payload, best_ckpt_path)
# Out:
# {'epoch': 1001, 'epoch_time_sec': 1853.91, 'lr': 9.064498625421081e-05, 'train_loss': 0.012435, 'train_psnr': 24.6832, 'val_psnr': 23.7147, 'best_val_psnr': 23.7159}
# {'epoch': 1002, 'epoch_time_sec': 12.35, 'lr': 9.062675360042891e-05, 'train_loss': 0.012065, 'train_psnr': 24.8636, 'val_psnr': 23.7147, 'best_val_psnr': 23.7159}
# {'epoch': 1003, 'epoch_time_sec': 12.63, 'lr': 9.060850505442578e-05, 'train_loss': 0.012076, 'train_psnr': 24.857, 'val_psnr': 23.7147, 'best_val_psnr': 23.7159}
# {'epoch': 1004, 'epoch_time_sec': 12.44, 'lr': 9.059024062342873e-05, 'train_loss': 0.012071, 'train_psnr': 24.8619, 'val_psnr': 23.7149, 'best_val_psnr': 23.7159}
# {'epoch': 1005, 'epoch_time_sec': 12.51, 'lr': 9.05719603146714e-05, 'train_loss': 0.012071, 'train_psnr': 24.8607, 'val_psnr': 23.7149, 'best_val_psnr': 23.7159}
# {'epoch': 1006, 'epoch_time_sec': 12.49, 'lr': 9.055366413539372e-05, 'train_loss': 0.012082, 'train_psnr': 24.8543, 'val_psnr': 23.7149, 'best_val_psnr': 23.7159}
# {'epoch': 1007, 'epoch_time_sec': 12.55, 'lr': 9.053535209284192e-05, 'train_loss': 0.012079, 'train_psnr': 24.8572, 'val_psnr': 23.7151, 'best_val_psnr': 23.7159}
# {'epoch': 1008, 'epoch_time_sec': 12.58, 'lr': 9.051702419426846e-05, 'train_loss': 0.012049, 'train_psnr': 24.8718, 'val_psnr': 23.7152, 'best_val_psnr': 23.7159}
# {'epoch': 1009, 'epoch_time_sec': 12.82, 'lr': 9.049868044693213e-05, 'train_loss': 0.012078, 'train_psnr': 24.8586, 'val_psnr': 23.7153, 'best_val_psnr': 23.7159}
# {'epoch': 1010, 'epoch_time_sec': 12.22, 'lr': 9.048032085809797e-05, 'train_loss': 0.012065, 'train_psnr': 24.8641, 'val_psnr': 23.7154, 'best_val_psnr': 23.7159}
# {'epoch': 1011, 'epoch_time_sec': 12.31, 'lr': 9.046194543503733e-05, 'train_loss': 0.012076, 'train_psnr': 24.8592, 'val_psnr': 23.7155, 'best_val_psnr': 23.7159}
# {'epoch': 1012, 'epoch_time_sec': 12.23, 'lr': 9.044355418502778e-05, 'train_loss': 0.012061, 'train_psnr': 24.8668, 'val_psnr': 23.7156, 'best_val_psnr': 23.7159}
# {'epoch': 1013, 'epoch_time_sec': 12.3, 'lr': 9.04251471153532e-05, 'train_loss': 0.012061, 'train_psnr': 24.8675, 'val_psnr': 23.7157, 'best_val_psnr': 23.7159}
# {'epoch': 1014, 'epoch_time_sec': 12.6, 'lr': 9.04067242333037e-05, 'train_loss': 0.012057, 'train_psnr': 24.8685, 'val_psnr': 23.7158, 'best_val_psnr': 23.7159}
# {'epoch': 1015, 'epoch_time_sec': 12.66, 'lr': 9.03882855461757e-05, 'train_loss': 0.012063, 'train_psnr': 24.8671, 'val_psnr': 23.7159, 'best_val_psnr': 23.7159}
# {'epoch': 1016, 'epoch_time_sec': 12.4, 'lr': 9.036983106127183e-05, 'train_loss': 0.012086, 'train_psnr': 24.8572, 'val_psnr': 23.716, 'best_val_psnr': 23.716}
# {'epoch': 1017, 'epoch_time_sec': 12.63, 'lr': 9.035136078590101e-05, 'train_loss': 0.012051, 'train_psnr': 24.8716, 'val_psnr': 23.7161, 'best_val_psnr': 23.7161}
# {'epoch': 1018, 'epoch_time_sec': 12.37, 'lr': 9.033287472737838e-05, 'train_loss': 0.01206, 'train_psnr': 24.8655, 'val_psnr': 23.7164, 'best_val_psnr': 23.7164}
# {'epoch': 1019, 'epoch_time_sec': 12.34, 'lr': 9.031437289302538e-05, 'train_loss': 0.01209, 'train_psnr': 24.8534, 'val_psnr': 23.7167, 'best_val_psnr': 23.7167}
# {'epoch': 1020, 'epoch_time_sec': 12.27, 'lr': 9.029585529016966e-05, 'train_loss': 0.012045, 'train_psnr': 24.8755, 'val_psnr': 23.7168, 'best_val_psnr': 23.7168}
# {'epoch': 1021, 'epoch_time_sec': 12.25, 'lr': 9.027732192614513e-05, 'train_loss': 0.012066, 'train_psnr': 24.8645, 'val_psnr': 23.7168, 'best_val_psnr': 23.7168}
# {'epoch': 1022, 'epoch_time_sec': 12.2, 'lr': 9.025877280829192e-05, 'train_loss': 0.012076, 'train_psnr': 24.8626, 'val_psnr': 23.717, 'best_val_psnr': 23.717}
# {'epoch': 1023, 'epoch_time_sec': 12.26, 'lr': 9.024020794395645e-05, 'train_loss': 0.012071, 'train_psnr': 24.8626, 'val_psnr': 23.7172, 'best_val_psnr': 23.7172}
# {'epoch': 1024, 'epoch_time_sec': 12.32, 'lr': 9.022162734049132e-05, 'train_loss': 0.012056, 'train_psnr': 24.8699, 'val_psnr': 23.7175, 'best_val_psnr': 23.7175}
# {'epoch': 1025, 'epoch_time_sec': 12.5, 'lr': 9.020303100525539e-05, 'train_loss': 0.012057, 'train_psnr': 24.8676, 'val_psnr': 23.7176, 'best_val_psnr': 23.7176}
# {'epoch': 1026, 'epoch_time_sec': 12.35, 'lr': 9.018441894561376e-05, 'train_loss': 0.012052, 'train_psnr': 24.8708, 'val_psnr': 23.7178, 'best_val_psnr': 23.7178}
# {'epoch': 1027, 'epoch_time_sec': 12.66, 'lr': 9.016579116893772e-05, 'train_loss': 0.012088, 'train_psnr': 24.8562, 'val_psnr': 23.718, 'best_val_psnr': 23.718}
# {'epoch': 1028, 'epoch_time_sec': 12.25, 'lr': 9.014714768260485e-05, 'train_loss': 0.012052, 'train_psnr': 24.8709, 'val_psnr': 23.7181, 'best_val_psnr': 23.7181}
# {'epoch': 1029, 'epoch_time_sec': 12.5, 'lr': 9.012848849399887e-05, 'train_loss': 0.012062, 'train_psnr': 24.8666, 'val_psnr': 23.7183, 'best_val_psnr': 23.7183}
# {'epoch': 1030, 'epoch_time_sec': 12.43, 'lr': 9.010981361050979e-05, 'train_loss': 0.012048, 'train_psnr': 24.8738, 'val_psnr': 23.7185, 'best_val_psnr': 23.7185}
# {'epoch': 1031, 'epoch_time_sec': 12.29, 'lr': 9.00911230395338e-05, 'train_loss': 0.012065, 'train_psnr': 24.8645, 'val_psnr': 23.7187, 'best_val_psnr': 23.7187}
# {'epoch': 1032, 'epoch_time_sec': 12.2, 'lr': 9.007241678847332e-05, 'train_loss': 0.012044, 'train_psnr': 24.8757, 'val_psnr': 23.719, 'best_val_psnr': 23.719}
# {'epoch': 1033, 'epoch_time_sec': 12.25, 'lr': 9.005369486473694e-05, 'train_loss': 0.012075, 'train_psnr': 24.8606, 'val_psnr': 23.7191, 'best_val_psnr': 23.7191}
# {'epoch': 1034, 'epoch_time_sec': 12.19, 'lr': 9.003495727573951e-05, 'train_loss': 0.012052, 'train_psnr': 24.8705, 'val_psnr': 23.7193, 'best_val_psnr': 23.7193}
# {'epoch': 1035, 'epoch_time_sec': 12.14, 'lr': 9.001620402890206e-05, 'train_loss': 0.01207, 'train_psnr': 24.8621, 'val_psnr': 23.7196, 'best_val_psnr': 23.7196}
# {'epoch': 1036, 'epoch_time_sec': 12.31, 'lr': 8.999743513165183e-05, 'train_loss': 0.012072, 'train_psnr': 24.8622, 'val_psnr': 23.7197, 'best_val_psnr': 23.7197}
# {'epoch': 1037, 'epoch_time_sec': 12.39, 'lr': 8.997865059142223e-05, 'train_loss': 0.012074, 'train_psnr': 24.8614, 'val_psnr': 23.7198, 'best_val_psnr': 23.7198}
# {'epoch': 1038, 'epoch_time_sec': 12.68, 'lr': 8.99598504156529e-05, 'train_loss': 0.012047, 'train_psnr': 24.874, 'val_psnr': 23.72, 'best_val_psnr': 23.72}
# {'epoch': 1039, 'epoch_time_sec': 12.21, 'lr': 8.994103461178967e-05, 'train_loss': 0.012048, 'train_psnr': 24.8732, 'val_psnr': 23.7201, 'best_val_psnr': 23.7201}
# {'epoch': 1040, 'epoch_time_sec': 11.96, 'lr': 8.992220318728453e-05, 'train_loss': 0.012088, 'train_psnr': 24.8579, 'val_psnr': 23.7204, 'best_val_psnr': 23.7204}
# {'epoch': 1041, 'epoch_time_sec': 12.25, 'lr': 8.990335614959568e-05, 'train_loss': 0.012053, 'train_psnr': 24.8728, 'val_psnr': 23.7207, 'best_val_psnr': 23.7207}
# {'epoch': 1042, 'epoch_time_sec': 12.21, 'lr': 8.98844935061875e-05, 'train_loss': 0.01208, 'train_psnr': 24.8626, 'val_psnr': 23.7209, 'best_val_psnr': 23.7209}
# {'epoch': 1043, 'epoch_time_sec': 12.34, 'lr': 8.986561526453055e-05, 'train_loss': 0.012049, 'train_psnr': 24.8744, 'val_psnr': 23.721, 'best_val_psnr': 23.721}
# {'epoch': 1044, 'epoch_time_sec': 12.41, 'lr': 8.984672143210156e-05, 'train_loss': 0.012062, 'train_psnr': 24.8685, 'val_psnr': 23.7213, 'best_val_psnr': 23.7213}
# {'epoch': 1045, 'epoch_time_sec': 12.37, 'lr': 8.982781201638347e-05, 'train_loss': 0.012099, 'train_psnr': 24.8502, 'val_psnr': 23.7215, 'best_val_psnr': 23.7215}
# {'epoch': 1046, 'epoch_time_sec': 12.41, 'lr': 8.980888702486535e-05, 'train_loss': 0.012078, 'train_psnr': 24.863, 'val_psnr': 23.7215, 'best_val_psnr': 23.7215}
# {'epoch': 1047, 'epoch_time_sec': 12.47, 'lr': 8.978994646504241e-05, 'train_loss': 0.012081, 'train_psnr': 24.8594, 'val_psnr': 23.7215, 'best_val_psnr': 23.7215}
# {'epoch': 1048, 'epoch_time_sec': 12.29, 'lr': 8.977099034441615e-05, 'train_loss': 0.012051, 'train_psnr': 24.872, 'val_psnr': 23.7216, 'best_val_psnr': 23.7216}
# {'epoch': 1049, 'epoch_time_sec': 12.47, 'lr': 8.975201867049408e-05, 'train_loss': 0.01204, 'train_psnr': 24.8772, 'val_psnr': 23.7219, 'best_val_psnr': 23.7219}
# {'epoch': 1050, 'epoch_time_sec': 12.22, 'lr': 8.973303145078997e-05, 'train_loss': 0.012052, 'train_psnr': 24.8728, 'val_psnr': 23.7221, 'best_val_psnr': 23.7221}
# {'epoch': 1051, 'epoch_time_sec': 12.62, 'lr': 8.971402869282371e-05, 'train_loss': 0.012055, 'train_psnr': 24.8708, 'val_psnr': 23.7221, 'best_val_psnr': 23.7221}
# {'epoch': 1052, 'epoch_time_sec': 12.27, 'lr': 8.969501040412137e-05, 'train_loss': 0.012075, 'train_psnr': 24.8605, 'val_psnr': 23.7222, 'best_val_psnr': 23.7222}
# {'epoch': 1053, 'epoch_time_sec': 12.29, 'lr': 8.967597659221513e-05, 'train_loss': 0.012093, 'train_psnr': 24.852, 'val_psnr': 23.7224, 'best_val_psnr': 23.7224}
# {'epoch': 1054, 'epoch_time_sec': 12.38, 'lr': 8.965692726464336e-05, 'train_loss': 0.012047, 'train_psnr': 24.8746, 'val_psnr': 23.7226, 'best_val_psnr': 23.7226}
# {'epoch': 1055, 'epoch_time_sec': 12.3, 'lr': 8.963786242895053e-05, 'train_loss': 0.012054, 'train_psnr': 24.8704, 'val_psnr': 23.7226, 'best_val_psnr': 23.7226}
# {'epoch': 1056, 'epoch_time_sec': 12.4, 'lr': 8.961878209268732e-05, 'train_loss': 0.012047, 'train_psnr': 24.877, 'val_psnr': 23.7229, 'best_val_psnr': 23.7229}
# {'epoch': 1057, 'epoch_time_sec': 12.41, 'lr': 8.959968626341047e-05, 'train_loss': 0.012046, 'train_psnr': 24.874, 'val_psnr': 23.7231, 'best_val_psnr': 23.7231}
# {'epoch': 1058, 'epoch_time_sec': 12.48, 'lr': 8.95805749486829e-05, 'train_loss': 0.012053, 'train_psnr': 24.8714, 'val_psnr': 23.7232, 'best_val_psnr': 23.7232}
# {'epoch': 1059, 'epoch_time_sec': 12.1, 'lr': 8.956144815607366e-05, 'train_loss': 0.012061, 'train_psnr': 24.8697, 'val_psnr': 23.7234, 'best_val_psnr': 23.7234}
# {'epoch': 1060, 'epoch_time_sec': 12.35, 'lr': 8.954230589315794e-05, 'train_loss': 0.012061, 'train_psnr': 24.866, 'val_psnr': 23.7236, 'best_val_psnr': 23.7236}
# {'epoch': 1061, 'epoch_time_sec': 12.28, 'lr': 8.952314816751702e-05, 'train_loss': 0.01207, 'train_psnr': 24.8652, 'val_psnr': 23.7236, 'best_val_psnr': 23.7236}
# {'epoch': 1062, 'epoch_time_sec': 12.23, 'lr': 8.950397498673833e-05, 'train_loss': 0.01207, 'train_psnr': 24.8625, 'val_psnr': 23.7237, 'best_val_psnr': 23.7237}
# {'epoch': 1063, 'epoch_time_sec': 12.39, 'lr': 8.948478635841543e-05, 'train_loss': 0.012052, 'train_psnr': 24.8729, 'val_psnr': 23.7238, 'best_val_psnr': 23.7238}
# {'epoch': 1064, 'epoch_time_sec': 12.4, 'lr': 8.946558229014798e-05, 'train_loss': 0.012034, 'train_psnr': 24.8804, 'val_psnr': 23.7241, 'best_val_psnr': 23.7241}
# {'epoch': 1065, 'epoch_time_sec': 12.26, 'lr': 8.944636278954177e-05, 'train_loss': 0.012046, 'train_psnr': 24.8768, 'val_psnr': 23.7243, 'best_val_psnr': 23.7243}
# {'epoch': 1066, 'epoch_time_sec': 12.67, 'lr': 8.942712786420868e-05, 'train_loss': 0.012065, 'train_psnr': 24.8675, 'val_psnr': 23.7245, 'best_val_psnr': 23.7245}
# {'epoch': 1067, 'epoch_time_sec': 12.48, 'lr': 8.940787752176672e-05, 'train_loss': 0.012032, 'train_psnr': 24.8818, 'val_psnr': 23.7246, 'best_val_psnr': 23.7246}
# {'epoch': 1068, 'epoch_time_sec': 12.22, 'lr': 8.938861176983999e-05, 'train_loss': 0.012034, 'train_psnr': 24.8819, 'val_psnr': 23.7249, 'best_val_psnr': 23.7249}
# {'epoch': 1069, 'epoch_time_sec': 12.26, 'lr': 8.93693306160587e-05, 'train_loss': 0.012067, 'train_psnr': 24.8653, 'val_psnr': 23.7252, 'best_val_psnr': 23.7252}
# {'epoch': 1070, 'epoch_time_sec': 12.42, 'lr': 8.935003406805918e-05, 'train_loss': 0.012055, 'train_psnr': 24.8728, 'val_psnr': 23.7254, 'best_val_psnr': 23.7254}
# {'epoch': 1071, 'epoch_time_sec': 12.17, 'lr': 8.933072213348383e-05, 'train_loss': 0.012047, 'train_psnr': 24.8757, 'val_psnr': 23.7256, 'best_val_psnr': 23.7256}
# {'epoch': 1072, 'epoch_time_sec': 12.23, 'lr': 8.931139481998112e-05, 'train_loss': 0.012047, 'train_psnr': 24.8748, 'val_psnr': 23.7258, 'best_val_psnr': 23.7258}
# {'epoch': 1073, 'epoch_time_sec': 12.05, 'lr': 8.92920521352057e-05, 'train_loss': 0.012054, 'train_psnr': 24.872, 'val_psnr': 23.7258, 'best_val_psnr': 23.7258}
# {'epoch': 1074, 'epoch_time_sec': 12.2, 'lr': 8.92726940868182e-05, 'train_loss': 0.012037, 'train_psnr': 24.8796, 'val_psnr': 23.726, 'best_val_psnr': 23.726}
# {'epoch': 1075, 'epoch_time_sec': 12.37, 'lr': 8.92533206824854e-05, 'train_loss': 0.012047, 'train_psnr': 24.8732, 'val_psnr': 23.7261, 'best_val_psnr': 23.7261}
# {'epoch': 1076, 'epoch_time_sec': 12.49, 'lr': 8.923393192988017e-05, 'train_loss': 0.012053, 'train_psnr': 24.872, 'val_psnr': 23.7262, 'best_val_psnr': 23.7262}
# {'epoch': 1077, 'epoch_time_sec': 12.29, 'lr': 8.921452783668139e-05, 'train_loss': 0.012042, 'train_psnr': 24.8761, 'val_psnr': 23.7264, 'best_val_psnr': 23.7264}
# {'epoch': 1078, 'epoch_time_sec': 12.2, 'lr': 8.91951084105741e-05, 'train_loss': 0.012051, 'train_psnr': 24.8733, 'val_psnr': 23.7266, 'best_val_psnr': 23.7266}
# {'epoch': 1079, 'epoch_time_sec': 12.35, 'lr': 8.917567365924937e-05, 'train_loss': 0.012043, 'train_psnr': 24.8769, 'val_psnr': 23.7269, 'best_val_psnr': 23.7269}
# {'epoch': 1080, 'epoch_time_sec': 12.31, 'lr': 8.915622359040431e-05, 'train_loss': 0.012038, 'train_psnr': 24.8801, 'val_psnr': 23.7269, 'best_val_psnr': 23.7269}
# {'epoch': 1081, 'epoch_time_sec': 12.28, 'lr': 8.913675821174217e-05, 'train_loss': 0.012056, 'train_psnr': 24.8713, 'val_psnr': 23.727, 'best_val_psnr': 23.727}
# {'epoch': 1082, 'epoch_time_sec': 12.34, 'lr': 8.911727753097218e-05, 'train_loss': 0.012044, 'train_psnr': 24.8766, 'val_psnr': 23.7273, 'best_val_psnr': 23.7273}
# {'epoch': 1083, 'epoch_time_sec': 12.26, 'lr': 8.909778155580973e-05, 'train_loss': 0.012046, 'train_psnr': 24.8758, 'val_psnr': 23.7274, 'best_val_psnr': 23.7274}
# {'epoch': 1084, 'epoch_time_sec': 12.27, 'lr': 8.907827029397616e-05, 'train_loss': 0.012046, 'train_psnr': 24.8759, 'val_psnr': 23.7275, 'best_val_psnr': 23.7275}
# {'epoch': 1085, 'epoch_time_sec': 12.22, 'lr': 8.905874375319896e-05, 'train_loss': 0.012038, 'train_psnr': 24.8781, 'val_psnr': 23.7277, 'best_val_psnr': 23.7277}
# {'epoch': 1086, 'epoch_time_sec': 12.23, 'lr': 8.903920194121158e-05, 'train_loss': 0.012071, 'train_psnr': 24.8672, 'val_psnr': 23.7279, 'best_val_psnr': 23.7279}
# {'epoch': 1087, 'epoch_time_sec': 12.26, 'lr': 8.901964486575359e-05, 'train_loss': 0.012039, 'train_psnr': 24.8802, 'val_psnr': 23.7281, 'best_val_psnr': 23.7281}
# {'epoch': 1088, 'epoch_time_sec': 12.44, 'lr': 8.90000725345706e-05, 'train_loss': 0.012046, 'train_psnr': 24.8754, 'val_psnr': 23.7282, 'best_val_psnr': 23.7282}
# {'epoch': 1089, 'epoch_time_sec': 12.14, 'lr': 8.898048495541418e-05, 'train_loss': 0.012039, 'train_psnr': 24.8801, 'val_psnr': 23.7285, 'best_val_psnr': 23.7285}
# {'epoch': 1090, 'epoch_time_sec': 12.25, 'lr': 8.896088213604207e-05, 'train_loss': 0.012051, 'train_psnr': 24.8738, 'val_psnr': 23.7287, 'best_val_psnr': 23.7287}
# {'epoch': 1091, 'epoch_time_sec': 12.32, 'lr': 8.894126408421794e-05, 'train_loss': 0.01203, 'train_psnr': 24.8827, 'val_psnr': 23.7288, 'best_val_psnr': 23.7288}
# {'epoch': 1092, 'epoch_time_sec': 12.65, 'lr': 8.892163080771152e-05, 'train_loss': 0.012047, 'train_psnr': 24.8768, 'val_psnr': 23.7289, 'best_val_psnr': 23.7289}
# {'epoch': 1093, 'epoch_time_sec': 12.51, 'lr': 8.890198231429861e-05, 'train_loss': 0.012054, 'train_psnr': 24.8735, 'val_psnr': 23.729, 'best_val_psnr': 23.729}
# {'epoch': 1094, 'epoch_time_sec': 12.27, 'lr': 8.888231861176098e-05, 'train_loss': 0.012035, 'train_psnr': 24.8806, 'val_psnr': 23.7293, 'best_val_psnr': 23.7293}
# {'epoch': 1095, 'epoch_time_sec': 12.13, 'lr': 8.886263970788648e-05, 'train_loss': 0.01205, 'train_psnr': 24.8746, 'val_psnr': 23.7294, 'best_val_psnr': 23.7294}
# {'epoch': 1096, 'epoch_time_sec': 12.04, 'lr': 8.88429456104689e-05, 'train_loss': 0.012053, 'train_psnr': 24.8732, 'val_psnr': 23.7294, 'best_val_psnr': 23.7294}
# {'epoch': 1097, 'epoch_time_sec': 12.17, 'lr': 8.882323632730816e-05, 'train_loss': 0.012036, 'train_psnr': 24.8812, 'val_psnr': 23.7296, 'best_val_psnr': 23.7296}
# {'epoch': 1098, 'epoch_time_sec': 12.22, 'lr': 8.880351186621007e-05, 'train_loss': 0.012032, 'train_psnr': 24.8825, 'val_psnr': 23.7298, 'best_val_psnr': 23.7298}
# {'epoch': 1099, 'epoch_time_sec': 12.41, 'lr': 8.878377223498655e-05, 'train_loss': 0.012032, 'train_psnr': 24.8833, 'val_psnr': 23.7301, 'best_val_psnr': 23.7301}
# {'epoch': 1100, 'epoch_time_sec': 12.37, 'lr': 8.876401744145549e-05, 'train_loss': 0.01208, 'train_psnr': 24.8612, 'val_psnr': 23.7304, 'best_val_psnr': 23.7304}
# {'epoch': 1101, 'epoch_time_sec': 12.25, 'lr': 8.874424749344077e-05, 'train_loss': 0.012031, 'train_psnr': 24.8845, 'val_psnr': 23.7306, 'best_val_psnr': 23.7306}
# {'epoch': 1102, 'epoch_time_sec': 12.34, 'lr': 8.87244623987723e-05, 'train_loss': 0.012025, 'train_psnr': 24.8848, 'val_psnr': 23.7308, 'best_val_psnr': 23.7308}
# {'epoch': 1103, 'epoch_time_sec': 12.31, 'lr': 8.870466216528596e-05, 'train_loss': 0.012047, 'train_psnr': 24.8765, 'val_psnr': 23.7309, 'best_val_psnr': 23.7309}
# {'epoch': 1104, 'epoch_time_sec': 12.34, 'lr': 8.868484680082368e-05, 'train_loss': 0.012042, 'train_psnr': 24.8805, 'val_psnr': 23.7311, 'best_val_psnr': 23.7311}
# {'epoch': 1105, 'epoch_time_sec': 12.3, 'lr': 8.866501631323331e-05, 'train_loss': 0.012051, 'train_psnr': 24.8735, 'val_psnr': 23.7312, 'best_val_psnr': 23.7312}
# {'epoch': 1106, 'epoch_time_sec': 12.08, 'lr': 8.864517071036874e-05, 'train_loss': 0.012048, 'train_psnr': 24.8761, 'val_psnr': 23.7313, 'best_val_psnr': 23.7313}
# {'epoch': 1107, 'epoch_time_sec': 12.23, 'lr': 8.862531000008982e-05, 'train_loss': 0.012042, 'train_psnr': 24.8787, 'val_psnr': 23.7316, 'best_val_psnr': 23.7316}
# {'epoch': 1108, 'epoch_time_sec': 12.04, 'lr': 8.860543419026241e-05, 'train_loss': 0.012052, 'train_psnr': 24.8745, 'val_psnr': 23.7317, 'best_val_psnr': 23.7317}
# {'epoch': 1109, 'epoch_time_sec': 12.27, 'lr': 8.858554328875831e-05, 'train_loss': 0.012058, 'train_psnr': 24.87, 'val_psnr': 23.7318, 'best_val_psnr': 23.7318}
# {'epoch': 1110, 'epoch_time_sec': 12.23, 'lr': 8.856563730345535e-05, 'train_loss': 0.01206, 'train_psnr': 24.8708, 'val_psnr': 23.7318, 'best_val_psnr': 23.7318}
# {'epoch': 1111, 'epoch_time_sec': 12.05, 'lr': 8.85457162422373e-05, 'train_loss': 0.012054, 'train_psnr': 24.8714, 'val_psnr': 23.7319, 'best_val_psnr': 23.7319}
# {'epoch': 1112, 'epoch_time_sec': 12.12, 'lr': 8.85257801129939e-05, 'train_loss': 0.012032, 'train_psnr': 24.883, 'val_psnr': 23.732, 'best_val_psnr': 23.732}
# {'epoch': 1113, 'epoch_time_sec': 12.05, 'lr': 8.850582892362085e-05, 'train_loss': 0.012021, 'train_psnr': 24.8881, 'val_psnr': 23.7322, 'best_val_psnr': 23.7322}
# {'epoch': 1114, 'epoch_time_sec': 11.94, 'lr': 8.848586268201985e-05, 'train_loss': 0.01205, 'train_psnr': 24.877, 'val_psnr': 23.7324, 'best_val_psnr': 23.7324}
# {'epoch': 1115, 'epoch_time_sec': 12.13, 'lr': 8.846588139609854e-05, 'train_loss': 0.012033, 'train_psnr': 24.8819, 'val_psnr': 23.7326, 'best_val_psnr': 23.7326}
# {'epoch': 1116, 'epoch_time_sec': 12.26, 'lr': 8.84458850737705e-05, 'train_loss': 0.012027, 'train_psnr': 24.8884, 'val_psnr': 23.7327, 'best_val_psnr': 23.7327}
# {'epoch': 1117, 'epoch_time_sec': 12.49, 'lr': 8.84258737229553e-05, 'train_loss': 0.012046, 'train_psnr': 24.8766, 'val_psnr': 23.7329, 'best_val_psnr': 23.7329}
# {'epoch': 1118, 'epoch_time_sec': 12.18, 'lr': 8.840584735157843e-05, 'train_loss': 0.012044, 'train_psnr': 24.8785, 'val_psnr': 23.7329, 'best_val_psnr': 23.7329}
# {'epoch': 1119, 'epoch_time_sec': 12.42, 'lr': 8.838580596757138e-05, 'train_loss': 0.012055, 'train_psnr': 24.8727, 'val_psnr': 23.7331, 'best_val_psnr': 23.7331}
# {'epoch': 1120, 'epoch_time_sec': 12.26, 'lr': 8.83657495788715e-05, 'train_loss': 0.012031, 'train_psnr': 24.886, 'val_psnr': 23.7332, 'best_val_psnr': 23.7332}
# {'epoch': 1121, 'epoch_time_sec': 12.22, 'lr': 8.834567819342217e-05, 'train_loss': 0.012027, 'train_psnr': 24.8871, 'val_psnr': 23.7335, 'best_val_psnr': 23.7335}
# {'epoch': 1122, 'epoch_time_sec': 12.17, 'lr': 8.832559181917268e-05, 'train_loss': 0.01203, 'train_psnr': 24.8822, 'val_psnr': 23.7335, 'best_val_psnr': 23.7335}
# {'epoch': 1123, 'epoch_time_sec': 12.42, 'lr': 8.830549046407821e-05, 'train_loss': 0.012055, 'train_psnr': 24.8719, 'val_psnr': 23.7337, 'best_val_psnr': 23.7337}
# {'epoch': 1124, 'epoch_time_sec': 12.45, 'lr': 8.828537413609993e-05, 'train_loss': 0.012046, 'train_psnr': 24.8773, 'val_psnr': 23.7339, 'best_val_psnr': 23.7339}
# {'epoch': 1125, 'epoch_time_sec': 12.51, 'lr': 8.826524284320493e-05, 'train_loss': 0.012029, 'train_psnr': 24.8846, 'val_psnr': 23.734, 'best_val_psnr': 23.734}
# {'epoch': 1126, 'epoch_time_sec': 12.23, 'lr': 8.824509659336622e-05, 'train_loss': 0.01205, 'train_psnr': 24.8739, 'val_psnr': 23.7341, 'best_val_psnr': 23.7341}
# {'epoch': 1127, 'epoch_time_sec': 12.29, 'lr': 8.822493539456271e-05, 'train_loss': 0.012016, 'train_psnr': 24.8926, 'val_psnr': 23.7342, 'best_val_psnr': 23.7342}
# {'epoch': 1128, 'epoch_time_sec': 12.24, 'lr': 8.820475925477928e-05, 'train_loss': 0.012048, 'train_psnr': 24.8769, 'val_psnr': 23.7344, 'best_val_psnr': 23.7344}
# {'epoch': 1129, 'epoch_time_sec': 12.27, 'lr': 8.818456818200669e-05, 'train_loss': 0.012035, 'train_psnr': 24.8822, 'val_psnr': 23.7345, 'best_val_psnr': 23.7345}
# {'epoch': 1130, 'epoch_time_sec': 12.42, 'lr': 8.816436218424161e-05, 'train_loss': 0.012028, 'train_psnr': 24.8854, 'val_psnr': 23.7346, 'best_val_psnr': 23.7346}
# {'epoch': 1131, 'epoch_time_sec': 12.19, 'lr': 8.814414126948666e-05, 'train_loss': 0.012041, 'train_psnr': 24.8791, 'val_psnr': 23.7348, 'best_val_psnr': 23.7348}
# {'epoch': 1132, 'epoch_time_sec': 12.22, 'lr': 8.812390544575034e-05, 'train_loss': 0.012063, 'train_psnr': 24.8714, 'val_psnr': 23.7349, 'best_val_psnr': 23.7349}
# {'epoch': 1133, 'epoch_time_sec': 12.38, 'lr': 8.810365472104705e-05, 'train_loss': 0.012039, 'train_psnr': 24.8797, 'val_psnr': 23.735, 'best_val_psnr': 23.735}
# {'epoch': 1134, 'epoch_time_sec': 12.26, 'lr': 8.80833891033971e-05, 'train_loss': 0.012017, 'train_psnr': 24.8918, 'val_psnr': 23.7353, 'best_val_psnr': 23.7353}
# {'epoch': 1135, 'epoch_time_sec': 12.26, 'lr': 8.806310860082668e-05, 'train_loss': 0.012023, 'train_psnr': 24.8898, 'val_psnr': 23.7356, 'best_val_psnr': 23.7356}
# {'epoch': 1136, 'epoch_time_sec': 12.35, 'lr': 8.804281322136794e-05, 'train_loss': 0.012041, 'train_psnr': 24.8807, 'val_psnr': 23.7357, 'best_val_psnr': 23.7357}
# {'epoch': 1137, 'epoch_time_sec': 12.15, 'lr': 8.802250297305882e-05, 'train_loss': 0.012038, 'train_psnr': 24.8842, 'val_psnr': 23.7361, 'best_val_psnr': 23.7361}
# {'epoch': 1138, 'epoch_time_sec': 12.09, 'lr': 8.800217786394326e-05, 'train_loss': 0.012031, 'train_psnr': 24.883, 'val_psnr': 23.7363, 'best_val_psnr': 23.7363}
# {'epoch': 1139, 'epoch_time_sec': 12.16, 'lr': 8.798183790207099e-05, 'train_loss': 0.012039, 'train_psnr': 24.88, 'val_psnr': 23.7365, 'best_val_psnr': 23.7365}
# {'epoch': 1140, 'epoch_time_sec': 12.26, 'lr': 8.796148309549768e-05, 'train_loss': 0.012084, 'train_psnr': 24.8665, 'val_psnr': 23.7366, 'best_val_psnr': 23.7366}
# {'epoch': 1141, 'epoch_time_sec': 12.32, 'lr': 8.794111345228484e-05, 'train_loss': 0.012027, 'train_psnr': 24.8873, 'val_psnr': 23.7367, 'best_val_psnr': 23.7367}
# {'epoch': 1142, 'epoch_time_sec': 12.12, 'lr': 8.79207289804999e-05, 'train_loss': 0.012035, 'train_psnr': 24.8821, 'val_psnr': 23.7368, 'best_val_psnr': 23.7368}
# {'epoch': 1143, 'epoch_time_sec': 12.35, 'lr': 8.790032968821615e-05, 'train_loss': 0.012027, 'train_psnr': 24.8867, 'val_psnr': 23.7369, 'best_val_psnr': 23.7369}
# {'epoch': 1144, 'epoch_time_sec': 12.22, 'lr': 8.787991558351272e-05, 'train_loss': 0.012046, 'train_psnr': 24.8792, 'val_psnr': 23.737, 'best_val_psnr': 23.737}
# {'epoch': 1145, 'epoch_time_sec': 12.26, 'lr': 8.785948667447462e-05, 'train_loss': 0.012028, 'train_psnr': 24.8858, 'val_psnr': 23.7372, 'best_val_psnr': 23.7372}
# {'epoch': 1146, 'epoch_time_sec': 12.29, 'lr': 8.783904296919275e-05, 'train_loss': 0.012045, 'train_psnr': 24.8776, 'val_psnr': 23.7373, 'best_val_psnr': 23.7373}
# {'epoch': 1147, 'epoch_time_sec': 12.03, 'lr': 8.781858447576384e-05, 'train_loss': 0.012037, 'train_psnr': 24.8825, 'val_psnr': 23.7375, 'best_val_psnr': 23.7375}
# {'epoch': 1148, 'epoch_time_sec': 12.01, 'lr': 8.779811120229049e-05, 'train_loss': 0.012029, 'train_psnr': 24.8871, 'val_psnr': 23.7378, 'best_val_psnr': 23.7378}
# {'epoch': 1149, 'epoch_time_sec': 12.24, 'lr': 8.777762315688114e-05, 'train_loss': 0.012025, 'train_psnr': 24.8888, 'val_psnr': 23.738, 'best_val_psnr': 23.738}
# {'epoch': 1150, 'epoch_time_sec': 12.19, 'lr': 8.77571203476501e-05, 'train_loss': 0.012022, 'train_psnr': 24.8898, 'val_psnr': 23.7382, 'best_val_psnr': 23.7382}
# {'epoch': 1151, 'epoch_time_sec': 11.93, 'lr': 8.773660278271753e-05, 'train_loss': 0.012055, 'train_psnr': 24.8731, 'val_psnr': 23.7384, 'best_val_psnr': 23.7384}
# {'epoch': 1152, 'epoch_time_sec': 12.02, 'lr': 8.771607047020938e-05, 'train_loss': 0.012035, 'train_psnr': 24.8832, 'val_psnr': 23.7385, 'best_val_psnr': 23.7385}
# {'epoch': 1153, 'epoch_time_sec': 12.16, 'lr': 8.769552341825754e-05, 'train_loss': 0.012032, 'train_psnr': 24.8849, 'val_psnr': 23.7387, 'best_val_psnr': 23.7387}
# {'epoch': 1154, 'epoch_time_sec': 12.46, 'lr': 8.767496163499963e-05, 'train_loss': 0.012032, 'train_psnr': 24.8844, 'val_psnr': 23.7389, 'best_val_psnr': 23.7389}
# {'epoch': 1155, 'epoch_time_sec': 12.29, 'lr': 8.76543851285792e-05, 'train_loss': 0.012028, 'train_psnr': 24.8844, 'val_psnr': 23.7391, 'best_val_psnr': 23.7391}
# {'epoch': 1156, 'epoch_time_sec': 12.21, 'lr': 8.763379390714554e-05, 'train_loss': 0.012031, 'train_psnr': 24.8852, 'val_psnr': 23.7392, 'best_val_psnr': 23.7392}
# {'epoch': 1157, 'epoch_time_sec': 12.1, 'lr': 8.761318797885385e-05, 'train_loss': 0.012039, 'train_psnr': 24.8838, 'val_psnr': 23.7394, 'best_val_psnr': 23.7394}
# {'epoch': 1158, 'epoch_time_sec': 12.2, 'lr': 8.759256735186511e-05, 'train_loss': 0.012027, 'train_psnr': 24.8869, 'val_psnr': 23.7397, 'best_val_psnr': 23.7397}
# {'epoch': 1159, 'epoch_time_sec': 12.13, 'lr': 8.757193203434612e-05, 'train_loss': 0.012039, 'train_psnr': 24.881, 'val_psnr': 23.74, 'best_val_psnr': 23.74}
# {'epoch': 1160, 'epoch_time_sec': 12.13, 'lr': 8.755128203446951e-05, 'train_loss': 0.012033, 'train_psnr': 24.8835, 'val_psnr': 23.7403, 'best_val_psnr': 23.7403}
# {'epoch': 1161, 'epoch_time_sec': 12.16, 'lr': 8.753061736041374e-05, 'train_loss': 0.012044, 'train_psnr': 24.8814, 'val_psnr': 23.7404, 'best_val_psnr': 23.7404}
# {'epoch': 1162, 'epoch_time_sec': 12.0, 'lr': 8.750993802036302e-05, 'train_loss': 0.01206, 'train_psnr': 24.873, 'val_psnr': 23.7405, 'best_val_psnr': 23.7405}
# {'epoch': 1163, 'epoch_time_sec': 12.28, 'lr': 8.748924402250747e-05, 'train_loss': 0.012025, 'train_psnr': 24.8904, 'val_psnr': 23.7407, 'best_val_psnr': 23.7407}
# {'epoch': 1164, 'epoch_time_sec': 11.88, 'lr': 8.746853537504293e-05, 'train_loss': 0.012023, 'train_psnr': 24.8893, 'val_psnr': 23.7408, 'best_val_psnr': 23.7408}
# {'epoch': 1165, 'epoch_time_sec': 12.21, 'lr': 8.744781208617105e-05, 'train_loss': 0.012029, 'train_psnr': 24.8856, 'val_psnr': 23.7409, 'best_val_psnr': 23.7409}
# {'epoch': 1166, 'epoch_time_sec': 12.44, 'lr': 8.742707416409936e-05, 'train_loss': 0.012007, 'train_psnr': 24.8976, 'val_psnr': 23.741, 'best_val_psnr': 23.741}
# {'epoch': 1167, 'epoch_time_sec': 12.35, 'lr': 8.740632161704105e-05, 'train_loss': 0.012025, 'train_psnr': 24.8871, 'val_psnr': 23.7412, 'best_val_psnr': 23.7412}
# {'epoch': 1168, 'epoch_time_sec': 12.51, 'lr': 8.738555445321522e-05, 'train_loss': 0.012034, 'train_psnr': 24.8844, 'val_psnr': 23.7413, 'best_val_psnr': 23.7413}
# {'epoch': 1169, 'epoch_time_sec': 12.17, 'lr': 8.736477268084673e-05, 'train_loss': 0.012014, 'train_psnr': 24.894, 'val_psnr': 23.7415, 'best_val_psnr': 23.7415}
# {'epoch': 1170, 'epoch_time_sec': 11.94, 'lr': 8.734397630816618e-05, 'train_loss': 0.012041, 'train_psnr': 24.8822, 'val_psnr': 23.7416, 'best_val_psnr': 23.7416}
# {'epoch': 1171, 'epoch_time_sec': 12.22, 'lr': 8.732316534340999e-05, 'train_loss': 0.012036, 'train_psnr': 24.8827, 'val_psnr': 23.7417, 'best_val_psnr': 23.7417}
# {'epoch': 1172, 'epoch_time_sec': 12.03, 'lr': 8.730233979482036e-05, 'train_loss': 0.012017, 'train_psnr': 24.8923, 'val_psnr': 23.7419, 'best_val_psnr': 23.7419}
# {'epoch': 1173, 'epoch_time_sec': 12.16, 'lr': 8.728149967064527e-05, 'train_loss': 0.012017, 'train_psnr': 24.8937, 'val_psnr': 23.7419, 'best_val_psnr': 23.7419}
# {'epoch': 1174, 'epoch_time_sec': 12.15, 'lr': 8.726064497913842e-05, 'train_loss': 0.012018, 'train_psnr': 24.8907, 'val_psnr': 23.742, 'best_val_psnr': 23.742}
# {'epoch': 1175, 'epoch_time_sec': 12.48, 'lr': 8.723977572855936e-05, 'train_loss': 0.012024, 'train_psnr': 24.8897, 'val_psnr': 23.7422, 'best_val_psnr': 23.7422}
# {'epoch': 1176, 'epoch_time_sec': 12.28, 'lr': 8.721889192717339e-05, 'train_loss': 0.012014, 'train_psnr': 24.8934, 'val_psnr': 23.7423, 'best_val_psnr': 23.7423}
# {'epoch': 1177, 'epoch_time_sec': 12.14, 'lr': 8.719799358325148e-05, 'train_loss': 0.012031, 'train_psnr': 24.8857, 'val_psnr': 23.7425, 'best_val_psnr': 23.7425}
# {'epoch': 1178, 'epoch_time_sec': 12.33, 'lr': 8.717708070507048e-05, 'train_loss': 0.012015, 'train_psnr': 24.8932, 'val_psnr': 23.7427, 'best_val_psnr': 23.7427}
# {'epoch': 1179, 'epoch_time_sec': 12.11, 'lr': 8.715615330091293e-05, 'train_loss': 0.012032, 'train_psnr': 24.8873, 'val_psnr': 23.7428, 'best_val_psnr': 23.7428}
# {'epoch': 1180, 'epoch_time_sec': 12.05, 'lr': 8.713521137906715e-05, 'train_loss': 0.01204, 'train_psnr': 24.8789, 'val_psnr': 23.7429, 'best_val_psnr': 23.7429}
# {'epoch': 1181, 'epoch_time_sec': 12.16, 'lr': 8.711425494782719e-05, 'train_loss': 0.012029, 'train_psnr': 24.8879, 'val_psnr': 23.7431, 'best_val_psnr': 23.7431}
# {'epoch': 1182, 'epoch_time_sec': 12.21, 'lr': 8.709328401549285e-05, 'train_loss': 0.012019, 'train_psnr': 24.8899, 'val_psnr': 23.7433, 'best_val_psnr': 23.7433}
# {'epoch': 1183, 'epoch_time_sec': 12.43, 'lr': 8.70722985903697e-05, 'train_loss': 0.012024, 'train_psnr': 24.8902, 'val_psnr': 23.7434, 'best_val_psnr': 23.7434}
# {'epoch': 1184, 'epoch_time_sec': 12.18, 'lr': 8.7051298680769e-05, 'train_loss': 0.012016, 'train_psnr': 24.8934, 'val_psnr': 23.7435, 'best_val_psnr': 23.7435}
# {'epoch': 1185, 'epoch_time_sec': 12.49, 'lr': 8.703028429500778e-05, 'train_loss': 0.012016, 'train_psnr': 24.8925, 'val_psnr': 23.7438, 'best_val_psnr': 23.7438}
# {'epoch': 1186, 'epoch_time_sec': 12.27, 'lr': 8.700925544140882e-05, 'train_loss': 0.012013, 'train_psnr': 24.8948, 'val_psnr': 23.7441, 'best_val_psnr': 23.7441}
# {'epoch': 1187, 'epoch_time_sec': 12.01, 'lr': 8.69882121283006e-05, 'train_loss': 0.012026, 'train_psnr': 24.8877, 'val_psnr': 23.7442, 'best_val_psnr': 23.7442}
# {'epoch': 1188, 'epoch_time_sec': 12.43, 'lr': 8.696715436401732e-05, 'train_loss': 0.012037, 'train_psnr': 24.8825, 'val_psnr': 23.7444, 'best_val_psnr': 23.7444}
# {'epoch': 1189, 'epoch_time_sec': 12.31, 'lr': 8.694608215689895e-05, 'train_loss': 0.012026, 'train_psnr': 24.8893, 'val_psnr': 23.7446, 'best_val_psnr': 23.7446}
# {'epoch': 1190, 'epoch_time_sec': 11.89, 'lr': 8.69249955152911e-05, 'train_loss': 0.012044, 'train_psnr': 24.8802, 'val_psnr': 23.7448, 'best_val_psnr': 23.7448}
# {'epoch': 1191, 'epoch_time_sec': 11.97, 'lr': 8.690389444754518e-05, 'train_loss': 0.012021, 'train_psnr': 24.8915, 'val_psnr': 23.7449, 'best_val_psnr': 23.7449}
# {'epoch': 1192, 'epoch_time_sec': 12.15, 'lr': 8.688277896201827e-05, 'train_loss': 0.012016, 'train_psnr': 24.8935, 'val_psnr': 23.745, 'best_val_psnr': 23.745}
# {'epoch': 1193, 'epoch_time_sec': 12.5, 'lr': 8.686164906707318e-05, 'train_loss': 0.012026, 'train_psnr': 24.89, 'val_psnr': 23.745, 'best_val_psnr': 23.745}
# {'epoch': 1194, 'epoch_time_sec': 12.15, 'lr': 8.684050477107837e-05, 'train_loss': 0.01202, 'train_psnr': 24.8937, 'val_psnr': 23.7452, 'best_val_psnr': 23.7452}
# {'epoch': 1195, 'epoch_time_sec': 11.9, 'lr': 8.681934608240813e-05, 'train_loss': 0.012035, 'train_psnr': 24.8836, 'val_psnr': 23.7451, 'best_val_psnr': 23.7452}
# {'epoch': 1196, 'epoch_time_sec': 12.14, 'lr': 8.67981730094423e-05, 'train_loss': 0.012023, 'train_psnr': 24.8905, 'val_psnr': 23.7452, 'best_val_psnr': 23.7452}
# {'epoch': 1197, 'epoch_time_sec': 11.91, 'lr': 8.677698556056652e-05, 'train_loss': 0.012033, 'train_psnr': 24.8843, 'val_psnr': 23.7454, 'best_val_psnr': 23.7454}
# {'epoch': 1198, 'epoch_time_sec': 11.92, 'lr': 8.675578374417207e-05, 'train_loss': 0.012027, 'train_psnr': 24.8878, 'val_psnr': 23.7456, 'best_val_psnr': 23.7456}
# {'epoch': 1199, 'epoch_time_sec': 11.82, 'lr': 8.673456756865595e-05, 'train_loss': 0.012015, 'train_psnr': 24.8947, 'val_psnr': 23.7458, 'best_val_psnr': 23.7458}
# {'epoch': 1200, 'epoch_time_sec': 12.0, 'lr': 8.671333704242082e-05, 'train_loss': 0.012018, 'train_psnr': 24.8955, 'val_psnr': 23.746, 'best_val_psnr': 23.746}
# {'epoch': 1201, 'epoch_time_sec': 11.98, 'lr': 8.669209217387509e-05, 'train_loss': 0.012013, 'train_psnr': 24.8936, 'val_psnr': 23.7461, 'best_val_psnr': 23.7461}
# {'epoch': 1202, 'epoch_time_sec': 12.09, 'lr': 8.667083297143276e-05, 'train_loss': 0.012018, 'train_psnr': 24.8913, 'val_psnr': 23.7463, 'best_val_psnr': 23.7463}
# {'epoch': 1203, 'epoch_time_sec': 12.13, 'lr': 8.664955944351356e-05, 'train_loss': 0.011995, 'train_psnr': 24.9051, 'val_psnr': 23.7464, 'best_val_psnr': 23.7464}
# {'epoch': 1204, 'epoch_time_sec': 11.86, 'lr': 8.662827159854286e-05, 'train_loss': 0.012021, 'train_psnr': 24.8916, 'val_psnr': 23.7466, 'best_val_psnr': 23.7466}
# {'epoch': 1205, 'epoch_time_sec': 12.19, 'lr': 8.660696944495177e-05, 'train_loss': 0.012029, 'train_psnr': 24.8913, 'val_psnr': 23.7469, 'best_val_psnr': 23.7469}
# {'epoch': 1206, 'epoch_time_sec': 11.73, 'lr': 8.658565299117697e-05, 'train_loss': 0.012028, 'train_psnr': 24.8889, 'val_psnr': 23.747, 'best_val_psnr': 23.747}
# {'epoch': 1207, 'epoch_time_sec': 11.89, 'lr': 8.656432224566087e-05, 'train_loss': 0.012019, 'train_psnr': 24.8914, 'val_psnr': 23.7471, 'best_val_psnr': 23.7471}
# {'epoch': 1208, 'epoch_time_sec': 11.79, 'lr': 8.654297721685153e-05, 'train_loss': 0.012027, 'train_psnr': 24.8866, 'val_psnr': 23.7472, 'best_val_psnr': 23.7472}
# {'epoch': 1209, 'epoch_time_sec': 12.0, 'lr': 8.652161791320265e-05, 'train_loss': 0.01204, 'train_psnr': 24.8801, 'val_psnr': 23.747, 'best_val_psnr': 23.7472}
# {'epoch': 1210, 'epoch_time_sec': 12.1, 'lr': 8.65002443431736e-05, 'train_loss': 0.012014, 'train_psnr': 24.895, 'val_psnr': 23.7474, 'best_val_psnr': 23.7474}
# {'epoch': 1211, 'epoch_time_sec': 12.09, 'lr': 8.647885651522938e-05, 'train_loss': 0.012038, 'train_psnr': 24.8844, 'val_psnr': 23.7474, 'best_val_psnr': 23.7474}
# {'epoch': 1212, 'epoch_time_sec': 12.09, 'lr': 8.645745443784069e-05, 'train_loss': 0.012012, 'train_psnr': 24.8944, 'val_psnr': 23.7475, 'best_val_psnr': 23.7475}
# {'epoch': 1213, 'epoch_time_sec': 11.96, 'lr': 8.643603811948379e-05, 'train_loss': 0.012004, 'train_psnr': 24.9002, 'val_psnr': 23.7476, 'best_val_psnr': 23.7476}
# {'epoch': 1214, 'epoch_time_sec': 12.06, 'lr': 8.641460756864062e-05, 'train_loss': 0.012019, 'train_psnr': 24.8914, 'val_psnr': 23.7477, 'best_val_psnr': 23.7477}
# {'epoch': 1215, 'epoch_time_sec': 11.9, 'lr': 8.63931627937988e-05, 'train_loss': 0.012047, 'train_psnr': 24.8799, 'val_psnr': 23.7478, 'best_val_psnr': 23.7478}
# {'epoch': 1216, 'epoch_time_sec': 12.18, 'lr': 8.637170380345152e-05, 'train_loss': 0.012027, 'train_psnr': 24.8915, 'val_psnr': 23.7479, 'best_val_psnr': 23.7479}
# {'epoch': 1217, 'epoch_time_sec': 12.12, 'lr': 8.635023060609762e-05, 'train_loss': 0.012005, 'train_psnr': 24.8989, 'val_psnr': 23.7482, 'best_val_psnr': 23.7482}
# {'epoch': 1218, 'epoch_time_sec': 12.15, 'lr': 8.632874321024158e-05, 'train_loss': 0.012064, 'train_psnr': 24.873, 'val_psnr': 23.7483, 'best_val_psnr': 23.7483}
# {'epoch': 1219, 'epoch_time_sec': 12.22, 'lr': 8.630724162439349e-05, 'train_loss': 0.012012, 'train_psnr': 24.8967, 'val_psnr': 23.7485, 'best_val_psnr': 23.7485}
# {'epoch': 1220, 'epoch_time_sec': 12.18, 'lr': 8.628572585706906e-05, 'train_loss': 0.012005, 'train_psnr': 24.9011, 'val_psnr': 23.7486, 'best_val_psnr': 23.7486}
# {'epoch': 1221, 'epoch_time_sec': 12.05, 'lr': 8.626419591678964e-05, 'train_loss': 0.012014, 'train_psnr': 24.8955, 'val_psnr': 23.7486, 'best_val_psnr': 23.7486}
# {'epoch': 1222, 'epoch_time_sec': 12.17, 'lr': 8.624265181208215e-05, 'train_loss': 0.012007, 'train_psnr': 24.8986, 'val_psnr': 23.7488, 'best_val_psnr': 23.7488}
# {'epoch': 1223, 'epoch_time_sec': 12.18, 'lr': 8.622109355147916e-05, 'train_loss': 0.012022, 'train_psnr': 24.8908, 'val_psnr': 23.749, 'best_val_psnr': 23.749}
# {'epoch': 1224, 'epoch_time_sec': 12.02, 'lr': 8.619952114351882e-05, 'train_loss': 0.01202, 'train_psnr': 24.8929, 'val_psnr': 23.7491, 'best_val_psnr': 23.7491}
# {'epoch': 1225, 'epoch_time_sec': 12.23, 'lr': 8.617793459674491e-05, 'train_loss': 0.012014, 'train_psnr': 24.8963, 'val_psnr': 23.7493, 'best_val_psnr': 23.7493}
# {'epoch': 1226, 'epoch_time_sec': 12.13, 'lr': 8.615633391970677e-05, 'train_loss': 0.012013, 'train_psnr': 24.8951, 'val_psnr': 23.7494, 'best_val_psnr': 23.7494}
# {'epoch': 1227, 'epoch_time_sec': 12.11, 'lr': 8.613471912095937e-05, 'train_loss': 0.012012, 'train_psnr': 24.8956, 'val_psnr': 23.7495, 'best_val_psnr': 23.7495}
# {'epoch': 1228, 'epoch_time_sec': 12.03, 'lr': 8.611309020906325e-05, 'train_loss': 0.01202, 'train_psnr': 24.8936, 'val_psnr': 23.7498, 'best_val_psnr': 23.7498}
# {'epoch': 1229, 'epoch_time_sec': 11.97, 'lr': 8.609144719258457e-05, 'train_loss': 0.011999, 'train_psnr': 24.9024, 'val_psnr': 23.7499, 'best_val_psnr': 23.7499}
# {'epoch': 1230, 'epoch_time_sec': 11.9, 'lr': 8.606979008009505e-05, 'train_loss': 0.012005, 'train_psnr': 24.9018, 'val_psnr': 23.7501, 'best_val_psnr': 23.7501}
# {'epoch': 1231, 'epoch_time_sec': 12.15, 'lr': 8.604811888017201e-05, 'train_loss': 0.012007, 'train_psnr': 24.899, 'val_psnr': 23.7503, 'best_val_psnr': 23.7503}
# {'epoch': 1232, 'epoch_time_sec': 11.96, 'lr': 8.602643360139834e-05, 'train_loss': 0.012012, 'train_psnr': 24.8963, 'val_psnr': 23.7505, 'best_val_psnr': 23.7505}
# {'epoch': 1233, 'epoch_time_sec': 12.09, 'lr': 8.600473425236247e-05, 'train_loss': 0.012016, 'train_psnr': 24.8942, 'val_psnr': 23.7507, 'best_val_psnr': 23.7507}
# {'epoch': 1234, 'epoch_time_sec': 11.77, 'lr': 8.598302084165848e-05, 'train_loss': 0.012023, 'train_psnr': 24.8904, 'val_psnr': 23.7508, 'best_val_psnr': 23.7508}
# {'epoch': 1235, 'epoch_time_sec': 12.13, 'lr': 8.596129337788596e-05, 'train_loss': 0.012, 'train_psnr': 24.9033, 'val_psnr': 23.7509, 'best_val_psnr': 23.7509}
# {'epoch': 1236, 'epoch_time_sec': 12.05, 'lr': 8.59395518696501e-05, 'train_loss': 0.01201, 'train_psnr': 24.8986, 'val_psnr': 23.7512, 'best_val_psnr': 23.7512}
# {'epoch': 1237, 'epoch_time_sec': 12.17, 'lr': 8.59177963255616e-05, 'train_loss': 0.012021, 'train_psnr': 24.8917, 'val_psnr': 23.7515, 'best_val_psnr': 23.7515}
# {'epoch': 1238, 'epoch_time_sec': 12.17, 'lr': 8.589602675423678e-05, 'train_loss': 0.011998, 'train_psnr': 24.9031, 'val_psnr': 23.7516, 'best_val_psnr': 23.7516}
# {'epoch': 1239, 'epoch_time_sec': 11.85, 'lr': 8.587424316429748e-05, 'train_loss': 0.012007, 'train_psnr': 24.9017, 'val_psnr': 23.7519, 'best_val_psnr': 23.7519}
# {'epoch': 1240, 'epoch_time_sec': 11.86, 'lr': 8.585244556437112e-05, 'train_loss': 0.012022, 'train_psnr': 24.8925, 'val_psnr': 23.752, 'best_val_psnr': 23.752}
# {'epoch': 1241, 'epoch_time_sec': 11.89, 'lr': 8.583063396309064e-05, 'train_loss': 0.012018, 'train_psnr': 24.8938, 'val_psnr': 23.7522, 'best_val_psnr': 23.7522}
# {'epoch': 1242, 'epoch_time_sec': 12.1, 'lr': 8.580880836909451e-05, 'train_loss': 0.012013, 'train_psnr': 24.8952, 'val_psnr': 23.7523, 'best_val_psnr': 23.7523}
# {'epoch': 1243, 'epoch_time_sec': 11.88, 'lr': 8.57869687910268e-05, 'train_loss': 0.012007, 'train_psnr': 24.8986, 'val_psnr': 23.7522, 'best_val_psnr': 23.7523}
# {'epoch': 1244, 'epoch_time_sec': 12.26, 'lr': 8.57651152375371e-05, 'train_loss': 0.012008, 'train_psnr': 24.8974, 'val_psnr': 23.7524, 'best_val_psnr': 23.7524}
# {'epoch': 1245, 'epoch_time_sec': 12.29, 'lr': 8.574324771728047e-05, 'train_loss': 0.012009, 'train_psnr': 24.9002, 'val_psnr': 23.7526, 'best_val_psnr': 23.7526}
# {'epoch': 1246, 'epoch_time_sec': 12.11, 'lr': 8.57213662389176e-05, 'train_loss': 0.012028, 'train_psnr': 24.889, 'val_psnr': 23.7527, 'best_val_psnr': 23.7527}
# {'epoch': 1247, 'epoch_time_sec': 11.92, 'lr': 8.569947081111463e-05, 'train_loss': 0.011993, 'train_psnr': 24.907, 'val_psnr': 23.7528, 'best_val_psnr': 23.7528}
# {'epoch': 1248, 'epoch_time_sec': 12.3, 'lr': 8.567756144254327e-05, 'train_loss': 0.012013, 'train_psnr': 24.8972, 'val_psnr': 23.7529, 'best_val_psnr': 23.7529}
# {'epoch': 1249, 'epoch_time_sec': 12.0, 'lr': 8.565563814188073e-05, 'train_loss': 0.011991, 'train_psnr': 24.9075, 'val_psnr': 23.753, 'best_val_psnr': 23.753}
# {'epoch': 1250, 'epoch_time_sec': 12.01, 'lr': 8.563370091780977e-05, 'train_loss': 0.012006, 'train_psnr': 24.8999, 'val_psnr': 23.7532, 'best_val_psnr': 23.7532}
# {'epoch': 1251, 'epoch_time_sec': 11.96, 'lr': 8.561174977901858e-05, 'train_loss': 0.012008, 'train_psnr': 24.8983, 'val_psnr': 23.7533, 'best_val_psnr': 23.7533}
# {'epoch': 1252, 'epoch_time_sec': 12.21, 'lr': 8.558978473420098e-05, 'train_loss': 0.012003, 'train_psnr': 24.9012, 'val_psnr': 23.7534, 'best_val_psnr': 23.7534}
# {'epoch': 1253, 'epoch_time_sec': 12.05, 'lr': 8.556780579205621e-05, 'train_loss': 0.012017, 'train_psnr': 24.8954, 'val_psnr': 23.7535, 'best_val_psnr': 23.7535}
# {'epoch': 1254, 'epoch_time_sec': 12.17, 'lr': 8.554581296128905e-05, 'train_loss': 0.012005, 'train_psnr': 24.8987, 'val_psnr': 23.7538, 'best_val_psnr': 23.7538}
# {'epoch': 1255, 'epoch_time_sec': 11.95, 'lr': 8.552380625060975e-05, 'train_loss': 0.012022, 'train_psnr': 24.8901, 'val_psnr': 23.7539, 'best_val_psnr': 23.7539}
# {'epoch': 1256, 'epoch_time_sec': 12.24, 'lr': 8.55017856687341e-05, 'train_loss': 0.011998, 'train_psnr': 24.9035, 'val_psnr': 23.754, 'best_val_psnr': 23.754}
# {'epoch': 1257, 'epoch_time_sec': 12.05, 'lr': 8.547975122438336e-05, 'train_loss': 0.012053, 'train_psnr': 24.8852, 'val_psnr': 23.7542, 'best_val_psnr': 23.7542}
# {'epoch': 1258, 'epoch_time_sec': 12.13, 'lr': 8.54577029262843e-05, 'train_loss': 0.012002, 'train_psnr': 24.9037, 'val_psnr': 23.7542, 'best_val_psnr': 23.7542}
# {'epoch': 1259, 'epoch_time_sec': 12.04, 'lr': 8.543564078316913e-05, 'train_loss': 0.012003, 'train_psnr': 24.9014, 'val_psnr': 23.7544, 'best_val_psnr': 23.7544}
# {'epoch': 1260, 'epoch_time_sec': 11.98, 'lr': 8.541356480377558e-05, 'train_loss': 0.012005, 'train_psnr': 24.8999, 'val_psnr': 23.7545, 'best_val_psnr': 23.7545}
# {'epoch': 1261, 'epoch_time_sec': 12.05, 'lr': 8.539147499684685e-05, 'train_loss': 0.012014, 'train_psnr': 24.898, 'val_psnr': 23.7546, 'best_val_psnr': 23.7546}
# {'epoch': 1262, 'epoch_time_sec': 12.17, 'lr': 8.536937137113163e-05, 'train_loss': 0.012012, 'train_psnr': 24.8973, 'val_psnr': 23.7547, 'best_val_psnr': 23.7547}
# {'epoch': 1263, 'epoch_time_sec': 11.94, 'lr': 8.534725393538407e-05, 'train_loss': 0.012018, 'train_psnr': 24.8954, 'val_psnr': 23.7548, 'best_val_psnr': 23.7548}
# {'epoch': 1264, 'epoch_time_sec': 12.17, 'lr': 8.53251226983638e-05, 'train_loss': 0.011992, 'train_psnr': 24.9077, 'val_psnr': 23.755, 'best_val_psnr': 23.755}
# {'epoch': 1265, 'epoch_time_sec': 12.19, 'lr': 8.530297766883588e-05, 'train_loss': 0.012006, 'train_psnr': 24.899, 'val_psnr': 23.7552, 'best_val_psnr': 23.7552}
# {'epoch': 1266, 'epoch_time_sec': 11.88, 'lr': 8.52808188555709e-05, 'train_loss': 0.01202, 'train_psnr': 24.8964, 'val_psnr': 23.7554, 'best_val_psnr': 23.7554}
# {'epoch': 1267, 'epoch_time_sec': 12.08, 'lr': 8.525864626734483e-05, 'train_loss': 0.011998, 'train_psnr': 24.9043, 'val_psnr': 23.7555, 'best_val_psnr': 23.7555}
# {'epoch': 1268, 'epoch_time_sec': 11.99, 'lr': 8.523645991293918e-05, 'train_loss': 0.01199, 'train_psnr': 24.9082, 'val_psnr': 23.7557, 'best_val_psnr': 23.7557}
# {'epoch': 1269, 'epoch_time_sec': 12.08, 'lr': 8.52142598011408e-05, 'train_loss': 0.012012, 'train_psnr': 24.8961, 'val_psnr': 23.7558, 'best_val_psnr': 23.7558}
# {'epoch': 1270, 'epoch_time_sec': 12.06, 'lr': 8.519204594074213e-05, 'train_loss': 0.011996, 'train_psnr': 24.9075, 'val_psnr': 23.756, 'best_val_psnr': 23.756}
# {'epoch': 1271, 'epoch_time_sec': 12.08, 'lr': 8.516981834054092e-05, 'train_loss': 0.012004, 'train_psnr': 24.9019, 'val_psnr': 23.756, 'best_val_psnr': 23.756}
# {'epoch': 1272, 'epoch_time_sec': 12.04, 'lr': 8.514757700934046e-05, 'train_loss': 0.012002, 'train_psnr': 24.9, 'val_psnr': 23.7561, 'best_val_psnr': 23.7561}
# {'epoch': 1273, 'epoch_time_sec': 12.04, 'lr': 8.512532195594943e-05, 'train_loss': 0.011995, 'train_psnr': 24.9048, 'val_psnr': 23.7561, 'best_val_psnr': 23.7561}
# {'epoch': 1274, 'epoch_time_sec': 11.74, 'lr': 8.510305318918194e-05, 'train_loss': 0.011995, 'train_psnr': 24.906, 'val_psnr': 23.7562, 'best_val_psnr': 23.7562}
# {'epoch': 1275, 'epoch_time_sec': 12.05, 'lr': 8.508077071785758e-05, 'train_loss': 0.012024, 'train_psnr': 24.8904, 'val_psnr': 23.7563, 'best_val_psnr': 23.7563}
# {'epoch': 1276, 'epoch_time_sec': 12.02, 'lr': 8.505847455080131e-05, 'train_loss': 0.011995, 'train_psnr': 24.9058, 'val_psnr': 23.7565, 'best_val_psnr': 23.7565}
# {'epoch': 1277, 'epoch_time_sec': 12.34, 'lr': 8.503616469684354e-05, 'train_loss': 0.012005, 'train_psnr': 24.9025, 'val_psnr': 23.7567, 'best_val_psnr': 23.7567}
# {'epoch': 1278, 'epoch_time_sec': 12.12, 'lr': 8.50138411648201e-05, 'train_loss': 0.011998, 'train_psnr': 24.9056, 'val_psnr': 23.7568, 'best_val_psnr': 23.7568}
# {'epoch': 1279, 'epoch_time_sec': 12.08, 'lr': 8.499150396357224e-05, 'train_loss': 0.012028, 'train_psnr': 24.8935, 'val_psnr': 23.7569, 'best_val_psnr': 23.7569}
# {'epoch': 1280, 'epoch_time_sec': 12.09, 'lr': 8.496915310194661e-05, 'train_loss': 0.011996, 'train_psnr': 24.9046, 'val_psnr': 23.7571, 'best_val_psnr': 23.7571}
# {'epoch': 1281, 'epoch_time_sec': 12.11, 'lr': 8.494678858879531e-05, 'train_loss': 0.011996, 'train_psnr': 24.9046, 'val_psnr': 23.7571, 'best_val_psnr': 23.7571}
# {'epoch': 1282, 'epoch_time_sec': 11.99, 'lr': 8.492441043297578e-05, 'train_loss': 0.012004, 'train_psnr': 24.9016, 'val_psnr': 23.7574, 'best_val_psnr': 23.7574}
# {'epoch': 1283, 'epoch_time_sec': 11.77, 'lr': 8.490201864335091e-05, 'train_loss': 0.012007, 'train_psnr': 24.9036, 'val_psnr': 23.7575, 'best_val_psnr': 23.7575}
# {'epoch': 1284, 'epoch_time_sec': 12.22, 'lr': 8.487961322878901e-05, 'train_loss': 0.011995, 'train_psnr': 24.9087, 'val_psnr': 23.7576, 'best_val_psnr': 23.7576}
# {'epoch': 1285, 'epoch_time_sec': 12.03, 'lr': 8.485719419816371e-05, 'train_loss': 0.012004, 'train_psnr': 24.9022, 'val_psnr': 23.7579, 'best_val_psnr': 23.7579}
# {'epoch': 1286, 'epoch_time_sec': 11.97, 'lr': 8.483476156035411e-05, 'train_loss': 0.012005, 'train_psnr': 24.9029, 'val_psnr': 23.7581, 'best_val_psnr': 23.7581}
# {'epoch': 1287, 'epoch_time_sec': 12.0, 'lr': 8.481231532424463e-05, 'train_loss': 0.01202, 'train_psnr': 24.8939, 'val_psnr': 23.7582, 'best_val_psnr': 23.7582}
# {'epoch': 1288, 'epoch_time_sec': 11.99, 'lr': 8.478985549872518e-05, 'train_loss': 0.012022, 'train_psnr': 24.8936, 'val_psnr': 23.7583, 'best_val_psnr': 23.7583}
# {'epoch': 1289, 'epoch_time_sec': 12.06, 'lr': 8.476738209269093e-05, 'train_loss': 0.011997, 'train_psnr': 24.9052, 'val_psnr': 23.7585, 'best_val_psnr': 23.7585}
# {'epoch': 1290, 'epoch_time_sec': 12.01, 'lr': 8.47448951150425e-05, 'train_loss': 0.011987, 'train_psnr': 24.9092, 'val_psnr': 23.7587, 'best_val_psnr': 23.7587}
# {'epoch': 1291, 'epoch_time_sec': 12.07, 'lr': 8.472239457468585e-05, 'train_loss': 0.011996, 'train_psnr': 24.9058, 'val_psnr': 23.7589, 'best_val_psnr': 23.7589}
# {'epoch': 1292, 'epoch_time_sec': 12.17, 'lr': 8.469988048053237e-05, 'train_loss': 0.012017, 'train_psnr': 24.8965, 'val_psnr': 23.759, 'best_val_psnr': 23.759}
# {'epoch': 1293, 'epoch_time_sec': 11.94, 'lr': 8.467735284149876e-05, 'train_loss': 0.011995, 'train_psnr': 24.9049, 'val_psnr': 23.7591, 'best_val_psnr': 23.7591}
# ...
# {'epoch': 4342, 'epoch_time_sec': 22.01, 'lr': 5.183721632938619e-06, 'train_loss': 0.011821, 'train_psnr': 25.0117, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4343, 'epoch_time_sec': 21.29, 'lr': 5.171196363704554e-06, 'train_loss': 0.011812, 'train_psnr': 25.0171, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4344, 'epoch_time_sec': 22.05, 'lr': 5.1586890469663355e-06, 'train_loss': 0.011819, 'train_psnr': 25.0108, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4345, 'epoch_time_sec': 21.34, 'lr': 5.146199687677483e-06, 'train_loss': 0.011836, 'train_psnr': 25.0065, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4346, 'epoch_time_sec': 21.99, 'lr': 5.133728290784403e-06, 'train_loss': 0.01182, 'train_psnr': 25.0119, 'val_psnr': 23.8659, 'best_val_psnr': 23.8659}
# {'epoch': 4347, 'epoch_time_sec': 21.28, 'lr': 5.121274861226401e-06, 'train_loss': 0.011818, 'train_psnr': 25.0124, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4348, 'epoch_time_sec': 21.99, 'lr': 5.108839403935676e-06, 'train_loss': 0.011818, 'train_psnr': 25.013, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4349, 'epoch_time_sec': 21.27, 'lr': 5.0964219238372845e-06, 'train_loss': 0.011808, 'train_psnr': 25.0171, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4350, 'epoch_time_sec': 22.01, 'lr': 5.084022425849183e-06, 'train_loss': 0.011831, 'train_psnr': 25.0098, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4351, 'epoch_time_sec': 21.34, 'lr': 5.071640914882192e-06, 'train_loss': 0.011819, 'train_psnr': 25.0127, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4352, 'epoch_time_sec': 21.93, 'lr': 5.059277395840025e-06, 'train_loss': 0.011843, 'train_psnr': 25.0046, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4353, 'epoch_time_sec': 21.38, 'lr': 5.046931873619252e-06, 'train_loss': 0.011821, 'train_psnr': 25.0093, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4354, 'epoch_time_sec': 21.95, 'lr': 5.034604353109328e-06, 'train_loss': 0.011824, 'train_psnr': 25.01, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4355, 'epoch_time_sec': 21.84, 'lr': 5.022294839192567e-06, 'train_loss': 0.011829, 'train_psnr': 25.0071, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4356, 'epoch_time_sec': 21.96, 'lr': 5.01000333674416e-06, 'train_loss': 0.011835, 'train_psnr': 25.0073, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4357, 'epoch_time_sec': 22.01, 'lr': 4.997729850632181e-06, 'train_loss': 0.011823, 'train_psnr': 25.0119, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4358, 'epoch_time_sec': 21.4, 'lr': 4.985474385717528e-06, 'train_loss': 0.011811, 'train_psnr': 25.0166, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4359, 'epoch_time_sec': 22.02, 'lr': 4.973236946853976e-06, 'train_loss': 0.011818, 'train_psnr': 25.0119, 'val_psnr': 23.8659, 'best_val_psnr': 23.8659}
# {'epoch': 4360, 'epoch_time_sec': 21.28, 'lr': 4.961017538888201e-06, 'train_loss': 0.011819, 'train_psnr': 25.012, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4361, 'epoch_time_sec': 21.98, 'lr': 4.9488161666596925e-06, 'train_loss': 0.011813, 'train_psnr': 25.0163, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4362, 'epoch_time_sec': 21.29, 'lr': 4.936632835000796e-06, 'train_loss': 0.011809, 'train_psnr': 25.0171, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4363, 'epoch_time_sec': 22.0, 'lr': 4.9244675487367396e-06, 'train_loss': 0.011822, 'train_psnr': 25.0106, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4364, 'epoch_time_sec': 21.23, 'lr': 4.912320312685596e-06, 'train_loss': 0.011813, 'train_psnr': 25.0159, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4365, 'epoch_time_sec': 21.97, 'lr': 4.900191131658265e-06, 'train_loss': 0.011816, 'train_psnr': 25.014, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4366, 'epoch_time_sec': 21.25, 'lr': 4.8880800104585395e-06, 'train_loss': 0.011812, 'train_psnr': 25.0135, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4367, 'epoch_time_sec': 21.95, 'lr': 4.875986953883013e-06, 'train_loss': 0.011822, 'train_psnr': 25.0111, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4368, 'epoch_time_sec': 21.29, 'lr': 4.863911966721162e-06, 'train_loss': 0.011817, 'train_psnr': 25.0141, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4369, 'epoch_time_sec': 21.91, 'lr': 4.851855053755279e-06, 'train_loss': 0.011831, 'train_psnr': 25.0072, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4370, 'epoch_time_sec': 21.27, 'lr': 4.839816219760526e-06, 'train_loss': 0.011822, 'train_psnr': 25.0105, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4371, 'epoch_time_sec': 22.0, 'lr': 4.827795469504876e-06, 'train_loss': 0.011825, 'train_psnr': 25.0129, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4372, 'epoch_time_sec': 21.37, 'lr': 4.815792807749154e-06, 'train_loss': 0.011812, 'train_psnr': 25.0156, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4373, 'epoch_time_sec': 22.05, 'lr': 4.80380823924703e-06, 'train_loss': 0.011827, 'train_psnr': 25.0131, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4374, 'epoch_time_sec': 21.22, 'lr': 4.791841768744998e-06, 'train_loss': 0.011831, 'train_psnr': 25.007, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4375, 'epoch_time_sec': 22.03, 'lr': 4.77989340098236e-06, 'train_loss': 0.011819, 'train_psnr': 25.0115, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4376, 'epoch_time_sec': 21.32, 'lr': 4.767963140691306e-06, 'train_loss': 0.011812, 'train_psnr': 25.0139, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4377, 'epoch_time_sec': 22.02, 'lr': 4.756050992596814e-06, 'train_loss': 0.011813, 'train_psnr': 25.0159, 'val_psnr': 23.8659, 'best_val_psnr': 23.8659}
# {'epoch': 4378, 'epoch_time_sec': 21.25, 'lr': 4.744156961416669e-06, 'train_loss': 0.011817, 'train_psnr': 25.012, 'val_psnr': 23.8659, 'best_val_psnr': 23.8659}
# {'epoch': 4379, 'epoch_time_sec': 22.05, 'lr': 4.732281051861548e-06, 'train_loss': 0.011822, 'train_psnr': 25.0113, 'val_psnr': 23.8659, 'best_val_psnr': 23.8659}
# {'epoch': 4380, 'epoch_time_sec': 21.36, 'lr': 4.720423268634894e-06, 'train_loss': 0.011827, 'train_psnr': 25.0061, 'val_psnr': 23.8659, 'best_val_psnr': 23.8659}
# {'epoch': 4381, 'epoch_time_sec': 21.95, 'lr': 4.708583616432976e-06, 'train_loss': 0.01183, 'train_psnr': 25.0073, 'val_psnr': 23.8659, 'best_val_psnr': 23.8659}
# {'epoch': 4382, 'epoch_time_sec': 21.31, 'lr': 4.696762099944908e-06, 'train_loss': 0.011817, 'train_psnr': 25.013, 'val_psnr': 23.8659, 'best_val_psnr': 23.8659}
# {'epoch': 4383, 'epoch_time_sec': 21.97, 'lr': 4.6849587238526135e-06, 'train_loss': 0.011816, 'train_psnr': 25.0117, 'val_psnr': 23.8659, 'best_val_psnr': 23.8659}
# {'epoch': 4384, 'epoch_time_sec': 21.26, 'lr': 4.673173492830808e-06, 'train_loss': 0.011805, 'train_psnr': 25.021, 'val_psnr': 23.8659, 'best_val_psnr': 23.8659}
# {'epoch': 4385, 'epoch_time_sec': 22.0, 'lr': 4.661406411547049e-06, 'train_loss': 0.011814, 'train_psnr': 25.0138, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4386, 'epoch_time_sec': 21.31, 'lr': 4.649657484661694e-06, 'train_loss': 0.011819, 'train_psnr': 25.0118, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4387, 'epoch_time_sec': 21.96, 'lr': 4.637926716827913e-06, 'train_loss': 0.011812, 'train_psnr': 25.0154, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4388, 'epoch_time_sec': 21.22, 'lr': 4.626214112691674e-06, 'train_loss': 0.011808, 'train_psnr': 25.0178, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4389, 'epoch_time_sec': 22.02, 'lr': 4.614519676891777e-06, 'train_loss': 0.011834, 'train_psnr': 25.0049, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4390, 'epoch_time_sec': 21.35, 'lr': 4.602843414059785e-06, 'train_loss': 0.011816, 'train_psnr': 25.0129, 'val_psnr': 23.8658, 'best_val_psnr': 23.8659}
# {'epoch': 4391, 'epoch_time_sec': 22.02, 'lr': 4.591185328820107e-06, 'train_loss': 0.011823, 'train_psnr': 25.0107, 'val_psnr': 23.8659, 'best_val_psnr': 23.8659}
# {'epoch': 4392, 'epoch_time_sec': 21.32, 'lr': 4.579545425789928e-06, 'train_loss': 0.011815, 'train_psnr': 25.0132, 'val_psnr': 23.8659, 'best_val_psnr': 23.8659}
# {'epoch': 4393, 'epoch_time_sec': 21.86, 'lr': 4.567923709579244e-06, 'train_loss': 0.011824, 'train_psnr': 25.0093, 'val_psnr': 23.8659, 'best_val_psnr': 23.8659}
# {'epoch': 4394, 'epoch_time_sec': 21.7, 'lr': 4.556320184790817e-06, 'train_loss': 0.011806, 'train_psnr': 25.0202, 'val_psnr': 23.8659, 'best_val_psnr': 23.8659}
# {'epoch': 4395, 'epoch_time_sec': 22.03, 'lr': 4.544734856020266e-06, 'train_loss': 0.011819, 'train_psnr': 25.0117, 'val_psnr': 23.8659, 'best_val_psnr': 23.8659}
# {'epoch': 4396, 'epoch_time_sec': 22.01, 'lr': 4.5331677278559425e-06, 'train_loss': 0.01183, 'train_psnr': 25.008, 'val_psnr': 23.8659, 'best_val_psnr': 23.8659}
# {'epoch': 4397, 'epoch_time_sec': 21.52, 'lr': 4.521618804879014e-06, 'train_loss': 0.011825, 'train_psnr': 25.0106, 'val_psnr': 23.8659, 'best_val_psnr': 23.8659}
# {'epoch': 4398, 'epoch_time_sec': 21.98, 'lr': 4.510088091663438e-06, 'train_loss': 0.011812, 'train_psnr': 25.0145, 'val_psnr': 23.8659, 'best_val_psnr': 23.8659}
# {'epoch': 4399, 'epoch_time_sec': 21.27, 'lr': 4.4985755927759745e-06, 'train_loss': 0.011812, 'train_psnr': 25.0161, 'val_psnr': 23.8659, 'best_val_psnr': 23.8659}
# {'epoch': 4400, 'epoch_time_sec': 22.08, 'lr': 4.4870813127761335e-06, 'train_loss': 0.011824, 'train_psnr': 25.0105, 'val_psnr': 23.8659, 'best_val_psnr': 23.8659}
# {'epoch': 4401, 'epoch_time_sec': 21.31, 'lr': 4.475605256216248e-06, 'train_loss': 0.011819, 'train_psnr': 25.0125, 'val_psnr': 23.8659, 'best_val_psnr': 23.8659}
# {'epoch': 4402, 'epoch_time_sec': 21.99, 'lr': 4.4641474276414025e-06, 'train_loss': 0.01182, 'train_psnr': 25.0105, 'val_psnr': 23.8659, 'best_val_psnr': 23.8659}
# {'epoch': 4403, 'epoch_time_sec': 21.27, 'lr': 4.452707831589487e-06, 'train_loss': 0.011823, 'train_psnr': 25.0127, 'val_psnr': 23.866, 'best_val_psnr': 23.866}
# {'epoch': 4404, 'epoch_time_sec': 21.99, 'lr': 4.4412864725911445e-06, 'train_loss': 0.011826, 'train_psnr': 25.0089, 'val_psnr': 23.866, 'best_val_psnr': 23.866}
# {'epoch': 4405, 'epoch_time_sec': 21.26, 'lr': 4.429883355169828e-06, 'train_loss': 0.011822, 'train_psnr': 25.0119, 'val_psnr': 23.866, 'best_val_psnr': 23.866}
# {'epoch': 4406, 'epoch_time_sec': 22.0, 'lr': 4.418498483841736e-06, 'train_loss': 0.011836, 'train_psnr': 25.0054, 'val_psnr': 23.866, 'best_val_psnr': 23.866}
# {'epoch': 4407, 'epoch_time_sec': 21.31, 'lr': 4.407131863115854e-06, 'train_loss': 0.011812, 'train_psnr': 25.0146, 'val_psnr': 23.866, 'best_val_psnr': 23.866}
# {'epoch': 4408, 'epoch_time_sec': 21.94, 'lr': 4.395783497493943e-06, 'train_loss': 0.011818, 'train_psnr': 25.0125, 'val_psnr': 23.866, 'best_val_psnr': 23.866}
# {'epoch': 4409, 'epoch_time_sec': 21.29, 'lr': 4.384453391470534e-06, 'train_loss': 0.011826, 'train_psnr': 25.0124, 'val_psnr': 23.866, 'best_val_psnr': 23.866}
# {'epoch': 4410, 'epoch_time_sec': 21.98, 'lr': 4.373141549532891e-06, 'train_loss': 0.011823, 'train_psnr': 25.011, 'val_psnr': 23.8659, 'best_val_psnr': 23.866}
# {'epoch': 4411, 'epoch_time_sec': 21.39, 'lr': 4.361847976161114e-06, 'train_loss': 0.011817, 'train_psnr': 25.0104, 'val_psnr': 23.866, 'best_val_psnr': 23.866}
# {'epoch': 4412, 'epoch_time_sec': 22.04, 'lr': 4.350572675828014e-06, 'train_loss': 0.01182, 'train_psnr': 25.0118, 'val_psnr': 23.866, 'best_val_psnr': 23.866}
# {'epoch': 4413, 'epoch_time_sec': 21.36, 'lr': 4.339315652999166e-06, 'train_loss': 0.011813, 'train_psnr': 25.0141, 'val_psnr': 23.8659, 'best_val_psnr': 23.866}
# {'epoch': 4414, 'epoch_time_sec': 21.98, 'lr': 4.328076912132932e-06, 'train_loss': 0.011814, 'train_psnr': 25.0132, 'val_psnr': 23.8659, 'best_val_psnr': 23.866}
# {'epoch': 4415, 'epoch_time_sec': 21.22, 'lr': 4.3168564576804275e-06, 'train_loss': 0.011829, 'train_psnr': 25.0082, 'val_psnr': 23.866, 'best_val_psnr': 23.866}
# {'epoch': 4416, 'epoch_time_sec': 21.96, 'lr': 4.305654294085503e-06, 'train_loss': 0.011821, 'train_psnr': 25.0114, 'val_psnr': 23.866, 'best_val_psnr': 23.866}
# {'epoch': 4417, 'epoch_time_sec': 21.2, 'lr': 4.294470425784792e-06, 'train_loss': 0.011804, 'train_psnr': 25.0212, 'val_psnr': 23.866, 'best_val_psnr': 23.866}
# {'epoch': 4418, 'epoch_time_sec': 21.98, 'lr': 4.283304857207674e-06, 'train_loss': 0.011839, 'train_psnr': 25.0026, 'val_psnr': 23.866, 'best_val_psnr': 23.866}
# {'epoch': 4419, 'epoch_time_sec': 21.31, 'lr': 4.272157592776276e-06, 'train_loss': 0.011836, 'train_psnr': 25.0033, 'val_psnr': 23.8661, 'best_val_psnr': 23.8661}
# {'epoch': 4420, 'epoch_time_sec': 22.03, 'lr': 4.261028636905463e-06, 'train_loss': 0.011814, 'train_psnr': 25.0142, 'val_psnr': 23.8661, 'best_val_psnr': 23.8661}
# {'epoch': 4421, 'epoch_time_sec': 21.23, 'lr': 4.249917994002879e-06, 'train_loss': 0.011825, 'train_psnr': 25.0095, 'val_psnr': 23.866, 'best_val_psnr': 23.8661}
# {'epoch': 4422, 'epoch_time_sec': 21.88, 'lr': 4.238825668468899e-06, 'train_loss': 0.011814, 'train_psnr': 25.0169, 'val_psnr': 23.8661, 'best_val_psnr': 23.8661}
# {'epoch': 4423, 'epoch_time_sec': 21.3, 'lr': 4.227751664696638e-06, 'train_loss': 0.011811, 'train_psnr': 25.0159, 'val_psnr': 23.8661, 'best_val_psnr': 23.8661}
# {'epoch': 4424, 'epoch_time_sec': 22.01, 'lr': 4.216695987071971e-06, 'train_loss': 0.011814, 'train_psnr': 25.0129, 'val_psnr': 23.8661, 'best_val_psnr': 23.8661}
# {'epoch': 4425, 'epoch_time_sec': 21.27, 'lr': 4.20565863997349e-06, 'train_loss': 0.011822, 'train_psnr': 25.011, 'val_psnr': 23.866, 'best_val_psnr': 23.8661}
# {'epoch': 4426, 'epoch_time_sec': 22.0, 'lr': 4.1946396277725494e-06, 'train_loss': 0.011816, 'train_psnr': 25.0118, 'val_psnr': 23.866, 'best_val_psnr': 23.8661}
# {'epoch': 4427, 'epoch_time_sec': 21.29, 'lr': 4.183638954833243e-06, 'train_loss': 0.011811, 'train_psnr': 25.0163, 'val_psnr': 23.866, 'best_val_psnr': 23.8661}
# {'epoch': 4428, 'epoch_time_sec': 21.98, 'lr': 4.172656625512386e-06, 'train_loss': 0.011809, 'train_psnr': 25.0176, 'val_psnr': 23.866, 'best_val_psnr': 23.8661}
# {'epoch': 4429, 'epoch_time_sec': 21.26, 'lr': 4.1616926441595246e-06, 'train_loss': 0.011816, 'train_psnr': 25.0142, 'val_psnr': 23.866, 'best_val_psnr': 23.8661}
# {'epoch': 4430, 'epoch_time_sec': 22.03, 'lr': 4.15074701511696e-06, 'train_loss': 0.011824, 'train_psnr': 25.0121, 'val_psnr': 23.866, 'best_val_psnr': 23.8661}
# {'epoch': 4431, 'epoch_time_sec': 21.27, 'lr': 4.1398197427197235e-06, 'train_loss': 0.011817, 'train_psnr': 25.0129, 'val_psnr': 23.866, 'best_val_psnr': 23.8661}
# {'epoch': 4432, 'epoch_time_sec': 21.89, 'lr': 4.128910831295543e-06, 'train_loss': 0.011821, 'train_psnr': 25.0109, 'val_psnr': 23.8659, 'best_val_psnr': 23.8661}
# {'epoch': 4433, 'epoch_time_sec': 21.22, 'lr': 4.118020285164919e-06, 'train_loss': 0.011811, 'train_psnr': 25.0146, 'val_psnr': 23.8659, 'best_val_psnr': 23.8661}
# {'epoch': 4434, 'epoch_time_sec': 21.9, 'lr': 4.107148108641055e-06, 'train_loss': 0.011825, 'train_psnr': 25.0101, 'val_psnr': 23.8659, 'best_val_psnr': 23.8661}
# {'epoch': 4435, 'epoch_time_sec': 21.67, 'lr': 4.096294306029878e-06, 'train_loss': 0.011815, 'train_psnr': 25.0132, 'val_psnr': 23.8659, 'best_val_psnr': 23.8661}
# {'epoch': 4436, 'epoch_time_sec': 22.03, 'lr': 4.085458881630037e-06, 'train_loss': 0.011822, 'train_psnr': 25.0103, 'val_psnr': 23.8659, 'best_val_psnr': 23.8661}
# {'epoch': 4437, 'epoch_time_sec': 22.07, 'lr': 4.074641839732913e-06, 'train_loss': 0.011824, 'train_psnr': 25.0114, 'val_psnr': 23.8659, 'best_val_psnr': 23.8661}
# {'epoch': 4438, 'epoch_time_sec': 21.62, 'lr': 4.063843184622608e-06, 'train_loss': 0.01182, 'train_psnr': 25.0107, 'val_psnr': 23.8659, 'best_val_psnr': 23.8661}

# %% [markdown]
# ## 4. Validation

# %%
best_model = build_eval_model_from_checkpoint(best_ckpt_path, device)
preview_info = write_val_preview(best_model, val_loader, preview_dir, device)
best_val_psnr = evaluate_psnr(best_model, val_loader, device)
validation_summary = {
    'input_psnr': input_psnr,
    'val_psnr': best_val_psnr,
    'delta_psnr': best_val_psnr - input_psnr,
}
print({
    'validation_summary': validation_summary,
    'preview': preview_info,
    'best_checkpoint_path': str(best_ckpt_path),
})

# %% [markdown]
# ## 5. Export and Submission Artifacts
#
# ONNX export is included here. MXQ conversion stays in a separate workflow.

# %%
onnx_path = exports_dir / f'{cfg.model_id}.onnx'
export_model = build_eval_model_from_checkpoint(best_ckpt_path, device)
dummy = torch.randn(1, 3, 256, 256, device=device)

torch.onnx.export(
    export_model,
    dummy,
    str(onnx_path),
    input_names=['input'],
    output_names=['output'],
    opset_version=17,
    dynamo=False,
)

onnx_model = onnx.load(str(onnx_path))
onnx.checker.check_model(onnx_model)
node_ops = [node.op_type for node in onnx_model.graph.node]
op_histogram = {op: node_ops.count(op) for op in sorted(set(node_ops))}
print({
    'onnx_path': str(onnx_path),
    'graph_op_count': len(node_ops),
    'op_histogram': op_histogram,
})

parity_result = {
    'attempted': False,
    'onnxruntime_available': False,
    'max_abs_diff': None,
}
try:
    import onnxruntime as ort

    parity_result['attempted'] = True
    parity_result['onnxruntime_available'] = True
    cpu_model = build_eval_model_from_checkpoint(best_ckpt_path, torch.device('cpu')).cpu().eval()
    parity_input = torch.randn(1, 3, 256, 256)
    with torch.no_grad():
        torch_out = cpu_model(parity_input).detach().cpu().numpy()
    ort_session = ort.InferenceSession(str(onnx_path), providers=['CPUExecutionProvider'])
    ort_out = ort_session.run(['output'], {'input': parity_input.numpy()})[0]
    parity_result['max_abs_diff'] = float(np.max(np.abs(torch_out - ort_out)))
except ImportError:
    print('onnxruntime not installed; skipping CPU parity check')
print(parity_result)

summary = {
    'model_id': cfg.model_id,
    'run_root': str(run_root),
    'best_checkpoint_path': str(best_ckpt_path),
    'last_checkpoint_path': str(last_ckpt_path),
    'onnx_path': str(onnx_path),
    'metrics_csv_path': str(metrics_csv_path),
    'validation': validation_summary,
    'preview': preview_info,
    'onnx_parity': parity_result,
    'mxq_scope': 'Not handled in this notebook; separate workflow.',
}
summary_path.write_text(json.dumps(summary, indent=2), encoding='utf-8')
print(summary)
