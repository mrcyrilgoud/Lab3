# %% [markdown]
# # Lab 3 - TinySRCNNResidual (No-Add Colab A100, resume 180446 → 14000 epochs, aggressive LR)
#
# - Goal: resume from the fixed checkpoint below and continue toward epoch `14000` (base lr and min lr doubled vs. prior notebook).
# - Expected input/output: `256x256x3`.
# - Resume checkpoint: `/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/180446_2704_resume_latest_lr_floor/checkpoints/last.pth`.

# %% [markdown]
# ## 1. Setup
#
# This notebook follows the Lab 3 rubric structure while keeping the implementation lean.

# %%
try:
    import google.colab  # type: ignore
    IN_COLAB_BOOTSTRAP = True
except Exception:
    IN_COLAB_BOOTSTRAP = False

if IN_COLAB_BOOTSTRAP:
    # %pip install -q onnx onnxruntime

import csv
import json
import math
import os
import random
import sys
import time
from contextlib import nullcontext
from dataclasses import asdict, dataclass
from datetime import datetime
from pathlib import Path
from typing import Any

import numpy as np
import onnx
import torch
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
from torch.utils.data import DataLoader, Dataset


IMAGE_SUFFIXES = {'.png', '.jpg', '.jpeg', '.bmp'}
DRIVE_ROOT = Path('/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3')
DRIVE_DATA_ROOT = DRIVE_ROOT / 'Data'
DRIVE_RUNS_ROOT = DRIVE_ROOT / 'runs'

try:
    BICUBIC_RESAMPLE = Image.Resampling.BICUBIC
except AttributeError:
    BICUBIC_RESAMPLE = Image.BICUBIC

try:
    FLIP_LEFT_RIGHT = Image.Transpose.FLIP_LEFT_RIGHT
    FLIP_TOP_BOTTOM = Image.Transpose.FLIP_TOP_BOTTOM
    ROTATE_90 = Image.Transpose.ROTATE_90
    ROTATE_180 = Image.Transpose.ROTATE_180
    ROTATE_270 = Image.Transpose.ROTATE_270
except AttributeError:
    FLIP_LEFT_RIGHT = Image.FLIP_LEFT_RIGHT
    FLIP_TOP_BOTTOM = Image.FLIP_TOP_BOTTOM
    ROTATE_90 = Image.ROTATE_90
    ROTATE_180 = Image.ROTATE_180
    ROTATE_270 = Image.ROTATE_270


def set_global_seed(seed: int) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


def now_stamp() -> str:
    return datetime.now().strftime('%H%M%S_%d%m')


def is_colab_runtime() -> bool:
    try:
        import google.colab  # type: ignore  # noqa: F401
        return True
    except Exception:
        return False


def auto_num_workers(in_colab: bool) -> int:
    if sys.platform == 'darwin':
        return 0
    cpu_count = max(os.cpu_count() or 2, 2)
    if in_colab:
        return min(4, max(cpu_count - 1, 2))
    return min(2, cpu_count)


def resolve_repo_root(start: Path) -> Path:
    current = start.resolve()
    for candidate in [current, *current.parents]:
        if (candidate / 'Data').exists() and (candidate / 'runs').exists():
            return candidate
    for candidate in [current, *current.parents]:
        if (candidate / 'Data').exists():
            return candidate
    raise FileNotFoundError(f'Could not locate repo root from {start.resolve()}')


def make_unique_run_root(runs_root: Path, run_slug: str = '') -> Path:
    safe_slug = ''.join(ch if ch.isalnum() or ch in '_-' else '_' for ch in run_slug).strip('_')
    suffix = f'_{safe_slug}' if safe_slug else ''
    candidate = runs_root / f'{now_stamp()}{suffix}'
    while candidate.exists():
        time.sleep(1.1)
        candidate = runs_root / f'{now_stamp()}{suffix}'
    return candidate


def read_checkpoint_identity(checkpoint_path: Path) -> dict[str, Any] | None:
    try:
        checkpoint = torch.load(checkpoint_path, map_location='cpu')
    except Exception:
        return None
    config = checkpoint.get('config') or {}
    model_id = config.get('model_id')
    if not model_id:
        return None
    return {
        'path': str(checkpoint_path),
        'model_id': model_id,
        'epoch': int(checkpoint.get('epoch', 0)),
        'kind': checkpoint_path.name,
        'mtime': checkpoint_path.stat().st_mtime,
    }


def find_latest_model_checkpoint(runs_root: Path, model_id: str, filename: str = 'last.pth') -> str | None:
    candidates: list[dict[str, Any]] = []
    for checkpoint_path in runs_root.rglob(f'checkpoints/{filename}'):
        identity = read_checkpoint_identity(checkpoint_path)
        if identity and identity['model_id'] == model_id:
            candidates.append(identity)
    if not candidates:
        return None
    winner = max(candidates, key=lambda item: item['mtime'])
    return winner['path']


def resolve_resume_checkpoint_path(resume_checkpoint_path: str | None, runs_root: Path, model_id: str) -> str | None:
    if not resume_checkpoint_path:
        return None
    if resume_checkpoint_path == 'last.pth':
        return find_latest_model_checkpoint(runs_root, model_id, filename='last.pth')
    path = Path(resume_checkpoint_path)
    if not path.is_absolute():
        path = runs_root / path
    if path.name == 'exports':
        candidate_paths = [path.parent / 'checkpoints' / 'last.pth']
    elif path.is_dir():
        candidate_paths = [path / 'last.pth']
    else:
        candidate_paths = [path]
    for candidate in candidate_paths:
        if candidate.is_file():
            return str(candidate)
    return None



@dataclass
class RunConfig:
    model_id: str = 'tinysrcnn_noadd_lrelu'
    run_slug: str = 'resume_180446_14000_aggressive_lr'
    enable_resume: bool = True
    resume_checkpoint_path: str | None = '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/180446_2704_resume_latest_lr_floor/checkpoints/last.pth'
    seed: int = 1337
    train_patch_size: int = 256
    eval_size: int = 256
    batch_size: int = 16
    epochs: int = 14000
    lr: float = 2e-4
    min_lr: float = 2e-5
    weight_decay: float = 1e-4
    warmup_epochs: int = 8
    num_workers: int | None = 2
    prefetch_factor: int = 2
    use_amp: bool = True
    use_ema: bool = True
    ema_decay: float = 0.999


cfg = RunConfig()
in_colab = is_colab_runtime()
if in_colab:
    from google.colab import drive  # type: ignore

    drive.mount('/content/drive', force_remount=False)
    data_root = DRIVE_DATA_ROOT
    runs_root = DRIVE_RUNS_ROOT
    if not data_root.exists():
        raise FileNotFoundError(f'Google Drive data root not found: {data_root}')
else:
    repo_root = resolve_repo_root(Path.cwd())
    data_root = repo_root / 'Data'
    runs_root = repo_root / 'runs'
    if not data_root.exists():
        raise FileNotFoundError(f'Data root not found: {data_root}')

runs_root.mkdir(parents=True, exist_ok=True)
if cfg.num_workers is None:
    cfg.num_workers = auto_num_workers(in_colab)
if cfg.enable_resume:
    cfg.resume_checkpoint_path = resolve_resume_checkpoint_path(cfg.resume_checkpoint_path, runs_root, cfg.model_id)
    if cfg.resume_checkpoint_path is None:
        raise FileNotFoundError(f'No latest last.pth found for model_id={cfg.model_id!r} under {runs_root}')
else:
    cfg.resume_checkpoint_path = None

run_root = make_unique_run_root(runs_root, cfg.run_slug)
checkpoints_dir = run_root / 'checkpoints'
exports_dir = run_root / 'exports'
preview_dir = exports_dir / 'val_preview'
summary_path = run_root / 'summary.json'
metrics_csv_path = run_root / 'metrics.csv'

for directory in [run_root, checkpoints_dir, exports_dir, preview_dir]:
    directory.mkdir(parents=True, exist_ok=True)

set_global_seed(cfg.seed)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
if device.type == 'cuda':
    torch.backends.cudnn.benchmark = True
    if hasattr(torch.backends.cuda.matmul, 'allow_tf32'):
        torch.backends.cuda.matmul.allow_tf32 = True
    if hasattr(torch.backends.cudnn, 'allow_tf32'):
        torch.backends.cudnn.allow_tf32 = True
    if hasattr(torch, 'set_float32_matmul_precision'):
        torch.set_float32_matmul_precision('high')

print({
    'device': str(device),
    'data_root': str(data_root),
    'runs_root': str(runs_root),
    'run_root': str(run_root),
    'config': asdict(cfg),
})
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# {'device': 'cuda', 'data_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/Data', 'runs_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs', 'run_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/010743_2804_resume_180446_14000_aggressive_lr', 'config': {'model_id': 'tinysrcnn_noadd_lrelu', 'run_slug': 'resume_180446_14000_aggressive_lr', 'enable_resume': True, 'resume_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/180446_2704_resume_latest_lr_floor/checkpoints/last.pth', 'seed': 1337, 'train_patch_size': 256, 'eval_size': 256, 'batch_size': 16, 'epochs': 14000, 'lr': 0.0002, 'min_lr': 2e-05, 'weight_decay': 0.0001, 'warmup_epochs': 8, 'num_workers': 2, 'prefetch_factor': 2, 'use_amp': True, 'use_ema': True, 'ema_decay': 0.999}}

# %% [markdown]
# ## 2. Data

# %%
L3_TRAIN_SPLITS = (
    ('LR_HR/L3_HR_train1', 'L3_LR/L3_L3_train1', 'L3_HR_train1'),
    ('LR_HR/L3_HR_train2', 'L3_LR/L3_L3_train2', 'L3_HR_train2'),
    ('LR_HR/L3_HR_train3', 'L3_LR/L3_LR_train3', 'L3_HR_train3'),
    ('LR_HR/L3_HR_train4', 'L3_LR/L3_LR_train4', 'L3_HR_train4'),
    ('LR_HR/L3_HR_train', 'L3_LR/L3_LR_train', 'L3_HR_train'),
)
L3_VAL_DIRS = ('L3_HR_valid', 'L3_LR_valid')


def scan_image_directory(directory: Path) -> dict[str, Path]:
    if not directory.exists():
        raise FileNotFoundError(f'Missing directory: {directory}')
    return {
        path.stem: path
        for path in directory.iterdir()
        if path.is_file() and path.suffix.lower() in IMAGE_SUFFIXES
    }


def collect_split_pairs(hr_dir: Path, lr_dir: Path, split_name: str) -> list[tuple[Path, Path, str]]:
    hr_map = scan_image_directory(hr_dir)
    lr_map = scan_image_directory(lr_dir)
    pairs: list[tuple[Path, Path, str]] = []
    for stem in sorted(set(hr_map) & set(lr_map)):
        name = stem if split_name == 'val' else f'{split_name}/{stem}'
        pairs.append((lr_map[stem], hr_map[stem], name))
    return pairs


def collect_all_pairs(data_root: Path) -> tuple[list[tuple[Path, Path, str]], list[tuple[Path, Path, str]]]:
    train_pairs: list[tuple[Path, Path, str]] = []
    for hr_rel, lr_rel, split_name in L3_TRAIN_SPLITS:
        train_pairs.extend(collect_split_pairs(data_root / hr_rel, data_root / lr_rel, split_name))
    val_pairs = collect_split_pairs(data_root / L3_VAL_DIRS[0], data_root / L3_VAL_DIRS[1], 'val')
    return train_pairs, val_pairs


class PairedSRDataset(Dataset):
    def __init__(self, pairs: list[tuple[Path, Path, str]], *, train: bool, patch_size: int, eval_size: int, seed: int):
        self.pairs = pairs
        self.train = train
        self.patch_size = patch_size
        self.eval_size = eval_size
        self.seed = seed
        self.epoch = 0

    def set_epoch(self, epoch: int) -> None:
        self.epoch = epoch

    @staticmethod
    def to_tensor(img: Image.Image) -> torch.Tensor:
        arr = np.asarray(img, dtype=np.float32) / 255.0
        return torch.from_numpy(arr).permute(2, 0, 1).contiguous()

    def augment_pair(self, lr: Image.Image, hr: Image.Image, index: int) -> tuple[Image.Image, Image.Image]:
        rng = random.Random((self.seed * 1_000_003) + (self.epoch * 9_973) + index)
        width, height = lr.size
        patch = self.patch_size
        if width < patch or height < patch:
            lr = lr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            hr = hr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            width, height = lr.size
        left = rng.randint(0, width - patch)
        top = rng.randint(0, height - patch)
        box = (left, top, left + patch, top + patch)
        lr = lr.crop(box)
        hr = hr.crop(box)
        if rng.random() < 0.5:
            lr = lr.transpose(FLIP_LEFT_RIGHT)
            hr = hr.transpose(FLIP_LEFT_RIGHT)
        if rng.random() < 0.5:
            lr = lr.transpose(FLIP_TOP_BOTTOM)
            hr = hr.transpose(FLIP_TOP_BOTTOM)
        rot = rng.choice([0, 1, 2, 3])
        if rot:
            rotate_ops = [ROTATE_90, ROTATE_180, ROTATE_270]
            lr = lr.transpose(rotate_ops[rot - 1])
            hr = hr.transpose(rotate_ops[rot - 1])
        return lr, hr

    def __len__(self) -> int:
        return len(self.pairs)

    def __getitem__(self, index: int) -> dict[str, Any]:
        lr_path, hr_path, name = self.pairs[index]
        lr = Image.open(lr_path).convert('RGB')
        hr = Image.open(hr_path).convert('RGB')
        if self.train:
            lr, hr = self.augment_pair(lr, hr, index)
        elif lr.size != (self.eval_size, self.eval_size):
            lr = lr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            hr = hr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
        return {'lr': self.to_tensor(lr), 'hr': self.to_tensor(hr), 'name': name}


train_pairs, val_pairs = collect_all_pairs(data_root)
if not train_pairs:
    raise FileNotFoundError(f'No training pairs found under {data_root}')
if not val_pairs:
    raise FileNotFoundError(f'No validation pairs found under {data_root}')
print({
    'data_root': str(data_root),
    'train_pairs': len(train_pairs),
    'val_pairs': len(val_pairs),
})

train_ds = PairedSRDataset(train_pairs, train=True, patch_size=cfg.train_patch_size, eval_size=cfg.eval_size, seed=cfg.seed)
val_ds = PairedSRDataset(val_pairs, train=False, patch_size=cfg.train_patch_size, eval_size=cfg.eval_size, seed=cfg.seed)

loader_num_workers = cfg.num_workers if cfg.num_workers is not None else auto_num_workers(in_colab)
train_loader_kwargs = {
    'dataset': train_ds,
    'batch_size': cfg.batch_size,
    'shuffle': True,
    'num_workers': loader_num_workers,
    'pin_memory': device.type == 'cuda',
}
val_loader_kwargs = {
    'dataset': val_ds,
    'batch_size': 1,
    'shuffle': False,
    'num_workers': loader_num_workers,
    'pin_memory': device.type == 'cuda',
}
if loader_num_workers > 0:
    train_loader_kwargs['prefetch_factor'] = cfg.prefetch_factor
    val_loader_kwargs['prefetch_factor'] = cfg.prefetch_factor

train_loader = DataLoader(**train_loader_kwargs)
val_loader = DataLoader(**val_loader_kwargs)

sample_batch = next(iter(val_loader))
print({
    'validation_input_shape': tuple(sample_batch['lr'].shape),
    'validation_target_shape': tuple(sample_batch['hr'].shape),
    'sample_name': sample_batch['name'][0],
})
# Out:
# {'data_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/Data', 'train_pairs': 2217, 'val_pairs': 110}
# {'validation_input_shape': (1, 3, 256, 256), 'validation_target_shape': (1, 3, 256, 256), 'sample_name': '0000'}

# %% [markdown]
# ## 3. Model and Training

# %%
class TinySRCNNNoAdd(nn.Module):
    def __init__(self, channels: int = 64, slope: float = 0.1):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(3, channels, 3, padding=1),
            nn.LeakyReLU(slope, inplace=False),
            nn.Conv2d(channels, channels, 3, padding=1),
            nn.LeakyReLU(slope, inplace=False),
            nn.Conv2d(channels, channels, 3, padding=1),
            nn.LeakyReLU(slope, inplace=False),
            nn.Conv2d(channels, channels, 3, padding=1),
            nn.LeakyReLU(slope, inplace=False),
            nn.Conv2d(channels, 3, 3, padding=1),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.net(x)


def count_parameters(module: nn.Module) -> int:
    return int(sum(param.numel() for param in module.parameters()))


class EMA:
    def __init__(self, model: nn.Module, decay: float):
        self.decay = decay
        self.shadow = {k: v.detach().clone() for k, v in model.state_dict().items()}

    @torch.no_grad()
    def update(self, model: nn.Module) -> None:
        for key, value in model.state_dict().items():
            self.shadow[key].mul_(self.decay).add_(value.detach(), alpha=1.0 - self.decay)

    @torch.no_grad()
    def copy_to(self, model: nn.Module) -> None:
        model.load_state_dict(self.shadow, strict=True)


def make_grad_scaler(enabled: bool):
    if hasattr(torch, 'amp') and hasattr(torch.amp, 'GradScaler'):
        return torch.amp.GradScaler('cuda', enabled=enabled)
    return torch.cuda.amp.GradScaler(enabled=enabled)


def autocast_context(device_type: str, enabled: bool):
    if not enabled:
        return nullcontext()
    if hasattr(torch, 'amp') and hasattr(torch.amp, 'autocast'):
        return torch.amp.autocast(device_type=device_type, enabled=enabled)
    return torch.cuda.amp.autocast(enabled=enabled)


@torch.no_grad()
def batch_psnr(pred: torch.Tensor, target: torch.Tensor) -> float:
    mse = F.mse_loss(pred, target, reduction='none').mean(dim=(1, 2, 3))
    psnr = 10.0 * torch.log10(1.0 / torch.clamp(mse, min=1e-12))
    return float(psnr.mean().item())


def compute_loss(pred: torch.Tensor, hr: torch.Tensor) -> torch.Tensor:
    loss_mse = F.mse_loss(pred, hr)
    loss_l1 = F.l1_loss(pred, hr)
    return 0.8 * loss_mse + 0.2 * loss_l1


def lr_at_epoch(epoch_idx: int, *, base_lr: float, min_lr: float, warmup_epochs: int, total_epochs: int) -> float:
    step = epoch_idx + 1
    if warmup_epochs > 0 and step <= warmup_epochs:
        return base_lr * step / max(1, warmup_epochs)
    progress = max(0.0, (step - warmup_epochs) / max(1, total_epochs - warmup_epochs))
    cosine = 0.5 * (1.0 + math.cos(math.pi * min(progress, 1.0)))
    return min_lr + cosine * (base_lr - min_lr)


@torch.inference_mode()
def evaluate_psnr(model: nn.Module, loader: DataLoader, device: torch.device) -> float:
    model.eval()
    meter = 0.0
    count = 0
    for batch in loader:
        lr = batch['lr'].to(device, non_blocking=(device.type == 'cuda'))
        hr = batch['hr'].to(device, non_blocking=(device.type == 'cuda'))
        pred = model(lr).clamp(0.0, 1.0)
        meter += batch_psnr(pred, hr)
        count += 1
    return meter / max(count, 1)


@torch.inference_mode()
def compute_input_psnr(loader: DataLoader, device: torch.device) -> float:
    meter = 0.0
    count = 0
    for batch in loader:
        lr = batch['lr'].to(device, non_blocking=(device.type == 'cuda'))
        hr = batch['hr'].to(device, non_blocking=(device.type == 'cuda'))
        meter += batch_psnr(lr, hr)
        count += 1
    return meter / max(count, 1)


def tensor_to_uint8_image(x: torch.Tensor) -> Image.Image:
    x = x.detach().cpu().clamp(0.0, 1.0)
    arr = (x.permute(1, 2, 0).numpy() * 255.0).round().astype(np.uint8)
    return Image.fromarray(arr)


@torch.no_grad()
def write_val_preview(model: nn.Module, loader: DataLoader, out_dir: Path, device: torch.device) -> dict[str, str]:
    out_dir.mkdir(parents=True, exist_ok=True)
    batch = next(iter(loader))
    lr = batch['lr'].to(device, non_blocking=(device.type == 'cuda'))
    hr = batch['hr'].to(device, non_blocking=(device.type == 'cuda'))
    pred = model(lr).clamp(0.0, 1.0)
    name = batch['name'][0]
    lr_path = out_dir / 'val_preview_input.png'
    pred_path = out_dir / 'val_preview_pred.png'
    hr_path = out_dir / 'val_preview_target.png'
    tensor_to_uint8_image(lr[0]).save(lr_path)
    tensor_to_uint8_image(pred[0]).save(pred_path)
    tensor_to_uint8_image(hr[0]).save(hr_path)
    return {
        'sample_name': str(name),
        'input': str(lr_path),
        'prediction': str(pred_path),
        'target': str(hr_path),
    }


def checkpoint_payload(model: nn.Module, ema: EMA | None, optimizer: torch.optim.Optimizer, epoch: int, best_val_psnr: float, row: dict[str, Any]) -> dict[str, Any]:
    return {
        'config': asdict(cfg),
        'epoch': int(epoch),
        'model_state_dict': model.state_dict(),
        'ema_state_dict': ema.shadow if ema is not None else None,
        'optimizer_state_dict': optimizer.state_dict(),
        'best_val_psnr': float(best_val_psnr),
        'selected_weight_source': 'ema' if ema is not None else 'raw',
        'last_metrics': row,
    }


def build_eval_model_from_checkpoint(checkpoint_path: Path, device: torch.device) -> nn.Module:
    checkpoint = torch.load(checkpoint_path, map_location=device)
    model = TinySRCNNNoAdd().to(device)
    selected = checkpoint.get('selected_weight_source', 'raw')
    ema_state = checkpoint.get('ema_state_dict')
    if selected == 'ema' and ema_state is not None:
        model.load_state_dict(ema_state, strict=True)
    else:
        model.load_state_dict(checkpoint['model_state_dict'], strict=True)
    model.eval()
    return model


model = TinySRCNNNoAdd().to(device)
eval_model = TinySRCNNNoAdd().to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)
scaler = make_grad_scaler(enabled=(cfg.use_amp and device.type == 'cuda'))
ema = EMA(model, decay=cfg.ema_decay) if cfg.use_ema else None
start_epoch = 0
best_val_psnr = float('-inf')
if cfg.enable_resume and cfg.resume_checkpoint_path:
    checkpoint = torch.load(cfg.resume_checkpoint_path, map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'], strict=True)
    optimizer_state = checkpoint.get('optimizer_state_dict')
    if optimizer_state is not None:
        optimizer.load_state_dict(optimizer_state)
    ema_state = checkpoint.get('ema_state_dict')
    if ema is not None and ema_state is not None:
        ema.shadow = {key: value.detach().clone() for key, value in ema_state.items()}
    start_epoch = int(checkpoint.get('epoch', 0))
    best_val_psnr = float(checkpoint.get('best_val_psnr', float('-inf')))
if ema is not None:
    ema.copy_to(eval_model)
else:
    eval_model.load_state_dict(model.state_dict())

model_parameter_count = count_parameters(model)
print({
    'model_id': cfg.model_id,
    'architecture': 'Conv3x3(3->64) x4 with LeakyReLU, final Conv3x3(64->3), no Add',
    'params': model_parameter_count,
    'resume_checkpoint_path': cfg.resume_checkpoint_path,
    'start_epoch': start_epoch,
})

input_psnr = compute_input_psnr(val_loader, device)
print({'baseline_input_psnr': input_psnr})
# Out:
# {'model_id': 'tinysrcnn_noadd_lrelu', 'architecture': 'Conv3x3(3->64) x4 with LeakyReLU, final Conv3x3(64->3), no Add', 'params': 114307, 'resume_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/180446_2704_resume_latest_lr_floor/checkpoints/last.pth', 'start_epoch': 10000}
# {'baseline_input_psnr': 23.133060299266468}

# %%
metrics_header = [
    'epoch',
    'epoch_time_sec',
    'lr',
    'train_loss',
    'train_psnr',
    'val_psnr',
    'best_val_psnr',
]

best_ckpt_path = checkpoints_dir / 'best.pth'
last_ckpt_path = checkpoints_dir / 'last.pth'

with metrics_csv_path.open('w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=metrics_header)
    writer.writeheader()

for epoch in range(start_epoch, cfg.epochs):
    train_ds.set_epoch(epoch)
    epoch_lr = lr_at_epoch(
        epoch,
        base_lr=cfg.lr,
        min_lr=cfg.min_lr,
        warmup_epochs=cfg.warmup_epochs,
        total_epochs=cfg.epochs,
    )
    for group in optimizer.param_groups:
        group['lr'] = epoch_lr

    epoch_start = time.time()
    model.train()
    train_loss_sum = 0.0
    train_psnr_sum = 0.0
    train_batches = 0

    for batch in train_loader:
        lr = batch['lr'].to(device, non_blocking=(device.type == 'cuda'))
        hr = batch['hr'].to(device, non_blocking=(device.type == 'cuda'))

        optimizer.zero_grad(set_to_none=True)
        with autocast_context(device.type, enabled=(cfg.use_amp and device.type == 'cuda')):
            pred = model(lr)
            loss = compute_loss(pred, hr)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        if ema is not None:
            ema.update(model)

        train_loss_sum += float(loss.item())
        train_psnr_sum += batch_psnr(pred.detach().clamp(0.0, 1.0), hr)
        train_batches += 1

    if ema is not None:
        ema.copy_to(eval_model)
    else:
        eval_model.load_state_dict(model.state_dict())
    eval_model.eval()

    avg_train_loss = train_loss_sum / max(train_batches, 1)
    avg_train_psnr = train_psnr_sum / max(train_batches, 1)
    val_psnr = evaluate_psnr(eval_model, val_loader, device)
    epoch_time = time.time() - epoch_start
    is_best = val_psnr > best_val_psnr
    if is_best:
        best_val_psnr = val_psnr

    row = {
        'epoch': epoch + 1,
        'epoch_time_sec': round(epoch_time, 2),
        'lr': epoch_lr,
        'train_loss': round(avg_train_loss, 6),
        'train_psnr': round(avg_train_psnr, 4),
        'val_psnr': round(val_psnr, 4),
        'best_val_psnr': round(best_val_psnr, 4),
    }
    print(row)

    with metrics_csv_path.open('a', newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=metrics_header)
        writer.writerow(row)

    payload = checkpoint_payload(model, ema, optimizer, epoch + 1, best_val_psnr, row)
    torch.save(payload, last_ckpt_path)
    if is_best:
        torch.save(payload, best_ckpt_path)
# Out:
# {'epoch': 10001, 'epoch_time_sec': 41.14, 'lr': 5.390623299008081e-05, 'train_loss': 0.011831, 'train_psnr': 25.0097, 'val_psnr': 23.8985, 'best_val_psnr': 23.8989}
# {'epoch': 10002, 'epoch_time_sec': 22.4, 'lr': 5.389043190806506e-05, 'train_loss': 0.011792, 'train_psnr': 25.0297, 'val_psnr': 23.8984, 'best_val_psnr': 23.8989}
# {'epoch': 10003, 'epoch_time_sec': 22.44, 'lr': 5.387463365468541e-05, 'train_loss': 0.011809, 'train_psnr': 25.0213, 'val_psnr': 23.8985, 'best_val_psnr': 23.8989}
# {'epoch': 10004, 'epoch_time_sec': 21.65, 'lr': 5.385883823073824e-05, 'train_loss': 0.0118, 'train_psnr': 25.0269, 'val_psnr': 23.8983, 'best_val_psnr': 23.8989}
# {'epoch': 10005, 'epoch_time_sec': 22.44, 'lr': 5.38430456370199e-05, 'train_loss': 0.011793, 'train_psnr': 25.0296, 'val_psnr': 23.8981, 'best_val_psnr': 23.8989}
# {'epoch': 10006, 'epoch_time_sec': 21.71, 'lr': 5.3827255874326445e-05, 'train_loss': 0.011804, 'train_psnr': 25.0234, 'val_psnr': 23.898, 'best_val_psnr': 23.8989}
# {'epoch': 10007, 'epoch_time_sec': 22.38, 'lr': 5.381146894345402e-05, 'train_loss': 0.0118, 'train_psnr': 25.0262, 'val_psnr': 23.898, 'best_val_psnr': 23.8989}
# {'epoch': 10008, 'epoch_time_sec': 21.7, 'lr': 5.3795684845198355e-05, 'train_loss': 0.011786, 'train_psnr': 25.0325, 'val_psnr': 23.8979, 'best_val_psnr': 23.8989}
# {'epoch': 10009, 'epoch_time_sec': 22.48, 'lr': 5.377990358035529e-05, 'train_loss': 0.011801, 'train_psnr': 25.0263, 'val_psnr': 23.8978, 'best_val_psnr': 23.8989}
# {'epoch': 10010, 'epoch_time_sec': 21.75, 'lr': 5.376412514972027e-05, 'train_loss': 0.011804, 'train_psnr': 25.0248, 'val_psnr': 23.8977, 'best_val_psnr': 23.8989}
# {'epoch': 10011, 'epoch_time_sec': 22.17, 'lr': 5.374834955408884e-05, 'train_loss': 0.011798, 'train_psnr': 25.0268, 'val_psnr': 23.8976, 'best_val_psnr': 23.8989}
# {'epoch': 10012, 'epoch_time_sec': 22.51, 'lr': 5.373257679425623e-05, 'train_loss': 0.011798, 'train_psnr': 25.0272, 'val_psnr': 23.8976, 'best_val_psnr': 23.8989}
# {'epoch': 10013, 'epoch_time_sec': 21.84, 'lr': 5.371680687101762e-05, 'train_loss': 0.011785, 'train_psnr': 25.0347, 'val_psnr': 23.8978, 'best_val_psnr': 23.8989}
# {'epoch': 10014, 'epoch_time_sec': 22.42, 'lr': 5.370103978516798e-05, 'train_loss': 0.011805, 'train_psnr': 25.0245, 'val_psnr': 23.8976, 'best_val_psnr': 23.8989}
# {'epoch': 10015, 'epoch_time_sec': 21.73, 'lr': 5.368527553750218e-05, 'train_loss': 0.01179, 'train_psnr': 25.0318, 'val_psnr': 23.8975, 'best_val_psnr': 23.8989}
# {'epoch': 10016, 'epoch_time_sec': 22.48, 'lr': 5.366951412881495e-05, 'train_loss': 0.011808, 'train_psnr': 25.0252, 'val_psnr': 23.8974, 'best_val_psnr': 23.8989}
# {'epoch': 10017, 'epoch_time_sec': 21.82, 'lr': 5.365375555990091e-05, 'train_loss': 0.011789, 'train_psnr': 25.0315, 'val_psnr': 23.8974, 'best_val_psnr': 23.8989}
# {'epoch': 10018, 'epoch_time_sec': 22.41, 'lr': 5.36379998315544e-05, 'train_loss': 0.011794, 'train_psnr': 25.0278, 'val_psnr': 23.8974, 'best_val_psnr': 23.8989}
# {'epoch': 10019, 'epoch_time_sec': 21.71, 'lr': 5.362224694456978e-05, 'train_loss': 0.011801, 'train_psnr': 25.0263, 'val_psnr': 23.8976, 'best_val_psnr': 23.8989}
# {'epoch': 10020, 'epoch_time_sec': 21.74, 'lr': 5.360649689974116e-05, 'train_loss': 0.011782, 'train_psnr': 25.0355, 'val_psnr': 23.8975, 'best_val_psnr': 23.8989}
# {'epoch': 10021, 'epoch_time_sec': 22.43, 'lr': 5.359074969786254e-05, 'train_loss': 0.011791, 'train_psnr': 25.0311, 'val_psnr': 23.8974, 'best_val_psnr': 23.8989}
# {'epoch': 10022, 'epoch_time_sec': 21.71, 'lr': 5.3575005339727834e-05, 'train_loss': 0.011812, 'train_psnr': 25.0234, 'val_psnr': 23.8974, 'best_val_psnr': 23.8989}
# {'epoch': 10023, 'epoch_time_sec': 22.39, 'lr': 5.3559263826130694e-05, 'train_loss': 0.011805, 'train_psnr': 25.024, 'val_psnr': 23.8974, 'best_val_psnr': 23.8989}
# {'epoch': 10024, 'epoch_time_sec': 21.78, 'lr': 5.354352515786472e-05, 'train_loss': 0.01179, 'train_psnr': 25.0311, 'val_psnr': 23.8974, 'best_val_psnr': 23.8989}
# {'epoch': 10025, 'epoch_time_sec': 22.38, 'lr': 5.352778933572332e-05, 'train_loss': 0.011789, 'train_psnr': 25.0314, 'val_psnr': 23.8974, 'best_val_psnr': 23.8989}
# {'epoch': 10026, 'epoch_time_sec': 21.81, 'lr': 5.351205636049983e-05, 'train_loss': 0.011785, 'train_psnr': 25.0333, 'val_psnr': 23.8975, 'best_val_psnr': 23.8989}
# {'epoch': 10027, 'epoch_time_sec': 22.41, 'lr': 5.349632623298734e-05, 'train_loss': 0.011801, 'train_psnr': 25.0276, 'val_psnr': 23.8975, 'best_val_psnr': 23.8989}
# {'epoch': 10028, 'epoch_time_sec': 21.77, 'lr': 5.3480598953978885e-05, 'train_loss': 0.011794, 'train_psnr': 25.029, 'val_psnr': 23.8975, 'best_val_psnr': 23.8989}
# {'epoch': 10029, 'epoch_time_sec': 21.86, 'lr': 5.346487452426728e-05, 'train_loss': 0.011792, 'train_psnr': 25.0302, 'val_psnr': 23.8976, 'best_val_psnr': 23.8989}
# {'epoch': 10030, 'epoch_time_sec': 22.44, 'lr': 5.3449152944645294e-05, 'train_loss': 0.011784, 'train_psnr': 25.0347, 'val_psnr': 23.8976, 'best_val_psnr': 23.8989}
# {'epoch': 10031, 'epoch_time_sec': 21.77, 'lr': 5.343343421590542e-05, 'train_loss': 0.01179, 'train_psnr': 25.031, 'val_psnr': 23.8978, 'best_val_psnr': 23.8989}
# {'epoch': 10032, 'epoch_time_sec': 22.55, 'lr': 5.341771833884012e-05, 'train_loss': 0.011784, 'train_psnr': 25.0348, 'val_psnr': 23.8978, 'best_val_psnr': 23.8989}
# {'epoch': 10033, 'epoch_time_sec': 21.7, 'lr': 5.340200531424168e-05, 'train_loss': 0.011796, 'train_psnr': 25.0267, 'val_psnr': 23.8977, 'best_val_psnr': 23.8989}
# {'epoch': 10034, 'epoch_time_sec': 22.37, 'lr': 5.338629514290227e-05, 'train_loss': 0.011796, 'train_psnr': 25.027, 'val_psnr': 23.8976, 'best_val_psnr': 23.8989}
# {'epoch': 10035, 'epoch_time_sec': 21.78, 'lr': 5.337058782561381e-05, 'train_loss': 0.011811, 'train_psnr': 25.0203, 'val_psnr': 23.8979, 'best_val_psnr': 23.8989}
# {'epoch': 10036, 'epoch_time_sec': 22.46, 'lr': 5.335488336316822e-05, 'train_loss': 0.0118, 'train_psnr': 25.0262, 'val_psnr': 23.898, 'best_val_psnr': 23.8989}
# {'epoch': 10037, 'epoch_time_sec': 21.9, 'lr': 5.333918175635713e-05, 'train_loss': 0.011796, 'train_psnr': 25.0274, 'val_psnr': 23.8979, 'best_val_psnr': 23.8989}
# {'epoch': 10038, 'epoch_time_sec': 21.74, 'lr': 5.332348300597214e-05, 'train_loss': 0.011793, 'train_psnr': 25.0301, 'val_psnr': 23.8979, 'best_val_psnr': 23.8989}
# {'epoch': 10039, 'epoch_time_sec': 22.41, 'lr': 5.33077871128047e-05, 'train_loss': 0.011785, 'train_psnr': 25.0326, 'val_psnr': 23.8978, 'best_val_psnr': 23.8989}
# {'epoch': 10040, 'epoch_time_sec': 21.78, 'lr': 5.3292094077646014e-05, 'train_loss': 0.011819, 'train_psnr': 25.0197, 'val_psnr': 23.8977, 'best_val_psnr': 23.8989}
# {'epoch': 10041, 'epoch_time_sec': 22.42, 'lr': 5.3276403901287236e-05, 'train_loss': 0.011796, 'train_psnr': 25.0291, 'val_psnr': 23.8977, 'best_val_psnr': 23.8989}
# {'epoch': 10042, 'epoch_time_sec': 21.69, 'lr': 5.32607165845194e-05, 'train_loss': 0.011814, 'train_psnr': 25.025, 'val_psnr': 23.8977, 'best_val_psnr': 23.8989}
# {'epoch': 10043, 'epoch_time_sec': 22.52, 'lr': 5.324503212813328e-05, 'train_loss': 0.011791, 'train_psnr': 25.0325, 'val_psnr': 23.8975, 'best_val_psnr': 23.8989}
# {'epoch': 10044, 'epoch_time_sec': 21.74, 'lr': 5.32293505329196e-05, 'train_loss': 0.011802, 'train_psnr': 25.0262, 'val_psnr': 23.8976, 'best_val_psnr': 23.8989}
# {'epoch': 10045, 'epoch_time_sec': 22.41, 'lr': 5.321367179966892e-05, 'train_loss': 0.011811, 'train_psnr': 25.0231, 'val_psnr': 23.8977, 'best_val_psnr': 23.8989}
# {'epoch': 10046, 'epoch_time_sec': 21.82, 'lr': 5.3197995929171624e-05, 'train_loss': 0.01182, 'train_psnr': 25.0212, 'val_psnr': 23.8977, 'best_val_psnr': 23.8989}
# {'epoch': 10047, 'epoch_time_sec': 21.75, 'lr': 5.3182322922218025e-05, 'train_loss': 0.011799, 'train_psnr': 25.0278, 'val_psnr': 23.8976, 'best_val_psnr': 23.8989}
# {'epoch': 10048, 'epoch_time_sec': 22.44, 'lr': 5.3166652779598156e-05, 'train_loss': 0.011791, 'train_psnr': 25.0303, 'val_psnr': 23.8976, 'best_val_psnr': 23.8989}
# {'epoch': 10049, 'epoch_time_sec': 21.68, 'lr': 5.315098550210209e-05, 'train_loss': 0.01179, 'train_psnr': 25.0294, 'val_psnr': 23.8976, 'best_val_psnr': 23.8989}
# {'epoch': 10050, 'epoch_time_sec': 22.43, 'lr': 5.313532109051953e-05, 'train_loss': 0.011799, 'train_psnr': 25.0276, 'val_psnr': 23.8976, 'best_val_psnr': 23.8989}
# {'epoch': 10051, 'epoch_time_sec': 21.79, 'lr': 5.3119659545640315e-05, 'train_loss': 0.011793, 'train_psnr': 25.031, 'val_psnr': 23.8977, 'best_val_psnr': 23.8989}
# {'epoch': 10052, 'epoch_time_sec': 22.48, 'lr': 5.310400086825387e-05, 'train_loss': 0.0118, 'train_psnr': 25.026, 'val_psnr': 23.8979, 'best_val_psnr': 23.8989}
# {'epoch': 10053, 'epoch_time_sec': 21.72, 'lr': 5.3088345059149674e-05, 'train_loss': 0.011804, 'train_psnr': 25.0232, 'val_psnr': 23.8978, 'best_val_psnr': 23.8989}
# {'epoch': 10054, 'epoch_time_sec': 22.36, 'lr': 5.307269211911691e-05, 'train_loss': 0.011789, 'train_psnr': 25.0314, 'val_psnr': 23.8979, 'best_val_psnr': 23.8989}
# {'epoch': 10055, 'epoch_time_sec': 21.78, 'lr': 5.3057042048944734e-05, 'train_loss': 0.011786, 'train_psnr': 25.0318, 'val_psnr': 23.8979, 'best_val_psnr': 23.8989}
# {'epoch': 10056, 'epoch_time_sec': 21.74, 'lr': 5.304139484942206e-05, 'train_loss': 0.011798, 'train_psnr': 25.0291, 'val_psnr': 23.8979, 'best_val_psnr': 23.8989}
# {'epoch': 10057, 'epoch_time_sec': 22.47, 'lr': 5.302575052133773e-05, 'train_loss': 0.011791, 'train_psnr': 25.03, 'val_psnr': 23.8978, 'best_val_psnr': 23.8989}
# {'epoch': 10058, 'epoch_time_sec': 21.7, 'lr': 5.3010109065480465e-05, 'train_loss': 0.011785, 'train_psnr': 25.0329, 'val_psnr': 23.8979, 'best_val_psnr': 23.8989}
# {'epoch': 10059, 'epoch_time_sec': 22.42, 'lr': 5.299447048263869e-05, 'train_loss': 0.011798, 'train_psnr': 25.0296, 'val_psnr': 23.8979, 'best_val_psnr': 23.8989}
# {'epoch': 10060, 'epoch_time_sec': 21.78, 'lr': 5.297883477360088e-05, 'train_loss': 0.011806, 'train_psnr': 25.0208, 'val_psnr': 23.8978, 'best_val_psnr': 23.8989}
# {'epoch': 10061, 'epoch_time_sec': 22.46, 'lr': 5.2963201939155245e-05, 'train_loss': 0.011812, 'train_psnr': 25.0218, 'val_psnr': 23.8978, 'best_val_psnr': 23.8989}
# {'epoch': 10062, 'epoch_time_sec': 21.78, 'lr': 5.294757198008986e-05, 'train_loss': 0.011809, 'train_psnr': 25.0206, 'val_psnr': 23.8978, 'best_val_psnr': 23.8989}
# {'epoch': 10063, 'epoch_time_sec': 22.38, 'lr': 5.293194489719269e-05, 'train_loss': 0.011793, 'train_psnr': 25.03, 'val_psnr': 23.8978, 'best_val_psnr': 23.8989}
# {'epoch': 10064, 'epoch_time_sec': 21.76, 'lr': 5.2916320691251555e-05, 'train_loss': 0.011784, 'train_psnr': 25.033, 'val_psnr': 23.8979, 'best_val_psnr': 23.8989}
# {'epoch': 10065, 'epoch_time_sec': 21.7, 'lr': 5.290069936305408e-05, 'train_loss': 0.011797, 'train_psnr': 25.0288, 'val_psnr': 23.8979, 'best_val_psnr': 23.8989}
# {'epoch': 10066, 'epoch_time_sec': 22.51, 'lr': 5.2885080913387826e-05, 'train_loss': 0.011792, 'train_psnr': 25.0313, 'val_psnr': 23.898, 'best_val_psnr': 23.8989}
# {'epoch': 10067, 'epoch_time_sec': 21.69, 'lr': 5.286946534304006e-05, 'train_loss': 0.011785, 'train_psnr': 25.0342, 'val_psnr': 23.8979, 'best_val_psnr': 23.8989}
# {'epoch': 10068, 'epoch_time_sec': 22.4, 'lr': 5.285385265279814e-05, 'train_loss': 0.011788, 'train_psnr': 25.0333, 'val_psnr': 23.8979, 'best_val_psnr': 23.8989}
# {'epoch': 10069, 'epoch_time_sec': 21.68, 'lr': 5.2838242843449056e-05, 'train_loss': 0.011799, 'train_psnr': 25.026, 'val_psnr': 23.8979, 'best_val_psnr': 23.8989}
# {'epoch': 10070, 'epoch_time_sec': 22.44, 'lr': 5.2822635915779795e-05, 'train_loss': 0.011798, 'train_psnr': 25.0285, 'val_psnr': 23.8979, 'best_val_psnr': 23.8989}
# {'epoch': 10071, 'epoch_time_sec': 21.74, 'lr': 5.2807031870577084e-05, 'train_loss': 0.011795, 'train_psnr': 25.0297, 'val_psnr': 23.8981, 'best_val_psnr': 23.8989}
# {'epoch': 10072, 'epoch_time_sec': 22.36, 'lr': 5.279143070862762e-05, 'train_loss': 0.011804, 'train_psnr': 25.0253, 'val_psnr': 23.898, 'best_val_psnr': 23.8989}
# {'epoch': 10073, 'epoch_time_sec': 21.75, 'lr': 5.2775832430717844e-05, 'train_loss': 0.011802, 'train_psnr': 25.0263, 'val_psnr': 23.8981, 'best_val_psnr': 23.8989}
# {'epoch': 10074, 'epoch_time_sec': 21.75, 'lr': 5.276023703763418e-05, 'train_loss': 0.011797, 'train_psnr': 25.028, 'val_psnr': 23.8981, 'best_val_psnr': 23.8989}
# {'epoch': 10075, 'epoch_time_sec': 22.45, 'lr': 5.274464453016276e-05, 'train_loss': 0.011796, 'train_psnr': 25.0277, 'val_psnr': 23.8982, 'best_val_psnr': 23.8989}
# {'epoch': 10076, 'epoch_time_sec': 21.78, 'lr': 5.2729054909089675e-05, 'train_loss': 0.011785, 'train_psnr': 25.0341, 'val_psnr': 23.8982, 'best_val_psnr': 23.8989}
# {'epoch': 10077, 'epoch_time_sec': 22.44, 'lr': 5.2713468175200846e-05, 'train_loss': 0.01179, 'train_psnr': 25.0299, 'val_psnr': 23.8982, 'best_val_psnr': 23.8989}
# {'epoch': 10078, 'epoch_time_sec': 21.69, 'lr': 5.269788432928207e-05, 'train_loss': 0.011791, 'train_psnr': 25.0311, 'val_psnr': 23.8981, 'best_val_psnr': 23.8989}
# {'epoch': 10079, 'epoch_time_sec': 22.46, 'lr': 5.268230337211891e-05, 'train_loss': 0.011805, 'train_psnr': 25.0236, 'val_psnr': 23.8982, 'best_val_psnr': 23.8989}
# {'epoch': 10080, 'epoch_time_sec': 21.71, 'lr': 5.266672530449688e-05, 'train_loss': 0.011779, 'train_psnr': 25.0381, 'val_psnr': 23.8982, 'best_val_psnr': 23.8989}
# {'epoch': 10081, 'epoch_time_sec': 22.45, 'lr': 5.2651150127201355e-05, 'train_loss': 0.011801, 'train_psnr': 25.027, 'val_psnr': 23.8982, 'best_val_psnr': 23.8989}
# {'epoch': 10082, 'epoch_time_sec': 21.76, 'lr': 5.2635577841017426e-05, 'train_loss': 0.011789, 'train_psnr': 25.0306, 'val_psnr': 23.8983, 'best_val_psnr': 23.8989}
# {'epoch': 10083, 'epoch_time_sec': 21.65, 'lr': 5.2620008446730234e-05, 'train_loss': 0.011786, 'train_psnr': 25.0321, 'val_psnr': 23.8982, 'best_val_psnr': 23.8989}
# {'epoch': 10084, 'epoch_time_sec': 22.41, 'lr': 5.260444194512458e-05, 'train_loss': 0.011793, 'train_psnr': 25.0303, 'val_psnr': 23.8981, 'best_val_psnr': 23.8989}
# {'epoch': 10085, 'epoch_time_sec': 21.72, 'lr': 5.258887833698526e-05, 'train_loss': 0.011787, 'train_psnr': 25.0316, 'val_psnr': 23.898, 'best_val_psnr': 23.8989}
# {'epoch': 10086, 'epoch_time_sec': 22.39, 'lr': 5.257331762309688e-05, 'train_loss': 0.011807, 'train_psnr': 25.0259, 'val_psnr': 23.898, 'best_val_psnr': 23.8989}
# {'epoch': 10087, 'epoch_time_sec': 21.72, 'lr': 5.2557759804243914e-05, 'train_loss': 0.011794, 'train_psnr': 25.0298, 'val_psnr': 23.8978, 'best_val_psnr': 23.8989}
# {'epoch': 10088, 'epoch_time_sec': 22.5, 'lr': 5.254220488121064e-05, 'train_loss': 0.011789, 'train_psnr': 25.0311, 'val_psnr': 23.8978, 'best_val_psnr': 23.8989}
# {'epoch': 10089, 'epoch_time_sec': 21.72, 'lr': 5.252665285478127e-05, 'train_loss': 0.011788, 'train_psnr': 25.0328, 'val_psnr': 23.8979, 'best_val_psnr': 23.8989}
# {'epoch': 10090, 'epoch_time_sec': 22.39, 'lr': 5.251110372573975e-05, 'train_loss': 0.011792, 'train_psnr': 25.0303, 'val_psnr': 23.898, 'best_val_psnr': 23.8989}
# {'epoch': 10091, 'epoch_time_sec': 21.78, 'lr': 5.249555749487003e-05, 'train_loss': 0.011785, 'train_psnr': 25.0327, 'val_psnr': 23.898, 'best_val_psnr': 23.8989}
# {'epoch': 10092, 'epoch_time_sec': 21.82, 'lr': 5.2480014162955774e-05, 'train_loss': 0.01179, 'train_psnr': 25.0319, 'val_psnr': 23.8979, 'best_val_psnr': 23.8989}
# {'epoch': 10093, 'epoch_time_sec': 22.46, 'lr': 5.246447373078064e-05, 'train_loss': 0.011804, 'train_psnr': 25.0254, 'val_psnr': 23.8979, 'best_val_psnr': 23.8989}
# {'epoch': 10094, 'epoch_time_sec': 21.75, 'lr': 5.244893619912794e-05, 'train_loss': 0.011795, 'train_psnr': 25.0296, 'val_psnr': 23.8979, 'best_val_psnr': 23.8989}
# {'epoch': 10095, 'epoch_time_sec': 22.4, 'lr': 5.243340156878111e-05, 'train_loss': 0.011781, 'train_psnr': 25.0353, 'val_psnr': 23.8979, 'best_val_psnr': 23.8989}
# {'epoch': 10096, 'epoch_time_sec': 21.79, 'lr': 5.241786984052319e-05, 'train_loss': 0.01179, 'train_psnr': 25.0315, 'val_psnr': 23.8979, 'best_val_psnr': 23.8989}
# {'epoch': 10097, 'epoch_time_sec': 22.46, 'lr': 5.2402341015137235e-05, 'train_loss': 0.011792, 'train_psnr': 25.0311, 'val_psnr': 23.898, 'best_val_psnr': 23.8989}
# {'epoch': 10098, 'epoch_time_sec': 21.77, 'lr': 5.2386815093406056e-05, 'train_loss': 0.011788, 'train_psnr': 25.0323, 'val_psnr': 23.8979, 'best_val_psnr': 23.8989}
# {'epoch': 10099, 'epoch_time_sec': 22.38, 'lr': 5.2371292076112364e-05, 'train_loss': 0.011786, 'train_psnr': 25.0339, 'val_psnr': 23.898, 'best_val_psnr': 23.8989}
# {'epoch': 10100, 'epoch_time_sec': 21.73, 'lr': 5.235577196403875e-05, 'train_loss': 0.011813, 'train_psnr': 25.0205, 'val_psnr': 23.898, 'best_val_psnr': 23.8989}
# {'epoch': 10101, 'epoch_time_sec': 21.72, 'lr': 5.2340254757967574e-05, 'train_loss': 0.011781, 'train_psnr': 25.0363, 'val_psnr': 23.8982, 'best_val_psnr': 23.8989}
# {'epoch': 10102, 'epoch_time_sec': 22.41, 'lr': 5.2324740458681155e-05, 'train_loss': 0.011788, 'train_psnr': 25.0314, 'val_psnr': 23.8983, 'best_val_psnr': 23.8989}
# {'epoch': 10103, 'epoch_time_sec': 21.74, 'lr': 5.2309229066961556e-05, 'train_loss': 0.011797, 'train_psnr': 25.0292, 'val_psnr': 23.8983, 'best_val_psnr': 23.8989}
# {'epoch': 10104, 'epoch_time_sec': 22.48, 'lr': 5.229372058359077e-05, 'train_loss': 0.011802, 'train_psnr': 25.0278, 'val_psnr': 23.8983, 'best_val_psnr': 23.8989}
# {'epoch': 10105, 'epoch_time_sec': 21.71, 'lr': 5.227821500935063e-05, 'train_loss': 0.011804, 'train_psnr': 25.0236, 'val_psnr': 23.8983, 'best_val_psnr': 23.8989}
# {'epoch': 10106, 'epoch_time_sec': 22.43, 'lr': 5.2262712345022835e-05, 'train_loss': 0.011793, 'train_psnr': 25.0306, 'val_psnr': 23.8982, 'best_val_psnr': 23.8989}
# {'epoch': 10107, 'epoch_time_sec': 21.78, 'lr': 5.224721259138887e-05, 'train_loss': 0.011799, 'train_psnr': 25.0276, 'val_psnr': 23.8982, 'best_val_psnr': 23.8989}
# {'epoch': 10108, 'epoch_time_sec': 22.4, 'lr': 5.223171574923017e-05, 'train_loss': 0.011795, 'train_psnr': 25.0288, 'val_psnr': 23.8981, 'best_val_psnr': 23.8989}
# {'epoch': 10109, 'epoch_time_sec': 21.82, 'lr': 5.221622181932792e-05, 'train_loss': 0.011798, 'train_psnr': 25.0261, 'val_psnr': 23.8981, 'best_val_psnr': 23.8989}
# {'epoch': 10110, 'epoch_time_sec': 21.7, 'lr': 5.220073080246327e-05, 'train_loss': 0.011803, 'train_psnr': 25.0259, 'val_psnr': 23.8981, 'best_val_psnr': 23.8989}
# {'epoch': 10111, 'epoch_time_sec': 22.49, 'lr': 5.218524269941706e-05, 'train_loss': 0.011812, 'train_psnr': 25.0196, 'val_psnr': 23.8982, 'best_val_psnr': 23.8989}
# {'epoch': 10112, 'epoch_time_sec': 21.81, 'lr': 5.216975751097022e-05, 'train_loss': 0.011789, 'train_psnr': 25.0315, 'val_psnr': 23.8982, 'best_val_psnr': 23.8989}
# {'epoch': 10113, 'epoch_time_sec': 22.42, 'lr': 5.215427523790331e-05, 'train_loss': 0.011791, 'train_psnr': 25.03, 'val_psnr': 23.8982, 'best_val_psnr': 23.8989}
# {'epoch': 10114, 'epoch_time_sec': 21.78, 'lr': 5.21387958809969e-05, 'train_loss': 0.011798, 'train_psnr': 25.029, 'val_psnr': 23.8982, 'best_val_psnr': 23.8989}
# {'epoch': 10115, 'epoch_time_sec': 22.45, 'lr': 5.212331944103126e-05, 'train_loss': 0.011794, 'train_psnr': 25.0283, 'val_psnr': 23.8982, 'best_val_psnr': 23.8989}
# {'epoch': 10116, 'epoch_time_sec': 21.8, 'lr': 5.2107845918786686e-05, 'train_loss': 0.011788, 'train_psnr': 25.0346, 'val_psnr': 23.8984, 'best_val_psnr': 23.8989}
# {'epoch': 10117, 'epoch_time_sec': 22.35, 'lr': 5.209237531504318e-05, 'train_loss': 0.011804, 'train_psnr': 25.0237, 'val_psnr': 23.8985, 'best_val_psnr': 23.8989}
# {'epoch': 10118, 'epoch_time_sec': 21.98, 'lr': 5.207690763058067e-05, 'train_loss': 0.011805, 'train_psnr': 25.0242, 'val_psnr': 23.8984, 'best_val_psnr': 23.8989}
# {'epoch': 10119, 'epoch_time_sec': 21.82, 'lr': 5.2061442866178966e-05, 'train_loss': 0.011791, 'train_psnr': 25.0312, 'val_psnr': 23.8984, 'best_val_psnr': 23.8989}
# {'epoch': 10120, 'epoch_time_sec': 22.43, 'lr': 5.204598102261764e-05, 'train_loss': 0.011778, 'train_psnr': 25.039, 'val_psnr': 23.8984, 'best_val_psnr': 23.8989}
# {'epoch': 10121, 'epoch_time_sec': 21.72, 'lr': 5.203052210067617e-05, 'train_loss': 0.011792, 'train_psnr': 25.0319, 'val_psnr': 23.8985, 'best_val_psnr': 23.8989}
# {'epoch': 10122, 'epoch_time_sec': 22.5, 'lr': 5.201506610113392e-05, 'train_loss': 0.011787, 'train_psnr': 25.0306, 'val_psnr': 23.8986, 'best_val_psnr': 23.8989}
# {'epoch': 10123, 'epoch_time_sec': 21.77, 'lr': 5.1999613024770027e-05, 'train_loss': 0.011792, 'train_psnr': 25.0297, 'val_psnr': 23.8987, 'best_val_psnr': 23.8989}
# {'epoch': 10124, 'epoch_time_sec': 22.45, 'lr': 5.198416287236354e-05, 'train_loss': 0.011804, 'train_psnr': 25.0239, 'val_psnr': 23.8986, 'best_val_psnr': 23.8989}
# {'epoch': 10125, 'epoch_time_sec': 21.71, 'lr': 5.196871564469337e-05, 'train_loss': 0.011798, 'train_psnr': 25.0277, 'val_psnr': 23.8987, 'best_val_psnr': 23.8989}
# {'epoch': 10126, 'epoch_time_sec': 22.41, 'lr': 5.1953271342538196e-05, 'train_loss': 0.011795, 'train_psnr': 25.0285, 'val_psnr': 23.8986, 'best_val_psnr': 23.8989}
# {'epoch': 10127, 'epoch_time_sec': 22.2, 'lr': 5.193782996667666e-05, 'train_loss': 0.011789, 'train_psnr': 25.032, 'val_psnr': 23.8986, 'best_val_psnr': 23.8989}
# {'epoch': 10128, 'epoch_time_sec': 21.83, 'lr': 5.192239151788716e-05, 'train_loss': 0.011795, 'train_psnr': 25.0291, 'val_psnr': 23.8986, 'best_val_psnr': 23.8989}
# {'epoch': 10129, 'epoch_time_sec': 22.39, 'lr': 5.1906955996948014e-05, 'train_loss': 0.011791, 'train_psnr': 25.0312, 'val_psnr': 23.8986, 'best_val_psnr': 23.8989}
# {'epoch': 10130, 'epoch_time_sec': 21.75, 'lr': 5.189152340463735e-05, 'train_loss': 0.01179, 'train_psnr': 25.0312, 'val_psnr': 23.8987, 'best_val_psnr': 23.8989}
# {'epoch': 10131, 'epoch_time_sec': 22.42, 'lr': 5.1876093741733224e-05, 'train_loss': 0.011794, 'train_psnr': 25.0292, 'val_psnr': 23.8988, 'best_val_psnr': 23.8989}
# {'epoch': 10132, 'epoch_time_sec': 21.71, 'lr': 5.186066700901342e-05, 'train_loss': 0.011814, 'train_psnr': 25.0218, 'val_psnr': 23.8988, 'best_val_psnr': 23.8989}
# {'epoch': 10133, 'epoch_time_sec': 22.43, 'lr': 5.18452432072557e-05, 'train_loss': 0.011789, 'train_psnr': 25.0313, 'val_psnr': 23.8987, 'best_val_psnr': 23.8989}
# {'epoch': 10134, 'epoch_time_sec': 21.82, 'lr': 5.182982233723755e-05, 'train_loss': 0.011788, 'train_psnr': 25.0325, 'val_psnr': 23.8987, 'best_val_psnr': 23.8989}
# {'epoch': 10135, 'epoch_time_sec': 22.47, 'lr': 5.181440439973645e-05, 'train_loss': 0.011781, 'train_psnr': 25.0374, 'val_psnr': 23.8987, 'best_val_psnr': 23.8989}
# {'epoch': 10136, 'epoch_time_sec': 22.3, 'lr': 5.17989893955296e-05, 'train_loss': 0.011792, 'train_psnr': 25.0309, 'val_psnr': 23.8986, 'best_val_psnr': 23.8989}
# {'epoch': 10137, 'epoch_time_sec': 21.75, 'lr': 5.1783577325394145e-05, 'train_loss': 0.011799, 'train_psnr': 25.0292, 'val_psnr': 23.8987, 'best_val_psnr': 23.8989}
# {'epoch': 10138, 'epoch_time_sec': 22.43, 'lr': 5.176816819010702e-05, 'train_loss': 0.011801, 'train_psnr': 25.0242, 'val_psnr': 23.8988, 'best_val_psnr': 23.8989}
# {'epoch': 10139, 'epoch_time_sec': 21.74, 'lr': 5.175276199044511e-05, 'train_loss': 0.011803, 'train_psnr': 25.024, 'val_psnr': 23.8987, 'best_val_psnr': 23.8989}
# {'epoch': 10140, 'epoch_time_sec': 22.43, 'lr': 5.173735872718501e-05, 'train_loss': 0.011827, 'train_psnr': 25.0211, 'val_psnr': 23.8986, 'best_val_psnr': 23.8989}
# {'epoch': 10141, 'epoch_time_sec': 21.73, 'lr': 5.172195840110327e-05, 'train_loss': 0.011796, 'train_psnr': 25.0286, 'val_psnr': 23.8986, 'best_val_psnr': 23.8989}
# {'epoch': 10142, 'epoch_time_sec': 22.44, 'lr': 5.170656101297629e-05, 'train_loss': 0.01179, 'train_psnr': 25.0301, 'val_psnr': 23.8985, 'best_val_psnr': 23.8989}
# {'epoch': 10143, 'epoch_time_sec': 21.74, 'lr': 5.169116656358022e-05, 'train_loss': 0.011787, 'train_psnr': 25.0329, 'val_psnr': 23.8986, 'best_val_psnr': 23.8989}
# {'epoch': 10144, 'epoch_time_sec': 22.48, 'lr': 5.1675775053691225e-05, 'train_loss': 0.011817, 'train_psnr': 25.0182, 'val_psnr': 23.8984, 'best_val_psnr': 23.8989}
# {'epoch': 10145, 'epoch_time_sec': 22.48, 'lr': 5.166038648408515e-05, 'train_loss': 0.011798, 'train_psnr': 25.0272, 'val_psnr': 23.8984, 'best_val_psnr': 23.8989}
# {'epoch': 10146, 'epoch_time_sec': 21.73, 'lr': 5.164500085553786e-05, 'train_loss': 0.0118, 'train_psnr': 25.0258, 'val_psnr': 23.8983, 'best_val_psnr': 23.8989}
# {'epoch': 10147, 'epoch_time_sec': 22.38, 'lr': 5.1629618168824875e-05, 'train_loss': 0.011797, 'train_psnr': 25.029, 'val_psnr': 23.8984, 'best_val_psnr': 23.8989}
# {'epoch': 10148, 'epoch_time_sec': 21.76, 'lr': 5.161423842472179e-05, 'train_loss': 0.011797, 'train_psnr': 25.0291, 'val_psnr': 23.8984, 'best_val_psnr': 23.8989}
# {'epoch': 10149, 'epoch_time_sec': 22.48, 'lr': 5.159886162400388e-05, 'train_loss': 0.011792, 'train_psnr': 25.0314, 'val_psnr': 23.8984, 'best_val_psnr': 23.8989}
# {'epoch': 10150, 'epoch_time_sec': 21.75, 'lr': 5.158348776744637e-05, 'train_loss': 0.011797, 'train_psnr': 25.0281, 'val_psnr': 23.8984, 'best_val_psnr': 23.8989}
# {'epoch': 10151, 'epoch_time_sec': 22.39, 'lr': 5.1568116855824244e-05, 'train_loss': 0.011804, 'train_psnr': 25.0244, 'val_psnr': 23.8983, 'best_val_psnr': 23.8989}
# {'epoch': 10152, 'epoch_time_sec': 21.76, 'lr': 5.155274888991244e-05, 'train_loss': 0.011798, 'train_psnr': 25.028, 'val_psnr': 23.8983, 'best_val_psnr': 23.8989}
# {'epoch': 10153, 'epoch_time_sec': 22.38, 'lr': 5.1537383870485656e-05, 'train_loss': 0.011788, 'train_psnr': 25.0326, 'val_psnr': 23.8984, 'best_val_psnr': 23.8989}
# {'epoch': 10154, 'epoch_time_sec': 22.5, 'lr': 5.1522021798318534e-05, 'train_loss': 0.011788, 'train_psnr': 25.0316, 'val_psnr': 23.8984, 'best_val_psnr': 23.8989}
# {'epoch': 10155, 'epoch_time_sec': 21.7, 'lr': 5.150666267418544e-05, 'train_loss': 0.01179, 'train_psnr': 25.0302, 'val_psnr': 23.8984, 'best_val_psnr': 23.8989}
# {'epoch': 10156, 'epoch_time_sec': 22.49, 'lr': 5.149130649886077e-05, 'train_loss': 0.011789, 'train_psnr': 25.0324, 'val_psnr': 23.8985, 'best_val_psnr': 23.8989}
# {'epoch': 10157, 'epoch_time_sec': 21.76, 'lr': 5.1475953273118596e-05, 'train_loss': 0.01181, 'train_psnr': 25.0242, 'val_psnr': 23.8986, 'best_val_psnr': 23.8989}
# {'epoch': 10158, 'epoch_time_sec': 22.49, 'lr': 5.1460602997732975e-05, 'train_loss': 0.01179, 'train_psnr': 25.0311, 'val_psnr': 23.8985, 'best_val_psnr': 23.8989}
# {'epoch': 10159, 'epoch_time_sec': 21.71, 'lr': 5.144525567347769e-05, 'train_loss': 0.011789, 'train_psnr': 25.0313, 'val_psnr': 23.8986, 'best_val_psnr': 23.8989}
# {'epoch': 10160, 'epoch_time_sec': 22.42, 'lr': 5.142991130112648e-05, 'train_loss': 0.011798, 'train_psnr': 25.0263, 'val_psnr': 23.8987, 'best_val_psnr': 23.8989}
# {'epoch': 10161, 'epoch_time_sec': 21.71, 'lr': 5.1414569881452906e-05, 'train_loss': 0.011816, 'train_psnr': 25.022, 'val_psnr': 23.8987, 'best_val_psnr': 23.8989}
# {'epoch': 10162, 'epoch_time_sec': 21.95, 'lr': 5.139923141523032e-05, 'train_loss': 0.011791, 'train_psnr': 25.0307, 'val_psnr': 23.8987, 'best_val_psnr': 23.8989}
# {'epoch': 10163, 'epoch_time_sec': 22.42, 'lr': 5.138389590323206e-05, 'train_loss': 0.011794, 'train_psnr': 25.031, 'val_psnr': 23.8986, 'best_val_psnr': 23.8989}
# {'epoch': 10164, 'epoch_time_sec': 21.81, 'lr': 5.1368563346231155e-05, 'train_loss': 0.011791, 'train_psnr': 25.0312, 'val_psnr': 23.8984, 'best_val_psnr': 23.8989}
# {'epoch': 10165, 'epoch_time_sec': 22.49, 'lr': 5.135323374500058e-05, 'train_loss': 0.011796, 'train_psnr': 25.0273, 'val_psnr': 23.8985, 'best_val_psnr': 23.8989}
# {'epoch': 10166, 'epoch_time_sec': 21.8, 'lr': 5.133790710031313e-05, 'train_loss': 0.011783, 'train_psnr': 25.0358, 'val_psnr': 23.8985, 'best_val_psnr': 23.8989}
# {'epoch': 10167, 'epoch_time_sec': 22.47, 'lr': 5.132258341294154e-05, 'train_loss': 0.011798, 'train_psnr': 25.0272, 'val_psnr': 23.8986, 'best_val_psnr': 23.8989}
# {'epoch': 10168, 'epoch_time_sec': 21.77, 'lr': 5.130726268365822e-05, 'train_loss': 0.011798, 'train_psnr': 25.0281, 'val_psnr': 23.8985, 'best_val_psnr': 23.8989}
# {'epoch': 10169, 'epoch_time_sec': 22.41, 'lr': 5.1291944913235595e-05, 'train_loss': 0.011789, 'train_psnr': 25.0321, 'val_psnr': 23.8986, 'best_val_psnr': 23.8989}
# {'epoch': 10170, 'epoch_time_sec': 21.67, 'lr': 5.1276630102445835e-05, 'train_loss': 0.011796, 'train_psnr': 25.0303, 'val_psnr': 23.8985, 'best_val_psnr': 23.8989}
# {'epoch': 10171, 'epoch_time_sec': 21.76, 'lr': 5.126131825206104e-05, 'train_loss': 0.011804, 'train_psnr': 25.0242, 'val_psnr': 23.8986, 'best_val_psnr': 23.8989}
# {'epoch': 10172, 'epoch_time_sec': 22.46, 'lr': 5.1246009362853067e-05, 'train_loss': 0.011789, 'train_psnr': 25.0315, 'val_psnr': 23.8986, 'best_val_psnr': 23.8989}
# {'epoch': 10173, 'epoch_time_sec': 21.74, 'lr': 5.123070343559372e-05, 'train_loss': 0.011786, 'train_psnr': 25.0347, 'val_psnr': 23.8986, 'best_val_psnr': 23.8989}
# {'epoch': 10174, 'epoch_time_sec': 22.44, 'lr': 5.1215400471054596e-05, 'train_loss': 0.011787, 'train_psnr': 25.0317, 'val_psnr': 23.8987, 'best_val_psnr': 23.8989}
# {'epoch': 10175, 'epoch_time_sec': 21.72, 'lr': 5.12001004700072e-05, 'train_loss': 0.011796, 'train_psnr': 25.0295, 'val_psnr': 23.8987, 'best_val_psnr': 23.8989}
# {'epoch': 10176, 'epoch_time_sec': 22.43, 'lr': 5.1184803433222787e-05, 'train_loss': 0.011786, 'train_psnr': 25.0332, 'val_psnr': 23.8986, 'best_val_psnr': 23.8989}
# {'epoch': 10177, 'epoch_time_sec': 21.79, 'lr': 5.116950936147258e-05, 'train_loss': 0.011788, 'train_psnr': 25.0319, 'val_psnr': 23.8986, 'best_val_psnr': 23.8989}
# {'epoch': 10178, 'epoch_time_sec': 22.33, 'lr': 5.1154218255527534e-05, 'train_loss': 0.011787, 'train_psnr': 25.0327, 'val_psnr': 23.8988, 'best_val_psnr': 23.8989}
# {'epoch': 10179, 'epoch_time_sec': 21.72, 'lr': 5.113893011615854e-05, 'train_loss': 0.011796, 'train_psnr': 25.0307, 'val_psnr': 23.8989, 'best_val_psnr': 23.8989}
# {'epoch': 10180, 'epoch_time_sec': 21.78, 'lr': 5.112364494413635e-05, 'train_loss': 0.0118, 'train_psnr': 25.0245, 'val_psnr': 23.8989, 'best_val_psnr': 23.8989}
# {'epoch': 10181, 'epoch_time_sec': 22.4, 'lr': 5.1108362740231474e-05, 'train_loss': 0.011803, 'train_psnr': 25.0262, 'val_psnr': 23.899, 'best_val_psnr': 23.899}
# {'epoch': 10182, 'epoch_time_sec': 21.75, 'lr': 5.109308350521436e-05, 'train_loss': 0.011793, 'train_psnr': 25.0287, 'val_psnr': 23.899, 'best_val_psnr': 23.899}
# {'epoch': 10183, 'epoch_time_sec': 22.47, 'lr': 5.107780723985527e-05, 'train_loss': 0.01179, 'train_psnr': 25.0322, 'val_psnr': 23.899, 'best_val_psnr': 23.899}
# {'epoch': 10184, 'epoch_time_sec': 21.72, 'lr': 5.106253394492436e-05, 'train_loss': 0.011787, 'train_psnr': 25.0326, 'val_psnr': 23.8991, 'best_val_psnr': 23.8991}
# {'epoch': 10185, 'epoch_time_sec': 22.4, 'lr': 5.1047263621191514e-05, 'train_loss': 0.011786, 'train_psnr': 25.0334, 'val_psnr': 23.8991, 'best_val_psnr': 23.8991}
# {'epoch': 10186, 'epoch_time_sec': 21.69, 'lr': 5.1031996269426636e-05, 'train_loss': 0.011781, 'train_psnr': 25.0361, 'val_psnr': 23.8992, 'best_val_psnr': 23.8992}
# {'epoch': 10187, 'epoch_time_sec': 22.42, 'lr': 5.101673189039935e-05, 'train_loss': 0.011806, 'train_psnr': 25.0227, 'val_psnr': 23.8991, 'best_val_psnr': 23.8992}
# {'epoch': 10188, 'epoch_time_sec': 21.75, 'lr': 5.10014704848792e-05, 'train_loss': 0.011816, 'train_psnr': 25.0183, 'val_psnr': 23.899, 'best_val_psnr': 23.8992}
# {'epoch': 10189, 'epoch_time_sec': 21.72, 'lr': 5.098621205363549e-05, 'train_loss': 0.011793, 'train_psnr': 25.0311, 'val_psnr': 23.8991, 'best_val_psnr': 23.8992}
# {'epoch': 10190, 'epoch_time_sec': 22.4, 'lr': 5.0970956597437515e-05, 'train_loss': 0.011799, 'train_psnr': 25.0284, 'val_psnr': 23.8991, 'best_val_psnr': 23.8992}
# {'epoch': 10191, 'epoch_time_sec': 21.75, 'lr': 5.09557041170543e-05, 'train_loss': 0.011795, 'train_psnr': 25.0294, 'val_psnr': 23.899, 'best_val_psnr': 23.8992}
# {'epoch': 10192, 'epoch_time_sec': 22.41, 'lr': 5.094045461325481e-05, 'train_loss': 0.011788, 'train_psnr': 25.0335, 'val_psnr': 23.8991, 'best_val_psnr': 23.8992}
# {'epoch': 10193, 'epoch_time_sec': 21.73, 'lr': 5.092520808680777e-05, 'train_loss': 0.01179, 'train_psnr': 25.0326, 'val_psnr': 23.8991, 'best_val_psnr': 23.8992}
# {'epoch': 10194, 'epoch_time_sec': 22.41, 'lr': 5.090996453848184e-05, 'train_loss': 0.011783, 'train_psnr': 25.0369, 'val_psnr': 23.899, 'best_val_psnr': 23.8992}
# {'epoch': 10195, 'epoch_time_sec': 21.76, 'lr': 5.0894723969045416e-05, 'train_loss': 0.011793, 'train_psnr': 25.0291, 'val_psnr': 23.8991, 'best_val_psnr': 23.8992}
# {'epoch': 10196, 'epoch_time_sec': 22.36, 'lr': 5.08794863792669e-05, 'train_loss': 0.011791, 'train_psnr': 25.0307, 'val_psnr': 23.899, 'best_val_psnr': 23.8992}
# {'epoch': 10197, 'epoch_time_sec': 21.71, 'lr': 5.0864251769914385e-05, 'train_loss': 0.011797, 'train_psnr': 25.0277, 'val_psnr': 23.8991, 'best_val_psnr': 23.8992}
# {'epoch': 10198, 'epoch_time_sec': 21.74, 'lr': 5.084902014175595e-05, 'train_loss': 0.011794, 'train_psnr': 25.0292, 'val_psnr': 23.8991, 'best_val_psnr': 23.8992}
# {'epoch': 10199, 'epoch_time_sec': 22.45, 'lr': 5.083379149555942e-05, 'train_loss': 0.011789, 'train_psnr': 25.0315, 'val_psnr': 23.899, 'best_val_psnr': 23.8992}
# {'epoch': 10200, 'epoch_time_sec': 21.83, 'lr': 5.0818565832092566e-05, 'train_loss': 0.011805, 'train_psnr': 25.027, 'val_psnr': 23.8992, 'best_val_psnr': 23.8992}
# {'epoch': 10201, 'epoch_time_sec': 22.42, 'lr': 5.0803343152122895e-05, 'train_loss': 0.01179, 'train_psnr': 25.031, 'val_psnr': 23.8991, 'best_val_psnr': 23.8992}
# {'epoch': 10202, 'epoch_time_sec': 21.8, 'lr': 5.078812345641785e-05, 'train_loss': 0.0118, 'train_psnr': 25.026, 'val_psnr': 23.8992, 'best_val_psnr': 23.8992}
# {'epoch': 10203, 'epoch_time_sec': 22.42, 'lr': 5.0772906745744727e-05, 'train_loss': 0.011782, 'train_psnr': 25.0377, 'val_psnr': 23.8991, 'best_val_psnr': 23.8992}
# {'epoch': 10204, 'epoch_time_sec': 21.77, 'lr': 5.075769302087059e-05, 'train_loss': 0.011797, 'train_psnr': 25.029, 'val_psnr': 23.8992, 'best_val_psnr': 23.8992}
# {'epoch': 10205, 'epoch_time_sec': 22.35, 'lr': 5.074248228256245e-05, 'train_loss': 0.011808, 'train_psnr': 25.0261, 'val_psnr': 23.8992, 'best_val_psnr': 23.8992}
# {'epoch': 10206, 'epoch_time_sec': 21.81, 'lr': 5.072727453158707e-05, 'train_loss': 0.011799, 'train_psnr': 25.0278, 'val_psnr': 23.8993, 'best_val_psnr': 23.8993}
# {'epoch': 10207, 'epoch_time_sec': 21.71, 'lr': 5.071206976871118e-05, 'train_loss': 0.011795, 'train_psnr': 25.0292, 'val_psnr': 23.8993, 'best_val_psnr': 23.8993}
# {'epoch': 10208, 'epoch_time_sec': 22.45, 'lr': 5.069686799470117e-05, 'train_loss': 0.011808, 'train_psnr': 25.0211, 'val_psnr': 23.8992, 'best_val_psnr': 23.8993}
# {'epoch': 10209, 'epoch_time_sec': 21.8, 'lr': 5.0681669210323575e-05, 'train_loss': 0.011794, 'train_psnr': 25.0286, 'val_psnr': 23.8992, 'best_val_psnr': 23.8993}
# {'epoch': 10210, 'epoch_time_sec': 22.49, 'lr': 5.0666473416344476e-05, 'train_loss': 0.011785, 'train_psnr': 25.0351, 'val_psnr': 23.8993, 'best_val_psnr': 23.8993}
# {'epoch': 10211, 'epoch_time_sec': 21.76, 'lr': 5.0651280613530026e-05, 'train_loss': 0.011807, 'train_psnr': 25.0243, 'val_psnr': 23.8993, 'best_val_psnr': 23.8993}
# {'epoch': 10212, 'epoch_time_sec': 22.42, 'lr': 5.063609080264605e-05, 'train_loss': 0.011787, 'train_psnr': 25.0316, 'val_psnr': 23.8993, 'best_val_psnr': 23.8993}
# {'epoch': 10213, 'epoch_time_sec': 21.68, 'lr': 5.0620903984458375e-05, 'train_loss': 0.011783, 'train_psnr': 25.0363, 'val_psnr': 23.8994, 'best_val_psnr': 23.8994}
# {'epoch': 10214, 'epoch_time_sec': 22.41, 'lr': 5.0605720159732555e-05, 'train_loss': 0.011799, 'train_psnr': 25.0261, 'val_psnr': 23.8992, 'best_val_psnr': 23.8994}
# {'epoch': 10215, 'epoch_time_sec': 22.05, 'lr': 5.059053932923409e-05, 'train_loss': 0.011799, 'train_psnr': 25.0279, 'val_psnr': 23.8992, 'best_val_psnr': 23.8994}
# {'epoch': 10216, 'epoch_time_sec': 21.72, 'lr': 5.057536149372827e-05, 'train_loss': 0.01179, 'train_psnr': 25.0347, 'val_psnr': 23.8992, 'best_val_psnr': 23.8994}
# {'epoch': 10217, 'epoch_time_sec': 22.41, 'lr': 5.0560186653980226e-05, 'train_loss': 0.011789, 'train_psnr': 25.0318, 'val_psnr': 23.8992, 'best_val_psnr': 23.8994}
# {'epoch': 10218, 'epoch_time_sec': 21.77, 'lr': 5.0545014810755e-05, 'train_loss': 0.011806, 'train_psnr': 25.0251, 'val_psnr': 23.8992, 'best_val_psnr': 23.8994}
# {'epoch': 10219, 'epoch_time_sec': 22.41, 'lr': 5.0529845964817475e-05, 'train_loss': 0.011791, 'train_psnr': 25.0313, 'val_psnr': 23.8992, 'best_val_psnr': 23.8994}
# {'epoch': 10220, 'epoch_time_sec': 21.77, 'lr': 5.0514680116932266e-05, 'train_loss': 0.01179, 'train_psnr': 25.0337, 'val_psnr': 23.8993, 'best_val_psnr': 23.8994}
# {'epoch': 10221, 'epoch_time_sec': 22.38, 'lr': 5.049951726786398e-05, 'train_loss': 0.011785, 'train_psnr': 25.0337, 'val_psnr': 23.8992, 'best_val_psnr': 23.8994}
# {'epoch': 10222, 'epoch_time_sec': 21.79, 'lr': 5.048435741837705e-05, 'train_loss': 0.011793, 'train_psnr': 25.0297, 'val_psnr': 23.8994, 'best_val_psnr': 23.8994}
# {'epoch': 10223, 'epoch_time_sec': 22.33, 'lr': 5.046920056923564e-05, 'train_loss': 0.01179, 'train_psnr': 25.0311, 'val_psnr': 23.8995, 'best_val_psnr': 23.8995}
# {'epoch': 10224, 'epoch_time_sec': 22.0, 'lr': 5.045404672120394e-05, 'train_loss': 0.011797, 'train_psnr': 25.0294, 'val_psnr': 23.8995, 'best_val_psnr': 23.8995}
# {'epoch': 10225, 'epoch_time_sec': 21.79, 'lr': 5.0438895875045806e-05, 'train_loss': 0.011795, 'train_psnr': 25.0302, 'val_psnr': 23.8994, 'best_val_psnr': 23.8995}
# {'epoch': 10226, 'epoch_time_sec': 22.4, 'lr': 5.042374803152508e-05, 'train_loss': 0.011799, 'train_psnr': 25.027, 'val_psnr': 23.8995, 'best_val_psnr': 23.8995}
# {'epoch': 10227, 'epoch_time_sec': 21.77, 'lr': 5.0408603191405416e-05, 'train_loss': 0.011787, 'train_psnr': 25.0328, 'val_psnr': 23.8995, 'best_val_psnr': 23.8995}
# {'epoch': 10228, 'epoch_time_sec': 22.39, 'lr': 5.039346135545032e-05, 'train_loss': 0.011804, 'train_psnr': 25.0248, 'val_psnr': 23.8995, 'best_val_psnr': 23.8995}
# {'epoch': 10229, 'epoch_time_sec': 21.75, 'lr': 5.037832252442306e-05, 'train_loss': 0.011783, 'train_psnr': 25.0342, 'val_psnr': 23.8995, 'best_val_psnr': 23.8995}
# {'epoch': 10230, 'epoch_time_sec': 22.39, 'lr': 5.036318669908693e-05, 'train_loss': 0.011785, 'train_psnr': 25.0354, 'val_psnr': 23.8995, 'best_val_psnr': 23.8995}
# {'epoch': 10231, 'epoch_time_sec': 21.81, 'lr': 5.0348053880204856e-05, 'train_loss': 0.011781, 'train_psnr': 25.0362, 'val_psnr': 23.8995, 'best_val_psnr': 23.8995}
# {'epoch': 10232, 'epoch_time_sec': 22.33, 'lr': 5.033292406853983e-05, 'train_loss': 0.011798, 'train_psnr': 25.0273, 'val_psnr': 23.8994, 'best_val_psnr': 23.8995}
# {'epoch': 10233, 'epoch_time_sec': 22.09, 'lr': 5.0317797264854504e-05, 'train_loss': 0.011799, 'train_psnr': 25.0265, 'val_psnr': 23.8993, 'best_val_psnr': 23.8995}
# {'epoch': 10234, 'epoch_time_sec': 21.72, 'lr': 5.0302673469911485e-05, 'train_loss': 0.011797, 'train_psnr': 25.0278, 'val_psnr': 23.8995, 'best_val_psnr': 23.8995}
# {'epoch': 10235, 'epoch_time_sec': 22.37, 'lr': 5.0287552684473215e-05, 'train_loss': 0.011786, 'train_psnr': 25.0341, 'val_psnr': 23.8995, 'best_val_psnr': 23.8995}
# {'epoch': 10236, 'epoch_time_sec': 21.77, 'lr': 5.027243490930201e-05, 'train_loss': 0.01179, 'train_psnr': 25.0334, 'val_psnr': 23.8996, 'best_val_psnr': 23.8996}
# {'epoch': 10237, 'epoch_time_sec': 22.52, 'lr': 5.0257320145159925e-05, 'train_loss': 0.011791, 'train_psnr': 25.0308, 'val_psnr': 23.8996, 'best_val_psnr': 23.8996}
# {'epoch': 10238, 'epoch_time_sec': 21.78, 'lr': 5.0242208392809015e-05, 'train_loss': 0.011782, 'train_psnr': 25.0352, 'val_psnr': 23.8996, 'best_val_psnr': 23.8996}
# {'epoch': 10239, 'epoch_time_sec': 22.37, 'lr': 5.0227099653011014e-05, 'train_loss': 0.011793, 'train_psnr': 25.0332, 'val_psnr': 23.8997, 'best_val_psnr': 23.8997}
# {'epoch': 10240, 'epoch_time_sec': 21.73, 'lr': 5.021199392652766e-05, 'train_loss': 0.011804, 'train_psnr': 25.0259, 'val_psnr': 23.8996, 'best_val_psnr': 23.8997}
# {'epoch': 10241, 'epoch_time_sec': 22.46, 'lr': 5.019689121412048e-05, 'train_loss': 0.011789, 'train_psnr': 25.033, 'val_psnr': 23.8997, 'best_val_psnr': 23.8997}
# {'epoch': 10242, 'epoch_time_sec': 22.24, 'lr': 5.018179151655079e-05, 'train_loss': 0.011791, 'train_psnr': 25.0293, 'val_psnr': 23.8997, 'best_val_psnr': 23.8997}
# {'epoch': 10243, 'epoch_time_sec': 21.7, 'lr': 5.016669483457983e-05, 'train_loss': 0.011784, 'train_psnr': 25.0341, 'val_psnr': 23.8995, 'best_val_psnr': 23.8997}
# {'epoch': 10244, 'epoch_time_sec': 22.39, 'lr': 5.015160116896868e-05, 'train_loss': 0.011799, 'train_psnr': 25.0252, 'val_psnr': 23.8995, 'best_val_psnr': 23.8997}
# {'epoch': 10245, 'epoch_time_sec': 21.74, 'lr': 5.013651052047827e-05, 'train_loss': 0.011793, 'train_psnr': 25.0327, 'val_psnr': 23.8997, 'best_val_psnr': 23.8997}
# {'epoch': 10246, 'epoch_time_sec': 22.44, 'lr': 5.01214228898693e-05, 'train_loss': 0.011798, 'train_psnr': 25.028, 'val_psnr': 23.8997, 'best_val_psnr': 23.8997}
# {'epoch': 10247, 'epoch_time_sec': 21.8, 'lr': 5.010633827790245e-05, 'train_loss': 0.011778, 'train_psnr': 25.039, 'val_psnr': 23.8997, 'best_val_psnr': 23.8997}
# {'epoch': 10248, 'epoch_time_sec': 22.41, 'lr': 5.009125668533811e-05, 'train_loss': 0.0118, 'train_psnr': 25.0268, 'val_psnr': 23.8997, 'best_val_psnr': 23.8997}
# {'epoch': 10249, 'epoch_time_sec': 21.81, 'lr': 5.0076178112936644e-05, 'train_loss': 0.011784, 'train_psnr': 25.0358, 'val_psnr': 23.8997, 'best_val_psnr': 23.8997}
# {'epoch': 10250, 'epoch_time_sec': 22.55, 'lr': 5.006110256145814e-05, 'train_loss': 0.011788, 'train_psnr': 25.0321, 'val_psnr': 23.8997, 'best_val_psnr': 23.8997}
# {'epoch': 10251, 'epoch_time_sec': 22.43, 'lr': 5.0046030031662664e-05, 'train_loss': 0.0118, 'train_psnr': 25.0263, 'val_psnr': 23.8998, 'best_val_psnr': 23.8998}
# {'epoch': 10252, 'epoch_time_sec': 21.78, 'lr': 5.003096052430997e-05, 'train_loss': 0.011787, 'train_psnr': 25.033, 'val_psnr': 23.8998, 'best_val_psnr': 23.8998}
# {'epoch': 10253, 'epoch_time_sec': 22.42, 'lr': 5.001589404015988e-05, 'train_loss': 0.011793, 'train_psnr': 25.03, 'val_psnr': 23.8999, 'best_val_psnr': 23.8999}
# {'epoch': 10254, 'epoch_time_sec': 21.8, 'lr': 5.000083057997183e-05, 'train_loss': 0.011797, 'train_psnr': 25.0265, 'val_psnr': 23.8999, 'best_val_psnr': 23.8999}
# {'epoch': 10255, 'epoch_time_sec': 22.42, 'lr': 4.9985770144505274e-05, 'train_loss': 0.011791, 'train_psnr': 25.0291, 'val_psnr': 23.8998, 'best_val_psnr': 23.8999}
# {'epoch': 10256, 'epoch_time_sec': 21.76, 'lr': 4.997071273451942e-05, 'train_loss': 0.011782, 'train_psnr': 25.0348, 'val_psnr': 23.8998, 'best_val_psnr': 23.8999}
# {'epoch': 10257, 'epoch_time_sec': 22.45, 'lr': 4.995565835077337e-05, 'train_loss': 0.011822, 'train_psnr': 25.024, 'val_psnr': 23.8999, 'best_val_psnr': 23.8999}
# {'epoch': 10258, 'epoch_time_sec': 21.74, 'lr': 4.994060699402602e-05, 'train_loss': 0.011795, 'train_psnr': 25.0316, 'val_psnr': 23.8998, 'best_val_psnr': 23.8999}
# {'epoch': 10259, 'epoch_time_sec': 22.33, 'lr': 4.992555866503617e-05, 'train_loss': 0.011793, 'train_psnr': 25.0306, 'val_psnr': 23.8999, 'best_val_psnr': 23.8999}
# {'epoch': 10260, 'epoch_time_sec': 22.48, 'lr': 4.991051336456249e-05, 'train_loss': 0.011798, 'train_psnr': 25.0273, 'val_psnr': 23.8997, 'best_val_psnr': 23.8999}
# {'epoch': 10261, 'epoch_time_sec': 21.77, 'lr': 4.989547109336338e-05, 'train_loss': 0.011796, 'train_psnr': 25.0307, 'val_psnr': 23.8998, 'best_val_psnr': 23.8999}
# {'epoch': 10262, 'epoch_time_sec': 22.47, 'lr': 4.9880431852197194e-05, 'train_loss': 0.011803, 'train_psnr': 25.0256, 'val_psnr': 23.8998, 'best_val_psnr': 23.8999}
# {'epoch': 10263, 'epoch_time_sec': 21.77, 'lr': 4.986539564182212e-05, 'train_loss': 0.011802, 'train_psnr': 25.0267, 'val_psnr': 23.8998, 'best_val_psnr': 23.8999}
# {'epoch': 10264, 'epoch_time_sec': 22.42, 'lr': 4.9850362462996173e-05, 'train_loss': 0.011782, 'train_psnr': 25.0362, 'val_psnr': 23.8997, 'best_val_psnr': 23.8999}
# {'epoch': 10265, 'epoch_time_sec': 21.83, 'lr': 4.983533231647718e-05, 'train_loss': 0.011786, 'train_psnr': 25.032, 'val_psnr': 23.8996, 'best_val_psnr': 23.8999}
# {'epoch': 10266, 'epoch_time_sec': 22.47, 'lr': 4.982030520302291e-05, 'train_loss': 0.011793, 'train_psnr': 25.033, 'val_psnr': 23.8996, 'best_val_psnr': 23.8999}
# {'epoch': 10267, 'epoch_time_sec': 21.69, 'lr': 4.980528112339086e-05, 'train_loss': 0.01179, 'train_psnr': 25.0331, 'val_psnr': 23.8995, 'best_val_psnr': 23.8999}
# {'epoch': 10268, 'epoch_time_sec': 21.84, 'lr': 4.979026007833847e-05, 'train_loss': 0.011784, 'train_psnr': 25.0349, 'val_psnr': 23.8995, 'best_val_psnr': 23.8999}
# {'epoch': 10269, 'epoch_time_sec': 22.44, 'lr': 4.977524206862297e-05, 'train_loss': 0.011791, 'train_psnr': 25.0295, 'val_psnr': 23.8994, 'best_val_psnr': 23.8999}
# {'epoch': 10270, 'epoch_time_sec': 21.78, 'lr': 4.9760227095001466e-05, 'train_loss': 0.011782, 'train_psnr': 25.0372, 'val_psnr': 23.8994, 'best_val_psnr': 23.8999}
# {'epoch': 10271, 'epoch_time_sec': 22.49, 'lr': 4.974521515823092e-05, 'train_loss': 0.011794, 'train_psnr': 25.0294, 'val_psnr': 23.8994, 'best_val_psnr': 23.8999}
# {'epoch': 10272, 'epoch_time_sec': 21.8, 'lr': 4.973020625906812e-05, 'train_loss': 0.011798, 'train_psnr': 25.0269, 'val_psnr': 23.8994, 'best_val_psnr': 23.8999}
# {'epoch': 10273, 'epoch_time_sec': 22.48, 'lr': 4.971520039826968e-05, 'train_loss': 0.011783, 'train_psnr': 25.0345, 'val_psnr': 23.8995, 'best_val_psnr': 23.8999}
# {'epoch': 10274, 'epoch_time_sec': 21.66, 'lr': 4.970019757659213e-05, 'train_loss': 0.011794, 'train_psnr': 25.0296, 'val_psnr': 23.8994, 'best_val_psnr': 23.8999}
# {'epoch': 10275, 'epoch_time_sec': 22.41, 'lr': 4.968519779479177e-05, 'train_loss': 0.0118, 'train_psnr': 25.0251, 'val_psnr': 23.8993, 'best_val_psnr': 23.8999}
# {'epoch': 10276, 'epoch_time_sec': 21.79, 'lr': 4.967020105362479e-05, 'train_loss': 0.011785, 'train_psnr': 25.0337, 'val_psnr': 23.8994, 'best_val_psnr': 23.8999}
# {'epoch': 10277, 'epoch_time_sec': 21.77, 'lr': 4.965520735384721e-05, 'train_loss': 0.011798, 'train_psnr': 25.0296, 'val_psnr': 23.8995, 'best_val_psnr': 23.8999}
# {'epoch': 10278, 'epoch_time_sec': 22.41, 'lr': 4.964021669621489e-05, 'train_loss': 0.011788, 'train_psnr': 25.0333, 'val_psnr': 23.8992, 'best_val_psnr': 23.8999}
# {'epoch': 10279, 'epoch_time_sec': 21.72, 'lr': 4.962522908148357e-05, 'train_loss': 0.011813, 'train_psnr': 25.0239, 'val_psnr': 23.8994, 'best_val_psnr': 23.8999}
# {'epoch': 10280, 'epoch_time_sec': 22.46, 'lr': 4.9610244510408835e-05, 'train_loss': 0.011789, 'train_psnr': 25.0309, 'val_psnr': 23.8994, 'best_val_psnr': 23.8999}
# {'epoch': 10281, 'epoch_time_sec': 21.76, 'lr': 4.959526298374606e-05, 'train_loss': 0.01179, 'train_psnr': 25.0311, 'val_psnr': 23.8994, 'best_val_psnr': 23.8999}
# {'epoch': 10282, 'epoch_time_sec': 22.43, 'lr': 4.958028450225052e-05, 'train_loss': 0.011788, 'train_psnr': 25.0318, 'val_psnr': 23.8995, 'best_val_psnr': 23.8999}
# {'epoch': 10283, 'epoch_time_sec': 21.75, 'lr': 4.956530906667735e-05, 'train_loss': 0.011798, 'train_psnr': 25.0315, 'val_psnr': 23.8995, 'best_val_psnr': 23.8999}
# {'epoch': 10284, 'epoch_time_sec': 22.47, 'lr': 4.955033667778145e-05, 'train_loss': 0.011794, 'train_psnr': 25.0327, 'val_psnr': 23.8996, 'best_val_psnr': 23.8999}
# {'epoch': 10285, 'epoch_time_sec': 21.73, 'lr': 4.9535367336317674e-05, 'train_loss': 0.011788, 'train_psnr': 25.0325, 'val_psnr': 23.8996, 'best_val_psnr': 23.8999}
# {'epoch': 10286, 'epoch_time_sec': 21.74, 'lr': 4.952040104304061e-05, 'train_loss': 0.011781, 'train_psnr': 25.0374, 'val_psnr': 23.8996, 'best_val_psnr': 23.8999}
# {'epoch': 10287, 'epoch_time_sec': 22.44, 'lr': 4.950543779870477e-05, 'train_loss': 0.01179, 'train_psnr': 25.0318, 'val_psnr': 23.8995, 'best_val_psnr': 23.8999}
# {'epoch': 10288, 'epoch_time_sec': 21.75, 'lr': 4.9490477604064494e-05, 'train_loss': 0.011815, 'train_psnr': 25.0201, 'val_psnr': 23.8995, 'best_val_psnr': 23.8999}
# {'epoch': 10289, 'epoch_time_sec': 22.44, 'lr': 4.9475520459874007e-05, 'train_loss': 0.011788, 'train_psnr': 25.0329, 'val_psnr': 23.8995, 'best_val_psnr': 23.8999}
# {'epoch': 10290, 'epoch_time_sec': 21.72, 'lr': 4.946056636688727e-05, 'train_loss': 0.01179, 'train_psnr': 25.0304, 'val_psnr': 23.8995, 'best_val_psnr': 23.8999}
# {'epoch': 10291, 'epoch_time_sec': 22.46, 'lr': 4.9445615325858224e-05, 'train_loss': 0.011794, 'train_psnr': 25.0303, 'val_psnr': 23.8996, 'best_val_psnr': 23.8999}
# ...
# {'epoch': 12576, 'epoch_time_sec': 32.33, 'lr': 2.4561102333568883e-05, 'train_loss': 0.011764, 'train_psnr': 25.0457, 'val_psnr': 23.9109, 'best_val_psnr': 23.9113}
# {'epoch': 12577, 'epoch_time_sec': 33.3, 'lr': 2.455475310968085e-05, 'train_loss': 0.011767, 'train_psnr': 25.0448, 'val_psnr': 23.9109, 'best_val_psnr': 23.9113}
# {'epoch': 12578, 'epoch_time_sec': 32.36, 'lr': 2.4548408193320307e-05, 'train_loss': 0.011767, 'train_psnr': 25.0468, 'val_psnr': 23.9109, 'best_val_psnr': 23.9113}
# {'epoch': 12579, 'epoch_time_sec': 33.29, 'lr': 2.4542067584807152e-05, 'train_loss': 0.011768, 'train_psnr': 25.0461, 'val_psnr': 23.9108, 'best_val_psnr': 23.9113}
# {'epoch': 12580, 'epoch_time_sec': 32.33, 'lr': 2.4535731284461e-05, 'train_loss': 0.011768, 'train_psnr': 25.0482, 'val_psnr': 23.9108, 'best_val_psnr': 23.9113}
# {'epoch': 12581, 'epoch_time_sec': 33.3, 'lr': 2.452939929260131e-05, 'train_loss': 0.011759, 'train_psnr': 25.0496, 'val_psnr': 23.9109, 'best_val_psnr': 23.9113}
# {'epoch': 12582, 'epoch_time_sec': 32.28, 'lr': 2.452307160954728e-05, 'train_loss': 0.011773, 'train_psnr': 25.0446, 'val_psnr': 23.9109, 'best_val_psnr': 23.9113}
# {'epoch': 12583, 'epoch_time_sec': 33.26, 'lr': 2.4516748235617915e-05, 'train_loss': 0.011761, 'train_psnr': 25.0479, 'val_psnr': 23.9109, 'best_val_psnr': 23.9113}
# {'epoch': 12584, 'epoch_time_sec': 32.32, 'lr': 2.4510429171131973e-05, 'train_loss': 0.011756, 'train_psnr': 25.051, 'val_psnr': 23.9109, 'best_val_psnr': 23.9113}
# {'epoch': 12585, 'epoch_time_sec': 33.25, 'lr': 2.450411441640805e-05, 'train_loss': 0.01176, 'train_psnr': 25.0496, 'val_psnr': 23.9109, 'best_val_psnr': 23.9113}
# {'epoch': 12586, 'epoch_time_sec': 32.45, 'lr': 2.449780397176446e-05, 'train_loss': 0.011753, 'train_psnr': 25.0527, 'val_psnr': 23.911, 'best_val_psnr': 23.9113}
# {'epoch': 12587, 'epoch_time_sec': 32.81, 'lr': 2.4491497837519344e-05, 'train_loss': 0.011761, 'train_psnr': 25.0492, 'val_psnr': 23.911, 'best_val_psnr': 23.9113}
# {'epoch': 12588, 'epoch_time_sec': 32.77, 'lr': 2.4485196013990606e-05, 'train_loss': 0.01176, 'train_psnr': 25.0495, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12589, 'epoch_time_sec': 32.82, 'lr': 2.4478898501495928e-05, 'train_loss': 0.011757, 'train_psnr': 25.0508, 'val_psnr': 23.911, 'best_val_psnr': 23.9113}
# {'epoch': 12590, 'epoch_time_sec': 32.82, 'lr': 2.44726053003528e-05, 'train_loss': 0.011761, 'train_psnr': 25.0481, 'val_psnr': 23.911, 'best_val_psnr': 23.9113}
# {'epoch': 12591, 'epoch_time_sec': 32.8, 'lr': 2.446631641087849e-05, 'train_loss': 0.011778, 'train_psnr': 25.0415, 'val_psnr': 23.911, 'best_val_psnr': 23.9113}
# {'epoch': 12592, 'epoch_time_sec': 32.82, 'lr': 2.446003183339001e-05, 'train_loss': 0.01176, 'train_psnr': 25.0487, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12593, 'epoch_time_sec': 32.8, 'lr': 2.44537515682042e-05, 'train_loss': 0.011752, 'train_psnr': 25.0538, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12594, 'epoch_time_sec': 32.83, 'lr': 2.4447475615637662e-05, 'train_loss': 0.011754, 'train_psnr': 25.0529, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12595, 'epoch_time_sec': 32.78, 'lr': 2.4441203976006775e-05, 'train_loss': 0.011766, 'train_psnr': 25.0476, 'val_psnr': 23.911, 'best_val_psnr': 23.9113}
# {'epoch': 12596, 'epoch_time_sec': 32.78, 'lr': 2.4434936649627732e-05, 'train_loss': 0.011772, 'train_psnr': 25.0433, 'val_psnr': 23.911, 'best_val_psnr': 23.9113}
# {'epoch': 12597, 'epoch_time_sec': 32.82, 'lr': 2.442867363681646e-05, 'train_loss': 0.011755, 'train_psnr': 25.0533, 'val_psnr': 23.9109, 'best_val_psnr': 23.9113}
# {'epoch': 12598, 'epoch_time_sec': 32.84, 'lr': 2.4422414937888713e-05, 'train_loss': 0.011762, 'train_psnr': 25.0481, 'val_psnr': 23.911, 'best_val_psnr': 23.9113}
# {'epoch': 12599, 'epoch_time_sec': 32.77, 'lr': 2.441616055315999e-05, 'train_loss': 0.011774, 'train_psnr': 25.0443, 'val_psnr': 23.911, 'best_val_psnr': 23.9113}
# {'epoch': 12600, 'epoch_time_sec': 32.71, 'lr': 2.440991048294562e-05, 'train_loss': 0.011772, 'train_psnr': 25.0435, 'val_psnr': 23.911, 'best_val_psnr': 23.9113}
# {'epoch': 12601, 'epoch_time_sec': 33.26, 'lr': 2.4403664727560657e-05, 'train_loss': 0.011756, 'train_psnr': 25.0517, 'val_psnr': 23.911, 'best_val_psnr': 23.9113}
# {'epoch': 12602, 'epoch_time_sec': 32.32, 'lr': 2.4397423287319994e-05, 'train_loss': 0.011765, 'train_psnr': 25.0469, 'val_psnr': 23.911, 'best_val_psnr': 23.9113}
# {'epoch': 12603, 'epoch_time_sec': 33.24, 'lr': 2.4391186162538246e-05, 'train_loss': 0.011768, 'train_psnr': 25.0457, 'val_psnr': 23.911, 'best_val_psnr': 23.9113}
# {'epoch': 12604, 'epoch_time_sec': 32.31, 'lr': 2.4384953353529884e-05, 'train_loss': 0.011758, 'train_psnr': 25.0501, 'val_psnr': 23.911, 'best_val_psnr': 23.9113}
# {'epoch': 12605, 'epoch_time_sec': 33.26, 'lr': 2.4378724860609083e-05, 'train_loss': 0.011758, 'train_psnr': 25.0509, 'val_psnr': 23.911, 'best_val_psnr': 23.9113}
# {'epoch': 12606, 'epoch_time_sec': 32.34, 'lr': 2.4372500684089864e-05, 'train_loss': 0.011761, 'train_psnr': 25.0482, 'val_psnr': 23.911, 'best_val_psnr': 23.9113}
# {'epoch': 12607, 'epoch_time_sec': 33.27, 'lr': 2.4366280824285972e-05, 'train_loss': 0.01177, 'train_psnr': 25.0463, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12608, 'epoch_time_sec': 32.29, 'lr': 2.4360065281511005e-05, 'train_loss': 0.011763, 'train_psnr': 25.0493, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12609, 'epoch_time_sec': 33.29, 'lr': 2.4353854056078292e-05, 'train_loss': 0.011774, 'train_psnr': 25.0441, 'val_psnr': 23.911, 'best_val_psnr': 23.9113}
# {'epoch': 12610, 'epoch_time_sec': 32.47, 'lr': 2.434764714830096e-05, 'train_loss': 0.011762, 'train_psnr': 25.0477, 'val_psnr': 23.911, 'best_val_psnr': 23.9113}
# {'epoch': 12611, 'epoch_time_sec': 33.28, 'lr': 2.4341444558491903e-05, 'train_loss': 0.011768, 'train_psnr': 25.0468, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12612, 'epoch_time_sec': 32.61, 'lr': 2.433524628696383e-05, 'train_loss': 0.011756, 'train_psnr': 25.0508, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12613, 'epoch_time_sec': 33.39, 'lr': 2.4329052334029183e-05, 'train_loss': 0.011754, 'train_psnr': 25.0539, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}
# {'epoch': 12614, 'epoch_time_sec': 33.37, 'lr': 2.4322862700000245e-05, 'train_loss': 0.011756, 'train_psnr': 25.0499, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}
# {'epoch': 12615, 'epoch_time_sec': 32.54, 'lr': 2.431667738518906e-05, 'train_loss': 0.01177, 'train_psnr': 25.0444, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12616, 'epoch_time_sec': 33.25, 'lr': 2.431049638990741e-05, 'train_loss': 0.01176, 'train_psnr': 25.0497, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12617, 'epoch_time_sec': 32.31, 'lr': 2.4304319714466913e-05, 'train_loss': 0.011768, 'train_psnr': 25.0508, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}
# {'epoch': 12618, 'epoch_time_sec': 33.29, 'lr': 2.429814735917895e-05, 'train_loss': 0.011768, 'train_psnr': 25.046, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}
# {'epoch': 12619, 'epoch_time_sec': 32.32, 'lr': 2.4291979324354706e-05, 'train_loss': 0.011759, 'train_psnr': 25.0507, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}
# {'epoch': 12620, 'epoch_time_sec': 33.29, 'lr': 2.42858156103051e-05, 'train_loss': 0.011768, 'train_psnr': 25.0453, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}
# {'epoch': 12621, 'epoch_time_sec': 32.43, 'lr': 2.4279656217340892e-05, 'train_loss': 0.011758, 'train_psnr': 25.0507, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}
# {'epoch': 12622, 'epoch_time_sec': 33.35, 'lr': 2.4273501145772558e-05, 'train_loss': 0.011755, 'train_psnr': 25.0525, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12623, 'epoch_time_sec': 32.39, 'lr': 2.4267350395910424e-05, 'train_loss': 0.011768, 'train_psnr': 25.0468, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12624, 'epoch_time_sec': 33.31, 'lr': 2.4261203968064535e-05, 'train_loss': 0.011769, 'train_psnr': 25.0458, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12625, 'epoch_time_sec': 32.32, 'lr': 2.4255061862544774e-05, 'train_loss': 0.01179, 'train_psnr': 25.04, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12626, 'epoch_time_sec': 33.22, 'lr': 2.4248924079660765e-05, 'train_loss': 0.01177, 'train_psnr': 25.0442, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12627, 'epoch_time_sec': 32.78, 'lr': 2.4242790619721956e-05, 'train_loss': 0.011766, 'train_psnr': 25.0457, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12628, 'epoch_time_sec': 32.79, 'lr': 2.423666148303753e-05, 'train_loss': 0.011762, 'train_psnr': 25.0486, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}
# {'epoch': 12629, 'epoch_time_sec': 32.81, 'lr': 2.423053666991647e-05, 'train_loss': 0.011766, 'train_psnr': 25.0468, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12630, 'epoch_time_sec': 32.85, 'lr': 2.4224416180667555e-05, 'train_loss': 0.01176, 'train_psnr': 25.05, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12631, 'epoch_time_sec': 32.83, 'lr': 2.421830001559933e-05, 'train_loss': 0.011764, 'train_psnr': 25.0465, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12632, 'epoch_time_sec': 32.82, 'lr': 2.4212188175020143e-05, 'train_loss': 0.011767, 'train_psnr': 25.0446, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12633, 'epoch_time_sec': 32.89, 'lr': 2.4206080659238076e-05, 'train_loss': 0.011773, 'train_psnr': 25.0434, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12634, 'epoch_time_sec': 32.88, 'lr': 2.4199977468561055e-05, 'train_loss': 0.011761, 'train_psnr': 25.0492, 'val_psnr': 23.911, 'best_val_psnr': 23.9113}
# {'epoch': 12635, 'epoch_time_sec': 32.85, 'lr': 2.419387860329675e-05, 'train_loss': 0.011767, 'train_psnr': 25.047, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12636, 'epoch_time_sec': 32.76, 'lr': 2.4187784063752618e-05, 'train_loss': 0.011778, 'train_psnr': 25.0426, 'val_psnr': 23.911, 'best_val_psnr': 23.9113}
# {'epoch': 12637, 'epoch_time_sec': 32.87, 'lr': 2.41816938502359e-05, 'train_loss': 0.011768, 'train_psnr': 25.0447, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}
# {'epoch': 12638, 'epoch_time_sec': 32.81, 'lr': 2.4175607963053637e-05, 'train_loss': 0.011764, 'train_psnr': 25.0477, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}
# {'epoch': 12639, 'epoch_time_sec': 32.69, 'lr': 2.4169526402512605e-05, 'train_loss': 0.011766, 'train_psnr': 25.0469, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}
# {'epoch': 12640, 'epoch_time_sec': 33.33, 'lr': 2.4163449168919424e-05, 'train_loss': 0.011778, 'train_psnr': 25.0408, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}
# {'epoch': 12641, 'epoch_time_sec': 32.37, 'lr': 2.415737626258043e-05, 'train_loss': 0.011764, 'train_psnr': 25.0455, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12642, 'epoch_time_sec': 33.29, 'lr': 2.4151307683801814e-05, 'train_loss': 0.011771, 'train_psnr': 25.0416, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}
# {'epoch': 12643, 'epoch_time_sec': 32.28, 'lr': 2.4145243432889464e-05, 'train_loss': 0.011756, 'train_psnr': 25.0533, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}
# {'epoch': 12644, 'epoch_time_sec': 33.32, 'lr': 2.4139183510149134e-05, 'train_loss': 0.01178, 'train_psnr': 25.0403, 'val_psnr': 23.9113, 'best_val_psnr': 23.9113}
# {'epoch': 12645, 'epoch_time_sec': 32.33, 'lr': 2.4133127915886312e-05, 'train_loss': 0.011754, 'train_psnr': 25.0521, 'val_psnr': 23.9113, 'best_val_psnr': 23.9113}
# {'epoch': 12646, 'epoch_time_sec': 33.31, 'lr': 2.4127076650406272e-05, 'train_loss': 0.011765, 'train_psnr': 25.046, 'val_psnr': 23.9113, 'best_val_psnr': 23.9113}
# {'epoch': 12647, 'epoch_time_sec': 32.31, 'lr': 2.412102971401407e-05, 'train_loss': 0.01177, 'train_psnr': 25.0455, 'val_psnr': 23.9113, 'best_val_psnr': 23.9113}
# {'epoch': 12648, 'epoch_time_sec': 33.23, 'lr': 2.4114987107014562e-05, 'train_loss': 0.011767, 'train_psnr': 25.0464, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}
# {'epoch': 12649, 'epoch_time_sec': 32.27, 'lr': 2.4108948829712357e-05, 'train_loss': 0.011758, 'train_psnr': 25.0502, 'val_psnr': 23.9113, 'best_val_psnr': 23.9113}
# {'epoch': 12650, 'epoch_time_sec': 33.3, 'lr': 2.4102914882411864e-05, 'train_loss': 0.011763, 'train_psnr': 25.0462, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}
# {'epoch': 12651, 'epoch_time_sec': 32.39, 'lr': 2.4096885265417268e-05, 'train_loss': 0.01176, 'train_psnr': 25.0491, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}
# {'epoch': 12652, 'epoch_time_sec': 33.3, 'lr': 2.4090859979032564e-05, 'train_loss': 0.011769, 'train_psnr': 25.0475, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}
# {'epoch': 12653, 'epoch_time_sec': 32.61, 'lr': 2.4084839023561475e-05, 'train_loss': 0.011761, 'train_psnr': 25.051, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}
# {'epoch': 12654, 'epoch_time_sec': 32.79, 'lr': 2.407882239930755e-05, 'train_loss': 0.011756, 'train_psnr': 25.0496, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12655, 'epoch_time_sec': 32.76, 'lr': 2.4072810106574094e-05, 'train_loss': 0.011757, 'train_psnr': 25.0508, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}
# {'epoch': 12656, 'epoch_time_sec': 32.79, 'lr': 2.4066802145664192e-05, 'train_loss': 0.011759, 'train_psnr': 25.0517, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}
# {'epoch': 12657, 'epoch_time_sec': 32.84, 'lr': 2.4060798516880758e-05, 'train_loss': 0.01176, 'train_psnr': 25.0483, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}
# {'epoch': 12658, 'epoch_time_sec': 32.8, 'lr': 2.4054799220526413e-05, 'train_loss': 0.011759, 'train_psnr': 25.051, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}
# {'epoch': 12659, 'epoch_time_sec': 32.75, 'lr': 2.4048804256903626e-05, 'train_loss': 0.011758, 'train_psnr': 25.0496, 'val_psnr': 23.9113, 'best_val_psnr': 23.9113}
# {'epoch': 12660, 'epoch_time_sec': 32.8, 'lr': 2.4042813626314574e-05, 'train_loss': 0.011763, 'train_psnr': 25.0472, 'val_psnr': 23.9113, 'best_val_psnr': 23.9113}
# {'epoch': 12661, 'epoch_time_sec': 32.85, 'lr': 2.4036827329061333e-05, 'train_loss': 0.011763, 'train_psnr': 25.0467, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}
# {'epoch': 12662, 'epoch_time_sec': 32.78, 'lr': 2.403084536544562e-05, 'train_loss': 0.011762, 'train_psnr': 25.0478, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12663, 'epoch_time_sec': 32.81, 'lr': 2.4024867735769055e-05, 'train_loss': 0.011764, 'train_psnr': 25.0469, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12664, 'epoch_time_sec': 32.78, 'lr': 2.4018894440332946e-05, 'train_loss': 0.011762, 'train_psnr': 25.0484, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12665, 'epoch_time_sec': 32.78, 'lr': 2.401292547943846e-05, 'train_loss': 0.011774, 'train_psnr': 25.0417, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}
# {'epoch': 12666, 'epoch_time_sec': 32.83, 'lr': 2.4006960853386473e-05, 'train_loss': 0.011789, 'train_psnr': 25.0355, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}
# {'epoch': 12667, 'epoch_time_sec': 32.4, 'lr': 2.40010005624777e-05, 'train_loss': 0.01177, 'train_psnr': 25.0465, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12668, 'epoch_time_sec': 33.27, 'lr': 2.39950446070126e-05, 'train_loss': 0.01175, 'train_psnr': 25.0554, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}
# {'epoch': 12669, 'epoch_time_sec': 32.41, 'lr': 2.3989092987291434e-05, 'train_loss': 0.011773, 'train_psnr': 25.0435, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12670, 'epoch_time_sec': 33.26, 'lr': 2.398314570361425e-05, 'train_loss': 0.011762, 'train_psnr': 25.0484, 'val_psnr': 23.9111, 'best_val_psnr': 23.9113}
# {'epoch': 12671, 'epoch_time_sec': 32.49, 'lr': 2.3977202756280872e-05, 'train_loss': 0.011761, 'train_psnr': 25.0501, 'val_psnr': 23.9112, 'best_val_psnr': 23.9113}

# %% [markdown]
# ## 4. Validation

# %%
best_model = build_eval_model_from_checkpoint(best_ckpt_path, device)
preview_info = write_val_preview(best_model, val_loader, preview_dir, device)
best_val_psnr = evaluate_psnr(best_model, val_loader, device)
validation_summary = {
    'input_psnr': input_psnr,
    'val_psnr': best_val_psnr,
    'delta_psnr': best_val_psnr - input_psnr,
}
print({
    'validation_summary': validation_summary,
    'preview': preview_info,
    'best_checkpoint_path': str(best_ckpt_path),
})

# %% [markdown]
# ## 5. Export and Submission Artifacts
#
# ONNX export is included here. MXQ conversion stays in a separate workflow.

# %%
onnx_path = exports_dir / f'{cfg.model_id}.onnx'
export_model = build_eval_model_from_checkpoint(best_ckpt_path, device)
dummy = torch.randn(1, 3, 256, 256, device=device)

torch.onnx.export(
    export_model,
    dummy,
    str(onnx_path),
    input_names=['input'],
    output_names=['output'],
    opset_version=17,
    dynamo=False,
)

onnx_model = onnx.load(str(onnx_path))
onnx.checker.check_model(onnx_model)
node_ops = [node.op_type for node in onnx_model.graph.node]
op_histogram = {op: node_ops.count(op) for op in sorted(set(node_ops))}
print({
    'onnx_path': str(onnx_path),
    'graph_op_count': len(node_ops),
    'op_histogram': op_histogram,
})

parity_result = {
    'attempted': False,
    'onnxruntime_available': False,
    'max_abs_diff': None,
}
try:
    import onnxruntime as ort

    parity_result['attempted'] = True
    parity_result['onnxruntime_available'] = True
    cpu_model = build_eval_model_from_checkpoint(best_ckpt_path, torch.device('cpu')).cpu().eval()
    parity_input = torch.randn(1, 3, 256, 256)
    with torch.no_grad():
        torch_out = cpu_model(parity_input).detach().cpu().numpy()
    ort_session = ort.InferenceSession(str(onnx_path), providers=['CPUExecutionProvider'])
    ort_out = ort_session.run(['output'], {'input': parity_input.numpy()})[0]
    parity_result['max_abs_diff'] = float(np.max(np.abs(torch_out - ort_out)))
except ImportError:
    print('onnxruntime not installed; skipping CPU parity check')
print(parity_result)

summary = {
    'model_id': cfg.model_id,
    'run_root': str(run_root),
    'best_checkpoint_path': str(best_ckpt_path),
    'last_checkpoint_path': str(last_ckpt_path),
    'onnx_path': str(onnx_path),
    'metrics_csv_path': str(metrics_csv_path),
    'validation': validation_summary,
    'preview': preview_info,
    'onnx_parity': parity_result,
    'mxq_scope': 'Not handled in this notebook; separate workflow.',
}
summary_path.write_text(json.dumps(summary, indent=2), encoding='utf-8')
print(summary)
