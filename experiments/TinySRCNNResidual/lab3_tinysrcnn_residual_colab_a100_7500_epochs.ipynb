# %% [markdown]
# # Lab 3 - TinySRCNNResidual (No-Add Colab, 7500 epochs)
#
# - Goal: train a TinySRCNN-style no-add super-resolution model for Lab 3.
# - Expected input/output: `256x256x3`
# - Runtime target: Google Colab with Google Drive.
# - Note: MXQ conversion is intentionally handled outside this notebook.

# %% [markdown]
# ## 1. Setup
#
# This notebook follows the Lab 3 rubric structure while keeping the implementation lean.

# %%
try:
    import google.colab  # type: ignore
    IN_COLAB_BOOTSTRAP = True
except Exception:
    IN_COLAB_BOOTSTRAP = False

if IN_COLAB_BOOTSTRAP:
    # %pip install -q onnx onnxruntime

import csv
import json
import math
import os
import random
import sys
import time
from contextlib import nullcontext
from dataclasses import asdict, dataclass
from datetime import datetime
from pathlib import Path
from typing import Any

import numpy as np
import onnx
import torch
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
from torch.utils.data import DataLoader, Dataset


IMAGE_SUFFIXES = {'.png', '.jpg', '.jpeg', '.bmp'}
DRIVE_ROOT = Path('/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3')
DRIVE_DATA_ROOT = DRIVE_ROOT / 'Data'
DRIVE_RUNS_ROOT = DRIVE_ROOT / 'runs'

try:
    BICUBIC_RESAMPLE = Image.Resampling.BICUBIC
except AttributeError:
    BICUBIC_RESAMPLE = Image.BICUBIC

try:
    FLIP_LEFT_RIGHT = Image.Transpose.FLIP_LEFT_RIGHT
    FLIP_TOP_BOTTOM = Image.Transpose.FLIP_TOP_BOTTOM
    ROTATE_90 = Image.Transpose.ROTATE_90
    ROTATE_180 = Image.Transpose.ROTATE_180
    ROTATE_270 = Image.Transpose.ROTATE_270
except AttributeError:
    FLIP_LEFT_RIGHT = Image.FLIP_LEFT_RIGHT
    FLIP_TOP_BOTTOM = Image.FLIP_TOP_BOTTOM
    ROTATE_90 = Image.ROTATE_90
    ROTATE_180 = Image.ROTATE_180
    ROTATE_270 = Image.ROTATE_270


def set_global_seed(seed: int) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


def now_stamp() -> str:
    return datetime.now().strftime('%H%M%S_%d%m')


def is_colab_runtime() -> bool:
    try:
        import google.colab  # type: ignore  # noqa: F401
        return True
    except Exception:
        return False


def auto_num_workers(in_colab: bool) -> int:
    if sys.platform == 'darwin':
        return 0
    cpu_count = max(os.cpu_count() or 2, 2)
    if in_colab:
        return min(4, max(cpu_count - 1, 2))
    return min(2, cpu_count)


def resolve_repo_root(start: Path) -> Path:
    current = start.resolve()
    for candidate in [current, *current.parents]:
        if (candidate / 'Data').exists() and (candidate / 'runs').exists():
            return candidate
    for candidate in [current, *current.parents]:
        if (candidate / 'Data').exists():
            return candidate
    raise FileNotFoundError(f'Could not locate repo root from {start.resolve()}')


def make_unique_run_root(runs_root: Path, run_slug: str = '') -> Path:
    safe_slug = ''.join(ch if ch.isalnum() or ch in '_-' else '_' for ch in run_slug).strip('_')
    suffix = f'_{safe_slug}' if safe_slug else ''
    candidate = runs_root / f'{now_stamp()}{suffix}'
    while candidate.exists():
        time.sleep(1.1)
        candidate = runs_root / f'{now_stamp()}{suffix}'
    return candidate


def read_checkpoint_identity(checkpoint_path: Path) -> dict[str, Any] | None:
    try:
        checkpoint = torch.load(checkpoint_path, map_location='cpu')
    except Exception:
        return None
    config = checkpoint.get('config') or {}
    model_id = config.get('model_id')
    if not model_id:
        return None
    return {
        'path': str(checkpoint_path),
        'model_id': model_id,
        'epoch': int(checkpoint.get('epoch', 0)),
        'kind': checkpoint_path.name,
        'mtime': checkpoint_path.stat().st_mtime,
    }


def find_latest_model_checkpoint(runs_root: Path, model_id: str, filename: str = 'last.pth') -> str | None:
    candidates: list[dict[str, Any]] = []
    for checkpoint_path in runs_root.rglob(f'checkpoints/{filename}'):
        identity = read_checkpoint_identity(checkpoint_path)
        if identity and identity['model_id'] == model_id:
            candidates.append(identity)
    if not candidates:
        return None
    winner = max(candidates, key=lambda item: item['mtime'])
    return winner['path']


def resolve_resume_checkpoint_path(resume_checkpoint_path: str | None, runs_root: Path, model_id: str) -> str | None:
    if not resume_checkpoint_path:
        return None
    if resume_checkpoint_path == 'last.pth':
        return find_latest_model_checkpoint(runs_root, model_id, filename='last.pth')
    path = Path(resume_checkpoint_path)
    if not path.is_absolute():
        path = runs_root / path
    if path.name == 'exports':
        candidate_paths = [path.parent / 'checkpoints' / 'last.pth']
    elif path.is_dir():
        candidate_paths = [path / 'last.pth']
    else:
        candidate_paths = [path]
    for candidate in candidate_paths:
        if candidate.is_file():
            return str(candidate)
    return None



def required_relative_dirs() -> list[Path]:
    paths: list[Path] = []
    for hr_rel, lr_rel, _ in (
        ('LR_HR/L3_HR_train1', 'L3_LR/L3_L3_train1', 'L3_HR_train1'),
        ('LR_HR/L3_HR_train2', 'L3_LR/L3_L3_train2', 'L3_HR_train2'),
        ('LR_HR/L3_HR_train3', 'L3_LR/L3_LR_train3', 'L3_HR_train3'),
        ('LR_HR/L3_HR_train4', 'L3_LR/L3_LR_train4', 'L3_HR_train4'),
        ('LR_HR/L3_HR_train', 'L3_LR/L3_LR_train', 'L3_HR_train'),
    ):
        paths.append(Path(hr_rel))
        paths.append(Path(lr_rel))
    paths.append(Path('L3_HR_valid'))
    paths.append(Path('L3_LR_valid'))
    return paths


def stage_data_root(source_root: Path, local_root: Path) -> Path:
    import shutil

    required = required_relative_dirs()
    if all((local_root / rel).exists() for rel in required):
        print({
            'data_staging': 'reuse_existing',
            'source_root': str(source_root),
            'local_root': str(local_root),
        })
        return local_root

    start = time.time()
    for rel in required:
        src_dir = source_root / rel
        dst_dir = local_root / rel
        dst_dir.parent.mkdir(parents=True, exist_ok=True)
        if dst_dir.exists():
            shutil.rmtree(dst_dir)
        shutil.copytree(src_dir, dst_dir)
    elapsed = time.time() - start
    print({
        'data_staging': 'copied_to_local',
        'source_root': str(source_root),
        'local_root': str(local_root),
        'elapsed_sec': round(elapsed, 2),
    })
    return local_root


@dataclass
class RunConfig:
    model_id: str = 'tinysrcnn_noadd_lrelu'
    run_slug: str = 'base'
    enable_resume: bool = True
    resume_checkpoint_path: str | None = '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/161827_2504_base/checkpoints/last.pth'
    seed: int = 1337
    train_patch_size: int = 256
    eval_size: int = 256
    batch_size: int = 16
    epochs: int = 7500
    lr: float = 1e-4
    min_lr: float = 1e-6
    weight_decay: float = 1e-4
    warmup_epochs: int = 8
    num_workers: int | None = 2
    prefetch_factor: int = 2
    use_amp: bool = True
    use_ema: bool = True
    ema_decay: float = 0.999


cfg = RunConfig()
in_colab = is_colab_runtime()
if in_colab:
    from google.colab import drive  # type: ignore

    drive.mount('/content/drive', force_remount=False)
    data_root = DRIVE_DATA_ROOT
    runs_root = DRIVE_RUNS_ROOT
    if not data_root.exists():
        raise FileNotFoundError(f'Google Drive data root not found: {data_root}')
else:
    repo_root = resolve_repo_root(Path.cwd())
    data_root = repo_root / 'Data'
    runs_root = repo_root / 'runs'
    if not data_root.exists():
        raise FileNotFoundError(f'Data root not found: {data_root}')

runs_root.mkdir(parents=True, exist_ok=True)
if cfg.num_workers is None:
    cfg.num_workers = auto_num_workers(in_colab)
if cfg.enable_resume:
    cfg.resume_checkpoint_path = resolve_resume_checkpoint_path(cfg.resume_checkpoint_path, runs_root, cfg.model_id)
else:
    cfg.resume_checkpoint_path = None

run_root = make_unique_run_root(runs_root, cfg.run_slug)
checkpoints_dir = run_root / 'checkpoints'
exports_dir = run_root / 'exports'
preview_dir = exports_dir / 'val_preview'
summary_path = run_root / 'summary.json'
metrics_csv_path = run_root / 'metrics.csv'

for directory in [run_root, checkpoints_dir, exports_dir, preview_dir]:
    directory.mkdir(parents=True, exist_ok=True)

set_global_seed(cfg.seed)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
if device.type == 'cuda':
    torch.backends.cudnn.benchmark = True
    if hasattr(torch.backends.cuda.matmul, 'allow_tf32'):
        torch.backends.cuda.matmul.allow_tf32 = True
    if hasattr(torch.backends.cudnn, 'allow_tf32'):
        torch.backends.cudnn.allow_tf32 = True
    if hasattr(torch, 'set_float32_matmul_precision'):
        torch.set_float32_matmul_precision('high')

print({
    'device': str(device),
    'data_root': str(data_root),
    'runs_root': str(runs_root),
    'run_root': str(run_root),
    'config': asdict(cfg),
})
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# {'device': 'cuda', 'data_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/Data', 'runs_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs', 'run_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/083803_2604_base', 'config': {'model_id': 'tinysrcnn_noadd_lrelu', 'run_slug': 'base', 'enable_resume': True, 'resume_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/161827_2504_base/checkpoints/last.pth', 'seed': 1337, 'train_patch_size': 256, 'eval_size': 256, 'batch_size': 16, 'epochs': 7500, 'lr': 0.0001, 'min_lr': 1e-06, 'weight_decay': 0.0001, 'warmup_epochs': 8, 'num_workers': 2, 'prefetch_factor': 2, 'use_amp': True, 'use_ema': True, 'ema_decay': 0.999}}

# %% [markdown]
# ## 2. Data

# %%
L3_TRAIN_SPLITS = (
    ('LR_HR/L3_HR_train1', 'L3_LR/L3_L3_train1', 'L3_HR_train1'),
    ('LR_HR/L3_HR_train2', 'L3_LR/L3_L3_train2', 'L3_HR_train2'),
    ('LR_HR/L3_HR_train3', 'L3_LR/L3_LR_train3', 'L3_HR_train3'),
    ('LR_HR/L3_HR_train4', 'L3_LR/L3_LR_train4', 'L3_HR_train4'),
    ('LR_HR/L3_HR_train', 'L3_LR/L3_LR_train', 'L3_HR_train'),
)
L3_VAL_DIRS = ('L3_HR_valid', 'L3_LR_valid')


def scan_image_directory(directory: Path) -> dict[str, Path]:
    if not directory.exists():
        raise FileNotFoundError(f'Missing directory: {directory}')
    return {
        path.stem: path
        for path in directory.iterdir()
        if path.is_file() and path.suffix.lower() in IMAGE_SUFFIXES
    }


def collect_split_pairs(hr_dir: Path, lr_dir: Path, split_name: str) -> list[tuple[Path, Path, str]]:
    hr_map = scan_image_directory(hr_dir)
    lr_map = scan_image_directory(lr_dir)
    pairs: list[tuple[Path, Path, str]] = []
    for stem in sorted(set(hr_map) & set(lr_map)):
        name = stem if split_name == 'val' else f'{split_name}/{stem}'
        pairs.append((lr_map[stem], hr_map[stem], name))
    return pairs


def collect_all_pairs(data_root: Path) -> tuple[list[tuple[Path, Path, str]], list[tuple[Path, Path, str]]]:
    train_pairs: list[tuple[Path, Path, str]] = []
    for hr_rel, lr_rel, split_name in L3_TRAIN_SPLITS:
        train_pairs.extend(collect_split_pairs(data_root / hr_rel, data_root / lr_rel, split_name))
    val_pairs = collect_split_pairs(data_root / L3_VAL_DIRS[0], data_root / L3_VAL_DIRS[1], 'val')
    return train_pairs, val_pairs


class PairedSRDataset(Dataset):
    def __init__(self, pairs: list[tuple[Path, Path, str]], *, train: bool, patch_size: int, eval_size: int, seed: int):
        self.pairs = pairs
        self.train = train
        self.patch_size = patch_size
        self.eval_size = eval_size
        self.seed = seed
        self.epoch = 0

    def set_epoch(self, epoch: int) -> None:
        self.epoch = epoch

    @staticmethod
    def to_tensor(img: Image.Image) -> torch.Tensor:
        arr = np.asarray(img, dtype=np.float32) / 255.0
        return torch.from_numpy(arr).permute(2, 0, 1).contiguous()

    def augment_pair(self, lr: Image.Image, hr: Image.Image, index: int) -> tuple[Image.Image, Image.Image]:
        rng = random.Random((self.seed * 1_000_003) + (self.epoch * 9_973) + index)
        width, height = lr.size
        patch = self.patch_size
        if width < patch or height < patch:
            lr = lr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            hr = hr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            width, height = lr.size
        left = rng.randint(0, width - patch)
        top = rng.randint(0, height - patch)
        box = (left, top, left + patch, top + patch)
        lr = lr.crop(box)
        hr = hr.crop(box)
        if rng.random() < 0.5:
            lr = lr.transpose(FLIP_LEFT_RIGHT)
            hr = hr.transpose(FLIP_LEFT_RIGHT)
        if rng.random() < 0.5:
            lr = lr.transpose(FLIP_TOP_BOTTOM)
            hr = hr.transpose(FLIP_TOP_BOTTOM)
        rot = rng.choice([0, 1, 2, 3])
        if rot:
            rotate_ops = [ROTATE_90, ROTATE_180, ROTATE_270]
            lr = lr.transpose(rotate_ops[rot - 1])
            hr = hr.transpose(rotate_ops[rot - 1])
        return lr, hr

    def __len__(self) -> int:
        return len(self.pairs)

    def __getitem__(self, index: int) -> dict[str, Any]:
        lr_path, hr_path, name = self.pairs[index]
        lr = Image.open(lr_path).convert('RGB')
        hr = Image.open(hr_path).convert('RGB')
        if self.train:
            lr, hr = self.augment_pair(lr, hr, index)
        elif lr.size != (self.eval_size, self.eval_size):
            lr = lr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            hr = hr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
        return {'lr': self.to_tensor(lr), 'hr': self.to_tensor(hr), 'name': name}


train_pairs, val_pairs = collect_all_pairs(data_root)
if not train_pairs:
    raise FileNotFoundError(f'No training pairs found under {data_root}')
if not val_pairs:
    raise FileNotFoundError(f'No validation pairs found under {data_root}')
print({
    'data_root': str(data_root),
    'train_pairs': len(train_pairs),
    'val_pairs': len(val_pairs),
})

train_ds = PairedSRDataset(train_pairs, train=True, patch_size=cfg.train_patch_size, eval_size=cfg.eval_size, seed=cfg.seed)
val_ds = PairedSRDataset(val_pairs, train=False, patch_size=cfg.train_patch_size, eval_size=cfg.eval_size, seed=cfg.seed)

loader_num_workers = cfg.num_workers if cfg.num_workers is not None else auto_num_workers(in_colab)
train_loader_kwargs = {
    'dataset': train_ds,
    'batch_size': cfg.batch_size,
    'shuffle': True,
    'num_workers': loader_num_workers,
    'pin_memory': device.type == 'cuda',
}
val_loader_kwargs = {
    'dataset': val_ds,
    'batch_size': 1,
    'shuffle': False,
    'num_workers': loader_num_workers,
    'pin_memory': device.type == 'cuda',
}
if loader_num_workers > 0:
    train_loader_kwargs['prefetch_factor'] = cfg.prefetch_factor
    val_loader_kwargs['prefetch_factor'] = cfg.prefetch_factor

train_loader = DataLoader(**train_loader_kwargs)
val_loader = DataLoader(**val_loader_kwargs)

sample_batch = next(iter(val_loader))
print({
    'validation_input_shape': tuple(sample_batch['lr'].shape),
    'validation_target_shape': tuple(sample_batch['hr'].shape),
    'sample_name': sample_batch['name'][0],
})
# Out:
# {'data_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/Data', 'train_pairs': 2217, 'val_pairs': 110}
# {'validation_input_shape': (1, 3, 256, 256), 'validation_target_shape': (1, 3, 256, 256), 'sample_name': '0000'}

# %% [markdown]
# ## 3. Model and Training

# %%
class TinySRCNNNoAdd(nn.Module):
    def __init__(self, channels: int = 64, slope: float = 0.1):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(3, channels, 3, padding=1),
            nn.LeakyReLU(slope, inplace=False),
            nn.Conv2d(channels, channels, 3, padding=1),
            nn.LeakyReLU(slope, inplace=False),
            nn.Conv2d(channels, channels, 3, padding=1),
            nn.LeakyReLU(slope, inplace=False),
            nn.Conv2d(channels, channels, 3, padding=1),
            nn.LeakyReLU(slope, inplace=False),
            nn.Conv2d(channels, 3, 3, padding=1),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.net(x)


def count_parameters(module: nn.Module) -> int:
    return int(sum(param.numel() for param in module.parameters()))


class EMA:
    def __init__(self, model: nn.Module, decay: float):
        self.decay = decay
        self.shadow = {k: v.detach().clone() for k, v in model.state_dict().items()}

    @torch.no_grad()
    def update(self, model: nn.Module) -> None:
        for key, value in model.state_dict().items():
            self.shadow[key].mul_(self.decay).add_(value.detach(), alpha=1.0 - self.decay)

    @torch.no_grad()
    def copy_to(self, model: nn.Module) -> None:
        model.load_state_dict(self.shadow, strict=True)


def make_grad_scaler(enabled: bool):
    if hasattr(torch, 'amp') and hasattr(torch.amp, 'GradScaler'):
        return torch.amp.GradScaler('cuda', enabled=enabled)
    return torch.cuda.amp.GradScaler(enabled=enabled)


def autocast_context(device_type: str, enabled: bool):
    if not enabled:
        return nullcontext()
    if hasattr(torch, 'amp') and hasattr(torch.amp, 'autocast'):
        return torch.amp.autocast(device_type=device_type, enabled=enabled)
    return torch.cuda.amp.autocast(enabled=enabled)


@torch.no_grad()
def batch_psnr(pred: torch.Tensor, target: torch.Tensor) -> float:
    mse = F.mse_loss(pred, target, reduction='none').mean(dim=(1, 2, 3))
    psnr = 10.0 * torch.log10(1.0 / torch.clamp(mse, min=1e-12))
    return float(psnr.mean().item())


def compute_loss(pred: torch.Tensor, hr: torch.Tensor) -> torch.Tensor:
    loss_mse = F.mse_loss(pred, hr)
    loss_l1 = F.l1_loss(pred, hr)
    return 0.8 * loss_mse + 0.2 * loss_l1


def lr_at_epoch(epoch_idx: int, *, base_lr: float, min_lr: float, warmup_epochs: int, total_epochs: int) -> float:
    step = epoch_idx + 1
    if warmup_epochs > 0 and step <= warmup_epochs:
        return base_lr * step / max(1, warmup_epochs)
    progress = max(0.0, (step - warmup_epochs) / max(1, total_epochs - warmup_epochs))
    cosine = 0.5 * (1.0 + math.cos(math.pi * min(progress, 1.0)))
    return min_lr + cosine * (base_lr - min_lr)


@torch.inference_mode()
def evaluate_psnr(model: nn.Module, loader: DataLoader, device: torch.device) -> float:
    model.eval()
    meter = 0.0
    count = 0
    for batch in loader:
        lr = batch['lr'].to(device, non_blocking=(device.type == 'cuda'))
        hr = batch['hr'].to(device, non_blocking=(device.type == 'cuda'))
        pred = model(lr).clamp(0.0, 1.0)
        meter += batch_psnr(pred, hr)
        count += 1
    return meter / max(count, 1)


@torch.inference_mode()
def compute_input_psnr(loader: DataLoader, device: torch.device) -> float:
    meter = 0.0
    count = 0
    for batch in loader:
        lr = batch['lr'].to(device, non_blocking=(device.type == 'cuda'))
        hr = batch['hr'].to(device, non_blocking=(device.type == 'cuda'))
        meter += batch_psnr(lr, hr)
        count += 1
    return meter / max(count, 1)


def tensor_to_uint8_image(x: torch.Tensor) -> Image.Image:
    x = x.detach().cpu().clamp(0.0, 1.0)
    arr = (x.permute(1, 2, 0).numpy() * 255.0).round().astype(np.uint8)
    return Image.fromarray(arr)


@torch.no_grad()
def write_val_preview(model: nn.Module, loader: DataLoader, out_dir: Path, device: torch.device) -> dict[str, str]:
    out_dir.mkdir(parents=True, exist_ok=True)
    batch = next(iter(loader))
    lr = batch['lr'].to(device, non_blocking=(device.type == 'cuda'))
    hr = batch['hr'].to(device, non_blocking=(device.type == 'cuda'))
    pred = model(lr).clamp(0.0, 1.0)
    name = batch['name'][0]
    lr_path = out_dir / 'val_preview_input.png'
    pred_path = out_dir / 'val_preview_pred.png'
    hr_path = out_dir / 'val_preview_target.png'
    tensor_to_uint8_image(lr[0]).save(lr_path)
    tensor_to_uint8_image(pred[0]).save(pred_path)
    tensor_to_uint8_image(hr[0]).save(hr_path)
    return {
        'sample_name': str(name),
        'input': str(lr_path),
        'prediction': str(pred_path),
        'target': str(hr_path),
    }


def checkpoint_payload(model: nn.Module, ema: EMA | None, optimizer: torch.optim.Optimizer, epoch: int, best_val_psnr: float, row: dict[str, Any]) -> dict[str, Any]:
    return {
        'config': asdict(cfg),
        'epoch': int(epoch),
        'model_state_dict': model.state_dict(),
        'ema_state_dict': ema.shadow if ema is not None else None,
        'optimizer_state_dict': optimizer.state_dict(),
        'best_val_psnr': float(best_val_psnr),
        'selected_weight_source': 'ema' if ema is not None else 'raw',
        'last_metrics': row,
    }


def build_eval_model_from_checkpoint(checkpoint_path: Path, device: torch.device) -> nn.Module:
    checkpoint = torch.load(checkpoint_path, map_location=device)
    model = TinySRCNNNoAdd().to(device)
    selected = checkpoint.get('selected_weight_source', 'raw')
    ema_state = checkpoint.get('ema_state_dict')
    if selected == 'ema' and ema_state is not None:
        model.load_state_dict(ema_state, strict=True)
    else:
        model.load_state_dict(checkpoint['model_state_dict'], strict=True)
    model.eval()
    return model


model = TinySRCNNNoAdd().to(device)
eval_model = TinySRCNNNoAdd().to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)
scaler = make_grad_scaler(enabled=(cfg.use_amp and device.type == 'cuda'))
ema = EMA(model, decay=cfg.ema_decay) if cfg.use_ema else None
start_epoch = 0
best_val_psnr = float('-inf')
if cfg.enable_resume and cfg.resume_checkpoint_path:
    checkpoint = torch.load(cfg.resume_checkpoint_path, map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'], strict=True)
    optimizer_state = checkpoint.get('optimizer_state_dict')
    if optimizer_state is not None:
        optimizer.load_state_dict(optimizer_state)
    ema_state = checkpoint.get('ema_state_dict')
    if ema is not None and ema_state is not None:
        ema.shadow = {key: value.detach().clone() for key, value in ema_state.items()}
    start_epoch = int(checkpoint.get('epoch', 0))
    best_val_psnr = float(checkpoint.get('best_val_psnr', float('-inf')))
if ema is not None:
    ema.copy_to(eval_model)
else:
    eval_model.load_state_dict(model.state_dict())

model_parameter_count = count_parameters(model)
print({
    'model_id': cfg.model_id,
    'architecture': 'Conv3x3(3->64) x4 with LeakyReLU, final Conv3x3(64->3), no Add',
    'params': model_parameter_count,
    'resume_checkpoint_path': cfg.resume_checkpoint_path,
    'start_epoch': start_epoch,
})

input_psnr = compute_input_psnr(val_loader, device)
print({'baseline_input_psnr': input_psnr})
# Out:
# {'model_id': 'tinysrcnn_noadd_lrelu', 'architecture': 'Conv3x3(3->64) x4 with LeakyReLU, final Conv3x3(64->3), no Add', 'params': 114307, 'resume_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/161827_2504_base/checkpoints/last.pth', 'start_epoch': 4489}
# {'baseline_input_psnr': 23.133060299266468}

# %%
metrics_header = [
    'epoch',
    'epoch_time_sec',
    'lr',
    'train_loss',
    'train_psnr',
    'val_psnr',
    'best_val_psnr',
]

best_ckpt_path = checkpoints_dir / 'best.pth'
last_ckpt_path = checkpoints_dir / 'last.pth'

with metrics_csv_path.open('w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=metrics_header)
    writer.writeheader()

for epoch in range(start_epoch, cfg.epochs):
    train_ds.set_epoch(epoch)
    epoch_lr = lr_at_epoch(
        epoch,
        base_lr=cfg.lr,
        min_lr=cfg.min_lr,
        warmup_epochs=cfg.warmup_epochs,
        total_epochs=cfg.epochs,
    )
    for group in optimizer.param_groups:
        group['lr'] = epoch_lr

    epoch_start = time.time()
    model.train()
    train_loss_sum = 0.0
    train_psnr_sum = 0.0
    train_batches = 0

    for batch in train_loader:
        lr = batch['lr'].to(device, non_blocking=(device.type == 'cuda'))
        hr = batch['hr'].to(device, non_blocking=(device.type == 'cuda'))

        optimizer.zero_grad(set_to_none=True)
        with autocast_context(device.type, enabled=(cfg.use_amp and device.type == 'cuda')):
            pred = model(lr)
            loss = compute_loss(pred, hr)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        if ema is not None:
            ema.update(model)

        train_loss_sum += float(loss.item())
        train_psnr_sum += batch_psnr(pred.detach().clamp(0.0, 1.0), hr)
        train_batches += 1

    if ema is not None:
        ema.copy_to(eval_model)
    else:
        eval_model.load_state_dict(model.state_dict())
    eval_model.eval()

    avg_train_loss = train_loss_sum / max(train_batches, 1)
    avg_train_psnr = train_psnr_sum / max(train_batches, 1)
    val_psnr = evaluate_psnr(eval_model, val_loader, device)
    epoch_time = time.time() - epoch_start
    is_best = val_psnr > best_val_psnr
    if is_best:
        best_val_psnr = val_psnr

    row = {
        'epoch': epoch + 1,
        'epoch_time_sec': round(epoch_time, 2),
        'lr': epoch_lr,
        'train_loss': round(avg_train_loss, 6),
        'train_psnr': round(avg_train_psnr, 4),
        'val_psnr': round(val_psnr, 4),
        'best_val_psnr': round(best_val_psnr, 4),
    }
    print(row)

    with metrics_csv_path.open('a', newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=metrics_header)
        writer.writerow(row)

    payload = checkpoint_payload(model, ema, optimizer, epoch + 1, best_val_psnr, row)
    torch.save(payload, last_ckpt_path)
    if is_best:
        torch.save(payload, best_ckpt_path)
# Out:
# {'epoch': 4490, 'epoch_time_sec': 55.79, 'lr': 3.5464469655361894e-05, 'train_loss': 0.011859, 'train_psnr': 24.9919, 'val_psnr': 23.866, 'best_val_psnr': 23.8662}
# {'epoch': 4491, 'epoch_time_sec': 33.34, 'lr': 3.5444695028268054e-05, 'train_loss': 0.011829, 'train_psnr': 25.0064, 'val_psnr': 23.8659, 'best_val_psnr': 23.8662}
# {'epoch': 4492, 'epoch_time_sec': 34.01, 'lr': 3.542492304841694e-05, 'train_loss': 0.011842, 'train_psnr': 24.9994, 'val_psnr': 23.8658, 'best_val_psnr': 23.8662}
# {'epoch': 4493, 'epoch_time_sec': 33.56, 'lr': 3.5405153719285094e-05, 'train_loss': 0.011839, 'train_psnr': 25.0023, 'val_psnr': 23.8658, 'best_val_psnr': 23.8662}
# {'epoch': 4494, 'epoch_time_sec': 34.06, 'lr': 3.538538704434868e-05, 'train_loss': 0.011829, 'train_psnr': 25.0061, 'val_psnr': 23.8658, 'best_val_psnr': 23.8662}
# {'epoch': 4495, 'epoch_time_sec': 33.54, 'lr': 3.536562302708337e-05, 'train_loss': 0.01184, 'train_psnr': 25.0012, 'val_psnr': 23.8658, 'best_val_psnr': 23.8662}
# {'epoch': 4496, 'epoch_time_sec': 34.04, 'lr': 3.534586167096433e-05, 'train_loss': 0.011833, 'train_psnr': 25.0041, 'val_psnr': 23.8658, 'best_val_psnr': 23.8662}
# {'epoch': 4497, 'epoch_time_sec': 33.55, 'lr': 3.5326102979466304e-05, 'train_loss': 0.011823, 'train_psnr': 25.0088, 'val_psnr': 23.8658, 'best_val_psnr': 23.8662}
# {'epoch': 4498, 'epoch_time_sec': 34.08, 'lr': 3.530634695606356e-05, 'train_loss': 0.011839, 'train_psnr': 25.002, 'val_psnr': 23.8656, 'best_val_psnr': 23.8662}
# {'epoch': 4499, 'epoch_time_sec': 33.59, 'lr': 3.528659360422989e-05, 'train_loss': 0.01184, 'train_psnr': 25.002, 'val_psnr': 23.8657, 'best_val_psnr': 23.8662}
# {'epoch': 4500, 'epoch_time_sec': 33.98, 'lr': 3.526684292743861e-05, 'train_loss': 0.011843, 'train_psnr': 24.9995, 'val_psnr': 23.8656, 'best_val_psnr': 23.8662}
# {'epoch': 4501, 'epoch_time_sec': 33.49, 'lr': 3.5247094929162556e-05, 'train_loss': 0.011835, 'train_psnr': 25.003, 'val_psnr': 23.8656, 'best_val_psnr': 23.8662}
# {'epoch': 4502, 'epoch_time_sec': 33.97, 'lr': 3.522734961287414e-05, 'train_loss': 0.011823, 'train_psnr': 25.0106, 'val_psnr': 23.8656, 'best_val_psnr': 23.8662}
# {'epoch': 4503, 'epoch_time_sec': 33.64, 'lr': 3.520760698204524e-05, 'train_loss': 0.011829, 'train_psnr': 25.0072, 'val_psnr': 23.8656, 'best_val_psnr': 23.8662}
# {'epoch': 4504, 'epoch_time_sec': 34.17, 'lr': 3.5187867040147314e-05, 'train_loss': 0.011833, 'train_psnr': 25.0053, 'val_psnr': 23.8656, 'best_val_psnr': 23.8662}
# {'epoch': 4505, 'epoch_time_sec': 33.61, 'lr': 3.5168129790651336e-05, 'train_loss': 0.011843, 'train_psnr': 25.0015, 'val_psnr': 23.8655, 'best_val_psnr': 23.8662}
# {'epoch': 4506, 'epoch_time_sec': 33.28, 'lr': 3.514839523702775e-05, 'train_loss': 0.011827, 'train_psnr': 25.0078, 'val_psnr': 23.8655, 'best_val_psnr': 23.8662}
# {'epoch': 4507, 'epoch_time_sec': 34.13, 'lr': 3.51286633827466e-05, 'train_loss': 0.011822, 'train_psnr': 25.0083, 'val_psnr': 23.8655, 'best_val_psnr': 23.8662}
# {'epoch': 4508, 'epoch_time_sec': 33.03, 'lr': 3.510893423127743e-05, 'train_loss': 0.01184, 'train_psnr': 25.0017, 'val_psnr': 23.8656, 'best_val_psnr': 23.8662}
# {'epoch': 4509, 'epoch_time_sec': 34.09, 'lr': 3.508920778608932e-05, 'train_loss': 0.011822, 'train_psnr': 25.011, 'val_psnr': 23.8654, 'best_val_psnr': 23.8662}
# {'epoch': 4510, 'epoch_time_sec': 33.08, 'lr': 3.506948405065084e-05, 'train_loss': 0.011826, 'train_psnr': 25.0088, 'val_psnr': 23.8654, 'best_val_psnr': 23.8662}
# {'epoch': 4511, 'epoch_time_sec': 34.03, 'lr': 3.5049763028430095e-05, 'train_loss': 0.011847, 'train_psnr': 24.9999, 'val_psnr': 23.8653, 'best_val_psnr': 23.8662}
# {'epoch': 4512, 'epoch_time_sec': 33.43, 'lr': 3.5030044722894755e-05, 'train_loss': 0.01184, 'train_psnr': 25.0014, 'val_psnr': 23.8653, 'best_val_psnr': 23.8662}
# {'epoch': 4513, 'epoch_time_sec': 34.11, 'lr': 3.501032913751194e-05, 'train_loss': 0.011829, 'train_psnr': 25.0069, 'val_psnr': 23.8653, 'best_val_psnr': 23.8662}
# {'epoch': 4514, 'epoch_time_sec': 33.56, 'lr': 3.4990616275748365e-05, 'train_loss': 0.011827, 'train_psnr': 25.0066, 'val_psnr': 23.8654, 'best_val_psnr': 23.8662}
# {'epoch': 4515, 'epoch_time_sec': 34.13, 'lr': 3.497090614107021e-05, 'train_loss': 0.011823, 'train_psnr': 25.0091, 'val_psnr': 23.8654, 'best_val_psnr': 23.8662}
# {'epoch': 4516, 'epoch_time_sec': 34.17, 'lr': 3.495119873694323e-05, 'train_loss': 0.01184, 'train_psnr': 25.0033, 'val_psnr': 23.8655, 'best_val_psnr': 23.8662}
# {'epoch': 4517, 'epoch_time_sec': 42.49, 'lr': 3.493149406683261e-05, 'train_loss': 0.011829, 'train_psnr': 25.0065, 'val_psnr': 23.8654, 'best_val_psnr': 23.8662}
# {'epoch': 4518, 'epoch_time_sec': 45.13, 'lr': 3.4911792134203146e-05, 'train_loss': 0.011829, 'train_psnr': 25.007, 'val_psnr': 23.8655, 'best_val_psnr': 23.8662}
# {'epoch': 4519, 'epoch_time_sec': 41.75, 'lr': 3.489209294251915e-05, 'train_loss': 0.01183, 'train_psnr': 25.0065, 'val_psnr': 23.8656, 'best_val_psnr': 23.8662}
# {'epoch': 4520, 'epoch_time_sec': 45.07, 'lr': 3.487239649524437e-05, 'train_loss': 0.011828, 'train_psnr': 25.0064, 'val_psnr': 23.8657, 'best_val_psnr': 23.8662}
# {'epoch': 4521, 'epoch_time_sec': 45.08, 'lr': 3.485270279584213e-05, 'train_loss': 0.011822, 'train_psnr': 25.0107, 'val_psnr': 23.8657, 'best_val_psnr': 23.8662}
# {'epoch': 4522, 'epoch_time_sec': 44.94, 'lr': 3.4833011847775294e-05, 'train_loss': 0.011837, 'train_psnr': 25.0015, 'val_psnr': 23.8657, 'best_val_psnr': 23.8662}
# {'epoch': 4523, 'epoch_time_sec': 45.07, 'lr': 3.481332365450617e-05, 'train_loss': 0.011832, 'train_psnr': 25.0035, 'val_psnr': 23.8657, 'best_val_psnr': 23.8662}
# {'epoch': 4524, 'epoch_time_sec': 45.01, 'lr': 3.4793638219496644e-05, 'train_loss': 0.011837, 'train_psnr': 25.0023, 'val_psnr': 23.8658, 'best_val_psnr': 23.8662}
# {'epoch': 4525, 'epoch_time_sec': 45.42, 'lr': 3.477395554620809e-05, 'train_loss': 0.011834, 'train_psnr': 25.0041, 'val_psnr': 23.8658, 'best_val_psnr': 23.8662}
# {'epoch': 4526, 'epoch_time_sec': 44.59, 'lr': 3.475427563810142e-05, 'train_loss': 0.011829, 'train_psnr': 25.0062, 'val_psnr': 23.8659, 'best_val_psnr': 23.8662}
# {'epoch': 4527, 'epoch_time_sec': 45.22, 'lr': 3.4734598498637006e-05, 'train_loss': 0.011831, 'train_psnr': 25.005, 'val_psnr': 23.8658, 'best_val_psnr': 23.8662}
# {'epoch': 4528, 'epoch_time_sec': 45.03, 'lr': 3.4714924131274793e-05, 'train_loss': 0.011825, 'train_psnr': 25.008, 'val_psnr': 23.8658, 'best_val_psnr': 23.8662}
# {'epoch': 4529, 'epoch_time_sec': 45.07, 'lr': 3.4695252539474236e-05, 'train_loss': 0.011854, 'train_psnr': 24.9967, 'val_psnr': 23.8658, 'best_val_psnr': 23.8662}
# {'epoch': 4530, 'epoch_time_sec': 45.06, 'lr': 3.467558372669424e-05, 'train_loss': 0.011836, 'train_psnr': 25.0042, 'val_psnr': 23.8659, 'best_val_psnr': 23.8662}
# {'epoch': 4531, 'epoch_time_sec': 45.04, 'lr': 3.465591769639327e-05, 'train_loss': 0.011849, 'train_psnr': 25.0014, 'val_psnr': 23.8659, 'best_val_psnr': 23.8662}
# {'epoch': 4532, 'epoch_time_sec': 45.16, 'lr': 3.463625445202931e-05, 'train_loss': 0.011824, 'train_psnr': 25.0106, 'val_psnr': 23.8658, 'best_val_psnr': 23.8662}
# {'epoch': 4533, 'epoch_time_sec': 44.98, 'lr': 3.461659399705982e-05, 'train_loss': 0.011837, 'train_psnr': 25.0043, 'val_psnr': 23.8659, 'best_val_psnr': 23.8662}
# {'epoch': 4534, 'epoch_time_sec': 45.02, 'lr': 3.45969363349418e-05, 'train_loss': 0.011845, 'train_psnr': 25.0006, 'val_psnr': 23.8659, 'best_val_psnr': 23.8662}
# {'epoch': 4535, 'epoch_time_sec': 45.01, 'lr': 3.457728146913174e-05, 'train_loss': 0.011856, 'train_psnr': 24.9972, 'val_psnr': 23.8658, 'best_val_psnr': 23.8662}
# {'epoch': 4536, 'epoch_time_sec': 45.31, 'lr': 3.4557629403085655e-05, 'train_loss': 0.011838, 'train_psnr': 25.003, 'val_psnr': 23.8657, 'best_val_psnr': 23.8662}
# {'epoch': 4537, 'epoch_time_sec': 44.63, 'lr': 3.453798014025903e-05, 'train_loss': 0.011827, 'train_psnr': 25.007, 'val_psnr': 23.8657, 'best_val_psnr': 23.8662}
# {'epoch': 4538, 'epoch_time_sec': 45.58, 'lr': 3.451833368410691e-05, 'train_loss': 0.011827, 'train_psnr': 25.0064, 'val_psnr': 23.8657, 'best_val_psnr': 23.8662}
# {'epoch': 4539, 'epoch_time_sec': 44.59, 'lr': 3.449869003808382e-05, 'train_loss': 0.011836, 'train_psnr': 25.0041, 'val_psnr': 23.8657, 'best_val_psnr': 23.8662}
# {'epoch': 4540, 'epoch_time_sec': 45.42, 'lr': 3.447904920564378e-05, 'train_loss': 0.011828, 'train_psnr': 25.0083, 'val_psnr': 23.8657, 'best_val_psnr': 23.8662}
# {'epoch': 4541, 'epoch_time_sec': 44.64, 'lr': 3.445941119024033e-05, 'train_loss': 0.011837, 'train_psnr': 25.0023, 'val_psnr': 23.8657, 'best_val_psnr': 23.8662}
# {'epoch': 4542, 'epoch_time_sec': 45.58, 'lr': 3.44397759953265e-05, 'train_loss': 0.011834, 'train_psnr': 25.0031, 'val_psnr': 23.8657, 'best_val_psnr': 23.8662}
# {'epoch': 4543, 'epoch_time_sec': 44.42, 'lr': 3.4420143624354874e-05, 'train_loss': 0.011827, 'train_psnr': 25.0081, 'val_psnr': 23.8658, 'best_val_psnr': 23.8662}
# {'epoch': 4544, 'epoch_time_sec': 45.51, 'lr': 3.440051408077746e-05, 'train_loss': 0.011825, 'train_psnr': 25.0073, 'val_psnr': 23.8658, 'best_val_psnr': 23.8662}
# {'epoch': 4545, 'epoch_time_sec': 44.67, 'lr': 3.438088736804582e-05, 'train_loss': 0.011834, 'train_psnr': 25.0064, 'val_psnr': 23.8659, 'best_val_psnr': 23.8662}
# {'epoch': 4546, 'epoch_time_sec': 45.55, 'lr': 3.4361263489611035e-05, 'train_loss': 0.011828, 'train_psnr': 25.0066, 'val_psnr': 23.8659, 'best_val_psnr': 23.8662}
# {'epoch': 4547, 'epoch_time_sec': 44.59, 'lr': 3.434164244892362e-05, 'train_loss': 0.011828, 'train_psnr': 25.0063, 'val_psnr': 23.866, 'best_val_psnr': 23.8662}
# {'epoch': 4548, 'epoch_time_sec': 45.19, 'lr': 3.4322024249433646e-05, 'train_loss': 0.011835, 'train_psnr': 25.0056, 'val_psnr': 23.866, 'best_val_psnr': 23.8662}
# {'epoch': 4549, 'epoch_time_sec': 45.04, 'lr': 3.43024088945907e-05, 'train_loss': 0.011836, 'train_psnr': 25.0008, 'val_psnr': 23.866, 'best_val_psnr': 23.8662}
# {'epoch': 4550, 'epoch_time_sec': 44.92, 'lr': 3.4282796387843795e-05, 'train_loss': 0.011845, 'train_psnr': 24.999, 'val_psnr': 23.8661, 'best_val_psnr': 23.8662}
# {'epoch': 4551, 'epoch_time_sec': 44.92, 'lr': 3.42631867326415e-05, 'train_loss': 0.011838, 'train_psnr': 25.0008, 'val_psnr': 23.8661, 'best_val_psnr': 23.8662}
# {'epoch': 4552, 'epoch_time_sec': 44.79, 'lr': 3.424357993243188e-05, 'train_loss': 0.011824, 'train_psnr': 25.0089, 'val_psnr': 23.8661, 'best_val_psnr': 23.8662}
# {'epoch': 4553, 'epoch_time_sec': 45.23, 'lr': 3.42239759906625e-05, 'train_loss': 0.011823, 'train_psnr': 25.0083, 'val_psnr': 23.8662, 'best_val_psnr': 23.8662}
# {'epoch': 4554, 'epoch_time_sec': 44.69, 'lr': 3.420437491078037e-05, 'train_loss': 0.01183, 'train_psnr': 25.0073, 'val_psnr': 23.8664, 'best_val_psnr': 23.8664}
# {'epoch': 4555, 'epoch_time_sec': 45.45, 'lr': 3.418477669623208e-05, 'train_loss': 0.01183, 'train_psnr': 25.0069, 'val_psnr': 23.8663, 'best_val_psnr': 23.8664}
# {'epoch': 4556, 'epoch_time_sec': 44.58, 'lr': 3.416518135046366e-05, 'train_loss': 0.011817, 'train_psnr': 25.0131, 'val_psnr': 23.8662, 'best_val_psnr': 23.8664}
# {'epoch': 4557, 'epoch_time_sec': 45.57, 'lr': 3.414558887692062e-05, 'train_loss': 0.011821, 'train_psnr': 25.0112, 'val_psnr': 23.8662, 'best_val_psnr': 23.8664}
# {'epoch': 4558, 'epoch_time_sec': 44.7, 'lr': 3.412599927904802e-05, 'train_loss': 0.011836, 'train_psnr': 25.0027, 'val_psnr': 23.8661, 'best_val_psnr': 23.8664}
# {'epoch': 4559, 'epoch_time_sec': 45.51, 'lr': 3.41064125602904e-05, 'train_loss': 0.011836, 'train_psnr': 25.0047, 'val_psnr': 23.8662, 'best_val_psnr': 23.8664}
# {'epoch': 4560, 'epoch_time_sec': 44.86, 'lr': 3.4086828724091756e-05, 'train_loss': 0.011835, 'train_psnr': 25.0042, 'val_psnr': 23.8662, 'best_val_psnr': 23.8664}
# {'epoch': 4561, 'epoch_time_sec': 44.97, 'lr': 3.4067247773895616e-05, 'train_loss': 0.011826, 'train_psnr': 25.0085, 'val_psnr': 23.8662, 'best_val_psnr': 23.8664}
# {'epoch': 4562, 'epoch_time_sec': 45.11, 'lr': 3.404766971314497e-05, 'train_loss': 0.011839, 'train_psnr': 25.0024, 'val_psnr': 23.8663, 'best_val_psnr': 23.8664}
# {'epoch': 4563, 'epoch_time_sec': 45.14, 'lr': 3.4028094545282356e-05, 'train_loss': 0.011824, 'train_psnr': 25.0093, 'val_psnr': 23.8663, 'best_val_psnr': 23.8664}
# {'epoch': 4564, 'epoch_time_sec': 45.08, 'lr': 3.4008522273749724e-05, 'train_loss': 0.011834, 'train_psnr': 25.0027, 'val_psnr': 23.8663, 'best_val_psnr': 23.8664}
# {'epoch': 4565, 'epoch_time_sec': 45.05, 'lr': 3.398895290198857e-05, 'train_loss': 0.011819, 'train_psnr': 25.0114, 'val_psnr': 23.8663, 'best_val_psnr': 23.8664}
# {'epoch': 4566, 'epoch_time_sec': 44.9, 'lr': 3.3969386433439894e-05, 'train_loss': 0.011826, 'train_psnr': 25.006, 'val_psnr': 23.8662, 'best_val_psnr': 23.8664}
# {'epoch': 4567, 'epoch_time_sec': 44.98, 'lr': 3.39498228715441e-05, 'train_loss': 0.011828, 'train_psnr': 25.0067, 'val_psnr': 23.8663, 'best_val_psnr': 23.8664}
# {'epoch': 4568, 'epoch_time_sec': 44.91, 'lr': 3.393026221974117e-05, 'train_loss': 0.011836, 'train_psnr': 25.0041, 'val_psnr': 23.8664, 'best_val_psnr': 23.8664}
# {'epoch': 4569, 'epoch_time_sec': 45.09, 'lr': 3.3910704481470554e-05, 'train_loss': 0.01182, 'train_psnr': 25.0117, 'val_psnr': 23.8663, 'best_val_psnr': 23.8664}
# {'epoch': 4570, 'epoch_time_sec': 45.03, 'lr': 3.3891149660171176e-05, 'train_loss': 0.011825, 'train_psnr': 25.0086, 'val_psnr': 23.8662, 'best_val_psnr': 23.8664}
# {'epoch': 4571, 'epoch_time_sec': 45.09, 'lr': 3.387159775928141e-05, 'train_loss': 0.011829, 'train_psnr': 25.0053, 'val_psnr': 23.8664, 'best_val_psnr': 23.8664}
# {'epoch': 4572, 'epoch_time_sec': 44.62, 'lr': 3.3852048782239194e-05, 'train_loss': 0.011825, 'train_psnr': 25.0081, 'val_psnr': 23.8664, 'best_val_psnr': 23.8664}
# {'epoch': 4573, 'epoch_time_sec': 45.56, 'lr': 3.383250273248192e-05, 'train_loss': 0.011834, 'train_psnr': 25.0045, 'val_psnr': 23.8665, 'best_val_psnr': 23.8665}
# {'epoch': 4574, 'epoch_time_sec': 44.63, 'lr': 3.381295961344642e-05, 'train_loss': 0.011825, 'train_psnr': 25.008, 'val_psnr': 23.8664, 'best_val_psnr': 23.8665}
# {'epoch': 4575, 'epoch_time_sec': 45.57, 'lr': 3.3793419428569085e-05, 'train_loss': 0.011839, 'train_psnr': 25.0049, 'val_psnr': 23.8664, 'best_val_psnr': 23.8665}
# {'epoch': 4576, 'epoch_time_sec': 44.55, 'lr': 3.377388218128575e-05, 'train_loss': 0.011825, 'train_psnr': 25.0095, 'val_psnr': 23.8665, 'best_val_psnr': 23.8665}
# {'epoch': 4577, 'epoch_time_sec': 45.57, 'lr': 3.375434787503171e-05, 'train_loss': 0.011825, 'train_psnr': 25.0076, 'val_psnr': 23.8665, 'best_val_psnr': 23.8665}
# {'epoch': 4578, 'epoch_time_sec': 44.7, 'lr': 3.3734816513241784e-05, 'train_loss': 0.011821, 'train_psnr': 25.0114, 'val_psnr': 23.8664, 'best_val_psnr': 23.8665}
# {'epoch': 4579, 'epoch_time_sec': 45.37, 'lr': 3.3715288099350276e-05, 'train_loss': 0.011831, 'train_psnr': 25.0057, 'val_psnr': 23.8664, 'best_val_psnr': 23.8665}
# {'epoch': 4580, 'epoch_time_sec': 45.1, 'lr': 3.369576263679096e-05, 'train_loss': 0.011821, 'train_psnr': 25.0097, 'val_psnr': 23.8665, 'best_val_psnr': 23.8665}
# {'epoch': 4581, 'epoch_time_sec': 45.03, 'lr': 3.367624012899705e-05, 'train_loss': 0.011827, 'train_psnr': 25.0082, 'val_psnr': 23.8665, 'best_val_psnr': 23.8665}
# {'epoch': 4582, 'epoch_time_sec': 45.1, 'lr': 3.36567205794013e-05, 'train_loss': 0.011839, 'train_psnr': 25.003, 'val_psnr': 23.8665, 'best_val_psnr': 23.8665}
# {'epoch': 4583, 'epoch_time_sec': 44.8, 'lr': 3.363720399143594e-05, 'train_loss': 0.011827, 'train_psnr': 25.0082, 'val_psnr': 23.8665, 'best_val_psnr': 23.8665}
# {'epoch': 4584, 'epoch_time_sec': 45.58, 'lr': 3.3617690368532625e-05, 'train_loss': 0.011818, 'train_psnr': 25.012, 'val_psnr': 23.8665, 'best_val_psnr': 23.8665}
# {'epoch': 4585, 'epoch_time_sec': 44.58, 'lr': 3.359817971412255e-05, 'train_loss': 0.011824, 'train_psnr': 25.0092, 'val_psnr': 23.8665, 'best_val_psnr': 23.8665}
# {'epoch': 4586, 'epoch_time_sec': 45.41, 'lr': 3.357867203163636e-05, 'train_loss': 0.011827, 'train_psnr': 25.0076, 'val_psnr': 23.8665, 'best_val_psnr': 23.8665}
# {'epoch': 4587, 'epoch_time_sec': 44.57, 'lr': 3.3559167324504155e-05, 'train_loss': 0.011822, 'train_psnr': 25.0107, 'val_psnr': 23.8665, 'best_val_psnr': 23.8665}
# {'epoch': 4588, 'epoch_time_sec': 45.46, 'lr': 3.3539665596155555e-05, 'train_loss': 0.011821, 'train_psnr': 25.0106, 'val_psnr': 23.8665, 'best_val_psnr': 23.8665}
# {'epoch': 4589, 'epoch_time_sec': 44.69, 'lr': 3.352016685001964e-05, 'train_loss': 0.011844, 'train_psnr': 24.9998, 'val_psnr': 23.8665, 'best_val_psnr': 23.8665}
# {'epoch': 4590, 'epoch_time_sec': 45.56, 'lr': 3.350067108952496e-05, 'train_loss': 0.011819, 'train_psnr': 25.0122, 'val_psnr': 23.8665, 'best_val_psnr': 23.8665}
# {'epoch': 4591, 'epoch_time_sec': 44.55, 'lr': 3.348117831809954e-05, 'train_loss': 0.011826, 'train_psnr': 25.0074, 'val_psnr': 23.8666, 'best_val_psnr': 23.8666}
# {'epoch': 4592, 'epoch_time_sec': 45.51, 'lr': 3.346168853917088e-05, 'train_loss': 0.011834, 'train_psnr': 25.0055, 'val_psnr': 23.8666, 'best_val_psnr': 23.8666}
# {'epoch': 4593, 'epoch_time_sec': 44.7, 'lr': 3.3442201756165976e-05, 'train_loss': 0.011842, 'train_psnr': 25.0028, 'val_psnr': 23.8665, 'best_val_psnr': 23.8666}
# {'epoch': 4594, 'epoch_time_sec': 45.5, 'lr': 3.3422717972511243e-05, 'train_loss': 0.011837, 'train_psnr': 25.0017, 'val_psnr': 23.8666, 'best_val_psnr': 23.8666}
# {'epoch': 4595, 'epoch_time_sec': 44.76, 'lr': 3.340323719163263e-05, 'train_loss': 0.011833, 'train_psnr': 25.0056, 'val_psnr': 23.8667, 'best_val_psnr': 23.8667}
# {'epoch': 4596, 'epoch_time_sec': 45.08, 'lr': 3.3383759416955524e-05, 'train_loss': 0.011838, 'train_psnr': 25.003, 'val_psnr': 23.8667, 'best_val_psnr': 23.8667}
# {'epoch': 4597, 'epoch_time_sec': 44.92, 'lr': 3.3364284651904804e-05, 'train_loss': 0.011827, 'train_psnr': 25.0075, 'val_psnr': 23.8667, 'best_val_psnr': 23.8667}
# {'epoch': 4598, 'epoch_time_sec': 45.01, 'lr': 3.334481289990477e-05, 'train_loss': 0.011832, 'train_psnr': 25.0036, 'val_psnr': 23.8667, 'best_val_psnr': 23.8667}
# {'epoch': 4599, 'epoch_time_sec': 45.1, 'lr': 3.3325344164379264e-05, 'train_loss': 0.011835, 'train_psnr': 25.005, 'val_psnr': 23.8666, 'best_val_psnr': 23.8667}
# {'epoch': 4600, 'epoch_time_sec': 45.06, 'lr': 3.330587844875155e-05, 'train_loss': 0.011843, 'train_psnr': 24.9995, 'val_psnr': 23.8666, 'best_val_psnr': 23.8667}
# {'epoch': 4601, 'epoch_time_sec': 45.01, 'lr': 3.328641575644438e-05, 'train_loss': 0.011823, 'train_psnr': 25.009, 'val_psnr': 23.8666, 'best_val_psnr': 23.8667}
# {'epoch': 4602, 'epoch_time_sec': 45.04, 'lr': 3.3266956090879945e-05, 'train_loss': 0.011823, 'train_psnr': 25.0084, 'val_psnr': 23.8666, 'best_val_psnr': 23.8667}
# {'epoch': 4603, 'epoch_time_sec': 44.95, 'lr': 3.324749945547997e-05, 'train_loss': 0.011835, 'train_psnr': 25.0055, 'val_psnr': 23.8666, 'best_val_psnr': 23.8667}
# {'epoch': 4604, 'epoch_time_sec': 44.97, 'lr': 3.3228045853665545e-05, 'train_loss': 0.01183, 'train_psnr': 25.005, 'val_psnr': 23.8667, 'best_val_psnr': 23.8667}
# {'epoch': 4605, 'epoch_time_sec': 45.26, 'lr': 3.320859528885732e-05, 'train_loss': 0.011828, 'train_psnr': 25.0095, 'val_psnr': 23.8667, 'best_val_psnr': 23.8667}
# {'epoch': 4606, 'epoch_time_sec': 44.87, 'lr': 3.3189147764475376e-05, 'train_loss': 0.011836, 'train_psnr': 25.0023, 'val_psnr': 23.8667, 'best_val_psnr': 23.8667}
# {'epoch': 4607, 'epoch_time_sec': 45.3, 'lr': 3.316970328393928e-05, 'train_loss': 0.011842, 'train_psnr': 25.0006, 'val_psnr': 23.8667, 'best_val_psnr': 23.8667}
# {'epoch': 4608, 'epoch_time_sec': 45.09, 'lr': 3.3150261850667986e-05, 'train_loss': 0.011829, 'train_psnr': 25.0062, 'val_psnr': 23.8667, 'best_val_psnr': 23.8667}
# {'epoch': 4609, 'epoch_time_sec': 45.1, 'lr': 3.3130823468080016e-05, 'train_loss': 0.011816, 'train_psnr': 25.0146, 'val_psnr': 23.8668, 'best_val_psnr': 23.8668}
# {'epoch': 4610, 'epoch_time_sec': 45.1, 'lr': 3.31113881395933e-05, 'train_loss': 0.01183, 'train_psnr': 25.0084, 'val_psnr': 23.8668, 'best_val_psnr': 23.8668}
# {'epoch': 4611, 'epoch_time_sec': 45.11, 'lr': 3.309195586862524e-05, 'train_loss': 0.011827, 'train_psnr': 25.0062, 'val_psnr': 23.8668, 'best_val_psnr': 23.8668}
# {'epoch': 4612, 'epoch_time_sec': 44.98, 'lr': 3.307252665859268e-05, 'train_loss': 0.011831, 'train_psnr': 25.0054, 'val_psnr': 23.8668, 'best_val_psnr': 23.8668}
# {'epoch': 4613, 'epoch_time_sec': 45.07, 'lr': 3.305310051291198e-05, 'train_loss': 0.011838, 'train_psnr': 25.0024, 'val_psnr': 23.8668, 'best_val_psnr': 23.8668}
# {'epoch': 4614, 'epoch_time_sec': 44.97, 'lr': 3.30336774349989e-05, 'train_loss': 0.011824, 'train_psnr': 25.0088, 'val_psnr': 23.8669, 'best_val_psnr': 23.8669}
# {'epoch': 4615, 'epoch_time_sec': 45.15, 'lr': 3.3014257428268704e-05, 'train_loss': 0.011827, 'train_psnr': 25.0078, 'val_psnr': 23.8669, 'best_val_psnr': 23.8669}
# {'epoch': 4616, 'epoch_time_sec': 45.07, 'lr': 3.2994840496136085e-05, 'train_loss': 0.011822, 'train_psnr': 25.0108, 'val_psnr': 23.8669, 'best_val_psnr': 23.8669}
# {'epoch': 4617, 'epoch_time_sec': 45.09, 'lr': 3.2975426642015237e-05, 'train_loss': 0.011836, 'train_psnr': 25.0031, 'val_psnr': 23.867, 'best_val_psnr': 23.867}
# {'epoch': 4618, 'epoch_time_sec': 45.08, 'lr': 3.2956015869319755e-05, 'train_loss': 0.011826, 'train_psnr': 25.0081, 'val_psnr': 23.8671, 'best_val_psnr': 23.8671}
# {'epoch': 4619, 'epoch_time_sec': 45.24, 'lr': 3.293660818146273e-05, 'train_loss': 0.011825, 'train_psnr': 25.0082, 'val_psnr': 23.8671, 'best_val_psnr': 23.8671}
# {'epoch': 4620, 'epoch_time_sec': 44.68, 'lr': 3.291720358185674e-05, 'train_loss': 0.011832, 'train_psnr': 25.0047, 'val_psnr': 23.867, 'best_val_psnr': 23.8671}
# {'epoch': 4621, 'epoch_time_sec': 45.48, 'lr': 3.289780207391374e-05, 'train_loss': 0.011849, 'train_psnr': 24.9997, 'val_psnr': 23.8669, 'best_val_psnr': 23.8671}
# {'epoch': 4622, 'epoch_time_sec': 44.67, 'lr': 3.2878403661045195e-05, 'train_loss': 0.011829, 'train_psnr': 25.0067, 'val_psnr': 23.8669, 'best_val_psnr': 23.8671}
# {'epoch': 4623, 'epoch_time_sec': 45.59, 'lr': 3.2859008346662024e-05, 'train_loss': 0.011822, 'train_psnr': 25.01, 'val_psnr': 23.8668, 'best_val_psnr': 23.8671}
# {'epoch': 4624, 'epoch_time_sec': 44.54, 'lr': 3.28396161341746e-05, 'train_loss': 0.011822, 'train_psnr': 25.0109, 'val_psnr': 23.8669, 'best_val_psnr': 23.8671}
# {'epoch': 4625, 'epoch_time_sec': 45.53, 'lr': 3.282022702699274e-05, 'train_loss': 0.011826, 'train_psnr': 25.0082, 'val_psnr': 23.867, 'best_val_psnr': 23.8671}
# {'epoch': 4626, 'epoch_time_sec': 44.61, 'lr': 3.280084102852569e-05, 'train_loss': 0.011835, 'train_psnr': 25.0064, 'val_psnr': 23.867, 'best_val_psnr': 23.8671}
# {'epoch': 4627, 'epoch_time_sec': 45.54, 'lr': 3.278145814218223e-05, 'train_loss': 0.011833, 'train_psnr': 25.0038, 'val_psnr': 23.867, 'best_val_psnr': 23.8671}
# {'epoch': 4628, 'epoch_time_sec': 44.76, 'lr': 3.276207837137049e-05, 'train_loss': 0.011839, 'train_psnr': 25.0008, 'val_psnr': 23.8671, 'best_val_psnr': 23.8671}
# {'epoch': 4629, 'epoch_time_sec': 45.49, 'lr': 3.274270171949813e-05, 'train_loss': 0.011864, 'train_psnr': 24.9967, 'val_psnr': 23.867, 'best_val_psnr': 23.8671}
# {'epoch': 4630, 'epoch_time_sec': 44.74, 'lr': 3.272332818997225e-05, 'train_loss': 0.011829, 'train_psnr': 25.0075, 'val_psnr': 23.8669, 'best_val_psnr': 23.8671}
# {'epoch': 4631, 'epoch_time_sec': 44.93, 'lr': 3.270395778619935e-05, 'train_loss': 0.011827, 'train_psnr': 25.0069, 'val_psnr': 23.8669, 'best_val_psnr': 23.8671}
# {'epoch': 4632, 'epoch_time_sec': 45.53, 'lr': 3.268459051158543e-05, 'train_loss': 0.011826, 'train_psnr': 25.0079, 'val_psnr': 23.8669, 'best_val_psnr': 23.8671}
# {'epoch': 4633, 'epoch_time_sec': 44.63, 'lr': 3.266522636953593e-05, 'train_loss': 0.011835, 'train_psnr': 25.0045, 'val_psnr': 23.8668, 'best_val_psnr': 23.8671}
# {'epoch': 4634, 'epoch_time_sec': 45.44, 'lr': 3.264586536345575e-05, 'train_loss': 0.011828, 'train_psnr': 25.007, 'val_psnr': 23.8669, 'best_val_psnr': 23.8671}
# {'epoch': 4635, 'epoch_time_sec': 44.5, 'lr': 3.26265074967492e-05, 'train_loss': 0.011838, 'train_psnr': 25.0009, 'val_psnr': 23.8669, 'best_val_psnr': 23.8671}
# {'epoch': 4636, 'epoch_time_sec': 45.54, 'lr': 3.260715277282006e-05, 'train_loss': 0.011835, 'train_psnr': 25.0046, 'val_psnr': 23.867, 'best_val_psnr': 23.8671}
# {'epoch': 4637, 'epoch_time_sec': 44.58, 'lr': 3.258780119507158e-05, 'train_loss': 0.011831, 'train_psnr': 25.0066, 'val_psnr': 23.867, 'best_val_psnr': 23.8671}
# {'epoch': 4638, 'epoch_time_sec': 45.44, 'lr': 3.2568452766906416e-05, 'train_loss': 0.011829, 'train_psnr': 25.0074, 'val_psnr': 23.867, 'best_val_psnr': 23.8671}
# {'epoch': 4639, 'epoch_time_sec': 44.55, 'lr': 3.254910749172669e-05, 'train_loss': 0.011824, 'train_psnr': 25.0097, 'val_psnr': 23.867, 'best_val_psnr': 23.8671}
# {'epoch': 4640, 'epoch_time_sec': 45.46, 'lr': 3.252976537293401e-05, 'train_loss': 0.01184, 'train_psnr': 25.0011, 'val_psnr': 23.8671, 'best_val_psnr': 23.8671}
# {'epoch': 4641, 'epoch_time_sec': 44.6, 'lr': 3.251042641392933e-05, 'train_loss': 0.011833, 'train_psnr': 25.0055, 'val_psnr': 23.8671, 'best_val_psnr': 23.8671}
# {'epoch': 4642, 'epoch_time_sec': 45.38, 'lr': 3.249109061811314e-05, 'train_loss': 0.011819, 'train_psnr': 25.0122, 'val_psnr': 23.8671, 'best_val_psnr': 23.8671}
# {'epoch': 4643, 'epoch_time_sec': 44.96, 'lr': 3.247175798888532e-05, 'train_loss': 0.011827, 'train_psnr': 25.0065, 'val_psnr': 23.8671, 'best_val_psnr': 23.8671}
# {'epoch': 4644, 'epoch_time_sec': 45.11, 'lr': 3.245242852964526e-05, 'train_loss': 0.011825, 'train_psnr': 25.0073, 'val_psnr': 23.8671, 'best_val_psnr': 23.8671}
# {'epoch': 4645, 'epoch_time_sec': 45.12, 'lr': 3.2433102243791686e-05, 'train_loss': 0.011827, 'train_psnr': 25.0083, 'val_psnr': 23.867, 'best_val_psnr': 23.8671}
# {'epoch': 4646, 'epoch_time_sec': 45.11, 'lr': 3.241377913472288e-05, 'train_loss': 0.011838, 'train_psnr': 25.0045, 'val_psnr': 23.867, 'best_val_psnr': 23.8671}
# {'epoch': 4647, 'epoch_time_sec': 45.05, 'lr': 3.239445920583649e-05, 'train_loss': 0.011828, 'train_psnr': 25.0074, 'val_psnr': 23.867, 'best_val_psnr': 23.8671}
# {'epoch': 4648, 'epoch_time_sec': 45.01, 'lr': 3.237514246052961e-05, 'train_loss': 0.011825, 'train_psnr': 25.0088, 'val_psnr': 23.8671, 'best_val_psnr': 23.8671}
# {'epoch': 4649, 'epoch_time_sec': 45.06, 'lr': 3.235582890219879e-05, 'train_loss': 0.011828, 'train_psnr': 25.0064, 'val_psnr': 23.8671, 'best_val_psnr': 23.8671}
# {'epoch': 4650, 'epoch_time_sec': 45.12, 'lr': 3.233651853424006e-05, 'train_loss': 0.011845, 'train_psnr': 25.0012, 'val_psnr': 23.8671, 'best_val_psnr': 23.8671}
# {'epoch': 4651, 'epoch_time_sec': 44.92, 'lr': 3.2317211360048837e-05, 'train_loss': 0.011834, 'train_psnr': 25.0045, 'val_psnr': 23.8672, 'best_val_psnr': 23.8672}
# {'epoch': 4652, 'epoch_time_sec': 45.02, 'lr': 3.229790738301996e-05, 'train_loss': 0.011829, 'train_psnr': 25.0084, 'val_psnr': 23.8673, 'best_val_psnr': 23.8673}
# {'epoch': 4653, 'epoch_time_sec': 45.02, 'lr': 3.227860660654774e-05, 'train_loss': 0.011834, 'train_psnr': 25.0048, 'val_psnr': 23.8671, 'best_val_psnr': 23.8673}
# {'epoch': 4654, 'epoch_time_sec': 44.99, 'lr': 3.225930903402597e-05, 'train_loss': 0.011827, 'train_psnr': 25.0069, 'val_psnr': 23.8672, 'best_val_psnr': 23.8673}
# {'epoch': 4655, 'epoch_time_sec': 44.48, 'lr': 3.2240014668847764e-05, 'train_loss': 0.01182, 'train_psnr': 25.0114, 'val_psnr': 23.8671, 'best_val_psnr': 23.8673}
# {'epoch': 4656, 'epoch_time_sec': 45.54, 'lr': 3.222072351440578e-05, 'train_loss': 0.011827, 'train_psnr': 25.0077, 'val_psnr': 23.8671, 'best_val_psnr': 23.8673}
# {'epoch': 4657, 'epoch_time_sec': 44.78, 'lr': 3.2201435574092066e-05, 'train_loss': 0.011837, 'train_psnr': 25.0041, 'val_psnr': 23.8671, 'best_val_psnr': 23.8673}
# {'epoch': 4658, 'epoch_time_sec': 45.1, 'lr': 3.2182150851298085e-05, 'train_loss': 0.011821, 'train_psnr': 25.0106, 'val_psnr': 23.8671, 'best_val_psnr': 23.8673}
# {'epoch': 4659, 'epoch_time_sec': 44.99, 'lr': 3.2162869349414764e-05, 'train_loss': 0.011831, 'train_psnr': 25.0074, 'val_psnr': 23.8671, 'best_val_psnr': 23.8673}
# {'epoch': 4660, 'epoch_time_sec': 45.04, 'lr': 3.214359107183249e-05, 'train_loss': 0.01183, 'train_psnr': 25.0065, 'val_psnr': 23.8672, 'best_val_psnr': 23.8673}
# {'epoch': 4661, 'epoch_time_sec': 45.14, 'lr': 3.2124316021941024e-05, 'train_loss': 0.011819, 'train_psnr': 25.0114, 'val_psnr': 23.8671, 'best_val_psnr': 23.8673}
# {'epoch': 4662, 'epoch_time_sec': 45.06, 'lr': 3.2105044203129565e-05, 'train_loss': 0.011822, 'train_psnr': 25.0121, 'val_psnr': 23.8671, 'best_val_psnr': 23.8673}
# {'epoch': 4663, 'epoch_time_sec': 45.14, 'lr': 3.208577561878679e-05, 'train_loss': 0.011826, 'train_psnr': 25.0067, 'val_psnr': 23.867, 'best_val_psnr': 23.8673}
# {'epoch': 4664, 'epoch_time_sec': 45.0, 'lr': 3.2066510272300794e-05, 'train_loss': 0.011826, 'train_psnr': 25.0087, 'val_psnr': 23.867, 'best_val_psnr': 23.8673}
# {'epoch': 4665, 'epoch_time_sec': 45.09, 'lr': 3.204724816705906e-05, 'train_loss': 0.011821, 'train_psnr': 25.011, 'val_psnr': 23.867, 'best_val_psnr': 23.8673}
# {'epoch': 4666, 'epoch_time_sec': 44.87, 'lr': 3.2027989306448554e-05, 'train_loss': 0.011823, 'train_psnr': 25.0088, 'val_psnr': 23.867, 'best_val_psnr': 23.8673}
# {'epoch': 4667, 'epoch_time_sec': 45.53, 'lr': 3.2008733693855646e-05, 'train_loss': 0.011827, 'train_psnr': 25.0074, 'val_psnr': 23.8671, 'best_val_psnr': 23.8673}
# {'epoch': 4668, 'epoch_time_sec': 44.45, 'lr': 3.198948133266612e-05, 'train_loss': 0.011838, 'train_psnr': 25.0047, 'val_psnr': 23.8671, 'best_val_psnr': 23.8673}
# {'epoch': 4669, 'epoch_time_sec': 45.47, 'lr': 3.197023222626522e-05, 'train_loss': 0.011838, 'train_psnr': 24.9999, 'val_psnr': 23.8671, 'best_val_psnr': 23.8673}
# {'epoch': 4670, 'epoch_time_sec': 44.59, 'lr': 3.19509863780376e-05, 'train_loss': 0.011838, 'train_psnr': 25.0038, 'val_psnr': 23.8672, 'best_val_psnr': 23.8673}
# {'epoch': 4671, 'epoch_time_sec': 45.5, 'lr': 3.1931743791367374e-05, 'train_loss': 0.011824, 'train_psnr': 25.0077, 'val_psnr': 23.8673, 'best_val_psnr': 23.8673}
# {'epoch': 4672, 'epoch_time_sec': 44.68, 'lr': 3.191250446963801e-05, 'train_loss': 0.011827, 'train_psnr': 25.0079, 'val_psnr': 23.8672, 'best_val_psnr': 23.8673}
# {'epoch': 4673, 'epoch_time_sec': 45.61, 'lr': 3.1893268416232445e-05, 'train_loss': 0.011825, 'train_psnr': 25.0089, 'val_psnr': 23.8672, 'best_val_psnr': 23.8673}
# {'epoch': 4674, 'epoch_time_sec': 44.6, 'lr': 3.187403563453309e-05, 'train_loss': 0.011821, 'train_psnr': 25.0103, 'val_psnr': 23.8673, 'best_val_psnr': 23.8673}
# {'epoch': 4675, 'epoch_time_sec': 45.56, 'lr': 3.1854806127921675e-05, 'train_loss': 0.011821, 'train_psnr': 25.011, 'val_psnr': 23.8674, 'best_val_psnr': 23.8674}
# {'epoch': 4676, 'epoch_time_sec': 44.71, 'lr': 3.183557989977946e-05, 'train_loss': 0.011837, 'train_psnr': 25.0027, 'val_psnr': 23.8673, 'best_val_psnr': 23.8674}
# {'epoch': 4677, 'epoch_time_sec': 45.52, 'lr': 3.1816356953487034e-05, 'train_loss': 0.011833, 'train_psnr': 25.0038, 'val_psnr': 23.8673, 'best_val_psnr': 23.8674}
# {'epoch': 4678, 'epoch_time_sec': 44.53, 'lr': 3.179713729242451e-05, 'train_loss': 0.01183, 'train_psnr': 25.0075, 'val_psnr': 23.8674, 'best_val_psnr': 23.8674}
# {'epoch': 4679, 'epoch_time_sec': 45.09, 'lr': 3.1777920919971314e-05, 'train_loss': 0.011835, 'train_psnr': 25.0053, 'val_psnr': 23.8674, 'best_val_psnr': 23.8674}
# {'epoch': 4680, 'epoch_time_sec': 44.94, 'lr': 3.175870783950638e-05, 'train_loss': 0.011829, 'train_psnr': 25.0068, 'val_psnr': 23.8673, 'best_val_psnr': 23.8674}
# {'epoch': 4681, 'epoch_time_sec': 45.03, 'lr': 3.1739498054408034e-05, 'train_loss': 0.011821, 'train_psnr': 25.0115, 'val_psnr': 23.8673, 'best_val_psnr': 23.8674}
# {'epoch': 4682, 'epoch_time_sec': 45.04, 'lr': 3.172029156805399e-05, 'train_loss': 0.011827, 'train_psnr': 25.0086, 'val_psnr': 23.8673, 'best_val_psnr': 23.8674}
# {'epoch': 4683, 'epoch_time_sec': 44.94, 'lr': 3.170108838382144e-05, 'train_loss': 0.011821, 'train_psnr': 25.0127, 'val_psnr': 23.8673, 'best_val_psnr': 23.8674}
# {'epoch': 4684, 'epoch_time_sec': 45.5, 'lr': 3.1681888505086966e-05, 'train_loss': 0.011828, 'train_psnr': 25.0068, 'val_psnr': 23.8673, 'best_val_psnr': 23.8674}
# {'epoch': 4685, 'epoch_time_sec': 44.58, 'lr': 3.166269193522654e-05, 'train_loss': 0.011822, 'train_psnr': 25.0108, 'val_psnr': 23.8673, 'best_val_psnr': 23.8674}
# {'epoch': 4686, 'epoch_time_sec': 45.5, 'lr': 3.164349867761562e-05, 'train_loss': 0.011832, 'train_psnr': 25.0045, 'val_psnr': 23.8675, 'best_val_psnr': 23.8675}
# {'epoch': 4687, 'epoch_time_sec': 44.63, 'lr': 3.162430873562902e-05, 'train_loss': 0.011832, 'train_psnr': 25.0042, 'val_psnr': 23.8674, 'best_val_psnr': 23.8675}
# {'epoch': 4688, 'epoch_time_sec': 45.48, 'lr': 3.1605122112641017e-05, 'train_loss': 0.011824, 'train_psnr': 25.0091, 'val_psnr': 23.8673, 'best_val_psnr': 23.8675}
# {'epoch': 4689, 'epoch_time_sec': 44.66, 'lr': 3.1585938812025254e-05, 'train_loss': 0.011842, 'train_psnr': 25.0027, 'val_psnr': 23.8673, 'best_val_psnr': 23.8675}
# {'epoch': 4690, 'epoch_time_sec': 45.29, 'lr': 3.156675883715483e-05, 'train_loss': 0.011826, 'train_psnr': 25.0079, 'val_psnr': 23.8674, 'best_val_psnr': 23.8675}
# {'epoch': 4691, 'epoch_time_sec': 45.02, 'lr': 3.1547582191402267e-05, 'train_loss': 0.011832, 'train_psnr': 25.005, 'val_psnr': 23.8674, 'best_val_psnr': 23.8675}
# {'epoch': 4692, 'epoch_time_sec': 45.01, 'lr': 3.152840887813945e-05, 'train_loss': 0.011809, 'train_psnr': 25.0187, 'val_psnr': 23.8674, 'best_val_psnr': 23.8675}
# {'epoch': 4693, 'epoch_time_sec': 45.06, 'lr': 3.150923890073771e-05, 'train_loss': 0.011831, 'train_psnr': 25.0059, 'val_psnr': 23.8674, 'best_val_psnr': 23.8675}
# {'epoch': 4694, 'epoch_time_sec': 45.15, 'lr': 3.1490072262567835e-05, 'train_loss': 0.011845, 'train_psnr': 25.0025, 'val_psnr': 23.8675, 'best_val_psnr': 23.8675}
# {'epoch': 4695, 'epoch_time_sec': 45.03, 'lr': 3.1470908966999923e-05, 'train_loss': 0.011833, 'train_psnr': 25.0055, 'val_psnr': 23.8676, 'best_val_psnr': 23.8676}
# {'epoch': 4696, 'epoch_time_sec': 45.13, 'lr': 3.145174901740358e-05, 'train_loss': 0.011827, 'train_psnr': 25.0077, 'val_psnr': 23.8677, 'best_val_psnr': 23.8677}
# {'epoch': 4697, 'epoch_time_sec': 45.06, 'lr': 3.143259241714778e-05, 'train_loss': 0.011834, 'train_psnr': 25.0036, 'val_psnr': 23.8677, 'best_val_psnr': 23.8677}
# {'epoch': 4698, 'epoch_time_sec': 45.11, 'lr': 3.1413439169600926e-05, 'train_loss': 0.011827, 'train_psnr': 25.007, 'val_psnr': 23.8677, 'best_val_psnr': 23.8677}
# {'epoch': 4699, 'epoch_time_sec': 45.08, 'lr': 3.139428927813079e-05, 'train_loss': 0.01182, 'train_psnr': 25.0119, 'val_psnr': 23.8677, 'best_val_psnr': 23.8677}
# {'epoch': 4700, 'epoch_time_sec': 45.12, 'lr': 3.137514274610461e-05, 'train_loss': 0.011844, 'train_psnr': 25.0008, 'val_psnr': 23.8677, 'best_val_psnr': 23.8677}
# {'epoch': 4701, 'epoch_time_sec': 44.94, 'lr': 3.1355999576889014e-05, 'train_loss': 0.011823, 'train_psnr': 25.0081, 'val_psnr': 23.8677, 'best_val_psnr': 23.8677}
# {'epoch': 4702, 'epoch_time_sec': 45.35, 'lr': 3.133685977385001e-05, 'train_loss': 0.011822, 'train_psnr': 25.0124, 'val_psnr': 23.8678, 'best_val_psnr': 23.8678}
# {'epoch': 4703, 'epoch_time_sec': 44.57, 'lr': 3.131772334035303e-05, 'train_loss': 0.011825, 'train_psnr': 25.0075, 'val_psnr': 23.8677, 'best_val_psnr': 23.8678}
# {'epoch': 4704, 'epoch_time_sec': 45.53, 'lr': 3.1298590279762966e-05, 'train_loss': 0.01183, 'train_psnr': 25.0068, 'val_psnr': 23.8678, 'best_val_psnr': 23.8678}
# {'epoch': 4705, 'epoch_time_sec': 44.62, 'lr': 3.127946059544402e-05, 'train_loss': 0.011827, 'train_psnr': 25.0107, 'val_psnr': 23.8678, 'best_val_psnr': 23.8678}
# {'epoch': 4706, 'epoch_time_sec': 45.48, 'lr': 3.126033429075988e-05, 'train_loss': 0.011822, 'train_psnr': 25.0103, 'val_psnr': 23.8678, 'best_val_psnr': 23.8678}
# {'epoch': 4707, 'epoch_time_sec': 44.52, 'lr': 3.1241211369073585e-05, 'train_loss': 0.011838, 'train_psnr': 25.004, 'val_psnr': 23.8678, 'best_val_psnr': 23.8678}
# {'epoch': 4708, 'epoch_time_sec': 45.26, 'lr': 3.122209183374765e-05, 'train_loss': 0.011826, 'train_psnr': 25.0092, 'val_psnr': 23.8677, 'best_val_psnr': 23.8678}
# {'epoch': 4709, 'epoch_time_sec': 44.82, 'lr': 3.12029756881439e-05, 'train_loss': 0.011827, 'train_psnr': 25.0105, 'val_psnr': 23.8678, 'best_val_psnr': 23.8678}
# {'epoch': 4710, 'epoch_time_sec': 45.23, 'lr': 3.118386293562364e-05, 'train_loss': 0.011825, 'train_psnr': 25.0084, 'val_psnr': 23.8677, 'best_val_psnr': 23.8678}
# {'epoch': 4711, 'epoch_time_sec': 45.11, 'lr': 3.1164753579547574e-05, 'train_loss': 0.011829, 'train_psnr': 25.0075, 'val_psnr': 23.8678, 'best_val_psnr': 23.8678}
# {'epoch': 4712, 'epoch_time_sec': 44.95, 'lr': 3.114564762327575e-05, 'train_loss': 0.011824, 'train_psnr': 25.0089, 'val_psnr': 23.868, 'best_val_psnr': 23.868}
# {'epoch': 4713, 'epoch_time_sec': 45.03, 'lr': 3.112654507016765e-05, 'train_loss': 0.011829, 'train_psnr': 25.0078, 'val_psnr': 23.868, 'best_val_psnr': 23.868}
# {'epoch': 4714, 'epoch_time_sec': 44.65, 'lr': 3.110744592358219e-05, 'train_loss': 0.011835, 'train_psnr': 25.0054, 'val_psnr': 23.868, 'best_val_psnr': 23.868}
# {'epoch': 4715, 'epoch_time_sec': 45.49, 'lr': 3.108835018687766e-05, 'train_loss': 0.011833, 'train_psnr': 25.0044, 'val_psnr': 23.8679, 'best_val_psnr': 23.868}
# {'epoch': 4716, 'epoch_time_sec': 44.55, 'lr': 3.106925786341174e-05, 'train_loss': 0.011825, 'train_psnr': 25.0084, 'val_psnr': 23.8679, 'best_val_psnr': 23.868}
# {'epoch': 4717, 'epoch_time_sec': 45.53, 'lr': 3.105016895654151e-05, 'train_loss': 0.011828, 'train_psnr': 25.0081, 'val_psnr': 23.8679, 'best_val_psnr': 23.868}
# {'epoch': 4718, 'epoch_time_sec': 44.6, 'lr': 3.1031083469623474e-05, 'train_loss': 0.011815, 'train_psnr': 25.0135, 'val_psnr': 23.8679, 'best_val_psnr': 23.868}
# {'epoch': 4719, 'epoch_time_sec': 45.61, 'lr': 3.101200140601351e-05, 'train_loss': 0.011821, 'train_psnr': 25.0124, 'val_psnr': 23.8679, 'best_val_psnr': 23.868}
# {'epoch': 4720, 'epoch_time_sec': 44.66, 'lr': 3.0992922769066905e-05, 'train_loss': 0.011817, 'train_psnr': 25.0122, 'val_psnr': 23.8679, 'best_val_psnr': 23.868}
# {'epoch': 4721, 'epoch_time_sec': 45.45, 'lr': 3.097384756213837e-05, 'train_loss': 0.011829, 'train_psnr': 25.0072, 'val_psnr': 23.868, 'best_val_psnr': 23.868}
# {'epoch': 4722, 'epoch_time_sec': 44.62, 'lr': 3.0954775788581937e-05, 'train_loss': 0.011834, 'train_psnr': 25.004, 'val_psnr': 23.8679, 'best_val_psnr': 23.868}
# {'epoch': 4723, 'epoch_time_sec': 45.5, 'lr': 3.093570745175111e-05, 'train_loss': 0.011831, 'train_psnr': 25.0052, 'val_psnr': 23.8679, 'best_val_psnr': 23.868}
# {'epoch': 4724, 'epoch_time_sec': 44.75, 'lr': 3.091664255499875e-05, 'train_loss': 0.011822, 'train_psnr': 25.011, 'val_psnr': 23.8679, 'best_val_psnr': 23.868}
# {'epoch': 4725, 'epoch_time_sec': 45.35, 'lr': 3.0897581101677166e-05, 'train_loss': 0.011824, 'train_psnr': 25.0104, 'val_psnr': 23.8679, 'best_val_psnr': 23.868}
# {'epoch': 4726, 'epoch_time_sec': 45.01, 'lr': 3.087852309513797e-05, 'train_loss': 0.011825, 'train_psnr': 25.0089, 'val_psnr': 23.868, 'best_val_psnr': 23.868}
# {'epoch': 4727, 'epoch_time_sec': 45.12, 'lr': 3.085946853873223e-05, 'train_loss': 0.011819, 'train_psnr': 25.0118, 'val_psnr': 23.868, 'best_val_psnr': 23.868}
# {'epoch': 4728, 'epoch_time_sec': 44.96, 'lr': 3.0840417435810415e-05, 'train_loss': 0.011827, 'train_psnr': 25.0102, 'val_psnr': 23.8681, 'best_val_psnr': 23.8681}
# {'epoch': 4729, 'epoch_time_sec': 45.1, 'lr': 3.082136978972233e-05, 'train_loss': 0.011835, 'train_psnr': 25.0049, 'val_psnr': 23.8681, 'best_val_psnr': 23.8681}
# {'epoch': 4730, 'epoch_time_sec': 45.05, 'lr': 3.080232560381723e-05, 'train_loss': 0.011824, 'train_psnr': 25.0097, 'val_psnr': 23.8681, 'best_val_psnr': 23.8681}
# {'epoch': 4731, 'epoch_time_sec': 45.05, 'lr': 3.078328488144377e-05, 'train_loss': 0.011825, 'train_psnr': 25.0074, 'val_psnr': 23.8681, 'best_val_psnr': 23.8681}
# {'epoch': 4732, 'epoch_time_sec': 45.1, 'lr': 3.076424762594993e-05, 'train_loss': 0.011818, 'train_psnr': 25.0119, 'val_psnr': 23.8681, 'best_val_psnr': 23.8681}
# {'epoch': 4733, 'epoch_time_sec': 45.08, 'lr': 3.074521384068311e-05, 'train_loss': 0.01183, 'train_psnr': 25.0048, 'val_psnr': 23.868, 'best_val_psnr': 23.8681}
# {'epoch': 4734, 'epoch_time_sec': 45.0, 'lr': 3.0726183528990125e-05, 'train_loss': 0.011828, 'train_psnr': 25.0096, 'val_psnr': 23.8681, 'best_val_psnr': 23.8681}
# {'epoch': 4735, 'epoch_time_sec': 45.06, 'lr': 3.070715669421718e-05, 'train_loss': 0.011834, 'train_psnr': 25.0047, 'val_psnr': 23.8681, 'best_val_psnr': 23.8681}
# {'epoch': 4736, 'epoch_time_sec': 45.68, 'lr': 3.0688133339709826e-05, 'train_loss': 0.011815, 'train_psnr': 25.015, 'val_psnr': 23.8681, 'best_val_psnr': 23.8681}
# {'epoch': 4737, 'epoch_time_sec': 44.72, 'lr': 3.066911346881301e-05, 'train_loss': 0.011829, 'train_psnr': 25.0075, 'val_psnr': 23.8682, 'best_val_psnr': 23.8682}
# {'epoch': 4738, 'epoch_time_sec': 45.1, 'lr': 3.065009708487113e-05, 'train_loss': 0.011816, 'train_psnr': 25.0141, 'val_psnr': 23.8681, 'best_val_psnr': 23.8682}
# {'epoch': 4739, 'epoch_time_sec': 44.96, 'lr': 3.063108419122786e-05, 'train_loss': 0.011824, 'train_psnr': 25.0099, 'val_psnr': 23.8682, 'best_val_psnr': 23.8682}
# {'epoch': 4740, 'epoch_time_sec': 45.2, 'lr': 3.061207479122637e-05, 'train_loss': 0.011833, 'train_psnr': 25.0053, 'val_psnr': 23.8683, 'best_val_psnr': 23.8683}
# {'epoch': 4741, 'epoch_time_sec': 45.16, 'lr': 3.059306888820916e-05, 'train_loss': 0.011827, 'train_psnr': 25.0086, 'val_psnr': 23.8682, 'best_val_psnr': 23.8683}
# {'epoch': 4742, 'epoch_time_sec': 45.16, 'lr': 3.0574066485518136e-05, 'train_loss': 0.011831, 'train_psnr': 25.0064, 'val_psnr': 23.8682, 'best_val_psnr': 23.8683}
# {'epoch': 4743, 'epoch_time_sec': 45.09, 'lr': 3.055506758649454e-05, 'train_loss': 0.011832, 'train_psnr': 25.004, 'val_psnr': 23.8683, 'best_val_psnr': 23.8683}
# {'epoch': 4744, 'epoch_time_sec': 45.14, 'lr': 3.053607219447906e-05, 'train_loss': 0.011826, 'train_psnr': 25.0054, 'val_psnr': 23.8683, 'best_val_psnr': 23.8683}
# {'epoch': 4745, 'epoch_time_sec': 45.04, 'lr': 3.0517080312811756e-05, 'train_loss': 0.011818, 'train_psnr': 25.0129, 'val_psnr': 23.8683, 'best_val_psnr': 23.8683}
# {'epoch': 4746, 'epoch_time_sec': 44.99, 'lr': 3.049809194483203e-05, 'train_loss': 0.011859, 'train_psnr': 25.0004, 'val_psnr': 23.8682, 'best_val_psnr': 23.8683}
# {'epoch': 4747, 'epoch_time_sec': 45.01, 'lr': 3.0479107093878705e-05, 'train_loss': 0.01183, 'train_psnr': 25.0087, 'val_psnr': 23.8682, 'best_val_psnr': 23.8683}
# {'epoch': 4748, 'epoch_time_sec': 45.16, 'lr': 3.0460125763289983e-05, 'train_loss': 0.011827, 'train_psnr': 25.0086, 'val_psnr': 23.8683, 'best_val_psnr': 23.8683}
# {'epoch': 4749, 'epoch_time_sec': 44.67, 'lr': 3.0441147956403404e-05, 'train_loss': 0.011831, 'train_psnr': 25.006, 'val_psnr': 23.8682, 'best_val_psnr': 23.8683}
# {'epoch': 4750, 'epoch_time_sec': 45.47, 'lr': 3.0422173676555946e-05, 'train_loss': 0.011826, 'train_psnr': 25.0105, 'val_psnr': 23.8683, 'best_val_psnr': 23.8683}
# {'epoch': 4751, 'epoch_time_sec': 44.61, 'lr': 3.040320292708395e-05, 'train_loss': 0.011831, 'train_psnr': 25.0058, 'val_psnr': 23.8682, 'best_val_psnr': 23.8683}
# {'epoch': 4752, 'epoch_time_sec': 45.51, 'lr': 3.0384235711323136e-05, 'train_loss': 0.011832, 'train_psnr': 25.0072, 'val_psnr': 23.8682, 'best_val_psnr': 23.8683}
# {'epoch': 4753, 'epoch_time_sec': 44.62, 'lr': 3.0365272032608555e-05, 'train_loss': 0.011819, 'train_psnr': 25.0133, 'val_psnr': 23.8683, 'best_val_psnr': 23.8683}
# {'epoch': 4754, 'epoch_time_sec': 45.39, 'lr': 3.0346311894274703e-05, 'train_loss': 0.011827, 'train_psnr': 25.0066, 'val_psnr': 23.8683, 'best_val_psnr': 23.8683}
# {'epoch': 4755, 'epoch_time_sec': 44.61, 'lr': 3.0327355299655446e-05, 'train_loss': 0.011817, 'train_psnr': 25.0155, 'val_psnr': 23.8683, 'best_val_psnr': 23.8683}
# {'epoch': 4756, 'epoch_time_sec': 45.51, 'lr': 3.030840225208397e-05, 'train_loss': 0.011825, 'train_psnr': 25.009, 'val_psnr': 23.8683, 'best_val_psnr': 23.8683}
# {'epoch': 4757, 'epoch_time_sec': 44.54, 'lr': 3.0289452754892904e-05, 'train_loss': 0.011819, 'train_psnr': 25.0122, 'val_psnr': 23.8683, 'best_val_psnr': 23.8683}
# {'epoch': 4758, 'epoch_time_sec': 45.52, 'lr': 3.0270506811414227e-05, 'train_loss': 0.011824, 'train_psnr': 25.0085, 'val_psnr': 23.8683, 'best_val_psnr': 23.8683}
# {'epoch': 4759, 'epoch_time_sec': 44.39, 'lr': 3.0251564424979254e-05, 'train_loss': 0.011818, 'train_psnr': 25.014, 'val_psnr': 23.8685, 'best_val_psnr': 23.8685}
# {'epoch': 4760, 'epoch_time_sec': 45.5, 'lr': 3.0232625598918733e-05, 'train_loss': 0.01183, 'train_psnr': 25.0067, 'val_psnr': 23.8684, 'best_val_psnr': 23.8685}
# {'epoch': 4761, 'epoch_time_sec': 44.9, 'lr': 3.0213690336562776e-05, 'train_loss': 0.011831, 'train_psnr': 25.0047, 'val_psnr': 23.8684, 'best_val_psnr': 23.8685}
# {'epoch': 4762, 'epoch_time_sec': 44.48, 'lr': 3.0194758641240858e-05, 'train_loss': 0.011818, 'train_psnr': 25.0122, 'val_psnr': 23.8683, 'best_val_psnr': 23.8685}
# {'epoch': 4763, 'epoch_time_sec': 45.54, 'lr': 3.0175830516281793e-05, 'train_loss': 0.011816, 'train_psnr': 25.0137, 'val_psnr': 23.8684, 'best_val_psnr': 23.8685}
# {'epoch': 4764, 'epoch_time_sec': 44.6, 'lr': 3.0156905965013815e-05, 'train_loss': 0.011843, 'train_psnr': 24.9985, 'val_psnr': 23.8684, 'best_val_psnr': 23.8685}
# {'epoch': 4765, 'epoch_time_sec': 45.52, 'lr': 3.013798499076454e-05, 'train_loss': 0.01182, 'train_psnr': 25.011, 'val_psnr': 23.8684, 'best_val_psnr': 23.8685}
# {'epoch': 4766, 'epoch_time_sec': 44.6, 'lr': 3.011906759686089e-05, 'train_loss': 0.011834, 'train_psnr': 25.0064, 'val_psnr': 23.8684, 'best_val_psnr': 23.8685}
# {'epoch': 4767, 'epoch_time_sec': 45.49, 'lr': 3.0100153786629213e-05, 'train_loss': 0.011819, 'train_psnr': 25.0128, 'val_psnr': 23.8683, 'best_val_psnr': 23.8685}
# {'epoch': 4768, 'epoch_time_sec': 44.7, 'lr': 3.008124356339521e-05, 'train_loss': 0.011844, 'train_psnr': 25.0037, 'val_psnr': 23.8684, 'best_val_psnr': 23.8685}
# {'epoch': 4769, 'epoch_time_sec': 45.54, 'lr': 3.0062336930483972e-05, 'train_loss': 0.011827, 'train_psnr': 25.0073, 'val_psnr': 23.8685, 'best_val_psnr': 23.8685}
# {'epoch': 4770, 'epoch_time_sec': 44.64, 'lr': 3.004343389121989e-05, 'train_loss': 0.011825, 'train_psnr': 25.0074, 'val_psnr': 23.8685, 'best_val_psnr': 23.8685}
# {'epoch': 4771, 'epoch_time_sec': 45.52, 'lr': 3.0024534448926818e-05, 'train_loss': 0.011823, 'train_psnr': 25.0094, 'val_psnr': 23.8686, 'best_val_psnr': 23.8686}
# {'epoch': 4772, 'epoch_time_sec': 44.58, 'lr': 3.0005638606927906e-05, 'train_loss': 0.011836, 'train_psnr': 25.0082, 'val_psnr': 23.8686, 'best_val_psnr': 23.8686}
# {'epoch': 4773, 'epoch_time_sec': 45.01, 'lr': 2.9986746368545707e-05, 'train_loss': 0.011823, 'train_psnr': 25.0128, 'val_psnr': 23.8685, 'best_val_psnr': 23.8686}
# {'epoch': 4774, 'epoch_time_sec': 45.03, 'lr': 2.9967857737102105e-05, 'train_loss': 0.011821, 'train_psnr': 25.011, 'val_psnr': 23.8685, 'best_val_psnr': 23.8686}
# {'epoch': 4775, 'epoch_time_sec': 44.99, 'lr': 2.9948972715918418e-05, 'train_loss': 0.011815, 'train_psnr': 25.0151, 'val_psnr': 23.8686, 'best_val_psnr': 23.8686}
# {'epoch': 4776, 'epoch_time_sec': 45.04, 'lr': 2.9930091308315245e-05, 'train_loss': 0.011819, 'train_psnr': 25.0115, 'val_psnr': 23.8685, 'best_val_psnr': 23.8686}
# {'epoch': 4777, 'epoch_time_sec': 45.2, 'lr': 2.991121351761261e-05, 'train_loss': 0.011849, 'train_psnr': 24.9993, 'val_psnr': 23.8685, 'best_val_psnr': 23.8686}
# {'epoch': 4778, 'epoch_time_sec': 45.1, 'lr': 2.989233934712987e-05, 'train_loss': 0.011823, 'train_psnr': 25.0106, 'val_psnr': 23.8684, 'best_val_psnr': 23.8686}
# {'epoch': 4779, 'epoch_time_sec': 45.15, 'lr': 2.9873468800185764e-05, 'train_loss': 0.011823, 'train_psnr': 25.0093, 'val_psnr': 23.8685, 'best_val_psnr': 23.8686}
# {'epoch': 4780, 'epoch_time_sec': 45.1, 'lr': 2.9854601880098386e-05, 'train_loss': 0.011829, 'train_psnr': 25.0069, 'val_psnr': 23.8686, 'best_val_psnr': 23.8686}
# {'epoch': 4781, 'epoch_time_sec': 45.11, 'lr': 2.9835738590185175e-05, 'train_loss': 0.011829, 'train_psnr': 25.0084, 'val_psnr': 23.8686, 'best_val_psnr': 23.8686}
# ...
# {'epoch': 5048, 'epoch_time_sec': 34.28, 'lr': 2.4939618383576858e-05, 'train_loss': 0.011816, 'train_psnr': 25.0148, 'val_psnr': 23.8711, 'best_val_psnr': 23.8711}
# {'epoch': 5049, 'epoch_time_sec': 33.86, 'lr': 2.4921845365661076e-05, 'train_loss': 0.011817, 'train_psnr': 25.0129, 'val_psnr': 23.871, 'best_val_psnr': 23.8711}
# {'epoch': 5050, 'epoch_time_sec': 34.75, 'lr': 2.4904076845268434e-05, 'train_loss': 0.011812, 'train_psnr': 25.0166, 'val_psnr': 23.8711, 'best_val_psnr': 23.8711}
# {'epoch': 5051, 'epoch_time_sec': 33.78, 'lr': 2.488631282552331e-05, 'train_loss': 0.011829, 'train_psnr': 25.008, 'val_psnr': 23.8711, 'best_val_psnr': 23.8711}
# {'epoch': 5052, 'epoch_time_sec': 34.82, 'lr': 2.486855330954921e-05, 'train_loss': 0.011827, 'train_psnr': 25.0092, 'val_psnr': 23.8712, 'best_val_psnr': 23.8712}
# {'epoch': 5053, 'epoch_time_sec': 33.83, 'lr': 2.4850798300468875e-05, 'train_loss': 0.011814, 'train_psnr': 25.0143, 'val_psnr': 23.8713, 'best_val_psnr': 23.8713}
# {'epoch': 5054, 'epoch_time_sec': 34.73, 'lr': 2.4833047801404247e-05, 'train_loss': 0.01183, 'train_psnr': 25.0086, 'val_psnr': 23.8713, 'best_val_psnr': 23.8713}
# {'epoch': 5055, 'epoch_time_sec': 33.81, 'lr': 2.4815301815476473e-05, 'train_loss': 0.01181, 'train_psnr': 25.0165, 'val_psnr': 23.8713, 'best_val_psnr': 23.8713}
# {'epoch': 5056, 'epoch_time_sec': 34.71, 'lr': 2.4797560345805922e-05, 'train_loss': 0.011826, 'train_psnr': 25.0091, 'val_psnr': 23.8713, 'best_val_psnr': 23.8713}
# {'epoch': 5057, 'epoch_time_sec': 34.38, 'lr': 2.4779823395512144e-05, 'train_loss': 0.011829, 'train_psnr': 25.0087, 'val_psnr': 23.8713, 'best_val_psnr': 23.8713}
# {'epoch': 5058, 'epoch_time_sec': 34.37, 'lr': 2.4762090967713896e-05, 'train_loss': 0.011815, 'train_psnr': 25.0153, 'val_psnr': 23.8714, 'best_val_psnr': 23.8714}
# {'epoch': 5059, 'epoch_time_sec': 34.61, 'lr': 2.47443630655292e-05, 'train_loss': 0.011817, 'train_psnr': 25.013, 'val_psnr': 23.8713, 'best_val_psnr': 23.8714}
# {'epoch': 5060, 'epoch_time_sec': 33.7, 'lr': 2.472663969207517e-05, 'train_loss': 0.011817, 'train_psnr': 25.0136, 'val_psnr': 23.8713, 'best_val_psnr': 23.8714}
# {'epoch': 5061, 'epoch_time_sec': 34.71, 'lr': 2.470892085046824e-05, 'train_loss': 0.011821, 'train_psnr': 25.011, 'val_psnr': 23.8713, 'best_val_psnr': 23.8714}
# {'epoch': 5062, 'epoch_time_sec': 33.72, 'lr': 2.469120654382397e-05, 'train_loss': 0.011817, 'train_psnr': 25.0145, 'val_psnr': 23.8713, 'best_val_psnr': 23.8714}
# {'epoch': 5063, 'epoch_time_sec': 34.73, 'lr': 2.4673496775257153e-05, 'train_loss': 0.011818, 'train_psnr': 25.0122, 'val_psnr': 23.8714, 'best_val_psnr': 23.8714}
# {'epoch': 5064, 'epoch_time_sec': 33.7, 'lr': 2.4655791547881775e-05, 'train_loss': 0.011817, 'train_psnr': 25.0134, 'val_psnr': 23.8714, 'best_val_psnr': 23.8714}
# {'epoch': 5065, 'epoch_time_sec': 34.73, 'lr': 2.463809086481101e-05, 'train_loss': 0.011818, 'train_psnr': 25.0133, 'val_psnr': 23.8714, 'best_val_psnr': 23.8714}
# {'epoch': 5066, 'epoch_time_sec': 33.86, 'lr': 2.46203947291573e-05, 'train_loss': 0.011824, 'train_psnr': 25.0124, 'val_psnr': 23.8715, 'best_val_psnr': 23.8715}
# {'epoch': 5067, 'epoch_time_sec': 34.67, 'lr': 2.460270314403219e-05, 'train_loss': 0.011826, 'train_psnr': 25.0092, 'val_psnr': 23.8714, 'best_val_psnr': 23.8715}
# {'epoch': 5068, 'epoch_time_sec': 33.83, 'lr': 2.4585016112546467e-05, 'train_loss': 0.011819, 'train_psnr': 25.0136, 'val_psnr': 23.8713, 'best_val_psnr': 23.8715}
# {'epoch': 5069, 'epoch_time_sec': 34.71, 'lr': 2.4567333637810176e-05, 'train_loss': 0.011819, 'train_psnr': 25.013, 'val_psnr': 23.8713, 'best_val_psnr': 23.8715}
# {'epoch': 5070, 'epoch_time_sec': 34.1, 'lr': 2.4549655722932432e-05, 'train_loss': 0.011827, 'train_psnr': 25.0093, 'val_psnr': 23.8713, 'best_val_psnr': 23.8715}
# {'epoch': 5071, 'epoch_time_sec': 34.21, 'lr': 2.4531982371021687e-05, 'train_loss': 0.011813, 'train_psnr': 25.0154, 'val_psnr': 23.8714, 'best_val_psnr': 23.8715}
# {'epoch': 5072, 'epoch_time_sec': 34.31, 'lr': 2.45143135851855e-05, 'train_loss': 0.011814, 'train_psnr': 25.0146, 'val_psnr': 23.8714, 'best_val_psnr': 23.8715}
# {'epoch': 5073, 'epoch_time_sec': 34.24, 'lr': 2.4496649368530655e-05, 'train_loss': 0.011822, 'train_psnr': 25.0112, 'val_psnr': 23.8713, 'best_val_psnr': 23.8715}
# {'epoch': 5074, 'epoch_time_sec': 34.24, 'lr': 2.4478989724163138e-05, 'train_loss': 0.011827, 'train_psnr': 25.0108, 'val_psnr': 23.8713, 'best_val_psnr': 23.8715}
# {'epoch': 5075, 'epoch_time_sec': 34.32, 'lr': 2.4461334655188098e-05, 'train_loss': 0.011817, 'train_psnr': 25.0148, 'val_psnr': 23.8713, 'best_val_psnr': 23.8715}
# {'epoch': 5076, 'epoch_time_sec': 34.28, 'lr': 2.4443684164709965e-05, 'train_loss': 0.011821, 'train_psnr': 25.0115, 'val_psnr': 23.8714, 'best_val_psnr': 23.8715}
# {'epoch': 5077, 'epoch_time_sec': 34.38, 'lr': 2.442603825583225e-05, 'train_loss': 0.011824, 'train_psnr': 25.01, 'val_psnr': 23.8713, 'best_val_psnr': 23.8715}
# {'epoch': 5078, 'epoch_time_sec': 34.58, 'lr': 2.440839693165771e-05, 'train_loss': 0.011822, 'train_psnr': 25.0143, 'val_psnr': 23.8713, 'best_val_psnr': 23.8715}
# {'epoch': 5079, 'epoch_time_sec': 33.83, 'lr': 2.4390760195288363e-05, 'train_loss': 0.011828, 'train_psnr': 25.0093, 'val_psnr': 23.8713, 'best_val_psnr': 23.8715}
# {'epoch': 5080, 'epoch_time_sec': 34.59, 'lr': 2.4373128049825272e-05, 'train_loss': 0.011819, 'train_psnr': 25.0113, 'val_psnr': 23.8713, 'best_val_psnr': 23.8715}
# {'epoch': 5081, 'epoch_time_sec': 34.28, 'lr': 2.4355500498368837e-05, 'train_loss': 0.01182, 'train_psnr': 25.0109, 'val_psnr': 23.8713, 'best_val_psnr': 23.8715}
# {'epoch': 5082, 'epoch_time_sec': 34.35, 'lr': 2.4337877544018572e-05, 'train_loss': 0.011817, 'train_psnr': 25.0136, 'val_psnr': 23.8714, 'best_val_psnr': 23.8715}
# {'epoch': 5083, 'epoch_time_sec': 34.31, 'lr': 2.4320259189873205e-05, 'train_loss': 0.011813, 'train_psnr': 25.0157, 'val_psnr': 23.8713, 'best_val_psnr': 23.8715}
# {'epoch': 5084, 'epoch_time_sec': 34.34, 'lr': 2.4302645439030648e-05, 'train_loss': 0.011816, 'train_psnr': 25.0156, 'val_psnr': 23.8712, 'best_val_psnr': 23.8715}
# {'epoch': 5085, 'epoch_time_sec': 34.26, 'lr': 2.4285036294587987e-05, 'train_loss': 0.011819, 'train_psnr': 25.0125, 'val_psnr': 23.8713, 'best_val_psnr': 23.8715}
# {'epoch': 5086, 'epoch_time_sec': 34.29, 'lr': 2.4267431759641575e-05, 'train_loss': 0.011812, 'train_psnr': 25.0168, 'val_psnr': 23.8714, 'best_val_psnr': 23.8715}
# {'epoch': 5087, 'epoch_time_sec': 34.21, 'lr': 2.424983183728684e-05, 'train_loss': 0.011813, 'train_psnr': 25.0168, 'val_psnr': 23.8715, 'best_val_psnr': 23.8715}
# {'epoch': 5088, 'epoch_time_sec': 34.28, 'lr': 2.4232236530618457e-05, 'train_loss': 0.011819, 'train_psnr': 25.0146, 'val_psnr': 23.8714, 'best_val_psnr': 23.8715}
# {'epoch': 5089, 'epoch_time_sec': 34.25, 'lr': 2.4214645842730352e-05, 'train_loss': 0.011832, 'train_psnr': 25.0069, 'val_psnr': 23.8715, 'best_val_psnr': 23.8715}
# {'epoch': 5090, 'epoch_time_sec': 34.38, 'lr': 2.4197059776715488e-05, 'train_loss': 0.011813, 'train_psnr': 25.0169, 'val_psnr': 23.8715, 'best_val_psnr': 23.8715}
# {'epoch': 5091, 'epoch_time_sec': 34.11, 'lr': 2.4179478335666168e-05, 'train_loss': 0.011838, 'train_psnr': 25.0059, 'val_psnr': 23.8715, 'best_val_psnr': 23.8715}
# {'epoch': 5092, 'epoch_time_sec': 34.67, 'lr': 2.4161901522673795e-05, 'train_loss': 0.011806, 'train_psnr': 25.0209, 'val_psnr': 23.8714, 'best_val_psnr': 23.8715}
# {'epoch': 5093, 'epoch_time_sec': 33.79, 'lr': 2.4144329340828976e-05, 'train_loss': 0.011821, 'train_psnr': 25.0122, 'val_psnr': 23.8714, 'best_val_psnr': 23.8715}
# {'epoch': 5094, 'epoch_time_sec': 34.69, 'lr': 2.4126761793221518e-05, 'train_loss': 0.011835, 'train_psnr': 25.0066, 'val_psnr': 23.8716, 'best_val_psnr': 23.8716}
# {'epoch': 5095, 'epoch_time_sec': 33.81, 'lr': 2.4109198882940372e-05, 'train_loss': 0.01182, 'train_psnr': 25.0107, 'val_psnr': 23.8715, 'best_val_psnr': 23.8716}
# {'epoch': 5096, 'epoch_time_sec': 34.78, 'lr': 2.409164061307377e-05, 'train_loss': 0.011827, 'train_psnr': 25.0098, 'val_psnr': 23.8716, 'best_val_psnr': 23.8716}
# {'epoch': 5097, 'epoch_time_sec': 33.88, 'lr': 2.4074086986708987e-05, 'train_loss': 0.011812, 'train_psnr': 25.0171, 'val_psnr': 23.8716, 'best_val_psnr': 23.8716}
# {'epoch': 5098, 'epoch_time_sec': 34.76, 'lr': 2.405653800693261e-05, 'train_loss': 0.011823, 'train_psnr': 25.0086, 'val_psnr': 23.8716, 'best_val_psnr': 23.8716}
# {'epoch': 5099, 'epoch_time_sec': 34.09, 'lr': 2.403899367683035e-05, 'train_loss': 0.011825, 'train_psnr': 25.0095, 'val_psnr': 23.8716, 'best_val_psnr': 23.8716}
# {'epoch': 5100, 'epoch_time_sec': 34.31, 'lr': 2.4021453999487055e-05, 'train_loss': 0.01182, 'train_psnr': 25.012, 'val_psnr': 23.8716, 'best_val_psnr': 23.8716}
# {'epoch': 5101, 'epoch_time_sec': 34.27, 'lr': 2.400391897798687e-05, 'train_loss': 0.011823, 'train_psnr': 25.0104, 'val_psnr': 23.8716, 'best_val_psnr': 23.8716}
# {'epoch': 5102, 'epoch_time_sec': 33.81, 'lr': 2.3986388615413023e-05, 'train_loss': 0.011814, 'train_psnr': 25.0156, 'val_psnr': 23.8716, 'best_val_psnr': 23.8716}
# {'epoch': 5103, 'epoch_time_sec': 34.7, 'lr': 2.3968862914847977e-05, 'train_loss': 0.01183, 'train_psnr': 25.0088, 'val_psnr': 23.8716, 'best_val_psnr': 23.8716}
# {'epoch': 5104, 'epoch_time_sec': 33.63, 'lr': 2.395134187937334e-05, 'train_loss': 0.011822, 'train_psnr': 25.0122, 'val_psnr': 23.8717, 'best_val_psnr': 23.8717}
# {'epoch': 5105, 'epoch_time_sec': 34.71, 'lr': 2.3933825512069902e-05, 'train_loss': 0.011824, 'train_psnr': 25.0104, 'val_psnr': 23.8717, 'best_val_psnr': 23.8717}
# {'epoch': 5106, 'epoch_time_sec': 33.76, 'lr': 2.39163138160177e-05, 'train_loss': 0.011831, 'train_psnr': 25.007, 'val_psnr': 23.8717, 'best_val_psnr': 23.8717}
# {'epoch': 5107, 'epoch_time_sec': 34.73, 'lr': 2.3898806794295828e-05, 'train_loss': 0.011806, 'train_psnr': 25.0208, 'val_psnr': 23.8717, 'best_val_psnr': 23.8717}
# {'epoch': 5108, 'epoch_time_sec': 33.79, 'lr': 2.388130444998266e-05, 'train_loss': 0.011815, 'train_psnr': 25.0152, 'val_psnr': 23.8717, 'best_val_psnr': 23.8717}
# {'epoch': 5109, 'epoch_time_sec': 34.77, 'lr': 2.386380678615574e-05, 'train_loss': 0.011824, 'train_psnr': 25.0096, 'val_psnr': 23.8717, 'best_val_psnr': 23.8717}
# {'epoch': 5110, 'epoch_time_sec': 33.88, 'lr': 2.384631380589169e-05, 'train_loss': 0.011809, 'train_psnr': 25.0176, 'val_psnr': 23.8716, 'best_val_psnr': 23.8717}
# {'epoch': 5111, 'epoch_time_sec': 34.71, 'lr': 2.3828825512266444e-05, 'train_loss': 0.011806, 'train_psnr': 25.0211, 'val_psnr': 23.8717, 'best_val_psnr': 23.8717}
# {'epoch': 5112, 'epoch_time_sec': 33.83, 'lr': 2.3811341908355018e-05, 'train_loss': 0.011815, 'train_psnr': 25.0145, 'val_psnr': 23.8716, 'best_val_psnr': 23.8717}
# {'epoch': 5113, 'epoch_time_sec': 34.37, 'lr': 2.3793862997231644e-05, 'train_loss': 0.011809, 'train_psnr': 25.0171, 'val_psnr': 23.8718, 'best_val_psnr': 23.8718}
# {'epoch': 5114, 'epoch_time_sec': 34.25, 'lr': 2.3776388781969716e-05, 'train_loss': 0.011825, 'train_psnr': 25.0086, 'val_psnr': 23.8718, 'best_val_psnr': 23.8718}
# {'epoch': 5115, 'epoch_time_sec': 34.3, 'lr': 2.375891926564178e-05, 'train_loss': 0.01181, 'train_psnr': 25.0175, 'val_psnr': 23.8718, 'best_val_psnr': 23.8718}
# {'epoch': 5116, 'epoch_time_sec': 34.3, 'lr': 2.3741454451319646e-05, 'train_loss': 0.011809, 'train_psnr': 25.017, 'val_psnr': 23.8718, 'best_val_psnr': 23.8718}
# {'epoch': 5117, 'epoch_time_sec': 34.39, 'lr': 2.372399434207415e-05, 'train_loss': 0.011822, 'train_psnr': 25.0144, 'val_psnr': 23.8717, 'best_val_psnr': 23.8718}
# {'epoch': 5118, 'epoch_time_sec': 34.23, 'lr': 2.370653894097544e-05, 'train_loss': 0.011835, 'train_psnr': 25.0074, 'val_psnr': 23.8718, 'best_val_psnr': 23.8718}
# {'epoch': 5119, 'epoch_time_sec': 34.29, 'lr': 2.3689088251092763e-05, 'train_loss': 0.011815, 'train_psnr': 25.0143, 'val_psnr': 23.8718, 'best_val_psnr': 23.8718}
# {'epoch': 5120, 'epoch_time_sec': 34.29, 'lr': 2.3671642275494546e-05, 'train_loss': 0.011807, 'train_psnr': 25.0202, 'val_psnr': 23.8717, 'best_val_psnr': 23.8718}
# {'epoch': 5121, 'epoch_time_sec': 34.29, 'lr': 2.3654201017248407e-05, 'train_loss': 0.011818, 'train_psnr': 25.0145, 'val_psnr': 23.8718, 'best_val_psnr': 23.8718}
# {'epoch': 5122, 'epoch_time_sec': 34.69, 'lr': 2.363676447942111e-05, 'train_loss': 0.011834, 'train_psnr': 25.0078, 'val_psnr': 23.8718, 'best_val_psnr': 23.8718}
# {'epoch': 5123, 'epoch_time_sec': 33.84, 'lr': 2.36193326650786e-05, 'train_loss': 0.011834, 'train_psnr': 25.0044, 'val_psnr': 23.8718, 'best_val_psnr': 23.8718}
# {'epoch': 5124, 'epoch_time_sec': 34.25, 'lr': 2.3601905577286e-05, 'train_loss': 0.011823, 'train_psnr': 25.01, 'val_psnr': 23.8717, 'best_val_psnr': 23.8718}
# {'epoch': 5125, 'epoch_time_sec': 34.31, 'lr': 2.3584483219107574e-05, 'train_loss': 0.011813, 'train_psnr': 25.0155, 'val_psnr': 23.8717, 'best_val_psnr': 23.8718}
# {'epoch': 5126, 'epoch_time_sec': 34.35, 'lr': 2.3567065593606826e-05, 'train_loss': 0.011815, 'train_psnr': 25.0164, 'val_psnr': 23.8718, 'best_val_psnr': 23.8718}
# {'epoch': 5127, 'epoch_time_sec': 34.27, 'lr': 2.35496527038463e-05, 'train_loss': 0.01181, 'train_psnr': 25.0154, 'val_psnr': 23.8718, 'best_val_psnr': 23.8718}
# {'epoch': 5128, 'epoch_time_sec': 34.25, 'lr': 2.3532244552887846e-05, 'train_loss': 0.011823, 'train_psnr': 25.0123, 'val_psnr': 23.8719, 'best_val_psnr': 23.8719}
# {'epoch': 5129, 'epoch_time_sec': 34.26, 'lr': 2.3514841143792404e-05, 'train_loss': 0.011813, 'train_psnr': 25.0158, 'val_psnr': 23.8719, 'best_val_psnr': 23.8719}
# {'epoch': 5130, 'epoch_time_sec': 34.18, 'lr': 2.3497442479620078e-05, 'train_loss': 0.011824, 'train_psnr': 25.0113, 'val_psnr': 23.872, 'best_val_psnr': 23.872}
# {'epoch': 5131, 'epoch_time_sec': 34.26, 'lr': 2.348004856343017e-05, 'train_loss': 0.011817, 'train_psnr': 25.0135, 'val_psnr': 23.872, 'best_val_psnr': 23.872}
# {'epoch': 5132, 'epoch_time_sec': 34.29, 'lr': 2.3462659398281122e-05, 'train_loss': 0.011811, 'train_psnr': 25.0162, 'val_psnr': 23.8721, 'best_val_psnr': 23.8721}
# {'epoch': 5133, 'epoch_time_sec': 34.21, 'lr': 2.344527498723055e-05, 'train_loss': 0.011821, 'train_psnr': 25.012, 'val_psnr': 23.8721, 'best_val_psnr': 23.8721}
# {'epoch': 5134, 'epoch_time_sec': 34.32, 'lr': 2.3427895333335237e-05, 'train_loss': 0.011823, 'train_psnr': 25.0108, 'val_psnr': 23.8721, 'best_val_psnr': 23.8721}
# {'epoch': 5135, 'epoch_time_sec': 33.79, 'lr': 2.3410520439651113e-05, 'train_loss': 0.011831, 'train_psnr': 25.0087, 'val_psnr': 23.8721, 'best_val_psnr': 23.8721}
# {'epoch': 5136, 'epoch_time_sec': 34.79, 'lr': 2.339315030923333e-05, 'train_loss': 0.011811, 'train_psnr': 25.0165, 'val_psnr': 23.8721, 'best_val_psnr': 23.8721}
# {'epoch': 5137, 'epoch_time_sec': 33.82, 'lr': 2.3375784945136097e-05, 'train_loss': 0.01183, 'train_psnr': 25.0088, 'val_psnr': 23.872, 'best_val_psnr': 23.8721}
# {'epoch': 5138, 'epoch_time_sec': 34.79, 'lr': 2.335842435041288e-05, 'train_loss': 0.011825, 'train_psnr': 25.0097, 'val_psnr': 23.872, 'best_val_psnr': 23.8721}
# {'epoch': 5139, 'epoch_time_sec': 33.77, 'lr': 2.3341068528116276e-05, 'train_loss': 0.011817, 'train_psnr': 25.0134, 'val_psnr': 23.872, 'best_val_psnr': 23.8721}
# {'epoch': 5140, 'epoch_time_sec': 34.72, 'lr': 2.3323717481298017e-05, 'train_loss': 0.011815, 'train_psnr': 25.0149, 'val_psnr': 23.8721, 'best_val_psnr': 23.8721}
# {'epoch': 5141, 'epoch_time_sec': 33.74, 'lr': 2.330637121300903e-05, 'train_loss': 0.011821, 'train_psnr': 25.0106, 'val_psnr': 23.8721, 'best_val_psnr': 23.8721}
# {'epoch': 5142, 'epoch_time_sec': 34.7, 'lr': 2.328902972629938e-05, 'train_loss': 0.011811, 'train_psnr': 25.019, 'val_psnr': 23.8721, 'best_val_psnr': 23.8721}
# {'epoch': 5143, 'epoch_time_sec': 33.79, 'lr': 2.3271693024218305e-05, 'train_loss': 0.011821, 'train_psnr': 25.0119, 'val_psnr': 23.8721, 'best_val_psnr': 23.8721}
# {'epoch': 5144, 'epoch_time_sec': 34.5, 'lr': 2.3254361109814195e-05, 'train_loss': 0.01182, 'train_psnr': 25.0123, 'val_psnr': 23.8721, 'best_val_psnr': 23.8721}

# %% [markdown]
# ## 4. Validation

# %%
best_model = build_eval_model_from_checkpoint(best_ckpt_path, device)
preview_info = write_val_preview(best_model, val_loader, preview_dir, device)
best_val_psnr = evaluate_psnr(best_model, val_loader, device)
validation_summary = {
    'input_psnr': input_psnr,
    'val_psnr': best_val_psnr,
    'delta_psnr': best_val_psnr - input_psnr,
}
print({
    'validation_summary': validation_summary,
    'preview': preview_info,
    'best_checkpoint_path': str(best_ckpt_path),
})

# %% [markdown]
# ## 5. Export and Submission Artifacts
#
# ONNX export is included here. MXQ conversion stays in a separate workflow.

# %%
onnx_path = exports_dir / f'{cfg.model_id}.onnx'
export_model = build_eval_model_from_checkpoint(best_ckpt_path, device)
dummy = torch.randn(1, 3, 256, 256, device=device)

torch.onnx.export(
    export_model,
    dummy,
    str(onnx_path),
    input_names=['input'],
    output_names=['output'],
    opset_version=17,
    dynamo=False,
)

onnx_model = onnx.load(str(onnx_path))
onnx.checker.check_model(onnx_model)
node_ops = [node.op_type for node in onnx_model.graph.node]
op_histogram = {op: node_ops.count(op) for op in sorted(set(node_ops))}
print({
    'onnx_path': str(onnx_path),
    'graph_op_count': len(node_ops),
    'op_histogram': op_histogram,
})

parity_result = {
    'attempted': False,
    'onnxruntime_available': False,
    'max_abs_diff': None,
}
try:
    import onnxruntime as ort

    parity_result['attempted'] = True
    parity_result['onnxruntime_available'] = True
    cpu_model = build_eval_model_from_checkpoint(best_ckpt_path, torch.device('cpu')).cpu().eval()
    parity_input = torch.randn(1, 3, 256, 256)
    with torch.no_grad():
        torch_out = cpu_model(parity_input).detach().cpu().numpy()
    ort_session = ort.InferenceSession(str(onnx_path), providers=['CPUExecutionProvider'])
    ort_out = ort_session.run(['output'], {'input': parity_input.numpy()})[0]
    parity_result['max_abs_diff'] = float(np.max(np.abs(torch_out - ort_out)))
except ImportError:
    print('onnxruntime not installed; skipping CPU parity check')
print(parity_result)

summary = {
    'model_id': cfg.model_id,
    'run_root': str(run_root),
    'best_checkpoint_path': str(best_ckpt_path),
    'last_checkpoint_path': str(last_ckpt_path),
    'onnx_path': str(onnx_path),
    'metrics_csv_path': str(metrics_csv_path),
    'validation': validation_summary,
    'preview': preview_info,
    'onnx_parity': parity_result,
    'mxq_scope': 'Not handled in this notebook; separate workflow.',
}
summary_path.write_text(json.dumps(summary, indent=2), encoding='utf-8')
print(summary)
