# %% [markdown]
# # Lab 3 - TinySRCNNResidual (No-Add Colab A100, resume 5144 to 10000 epochs)
#
# - Goal: resume the TinySRCNN-style no-add super-resolution model from epoch `5144` and train to epoch `10000` for Lab 3.
# - Expected input/output: `256x256x3`
# - Runtime target: Google Colab with Google Drive.
# - Resume checkpoint: `/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/083803_2604_base/checkpoints/last.pth`
# - Note: MXQ conversion is intentionally handled outside this notebook.

# %% [markdown]
# ## 1. Setup
#
# This notebook follows the Lab 3 rubric structure while keeping the implementation lean.

# %%
try:
    import google.colab  # type: ignore
    IN_COLAB_BOOTSTRAP = True
except Exception:
    IN_COLAB_BOOTSTRAP = False

if IN_COLAB_BOOTSTRAP:
    # %pip install -q onnx onnxruntime

import csv
import json
import math
import os
import random
import sys
import time
from contextlib import nullcontext
from dataclasses import asdict, dataclass
from datetime import datetime
from pathlib import Path
from typing import Any

import numpy as np
import onnx
import torch
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
from torch.utils.data import DataLoader, Dataset


IMAGE_SUFFIXES = {'.png', '.jpg', '.jpeg', '.bmp'}
DRIVE_ROOT = Path('/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3')
DRIVE_DATA_ROOT = DRIVE_ROOT / 'Data'
DRIVE_RUNS_ROOT = DRIVE_ROOT / 'runs'

try:
    BICUBIC_RESAMPLE = Image.Resampling.BICUBIC
except AttributeError:
    BICUBIC_RESAMPLE = Image.BICUBIC

try:
    FLIP_LEFT_RIGHT = Image.Transpose.FLIP_LEFT_RIGHT
    FLIP_TOP_BOTTOM = Image.Transpose.FLIP_TOP_BOTTOM
    ROTATE_90 = Image.Transpose.ROTATE_90
    ROTATE_180 = Image.Transpose.ROTATE_180
    ROTATE_270 = Image.Transpose.ROTATE_270
except AttributeError:
    FLIP_LEFT_RIGHT = Image.FLIP_LEFT_RIGHT
    FLIP_TOP_BOTTOM = Image.FLIP_TOP_BOTTOM
    ROTATE_90 = Image.ROTATE_90
    ROTATE_180 = Image.ROTATE_180
    ROTATE_270 = Image.ROTATE_270


def set_global_seed(seed: int) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


def now_stamp() -> str:
    return datetime.now().strftime('%H%M%S_%d%m')


def is_colab_runtime() -> bool:
    try:
        import google.colab  # type: ignore  # noqa: F401
        return True
    except Exception:
        return False


def auto_num_workers(in_colab: bool) -> int:
    if sys.platform == 'darwin':
        return 0
    cpu_count = max(os.cpu_count() or 2, 2)
    if in_colab:
        return min(4, max(cpu_count - 1, 2))
    return min(2, cpu_count)


def resolve_repo_root(start: Path) -> Path:
    current = start.resolve()
    for candidate in [current, *current.parents]:
        if (candidate / 'Data').exists() and (candidate / 'runs').exists():
            return candidate
    for candidate in [current, *current.parents]:
        if (candidate / 'Data').exists():
            return candidate
    raise FileNotFoundError(f'Could not locate repo root from {start.resolve()}')


def make_unique_run_root(runs_root: Path, run_slug: str = '') -> Path:
    safe_slug = ''.join(ch if ch.isalnum() or ch in '_-' else '_' for ch in run_slug).strip('_')
    suffix = f'_{safe_slug}' if safe_slug else ''
    candidate = runs_root / f'{now_stamp()}{suffix}'
    while candidate.exists():
        time.sleep(1.1)
        candidate = runs_root / f'{now_stamp()}{suffix}'
    return candidate


def read_checkpoint_identity(checkpoint_path: Path) -> dict[str, Any] | None:
    try:
        checkpoint = torch.load(checkpoint_path, map_location='cpu')
    except Exception:
        return None
    config = checkpoint.get('config') or {}
    model_id = config.get('model_id')
    if not model_id:
        return None
    return {
        'path': str(checkpoint_path),
        'model_id': model_id,
        'epoch': int(checkpoint.get('epoch', 0)),
        'kind': checkpoint_path.name,
        'mtime': checkpoint_path.stat().st_mtime,
    }


def find_latest_model_checkpoint(runs_root: Path, model_id: str, filename: str = 'last.pth') -> str | None:
    candidates: list[dict[str, Any]] = []
    for checkpoint_path in runs_root.rglob(f'checkpoints/{filename}'):
        identity = read_checkpoint_identity(checkpoint_path)
        if identity and identity['model_id'] == model_id:
            candidates.append(identity)
    if not candidates:
        return None
    winner = max(candidates, key=lambda item: item['mtime'])
    return winner['path']


def resolve_resume_checkpoint_path(resume_checkpoint_path: str | None, runs_root: Path, model_id: str) -> str | None:
    if not resume_checkpoint_path:
        return None
    if resume_checkpoint_path == 'last.pth':
        return find_latest_model_checkpoint(runs_root, model_id, filename='last.pth')
    path = Path(resume_checkpoint_path)
    if not path.is_absolute():
        path = runs_root / path
    if path.name == 'exports':
        candidate_paths = [path.parent / 'checkpoints' / 'last.pth']
    elif path.is_dir():
        candidate_paths = [path / 'last.pth']
    else:
        candidate_paths = [path]
    for candidate in candidate_paths:
        if candidate.is_file():
            return str(candidate)
    return None



def required_relative_dirs() -> list[Path]:
    paths: list[Path] = []
    for hr_rel, lr_rel, _ in (
        ('LR_HR/L3_HR_train1', 'L3_LR/L3_L3_train1', 'L3_HR_train1'),
        ('LR_HR/L3_HR_train2', 'L3_LR/L3_L3_train2', 'L3_HR_train2'),
        ('LR_HR/L3_HR_train3', 'L3_LR/L3_LR_train3', 'L3_HR_train3'),
        ('LR_HR/L3_HR_train4', 'L3_LR/L3_LR_train4', 'L3_HR_train4'),
        ('LR_HR/L3_HR_train', 'L3_LR/L3_LR_train', 'L3_HR_train'),
    ):
        paths.append(Path(hr_rel))
        paths.append(Path(lr_rel))
    paths.append(Path('L3_HR_valid'))
    paths.append(Path('L3_LR_valid'))
    return paths


def stage_data_root(source_root: Path, local_root: Path) -> Path:
    import shutil

    required = required_relative_dirs()
    if all((local_root / rel).exists() for rel in required):
        print({
            'data_staging': 'reuse_existing',
            'source_root': str(source_root),
            'local_root': str(local_root),
        })
        return local_root

    start = time.time()
    for rel in required:
        src_dir = source_root / rel
        dst_dir = local_root / rel
        dst_dir.parent.mkdir(parents=True, exist_ok=True)
        if dst_dir.exists():
            shutil.rmtree(dst_dir)
        shutil.copytree(src_dir, dst_dir)
    elapsed = time.time() - start
    print({
        'data_staging': 'copied_to_local',
        'source_root': str(source_root),
        'local_root': str(local_root),
        'elapsed_sec': round(elapsed, 2),
    })
    return local_root


@dataclass
class RunConfig:
    model_id: str = 'tinysrcnn_noadd_lrelu'
    run_slug: str = 'resume_5144_to_10000'
    enable_resume: bool = True
    resume_checkpoint_path: str | None = '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/083803_2604_base/checkpoints/last.pth'
    seed: int = 1337
    train_patch_size: int = 256
    eval_size: int = 256
    batch_size: int = 16
    epochs: int = 10000
    lr: float = 1e-4
    min_lr: float = 1e-6
    weight_decay: float = 1e-4
    warmup_epochs: int = 8
    num_workers: int | None = 2
    prefetch_factor: int = 2
    use_amp: bool = True
    use_ema: bool = True
    ema_decay: float = 0.999


cfg = RunConfig()
in_colab = is_colab_runtime()
if in_colab:
    from google.colab import drive  # type: ignore

    drive.mount('/content/drive', force_remount=False)
    data_root = DRIVE_DATA_ROOT
    runs_root = DRIVE_RUNS_ROOT
    if not data_root.exists():
        raise FileNotFoundError(f'Google Drive data root not found: {data_root}')
else:
    repo_root = resolve_repo_root(Path.cwd())
    data_root = repo_root / 'Data'
    runs_root = repo_root / 'runs'
    if not data_root.exists():
        raise FileNotFoundError(f'Data root not found: {data_root}')

runs_root.mkdir(parents=True, exist_ok=True)
if cfg.num_workers is None:
    cfg.num_workers = auto_num_workers(in_colab)
if cfg.enable_resume:
    cfg.resume_checkpoint_path = resolve_resume_checkpoint_path(cfg.resume_checkpoint_path, runs_root, cfg.model_id)
else:
    cfg.resume_checkpoint_path = None

run_root = make_unique_run_root(runs_root, cfg.run_slug)
checkpoints_dir = run_root / 'checkpoints'
exports_dir = run_root / 'exports'
preview_dir = exports_dir / 'val_preview'
summary_path = run_root / 'summary.json'
metrics_csv_path = run_root / 'metrics.csv'

for directory in [run_root, checkpoints_dir, exports_dir, preview_dir]:
    directory.mkdir(parents=True, exist_ok=True)

set_global_seed(cfg.seed)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
if device.type == 'cuda':
    torch.backends.cudnn.benchmark = True
    if hasattr(torch.backends.cuda.matmul, 'allow_tf32'):
        torch.backends.cuda.matmul.allow_tf32 = True
    if hasattr(torch.backends.cudnn, 'allow_tf32'):
        torch.backends.cudnn.allow_tf32 = True
    if hasattr(torch, 'set_float32_matmul_precision'):
        torch.set_float32_matmul_precision('high')

print({
    'device': str(device),
    'data_root': str(data_root),
    'runs_root': str(runs_root),
    'run_root': str(run_root),
    'config': asdict(cfg),
})
# Out:
# Mounted at /content/drive
# {'device': 'cuda', 'data_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/Data', 'runs_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs', 'run_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/191346_2604_resume_5144_to_10000', 'config': {'model_id': 'tinysrcnn_noadd_lrelu', 'run_slug': 'resume_5144_to_10000', 'enable_resume': True, 'resume_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/083803_2604_base/checkpoints/last.pth', 'seed': 1337, 'train_patch_size': 256, 'eval_size': 256, 'batch_size': 16, 'epochs': 10000, 'lr': 0.0001, 'min_lr': 1e-06, 'weight_decay': 0.0001, 'warmup_epochs': 8, 'num_workers': 2, 'prefetch_factor': 2, 'use_amp': True, 'use_ema': True, 'ema_decay': 0.999}}

# %% [markdown]
# ## 2. Data

# %%
L3_TRAIN_SPLITS = (
    ('LR_HR/L3_HR_train1', 'L3_LR/L3_L3_train1', 'L3_HR_train1'),
    ('LR_HR/L3_HR_train2', 'L3_LR/L3_L3_train2', 'L3_HR_train2'),
    ('LR_HR/L3_HR_train3', 'L3_LR/L3_LR_train3', 'L3_HR_train3'),
    ('LR_HR/L3_HR_train4', 'L3_LR/L3_LR_train4', 'L3_HR_train4'),
    ('LR_HR/L3_HR_train', 'L3_LR/L3_LR_train', 'L3_HR_train'),
)
L3_VAL_DIRS = ('L3_HR_valid', 'L3_LR_valid')


def scan_image_directory(directory: Path) -> dict[str, Path]:
    if not directory.exists():
        raise FileNotFoundError(f'Missing directory: {directory}')
    return {
        path.stem: path
        for path in directory.iterdir()
        if path.is_file() and path.suffix.lower() in IMAGE_SUFFIXES
    }


def collect_split_pairs(hr_dir: Path, lr_dir: Path, split_name: str) -> list[tuple[Path, Path, str]]:
    hr_map = scan_image_directory(hr_dir)
    lr_map = scan_image_directory(lr_dir)
    pairs: list[tuple[Path, Path, str]] = []
    for stem in sorted(set(hr_map) & set(lr_map)):
        name = stem if split_name == 'val' else f'{split_name}/{stem}'
        pairs.append((lr_map[stem], hr_map[stem], name))
    return pairs


def collect_all_pairs(data_root: Path) -> tuple[list[tuple[Path, Path, str]], list[tuple[Path, Path, str]]]:
    train_pairs: list[tuple[Path, Path, str]] = []
    for hr_rel, lr_rel, split_name in L3_TRAIN_SPLITS:
        train_pairs.extend(collect_split_pairs(data_root / hr_rel, data_root / lr_rel, split_name))
    val_pairs = collect_split_pairs(data_root / L3_VAL_DIRS[0], data_root / L3_VAL_DIRS[1], 'val')
    return train_pairs, val_pairs


class PairedSRDataset(Dataset):
    def __init__(self, pairs: list[tuple[Path, Path, str]], *, train: bool, patch_size: int, eval_size: int, seed: int):
        self.pairs = pairs
        self.train = train
        self.patch_size = patch_size
        self.eval_size = eval_size
        self.seed = seed
        self.epoch = 0

    def set_epoch(self, epoch: int) -> None:
        self.epoch = epoch

    @staticmethod
    def to_tensor(img: Image.Image) -> torch.Tensor:
        arr = np.asarray(img, dtype=np.float32) / 255.0
        return torch.from_numpy(arr).permute(2, 0, 1).contiguous()

    def augment_pair(self, lr: Image.Image, hr: Image.Image, index: int) -> tuple[Image.Image, Image.Image]:
        rng = random.Random((self.seed * 1_000_003) + (self.epoch * 9_973) + index)
        width, height = lr.size
        patch = self.patch_size
        if width < patch or height < patch:
            lr = lr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            hr = hr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            width, height = lr.size
        left = rng.randint(0, width - patch)
        top = rng.randint(0, height - patch)
        box = (left, top, left + patch, top + patch)
        lr = lr.crop(box)
        hr = hr.crop(box)
        if rng.random() < 0.5:
            lr = lr.transpose(FLIP_LEFT_RIGHT)
            hr = hr.transpose(FLIP_LEFT_RIGHT)
        if rng.random() < 0.5:
            lr = lr.transpose(FLIP_TOP_BOTTOM)
            hr = hr.transpose(FLIP_TOP_BOTTOM)
        rot = rng.choice([0, 1, 2, 3])
        if rot:
            rotate_ops = [ROTATE_90, ROTATE_180, ROTATE_270]
            lr = lr.transpose(rotate_ops[rot - 1])
            hr = hr.transpose(rotate_ops[rot - 1])
        return lr, hr

    def __len__(self) -> int:
        return len(self.pairs)

    def __getitem__(self, index: int) -> dict[str, Any]:
        lr_path, hr_path, name = self.pairs[index]
        lr = Image.open(lr_path).convert('RGB')
        hr = Image.open(hr_path).convert('RGB')
        if self.train:
            lr, hr = self.augment_pair(lr, hr, index)
        elif lr.size != (self.eval_size, self.eval_size):
            lr = lr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            hr = hr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
        return {'lr': self.to_tensor(lr), 'hr': self.to_tensor(hr), 'name': name}


train_pairs, val_pairs = collect_all_pairs(data_root)
if not train_pairs:
    raise FileNotFoundError(f'No training pairs found under {data_root}')
if not val_pairs:
    raise FileNotFoundError(f'No validation pairs found under {data_root}')
print({
    'data_root': str(data_root),
    'train_pairs': len(train_pairs),
    'val_pairs': len(val_pairs),
})

train_ds = PairedSRDataset(train_pairs, train=True, patch_size=cfg.train_patch_size, eval_size=cfg.eval_size, seed=cfg.seed)
val_ds = PairedSRDataset(val_pairs, train=False, patch_size=cfg.train_patch_size, eval_size=cfg.eval_size, seed=cfg.seed)

loader_num_workers = cfg.num_workers if cfg.num_workers is not None else auto_num_workers(in_colab)
train_loader_kwargs = {
    'dataset': train_ds,
    'batch_size': cfg.batch_size,
    'shuffle': True,
    'num_workers': loader_num_workers,
    'pin_memory': device.type == 'cuda',
}
val_loader_kwargs = {
    'dataset': val_ds,
    'batch_size': 1,
    'shuffle': False,
    'num_workers': loader_num_workers,
    'pin_memory': device.type == 'cuda',
}
if loader_num_workers > 0:
    train_loader_kwargs['prefetch_factor'] = cfg.prefetch_factor
    val_loader_kwargs['prefetch_factor'] = cfg.prefetch_factor

train_loader = DataLoader(**train_loader_kwargs)
val_loader = DataLoader(**val_loader_kwargs)

sample_batch = next(iter(val_loader))
print({
    'validation_input_shape': tuple(sample_batch['lr'].shape),
    'validation_target_shape': tuple(sample_batch['hr'].shape),
    'sample_name': sample_batch['name'][0],
})
# Out:
# {'data_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/Data', 'train_pairs': 2217, 'val_pairs': 110}
# {'validation_input_shape': (1, 3, 256, 256), 'validation_target_shape': (1, 3, 256, 256), 'sample_name': '0000'}

# %% [markdown]
# ## 3. Model and Training

# %%
class TinySRCNNNoAdd(nn.Module):
    def __init__(self, channels: int = 64, slope: float = 0.1):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(3, channels, 3, padding=1),
            nn.LeakyReLU(slope, inplace=False),
            nn.Conv2d(channels, channels, 3, padding=1),
            nn.LeakyReLU(slope, inplace=False),
            nn.Conv2d(channels, channels, 3, padding=1),
            nn.LeakyReLU(slope, inplace=False),
            nn.Conv2d(channels, channels, 3, padding=1),
            nn.LeakyReLU(slope, inplace=False),
            nn.Conv2d(channels, 3, 3, padding=1),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.net(x)


def count_parameters(module: nn.Module) -> int:
    return int(sum(param.numel() for param in module.parameters()))


class EMA:
    def __init__(self, model: nn.Module, decay: float):
        self.decay = decay
        self.shadow = {k: v.detach().clone() for k, v in model.state_dict().items()}

    @torch.no_grad()
    def update(self, model: nn.Module) -> None:
        for key, value in model.state_dict().items():
            self.shadow[key].mul_(self.decay).add_(value.detach(), alpha=1.0 - self.decay)

    @torch.no_grad()
    def copy_to(self, model: nn.Module) -> None:
        model.load_state_dict(self.shadow, strict=True)


def make_grad_scaler(enabled: bool):
    if hasattr(torch, 'amp') and hasattr(torch.amp, 'GradScaler'):
        return torch.amp.GradScaler('cuda', enabled=enabled)
    return torch.cuda.amp.GradScaler(enabled=enabled)


def autocast_context(device_type: str, enabled: bool):
    if not enabled:
        return nullcontext()
    if hasattr(torch, 'amp') and hasattr(torch.amp, 'autocast'):
        return torch.amp.autocast(device_type=device_type, enabled=enabled)
    return torch.cuda.amp.autocast(enabled=enabled)


@torch.no_grad()
def batch_psnr(pred: torch.Tensor, target: torch.Tensor) -> float:
    mse = F.mse_loss(pred, target, reduction='none').mean(dim=(1, 2, 3))
    psnr = 10.0 * torch.log10(1.0 / torch.clamp(mse, min=1e-12))
    return float(psnr.mean().item())


def compute_loss(pred: torch.Tensor, hr: torch.Tensor) -> torch.Tensor:
    loss_mse = F.mse_loss(pred, hr)
    loss_l1 = F.l1_loss(pred, hr)
    return 0.8 * loss_mse + 0.2 * loss_l1


def lr_at_epoch(epoch_idx: int, *, base_lr: float, min_lr: float, warmup_epochs: int, total_epochs: int) -> float:
    step = epoch_idx + 1
    if warmup_epochs > 0 and step <= warmup_epochs:
        return base_lr * step / max(1, warmup_epochs)
    progress = max(0.0, (step - warmup_epochs) / max(1, total_epochs - warmup_epochs))
    cosine = 0.5 * (1.0 + math.cos(math.pi * min(progress, 1.0)))
    return min_lr + cosine * (base_lr - min_lr)


@torch.inference_mode()
def evaluate_psnr(model: nn.Module, loader: DataLoader, device: torch.device) -> float:
    model.eval()
    meter = 0.0
    count = 0
    for batch in loader:
        lr = batch['lr'].to(device, non_blocking=(device.type == 'cuda'))
        hr = batch['hr'].to(device, non_blocking=(device.type == 'cuda'))
        pred = model(lr).clamp(0.0, 1.0)
        meter += batch_psnr(pred, hr)
        count += 1
    return meter / max(count, 1)


@torch.inference_mode()
def compute_input_psnr(loader: DataLoader, device: torch.device) -> float:
    meter = 0.0
    count = 0
    for batch in loader:
        lr = batch['lr'].to(device, non_blocking=(device.type == 'cuda'))
        hr = batch['hr'].to(device, non_blocking=(device.type == 'cuda'))
        meter += batch_psnr(lr, hr)
        count += 1
    return meter / max(count, 1)


def tensor_to_uint8_image(x: torch.Tensor) -> Image.Image:
    x = x.detach().cpu().clamp(0.0, 1.0)
    arr = (x.permute(1, 2, 0).numpy() * 255.0).round().astype(np.uint8)
    return Image.fromarray(arr)


@torch.no_grad()
def write_val_preview(model: nn.Module, loader: DataLoader, out_dir: Path, device: torch.device) -> dict[str, str]:
    out_dir.mkdir(parents=True, exist_ok=True)
    batch = next(iter(loader))
    lr = batch['lr'].to(device, non_blocking=(device.type == 'cuda'))
    hr = batch['hr'].to(device, non_blocking=(device.type == 'cuda'))
    pred = model(lr).clamp(0.0, 1.0)
    name = batch['name'][0]
    lr_path = out_dir / 'val_preview_input.png'
    pred_path = out_dir / 'val_preview_pred.png'
    hr_path = out_dir / 'val_preview_target.png'
    tensor_to_uint8_image(lr[0]).save(lr_path)
    tensor_to_uint8_image(pred[0]).save(pred_path)
    tensor_to_uint8_image(hr[0]).save(hr_path)
    return {
        'sample_name': str(name),
        'input': str(lr_path),
        'prediction': str(pred_path),
        'target': str(hr_path),
    }


def checkpoint_payload(model: nn.Module, ema: EMA | None, optimizer: torch.optim.Optimizer, epoch: int, best_val_psnr: float, row: dict[str, Any]) -> dict[str, Any]:
    return {
        'config': asdict(cfg),
        'epoch': int(epoch),
        'model_state_dict': model.state_dict(),
        'ema_state_dict': ema.shadow if ema is not None else None,
        'optimizer_state_dict': optimizer.state_dict(),
        'best_val_psnr': float(best_val_psnr),
        'selected_weight_source': 'ema' if ema is not None else 'raw',
        'last_metrics': row,
    }


def build_eval_model_from_checkpoint(checkpoint_path: Path, device: torch.device) -> nn.Module:
    checkpoint = torch.load(checkpoint_path, map_location=device)
    model = TinySRCNNNoAdd().to(device)
    selected = checkpoint.get('selected_weight_source', 'raw')
    ema_state = checkpoint.get('ema_state_dict')
    if selected == 'ema' and ema_state is not None:
        model.load_state_dict(ema_state, strict=True)
    else:
        model.load_state_dict(checkpoint['model_state_dict'], strict=True)
    model.eval()
    return model


model = TinySRCNNNoAdd().to(device)
eval_model = TinySRCNNNoAdd().to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)
scaler = make_grad_scaler(enabled=(cfg.use_amp and device.type == 'cuda'))
ema = EMA(model, decay=cfg.ema_decay) if cfg.use_ema else None
start_epoch = 0
best_val_psnr = float('-inf')
if cfg.enable_resume and cfg.resume_checkpoint_path:
    checkpoint = torch.load(cfg.resume_checkpoint_path, map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'], strict=True)
    optimizer_state = checkpoint.get('optimizer_state_dict')
    if optimizer_state is not None:
        optimizer.load_state_dict(optimizer_state)
    ema_state = checkpoint.get('ema_state_dict')
    if ema is not None and ema_state is not None:
        ema.shadow = {key: value.detach().clone() for key, value in ema_state.items()}
    start_epoch = int(checkpoint.get('epoch', 0))
    expected_resume_epoch = 5144
    if start_epoch != expected_resume_epoch:
        raise ValueError(
            f'Expected resume checkpoint at epoch {expected_resume_epoch}, '
            f'but loaded epoch {start_epoch}: {cfg.resume_checkpoint_path}'
        )
    best_val_psnr = float(checkpoint.get('best_val_psnr', float('-inf')))
if ema is not None:
    ema.copy_to(eval_model)
else:
    eval_model.load_state_dict(model.state_dict())

model_parameter_count = count_parameters(model)
print({
    'model_id': cfg.model_id,
    'architecture': 'Conv3x3(3->64) x4 with LeakyReLU, final Conv3x3(64->3), no Add',
    'params': model_parameter_count,
    'resume_checkpoint_path': cfg.resume_checkpoint_path,
    'start_epoch': start_epoch,
})

input_psnr = compute_input_psnr(val_loader, device)
print({'baseline_input_psnr': input_psnr})
# Out:
# {'model_id': 'tinysrcnn_noadd_lrelu', 'architecture': 'Conv3x3(3->64) x4 with LeakyReLU, final Conv3x3(64->3), no Add', 'params': 114307, 'resume_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/083803_2604_base/checkpoints/last.pth', 'start_epoch': 5144}
# {'baseline_input_psnr': 23.133060299266468}

# %%
metrics_header = [
    'epoch',
    'epoch_time_sec',
    'lr',
    'train_loss',
    'train_psnr',
    'val_psnr',
    'best_val_psnr',
]

best_ckpt_path = checkpoints_dir / 'best.pth'
last_ckpt_path = checkpoints_dir / 'last.pth'

with metrics_csv_path.open('w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=metrics_header)
    writer.writeheader()

for epoch in range(start_epoch, cfg.epochs):
    train_ds.set_epoch(epoch)
    epoch_lr = lr_at_epoch(
        epoch,
        base_lr=cfg.lr,
        min_lr=cfg.min_lr,
        warmup_epochs=cfg.warmup_epochs,
        total_epochs=cfg.epochs,
    )
    for group in optimizer.param_groups:
        group['lr'] = epoch_lr

    epoch_start = time.time()
    model.train()
    train_loss_sum = 0.0
    train_psnr_sum = 0.0
    train_batches = 0

    for batch in train_loader:
        lr = batch['lr'].to(device, non_blocking=(device.type == 'cuda'))
        hr = batch['hr'].to(device, non_blocking=(device.type == 'cuda'))

        optimizer.zero_grad(set_to_none=True)
        with autocast_context(device.type, enabled=(cfg.use_amp and device.type == 'cuda')):
            pred = model(lr)
            loss = compute_loss(pred, hr)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        if ema is not None:
            ema.update(model)

        train_loss_sum += float(loss.item())
        train_psnr_sum += batch_psnr(pred.detach().clamp(0.0, 1.0), hr)
        train_batches += 1

    if ema is not None:
        ema.copy_to(eval_model)
    else:
        eval_model.load_state_dict(model.state_dict())
    eval_model.eval()

    avg_train_loss = train_loss_sum / max(train_batches, 1)
    avg_train_psnr = train_psnr_sum / max(train_batches, 1)
    val_psnr = evaluate_psnr(eval_model, val_loader, device)
    epoch_time = time.time() - epoch_start
    is_best = val_psnr > best_val_psnr
    if is_best:
        best_val_psnr = val_psnr

    row = {
        'epoch': epoch + 1,
        'epoch_time_sec': round(epoch_time, 2),
        'lr': epoch_lr,
        'train_loss': round(avg_train_loss, 6),
        'train_psnr': round(avg_train_psnr, 4),
        'val_psnr': round(val_psnr, 4),
        'best_val_psnr': round(best_val_psnr, 4),
    }
    print(row)

    with metrics_csv_path.open('a', newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=metrics_header)
        writer.writerow(row)

    payload = checkpoint_payload(model, ema, optimizer, epoch + 1, best_val_psnr, row)
    torch.save(payload, last_ckpt_path)
    if is_best:
        torch.save(payload, best_ckpt_path)
# Out:
# {'epoch': 5145, 'epoch_time_sec': 1610.58, 'lr': 4.830628858533962e-05, 'train_loss': 0.011844, 'train_psnr': 25.0008, 'val_psnr': 23.872, 'best_val_psnr': 23.8721}
# {'epoch': 5146, 'epoch_time_sec': 12.5, 'lr': 4.8290740650677935e-05, 'train_loss': 0.011828, 'train_psnr': 25.0081, 'val_psnr': 23.872, 'best_val_psnr': 23.8721}
# {'epoch': 5147, 'epoch_time_sec': 12.44, 'lr': 4.827519293441069e-05, 'train_loss': 0.011837, 'train_psnr': 25.0026, 'val_psnr': 23.8719, 'best_val_psnr': 23.8721}
# {'epoch': 5148, 'epoch_time_sec': 12.18, 'lr': 4.825964543807485e-05, 'train_loss': 0.011832, 'train_psnr': 25.0066, 'val_psnr': 23.8719, 'best_val_psnr': 23.8721}
# {'epoch': 5149, 'epoch_time_sec': 12.09, 'lr': 4.824409816320736e-05, 'train_loss': 0.01182, 'train_psnr': 25.0121, 'val_psnr': 23.8719, 'best_val_psnr': 23.8721}
# {'epoch': 5150, 'epoch_time_sec': 12.07, 'lr': 4.8228551111345104e-05, 'train_loss': 0.011834, 'train_psnr': 25.005, 'val_psnr': 23.8717, 'best_val_psnr': 23.8721}
# {'epoch': 5151, 'epoch_time_sec': 12.28, 'lr': 4.821300428402499e-05, 'train_loss': 0.011831, 'train_psnr': 25.0067, 'val_psnr': 23.8718, 'best_val_psnr': 23.8721}
# {'epoch': 5152, 'epoch_time_sec': 12.31, 'lr': 4.819745768278389e-05, 'train_loss': 0.011818, 'train_psnr': 25.0125, 'val_psnr': 23.8717, 'best_val_psnr': 23.8721}
# {'epoch': 5153, 'epoch_time_sec': 12.12, 'lr': 4.8181911309158654e-05, 'train_loss': 0.011831, 'train_psnr': 25.0066, 'val_psnr': 23.8717, 'best_val_psnr': 23.8721}
# {'epoch': 5154, 'epoch_time_sec': 12.06, 'lr': 4.81663651646861e-05, 'train_loss': 0.011834, 'train_psnr': 25.0061, 'val_psnr': 23.8717, 'best_val_psnr': 23.8721}
# {'epoch': 5155, 'epoch_time_sec': 12.15, 'lr': 4.815081925090302e-05, 'train_loss': 0.011833, 'train_psnr': 25.0058, 'val_psnr': 23.8716, 'best_val_psnr': 23.8721}
# {'epoch': 5156, 'epoch_time_sec': 12.27, 'lr': 4.8135273569346185e-05, 'train_loss': 0.011831, 'train_psnr': 25.0066, 'val_psnr': 23.8717, 'best_val_psnr': 23.8721}
# {'epoch': 5157, 'epoch_time_sec': 12.3, 'lr': 4.811972812155237e-05, 'train_loss': 0.011823, 'train_psnr': 25.0112, 'val_psnr': 23.8717, 'best_val_psnr': 23.8721}
# {'epoch': 5158, 'epoch_time_sec': 12.11, 'lr': 4.810418290905832e-05, 'train_loss': 0.011827, 'train_psnr': 25.0096, 'val_psnr': 23.8717, 'best_val_psnr': 23.8721}
# {'epoch': 5159, 'epoch_time_sec': 12.26, 'lr': 4.80886379334007e-05, 'train_loss': 0.011827, 'train_psnr': 25.0093, 'val_psnr': 23.8717, 'best_val_psnr': 23.8721}
# {'epoch': 5160, 'epoch_time_sec': 12.33, 'lr': 4.807309319611622e-05, 'train_loss': 0.01184, 'train_psnr': 25.0047, 'val_psnr': 23.8717, 'best_val_psnr': 23.8721}
# {'epoch': 5161, 'epoch_time_sec': 12.24, 'lr': 4.8057548698741544e-05, 'train_loss': 0.011824, 'train_psnr': 25.0105, 'val_psnr': 23.8716, 'best_val_psnr': 23.8721}
# {'epoch': 5162, 'epoch_time_sec': 12.32, 'lr': 4.8042004442813324e-05, 'train_loss': 0.011819, 'train_psnr': 25.0114, 'val_psnr': 23.8717, 'best_val_psnr': 23.8721}
# {'epoch': 5163, 'epoch_time_sec': 12.59, 'lr': 4.802646042986814e-05, 'train_loss': 0.011835, 'train_psnr': 25.0052, 'val_psnr': 23.8719, 'best_val_psnr': 23.8721}
# {'epoch': 5164, 'epoch_time_sec': 12.6, 'lr': 4.801091666144261e-05, 'train_loss': 0.011817, 'train_psnr': 25.0142, 'val_psnr': 23.8717, 'best_val_psnr': 23.8721}
# {'epoch': 5165, 'epoch_time_sec': 12.32, 'lr': 4.799537313907327e-05, 'train_loss': 0.011827, 'train_psnr': 25.0093, 'val_psnr': 23.8717, 'best_val_psnr': 23.8721}
# {'epoch': 5166, 'epoch_time_sec': 12.24, 'lr': 4.797982986429669e-05, 'train_loss': 0.011842, 'train_psnr': 25.0042, 'val_psnr': 23.8716, 'best_val_psnr': 23.8721}
# {'epoch': 5167, 'epoch_time_sec': 12.18, 'lr': 4.79642868386494e-05, 'train_loss': 0.011838, 'train_psnr': 25.0032, 'val_psnr': 23.8717, 'best_val_psnr': 23.8721}
# {'epoch': 5168, 'epoch_time_sec': 12.13, 'lr': 4.794874406366784e-05, 'train_loss': 0.011823, 'train_psnr': 25.011, 'val_psnr': 23.8716, 'best_val_psnr': 23.8721}
# {'epoch': 5169, 'epoch_time_sec': 12.32, 'lr': 4.7933201540888514e-05, 'train_loss': 0.011819, 'train_psnr': 25.012, 'val_psnr': 23.8718, 'best_val_psnr': 23.8721}
# {'epoch': 5170, 'epoch_time_sec': 12.26, 'lr': 4.791765927184787e-05, 'train_loss': 0.011819, 'train_psnr': 25.0124, 'val_psnr': 23.8718, 'best_val_psnr': 23.8721}
# {'epoch': 5171, 'epoch_time_sec': 12.42, 'lr': 4.7902117258082316e-05, 'train_loss': 0.01183, 'train_psnr': 25.0087, 'val_psnr': 23.8719, 'best_val_psnr': 23.8721}
# {'epoch': 5172, 'epoch_time_sec': 12.15, 'lr': 4.788657550112824e-05, 'train_loss': 0.011825, 'train_psnr': 25.0089, 'val_psnr': 23.8719, 'best_val_psnr': 23.8721}
# {'epoch': 5173, 'epoch_time_sec': 12.03, 'lr': 4.7871034002522e-05, 'train_loss': 0.011829, 'train_psnr': 25.0082, 'val_psnr': 23.8719, 'best_val_psnr': 23.8721}
# {'epoch': 5174, 'epoch_time_sec': 12.23, 'lr': 4.7855492763799954e-05, 'train_loss': 0.011821, 'train_psnr': 25.0114, 'val_psnr': 23.872, 'best_val_psnr': 23.8721}
# {'epoch': 5175, 'epoch_time_sec': 12.59, 'lr': 4.783995178649844e-05, 'train_loss': 0.011825, 'train_psnr': 25.0091, 'val_psnr': 23.8721, 'best_val_psnr': 23.8721}
# {'epoch': 5176, 'epoch_time_sec': 12.24, 'lr': 4.782441107215369e-05, 'train_loss': 0.011817, 'train_psnr': 25.0139, 'val_psnr': 23.8721, 'best_val_psnr': 23.8721}
# {'epoch': 5177, 'epoch_time_sec': 12.32, 'lr': 4.780887062230201e-05, 'train_loss': 0.01183, 'train_psnr': 25.0058, 'val_psnr': 23.8721, 'best_val_psnr': 23.8721}
# {'epoch': 5178, 'epoch_time_sec': 12.33, 'lr': 4.779333043847962e-05, 'train_loss': 0.011827, 'train_psnr': 25.0069, 'val_psnr': 23.8722, 'best_val_psnr': 23.8722}
# {'epoch': 5179, 'epoch_time_sec': 12.01, 'lr': 4.7777790522222756e-05, 'train_loss': 0.011839, 'train_psnr': 25.0024, 'val_psnr': 23.8722, 'best_val_psnr': 23.8722}
# {'epoch': 5180, 'epoch_time_sec': 12.09, 'lr': 4.776225087506758e-05, 'train_loss': 0.011832, 'train_psnr': 25.0056, 'val_psnr': 23.8722, 'best_val_psnr': 23.8722}
# {'epoch': 5181, 'epoch_time_sec': 12.14, 'lr': 4.774671149855026e-05, 'train_loss': 0.011824, 'train_psnr': 25.0092, 'val_psnr': 23.8721, 'best_val_psnr': 23.8722}
# {'epoch': 5182, 'epoch_time_sec': 12.19, 'lr': 4.773117239420692e-05, 'train_loss': 0.011828, 'train_psnr': 25.0084, 'val_psnr': 23.8722, 'best_val_psnr': 23.8722}
# {'epoch': 5183, 'epoch_time_sec': 12.06, 'lr': 4.771563356357366e-05, 'train_loss': 0.011817, 'train_psnr': 25.0127, 'val_psnr': 23.8721, 'best_val_psnr': 23.8722}
# {'epoch': 5184, 'epoch_time_sec': 12.09, 'lr': 4.77000950081866e-05, 'train_loss': 0.011849, 'train_psnr': 25.0007, 'val_psnr': 23.8722, 'best_val_psnr': 23.8722}
# {'epoch': 5185, 'epoch_time_sec': 12.2, 'lr': 4.768455672958173e-05, 'train_loss': 0.011824, 'train_psnr': 25.0119, 'val_psnr': 23.8723, 'best_val_psnr': 23.8723}
# {'epoch': 5186, 'epoch_time_sec': 12.06, 'lr': 4.7669018729295106e-05, 'train_loss': 0.011846, 'train_psnr': 25.0046, 'val_psnr': 23.8724, 'best_val_psnr': 23.8724}
# {'epoch': 5187, 'epoch_time_sec': 12.22, 'lr': 4.765348100886272e-05, 'train_loss': 0.011823, 'train_psnr': 25.0121, 'val_psnr': 23.8723, 'best_val_psnr': 23.8724}
# {'epoch': 5188, 'epoch_time_sec': 12.34, 'lr': 4.763794356982055e-05, 'train_loss': 0.011834, 'train_psnr': 25.0063, 'val_psnr': 23.8723, 'best_val_psnr': 23.8724}
# {'epoch': 5189, 'epoch_time_sec': 12.73, 'lr': 4.7622406413704515e-05, 'train_loss': 0.011842, 'train_psnr': 25.0028, 'val_psnr': 23.8723, 'best_val_psnr': 23.8724}
# {'epoch': 5190, 'epoch_time_sec': 12.84, 'lr': 4.760686954205055e-05, 'train_loss': 0.011853, 'train_psnr': 25.0002, 'val_psnr': 23.8721, 'best_val_psnr': 23.8724}
# {'epoch': 5191, 'epoch_time_sec': 15.07, 'lr': 4.759133295639451e-05, 'train_loss': 0.011831, 'train_psnr': 25.0068, 'val_psnr': 23.8721, 'best_val_psnr': 23.8724}
# {'epoch': 5192, 'epoch_time_sec': 21.84, 'lr': 4.7575796658272294e-05, 'train_loss': 0.011824, 'train_psnr': 25.0095, 'val_psnr': 23.8721, 'best_val_psnr': 23.8724}
# {'epoch': 5193, 'epoch_time_sec': 18.33, 'lr': 4.756026064921968e-05, 'train_loss': 0.011822, 'train_psnr': 25.0101, 'val_psnr': 23.8721, 'best_val_psnr': 23.8724}
# {'epoch': 5194, 'epoch_time_sec': 19.07, 'lr': 4.754472493077249e-05, 'train_loss': 0.011831, 'train_psnr': 25.0075, 'val_psnr': 23.8721, 'best_val_psnr': 23.8724}
# {'epoch': 5195, 'epoch_time_sec': 21.8, 'lr': 4.752918950446649e-05, 'train_loss': 0.01183, 'train_psnr': 25.0084, 'val_psnr': 23.872, 'best_val_psnr': 23.8724}
# {'epoch': 5196, 'epoch_time_sec': 21.14, 'lr': 4.751365437183744e-05, 'train_loss': 0.011831, 'train_psnr': 25.006, 'val_psnr': 23.8722, 'best_val_psnr': 23.8724}
# {'epoch': 5197, 'epoch_time_sec': 21.82, 'lr': 4.749811953442105e-05, 'train_loss': 0.011833, 'train_psnr': 25.0043, 'val_psnr': 23.8722, 'best_val_psnr': 23.8724}
# {'epoch': 5198, 'epoch_time_sec': 21.2, 'lr': 4.7482584993752973e-05, 'train_loss': 0.011825, 'train_psnr': 25.0098, 'val_psnr': 23.8722, 'best_val_psnr': 23.8724}
# {'epoch': 5199, 'epoch_time_sec': 21.8, 'lr': 4.746705075136889e-05, 'train_loss': 0.011825, 'train_psnr': 25.0085, 'val_psnr': 23.8722, 'best_val_psnr': 23.8724}
# {'epoch': 5200, 'epoch_time_sec': 21.21, 'lr': 4.7451516808804414e-05, 'train_loss': 0.011828, 'train_psnr': 25.01, 'val_psnr': 23.8722, 'best_val_psnr': 23.8724}
# {'epoch': 5201, 'epoch_time_sec': 21.86, 'lr': 4.743598316759516e-05, 'train_loss': 0.011827, 'train_psnr': 25.0076, 'val_psnr': 23.8722, 'best_val_psnr': 23.8724}
# {'epoch': 5202, 'epoch_time_sec': 21.1, 'lr': 4.742044982927664e-05, 'train_loss': 0.011822, 'train_psnr': 25.0094, 'val_psnr': 23.8722, 'best_val_psnr': 23.8724}
# {'epoch': 5203, 'epoch_time_sec': 21.82, 'lr': 4.740491679538444e-05, 'train_loss': 0.011828, 'train_psnr': 25.0105, 'val_psnr': 23.8722, 'best_val_psnr': 23.8724}
# {'epoch': 5204, 'epoch_time_sec': 21.2, 'lr': 4.7389384067454045e-05, 'train_loss': 0.011836, 'train_psnr': 25.0013, 'val_psnr': 23.8723, 'best_val_psnr': 23.8724}
# {'epoch': 5205, 'epoch_time_sec': 21.76, 'lr': 4.7373851647020946e-05, 'train_loss': 0.011842, 'train_psnr': 25.002, 'val_psnr': 23.8723, 'best_val_psnr': 23.8724}
# {'epoch': 5206, 'epoch_time_sec': 21.12, 'lr': 4.735831953562056e-05, 'train_loss': 0.011835, 'train_psnr': 25.0029, 'val_psnr': 23.8723, 'best_val_psnr': 23.8724}
# {'epoch': 5207, 'epoch_time_sec': 21.78, 'lr': 4.7342787734788317e-05, 'train_loss': 0.011822, 'train_psnr': 25.0116, 'val_psnr': 23.8723, 'best_val_psnr': 23.8724}
# {'epoch': 5208, 'epoch_time_sec': 21.13, 'lr': 4.7327256246059605e-05, 'train_loss': 0.011818, 'train_psnr': 25.0119, 'val_psnr': 23.8724, 'best_val_psnr': 23.8724}
# {'epoch': 5209, 'epoch_time_sec': 21.8, 'lr': 4.7311725070969765e-05, 'train_loss': 0.011835, 'train_psnr': 25.0057, 'val_psnr': 23.8724, 'best_val_psnr': 23.8724}
# {'epoch': 5210, 'epoch_time_sec': 21.17, 'lr': 4.7296194211054135e-05, 'train_loss': 0.011825, 'train_psnr': 25.0106, 'val_psnr': 23.8722, 'best_val_psnr': 23.8724}
# {'epoch': 5211, 'epoch_time_sec': 21.83, 'lr': 4.7280663667847974e-05, 'train_loss': 0.011814, 'train_psnr': 25.0152, 'val_psnr': 23.8722, 'best_val_psnr': 23.8724}
# {'epoch': 5212, 'epoch_time_sec': 21.16, 'lr': 4.7265133442886565e-05, 'train_loss': 0.011815, 'train_psnr': 25.0151, 'val_psnr': 23.8722, 'best_val_psnr': 23.8724}
# {'epoch': 5213, 'epoch_time_sec': 21.85, 'lr': 4.724960353770512e-05, 'train_loss': 0.011831, 'train_psnr': 25.0057, 'val_psnr': 23.8723, 'best_val_psnr': 23.8724}
# {'epoch': 5214, 'epoch_time_sec': 21.23, 'lr': 4.7234073953838864e-05, 'train_loss': 0.011829, 'train_psnr': 25.0094, 'val_psnr': 23.8724, 'best_val_psnr': 23.8724}
# {'epoch': 5215, 'epoch_time_sec': 21.79, 'lr': 4.7218544692822924e-05, 'train_loss': 0.011827, 'train_psnr': 25.0095, 'val_psnr': 23.8725, 'best_val_psnr': 23.8725}
# {'epoch': 5216, 'epoch_time_sec': 21.22, 'lr': 4.720301575619245e-05, 'train_loss': 0.011829, 'train_psnr': 25.0087, 'val_psnr': 23.8724, 'best_val_psnr': 23.8725}
# {'epoch': 5217, 'epoch_time_sec': 21.8, 'lr': 4.718748714548254e-05, 'train_loss': 0.011834, 'train_psnr': 25.0061, 'val_psnr': 23.8724, 'best_val_psnr': 23.8725}
# {'epoch': 5218, 'epoch_time_sec': 21.16, 'lr': 4.717195886222827e-05, 'train_loss': 0.011824, 'train_psnr': 25.01, 'val_psnr': 23.8725, 'best_val_psnr': 23.8725}
# {'epoch': 5219, 'epoch_time_sec': 21.82, 'lr': 4.7156430907964666e-05, 'train_loss': 0.011827, 'train_psnr': 25.008, 'val_psnr': 23.8725, 'best_val_psnr': 23.8725}
# {'epoch': 5220, 'epoch_time_sec': 21.23, 'lr': 4.714090328422671e-05, 'train_loss': 0.011818, 'train_psnr': 25.0137, 'val_psnr': 23.8726, 'best_val_psnr': 23.8726}
# {'epoch': 5221, 'epoch_time_sec': 21.83, 'lr': 4.7125375992549406e-05, 'train_loss': 0.011823, 'train_psnr': 25.0093, 'val_psnr': 23.8726, 'best_val_psnr': 23.8726}
# {'epoch': 5222, 'epoch_time_sec': 21.18, 'lr': 4.7109849034467676e-05, 'train_loss': 0.011821, 'train_psnr': 25.0114, 'val_psnr': 23.8726, 'best_val_psnr': 23.8726}
# {'epoch': 5223, 'epoch_time_sec': 21.77, 'lr': 4.7094322411516444e-05, 'train_loss': 0.011836, 'train_psnr': 25.0047, 'val_psnr': 23.8726, 'best_val_psnr': 23.8726}
# {'epoch': 5224, 'epoch_time_sec': 21.12, 'lr': 4.7078796125230545e-05, 'train_loss': 0.011815, 'train_psnr': 25.0158, 'val_psnr': 23.8725, 'best_val_psnr': 23.8726}
# {'epoch': 5225, 'epoch_time_sec': 21.77, 'lr': 4.706327017714483e-05, 'train_loss': 0.011832, 'train_psnr': 25.0069, 'val_psnr': 23.8726, 'best_val_psnr': 23.8726}
# {'epoch': 5226, 'epoch_time_sec': 21.08, 'lr': 4.7047744568794124e-05, 'train_loss': 0.011822, 'train_psnr': 25.0104, 'val_psnr': 23.8727, 'best_val_psnr': 23.8727}
# {'epoch': 5227, 'epoch_time_sec': 21.78, 'lr': 4.703221930171318e-05, 'train_loss': 0.01182, 'train_psnr': 25.0118, 'val_psnr': 23.8727, 'best_val_psnr': 23.8727}
# {'epoch': 5228, 'epoch_time_sec': 21.11, 'lr': 4.701669437743674e-05, 'train_loss': 0.011825, 'train_psnr': 25.0098, 'val_psnr': 23.8725, 'best_val_psnr': 23.8727}
# {'epoch': 5229, 'epoch_time_sec': 21.82, 'lr': 4.700116979749949e-05, 'train_loss': 0.011819, 'train_psnr': 25.0117, 'val_psnr': 23.8724, 'best_val_psnr': 23.8727}
# {'epoch': 5230, 'epoch_time_sec': 21.13, 'lr': 4.698564556343612e-05, 'train_loss': 0.011835, 'train_psnr': 25.0081, 'val_psnr': 23.8724, 'best_val_psnr': 23.8727}
# {'epoch': 5231, 'epoch_time_sec': 21.76, 'lr': 4.697012167678127e-05, 'train_loss': 0.011826, 'train_psnr': 25.0103, 'val_psnr': 23.8723, 'best_val_psnr': 23.8727}
# {'epoch': 5232, 'epoch_time_sec': 21.12, 'lr': 4.6954598139069515e-05, 'train_loss': 0.011821, 'train_psnr': 25.0109, 'val_psnr': 23.8723, 'best_val_psnr': 23.8727}
# {'epoch': 5233, 'epoch_time_sec': 21.79, 'lr': 4.6939074951835434e-05, 'train_loss': 0.011817, 'train_psnr': 25.0137, 'val_psnr': 23.8722, 'best_val_psnr': 23.8727}
# {'epoch': 5234, 'epoch_time_sec': 21.2, 'lr': 4.6923552116613575e-05, 'train_loss': 0.011827, 'train_psnr': 25.0089, 'val_psnr': 23.8721, 'best_val_psnr': 23.8727}
# {'epoch': 5235, 'epoch_time_sec': 21.85, 'lr': 4.690802963493841e-05, 'train_loss': 0.011818, 'train_psnr': 25.0118, 'val_psnr': 23.8721, 'best_val_psnr': 23.8727}
# {'epoch': 5236, 'epoch_time_sec': 21.2, 'lr': 4.689250750834441e-05, 'train_loss': 0.011822, 'train_psnr': 25.0118, 'val_psnr': 23.8722, 'best_val_psnr': 23.8727}
# {'epoch': 5237, 'epoch_time_sec': 21.8, 'lr': 4.6876985738366004e-05, 'train_loss': 0.011834, 'train_psnr': 25.0064, 'val_psnr': 23.8723, 'best_val_psnr': 23.8727}
# {'epoch': 5238, 'epoch_time_sec': 21.13, 'lr': 4.686146432653757e-05, 'train_loss': 0.011829, 'train_psnr': 25.0079, 'val_psnr': 23.8724, 'best_val_psnr': 23.8727}
# {'epoch': 5239, 'epoch_time_sec': 21.8, 'lr': 4.684594327439348e-05, 'train_loss': 0.011814, 'train_psnr': 25.0148, 'val_psnr': 23.8724, 'best_val_psnr': 23.8727}
# {'epoch': 5240, 'epoch_time_sec': 21.1, 'lr': 4.683042258346807e-05, 'train_loss': 0.011825, 'train_psnr': 25.0093, 'val_psnr': 23.8723, 'best_val_psnr': 23.8727}
# {'epoch': 5241, 'epoch_time_sec': 21.85, 'lr': 4.681490225529558e-05, 'train_loss': 0.011819, 'train_psnr': 25.0127, 'val_psnr': 23.8723, 'best_val_psnr': 23.8727}
# {'epoch': 5242, 'epoch_time_sec': 21.23, 'lr': 4.679938229141028e-05, 'train_loss': 0.011818, 'train_psnr': 25.0138, 'val_psnr': 23.8723, 'best_val_psnr': 23.8727}
# {'epoch': 5243, 'epoch_time_sec': 21.77, 'lr': 4.67838626933464e-05, 'train_loss': 0.011819, 'train_psnr': 25.0126, 'val_psnr': 23.8725, 'best_val_psnr': 23.8727}
# {'epoch': 5244, 'epoch_time_sec': 21.22, 'lr': 4.67683434626381e-05, 'train_loss': 0.011852, 'train_psnr': 24.9973, 'val_psnr': 23.8725, 'best_val_psnr': 23.8727}
# {'epoch': 5245, 'epoch_time_sec': 21.8, 'lr': 4.675282460081952e-05, 'train_loss': 0.011815, 'train_psnr': 25.0151, 'val_psnr': 23.8725, 'best_val_psnr': 23.8727}
# {'epoch': 5246, 'epoch_time_sec': 21.15, 'lr': 4.6737306109424765e-05, 'train_loss': 0.01182, 'train_psnr': 25.0112, 'val_psnr': 23.8725, 'best_val_psnr': 23.8727}
# {'epoch': 5247, 'epoch_time_sec': 21.86, 'lr': 4.672178798998789e-05, 'train_loss': 0.011828, 'train_psnr': 25.0092, 'val_psnr': 23.8725, 'best_val_psnr': 23.8727}
# {'epoch': 5248, 'epoch_time_sec': 21.12, 'lr': 4.670627024404295e-05, 'train_loss': 0.011837, 'train_psnr': 25.0051, 'val_psnr': 23.8724, 'best_val_psnr': 23.8727}
# {'epoch': 5249, 'epoch_time_sec': 21.78, 'lr': 4.669075287312394e-05, 'train_loss': 0.011834, 'train_psnr': 25.0044, 'val_psnr': 23.8724, 'best_val_psnr': 23.8727}
# {'epoch': 5250, 'epoch_time_sec': 21.2, 'lr': 4.6675235878764786e-05, 'train_loss': 0.011827, 'train_psnr': 25.0099, 'val_psnr': 23.8724, 'best_val_psnr': 23.8727}
# {'epoch': 5251, 'epoch_time_sec': 21.8, 'lr': 4.665971926249943e-05, 'train_loss': 0.011832, 'train_psnr': 25.0067, 'val_psnr': 23.8724, 'best_val_psnr': 23.8727}
# {'epoch': 5252, 'epoch_time_sec': 21.14, 'lr': 4.664420302586176e-05, 'train_loss': 0.011824, 'train_psnr': 25.0102, 'val_psnr': 23.8724, 'best_val_psnr': 23.8727}
# {'epoch': 5253, 'epoch_time_sec': 21.81, 'lr': 4.66286871703856e-05, 'train_loss': 0.011826, 'train_psnr': 25.0079, 'val_psnr': 23.8725, 'best_val_psnr': 23.8727}
# {'epoch': 5254, 'epoch_time_sec': 21.11, 'lr': 4.6613171697604765e-05, 'train_loss': 0.011831, 'train_psnr': 25.0075, 'val_psnr': 23.8725, 'best_val_psnr': 23.8727}
# {'epoch': 5255, 'epoch_time_sec': 21.81, 'lr': 4.659765660905302e-05, 'train_loss': 0.011841, 'train_psnr': 25.0015, 'val_psnr': 23.8725, 'best_val_psnr': 23.8727}
# {'epoch': 5256, 'epoch_time_sec': 21.13, 'lr': 4.65821419062641e-05, 'train_loss': 0.01182, 'train_psnr': 25.0114, 'val_psnr': 23.8726, 'best_val_psnr': 23.8727}
# {'epoch': 5257, 'epoch_time_sec': 21.88, 'lr': 4.6566627590771724e-05, 'train_loss': 0.011825, 'train_psnr': 25.0085, 'val_psnr': 23.8726, 'best_val_psnr': 23.8727}
# {'epoch': 5258, 'epoch_time_sec': 21.2, 'lr': 4.655111366410949e-05, 'train_loss': 0.011828, 'train_psnr': 25.0103, 'val_psnr': 23.8727, 'best_val_psnr': 23.8727}
# {'epoch': 5259, 'epoch_time_sec': 21.79, 'lr': 4.6535600127811047e-05, 'train_loss': 0.011827, 'train_psnr': 25.0083, 'val_psnr': 23.8727, 'best_val_psnr': 23.8727}
# {'epoch': 5260, 'epoch_time_sec': 21.22, 'lr': 4.652008698340997e-05, 'train_loss': 0.011822, 'train_psnr': 25.0133, 'val_psnr': 23.8728, 'best_val_psnr': 23.8728}
# {'epoch': 5261, 'epoch_time_sec': 21.84, 'lr': 4.650457423243981e-05, 'train_loss': 0.011838, 'train_psnr': 25.0028, 'val_psnr': 23.8729, 'best_val_psnr': 23.8729}
# {'epoch': 5262, 'epoch_time_sec': 21.08, 'lr': 4.648906187643406e-05, 'train_loss': 0.011839, 'train_psnr': 25.0028, 'val_psnr': 23.8729, 'best_val_psnr': 23.8729}
# {'epoch': 5263, 'epoch_time_sec': 21.86, 'lr': 4.647354991692617e-05, 'train_loss': 0.011822, 'train_psnr': 25.011, 'val_psnr': 23.8729, 'best_val_psnr': 23.8729}
# {'epoch': 5264, 'epoch_time_sec': 21.16, 'lr': 4.6458038355449555e-05, 'train_loss': 0.01181, 'train_psnr': 25.0184, 'val_psnr': 23.8729, 'best_val_psnr': 23.8729}
# {'epoch': 5265, 'epoch_time_sec': 21.79, 'lr': 4.644252719353761e-05, 'train_loss': 0.011826, 'train_psnr': 25.0108, 'val_psnr': 23.873, 'best_val_psnr': 23.873}
# {'epoch': 5266, 'epoch_time_sec': 21.14, 'lr': 4.64270164327237e-05, 'train_loss': 0.01182, 'train_psnr': 25.0107, 'val_psnr': 23.873, 'best_val_psnr': 23.873}
# {'epoch': 5267, 'epoch_time_sec': 21.76, 'lr': 4.641150607454108e-05, 'train_loss': 0.011828, 'train_psnr': 25.0078, 'val_psnr': 23.873, 'best_val_psnr': 23.873}
# {'epoch': 5268, 'epoch_time_sec': 21.19, 'lr': 4.6395996120523034e-05, 'train_loss': 0.011835, 'train_psnr': 25.0045, 'val_psnr': 23.873, 'best_val_psnr': 23.873}
# {'epoch': 5269, 'epoch_time_sec': 21.76, 'lr': 4.63804865722028e-05, 'train_loss': 0.011821, 'train_psnr': 25.0116, 'val_psnr': 23.8731, 'best_val_psnr': 23.8731}
# {'epoch': 5270, 'epoch_time_sec': 21.23, 'lr': 4.6364977431113564e-05, 'train_loss': 0.011826, 'train_psnr': 25.0089, 'val_psnr': 23.8731, 'best_val_psnr': 23.8731}
# {'epoch': 5271, 'epoch_time_sec': 21.76, 'lr': 4.634946869878843e-05, 'train_loss': 0.011821, 'train_psnr': 25.0114, 'val_psnr': 23.8731, 'best_val_psnr': 23.8731}
# {'epoch': 5272, 'epoch_time_sec': 21.22, 'lr': 4.6333960376760544e-05, 'train_loss': 0.011827, 'train_psnr': 25.0088, 'val_psnr': 23.8732, 'best_val_psnr': 23.8732}
# {'epoch': 5273, 'epoch_time_sec': 21.78, 'lr': 4.631845246656294e-05, 'train_loss': 0.011833, 'train_psnr': 25.006, 'val_psnr': 23.8731, 'best_val_psnr': 23.8732}
# {'epoch': 5274, 'epoch_time_sec': 21.2, 'lr': 4.630294496972864e-05, 'train_loss': 0.011822, 'train_psnr': 25.0111, 'val_psnr': 23.8731, 'best_val_psnr': 23.8732}
# {'epoch': 5275, 'epoch_time_sec': 21.84, 'lr': 4.6287437887790656e-05, 'train_loss': 0.011828, 'train_psnr': 25.0084, 'val_psnr': 23.8732, 'best_val_psnr': 23.8732}
# {'epoch': 5276, 'epoch_time_sec': 21.26, 'lr': 4.627193122228189e-05, 'train_loss': 0.011845, 'train_psnr': 25.002, 'val_psnr': 23.8731, 'best_val_psnr': 23.8732}
# {'epoch': 5277, 'epoch_time_sec': 21.78, 'lr': 4.625642497473525e-05, 'train_loss': 0.011819, 'train_psnr': 25.0122, 'val_psnr': 23.873, 'best_val_psnr': 23.8732}
# {'epoch': 5278, 'epoch_time_sec': 21.2, 'lr': 4.62409191466836e-05, 'train_loss': 0.011821, 'train_psnr': 25.0119, 'val_psnr': 23.873, 'best_val_psnr': 23.8732}
# {'epoch': 5279, 'epoch_time_sec': 21.81, 'lr': 4.622541373965977e-05, 'train_loss': 0.011813, 'train_psnr': 25.0168, 'val_psnr': 23.8731, 'best_val_psnr': 23.8732}
# {'epoch': 5280, 'epoch_time_sec': 21.11, 'lr': 4.6209908755196505e-05, 'train_loss': 0.011821, 'train_psnr': 25.0118, 'val_psnr': 23.8732, 'best_val_psnr': 23.8732}
# {'epoch': 5281, 'epoch_time_sec': 21.83, 'lr': 4.6194404194826547e-05, 'train_loss': 0.011831, 'train_psnr': 25.0094, 'val_psnr': 23.8733, 'best_val_psnr': 23.8733}
# {'epoch': 5282, 'epoch_time_sec': 21.11, 'lr': 4.617890006008258e-05, 'train_loss': 0.01183, 'train_psnr': 25.0061, 'val_psnr': 23.8734, 'best_val_psnr': 23.8734}
# {'epoch': 5283, 'epoch_time_sec': 21.85, 'lr': 4.616339635249728e-05, 'train_loss': 0.011835, 'train_psnr': 25.0039, 'val_psnr': 23.8734, 'best_val_psnr': 23.8734}
# {'epoch': 5284, 'epoch_time_sec': 21.13, 'lr': 4.614789307360322e-05, 'train_loss': 0.011857, 'train_psnr': 25.0009, 'val_psnr': 23.8735, 'best_val_psnr': 23.8735}
# {'epoch': 5285, 'epoch_time_sec': 21.78, 'lr': 4.613239022493297e-05, 'train_loss': 0.011825, 'train_psnr': 25.0097, 'val_psnr': 23.8733, 'best_val_psnr': 23.8735}
# {'epoch': 5286, 'epoch_time_sec': 21.13, 'lr': 4.611688780801906e-05, 'train_loss': 0.011821, 'train_psnr': 25.0104, 'val_psnr': 23.8733, 'best_val_psnr': 23.8735}
# {'epoch': 5287, 'epoch_time_sec': 21.82, 'lr': 4.610138582439396e-05, 'train_loss': 0.011821, 'train_psnr': 25.0118, 'val_psnr': 23.8733, 'best_val_psnr': 23.8735}
# {'epoch': 5288, 'epoch_time_sec': 21.15, 'lr': 4.608588427559014e-05, 'train_loss': 0.011837, 'train_psnr': 25.0047, 'val_psnr': 23.8733, 'best_val_psnr': 23.8735}
# {'epoch': 5289, 'epoch_time_sec': 21.85, 'lr': 4.6070383163139933e-05, 'train_loss': 0.01183, 'train_psnr': 25.007, 'val_psnr': 23.8733, 'best_val_psnr': 23.8735}
# {'epoch': 5290, 'epoch_time_sec': 21.12, 'lr': 4.605488248857573e-05, 'train_loss': 0.011832, 'train_psnr': 25.0053, 'val_psnr': 23.8733, 'best_val_psnr': 23.8735}
# {'epoch': 5291, 'epoch_time_sec': 21.85, 'lr': 4.6039382253429814e-05, 'train_loss': 0.011829, 'train_psnr': 25.0084, 'val_psnr': 23.8734, 'best_val_psnr': 23.8735}
# {'epoch': 5292, 'epoch_time_sec': 21.17, 'lr': 4.6023882459234487e-05, 'train_loss': 0.011827, 'train_psnr': 25.0095, 'val_psnr': 23.8733, 'best_val_psnr': 23.8735}
# {'epoch': 5293, 'epoch_time_sec': 21.79, 'lr': 4.6008383107521907e-05, 'train_loss': 0.011823, 'train_psnr': 25.0121, 'val_psnr': 23.8733, 'best_val_psnr': 23.8735}
# {'epoch': 5294, 'epoch_time_sec': 21.06, 'lr': 4.599288419982429e-05, 'train_loss': 0.011825, 'train_psnr': 25.0102, 'val_psnr': 23.8733, 'best_val_psnr': 23.8735}
# {'epoch': 5295, 'epoch_time_sec': 21.76, 'lr': 4.5977385737673754e-05, 'train_loss': 0.011836, 'train_psnr': 25.0039, 'val_psnr': 23.8732, 'best_val_psnr': 23.8735}
# {'epoch': 5296, 'epoch_time_sec': 21.16, 'lr': 4.596188772260242e-05, 'train_loss': 0.011829, 'train_psnr': 25.0084, 'val_psnr': 23.8734, 'best_val_psnr': 23.8735}
# {'epoch': 5297, 'epoch_time_sec': 21.81, 'lr': 4.5946390156142274e-05, 'train_loss': 0.011815, 'train_psnr': 25.0153, 'val_psnr': 23.8735, 'best_val_psnr': 23.8735}
# {'epoch': 5298, 'epoch_time_sec': 21.14, 'lr': 4.5930893039825346e-05, 'train_loss': 0.011822, 'train_psnr': 25.0104, 'val_psnr': 23.8734, 'best_val_psnr': 23.8735}
# {'epoch': 5299, 'epoch_time_sec': 21.82, 'lr': 4.5915396375183595e-05, 'train_loss': 0.011825, 'train_psnr': 25.0091, 'val_psnr': 23.8736, 'best_val_psnr': 23.8736}
# {'epoch': 5300, 'epoch_time_sec': 21.16, 'lr': 4.589990016374891e-05, 'train_loss': 0.011818, 'train_psnr': 25.0131, 'val_psnr': 23.8735, 'best_val_psnr': 23.8736}
# {'epoch': 5301, 'epoch_time_sec': 21.85, 'lr': 4.58844044070532e-05, 'train_loss': 0.011842, 'train_psnr': 25.0043, 'val_psnr': 23.8736, 'best_val_psnr': 23.8736}
# {'epoch': 5302, 'epoch_time_sec': 21.21, 'lr': 4.5868909106628216e-05, 'train_loss': 0.01182, 'train_psnr': 25.012, 'val_psnr': 23.8736, 'best_val_psnr': 23.8736}
# {'epoch': 5303, 'epoch_time_sec': 21.85, 'lr': 4.5853414264005786e-05, 'train_loss': 0.011823, 'train_psnr': 25.0105, 'val_psnr': 23.8735, 'best_val_psnr': 23.8736}
# {'epoch': 5304, 'epoch_time_sec': 21.15, 'lr': 4.5837919880717614e-05, 'train_loss': 0.011829, 'train_psnr': 25.0066, 'val_psnr': 23.8736, 'best_val_psnr': 23.8736}
# {'epoch': 5305, 'epoch_time_sec': 21.79, 'lr': 4.582242595829541e-05, 'train_loss': 0.011844, 'train_psnr': 25.0037, 'val_psnr': 23.8735, 'best_val_psnr': 23.8736}
# {'epoch': 5306, 'epoch_time_sec': 21.19, 'lr': 4.580693249827078e-05, 'train_loss': 0.011823, 'train_psnr': 25.0109, 'val_psnr': 23.8735, 'best_val_psnr': 23.8736}
# {'epoch': 5307, 'epoch_time_sec': 21.79, 'lr': 4.579143950217535e-05, 'train_loss': 0.011827, 'train_psnr': 25.0104, 'val_psnr': 23.8734, 'best_val_psnr': 23.8736}
# {'epoch': 5308, 'epoch_time_sec': 21.13, 'lr': 4.577594697154064e-05, 'train_loss': 0.011824, 'train_psnr': 25.0103, 'val_psnr': 23.8734, 'best_val_psnr': 23.8736}
# {'epoch': 5309, 'epoch_time_sec': 21.82, 'lr': 4.576045490789817e-05, 'train_loss': 0.011832, 'train_psnr': 25.0054, 'val_psnr': 23.8734, 'best_val_psnr': 23.8736}
# {'epoch': 5310, 'epoch_time_sec': 21.16, 'lr': 4.574496331277937e-05, 'train_loss': 0.011814, 'train_psnr': 25.0153, 'val_psnr': 23.8734, 'best_val_psnr': 23.8736}
# {'epoch': 5311, 'epoch_time_sec': 21.84, 'lr': 4.572947218771567e-05, 'train_loss': 0.011824, 'train_psnr': 25.0102, 'val_psnr': 23.8735, 'best_val_psnr': 23.8736}
# {'epoch': 5312, 'epoch_time_sec': 21.14, 'lr': 4.571398153423841e-05, 'train_loss': 0.011832, 'train_psnr': 25.0074, 'val_psnr': 23.8735, 'best_val_psnr': 23.8736}
# {'epoch': 5313, 'epoch_time_sec': 21.81, 'lr': 4.569849135387893e-05, 'train_loss': 0.011818, 'train_psnr': 25.0131, 'val_psnr': 23.8735, 'best_val_psnr': 23.8736}
# {'epoch': 5314, 'epoch_time_sec': 21.16, 'lr': 4.568300164816851e-05, 'train_loss': 0.011826, 'train_psnr': 25.0112, 'val_psnr': 23.8735, 'best_val_psnr': 23.8736}
# {'epoch': 5315, 'epoch_time_sec': 21.81, 'lr': 4.566751241863833e-05, 'train_loss': 0.011831, 'train_psnr': 25.0066, 'val_psnr': 23.8735, 'best_val_psnr': 23.8736}
# {'epoch': 5316, 'epoch_time_sec': 21.23, 'lr': 4.56520236668196e-05, 'train_loss': 0.011817, 'train_psnr': 25.0135, 'val_psnr': 23.8735, 'best_val_psnr': 23.8736}
# {'epoch': 5317, 'epoch_time_sec': 21.82, 'lr': 4.563653539424342e-05, 'train_loss': 0.011818, 'train_psnr': 25.0144, 'val_psnr': 23.8736, 'best_val_psnr': 23.8736}
# {'epoch': 5318, 'epoch_time_sec': 21.17, 'lr': 4.56210476024409e-05, 'train_loss': 0.011819, 'train_psnr': 25.0113, 'val_psnr': 23.8736, 'best_val_psnr': 23.8736}
# {'epoch': 5319, 'epoch_time_sec': 21.78, 'lr': 4.560556029294304e-05, 'train_loss': 0.011824, 'train_psnr': 25.0111, 'val_psnr': 23.8736, 'best_val_psnr': 23.8736}
# {'epoch': 5320, 'epoch_time_sec': 21.15, 'lr': 4.559007346728083e-05, 'train_loss': 0.011819, 'train_psnr': 25.0129, 'val_psnr': 23.8736, 'best_val_psnr': 23.8736}
# {'epoch': 5321, 'epoch_time_sec': 21.79, 'lr': 4.557458712698523e-05, 'train_loss': 0.011823, 'train_psnr': 25.0112, 'val_psnr': 23.8736, 'best_val_psnr': 23.8736}
# {'epoch': 5322, 'epoch_time_sec': 21.16, 'lr': 4.5559101273587134e-05, 'train_loss': 0.011823, 'train_psnr': 25.0106, 'val_psnr': 23.8738, 'best_val_psnr': 23.8738}
# {'epoch': 5323, 'epoch_time_sec': 21.85, 'lr': 4.554361590861734e-05, 'train_loss': 0.01183, 'train_psnr': 25.0098, 'val_psnr': 23.8738, 'best_val_psnr': 23.8738}
# {'epoch': 5324, 'epoch_time_sec': 21.12, 'lr': 4.552813103360666e-05, 'train_loss': 0.01183, 'train_psnr': 25.0049, 'val_psnr': 23.8737, 'best_val_psnr': 23.8738}
# {'epoch': 5325, 'epoch_time_sec': 21.88, 'lr': 4.551264665008586e-05, 'train_loss': 0.011833, 'train_psnr': 25.0073, 'val_psnr': 23.8737, 'best_val_psnr': 23.8738}
# {'epoch': 5326, 'epoch_time_sec': 21.17, 'lr': 4.549716275958562e-05, 'train_loss': 0.011822, 'train_psnr': 25.0101, 'val_psnr': 23.8738, 'best_val_psnr': 23.8738}
# {'epoch': 5327, 'epoch_time_sec': 21.78, 'lr': 4.548167936363659e-05, 'train_loss': 0.011823, 'train_psnr': 25.0117, 'val_psnr': 23.8737, 'best_val_psnr': 23.8738}
# {'epoch': 5328, 'epoch_time_sec': 21.29, 'lr': 4.5466196463769354e-05, 'train_loss': 0.011822, 'train_psnr': 25.0111, 'val_psnr': 23.8737, 'best_val_psnr': 23.8738}
# {'epoch': 5329, 'epoch_time_sec': 21.77, 'lr': 4.545071406151446e-05, 'train_loss': 0.011815, 'train_psnr': 25.0145, 'val_psnr': 23.8738, 'best_val_psnr': 23.8738}
# {'epoch': 5330, 'epoch_time_sec': 21.21, 'lr': 4.543523215840242e-05, 'train_loss': 0.011815, 'train_psnr': 25.0148, 'val_psnr': 23.8738, 'best_val_psnr': 23.8738}
# {'epoch': 5331, 'epoch_time_sec': 21.83, 'lr': 4.541975075596371e-05, 'train_loss': 0.011837, 'train_psnr': 25.0038, 'val_psnr': 23.8737, 'best_val_psnr': 23.8738}
# {'epoch': 5332, 'epoch_time_sec': 21.14, 'lr': 4.540426985572868e-05, 'train_loss': 0.011837, 'train_psnr': 25.0036, 'val_psnr': 23.8737, 'best_val_psnr': 23.8738}
# {'epoch': 5333, 'epoch_time_sec': 21.78, 'lr': 4.5388789459227706e-05, 'train_loss': 0.011824, 'train_psnr': 25.0113, 'val_psnr': 23.8737, 'best_val_psnr': 23.8738}
# {'epoch': 5334, 'epoch_time_sec': 21.12, 'lr': 4.5373309567991095e-05, 'train_loss': 0.01183, 'train_psnr': 25.0085, 'val_psnr': 23.8737, 'best_val_psnr': 23.8738}
# {'epoch': 5335, 'epoch_time_sec': 21.78, 'lr': 4.535783018354909e-05, 'train_loss': 0.011823, 'train_psnr': 25.0113, 'val_psnr': 23.8737, 'best_val_psnr': 23.8738}
# {'epoch': 5336, 'epoch_time_sec': 21.16, 'lr': 4.5342351307431896e-05, 'train_loss': 0.011818, 'train_psnr': 25.0142, 'val_psnr': 23.8737, 'best_val_psnr': 23.8738}
# {'epoch': 5337, 'epoch_time_sec': 21.83, 'lr': 4.532687294116965e-05, 'train_loss': 0.011822, 'train_psnr': 25.0126, 'val_psnr': 23.8736, 'best_val_psnr': 23.8738}
# {'epoch': 5338, 'epoch_time_sec': 21.19, 'lr': 4.531139508629247e-05, 'train_loss': 0.011818, 'train_psnr': 25.0155, 'val_psnr': 23.8737, 'best_val_psnr': 23.8738}
# {'epoch': 5339, 'epoch_time_sec': 21.78, 'lr': 4.529591774433042e-05, 'train_loss': 0.011827, 'train_psnr': 25.0086, 'val_psnr': 23.8737, 'best_val_psnr': 23.8738}
# {'epoch': 5340, 'epoch_time_sec': 21.21, 'lr': 4.5280440916813457e-05, 'train_loss': 0.011814, 'train_psnr': 25.0148, 'val_psnr': 23.8737, 'best_val_psnr': 23.8738}
# {'epoch': 5341, 'epoch_time_sec': 21.85, 'lr': 4.5264964605271546e-05, 'train_loss': 0.011825, 'train_psnr': 25.0087, 'val_psnr': 23.8737, 'best_val_psnr': 23.8738}
# {'epoch': 5342, 'epoch_time_sec': 21.21, 'lr': 4.52494888112346e-05, 'train_loss': 0.011828, 'train_psnr': 25.0074, 'val_psnr': 23.8738, 'best_val_psnr': 23.8738}
# {'epoch': 5343, 'epoch_time_sec': 21.82, 'lr': 4.5234013536232466e-05, 'train_loss': 0.01182, 'train_psnr': 25.0126, 'val_psnr': 23.8738, 'best_val_psnr': 23.8738}
# {'epoch': 5344, 'epoch_time_sec': 21.19, 'lr': 4.521853878179493e-05, 'train_loss': 0.011835, 'train_psnr': 25.0076, 'val_psnr': 23.8739, 'best_val_psnr': 23.8739}
# {'epoch': 5345, 'epoch_time_sec': 21.85, 'lr': 4.520306454945173e-05, 'train_loss': 0.011821, 'train_psnr': 25.0112, 'val_psnr': 23.8739, 'best_val_psnr': 23.8739}
# {'epoch': 5346, 'epoch_time_sec': 21.19, 'lr': 4.518759084073256e-05, 'train_loss': 0.011831, 'train_psnr': 25.0064, 'val_psnr': 23.874, 'best_val_psnr': 23.874}
# {'epoch': 5347, 'epoch_time_sec': 21.83, 'lr': 4.517211765716706e-05, 'train_loss': 0.011809, 'train_psnr': 25.0205, 'val_psnr': 23.874, 'best_val_psnr': 23.874}
# {'epoch': 5348, 'epoch_time_sec': 21.17, 'lr': 4.5156645000284844e-05, 'train_loss': 0.011829, 'train_psnr': 25.0083, 'val_psnr': 23.874, 'best_val_psnr': 23.874}
# {'epoch': 5349, 'epoch_time_sec': 21.81, 'lr': 4.51411728716154e-05, 'train_loss': 0.011841, 'train_psnr': 25.0055, 'val_psnr': 23.874, 'best_val_psnr': 23.874}
# {'epoch': 5350, 'epoch_time_sec': 21.12, 'lr': 4.512570127268825e-05, 'train_loss': 0.011829, 'train_psnr': 25.0088, 'val_psnr': 23.874, 'best_val_psnr': 23.874}
# {'epoch': 5351, 'epoch_time_sec': 21.84, 'lr': 4.51102302050328e-05, 'train_loss': 0.011826, 'train_psnr': 25.0096, 'val_psnr': 23.874, 'best_val_psnr': 23.874}
# {'epoch': 5352, 'epoch_time_sec': 21.17, 'lr': 4.5094759670178473e-05, 'train_loss': 0.011832, 'train_psnr': 25.0055, 'val_psnr': 23.874, 'best_val_psnr': 23.874}
# {'epoch': 5353, 'epoch_time_sec': 21.82, 'lr': 4.507928966965454e-05, 'train_loss': 0.011823, 'train_psnr': 25.0089, 'val_psnr': 23.8741, 'best_val_psnr': 23.8741}
# {'epoch': 5354, 'epoch_time_sec': 21.11, 'lr': 4.506382020499032e-05, 'train_loss': 0.01182, 'train_psnr': 25.0138, 'val_psnr': 23.8741, 'best_val_psnr': 23.8741}
# {'epoch': 5355, 'epoch_time_sec': 21.79, 'lr': 4.5048351277715e-05, 'train_loss': 0.011841, 'train_psnr': 25.0035, 'val_psnr': 23.8741, 'best_val_psnr': 23.8741}
# {'epoch': 5356, 'epoch_time_sec': 21.2, 'lr': 4.503288288935775e-05, 'train_loss': 0.01182, 'train_psnr': 25.0111, 'val_psnr': 23.8741, 'best_val_psnr': 23.8741}
# {'epoch': 5357, 'epoch_time_sec': 21.83, 'lr': 4.5017415041447736e-05, 'train_loss': 0.011815, 'train_psnr': 25.0162, 'val_psnr': 23.8742, 'best_val_psnr': 23.8742}
# {'epoch': 5358, 'epoch_time_sec': 21.13, 'lr': 4.500194773551395e-05, 'train_loss': 0.011822, 'train_psnr': 25.0099, 'val_psnr': 23.8741, 'best_val_psnr': 23.8742}
# {'epoch': 5359, 'epoch_time_sec': 21.81, 'lr': 4.498648097308542e-05, 'train_loss': 0.011829, 'train_psnr': 25.009, 'val_psnr': 23.8742, 'best_val_psnr': 23.8742}
# {'epoch': 5360, 'epoch_time_sec': 21.15, 'lr': 4.4971014755691115e-05, 'train_loss': 0.011821, 'train_psnr': 25.0151, 'val_psnr': 23.8741, 'best_val_psnr': 23.8742}
# {'epoch': 5361, 'epoch_time_sec': 21.79, 'lr': 4.495554908485995e-05, 'train_loss': 0.011819, 'train_psnr': 25.0129, 'val_psnr': 23.8742, 'best_val_psnr': 23.8742}
# {'epoch': 5362, 'epoch_time_sec': 21.19, 'lr': 4.4940083962120724e-05, 'train_loss': 0.011839, 'train_psnr': 25.0044, 'val_psnr': 23.8742, 'best_val_psnr': 23.8742}
# {'epoch': 5363, 'epoch_time_sec': 21.8, 'lr': 4.4924619389002265e-05, 'train_loss': 0.011823, 'train_psnr': 25.0115, 'val_psnr': 23.8742, 'best_val_psnr': 23.8742}
# {'epoch': 5364, 'epoch_time_sec': 21.25, 'lr': 4.490915536703329e-05, 'train_loss': 0.011823, 'train_psnr': 25.0125, 'val_psnr': 23.8743, 'best_val_psnr': 23.8743}
# {'epoch': 5365, 'epoch_time_sec': 21.85, 'lr': 4.489369189774251e-05, 'train_loss': 0.011817, 'train_psnr': 25.0135, 'val_psnr': 23.8743, 'best_val_psnr': 23.8743}
# {'epoch': 5366, 'epoch_time_sec': 21.18, 'lr': 4.487822898265851e-05, 'train_loss': 0.011827, 'train_psnr': 25.0089, 'val_psnr': 23.8743, 'best_val_psnr': 23.8743}
# {'epoch': 5367, 'epoch_time_sec': 21.85, 'lr': 4.486276662330988e-05, 'train_loss': 0.011816, 'train_psnr': 25.0137, 'val_psnr': 23.8744, 'best_val_psnr': 23.8744}
# {'epoch': 5368, 'epoch_time_sec': 21.17, 'lr': 4.484730482122516e-05, 'train_loss': 0.011829, 'train_psnr': 25.0096, 'val_psnr': 23.8744, 'best_val_psnr': 23.8744}
# {'epoch': 5369, 'epoch_time_sec': 21.84, 'lr': 4.48318435779328e-05, 'train_loss': 0.011826, 'train_psnr': 25.0107, 'val_psnr': 23.8745, 'best_val_psnr': 23.8745}
# {'epoch': 5370, 'epoch_time_sec': 21.26, 'lr': 4.4816382894961206e-05, 'train_loss': 0.011828, 'train_psnr': 25.008, 'val_psnr': 23.8744, 'best_val_psnr': 23.8745}
# {'epoch': 5371, 'epoch_time_sec': 21.85, 'lr': 4.480092277383873e-05, 'train_loss': 0.011819, 'train_psnr': 25.0132, 'val_psnr': 23.8746, 'best_val_psnr': 23.8746}
# {'epoch': 5372, 'epoch_time_sec': 21.15, 'lr': 4.4785463216093655e-05, 'train_loss': 0.011836, 'train_psnr': 25.0049, 'val_psnr': 23.8746, 'best_val_psnr': 23.8746}
# {'epoch': 5373, 'epoch_time_sec': 21.78, 'lr': 4.477000422325424e-05, 'train_loss': 0.01181, 'train_psnr': 25.0167, 'val_psnr': 23.8745, 'best_val_psnr': 23.8746}
# {'epoch': 5374, 'epoch_time_sec': 21.18, 'lr': 4.475454579684869e-05, 'train_loss': 0.011818, 'train_psnr': 25.015, 'val_psnr': 23.8746, 'best_val_psnr': 23.8746}
# {'epoch': 5375, 'epoch_time_sec': 21.8, 'lr': 4.473908793840509e-05, 'train_loss': 0.011813, 'train_psnr': 25.0156, 'val_psnr': 23.8745, 'best_val_psnr': 23.8746}
# {'epoch': 5376, 'epoch_time_sec': 21.17, 'lr': 4.472363064945153e-05, 'train_loss': 0.011826, 'train_psnr': 25.0095, 'val_psnr': 23.8746, 'best_val_psnr': 23.8746}
# {'epoch': 5377, 'epoch_time_sec': 21.84, 'lr': 4.470817393151604e-05, 'train_loss': 0.011832, 'train_psnr': 25.0065, 'val_psnr': 23.8744, 'best_val_psnr': 23.8746}
# {'epoch': 5378, 'epoch_time_sec': 21.13, 'lr': 4.4692717786126596e-05, 'train_loss': 0.011829, 'train_psnr': 25.0082, 'val_psnr': 23.8745, 'best_val_psnr': 23.8746}
# {'epoch': 5379, 'epoch_time_sec': 21.8, 'lr': 4.467726221481105e-05, 'train_loss': 0.011819, 'train_psnr': 25.0135, 'val_psnr': 23.8745, 'best_val_psnr': 23.8746}
# {'epoch': 5380, 'epoch_time_sec': 21.22, 'lr': 4.4661807219097295e-05, 'train_loss': 0.011823, 'train_psnr': 25.0123, 'val_psnr': 23.8746, 'best_val_psnr': 23.8746}
# {'epoch': 5381, 'epoch_time_sec': 21.82, 'lr': 4.464635280051309e-05, 'train_loss': 0.011821, 'train_psnr': 25.0117, 'val_psnr': 23.8748, 'best_val_psnr': 23.8748}
# {'epoch': 5382, 'epoch_time_sec': 21.12, 'lr': 4.4630898960586185e-05, 'train_loss': 0.011815, 'train_psnr': 25.0152, 'val_psnr': 23.8748, 'best_val_psnr': 23.8748}
# {'epoch': 5383, 'epoch_time_sec': 21.83, 'lr': 4.461544570084428e-05, 'train_loss': 0.01182, 'train_psnr': 25.0152, 'val_psnr': 23.8748, 'best_val_psnr': 23.8748}
# {'epoch': 5384, 'epoch_time_sec': 21.15, 'lr': 4.4599993022814935e-05, 'train_loss': 0.011831, 'train_psnr': 25.0081, 'val_psnr': 23.8749, 'best_val_psnr': 23.8749}
# {'epoch': 5385, 'epoch_time_sec': 21.85, 'lr': 4.458454092802575e-05, 'train_loss': 0.011818, 'train_psnr': 25.0137, 'val_psnr': 23.8748, 'best_val_psnr': 23.8749}
# {'epoch': 5386, 'epoch_time_sec': 21.24, 'lr': 4.4569089418004224e-05, 'train_loss': 0.011821, 'train_psnr': 25.0099, 'val_psnr': 23.8747, 'best_val_psnr': 23.8749}
# {'epoch': 5387, 'epoch_time_sec': 21.84, 'lr': 4.4553638494277833e-05, 'train_loss': 0.011813, 'train_psnr': 25.0153, 'val_psnr': 23.8745, 'best_val_psnr': 23.8749}
# {'epoch': 5388, 'epoch_time_sec': 21.16, 'lr': 4.45381881583739e-05, 'train_loss': 0.011829, 'train_psnr': 25.0061, 'val_psnr': 23.8746, 'best_val_psnr': 23.8749}
# {'epoch': 5389, 'epoch_time_sec': 21.78, 'lr': 4.45227384118198e-05, 'train_loss': 0.011829, 'train_psnr': 25.0099, 'val_psnr': 23.8747, 'best_val_psnr': 23.8749}
# {'epoch': 5390, 'epoch_time_sec': 21.15, 'lr': 4.450728925614279e-05, 'train_loss': 0.011828, 'train_psnr': 25.0085, 'val_psnr': 23.8747, 'best_val_psnr': 23.8749}
# {'epoch': 5391, 'epoch_time_sec': 21.83, 'lr': 4.44918406928701e-05, 'train_loss': 0.011811, 'train_psnr': 25.0183, 'val_psnr': 23.8747, 'best_val_psnr': 23.8749}
# {'epoch': 5392, 'epoch_time_sec': 21.1, 'lr': 4.447639272352885e-05, 'train_loss': 0.011828, 'train_psnr': 25.0088, 'val_psnr': 23.8748, 'best_val_psnr': 23.8749}
# {'epoch': 5393, 'epoch_time_sec': 21.83, 'lr': 4.446094534964616e-05, 'train_loss': 0.011815, 'train_psnr': 25.0162, 'val_psnr': 23.8748, 'best_val_psnr': 23.8749}
# {'epoch': 5394, 'epoch_time_sec': 21.11, 'lr': 4.4445498572749064e-05, 'train_loss': 0.011816, 'train_psnr': 25.0143, 'val_psnr': 23.8749, 'best_val_psnr': 23.8749}
# {'epoch': 5395, 'epoch_time_sec': 21.78, 'lr': 4.4430052394364536e-05, 'train_loss': 0.011829, 'train_psnr': 25.008, 'val_psnr': 23.8749, 'best_val_psnr': 23.8749}
# {'epoch': 5396, 'epoch_time_sec': 21.25, 'lr': 4.441460681601952e-05, 'train_loss': 0.011826, 'train_psnr': 25.0101, 'val_psnr': 23.8748, 'best_val_psnr': 23.8749}
# {'epoch': 5397, 'epoch_time_sec': 21.8, 'lr': 4.4399161839240834e-05, 'train_loss': 0.011823, 'train_psnr': 25.0117, 'val_psnr': 23.8748, 'best_val_psnr': 23.8749}
# {'epoch': 5398, 'epoch_time_sec': 21.22, 'lr': 4.4383717465555315e-05, 'train_loss': 0.011827, 'train_psnr': 25.0078, 'val_psnr': 23.875, 'best_val_psnr': 23.875}
# {'epoch': 5399, 'epoch_time_sec': 21.87, 'lr': 4.4368273696489666e-05, 'train_loss': 0.011828, 'train_psnr': 25.0055, 'val_psnr': 23.8749, 'best_val_psnr': 23.875}
# {'epoch': 5400, 'epoch_time_sec': 21.21, 'lr': 4.435283053357061e-05, 'train_loss': 0.011812, 'train_psnr': 25.0167, 'val_psnr': 23.8749, 'best_val_psnr': 23.875}
# {'epoch': 5401, 'epoch_time_sec': 21.81, 'lr': 4.4337387978324726e-05, 'train_loss': 0.011854, 'train_psnr': 25.004, 'val_psnr': 23.8751, 'best_val_psnr': 23.8751}
# {'epoch': 5402, 'epoch_time_sec': 21.15, 'lr': 4.4321946032278595e-05, 'train_loss': 0.011823, 'train_psnr': 25.0139, 'val_psnr': 23.8751, 'best_val_psnr': 23.8751}
# {'epoch': 5403, 'epoch_time_sec': 21.77, 'lr': 4.430650469695871e-05, 'train_loss': 0.011824, 'train_psnr': 25.0109, 'val_psnr': 23.8751, 'best_val_psnr': 23.8751}
# {'epoch': 5404, 'epoch_time_sec': 21.11, 'lr': 4.4291063973891546e-05, 'train_loss': 0.011829, 'train_psnr': 25.0075, 'val_psnr': 23.8752, 'best_val_psnr': 23.8752}
# {'epoch': 5405, 'epoch_time_sec': 21.81, 'lr': 4.427562386460343e-05, 'train_loss': 0.011828, 'train_psnr': 25.0108, 'val_psnr': 23.8752, 'best_val_psnr': 23.8752}
# {'epoch': 5406, 'epoch_time_sec': 21.23, 'lr': 4.4260184370620706e-05, 'train_loss': 0.011831, 'train_psnr': 25.008, 'val_psnr': 23.8752, 'best_val_psnr': 23.8752}
# {'epoch': 5407, 'epoch_time_sec': 21.86, 'lr': 4.424474549346964e-05, 'train_loss': 0.011836, 'train_psnr': 25.0066, 'val_psnr': 23.8753, 'best_val_psnr': 23.8753}
# {'epoch': 5408, 'epoch_time_sec': 21.12, 'lr': 4.422930723467641e-05, 'train_loss': 0.011813, 'train_psnr': 25.0172, 'val_psnr': 23.8752, 'best_val_psnr': 23.8753}
# {'epoch': 5409, 'epoch_time_sec': 21.86, 'lr': 4.4213869595767185e-05, 'train_loss': 0.011817, 'train_psnr': 25.0119, 'val_psnr': 23.8752, 'best_val_psnr': 23.8753}
# {'epoch': 5410, 'epoch_time_sec': 21.23, 'lr': 4.419843257826799e-05, 'train_loss': 0.011814, 'train_psnr': 25.0179, 'val_psnr': 23.8752, 'best_val_psnr': 23.8753}
# {'epoch': 5411, 'epoch_time_sec': 21.81, 'lr': 4.418299618370487e-05, 'train_loss': 0.011818, 'train_psnr': 25.0144, 'val_psnr': 23.8752, 'best_val_psnr': 23.8753}
# {'epoch': 5412, 'epoch_time_sec': 21.13, 'lr': 4.416756041360377e-05, 'train_loss': 0.011817, 'train_psnr': 25.0147, 'val_psnr': 23.8752, 'best_val_psnr': 23.8753}
# {'epoch': 5413, 'epoch_time_sec': 21.83, 'lr': 4.41521252694906e-05, 'train_loss': 0.011824, 'train_psnr': 25.0088, 'val_psnr': 23.8753, 'best_val_psnr': 23.8753}
# {'epoch': 5414, 'epoch_time_sec': 21.13, 'lr': 4.413669075289115e-05, 'train_loss': 0.011814, 'train_psnr': 25.0178, 'val_psnr': 23.8753, 'best_val_psnr': 23.8753}
# {'epoch': 5415, 'epoch_time_sec': 21.81, 'lr': 4.4121256865331204e-05, 'train_loss': 0.01183, 'train_psnr': 25.0081, 'val_psnr': 23.8753, 'best_val_psnr': 23.8753}
# {'epoch': 5416, 'epoch_time_sec': 21.19, 'lr': 4.410582360833647e-05, 'train_loss': 0.011829, 'train_psnr': 25.0073, 'val_psnr': 23.8752, 'best_val_psnr': 23.8753}
# {'epoch': 5417, 'epoch_time_sec': 21.88, 'lr': 4.4090390983432594e-05, 'train_loss': 0.011813, 'train_psnr': 25.0158, 'val_psnr': 23.8752, 'best_val_psnr': 23.8753}
# {'epoch': 5418, 'epoch_time_sec': 21.18, 'lr': 4.407495899214515e-05, 'train_loss': 0.011814, 'train_psnr': 25.0158, 'val_psnr': 23.8753, 'best_val_psnr': 23.8753}
# {'epoch': 5419, 'epoch_time_sec': 21.85, 'lr': 4.4059527635999636e-05, 'train_loss': 0.011834, 'train_psnr': 25.004, 'val_psnr': 23.8753, 'best_val_psnr': 23.8753}
# {'epoch': 5420, 'epoch_time_sec': 21.2, 'lr': 4.404409691652152e-05, 'train_loss': 0.011814, 'train_psnr': 25.0148, 'val_psnr': 23.8754, 'best_val_psnr': 23.8754}
# {'epoch': 5421, 'epoch_time_sec': 21.77, 'lr': 4.402866683523619e-05, 'train_loss': 0.011829, 'train_psnr': 25.0097, 'val_psnr': 23.8753, 'best_val_psnr': 23.8754}
# {'epoch': 5422, 'epoch_time_sec': 21.21, 'lr': 4.401323739366901e-05, 'train_loss': 0.011815, 'train_psnr': 25.0157, 'val_psnr': 23.8752, 'best_val_psnr': 23.8754}
# {'epoch': 5423, 'epoch_time_sec': 21.81, 'lr': 4.3997808593345186e-05, 'train_loss': 0.01184, 'train_psnr': 25.0063, 'val_psnr': 23.8753, 'best_val_psnr': 23.8754}
# {'epoch': 5424, 'epoch_time_sec': 21.1, 'lr': 4.398238043578994e-05, 'train_loss': 0.011822, 'train_psnr': 25.0115, 'val_psnr': 23.8753, 'best_val_psnr': 23.8754}
# {'epoch': 5425, 'epoch_time_sec': 21.86, 'lr': 4.396695292252843e-05, 'train_loss': 0.011822, 'train_psnr': 25.011, 'val_psnr': 23.8752, 'best_val_psnr': 23.8754}
# {'epoch': 5426, 'epoch_time_sec': 21.22, 'lr': 4.395152605508571e-05, 'train_loss': 0.011818, 'train_psnr': 25.0133, 'val_psnr': 23.8752, 'best_val_psnr': 23.8754}
# {'epoch': 5427, 'epoch_time_sec': 21.88, 'lr': 4.3936099834986795e-05, 'train_loss': 0.011829, 'train_psnr': 25.0113, 'val_psnr': 23.8752, 'best_val_psnr': 23.8754}
# {'epoch': 5428, 'epoch_time_sec': 21.22, 'lr': 4.392067426375662e-05, 'train_loss': 0.011821, 'train_psnr': 25.0148, 'val_psnr': 23.8752, 'best_val_psnr': 23.8754}
# {'epoch': 5429, 'epoch_time_sec': 21.81, 'lr': 4.3905249342920064e-05, 'train_loss': 0.011819, 'train_psnr': 25.013, 'val_psnr': 23.8753, 'best_val_psnr': 23.8754}
# {'epoch': 5430, 'epoch_time_sec': 21.14, 'lr': 4.3889825074001985e-05, 'train_loss': 0.011811, 'train_psnr': 25.0182, 'val_psnr': 23.8753, 'best_val_psnr': 23.8754}
# {'epoch': 5431, 'epoch_time_sec': 21.84, 'lr': 4.387440145852709e-05, 'train_loss': 0.011818, 'train_psnr': 25.013, 'val_psnr': 23.8752, 'best_val_psnr': 23.8754}
# {'epoch': 5432, 'epoch_time_sec': 21.16, 'lr': 4.385897849802008e-05, 'train_loss': 0.011844, 'train_psnr': 25.0025, 'val_psnr': 23.8753, 'best_val_psnr': 23.8754}
# {'epoch': 5433, 'epoch_time_sec': 21.83, 'lr': 4.3843556194005586e-05, 'train_loss': 0.011818, 'train_psnr': 25.0134, 'val_psnr': 23.8752, 'best_val_psnr': 23.8754}
# {'epoch': 5434, 'epoch_time_sec': 21.26, 'lr': 4.3828134548008166e-05, 'train_loss': 0.011822, 'train_psnr': 25.011, 'val_psnr': 23.8751, 'best_val_psnr': 23.8754}
# {'epoch': 5435, 'epoch_time_sec': 21.81, 'lr': 4.381271356155233e-05, 'train_loss': 0.011825, 'train_psnr': 25.0105, 'val_psnr': 23.8752, 'best_val_psnr': 23.8754}
# {'epoch': 5436, 'epoch_time_sec': 21.14, 'lr': 4.3797293236162465e-05, 'train_loss': 0.011827, 'train_psnr': 25.0098, 'val_psnr': 23.8753, 'best_val_psnr': 23.8754}
# ...
# {'epoch': 8878, 'epoch_time_sec': 21.34, 'lr': 4.048226850964686e-06, 'train_loss': 0.011774, 'train_psnr': 25.0412, 'val_psnr': 23.896, 'best_val_psnr': 23.8961}
# {'epoch': 8879, 'epoch_time_sec': 22.06, 'lr': 4.0428520534844456e-06, 'train_loss': 0.011789, 'train_psnr': 25.0346, 'val_psnr': 23.8961, 'best_val_psnr': 23.8961}
# {'epoch': 8880, 'epoch_time_sec': 21.34, 'lr': 4.037481848485912e-06, 'train_loss': 0.011786, 'train_psnr': 25.0343, 'val_psnr': 23.8961, 'best_val_psnr': 23.8961}
# {'epoch': 8881, 'epoch_time_sec': 22.1, 'lr': 4.0321162364999594e-06, 'train_loss': 0.011786, 'train_psnr': 25.0357, 'val_psnr': 23.8961, 'best_val_psnr': 23.8961}
# {'epoch': 8882, 'epoch_time_sec': 21.41, 'lr': 4.026755218056996e-06, 'train_loss': 0.011767, 'train_psnr': 25.0441, 'val_psnr': 23.8961, 'best_val_psnr': 23.8961}
# {'epoch': 8883, 'epoch_time_sec': 22.11, 'lr': 4.0213987936869915e-06, 'train_loss': 0.011794, 'train_psnr': 25.034, 'val_psnr': 23.8961, 'best_val_psnr': 23.8961}
# {'epoch': 8884, 'epoch_time_sec': 21.35, 'lr': 4.016046963919435e-06, 'train_loss': 0.011787, 'train_psnr': 25.0349, 'val_psnr': 23.8962, 'best_val_psnr': 23.8962}
# {'epoch': 8885, 'epoch_time_sec': 22.07, 'lr': 4.010699729283388e-06, 'train_loss': 0.011784, 'train_psnr': 25.0345, 'val_psnr': 23.8961, 'best_val_psnr': 23.8962}
# {'epoch': 8886, 'epoch_time_sec': 21.48, 'lr': 4.005357090307447e-06, 'train_loss': 0.01179, 'train_psnr': 25.0333, 'val_psnr': 23.8961, 'best_val_psnr': 23.8962}
# {'epoch': 8887, 'epoch_time_sec': 22.09, 'lr': 4.000019047519744e-06, 'train_loss': 0.011782, 'train_psnr': 25.0348, 'val_psnr': 23.8962, 'best_val_psnr': 23.8962}
# {'epoch': 8888, 'epoch_time_sec': 21.36, 'lr': 3.994685601447983e-06, 'train_loss': 0.011769, 'train_psnr': 25.0418, 'val_psnr': 23.8961, 'best_val_psnr': 23.8962}
# {'epoch': 8889, 'epoch_time_sec': 22.09, 'lr': 3.98935675261938e-06, 'train_loss': 0.011785, 'train_psnr': 25.035, 'val_psnr': 23.8961, 'best_val_psnr': 23.8962}
# {'epoch': 8890, 'epoch_time_sec': 21.39, 'lr': 3.984032501560721e-06, 'train_loss': 0.011771, 'train_psnr': 25.0408, 'val_psnr': 23.896, 'best_val_psnr': 23.8962}
# {'epoch': 8891, 'epoch_time_sec': 22.07, 'lr': 3.978712848798326e-06, 'train_loss': 0.011787, 'train_psnr': 25.033, 'val_psnr': 23.8962, 'best_val_psnr': 23.8962}
# {'epoch': 8892, 'epoch_time_sec': 21.4, 'lr': 3.973397794858085e-06, 'train_loss': 0.011791, 'train_psnr': 25.0315, 'val_psnr': 23.8962, 'best_val_psnr': 23.8962}
# {'epoch': 8893, 'epoch_time_sec': 22.07, 'lr': 3.968087340265384e-06, 'train_loss': 0.011776, 'train_psnr': 25.039, 'val_psnr': 23.8962, 'best_val_psnr': 23.8962}
# {'epoch': 8894, 'epoch_time_sec': 21.43, 'lr': 3.962781485545202e-06, 'train_loss': 0.011773, 'train_psnr': 25.0412, 'val_psnr': 23.8961, 'best_val_psnr': 23.8962}
# {'epoch': 8895, 'epoch_time_sec': 22.11, 'lr': 3.9574802312220325e-06, 'train_loss': 0.011786, 'train_psnr': 25.0346, 'val_psnr': 23.8962, 'best_val_psnr': 23.8962}
# {'epoch': 8896, 'epoch_time_sec': 21.4, 'lr': 3.952183577819949e-06, 'train_loss': 0.011789, 'train_psnr': 25.035, 'val_psnr': 23.8961, 'best_val_psnr': 23.8962}
# {'epoch': 8897, 'epoch_time_sec': 22.17, 'lr': 3.946891525862522e-06, 'train_loss': 0.011772, 'train_psnr': 25.0417, 'val_psnr': 23.8962, 'best_val_psnr': 23.8962}
# {'epoch': 8898, 'epoch_time_sec': 21.31, 'lr': 3.9416040758729e-06, 'train_loss': 0.011797, 'train_psnr': 25.0299, 'val_psnr': 23.8961, 'best_val_psnr': 23.8962}
# {'epoch': 8899, 'epoch_time_sec': 22.09, 'lr': 3.9363212283737756e-06, 'train_loss': 0.01178, 'train_psnr': 25.0355, 'val_psnr': 23.8962, 'best_val_psnr': 23.8962}
# {'epoch': 8900, 'epoch_time_sec': 21.39, 'lr': 3.93104298388738e-06, 'train_loss': 0.011789, 'train_psnr': 25.0324, 'val_psnr': 23.8962, 'best_val_psnr': 23.8962}
# {'epoch': 8901, 'epoch_time_sec': 22.07, 'lr': 3.9257693429354875e-06, 'train_loss': 0.01178, 'train_psnr': 25.0395, 'val_psnr': 23.8962, 'best_val_psnr': 23.8962}
# {'epoch': 8902, 'epoch_time_sec': 21.41, 'lr': 3.920500306039417e-06, 'train_loss': 0.011777, 'train_psnr': 25.0365, 'val_psnr': 23.8961, 'best_val_psnr': 23.8962}
# {'epoch': 8903, 'epoch_time_sec': 22.07, 'lr': 3.915235873720035e-06, 'train_loss': 0.011769, 'train_psnr': 25.0429, 'val_psnr': 23.8961, 'best_val_psnr': 23.8962}
# {'epoch': 8904, 'epoch_time_sec': 21.43, 'lr': 3.90997604649776e-06, 'train_loss': 0.011771, 'train_psnr': 25.0423, 'val_psnr': 23.896, 'best_val_psnr': 23.8962}
# {'epoch': 8905, 'epoch_time_sec': 22.05, 'lr': 3.904720824892531e-06, 'train_loss': 0.011778, 'train_psnr': 25.0375, 'val_psnr': 23.8961, 'best_val_psnr': 23.8962}
# {'epoch': 8906, 'epoch_time_sec': 21.42, 'lr': 3.899470209423869e-06, 'train_loss': 0.011771, 'train_psnr': 25.0405, 'val_psnr': 23.896, 'best_val_psnr': 23.8962}
# {'epoch': 8907, 'epoch_time_sec': 22.08, 'lr': 3.894224200610801e-06, 'train_loss': 0.011785, 'train_psnr': 25.0333, 'val_psnr': 23.8959, 'best_val_psnr': 23.8962}
# {'epoch': 8908, 'epoch_time_sec': 21.42, 'lr': 3.8889827989719254e-06, 'train_loss': 0.011769, 'train_psnr': 25.0418, 'val_psnr': 23.8959, 'best_val_psnr': 23.8962}
# {'epoch': 8909, 'epoch_time_sec': 22.07, 'lr': 3.8837460050253836e-06, 'train_loss': 0.011782, 'train_psnr': 25.035, 'val_psnr': 23.896, 'best_val_psnr': 23.8962}
# {'epoch': 8910, 'epoch_time_sec': 21.43, 'lr': 3.87851381928884e-06, 'train_loss': 0.011767, 'train_psnr': 25.0428, 'val_psnr': 23.896, 'best_val_psnr': 23.8962}
# {'epoch': 8911, 'epoch_time_sec': 22.07, 'lr': 3.873286242279525e-06, 'train_loss': 0.011781, 'train_psnr': 25.0372, 'val_psnr': 23.8961, 'best_val_psnr': 23.8962}
# {'epoch': 8912, 'epoch_time_sec': 21.39, 'lr': 3.868063274514205e-06, 'train_loss': 0.011767, 'train_psnr': 25.0422, 'val_psnr': 23.896, 'best_val_psnr': 23.8962}
# {'epoch': 8913, 'epoch_time_sec': 22.05, 'lr': 3.8628449165091875e-06, 'train_loss': 0.011768, 'train_psnr': 25.0424, 'val_psnr': 23.8961, 'best_val_psnr': 23.8962}
# {'epoch': 8914, 'epoch_time_sec': 21.38, 'lr': 3.857631168780351e-06, 'train_loss': 0.011776, 'train_psnr': 25.0386, 'val_psnr': 23.8961, 'best_val_psnr': 23.8962}
# {'epoch': 8915, 'epoch_time_sec': 22.1, 'lr': 3.852422031843061e-06, 'train_loss': 0.011786, 'train_psnr': 25.0345, 'val_psnr': 23.8961, 'best_val_psnr': 23.8962}
# {'epoch': 8916, 'epoch_time_sec': 21.37, 'lr': 3.847217506212289e-06, 'train_loss': 0.011794, 'train_psnr': 25.0316, 'val_psnr': 23.896, 'best_val_psnr': 23.8962}
# {'epoch': 8917, 'epoch_time_sec': 22.06, 'lr': 3.842017592402512e-06, 'train_loss': 0.011778, 'train_psnr': 25.0368, 'val_psnr': 23.8961, 'best_val_psnr': 23.8962}
# {'epoch': 8918, 'epoch_time_sec': 21.4, 'lr': 3.836822290927772e-06, 'train_loss': 0.011773, 'train_psnr': 25.0402, 'val_psnr': 23.8961, 'best_val_psnr': 23.8962}
# {'epoch': 8919, 'epoch_time_sec': 22.12, 'lr': 3.831631602301638e-06, 'train_loss': 0.011774, 'train_psnr': 25.0393, 'val_psnr': 23.8961, 'best_val_psnr': 23.8962}
# {'epoch': 8920, 'epoch_time_sec': 21.36, 'lr': 3.82644552703723e-06, 'train_loss': 0.011779, 'train_psnr': 25.0371, 'val_psnr': 23.8961, 'best_val_psnr': 23.8962}
# {'epoch': 8921, 'epoch_time_sec': 22.09, 'lr': 3.821264065647216e-06, 'train_loss': 0.01179, 'train_psnr': 25.0356, 'val_psnr': 23.8961, 'best_val_psnr': 23.8962}
# {'epoch': 8922, 'epoch_time_sec': 21.4, 'lr': 3.8160872186438134e-06, 'train_loss': 0.011783, 'train_psnr': 25.0339, 'val_psnr': 23.8962, 'best_val_psnr': 23.8962}
# {'epoch': 8923, 'epoch_time_sec': 22.1, 'lr': 3.810914986538758e-06, 'train_loss': 0.011771, 'train_psnr': 25.041, 'val_psnr': 23.8962, 'best_val_psnr': 23.8962}
# {'epoch': 8924, 'epoch_time_sec': 21.38, 'lr': 3.8057473698433696e-06, 'train_loss': 0.011776, 'train_psnr': 25.0426, 'val_psnr': 23.8963, 'best_val_psnr': 23.8963}
# {'epoch': 8925, 'epoch_time_sec': 22.11, 'lr': 3.8005843690684598e-06, 'train_loss': 0.011769, 'train_psnr': 25.0437, 'val_psnr': 23.8963, 'best_val_psnr': 23.8963}
# {'epoch': 8926, 'epoch_time_sec': 21.3, 'lr': 3.795425984724428e-06, 'train_loss': 0.011769, 'train_psnr': 25.0423, 'val_psnr': 23.8963, 'best_val_psnr': 23.8963}
# {'epoch': 8927, 'epoch_time_sec': 22.07, 'lr': 3.7902722173212113e-06, 'train_loss': 0.011775, 'train_psnr': 25.0409, 'val_psnr': 23.8963, 'best_val_psnr': 23.8963}
# {'epoch': 8928, 'epoch_time_sec': 21.39, 'lr': 3.7851230673682674e-06, 'train_loss': 0.011766, 'train_psnr': 25.0442, 'val_psnr': 23.8963, 'best_val_psnr': 23.8963}
# {'epoch': 8929, 'epoch_time_sec': 22.09, 'lr': 3.7799785353746062e-06, 'train_loss': 0.011776, 'train_psnr': 25.0401, 'val_psnr': 23.8963, 'best_val_psnr': 23.8963}
# {'epoch': 8930, 'epoch_time_sec': 21.43, 'lr': 3.7748386218488008e-06, 'train_loss': 0.011774, 'train_psnr': 25.0407, 'val_psnr': 23.8963, 'best_val_psnr': 23.8963}
# {'epoch': 8931, 'epoch_time_sec': 22.08, 'lr': 3.769703327298953e-06, 'train_loss': 0.011795, 'train_psnr': 25.0322, 'val_psnr': 23.8963, 'best_val_psnr': 23.8963}
# {'epoch': 8932, 'epoch_time_sec': 21.39, 'lr': 3.7645726522326916e-06, 'train_loss': 0.011786, 'train_psnr': 25.0349, 'val_psnr': 23.8963, 'best_val_psnr': 23.8963}
# {'epoch': 8933, 'epoch_time_sec': 22.04, 'lr': 3.759446597157218e-06, 'train_loss': 0.011773, 'train_psnr': 25.0407, 'val_psnr': 23.8963, 'best_val_psnr': 23.8963}
# {'epoch': 8934, 'epoch_time_sec': 21.32, 'lr': 3.754325162579258e-06, 'train_loss': 0.011774, 'train_psnr': 25.0391, 'val_psnr': 23.8963, 'best_val_psnr': 23.8963}
# {'epoch': 8935, 'epoch_time_sec': 22.09, 'lr': 3.749208349005096e-06, 'train_loss': 0.011772, 'train_psnr': 25.0393, 'val_psnr': 23.8963, 'best_val_psnr': 23.8963}
# {'epoch': 8936, 'epoch_time_sec': 21.39, 'lr': 3.7440961569405406e-06, 'train_loss': 0.01178, 'train_psnr': 25.039, 'val_psnr': 23.8963, 'best_val_psnr': 23.8963}
# {'epoch': 8937, 'epoch_time_sec': 22.05, 'lr': 3.7389885868909567e-06, 'train_loss': 0.011777, 'train_psnr': 25.0366, 'val_psnr': 23.8963, 'best_val_psnr': 23.8963}
# {'epoch': 8938, 'epoch_time_sec': 21.39, 'lr': 3.7338856393612427e-06, 'train_loss': 0.011766, 'train_psnr': 25.0432, 'val_psnr': 23.8963, 'best_val_psnr': 23.8963}
# {'epoch': 8939, 'epoch_time_sec': 22.13, 'lr': 3.7287873148558668e-06, 'train_loss': 0.011769, 'train_psnr': 25.0419, 'val_psnr': 23.8963, 'best_val_psnr': 23.8963}
# {'epoch': 8940, 'epoch_time_sec': 21.35, 'lr': 3.7236936138787925e-06, 'train_loss': 0.011777, 'train_psnr': 25.0379, 'val_psnr': 23.8963, 'best_val_psnr': 23.8963}
# {'epoch': 8941, 'epoch_time_sec': 22.04, 'lr': 3.7186045369335656e-06, 'train_loss': 0.011772, 'train_psnr': 25.0395, 'val_psnr': 23.8963, 'best_val_psnr': 23.8963}
# {'epoch': 8942, 'epoch_time_sec': 21.42, 'lr': 3.7135200845232704e-06, 'train_loss': 0.011769, 'train_psnr': 25.0415, 'val_psnr': 23.8963, 'best_val_psnr': 23.8963}
# {'epoch': 8943, 'epoch_time_sec': 22.0, 'lr': 3.7084402571505124e-06, 'train_loss': 0.01177, 'train_psnr': 25.0429, 'val_psnr': 23.8963, 'best_val_psnr': 23.8963}
# {'epoch': 8944, 'epoch_time_sec': 21.39, 'lr': 3.7033650553174645e-06, 'train_loss': 0.011772, 'train_psnr': 25.0425, 'val_psnr': 23.8963, 'best_val_psnr': 23.8963}
# {'epoch': 8945, 'epoch_time_sec': 22.14, 'lr': 3.6982944795258243e-06, 'train_loss': 0.011775, 'train_psnr': 25.0395, 'val_psnr': 23.8963, 'best_val_psnr': 23.8963}
# {'epoch': 8946, 'epoch_time_sec': 21.41, 'lr': 3.6932285302768354e-06, 'train_loss': 0.011769, 'train_psnr': 25.0428, 'val_psnr': 23.8963, 'best_val_psnr': 23.8963}
# {'epoch': 8947, 'epoch_time_sec': 22.02, 'lr': 3.6881672080712966e-06, 'train_loss': 0.011775, 'train_psnr': 25.0391, 'val_psnr': 23.8964, 'best_val_psnr': 23.8964}
# {'epoch': 8948, 'epoch_time_sec': 21.39, 'lr': 3.683110513409543e-06, 'train_loss': 0.011786, 'train_psnr': 25.0348, 'val_psnr': 23.8964, 'best_val_psnr': 23.8964}
# {'epoch': 8949, 'epoch_time_sec': 22.02, 'lr': 3.6780584467914327e-06, 'train_loss': 0.011772, 'train_psnr': 25.0403, 'val_psnr': 23.8964, 'best_val_psnr': 23.8964}
# {'epoch': 8950, 'epoch_time_sec': 21.37, 'lr': 3.673011008716402e-06, 'train_loss': 0.011774, 'train_psnr': 25.04, 'val_psnr': 23.8964, 'best_val_psnr': 23.8964}
# {'epoch': 8951, 'epoch_time_sec': 22.08, 'lr': 3.6679681996834012e-06, 'train_loss': 0.011778, 'train_psnr': 25.0406, 'val_psnr': 23.8963, 'best_val_psnr': 23.8964}
# {'epoch': 8952, 'epoch_time_sec': 21.39, 'lr': 3.6629300201909477e-06, 'train_loss': 0.011778, 'train_psnr': 25.0379, 'val_psnr': 23.8964, 'best_val_psnr': 23.8964}
# {'epoch': 8953, 'epoch_time_sec': 22.09, 'lr': 3.6578964707370646e-06, 'train_loss': 0.011774, 'train_psnr': 25.0396, 'val_psnr': 23.8964, 'best_val_psnr': 23.8964}
# {'epoch': 8954, 'epoch_time_sec': 21.36, 'lr': 3.652867551819345e-06, 'train_loss': 0.011779, 'train_psnr': 25.038, 'val_psnr': 23.8964, 'best_val_psnr': 23.8964}
# {'epoch': 8955, 'epoch_time_sec': 22.08, 'lr': 3.647843263934928e-06, 'train_loss': 0.01178, 'train_psnr': 25.0364, 'val_psnr': 23.8964, 'best_val_psnr': 23.8964}
# {'epoch': 8956, 'epoch_time_sec': 21.42, 'lr': 3.6428236075804775e-06, 'train_loss': 0.011777, 'train_psnr': 25.0382, 'val_psnr': 23.8965, 'best_val_psnr': 23.8965}
# {'epoch': 8957, 'epoch_time_sec': 22.15, 'lr': 3.6378085832522198e-06, 'train_loss': 0.011763, 'train_psnr': 25.0463, 'val_psnr': 23.8964, 'best_val_psnr': 23.8965}
# {'epoch': 8958, 'epoch_time_sec': 21.47, 'lr': 3.632798191445891e-06, 'train_loss': 0.011769, 'train_psnr': 25.0423, 'val_psnr': 23.8965, 'best_val_psnr': 23.8965}
# {'epoch': 8959, 'epoch_time_sec': 22.11, 'lr': 3.6277924326568045e-06, 'train_loss': 0.011788, 'train_psnr': 25.0354, 'val_psnr': 23.8965, 'best_val_psnr': 23.8965}
# {'epoch': 8960, 'epoch_time_sec': 21.4, 'lr': 3.6227913073797903e-06, 'train_loss': 0.011774, 'train_psnr': 25.0398, 'val_psnr': 23.8965, 'best_val_psnr': 23.8965}
# {'epoch': 8961, 'epoch_time_sec': 22.11, 'lr': 3.6177948161092437e-06, 'train_loss': 0.011772, 'train_psnr': 25.0415, 'val_psnr': 23.8964, 'best_val_psnr': 23.8965}
# {'epoch': 8962, 'epoch_time_sec': 21.38, 'lr': 3.6128029593390654e-06, 'train_loss': 0.011768, 'train_psnr': 25.0422, 'val_psnr': 23.8964, 'best_val_psnr': 23.8965}
# {'epoch': 8963, 'epoch_time_sec': 22.05, 'lr': 3.6078157375627444e-06, 'train_loss': 0.011766, 'train_psnr': 25.0437, 'val_psnr': 23.8964, 'best_val_psnr': 23.8965}
# {'epoch': 8964, 'epoch_time_sec': 21.4, 'lr': 3.602833151273274e-06, 'train_loss': 0.011769, 'train_psnr': 25.0427, 'val_psnr': 23.8964, 'best_val_psnr': 23.8965}
# {'epoch': 8965, 'epoch_time_sec': 22.07, 'lr': 3.5978552009632162e-06, 'train_loss': 0.011773, 'train_psnr': 25.0409, 'val_psnr': 23.8964, 'best_val_psnr': 23.8965}
# {'epoch': 8966, 'epoch_time_sec': 21.44, 'lr': 3.592881887124645e-06, 'train_loss': 0.011772, 'train_psnr': 25.0404, 'val_psnr': 23.8963, 'best_val_psnr': 23.8965}
# {'epoch': 8967, 'epoch_time_sec': 22.08, 'lr': 3.58791321024921e-06, 'train_loss': 0.011789, 'train_psnr': 25.0317, 'val_psnr': 23.8963, 'best_val_psnr': 23.8965}
# {'epoch': 8968, 'epoch_time_sec': 21.33, 'lr': 3.582949170828074e-06, 'train_loss': 0.011766, 'train_psnr': 25.0438, 'val_psnr': 23.8963, 'best_val_psnr': 23.8965}
# {'epoch': 8969, 'epoch_time_sec': 22.08, 'lr': 3.5779897693519574e-06, 'train_loss': 0.011768, 'train_psnr': 25.0435, 'val_psnr': 23.8963, 'best_val_psnr': 23.8965}
# {'epoch': 8970, 'epoch_time_sec': 21.35, 'lr': 3.5730350063111216e-06, 'train_loss': 0.011772, 'train_psnr': 25.0414, 'val_psnr': 23.8964, 'best_val_psnr': 23.8965}
# {'epoch': 8971, 'epoch_time_sec': 22.09, 'lr': 3.5680848821953578e-06, 'train_loss': 0.011769, 'train_psnr': 25.0425, 'val_psnr': 23.8964, 'best_val_psnr': 23.8965}
# {'epoch': 8972, 'epoch_time_sec': 21.39, 'lr': 3.5631393974940103e-06, 'train_loss': 0.011779, 'train_psnr': 25.0369, 'val_psnr': 23.8963, 'best_val_psnr': 23.8965}
# {'epoch': 8973, 'epoch_time_sec': 22.08, 'lr': 3.558198552695957e-06, 'train_loss': 0.011774, 'train_psnr': 25.041, 'val_psnr': 23.8963, 'best_val_psnr': 23.8965}
# {'epoch': 8974, 'epoch_time_sec': 21.37, 'lr': 3.5532623482896316e-06, 'train_loss': 0.011772, 'train_psnr': 25.0418, 'val_psnr': 23.8963, 'best_val_psnr': 23.8965}

# %% [markdown]
# ## 4. Validation

# %%
best_model = build_eval_model_from_checkpoint(best_ckpt_path, device)
preview_info = write_val_preview(best_model, val_loader, preview_dir, device)
best_val_psnr = evaluate_psnr(best_model, val_loader, device)
validation_summary = {
    'input_psnr': input_psnr,
    'val_psnr': best_val_psnr,
    'delta_psnr': best_val_psnr - input_psnr,
}
print({
    'validation_summary': validation_summary,
    'preview': preview_info,
    'best_checkpoint_path': str(best_ckpt_path),
})

# %% [markdown]
# ## 5. Export and Submission Artifacts
#
# ONNX export is included here. MXQ conversion stays in a separate workflow.

# %%
onnx_path = exports_dir / f'{cfg.model_id}.onnx'
export_model = build_eval_model_from_checkpoint(best_ckpt_path, device)
dummy = torch.randn(1, 3, 256, 256, device=device)

torch.onnx.export(
    export_model,
    dummy,
    str(onnx_path),
    input_names=['input'],
    output_names=['output'],
    opset_version=17,
    dynamo=False,
)

onnx_model = onnx.load(str(onnx_path))
onnx.checker.check_model(onnx_model)
node_ops = [node.op_type for node in onnx_model.graph.node]
op_histogram = {op: node_ops.count(op) for op in sorted(set(node_ops))}
print({
    'onnx_path': str(onnx_path),
    'graph_op_count': len(node_ops),
    'op_histogram': op_histogram,
})

parity_result = {
    'attempted': False,
    'onnxruntime_available': False,
    'max_abs_diff': None,
}
try:
    import onnxruntime as ort

    parity_result['attempted'] = True
    parity_result['onnxruntime_available'] = True
    cpu_model = build_eval_model_from_checkpoint(best_ckpt_path, torch.device('cpu')).cpu().eval()
    parity_input = torch.randn(1, 3, 256, 256)
    with torch.no_grad():
        torch_out = cpu_model(parity_input).detach().cpu().numpy()
    ort_session = ort.InferenceSession(str(onnx_path), providers=['CPUExecutionProvider'])
    ort_out = ort_session.run(['output'], {'input': parity_input.numpy()})[0]
    parity_result['max_abs_diff'] = float(np.max(np.abs(torch_out - ort_out)))
except ImportError:
    print('onnxruntime not installed; skipping CPU parity check')
print(parity_result)

summary = {
    'model_id': cfg.model_id,
    'run_root': str(run_root),
    'best_checkpoint_path': str(best_ckpt_path),
    'last_checkpoint_path': str(last_ckpt_path),
    'onnx_path': str(onnx_path),
    'metrics_csv_path': str(metrics_csv_path),
    'validation': validation_summary,
    'preview': preview_info,
    'onnx_parity': parity_result,
    'mxq_scope': 'Not handled in this notebook; separate workflow.',
}
summary_path.write_text(json.dumps(summary, indent=2), encoding='utf-8')
print(summary)
