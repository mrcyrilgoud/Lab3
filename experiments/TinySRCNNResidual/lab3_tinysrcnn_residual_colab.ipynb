# %% [markdown]
# # Lab 3 - TinySRCNNResidual (No-Add Colab)
#
# - Goal: train a simple TinySRCNN-style no-add super-resolution model for Lab 3.
# - Expected input/output: `256x256x3`
# - Runtime target: Google Colab with Google Drive.
# - Note: MXQ conversion is intentionally handled outside this notebook.

# %% [markdown]
# ## 1. Setup
#
# This notebook follows the Lab 3 rubric structure while keeping the implementation lean.

# %%
try:
    import google.colab  # type: ignore
    IN_COLAB_BOOTSTRAP = True
except Exception:
    IN_COLAB_BOOTSTRAP = False

if IN_COLAB_BOOTSTRAP:
    # %pip install -q onnx onnxruntime

import csv
import json
import math
import os
import random
import sys
import time
from contextlib import nullcontext
from dataclasses import asdict, dataclass
from datetime import datetime
from pathlib import Path
from typing import Any

import numpy as np
import onnx
import torch
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
from torch.utils.data import DataLoader, Dataset


IMAGE_SUFFIXES = {'.png', '.jpg', '.jpeg', '.bmp'}
DRIVE_ROOT = Path('/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3')
DRIVE_DATA_ROOT = DRIVE_ROOT / 'Data'
DRIVE_RUNS_ROOT = DRIVE_ROOT / 'runs'

try:
    BICUBIC_RESAMPLE = Image.Resampling.BICUBIC
except AttributeError:
    BICUBIC_RESAMPLE = Image.BICUBIC

try:
    FLIP_LEFT_RIGHT = Image.Transpose.FLIP_LEFT_RIGHT
    FLIP_TOP_BOTTOM = Image.Transpose.FLIP_TOP_BOTTOM
    ROTATE_90 = Image.Transpose.ROTATE_90
    ROTATE_180 = Image.Transpose.ROTATE_180
    ROTATE_270 = Image.Transpose.ROTATE_270
except AttributeError:
    FLIP_LEFT_RIGHT = Image.FLIP_LEFT_RIGHT
    FLIP_TOP_BOTTOM = Image.FLIP_TOP_BOTTOM
    ROTATE_90 = Image.ROTATE_90
    ROTATE_180 = Image.ROTATE_180
    ROTATE_270 = Image.ROTATE_270


def set_global_seed(seed: int) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


def now_stamp() -> str:
    return datetime.now().strftime('%H%M%S_%d%m')


def is_colab_runtime() -> bool:
    try:
        import google.colab  # type: ignore  # noqa: F401
        return True
    except Exception:
        return False


def auto_num_workers(in_colab: bool) -> int:
    if sys.platform == 'darwin':
        return 0
    cpu_count = max(os.cpu_count() or 2, 2)
    if in_colab:
        return min(4, max(cpu_count - 1, 2))
    return min(2, cpu_count)


def resolve_repo_root(start: Path) -> Path:
    current = start.resolve()
    for candidate in [current, *current.parents]:
        if (candidate / 'Data').exists() and (candidate / 'runs').exists():
            return candidate
    for candidate in [current, *current.parents]:
        if (candidate / 'Data').exists():
            return candidate
    raise FileNotFoundError(f'Could not locate repo root from {start.resolve()}')


def make_unique_run_root(runs_root: Path, run_slug: str = '') -> Path:
    safe_slug = ''.join(ch if ch.isalnum() or ch in '_-' else '_' for ch in run_slug).strip('_')
    suffix = f'_{safe_slug}' if safe_slug else ''
    candidate = runs_root / f'{now_stamp()}{suffix}'
    while candidate.exists():
        time.sleep(1.1)
        candidate = runs_root / f'{now_stamp()}{suffix}'
    return candidate


def read_checkpoint_identity(checkpoint_path: Path) -> dict[str, Any] | None:
    try:
        checkpoint = torch.load(checkpoint_path, map_location='cpu')
    except Exception:
        return None
    config = checkpoint.get('config') or {}
    model_id = config.get('model_id')
    if not model_id:
        return None
    return {
        'path': str(checkpoint_path),
        'model_id': model_id,
        'epoch': int(checkpoint.get('epoch', 0)),
        'kind': checkpoint_path.name,
        'mtime': checkpoint_path.stat().st_mtime,
    }


def find_latest_model_checkpoint(runs_root: Path, model_id: str, filename: str = 'last.pth') -> str | None:
    candidates: list[dict[str, Any]] = []
    for checkpoint_path in runs_root.rglob(f'checkpoints/{filename}'):
        identity = read_checkpoint_identity(checkpoint_path)
        if identity and identity['model_id'] == model_id:
            candidates.append(identity)
    if not candidates:
        return None
    winner = max(candidates, key=lambda item: item['mtime'])
    return winner['path']


def resolve_resume_checkpoint_path(resume_checkpoint_path: str | None, runs_root: Path, model_id: str) -> str | None:
    if not resume_checkpoint_path:
        return None
    if resume_checkpoint_path == 'last.pth':
        return find_latest_model_checkpoint(runs_root, model_id, filename='last.pth')
    path = Path(resume_checkpoint_path)
    if not path.is_absolute():
        path = runs_root / path
    if path.exists():
        return str(path)
    return None


@dataclass
class RunConfig:
    model_id: str = 'tinysrcnn_noadd_lrelu'
    run_slug: str = 'base'
    enable_resume: bool = True
    resume_checkpoint_path: str | None = 'last.pth'
    seed: int = 1337
    train_patch_size: int = 256
    eval_size: int = 256
    batch_size: int = 16
    epochs: int = 1000
    lr: float = 1e-4
    min_lr: float = 1e-6
    weight_decay: float = 1e-4
    warmup_epochs: int = 8
    num_workers: int | None = 2
    prefetch_factor: int = 2
    use_amp: bool = True
    use_ema: bool = True
    ema_decay: float = 0.999


cfg = RunConfig()
in_colab = is_colab_runtime()
if in_colab:
    from google.colab import drive  # type: ignore

    drive.mount('/content/drive', force_remount=False)
    data_root = DRIVE_DATA_ROOT
    runs_root = DRIVE_RUNS_ROOT
    if not data_root.exists():
        raise FileNotFoundError(f'Google Drive data root not found: {data_root}')
else:
    repo_root = resolve_repo_root(Path.cwd())
    data_root = repo_root / 'Data'
    runs_root = repo_root / 'runs'
    if not data_root.exists():
        raise FileNotFoundError(f'Data root not found: {data_root}')

runs_root.mkdir(parents=True, exist_ok=True)
if cfg.num_workers is None:
    cfg.num_workers = auto_num_workers(in_colab)
if cfg.enable_resume:
    cfg.resume_checkpoint_path = resolve_resume_checkpoint_path(cfg.resume_checkpoint_path, runs_root, cfg.model_id)
else:
    cfg.resume_checkpoint_path = None

run_root = make_unique_run_root(runs_root, cfg.run_slug)
checkpoints_dir = run_root / 'checkpoints'
exports_dir = run_root / 'exports'
preview_dir = exports_dir / 'val_preview'
summary_path = run_root / 'summary.json'
metrics_csv_path = run_root / 'metrics.csv'

for directory in [run_root, checkpoints_dir, exports_dir, preview_dir]:
    directory.mkdir(parents=True, exist_ok=True)

set_global_seed(cfg.seed)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
if device.type == 'cuda':
    torch.backends.cudnn.benchmark = True
    if hasattr(torch.backends.cuda.matmul, 'allow_tf32'):
        torch.backends.cuda.matmul.allow_tf32 = True
    if hasattr(torch.backends.cudnn, 'allow_tf32'):
        torch.backends.cudnn.allow_tf32 = True
    if hasattr(torch, 'set_float32_matmul_precision'):
        torch.set_float32_matmul_precision('high')

print({
    'device': str(device),
    'data_root': str(data_root),
    'runs_root': str(runs_root),
    'run_root': str(run_root),
    'config': asdict(cfg),
})
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# {'device': 'cuda', 'data_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/Data', 'runs_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs', 'run_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/072607_2504_base', 'config': {'model_id': 'tinysrcnn_noadd_lrelu', 'run_slug': 'base', 'enable_resume': True, 'resume_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/062123_2504_base/checkpoints/last.pth', 'seed': 1337, 'train_patch_size': 256, 'eval_size': 256, 'batch_size': 16, 'epochs': 1000, 'lr': 0.0001, 'min_lr': 1e-06, 'weight_decay': 0.0001, 'warmup_epochs': 8, 'num_workers': 2, 'prefetch_factor': 2, 'use_amp': True, 'use_ema': True, 'ema_decay': 0.999}}

# %% [markdown]
# ## 2. Data

# %%
L3_TRAIN_SPLITS = (
    ('LR_HR/L3_HR_train1', 'L3_LR/L3_L3_train1', 'L3_HR_train1'),
    ('LR_HR/L3_HR_train2', 'L3_LR/L3_L3_train2', 'L3_HR_train2'),
    ('LR_HR/L3_HR_train3', 'L3_LR/L3_LR_train3', 'L3_HR_train3'),
    ('LR_HR/L3_HR_train4', 'L3_LR/L3_LR_train4', 'L3_HR_train4'),
    ('LR_HR/L3_HR_train', 'L3_LR/L3_LR_train', 'L3_HR_train'),
)
L3_VAL_DIRS = ('L3_HR_valid', 'L3_LR_valid')


def scan_image_directory(directory: Path) -> dict[str, Path]:
    if not directory.exists():
        raise FileNotFoundError(f'Missing directory: {directory}')
    return {
        path.stem: path
        for path in directory.iterdir()
        if path.is_file() and path.suffix.lower() in IMAGE_SUFFIXES
    }


def collect_split_pairs(hr_dir: Path, lr_dir: Path, split_name: str) -> list[tuple[Path, Path, str]]:
    hr_map = scan_image_directory(hr_dir)
    lr_map = scan_image_directory(lr_dir)
    pairs: list[tuple[Path, Path, str]] = []
    for stem in sorted(set(hr_map) & set(lr_map)):
        name = stem if split_name == 'val' else f'{split_name}/{stem}'
        pairs.append((lr_map[stem], hr_map[stem], name))
    return pairs


def collect_all_pairs(data_root: Path) -> tuple[list[tuple[Path, Path, str]], list[tuple[Path, Path, str]]]:
    train_pairs: list[tuple[Path, Path, str]] = []
    for hr_rel, lr_rel, split_name in L3_TRAIN_SPLITS:
        train_pairs.extend(collect_split_pairs(data_root / hr_rel, data_root / lr_rel, split_name))
    val_pairs = collect_split_pairs(data_root / L3_VAL_DIRS[0], data_root / L3_VAL_DIRS[1], 'val')
    return train_pairs, val_pairs


class PairedSRDataset(Dataset):
    def __init__(self, pairs: list[tuple[Path, Path, str]], *, train: bool, patch_size: int, eval_size: int, seed: int):
        self.pairs = pairs
        self.train = train
        self.patch_size = patch_size
        self.eval_size = eval_size
        self.seed = seed
        self.epoch = 0

    def set_epoch(self, epoch: int) -> None:
        self.epoch = epoch

    @staticmethod
    def to_tensor(img: Image.Image) -> torch.Tensor:
        arr = np.asarray(img, dtype=np.float32) / 255.0
        return torch.from_numpy(arr).permute(2, 0, 1).contiguous()

    def augment_pair(self, lr: Image.Image, hr: Image.Image, index: int) -> tuple[Image.Image, Image.Image]:
        rng = random.Random((self.seed * 1_000_003) + (self.epoch * 9_973) + index)
        width, height = lr.size
        patch = self.patch_size
        if width < patch or height < patch:
            lr = lr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            hr = hr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            width, height = lr.size
        left = rng.randint(0, width - patch)
        top = rng.randint(0, height - patch)
        box = (left, top, left + patch, top + patch)
        lr = lr.crop(box)
        hr = hr.crop(box)
        if rng.random() < 0.5:
            lr = lr.transpose(FLIP_LEFT_RIGHT)
            hr = hr.transpose(FLIP_LEFT_RIGHT)
        if rng.random() < 0.5:
            lr = lr.transpose(FLIP_TOP_BOTTOM)
            hr = hr.transpose(FLIP_TOP_BOTTOM)
        rot = rng.choice([0, 1, 2, 3])
        if rot:
            rotate_ops = [ROTATE_90, ROTATE_180, ROTATE_270]
            lr = lr.transpose(rotate_ops[rot - 1])
            hr = hr.transpose(rotate_ops[rot - 1])
        return lr, hr

    def __len__(self) -> int:
        return len(self.pairs)

    def __getitem__(self, index: int) -> dict[str, Any]:
        lr_path, hr_path, name = self.pairs[index]
        lr = Image.open(lr_path).convert('RGB')
        hr = Image.open(hr_path).convert('RGB')
        if self.train:
            lr, hr = self.augment_pair(lr, hr, index)
        elif lr.size != (self.eval_size, self.eval_size):
            lr = lr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            hr = hr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
        return {'lr': self.to_tensor(lr), 'hr': self.to_tensor(hr), 'name': name}


train_pairs, val_pairs = collect_all_pairs(data_root)
if not train_pairs:
    raise FileNotFoundError(f'No training pairs found under {data_root}')
if not val_pairs:
    raise FileNotFoundError(f'No validation pairs found under {data_root}')
print({
    'data_root': str(data_root),
    'train_pairs': len(train_pairs),
    'val_pairs': len(val_pairs),
})

train_ds = PairedSRDataset(train_pairs, train=True, patch_size=cfg.train_patch_size, eval_size=cfg.eval_size, seed=cfg.seed)
val_ds = PairedSRDataset(val_pairs, train=False, patch_size=cfg.train_patch_size, eval_size=cfg.eval_size, seed=cfg.seed)

loader_num_workers = cfg.num_workers if cfg.num_workers is not None else auto_num_workers(in_colab)
train_loader_kwargs = {
    'dataset': train_ds,
    'batch_size': cfg.batch_size,
    'shuffle': True,
    'num_workers': loader_num_workers,
    'pin_memory': device.type == 'cuda',
}
val_loader_kwargs = {
    'dataset': val_ds,
    'batch_size': 1,
    'shuffle': False,
    'num_workers': loader_num_workers,
    'pin_memory': device.type == 'cuda',
}
if loader_num_workers > 0:
    train_loader_kwargs['prefetch_factor'] = cfg.prefetch_factor
    val_loader_kwargs['prefetch_factor'] = cfg.prefetch_factor

train_loader = DataLoader(**train_loader_kwargs)
val_loader = DataLoader(**val_loader_kwargs)

sample_batch = next(iter(val_loader))
print({
    'validation_input_shape': tuple(sample_batch['lr'].shape),
    'validation_target_shape': tuple(sample_batch['hr'].shape),
    'sample_name': sample_batch['name'][0],
})
# Out:
# {'data_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/Data', 'train_pairs': 2217, 'val_pairs': 110}
# {'validation_input_shape': (1, 3, 256, 256), 'validation_target_shape': (1, 3, 256, 256), 'sample_name': '0000'}

# %% [markdown]
# ## 3. Model and Training

# %%
class TinySRCNNNoAdd(nn.Module):
    def __init__(self, channels: int = 64, slope: float = 0.1):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(3, channels, 3, padding=1),
            nn.LeakyReLU(slope, inplace=False),
            nn.Conv2d(channels, channels, 3, padding=1),
            nn.LeakyReLU(slope, inplace=False),
            nn.Conv2d(channels, channels, 3, padding=1),
            nn.LeakyReLU(slope, inplace=False),
            nn.Conv2d(channels, channels, 3, padding=1),
            nn.LeakyReLU(slope, inplace=False),
            nn.Conv2d(channels, 3, 3, padding=1),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.net(x)


def count_parameters(module: nn.Module) -> int:
    return int(sum(param.numel() for param in module.parameters()))


class EMA:
    def __init__(self, model: nn.Module, decay: float):
        self.decay = decay
        self.shadow = {k: v.detach().clone() for k, v in model.state_dict().items()}

    @torch.no_grad()
    def update(self, model: nn.Module) -> None:
        for key, value in model.state_dict().items():
            self.shadow[key].mul_(self.decay).add_(value.detach(), alpha=1.0 - self.decay)

    @torch.no_grad()
    def copy_to(self, model: nn.Module) -> None:
        model.load_state_dict(self.shadow, strict=True)


def make_grad_scaler(enabled: bool):
    if hasattr(torch, 'amp') and hasattr(torch.amp, 'GradScaler'):
        return torch.amp.GradScaler('cuda', enabled=enabled)
    return torch.cuda.amp.GradScaler(enabled=enabled)


def autocast_context(device_type: str, enabled: bool):
    if not enabled:
        return nullcontext()
    if hasattr(torch, 'amp') and hasattr(torch.amp, 'autocast'):
        return torch.amp.autocast(device_type=device_type, enabled=enabled)
    return torch.cuda.amp.autocast(enabled=enabled)


@torch.no_grad()
def batch_psnr(pred: torch.Tensor, target: torch.Tensor) -> float:
    mse = F.mse_loss(pred, target, reduction='none').mean(dim=(1, 2, 3))
    psnr = 10.0 * torch.log10(1.0 / torch.clamp(mse, min=1e-12))
    return float(psnr.mean().item())


def compute_loss(pred: torch.Tensor, hr: torch.Tensor) -> torch.Tensor:
    loss_mse = F.mse_loss(pred, hr)
    loss_l1 = F.l1_loss(pred, hr)
    return 0.8 * loss_mse + 0.2 * loss_l1


def lr_at_epoch(epoch_idx: int, *, base_lr: float, min_lr: float, warmup_epochs: int, total_epochs: int) -> float:
    step = epoch_idx + 1
    if warmup_epochs > 0 and step <= warmup_epochs:
        return base_lr * step / max(1, warmup_epochs)
    progress = max(0.0, (step - warmup_epochs) / max(1, total_epochs - warmup_epochs))
    cosine = 0.5 * (1.0 + math.cos(math.pi * min(progress, 1.0)))
    return min_lr + cosine * (base_lr - min_lr)


@torch.inference_mode()
def evaluate_psnr(model: nn.Module, loader: DataLoader, device: torch.device) -> float:
    model.eval()
    meter = 0.0
    count = 0
    for batch in loader:
        lr = batch['lr'].to(device, non_blocking=(device.type == 'cuda'))
        hr = batch['hr'].to(device, non_blocking=(device.type == 'cuda'))
        pred = model(lr).clamp(0.0, 1.0)
        meter += batch_psnr(pred, hr)
        count += 1
    return meter / max(count, 1)


@torch.inference_mode()
def compute_input_psnr(loader: DataLoader, device: torch.device) -> float:
    meter = 0.0
    count = 0
    for batch in loader:
        lr = batch['lr'].to(device, non_blocking=(device.type == 'cuda'))
        hr = batch['hr'].to(device, non_blocking=(device.type == 'cuda'))
        meter += batch_psnr(lr, hr)
        count += 1
    return meter / max(count, 1)


def tensor_to_uint8_image(x: torch.Tensor) -> Image.Image:
    x = x.detach().cpu().clamp(0.0, 1.0)
    arr = (x.permute(1, 2, 0).numpy() * 255.0).round().astype(np.uint8)
    return Image.fromarray(arr)


@torch.no_grad()
def write_val_preview(model: nn.Module, loader: DataLoader, out_dir: Path, device: torch.device) -> dict[str, str]:
    out_dir.mkdir(parents=True, exist_ok=True)
    batch = next(iter(loader))
    lr = batch['lr'].to(device, non_blocking=(device.type == 'cuda'))
    hr = batch['hr'].to(device, non_blocking=(device.type == 'cuda'))
    pred = model(lr).clamp(0.0, 1.0)
    name = batch['name'][0]
    lr_path = out_dir / 'val_preview_input.png'
    pred_path = out_dir / 'val_preview_pred.png'
    hr_path = out_dir / 'val_preview_target.png'
    tensor_to_uint8_image(lr[0]).save(lr_path)
    tensor_to_uint8_image(pred[0]).save(pred_path)
    tensor_to_uint8_image(hr[0]).save(hr_path)
    return {
        'sample_name': str(name),
        'input': str(lr_path),
        'prediction': str(pred_path),
        'target': str(hr_path),
    }


def checkpoint_payload(model: nn.Module, ema: EMA | None, optimizer: torch.optim.Optimizer, epoch: int, best_val_psnr: float, row: dict[str, Any]) -> dict[str, Any]:
    return {
        'config': asdict(cfg),
        'epoch': int(epoch),
        'model_state_dict': model.state_dict(),
        'ema_state_dict': ema.shadow if ema is not None else None,
        'optimizer_state_dict': optimizer.state_dict(),
        'best_val_psnr': float(best_val_psnr),
        'selected_weight_source': 'ema' if ema is not None else 'raw',
        'last_metrics': row,
    }


def build_eval_model_from_checkpoint(checkpoint_path: Path, device: torch.device) -> nn.Module:
    checkpoint = torch.load(checkpoint_path, map_location=device)
    model = TinySRCNNNoAdd().to(device)
    selected = checkpoint.get('selected_weight_source', 'raw')
    ema_state = checkpoint.get('ema_state_dict')
    if selected == 'ema' and ema_state is not None:
        model.load_state_dict(ema_state, strict=True)
    else:
        model.load_state_dict(checkpoint['model_state_dict'], strict=True)
    model.eval()
    return model


model = TinySRCNNNoAdd().to(device)
eval_model = TinySRCNNNoAdd().to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)
scaler = make_grad_scaler(enabled=(cfg.use_amp and device.type == 'cuda'))
ema = EMA(model, decay=cfg.ema_decay) if cfg.use_ema else None
start_epoch = 0
best_val_psnr = float('-inf')
if cfg.enable_resume and cfg.resume_checkpoint_path:
    checkpoint = torch.load(cfg.resume_checkpoint_path, map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'], strict=True)
    optimizer_state = checkpoint.get('optimizer_state_dict')
    if optimizer_state is not None:
        optimizer.load_state_dict(optimizer_state)
    ema_state = checkpoint.get('ema_state_dict')
    if ema is not None and ema_state is not None:
        ema.shadow = {key: value.detach().clone() for key, value in ema_state.items()}
    start_epoch = int(checkpoint.get('epoch', 0))
    best_val_psnr = float(checkpoint.get('best_val_psnr', float('-inf')))
if ema is not None:
    ema.copy_to(eval_model)
else:
    eval_model.load_state_dict(model.state_dict())

model_parameter_count = count_parameters(model)
print({
    'model_id': cfg.model_id,
    'architecture': 'Conv3x3(3->64) x4 with LeakyReLU, final Conv3x3(64->3), no Add',
    'params': model_parameter_count,
    'resume_checkpoint_path': cfg.resume_checkpoint_path,
    'start_epoch': start_epoch,
})

input_psnr = compute_input_psnr(val_loader, device)
print({'baseline_input_psnr': input_psnr})
# Out:
# {'model_id': 'tinysrcnn_noadd_lrelu', 'architecture': 'Conv3x3(3->64) x4 with LeakyReLU, final Conv3x3(64->3), no Add', 'params': 114307, 'resume_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/062123_2504_base/checkpoints/last.pth', 'start_epoch': 140}
# {'baseline_input_psnr': 23.133060299266468}

# %%
metrics_header = [
    'epoch',
    'epoch_time_sec',
    'lr',
    'train_loss',
    'train_psnr',
    'val_psnr',
    'best_val_psnr',
]

best_ckpt_path = checkpoints_dir / 'best.pth'
last_ckpt_path = checkpoints_dir / 'last.pth'

with metrics_csv_path.open('w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=metrics_header)
    writer.writeheader()

for epoch in range(start_epoch, cfg.epochs):
    train_ds.set_epoch(epoch)
    epoch_lr = lr_at_epoch(
        epoch,
        base_lr=cfg.lr,
        min_lr=cfg.min_lr,
        warmup_epochs=cfg.warmup_epochs,
        total_epochs=cfg.epochs,
    )
    for group in optimizer.param_groups:
        group['lr'] = epoch_lr

    epoch_start = time.time()
    model.train()
    train_loss_sum = 0.0
    train_psnr_sum = 0.0
    train_batches = 0

    for batch in train_loader:
        lr = batch['lr'].to(device, non_blocking=(device.type == 'cuda'))
        hr = batch['hr'].to(device, non_blocking=(device.type == 'cuda'))

        optimizer.zero_grad(set_to_none=True)
        with autocast_context(device.type, enabled=(cfg.use_amp and device.type == 'cuda')):
            pred = model(lr)
            loss = compute_loss(pred, hr)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        if ema is not None:
            ema.update(model)

        train_loss_sum += float(loss.item())
        train_psnr_sum += batch_psnr(pred.detach().clamp(0.0, 1.0), hr)
        train_batches += 1

    if ema is not None:
        ema.copy_to(eval_model)
    else:
        eval_model.load_state_dict(model.state_dict())
    eval_model.eval()

    avg_train_loss = train_loss_sum / max(train_batches, 1)
    avg_train_psnr = train_psnr_sum / max(train_batches, 1)
    val_psnr = evaluate_psnr(eval_model, val_loader, device)
    epoch_time = time.time() - epoch_start
    is_best = val_psnr > best_val_psnr
    if is_best:
        best_val_psnr = val_psnr

    row = {
        'epoch': epoch + 1,
        'epoch_time_sec': round(epoch_time, 2),
        'lr': epoch_lr,
        'train_loss': round(avg_train_loss, 6),
        'train_psnr': round(avg_train_psnr, 4),
        'val_psnr': round(val_psnr, 4),
        'best_val_psnr': round(best_val_psnr, 4),
    }
    print(row)

    with metrics_csv_path.open('a', newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=metrics_header)
        writer.writerow(row)

    payload = checkpoint_payload(model, ema, optimizer, epoch + 1, best_val_psnr, row)
    torch.save(payload, last_ckpt_path)
    if is_best:
        torch.save(payload, best_ckpt_path)
# Out:
# {'epoch': 141, 'epoch_time_sec': 29.28, 'lr': 9.567362000786297e-05, 'train_loss': 0.012438, 'train_psnr': 24.6638, 'val_psnr': 23.5264, 'best_val_psnr': 23.5264}
# {'epoch': 142, 'epoch_time_sec': 12.62, 'lr': 9.560929992954543e-05, 'train_loss': 0.012358, 'train_psnr': 24.7002, 'val_psnr': 23.5271, 'best_val_psnr': 23.5271}
# {'epoch': 143, 'epoch_time_sec': 12.53, 'lr': 9.554452743088428e-05, 'train_loss': 0.01238, 'train_psnr': 24.6908, 'val_psnr': 23.5278, 'best_val_psnr': 23.5278}
# {'epoch': 144, 'epoch_time_sec': 12.91, 'lr': 9.547930316151043e-05, 'train_loss': 0.012381, 'train_psnr': 24.691, 'val_psnr': 23.5287, 'best_val_psnr': 23.5287}
# {'epoch': 145, 'epoch_time_sec': 12.74, 'lr': 9.541362777558584e-05, 'train_loss': 0.012347, 'train_psnr': 24.706, 'val_psnr': 23.5295, 'best_val_psnr': 23.5295}
# {'epoch': 146, 'epoch_time_sec': 12.58, 'lr': 9.534750193179683e-05, 'train_loss': 0.012354, 'train_psnr': 24.7033, 'val_psnr': 23.5304, 'best_val_psnr': 23.5304}
# {'epoch': 147, 'epoch_time_sec': 12.68, 'lr': 9.528092629334762e-05, 'train_loss': 0.012364, 'train_psnr': 24.6996, 'val_psnr': 23.5314, 'best_val_psnr': 23.5314}
# {'epoch': 148, 'epoch_time_sec': 12.64, 'lr': 9.521390152795357e-05, 'train_loss': 0.012332, 'train_psnr': 24.7133, 'val_psnr': 23.5322, 'best_val_psnr': 23.5322}
# {'epoch': 149, 'epoch_time_sec': 12.53, 'lr': 9.514642830783455e-05, 'train_loss': 0.01236, 'train_psnr': 24.7022, 'val_psnr': 23.5332, 'best_val_psnr': 23.5332}
# {'epoch': 150, 'epoch_time_sec': 12.73, 'lr': 9.507850730970819e-05, 'train_loss': 0.01234, 'train_psnr': 24.7113, 'val_psnr': 23.5341, 'best_val_psnr': 23.5341}
# {'epoch': 151, 'epoch_time_sec': 12.6, 'lr': 9.501013921478301e-05, 'train_loss': 0.012418, 'train_psnr': 24.672, 'val_psnr': 23.535, 'best_val_psnr': 23.535}
# {'epoch': 152, 'epoch_time_sec': 12.57, 'lr': 9.494132470875172e-05, 'train_loss': 0.012341, 'train_psnr': 24.7103, 'val_psnr': 23.5358, 'best_val_psnr': 23.5358}
# {'epoch': 153, 'epoch_time_sec': 12.51, 'lr': 9.487206448178425e-05, 'train_loss': 0.012318, 'train_psnr': 24.723, 'val_psnr': 23.5368, 'best_val_psnr': 23.5368}
# {'epoch': 154, 'epoch_time_sec': 12.58, 'lr': 9.480235922852084e-05, 'train_loss': 0.012328, 'train_psnr': 24.7177, 'val_psnr': 23.5377, 'best_val_psnr': 23.5377}
# {'epoch': 155, 'epoch_time_sec': 12.76, 'lr': 9.473220964806512e-05, 'train_loss': 0.012335, 'train_psnr': 24.7149, 'val_psnr': 23.5388, 'best_val_psnr': 23.5388}
# {'epoch': 156, 'epoch_time_sec': 12.58, 'lr': 9.466161644397706e-05, 'train_loss': 0.012355, 'train_psnr': 24.7069, 'val_psnr': 23.5397, 'best_val_psnr': 23.5397}
# {'epoch': 157, 'epoch_time_sec': 12.74, 'lr': 9.459058032426588e-05, 'train_loss': 0.012324, 'train_psnr': 24.7195, 'val_psnr': 23.5407, 'best_val_psnr': 23.5407}
# {'epoch': 158, 'epoch_time_sec': 12.47, 'lr': 9.451910200138306e-05, 'train_loss': 0.012333, 'train_psnr': 24.7129, 'val_psnr': 23.5417, 'best_val_psnr': 23.5417}
# {'epoch': 159, 'epoch_time_sec': 12.59, 'lr': 9.444718219221506e-05, 'train_loss': 0.012342, 'train_psnr': 24.7107, 'val_psnr': 23.5427, 'best_val_psnr': 23.5427}
# {'epoch': 160, 'epoch_time_sec': 12.93, 'lr': 9.437482161807622e-05, 'train_loss': 0.012335, 'train_psnr': 24.7151, 'val_psnr': 23.5435, 'best_val_psnr': 23.5435}
# {'epoch': 161, 'epoch_time_sec': 12.79, 'lr': 9.430202100470148e-05, 'train_loss': 0.012373, 'train_psnr': 24.6976, 'val_psnr': 23.5443, 'best_val_psnr': 23.5443}
# {'epoch': 162, 'epoch_time_sec': 12.57, 'lr': 9.422878108223916e-05, 'train_loss': 0.012333, 'train_psnr': 24.7177, 'val_psnr': 23.5451, 'best_val_psnr': 23.5451}
# {'epoch': 163, 'epoch_time_sec': 12.66, 'lr': 9.415510258524357e-05, 'train_loss': 0.012331, 'train_psnr': 24.7161, 'val_psnr': 23.5461, 'best_val_psnr': 23.5461}
# {'epoch': 164, 'epoch_time_sec': 12.72, 'lr': 9.408098625266768e-05, 'train_loss': 0.012324, 'train_psnr': 24.7205, 'val_psnr': 23.5471, 'best_val_psnr': 23.5471}
# {'epoch': 165, 'epoch_time_sec': 12.86, 'lr': 9.400643282785568e-05, 'train_loss': 0.01231, 'train_psnr': 24.7263, 'val_psnr': 23.5481, 'best_val_psnr': 23.5481}
# {'epoch': 166, 'epoch_time_sec': 12.9, 'lr': 9.393144305853557e-05, 'train_loss': 0.012303, 'train_psnr': 24.7295, 'val_psnr': 23.549, 'best_val_psnr': 23.549}
# {'epoch': 167, 'epoch_time_sec': 12.67, 'lr': 9.385601769681162e-05, 'train_loss': 0.012309, 'train_psnr': 24.7274, 'val_psnr': 23.5499, 'best_val_psnr': 23.5499}
# {'epoch': 168, 'epoch_time_sec': 12.45, 'lr': 9.378015749915682e-05, 'train_loss': 0.012355, 'train_psnr': 24.7043, 'val_psnr': 23.5508, 'best_val_psnr': 23.5508}
# {'epoch': 169, 'epoch_time_sec': 12.38, 'lr': 9.370386322640538e-05, 'train_loss': 0.012333, 'train_psnr': 24.7165, 'val_psnr': 23.5517, 'best_val_psnr': 23.5517}
# {'epoch': 170, 'epoch_time_sec': 12.75, 'lr': 9.362713564374495e-05, 'train_loss': 0.012304, 'train_psnr': 24.7299, 'val_psnr': 23.5526, 'best_val_psnr': 23.5526}
# {'epoch': 171, 'epoch_time_sec': 12.37, 'lr': 9.35499755207091e-05, 'train_loss': 0.012325, 'train_psnr': 24.7194, 'val_psnr': 23.5534, 'best_val_psnr': 23.5534}
# {'epoch': 172, 'epoch_time_sec': 12.36, 'lr': 9.34723836311695e-05, 'train_loss': 0.01229, 'train_psnr': 24.7371, 'val_psnr': 23.5543, 'best_val_psnr': 23.5543}
# {'epoch': 173, 'epoch_time_sec': 12.52, 'lr': 9.339436075332819e-05, 'train_loss': 0.012353, 'train_psnr': 24.7069, 'val_psnr': 23.555, 'best_val_psnr': 23.555}
# {'epoch': 174, 'epoch_time_sec': 12.52, 'lr': 9.331590766970976e-05, 'train_loss': 0.012306, 'train_psnr': 24.7286, 'val_psnr': 23.5558, 'best_val_psnr': 23.5558}
# {'epoch': 175, 'epoch_time_sec': 12.58, 'lr': 9.323702516715355e-05, 'train_loss': 0.012328, 'train_psnr': 24.7188, 'val_psnr': 23.5567, 'best_val_psnr': 23.5567}
# {'epoch': 176, 'epoch_time_sec': 12.92, 'lr': 9.315771403680572e-05, 'train_loss': 0.012299, 'train_psnr': 24.7323, 'val_psnr': 23.5576, 'best_val_psnr': 23.5576}
# {'epoch': 177, 'epoch_time_sec': 12.71, 'lr': 9.307797507411129e-05, 'train_loss': 0.012318, 'train_psnr': 24.7238, 'val_psnr': 23.5585, 'best_val_psnr': 23.5585}
# {'epoch': 178, 'epoch_time_sec': 12.66, 'lr': 9.29978090788062e-05, 'train_loss': 0.012296, 'train_psnr': 24.7335, 'val_psnr': 23.5594, 'best_val_psnr': 23.5594}
# {'epoch': 179, 'epoch_time_sec': 12.7, 'lr': 9.29172168549093e-05, 'train_loss': 0.0123, 'train_psnr': 24.7314, 'val_psnr': 23.5601, 'best_val_psnr': 23.5601}
# {'epoch': 180, 'epoch_time_sec': 12.58, 'lr': 9.283619921071431e-05, 'train_loss': 0.012325, 'train_psnr': 24.724, 'val_psnr': 23.561, 'best_val_psnr': 23.561}
# {'epoch': 181, 'epoch_time_sec': 12.84, 'lr': 9.275475695878154e-05, 'train_loss': 0.012297, 'train_psnr': 24.7352, 'val_psnr': 23.5619, 'best_val_psnr': 23.5619}
# {'epoch': 182, 'epoch_time_sec': 12.97, 'lr': 9.267289091593003e-05, 'train_loss': 0.012348, 'train_psnr': 24.7144, 'val_psnr': 23.5627, 'best_val_psnr': 23.5627}
# {'epoch': 183, 'epoch_time_sec': 12.74, 'lr': 9.259060190322907e-05, 'train_loss': 0.012286, 'train_psnr': 24.7399, 'val_psnr': 23.5634, 'best_val_psnr': 23.5634}
# {'epoch': 184, 'epoch_time_sec': 13.01, 'lr': 9.250789074599018e-05, 'train_loss': 0.012309, 'train_psnr': 24.7302, 'val_psnr': 23.5642, 'best_val_psnr': 23.5642}
# {'epoch': 185, 'epoch_time_sec': 12.79, 'lr': 9.242475827375869e-05, 'train_loss': 0.012368, 'train_psnr': 24.7014, 'val_psnr': 23.5649, 'best_val_psnr': 23.5649}
# {'epoch': 186, 'epoch_time_sec': 12.59, 'lr': 9.23412053203055e-05, 'train_loss': 0.01232, 'train_psnr': 24.7268, 'val_psnr': 23.5655, 'best_val_psnr': 23.5655}
# {'epoch': 187, 'epoch_time_sec': 12.69, 'lr': 9.225723272361872e-05, 'train_loss': 0.012293, 'train_psnr': 24.7368, 'val_psnr': 23.5663, 'best_val_psnr': 23.5663}
# {'epoch': 188, 'epoch_time_sec': 12.66, 'lr': 9.217284132589519e-05, 'train_loss': 0.012284, 'train_psnr': 24.7403, 'val_psnr': 23.5671, 'best_val_psnr': 23.5671}
# {'epoch': 189, 'epoch_time_sec': 12.45, 'lr': 9.208803197353213e-05, 'train_loss': 0.012277, 'train_psnr': 24.7435, 'val_psnr': 23.5679, 'best_val_psnr': 23.5679}
# {'epoch': 190, 'epoch_time_sec': 12.57, 'lr': 9.200280551711857e-05, 'train_loss': 0.012288, 'train_psnr': 24.7404, 'val_psnr': 23.5687, 'best_val_psnr': 23.5687}
# {'epoch': 191, 'epoch_time_sec': 12.65, 'lr': 9.191716281142689e-05, 'train_loss': 0.012282, 'train_psnr': 24.7427, 'val_psnr': 23.5694, 'best_val_psnr': 23.5694}
# {'epoch': 192, 'epoch_time_sec': 12.65, 'lr': 9.183110471540418e-05, 'train_loss': 0.012291, 'train_psnr': 24.7369, 'val_psnr': 23.5702, 'best_val_psnr': 23.5702}
# {'epoch': 193, 'epoch_time_sec': 12.77, 'lr': 9.174463209216365e-05, 'train_loss': 0.012305, 'train_psnr': 24.7301, 'val_psnr': 23.5708, 'best_val_psnr': 23.5708}
# {'epoch': 194, 'epoch_time_sec': 12.77, 'lr': 9.1657745808976e-05, 'train_loss': 0.012322, 'train_psnr': 24.7232, 'val_psnr': 23.5716, 'best_val_psnr': 23.5716}
# {'epoch': 195, 'epoch_time_sec': 12.71, 'lr': 9.157044673726072e-05, 'train_loss': 0.012327, 'train_psnr': 24.7193, 'val_psnr': 23.5722, 'best_val_psnr': 23.5722}
# {'epoch': 196, 'epoch_time_sec': 12.63, 'lr': 9.148273575257727e-05, 'train_loss': 0.012288, 'train_psnr': 24.7418, 'val_psnr': 23.5728, 'best_val_psnr': 23.5728}
# {'epoch': 197, 'epoch_time_sec': 12.7, 'lr': 9.139461373461642e-05, 'train_loss': 0.012273, 'train_psnr': 24.7462, 'val_psnr': 23.5736, 'best_val_psnr': 23.5736}
# {'epoch': 198, 'epoch_time_sec': 12.71, 'lr': 9.130608156719137e-05, 'train_loss': 0.012273, 'train_psnr': 24.7459, 'val_psnr': 23.5743, 'best_val_psnr': 23.5743}
# {'epoch': 199, 'epoch_time_sec': 12.92, 'lr': 9.121714013822883e-05, 'train_loss': 0.012298, 'train_psnr': 24.7369, 'val_psnr': 23.575, 'best_val_psnr': 23.575}
# {'epoch': 200, 'epoch_time_sec': 12.8, 'lr': 9.112779033976019e-05, 'train_loss': 0.012287, 'train_psnr': 24.7381, 'val_psnr': 23.5757, 'best_val_psnr': 23.5757}
# {'epoch': 201, 'epoch_time_sec': 12.69, 'lr': 9.103803306791258e-05, 'train_loss': 0.012303, 'train_psnr': 24.7339, 'val_psnr': 23.5764, 'best_val_psnr': 23.5764}
# {'epoch': 202, 'epoch_time_sec': 12.67, 'lr': 9.094786922289982e-05, 'train_loss': 0.012271, 'train_psnr': 24.746, 'val_psnr': 23.5771, 'best_val_psnr': 23.5771}
# {'epoch': 203, 'epoch_time_sec': 12.63, 'lr': 9.085729970901344e-05, 'train_loss': 0.012271, 'train_psnr': 24.7478, 'val_psnr': 23.5778, 'best_val_psnr': 23.5778}
# {'epoch': 204, 'epoch_time_sec': 12.57, 'lr': 9.07663254346136e-05, 'train_loss': 0.012266, 'train_psnr': 24.7497, 'val_psnr': 23.5786, 'best_val_psnr': 23.5786}
# {'epoch': 205, 'epoch_time_sec': 12.76, 'lr': 9.067494731211998e-05, 'train_loss': 0.012282, 'train_psnr': 24.744, 'val_psnr': 23.5792, 'best_val_psnr': 23.5792}
# {'epoch': 206, 'epoch_time_sec': 12.57, 'lr': 9.058316625800257e-05, 'train_loss': 0.012265, 'train_psnr': 24.752, 'val_psnr': 23.5798, 'best_val_psnr': 23.5798}
# {'epoch': 207, 'epoch_time_sec': 12.82, 'lr': 9.049098319277262e-05, 'train_loss': 0.012268, 'train_psnr': 24.7507, 'val_psnr': 23.5805, 'best_val_psnr': 23.5805}
# {'epoch': 208, 'epoch_time_sec': 12.86, 'lr': 9.039839904097326e-05, 'train_loss': 0.01228, 'train_psnr': 24.7442, 'val_psnr': 23.5812, 'best_val_psnr': 23.5812}
# {'epoch': 209, 'epoch_time_sec': 13.43, 'lr': 9.030541473117029e-05, 'train_loss': 0.012277, 'train_psnr': 24.7456, 'val_psnr': 23.582, 'best_val_psnr': 23.582}
# {'epoch': 210, 'epoch_time_sec': 12.72, 'lr': 9.021203119594289e-05, 'train_loss': 0.012261, 'train_psnr': 24.7543, 'val_psnr': 23.5827, 'best_val_psnr': 23.5827}
# {'epoch': 211, 'epoch_time_sec': 12.5, 'lr': 9.011824937187422e-05, 'train_loss': 0.01226, 'train_psnr': 24.7544, 'val_psnr': 23.5833, 'best_val_psnr': 23.5833}
# {'epoch': 212, 'epoch_time_sec': 12.64, 'lr': 9.002407019954208e-05, 'train_loss': 0.012265, 'train_psnr': 24.7512, 'val_psnr': 23.5841, 'best_val_psnr': 23.5841}
# {'epoch': 213, 'epoch_time_sec': 12.73, 'lr': 8.99294946235094e-05, 'train_loss': 0.012281, 'train_psnr': 24.7442, 'val_psnr': 23.5847, 'best_val_psnr': 23.5847}
# {'epoch': 214, 'epoch_time_sec': 12.77, 'lr': 8.983452359231483e-05, 'train_loss': 0.012261, 'train_psnr': 24.7533, 'val_psnr': 23.5853, 'best_val_psnr': 23.5853}
# {'epoch': 215, 'epoch_time_sec': 12.88, 'lr': 8.973915805846325e-05, 'train_loss': 0.012255, 'train_psnr': 24.7553, 'val_psnr': 23.5861, 'best_val_psnr': 23.5861}
# {'epoch': 216, 'epoch_time_sec': 12.91, 'lr': 8.964339897841607e-05, 'train_loss': 0.012258, 'train_psnr': 24.7543, 'val_psnr': 23.5866, 'best_val_psnr': 23.5866}
# {'epoch': 217, 'epoch_time_sec': 12.67, 'lr': 8.954724731258189e-05, 'train_loss': 0.012252, 'train_psnr': 24.7564, 'val_psnr': 23.5873, 'best_val_psnr': 23.5873}
# {'epoch': 218, 'epoch_time_sec': 12.72, 'lr': 8.945070402530655e-05, 'train_loss': 0.01225, 'train_psnr': 24.7584, 'val_psnr': 23.588, 'best_val_psnr': 23.588}
# {'epoch': 219, 'epoch_time_sec': 12.7, 'lr': 8.93537700848638e-05, 'train_loss': 0.012262, 'train_psnr': 24.753, 'val_psnr': 23.5887, 'best_val_psnr': 23.5887}
# {'epoch': 220, 'epoch_time_sec': 12.69, 'lr': 8.925644646344526e-05, 'train_loss': 0.012253, 'train_psnr': 24.7582, 'val_psnr': 23.5893, 'best_val_psnr': 23.5893}
# {'epoch': 221, 'epoch_time_sec': 12.6, 'lr': 8.915873413715093e-05, 'train_loss': 0.012263, 'train_psnr': 24.7523, 'val_psnr': 23.59, 'best_val_psnr': 23.59}
# {'epoch': 222, 'epoch_time_sec': 13.0, 'lr': 8.906063408597928e-05, 'train_loss': 0.012277, 'train_psnr': 24.7466, 'val_psnr': 23.5906, 'best_val_psnr': 23.5906}
# {'epoch': 223, 'epoch_time_sec': 12.7, 'lr': 8.896214729381741e-05, 'train_loss': 0.012241, 'train_psnr': 24.7628, 'val_psnr': 23.5912, 'best_val_psnr': 23.5912}
# {'epoch': 224, 'epoch_time_sec': 13.03, 'lr': 8.88632747484312e-05, 'train_loss': 0.01226, 'train_psnr': 24.7549, 'val_psnr': 23.5918, 'best_val_psnr': 23.5918}
# {'epoch': 225, 'epoch_time_sec': 13.01, 'lr': 8.876401744145549e-05, 'train_loss': 0.012244, 'train_psnr': 24.761, 'val_psnr': 23.5924, 'best_val_psnr': 23.5924}
# {'epoch': 226, 'epoch_time_sec': 12.62, 'lr': 8.866437636838394e-05, 'train_loss': 0.012268, 'train_psnr': 24.7541, 'val_psnr': 23.5931, 'best_val_psnr': 23.5931}
# {'epoch': 227, 'epoch_time_sec': 12.77, 'lr': 8.856435252855927e-05, 'train_loss': 0.012235, 'train_psnr': 24.7674, 'val_psnr': 23.5938, 'best_val_psnr': 23.5938}
# {'epoch': 228, 'epoch_time_sec': 12.68, 'lr': 8.846394692516306e-05, 'train_loss': 0.012247, 'train_psnr': 24.7604, 'val_psnr': 23.5944, 'best_val_psnr': 23.5944}
# {'epoch': 229, 'epoch_time_sec': 12.55, 'lr': 8.83631605652058e-05, 'train_loss': 0.012239, 'train_psnr': 24.7648, 'val_psnr': 23.595, 'best_val_psnr': 23.595}
# {'epoch': 230, 'epoch_time_sec': 12.75, 'lr': 8.826199445951673e-05, 'train_loss': 0.01226, 'train_psnr': 24.7548, 'val_psnr': 23.5957, 'best_val_psnr': 23.5957}
# {'epoch': 231, 'epoch_time_sec': 12.83, 'lr': 8.816044962273375e-05, 'train_loss': 0.012236, 'train_psnr': 24.7652, 'val_psnr': 23.5962, 'best_val_psnr': 23.5962}
# {'epoch': 232, 'epoch_time_sec': 12.63, 'lr': 8.805852707329315e-05, 'train_loss': 0.012262, 'train_psnr': 24.7548, 'val_psnr': 23.5968, 'best_val_psnr': 23.5968}
# {'epoch': 233, 'epoch_time_sec': 13.14, 'lr': 8.795622783341954e-05, 'train_loss': 0.012242, 'train_psnr': 24.7639, 'val_psnr': 23.5973, 'best_val_psnr': 23.5973}
# {'epoch': 234, 'epoch_time_sec': 12.95, 'lr': 8.785355292911544e-05, 'train_loss': 0.012245, 'train_psnr': 24.7619, 'val_psnr': 23.5979, 'best_val_psnr': 23.5979}
# {'epoch': 235, 'epoch_time_sec': 12.47, 'lr': 8.775050339015117e-05, 'train_loss': 0.012226, 'train_psnr': 24.771, 'val_psnr': 23.5985, 'best_val_psnr': 23.5985}
# {'epoch': 236, 'epoch_time_sec': 12.72, 'lr': 8.76470802500543e-05, 'train_loss': 0.012243, 'train_psnr': 24.7625, 'val_psnr': 23.5988, 'best_val_psnr': 23.5988}
# {'epoch': 237, 'epoch_time_sec': 12.74, 'lr': 8.754328454609949e-05, 'train_loss': 0.012249, 'train_psnr': 24.7613, 'val_psnr': 23.5996, 'best_val_psnr': 23.5996}
# {'epoch': 238, 'epoch_time_sec': 13.0, 'lr': 8.743911731929798e-05, 'train_loss': 0.012225, 'train_psnr': 24.7713, 'val_psnr': 23.6001, 'best_val_psnr': 23.6001}
# {'epoch': 239, 'epoch_time_sec': 12.72, 'lr': 8.733457961438714e-05, 'train_loss': 0.012247, 'train_psnr': 24.7617, 'val_psnr': 23.6007, 'best_val_psnr': 23.6007}
# {'epoch': 240, 'epoch_time_sec': 12.79, 'lr': 8.72296724798201e-05, 'train_loss': 0.012288, 'train_psnr': 24.7435, 'val_psnr': 23.6013, 'best_val_psnr': 23.6013}
# {'epoch': 241, 'epoch_time_sec': 12.62, 'lr': 8.712439696775504e-05, 'train_loss': 0.01222, 'train_psnr': 24.7747, 'val_psnr': 23.6019, 'best_val_psnr': 23.6019}
# {'epoch': 242, 'epoch_time_sec': 13.21, 'lr': 8.701875413404487e-05, 'train_loss': 0.012217, 'train_psnr': 24.7749, 'val_psnr': 23.6024, 'best_val_psnr': 23.6024}
# {'epoch': 243, 'epoch_time_sec': 12.65, 'lr': 8.691274503822645e-05, 'train_loss': 0.012227, 'train_psnr': 24.7724, 'val_psnr': 23.6031, 'best_val_psnr': 23.6031}
# {'epoch': 244, 'epoch_time_sec': 12.44, 'lr': 8.680637074351009e-05, 'train_loss': 0.012243, 'train_psnr': 24.766, 'val_psnr': 23.6036, 'best_val_psnr': 23.6036}
# {'epoch': 245, 'epoch_time_sec': 12.66, 'lr': 8.669963231676877e-05, 'train_loss': 0.012244, 'train_psnr': 24.7626, 'val_psnr': 23.6042, 'best_val_psnr': 23.6042}
# {'epoch': 246, 'epoch_time_sec': 13.11, 'lr': 8.659253082852758e-05, 'train_loss': 0.012241, 'train_psnr': 24.7664, 'val_psnr': 23.6047, 'best_val_psnr': 23.6047}
# {'epoch': 247, 'epoch_time_sec': 12.7, 'lr': 8.648506735295284e-05, 'train_loss': 0.012239, 'train_psnr': 24.7655, 'val_psnr': 23.6054, 'best_val_psnr': 23.6054}
# {'epoch': 248, 'epoch_time_sec': 12.62, 'lr': 8.637724296784145e-05, 'train_loss': 0.012228, 'train_psnr': 24.7712, 'val_psnr': 23.6059, 'best_val_psnr': 23.6059}
# {'epoch': 249, 'epoch_time_sec': 12.82, 'lr': 8.626905875460998e-05, 'train_loss': 0.012286, 'train_psnr': 24.7445, 'val_psnr': 23.6063, 'best_val_psnr': 23.6063}
# {'epoch': 250, 'epoch_time_sec': 12.79, 'lr': 8.616051579828391e-05, 'train_loss': 0.012254, 'train_psnr': 24.7589, 'val_psnr': 23.6068, 'best_val_psnr': 23.6068}
# {'epoch': 251, 'epoch_time_sec': 12.7, 'lr': 8.605161518748667e-05, 'train_loss': 0.012261, 'train_psnr': 24.7547, 'val_psnr': 23.6073, 'best_val_psnr': 23.6073}
# {'epoch': 252, 'epoch_time_sec': 12.64, 'lr': 8.594235801442878e-05, 'train_loss': 0.012217, 'train_psnr': 24.7757, 'val_psnr': 23.6078, 'best_val_psnr': 23.6078}
# {'epoch': 253, 'epoch_time_sec': 12.59, 'lr': 8.58327453748969e-05, 'train_loss': 0.012216, 'train_psnr': 24.7762, 'val_psnr': 23.6082, 'best_val_psnr': 23.6082}
# {'epoch': 254, 'epoch_time_sec': 12.88, 'lr': 8.572277836824273e-05, 'train_loss': 0.012233, 'train_psnr': 24.7711, 'val_psnr': 23.6088, 'best_val_psnr': 23.6088}
# {'epoch': 255, 'epoch_time_sec': 12.49, 'lr': 8.561245809737218e-05, 'train_loss': 0.012214, 'train_psnr': 24.7771, 'val_psnr': 23.6092, 'best_val_psnr': 23.6092}
# {'epoch': 256, 'epoch_time_sec': 12.64, 'lr': 8.55017856687341e-05, 'train_loss': 0.012219, 'train_psnr': 24.7793, 'val_psnr': 23.6098, 'best_val_psnr': 23.6098}
# {'epoch': 257, 'epoch_time_sec': 12.9, 'lr': 8.539076219230936e-05, 'train_loss': 0.012223, 'train_psnr': 24.7729, 'val_psnr': 23.6104, 'best_val_psnr': 23.6104}
# {'epoch': 258, 'epoch_time_sec': 12.91, 'lr': 8.527938878159955e-05, 'train_loss': 0.012225, 'train_psnr': 24.7732, 'val_psnr': 23.6109, 'best_val_psnr': 23.6109}
# {'epoch': 259, 'epoch_time_sec': 12.52, 'lr': 8.516766655361597e-05, 'train_loss': 0.012229, 'train_psnr': 24.7715, 'val_psnr': 23.6114, 'best_val_psnr': 23.6114}
# {'epoch': 260, 'epoch_time_sec': 12.85, 'lr': 8.505559662886832e-05, 'train_loss': 0.012226, 'train_psnr': 24.7738, 'val_psnr': 23.612, 'best_val_psnr': 23.612}
# {'epoch': 261, 'epoch_time_sec': 12.7, 'lr': 8.494318013135353e-05, 'train_loss': 0.012219, 'train_psnr': 24.7776, 'val_psnr': 23.6126, 'best_val_psnr': 23.6126}
# {'epoch': 262, 'epoch_time_sec': 12.82, 'lr': 8.483041818854447e-05, 'train_loss': 0.012214, 'train_psnr': 24.7775, 'val_psnr': 23.6131, 'best_val_psnr': 23.6131}
# {'epoch': 263, 'epoch_time_sec': 12.74, 'lr': 8.471731193137854e-05, 'train_loss': 0.012228, 'train_psnr': 24.7719, 'val_psnr': 23.6137, 'best_val_psnr': 23.6137}
# {'epoch': 264, 'epoch_time_sec': 12.59, 'lr': 8.460386249424649e-05, 'train_loss': 0.012228, 'train_psnr': 24.7716, 'val_psnr': 23.6142, 'best_val_psnr': 23.6142}
# {'epoch': 265, 'epoch_time_sec': 12.76, 'lr': 8.449007101498095e-05, 'train_loss': 0.012206, 'train_psnr': 24.7821, 'val_psnr': 23.6147, 'best_val_psnr': 23.6147}
# {'epoch': 266, 'epoch_time_sec': 12.58, 'lr': 8.437593863484505e-05, 'train_loss': 0.012255, 'train_psnr': 24.7592, 'val_psnr': 23.6152, 'best_val_psnr': 23.6152}
# {'epoch': 267, 'epoch_time_sec': 12.9, 'lr': 8.426146649852091e-05, 'train_loss': 0.012208, 'train_psnr': 24.7826, 'val_psnr': 23.6156, 'best_val_psnr': 23.6156}
# {'epoch': 268, 'epoch_time_sec': 12.96, 'lr': 8.41466557540983e-05, 'train_loss': 0.012222, 'train_psnr': 24.7763, 'val_psnr': 23.6159, 'best_val_psnr': 23.6159}
# {'epoch': 269, 'epoch_time_sec': 12.63, 'lr': 8.403150755306291e-05, 'train_loss': 0.01223, 'train_psnr': 24.7712, 'val_psnr': 23.6165, 'best_val_psnr': 23.6165}
# {'epoch': 270, 'epoch_time_sec': 12.75, 'lr': 8.391602305028504e-05, 'train_loss': 0.012203, 'train_psnr': 24.7837, 'val_psnr': 23.6169, 'best_val_psnr': 23.6169}
# {'epoch': 271, 'epoch_time_sec': 12.72, 'lr': 8.380020340400786e-05, 'train_loss': 0.012205, 'train_psnr': 24.783, 'val_psnr': 23.6174, 'best_val_psnr': 23.6174}
# {'epoch': 272, 'epoch_time_sec': 12.81, 'lr': 8.368404977583579e-05, 'train_loss': 0.012247, 'train_psnr': 24.7665, 'val_psnr': 23.6178, 'best_val_psnr': 23.6178}
# {'epoch': 273, 'epoch_time_sec': 12.72, 'lr': 8.356756333072298e-05, 'train_loss': 0.01222, 'train_psnr': 24.7757, 'val_psnr': 23.6181, 'best_val_psnr': 23.6181}
# {'epoch': 274, 'epoch_time_sec': 12.65, 'lr': 8.34507452369615e-05, 'train_loss': 0.012192, 'train_psnr': 24.7891, 'val_psnr': 23.6186, 'best_val_psnr': 23.6186}
# {'epoch': 275, 'epoch_time_sec': 12.51, 'lr': 8.333359666616966e-05, 'train_loss': 0.012187, 'train_psnr': 24.7925, 'val_psnr': 23.619, 'best_val_psnr': 23.619}
# {'epoch': 276, 'epoch_time_sec': 12.53, 'lr': 8.321611879328028e-05, 'train_loss': 0.012196, 'train_psnr': 24.7878, 'val_psnr': 23.6196, 'best_val_psnr': 23.6196}
# {'epoch': 277, 'epoch_time_sec': 12.43, 'lr': 8.309831279652887e-05, 'train_loss': 0.012237, 'train_psnr': 24.7717, 'val_psnr': 23.6202, 'best_val_psnr': 23.6202}
# {'epoch': 278, 'epoch_time_sec': 12.7, 'lr': 8.298017985744186e-05, 'train_loss': 0.0122, 'train_psnr': 24.7842, 'val_psnr': 23.6206, 'best_val_psnr': 23.6206}
# {'epoch': 279, 'epoch_time_sec': 12.53, 'lr': 8.286172116082469e-05, 'train_loss': 0.012202, 'train_psnr': 24.7842, 'val_psnr': 23.6212, 'best_val_psnr': 23.6212}
# {'epoch': 280, 'epoch_time_sec': 12.78, 'lr': 8.274293789475001e-05, 'train_loss': 0.012242, 'train_psnr': 24.7729, 'val_psnr': 23.6216, 'best_val_psnr': 23.6216}
# {'epoch': 281, 'epoch_time_sec': 12.75, 'lr': 8.262383125054566e-05, 'train_loss': 0.012202, 'train_psnr': 24.7862, 'val_psnr': 23.6222, 'best_val_psnr': 23.6222}
# {'epoch': 282, 'epoch_time_sec': 12.93, 'lr': 8.250440242278284e-05, 'train_loss': 0.012205, 'train_psnr': 24.7828, 'val_psnr': 23.6226, 'best_val_psnr': 23.6226}
# {'epoch': 283, 'epoch_time_sec': 12.84, 'lr': 8.238465260926398e-05, 'train_loss': 0.012211, 'train_psnr': 24.7809, 'val_psnr': 23.6231, 'best_val_psnr': 23.6231}
# {'epoch': 284, 'epoch_time_sec': 12.69, 'lr': 8.22645830110109e-05, 'train_loss': 0.012216, 'train_psnr': 24.7803, 'val_psnr': 23.6234, 'best_val_psnr': 23.6234}
# {'epoch': 285, 'epoch_time_sec': 12.82, 'lr': 8.214419483225264e-05, 'train_loss': 0.012234, 'train_psnr': 24.7706, 'val_psnr': 23.6238, 'best_val_psnr': 23.6238}
# {'epoch': 286, 'epoch_time_sec': 12.81, 'lr': 8.20234892804134e-05, 'train_loss': 0.012209, 'train_psnr': 24.7812, 'val_psnr': 23.6242, 'best_val_psnr': 23.6242}
# {'epoch': 287, 'epoch_time_sec': 12.74, 'lr': 8.190246756610045e-05, 'train_loss': 0.012206, 'train_psnr': 24.7838, 'val_psnr': 23.6246, 'best_val_psnr': 23.6246}
# {'epoch': 288, 'epoch_time_sec': 12.54, 'lr': 8.178113090309204e-05, 'train_loss': 0.0122, 'train_psnr': 24.7875, 'val_psnr': 23.625, 'best_val_psnr': 23.625}
# {'epoch': 289, 'epoch_time_sec': 12.71, 'lr': 8.165948050832514e-05, 'train_loss': 0.012203, 'train_psnr': 24.7855, 'val_psnr': 23.6255, 'best_val_psnr': 23.6255}
# {'epoch': 290, 'epoch_time_sec': 13.1, 'lr': 8.153751760188326e-05, 'train_loss': 0.012197, 'train_psnr': 24.7885, 'val_psnr': 23.626, 'best_val_psnr': 23.626}
# {'epoch': 291, 'epoch_time_sec': 12.93, 'lr': 8.141524340698422e-05, 'train_loss': 0.012226, 'train_psnr': 24.7738, 'val_psnr': 23.6263, 'best_val_psnr': 23.6263}
# {'epoch': 292, 'epoch_time_sec': 12.75, 'lr': 8.12926591499679e-05, 'train_loss': 0.012194, 'train_psnr': 24.7898, 'val_psnr': 23.6266, 'best_val_psnr': 23.6266}
# {'epoch': 293, 'epoch_time_sec': 12.8, 'lr': 8.116976606028393e-05, 'train_loss': 0.012185, 'train_psnr': 24.7945, 'val_psnr': 23.627, 'best_val_psnr': 23.627}
# {'epoch': 294, 'epoch_time_sec': 12.74, 'lr': 8.104656537047935e-05, 'train_loss': 0.012187, 'train_psnr': 24.7922, 'val_psnr': 23.6274, 'best_val_psnr': 23.6274}
# {'epoch': 295, 'epoch_time_sec': 12.93, 'lr': 8.092305831618623e-05, 'train_loss': 0.012197, 'train_psnr': 24.7866, 'val_psnr': 23.6278, 'best_val_psnr': 23.6278}
# {'epoch': 296, 'epoch_time_sec': 12.6, 'lr': 8.079924613610932e-05, 'train_loss': 0.012193, 'train_psnr': 24.7908, 'val_psnr': 23.6283, 'best_val_psnr': 23.6283}
# {'epoch': 297, 'epoch_time_sec': 12.82, 'lr': 8.06751300720136e-05, 'train_loss': 0.012213, 'train_psnr': 24.7841, 'val_psnr': 23.6287, 'best_val_psnr': 23.6287}
# {'epoch': 298, 'epoch_time_sec': 12.62, 'lr': 8.055071136871184e-05, 'train_loss': 0.012187, 'train_psnr': 24.7933, 'val_psnr': 23.6292, 'best_val_psnr': 23.6292}
# {'epoch': 299, 'epoch_time_sec': 12.58, 'lr': 8.042599127405212e-05, 'train_loss': 0.012212, 'train_psnr': 24.7811, 'val_psnr': 23.6297, 'best_val_psnr': 23.6297}
# {'epoch': 300, 'epoch_time_sec': 12.78, 'lr': 8.030097103890526e-05, 'train_loss': 0.012197, 'train_psnr': 24.7876, 'val_psnr': 23.6301, 'best_val_psnr': 23.6301}
# {'epoch': 301, 'epoch_time_sec': 13.0, 'lr': 8.017565191715235e-05, 'train_loss': 0.012197, 'train_psnr': 24.7907, 'val_psnr': 23.6305, 'best_val_psnr': 23.6305}
# {'epoch': 302, 'epoch_time_sec': 12.69, 'lr': 8.005003516567213e-05, 'train_loss': 0.012213, 'train_psnr': 24.7827, 'val_psnr': 23.631, 'best_val_psnr': 23.631}
# {'epoch': 303, 'epoch_time_sec': 12.73, 'lr': 7.992412204432838e-05, 'train_loss': 0.01219, 'train_psnr': 24.7931, 'val_psnr': 23.6314, 'best_val_psnr': 23.6314}
# {'epoch': 304, 'epoch_time_sec': 12.73, 'lr': 7.979791381595735e-05, 'train_loss': 0.012179, 'train_psnr': 24.7974, 'val_psnr': 23.6318, 'best_val_psnr': 23.6318}
# {'epoch': 305, 'epoch_time_sec': 12.94, 'lr': 7.9671411746355e-05, 'train_loss': 0.012188, 'train_psnr': 24.7925, 'val_psnr': 23.6323, 'best_val_psnr': 23.6323}
# {'epoch': 306, 'epoch_time_sec': 12.85, 'lr': 7.954461710426433e-05, 'train_loss': 0.012191, 'train_psnr': 24.7926, 'val_psnr': 23.6326, 'best_val_psnr': 23.6326}
# {'epoch': 307, 'epoch_time_sec': 12.75, 'lr': 7.941753116136274e-05, 'train_loss': 0.012179, 'train_psnr': 24.7973, 'val_psnr': 23.6331, 'best_val_psnr': 23.6331}
# {'epoch': 308, 'epoch_time_sec': 12.74, 'lr': 7.929015519224913e-05, 'train_loss': 0.012188, 'train_psnr': 24.7942, 'val_psnr': 23.6335, 'best_val_psnr': 23.6335}
# {'epoch': 309, 'epoch_time_sec': 12.61, 'lr': 7.916249047443129e-05, 'train_loss': 0.012171, 'train_psnr': 24.801, 'val_psnr': 23.6339, 'best_val_psnr': 23.6339}
# {'epoch': 310, 'epoch_time_sec': 12.83, 'lr': 7.903453828831289e-05, 'train_loss': 0.01218, 'train_psnr': 24.7984, 'val_psnr': 23.6342, 'best_val_psnr': 23.6342}
# {'epoch': 311, 'epoch_time_sec': 13.04, 'lr': 7.890629991718083e-05, 'train_loss': 0.012207, 'train_psnr': 24.7842, 'val_psnr': 23.6347, 'best_val_psnr': 23.6347}
# {'epoch': 312, 'epoch_time_sec': 12.61, 'lr': 7.877777664719222e-05, 'train_loss': 0.012174, 'train_psnr': 24.8003, 'val_psnr': 23.6351, 'best_val_psnr': 23.6351}
# {'epoch': 313, 'epoch_time_sec': 12.73, 'lr': 7.864896976736158e-05, 'train_loss': 0.012185, 'train_psnr': 24.7959, 'val_psnr': 23.6355, 'best_val_psnr': 23.6355}
# {'epoch': 314, 'epoch_time_sec': 12.95, 'lr': 7.851988056954787e-05, 'train_loss': 0.012181, 'train_psnr': 24.7958, 'val_psnr': 23.6358, 'best_val_psnr': 23.6358}
# {'epoch': 315, 'epoch_time_sec': 12.57, 'lr': 7.83905103484415e-05, 'train_loss': 0.012185, 'train_psnr': 24.7958, 'val_psnr': 23.6363, 'best_val_psnr': 23.6363}
# {'epoch': 316, 'epoch_time_sec': 12.75, 'lr': 7.826086040155142e-05, 'train_loss': 0.012175, 'train_psnr': 24.799, 'val_psnr': 23.6367, 'best_val_psnr': 23.6367}
# {'epoch': 317, 'epoch_time_sec': 12.86, 'lr': 7.813093202919208e-05, 'train_loss': 0.012181, 'train_psnr': 24.7969, 'val_psnr': 23.6371, 'best_val_psnr': 23.6371}
# {'epoch': 318, 'epoch_time_sec': 12.61, 'lr': 7.80007265344703e-05, 'train_loss': 0.012174, 'train_psnr': 24.8005, 'val_psnr': 23.6375, 'best_val_psnr': 23.6375}
# {'epoch': 319, 'epoch_time_sec': 12.69, 'lr': 7.787024522327239e-05, 'train_loss': 0.012186, 'train_psnr': 24.7966, 'val_psnr': 23.6379, 'best_val_psnr': 23.6379}
# {'epoch': 320, 'epoch_time_sec': 12.78, 'lr': 7.773948940425087e-05, 'train_loss': 0.012212, 'train_psnr': 24.7805, 'val_psnr': 23.6382, 'best_val_psnr': 23.6382}
# {'epoch': 321, 'epoch_time_sec': 12.69, 'lr': 7.760846038881142e-05, 'train_loss': 0.012191, 'train_psnr': 24.7937, 'val_psnr': 23.6385, 'best_val_psnr': 23.6385}
# {'epoch': 322, 'epoch_time_sec': 12.75, 'lr': 7.747715949109973e-05, 'train_loss': 0.012182, 'train_psnr': 24.7965, 'val_psnr': 23.639, 'best_val_psnr': 23.639}
# {'epoch': 323, 'epoch_time_sec': 12.75, 'lr': 7.734558802798832e-05, 'train_loss': 0.012176, 'train_psnr': 24.8005, 'val_psnr': 23.6394, 'best_val_psnr': 23.6394}
# {'epoch': 324, 'epoch_time_sec': 12.53, 'lr': 7.721374731906332e-05, 'train_loss': 0.012188, 'train_psnr': 24.794, 'val_psnr': 23.6397, 'best_val_psnr': 23.6397}
# {'epoch': 325, 'epoch_time_sec': 12.76, 'lr': 7.708163868661122e-05, 'train_loss': 0.012175, 'train_psnr': 24.7993, 'val_psnr': 23.6401, 'best_val_psnr': 23.6401}
# {'epoch': 326, 'epoch_time_sec': 12.86, 'lr': 7.69492634556057e-05, 'train_loss': 0.012156, 'train_psnr': 24.809, 'val_psnr': 23.6405, 'best_val_psnr': 23.6405}
# {'epoch': 327, 'epoch_time_sec': 12.91, 'lr': 7.681662295369417e-05, 'train_loss': 0.012173, 'train_psnr': 24.8008, 'val_psnr': 23.6408, 'best_val_psnr': 23.6408}
# {'epoch': 328, 'epoch_time_sec': 13.09, 'lr': 7.668371851118464e-05, 'train_loss': 0.012182, 'train_psnr': 24.7966, 'val_psnr': 23.6411, 'best_val_psnr': 23.6411}
# {'epoch': 329, 'epoch_time_sec': 12.77, 'lr': 7.655055146103225e-05, 'train_loss': 0.012178, 'train_psnr': 24.8002, 'val_psnr': 23.6414, 'best_val_psnr': 23.6414}
# {'epoch': 330, 'epoch_time_sec': 12.9, 'lr': 7.641712313882593e-05, 'train_loss': 0.012196, 'train_psnr': 24.7917, 'val_psnr': 23.6417, 'best_val_psnr': 23.6417}
# {'epoch': 331, 'epoch_time_sec': 12.75, 'lr': 7.628343488277507e-05, 'train_loss': 0.012187, 'train_psnr': 24.7962, 'val_psnr': 23.642, 'best_val_psnr': 23.642}
# {'epoch': 332, 'epoch_time_sec': 12.63, 'lr': 7.6149488033696e-05, 'train_loss': 0.012167, 'train_psnr': 24.8056, 'val_psnr': 23.6423, 'best_val_psnr': 23.6423}
# {'epoch': 333, 'epoch_time_sec': 12.81, 'lr': 7.60152839349986e-05, 'train_loss': 0.012171, 'train_psnr': 24.8033, 'val_psnr': 23.6427, 'best_val_psnr': 23.6427}
# {'epoch': 334, 'epoch_time_sec': 12.65, 'lr': 7.588082393267285e-05, 'train_loss': 0.012186, 'train_psnr': 24.7981, 'val_psnr': 23.643, 'best_val_psnr': 23.643}
# {'epoch': 335, 'epoch_time_sec': 12.7, 'lr': 7.574610937527522e-05, 'train_loss': 0.012182, 'train_psnr': 24.7968, 'val_psnr': 23.6433, 'best_val_psnr': 23.6433}
# {'epoch': 336, 'epoch_time_sec': 12.44, 'lr': 7.561114161391532e-05, 'train_loss': 0.012157, 'train_psnr': 24.8098, 'val_psnr': 23.6436, 'best_val_psnr': 23.6436}
# {'epoch': 337, 'epoch_time_sec': 12.85, 'lr': 7.547592200224216e-05, 'train_loss': 0.012184, 'train_psnr': 24.7958, 'val_psnr': 23.6439, 'best_val_psnr': 23.6439}
# {'epoch': 338, 'epoch_time_sec': 12.7, 'lr': 7.534045189643074e-05, 'train_loss': 0.012178, 'train_psnr': 24.799, 'val_psnr': 23.6442, 'best_val_psnr': 23.6442}
# {'epoch': 339, 'epoch_time_sec': 12.58, 'lr': 7.520473265516831e-05, 'train_loss': 0.012174, 'train_psnr': 24.8024, 'val_psnr': 23.6446, 'best_val_psnr': 23.6446}
# {'epoch': 340, 'epoch_time_sec': 12.7, 'lr': 7.506876563964085e-05, 'train_loss': 0.012171, 'train_psnr': 24.8059, 'val_psnr': 23.6449, 'best_val_psnr': 23.6449}
# {'epoch': 341, 'epoch_time_sec': 12.71, 'lr': 7.493255221351932e-05, 'train_loss': 0.012155, 'train_psnr': 24.8092, 'val_psnr': 23.6452, 'best_val_psnr': 23.6452}
# {'epoch': 342, 'epoch_time_sec': 12.8, 'lr': 7.47960937429461e-05, 'train_loss': 0.01216, 'train_psnr': 24.8072, 'val_psnr': 23.6456, 'best_val_psnr': 23.6456}
# {'epoch': 343, 'epoch_time_sec': 12.77, 'lr': 7.465939159652119e-05, 'train_loss': 0.012146, 'train_psnr': 24.8166, 'val_psnr': 23.646, 'best_val_psnr': 23.646}
# {'epoch': 344, 'epoch_time_sec': 12.57, 'lr': 7.452244714528853e-05, 'train_loss': 0.012164, 'train_psnr': 24.8071, 'val_psnr': 23.6464, 'best_val_psnr': 23.6464}
# {'epoch': 345, 'epoch_time_sec': 12.83, 'lr': 7.43852617627222e-05, 'train_loss': 0.012176, 'train_psnr': 24.8041, 'val_psnr': 23.6468, 'best_val_psnr': 23.6468}
# {'epoch': 346, 'epoch_time_sec': 12.58, 'lr': 7.424783682471276e-05, 'train_loss': 0.012174, 'train_psnr': 24.8022, 'val_psnr': 23.6471, 'best_val_psnr': 23.6471}
# {'epoch': 347, 'epoch_time_sec': 12.8, 'lr': 7.41101737095533e-05, 'train_loss': 0.012184, 'train_psnr': 24.797, 'val_psnr': 23.6474, 'best_val_psnr': 23.6474}
# {'epoch': 348, 'epoch_time_sec': 12.89, 'lr': 7.397227379792574e-05, 'train_loss': 0.012169, 'train_psnr': 24.8027, 'val_psnr': 23.6476, 'best_val_psnr': 23.6476}
# {'epoch': 349, 'epoch_time_sec': 12.85, 'lr': 7.38341384728869e-05, 'train_loss': 0.012172, 'train_psnr': 24.8013, 'val_psnr': 23.6478, 'best_val_psnr': 23.6478}
# {'epoch': 350, 'epoch_time_sec': 12.82, 'lr': 7.369576911985464e-05, 'train_loss': 0.012157, 'train_psnr': 24.8095, 'val_psnr': 23.6481, 'best_val_psnr': 23.6481}
# {'epoch': 351, 'epoch_time_sec': 12.84, 'lr': 7.355716712659407e-05, 'train_loss': 0.012173, 'train_psnr': 24.8035, 'val_psnr': 23.6483, 'best_val_psnr': 23.6483}
# {'epoch': 352, 'epoch_time_sec': 12.7, 'lr': 7.341833388320348e-05, 'train_loss': 0.012153, 'train_psnr': 24.8113, 'val_psnr': 23.6487, 'best_val_psnr': 23.6487}
# {'epoch': 353, 'epoch_time_sec': 12.89, 'lr': 7.327927078210046e-05, 'train_loss': 0.012148, 'train_psnr': 24.8156, 'val_psnr': 23.6491, 'best_val_psnr': 23.6491}
# {'epoch': 354, 'epoch_time_sec': 13.03, 'lr': 7.3139979218008e-05, 'train_loss': 0.012152, 'train_psnr': 24.8114, 'val_psnr': 23.6494, 'best_val_psnr': 23.6494}
# {'epoch': 355, 'epoch_time_sec': 12.99, 'lr': 7.300046058794037e-05, 'train_loss': 0.0122, 'train_psnr': 24.7908, 'val_psnr': 23.6497, 'best_val_psnr': 23.6497}
# {'epoch': 356, 'epoch_time_sec': 12.64, 'lr': 7.286071629118922e-05, 'train_loss': 0.012167, 'train_psnr': 24.8076, 'val_psnr': 23.6501, 'best_val_psnr': 23.6501}
# {'epoch': 357, 'epoch_time_sec': 12.71, 'lr': 7.272074772930955e-05, 'train_loss': 0.012152, 'train_psnr': 24.8126, 'val_psnr': 23.6504, 'best_val_psnr': 23.6504}
# {'epoch': 358, 'epoch_time_sec': 12.73, 'lr': 7.258055630610548e-05, 'train_loss': 0.012206, 'train_psnr': 24.7883, 'val_psnr': 23.6505, 'best_val_psnr': 23.6505}
# {'epoch': 359, 'epoch_time_sec': 12.7, 'lr': 7.244014342761647e-05, 'train_loss': 0.012155, 'train_psnr': 24.812, 'val_psnr': 23.6509, 'best_val_psnr': 23.6509}
# {'epoch': 360, 'epoch_time_sec': 12.74, 'lr': 7.22995105021029e-05, 'train_loss': 0.012143, 'train_psnr': 24.8183, 'val_psnr': 23.6511, 'best_val_psnr': 23.6511}
# {'epoch': 361, 'epoch_time_sec': 12.73, 'lr': 7.21586589400322e-05, 'train_loss': 0.012148, 'train_psnr': 24.8143, 'val_psnr': 23.6513, 'best_val_psnr': 23.6513}
# {'epoch': 362, 'epoch_time_sec': 12.78, 'lr': 7.201759015406452e-05, 'train_loss': 0.012149, 'train_psnr': 24.8146, 'val_psnr': 23.6518, 'best_val_psnr': 23.6518}
# {'epoch': 363, 'epoch_time_sec': 12.56, 'lr': 7.187630555903872e-05, 'train_loss': 0.012164, 'train_psnr': 24.8064, 'val_psnr': 23.6521, 'best_val_psnr': 23.6521}
# {'epoch': 364, 'epoch_time_sec': 12.9, 'lr': 7.173480657195803e-05, 'train_loss': 0.01216, 'train_psnr': 24.8093, 'val_psnr': 23.6523, 'best_val_psnr': 23.6523}
# {'epoch': 365, 'epoch_time_sec': 12.78, 'lr': 7.159309461197596e-05, 'train_loss': 0.012147, 'train_psnr': 24.8161, 'val_psnr': 23.6527, 'best_val_psnr': 23.6527}
# {'epoch': 366, 'epoch_time_sec': 12.67, 'lr': 7.145117110038197e-05, 'train_loss': 0.012153, 'train_psnr': 24.8124, 'val_psnr': 23.6529, 'best_val_psnr': 23.6529}
# {'epoch': 367, 'epoch_time_sec': 12.75, 'lr': 7.13090374605873e-05, 'train_loss': 0.012151, 'train_psnr': 24.8122, 'val_psnr': 23.6533, 'best_val_psnr': 23.6533}
# {'epoch': 368, 'epoch_time_sec': 12.89, 'lr': 7.116669511811063e-05, 'train_loss': 0.012156, 'train_psnr': 24.8119, 'val_psnr': 23.6536, 'best_val_psnr': 23.6536}
# {'epoch': 369, 'epoch_time_sec': 12.69, 'lr': 7.102414550056383e-05, 'train_loss': 0.012136, 'train_psnr': 24.8195, 'val_psnr': 23.6539, 'best_val_psnr': 23.6539}
# {'epoch': 370, 'epoch_time_sec': 12.62, 'lr': 7.088139003763762e-05, 'train_loss': 0.012148, 'train_psnr': 24.8167, 'val_psnr': 23.6542, 'best_val_psnr': 23.6542}
# {'epoch': 371, 'epoch_time_sec': 12.93, 'lr': 7.073843016108717e-05, 'train_loss': 0.012146, 'train_psnr': 24.8159, 'val_psnr': 23.6544, 'best_val_psnr': 23.6544}
# {'epoch': 372, 'epoch_time_sec': 12.58, 'lr': 7.05952673047179e-05, 'train_loss': 0.012154, 'train_psnr': 24.8114, 'val_psnr': 23.6547, 'best_val_psnr': 23.6547}
# {'epoch': 373, 'epoch_time_sec': 12.75, 'lr': 7.045190290437095e-05, 'train_loss': 0.012153, 'train_psnr': 24.8126, 'val_psnr': 23.6551, 'best_val_psnr': 23.6551}
# {'epoch': 374, 'epoch_time_sec': 12.51, 'lr': 7.030833839790878e-05, 'train_loss': 0.012158, 'train_psnr': 24.8097, 'val_psnr': 23.6553, 'best_val_psnr': 23.6553}
# {'epoch': 375, 'epoch_time_sec': 12.73, 'lr': 7.016457522520091e-05, 'train_loss': 0.012147, 'train_psnr': 24.8165, 'val_psnr': 23.6555, 'best_val_psnr': 23.6555}
# {'epoch': 376, 'epoch_time_sec': 12.75, 'lr': 7.002061482810928e-05, 'train_loss': 0.012151, 'train_psnr': 24.8151, 'val_psnr': 23.6558, 'best_val_psnr': 23.6558}
# {'epoch': 377, 'epoch_time_sec': 12.67, 'lr': 6.98764586504739e-05, 'train_loss': 0.01215, 'train_psnr': 24.814, 'val_psnr': 23.6561, 'best_val_psnr': 23.6561}
# {'epoch': 378, 'epoch_time_sec': 12.93, 'lr': 6.973210813809836e-05, 'train_loss': 0.012137, 'train_psnr': 24.8205, 'val_psnr': 23.6563, 'best_val_psnr': 23.6563}
# {'epoch': 379, 'epoch_time_sec': 12.85, 'lr': 6.958756473873532e-05, 'train_loss': 0.012144, 'train_psnr': 24.8191, 'val_psnr': 23.6567, 'best_val_psnr': 23.6567}
# {'epoch': 380, 'epoch_time_sec': 12.64, 'lr': 6.944282990207195e-05, 'train_loss': 0.012157, 'train_psnr': 24.8109, 'val_psnr': 23.6569, 'best_val_psnr': 23.6569}
# {'epoch': 381, 'epoch_time_sec': 12.81, 'lr': 6.929790507971546e-05, 'train_loss': 0.012167, 'train_psnr': 24.8069, 'val_psnr': 23.6571, 'best_val_psnr': 23.6571}
# {'epoch': 382, 'epoch_time_sec': 12.55, 'lr': 6.91527917251785e-05, 'train_loss': 0.012144, 'train_psnr': 24.8162, 'val_psnr': 23.6574, 'best_val_psnr': 23.6574}
# {'epoch': 383, 'epoch_time_sec': 12.55, 'lr': 6.900749129386458e-05, 'train_loss': 0.01214, 'train_psnr': 24.8187, 'val_psnr': 23.6575, 'best_val_psnr': 23.6575}
# {'epoch': 384, 'epoch_time_sec': 12.65, 'lr': 6.886200524305352e-05, 'train_loss': 0.012141, 'train_psnr': 24.817, 'val_psnr': 23.6579, 'best_val_psnr': 23.6579}
# {'epoch': 385, 'epoch_time_sec': 12.98, 'lr': 6.871633503188671e-05, 'train_loss': 0.012143, 'train_psnr': 24.8202, 'val_psnr': 23.6581, 'best_val_psnr': 23.6581}
# {'epoch': 386, 'epoch_time_sec': 12.55, 'lr': 6.857048212135265e-05, 'train_loss': 0.01216, 'train_psnr': 24.81, 'val_psnr': 23.6584, 'best_val_psnr': 23.6584}
# {'epoch': 387, 'epoch_time_sec': 12.94, 'lr': 6.842444797427217e-05, 'train_loss': 0.012122, 'train_psnr': 24.8292, 'val_psnr': 23.6586, 'best_val_psnr': 23.6586}
# {'epoch': 388, 'epoch_time_sec': 12.63, 'lr': 6.827823405528382e-05, 'train_loss': 0.012142, 'train_psnr': 24.819, 'val_psnr': 23.659, 'best_val_psnr': 23.659}
# {'epoch': 389, 'epoch_time_sec': 13.01, 'lr': 6.813184183082911e-05, 'train_loss': 0.012124, 'train_psnr': 24.8281, 'val_psnr': 23.6593, 'best_val_psnr': 23.6593}
# {'epoch': 390, 'epoch_time_sec': 12.74, 'lr': 6.798527276913792e-05, 'train_loss': 0.012138, 'train_psnr': 24.8205, 'val_psnr': 23.6595, 'best_val_psnr': 23.6595}
# {'epoch': 391, 'epoch_time_sec': 12.54, 'lr': 6.783852834021367e-05, 'train_loss': 0.012143, 'train_psnr': 24.8175, 'val_psnr': 23.6597, 'best_val_psnr': 23.6597}
# {'epoch': 392, 'epoch_time_sec': 12.54, 'lr': 6.76916100158186e-05, 'train_loss': 0.012138, 'train_psnr': 24.8212, 'val_psnr': 23.6599, 'best_val_psnr': 23.6599}
# {'epoch': 393, 'epoch_time_sec': 12.79, 'lr': 6.754451926945904e-05, 'train_loss': 0.012147, 'train_psnr': 24.8171, 'val_psnr': 23.6602, 'best_val_psnr': 23.6602}
# {'epoch': 394, 'epoch_time_sec': 12.52, 'lr': 6.739725757637062e-05, 'train_loss': 0.012138, 'train_psnr': 24.8193, 'val_psnr': 23.6605, 'best_val_psnr': 23.6605}
# {'epoch': 395, 'epoch_time_sec': 12.81, 'lr': 6.724982641350343e-05, 'train_loss': 0.012135, 'train_psnr': 24.82, 'val_psnr': 23.6607, 'best_val_psnr': 23.6607}
# {'epoch': 396, 'epoch_time_sec': 12.7, 'lr': 6.710222725950732e-05, 'train_loss': 0.012133, 'train_psnr': 24.823, 'val_psnr': 23.6609, 'best_val_psnr': 23.6609}
# {'epoch': 397, 'epoch_time_sec': 12.89, 'lr': 6.695446159471689e-05, 'train_loss': 0.012176, 'train_psnr': 24.8102, 'val_psnr': 23.6612, 'best_val_psnr': 23.6612}
# {'epoch': 398, 'epoch_time_sec': 12.74, 'lr': 6.680653090113682e-05, 'train_loss': 0.012146, 'train_psnr': 24.819, 'val_psnr': 23.6615, 'best_val_psnr': 23.6615}
# {'epoch': 399, 'epoch_time_sec': 12.68, 'lr': 6.665843666242693e-05, 'train_loss': 0.012144, 'train_psnr': 24.8183, 'val_psnr': 23.6617, 'best_val_psnr': 23.6617}
# {'epoch': 400, 'epoch_time_sec': 12.69, 'lr': 6.651018036388729e-05, 'train_loss': 0.012137, 'train_psnr': 24.8199, 'val_psnr': 23.662, 'best_val_psnr': 23.662}
# {'epoch': 401, 'epoch_time_sec': 12.73, 'lr': 6.636176349244332e-05, 'train_loss': 0.012141, 'train_psnr': 24.8215, 'val_psnr': 23.6621, 'best_val_psnr': 23.6621}
# {'epoch': 402, 'epoch_time_sec': 12.79, 'lr': 6.621318753663094e-05, 'train_loss': 0.012145, 'train_psnr': 24.8175, 'val_psnr': 23.6623, 'best_val_psnr': 23.6623}
# {'epoch': 403, 'epoch_time_sec': 12.74, 'lr': 6.606445398658153e-05, 'train_loss': 0.012138, 'train_psnr': 24.8227, 'val_psnr': 23.6627, 'best_val_psnr': 23.6627}
# {'epoch': 404, 'epoch_time_sec': 12.77, 'lr': 6.591556433400713e-05, 'train_loss': 0.012119, 'train_psnr': 24.8308, 'val_psnr': 23.6629, 'best_val_psnr': 23.6629}
# {'epoch': 405, 'epoch_time_sec': 12.61, 'lr': 6.576652007218529e-05, 'train_loss': 0.012131, 'train_psnr': 24.8233, 'val_psnr': 23.6633, 'best_val_psnr': 23.6633}
# {'epoch': 406, 'epoch_time_sec': 12.61, 'lr': 6.561732269594433e-05, 'train_loss': 0.012135, 'train_psnr': 24.8249, 'val_psnr': 23.6635, 'best_val_psnr': 23.6635}
# {'epoch': 407, 'epoch_time_sec': 12.86, 'lr': 6.546797370164812e-05, 'train_loss': 0.01213, 'train_psnr': 24.8257, 'val_psnr': 23.6637, 'best_val_psnr': 23.6637}
# {'epoch': 408, 'epoch_time_sec': 12.52, 'lr': 6.531847458718123e-05, 'train_loss': 0.012126, 'train_psnr': 24.8267, 'val_psnr': 23.6639, 'best_val_psnr': 23.6639}
# {'epoch': 409, 'epoch_time_sec': 12.73, 'lr': 6.51688268519338e-05, 'train_loss': 0.012135, 'train_psnr': 24.8211, 'val_psnr': 23.6641, 'best_val_psnr': 23.6641}
# {'epoch': 410, 'epoch_time_sec': 13.02, 'lr': 6.501903199678659e-05, 'train_loss': 0.012144, 'train_psnr': 24.8204, 'val_psnr': 23.6644, 'best_val_psnr': 23.6644}
# {'epoch': 411, 'epoch_time_sec': 12.9, 'lr': 6.486909152409588e-05, 'train_loss': 0.01213, 'train_psnr': 24.8252, 'val_psnr': 23.6645, 'best_val_psnr': 23.6645}
# {'epoch': 412, 'epoch_time_sec': 12.98, 'lr': 6.471900693767842e-05, 'train_loss': 0.012132, 'train_psnr': 24.8231, 'val_psnr': 23.6648, 'best_val_psnr': 23.6648}
# {'epoch': 413, 'epoch_time_sec': 12.53, 'lr': 6.456877974279629e-05, 'train_loss': 0.012122, 'train_psnr': 24.8291, 'val_psnr': 23.665, 'best_val_psnr': 23.665}
# {'epoch': 414, 'epoch_time_sec': 12.75, 'lr': 6.44184114461419e-05, 'train_loss': 0.012129, 'train_psnr': 24.8261, 'val_psnr': 23.6652, 'best_val_psnr': 23.6652}
# {'epoch': 415, 'epoch_time_sec': 12.8, 'lr': 6.426790355582284e-05, 'train_loss': 0.012141, 'train_psnr': 24.8187, 'val_psnr': 23.6655, 'best_val_psnr': 23.6655}
# {'epoch': 416, 'epoch_time_sec': 12.63, 'lr': 6.411725758134666e-05, 'train_loss': 0.012117, 'train_psnr': 24.831, 'val_psnr': 23.6658, 'best_val_psnr': 23.6658}
# {'epoch': 417, 'epoch_time_sec': 12.5, 'lr': 6.396647503360593e-05, 'train_loss': 0.01213, 'train_psnr': 24.8272, 'val_psnr': 23.6661, 'best_val_psnr': 23.6661}
# {'epoch': 418, 'epoch_time_sec': 12.77, 'lr': 6.381555742486289e-05, 'train_loss': 0.012116, 'train_psnr': 24.8331, 'val_psnr': 23.6663, 'best_val_psnr': 23.6663}
# {'epoch': 419, 'epoch_time_sec': 12.85, 'lr': 6.366450626873439e-05, 'train_loss': 0.012156, 'train_psnr': 24.8163, 'val_psnr': 23.6666, 'best_val_psnr': 23.6666}
# {'epoch': 420, 'epoch_time_sec': 12.76, 'lr': 6.351332308017667e-05, 'train_loss': 0.012119, 'train_psnr': 24.8297, 'val_psnr': 23.6669, 'best_val_psnr': 23.6669}
# {'epoch': 421, 'epoch_time_sec': 12.58, 'lr': 6.336200937547022e-05, 'train_loss': 0.012125, 'train_psnr': 24.8267, 'val_psnr': 23.6671, 'best_val_psnr': 23.6671}
# {'epoch': 422, 'epoch_time_sec': 12.62, 'lr': 6.321056667220447e-05, 'train_loss': 0.012123, 'train_psnr': 24.8283, 'val_psnr': 23.6674, 'best_val_psnr': 23.6674}
# {'epoch': 423, 'epoch_time_sec': 12.76, 'lr': 6.305899648926269e-05, 'train_loss': 0.012135, 'train_psnr': 24.8266, 'val_psnr': 23.6676, 'best_val_psnr': 23.6676}
# {'epoch': 424, 'epoch_time_sec': 12.62, 'lr': 6.290730034680667e-05, 'train_loss': 0.012129, 'train_psnr': 24.829, 'val_psnr': 23.6679, 'best_val_psnr': 23.6679}
# {'epoch': 425, 'epoch_time_sec': 12.8, 'lr': 6.27554797662615e-05, 'train_loss': 0.012127, 'train_psnr': 24.8271, 'val_psnr': 23.6681, 'best_val_psnr': 23.6681}
# {'epoch': 426, 'epoch_time_sec': 12.78, 'lr': 6.260353627030031e-05, 'train_loss': 0.012122, 'train_psnr': 24.8303, 'val_psnr': 23.6683, 'best_val_psnr': 23.6683}
# {'epoch': 427, 'epoch_time_sec': 12.96, 'lr': 6.245147138282901e-05, 'train_loss': 0.012142, 'train_psnr': 24.8204, 'val_psnr': 23.6685, 'best_val_psnr': 23.6685}
# {'epoch': 428, 'epoch_time_sec': 12.9, 'lr': 6.2299286628971e-05, 'train_loss': 0.012149, 'train_psnr': 24.8179, 'val_psnr': 23.6688, 'best_val_psnr': 23.6688}
# {'epoch': 429, 'epoch_time_sec': 12.76, 'lr': 6.214698353505187e-05, 'train_loss': 0.012117, 'train_psnr': 24.8324, 'val_psnr': 23.669, 'best_val_psnr': 23.669}
# {'epoch': 430, 'epoch_time_sec': 12.72, 'lr': 6.199456362858407e-05, 'train_loss': 0.012115, 'train_psnr': 24.8322, 'val_psnr': 23.6692, 'best_val_psnr': 23.6692}
# {'epoch': 431, 'epoch_time_sec': 13.07, 'lr': 6.184202843825167e-05, 'train_loss': 0.012124, 'train_psnr': 24.8295, 'val_psnr': 23.6694, 'best_val_psnr': 23.6694}
# {'epoch': 432, 'epoch_time_sec': 12.75, 'lr': 6.168937949389488e-05, 'train_loss': 0.012132, 'train_psnr': 24.8254, 'val_psnr': 23.6696, 'best_val_psnr': 23.6696}
# {'epoch': 433, 'epoch_time_sec': 13.13, 'lr': 6.153661832649488e-05, 'train_loss': 0.012115, 'train_psnr': 24.8328, 'val_psnr': 23.6699, 'best_val_psnr': 23.6699}
# {'epoch': 434, 'epoch_time_sec': 12.98, 'lr': 6.138374646815834e-05, 'train_loss': 0.012133, 'train_psnr': 24.828, 'val_psnr': 23.6701, 'best_val_psnr': 23.6701}
# {'epoch': 435, 'epoch_time_sec': 12.76, 'lr': 6.123076545210214e-05, 'train_loss': 0.012105, 'train_psnr': 24.8384, 'val_psnr': 23.6702, 'best_val_psnr': 23.6702}
# ...
# {'epoch': 903, 'epoch_time_sec': 12.58, 'lr': 3.3172726173362226e-06, 'train_loss': 0.012019, 'train_psnr': 24.8864, 'val_psnr': 23.7152, 'best_val_psnr': 23.7152}
# {'epoch': 904, 'epoch_time_sec': 13.1, 'lr': 3.2701068081975835e-06, 'train_loss': 0.012019, 'train_psnr': 24.8865, 'val_psnr': 23.7153, 'best_val_psnr': 23.7153}
# {'epoch': 905, 'epoch_time_sec': 12.58, 'lr': 3.223414687733782e-06, 'train_loss': 0.012026, 'train_psnr': 24.884, 'val_psnr': 23.7153, 'best_val_psnr': 23.7153}
# {'epoch': 906, 'epoch_time_sec': 13.01, 'lr': 3.1771967242399384e-06, 'train_loss': 0.012019, 'train_psnr': 24.8864, 'val_psnr': 23.7153, 'best_val_psnr': 23.7153}
# {'epoch': 907, 'epoch_time_sec': 12.71, 'lr': 3.131453381255663e-06, 'train_loss': 0.012028, 'train_psnr': 24.8821, 'val_psnr': 23.7153, 'best_val_psnr': 23.7153}
# {'epoch': 908, 'epoch_time_sec': 12.76, 'lr': 3.086185117560378e-06, 'train_loss': 0.012021, 'train_psnr': 24.8857, 'val_psnr': 23.7153, 'best_val_psnr': 23.7153}
# {'epoch': 909, 'epoch_time_sec': 12.67, 'lr': 3.041392387168745e-06, 'train_loss': 0.012038, 'train_psnr': 24.8781, 'val_psnr': 23.7154, 'best_val_psnr': 23.7154}
# {'epoch': 910, 'epoch_time_sec': 12.6, 'lr': 2.9970756393260983e-06, 'train_loss': 0.012019, 'train_psnr': 24.8857, 'val_psnr': 23.7153, 'best_val_psnr': 23.7154}
# {'epoch': 911, 'epoch_time_sec': 12.53, 'lr': 2.9532353185039392e-06, 'train_loss': 0.012035, 'train_psnr': 24.8806, 'val_psnr': 23.7153, 'best_val_psnr': 23.7154}
# {'epoch': 912, 'epoch_time_sec': 12.57, 'lr': 2.9098718643954868e-06, 'train_loss': 0.012037, 'train_psnr': 24.8802, 'val_psnr': 23.7153, 'best_val_psnr': 23.7154}
# {'epoch': 913, 'epoch_time_sec': 12.8, 'lr': 2.8669857119112357e-06, 'train_loss': 0.012038, 'train_psnr': 24.8801, 'val_psnr': 23.7153, 'best_val_psnr': 23.7154}
# {'epoch': 914, 'epoch_time_sec': 12.82, 'lr': 2.8245772911746615e-06, 'train_loss': 0.012028, 'train_psnr': 24.8816, 'val_psnr': 23.7153, 'best_val_psnr': 23.7154}
# {'epoch': 915, 'epoch_time_sec': 12.47, 'lr': 2.7826470275178305e-06, 'train_loss': 0.012025, 'train_psnr': 24.882, 'val_psnr': 23.7154, 'best_val_psnr': 23.7154}
# {'epoch': 916, 'epoch_time_sec': 12.8, 'lr': 2.7411953414771794e-06, 'train_loss': 0.012017, 'train_psnr': 24.8892, 'val_psnr': 23.7154, 'best_val_psnr': 23.7154}
# {'epoch': 917, 'epoch_time_sec': 12.45, 'lr': 2.70022264878929e-06, 'train_loss': 0.012036, 'train_psnr': 24.8791, 'val_psnr': 23.7154, 'best_val_psnr': 23.7154}
# {'epoch': 918, 'epoch_time_sec': 12.72, 'lr': 2.6597293603867132e-06, 'train_loss': 0.012024, 'train_psnr': 24.8857, 'val_psnr': 23.7153, 'best_val_psnr': 23.7154}
# {'epoch': 919, 'epoch_time_sec': 12.84, 'lr': 2.619715882393857e-06, 'train_loss': 0.012023, 'train_psnr': 24.8839, 'val_psnr': 23.7154, 'best_val_psnr': 23.7154}
# {'epoch': 920, 'epoch_time_sec': 12.64, 'lr': 2.5801826161228934e-06, 'train_loss': 0.012021, 'train_psnr': 24.8862, 'val_psnr': 23.7154, 'best_val_psnr': 23.7154}
# {'epoch': 921, 'epoch_time_sec': 12.76, 'lr': 2.5411299580697444e-06, 'train_loss': 0.012035, 'train_psnr': 24.8785, 'val_psnr': 23.7154, 'best_val_psnr': 23.7154}
# {'epoch': 922, 'epoch_time_sec': 12.91, 'lr': 2.5025582999101403e-06, 'train_loss': 0.01202, 'train_psnr': 24.8863, 'val_psnr': 23.7154, 'best_val_psnr': 23.7154}
# {'epoch': 923, 'epoch_time_sec': 12.51, 'lr': 2.4644680284956247e-06, 'train_loss': 0.012038, 'train_psnr': 24.8809, 'val_psnr': 23.7154, 'best_val_psnr': 23.7154}
# {'epoch': 924, 'epoch_time_sec': 12.93, 'lr': 2.4268595258497227e-06, 'train_loss': 0.012019, 'train_psnr': 24.888, 'val_psnr': 23.7154, 'best_val_psnr': 23.7154}
# {'epoch': 925, 'epoch_time_sec': 12.75, 'lr': 2.3897331691640814e-06, 'train_loss': 0.012028, 'train_psnr': 24.8829, 'val_psnr': 23.7154, 'best_val_psnr': 23.7154}
# {'epoch': 926, 'epoch_time_sec': 12.74, 'lr': 2.353089330794733e-06, 'train_loss': 0.012024, 'train_psnr': 24.8833, 'val_psnr': 23.7154, 'best_val_psnr': 23.7154}
# {'epoch': 927, 'epoch_time_sec': 12.63, 'lr': 2.316928378258302e-06, 'train_loss': 0.012036, 'train_psnr': 24.8788, 'val_psnr': 23.7154, 'best_val_psnr': 23.7154}
# {'epoch': 928, 'epoch_time_sec': 12.59, 'lr': 2.2812506742283475e-06, 'train_loss': 0.012017, 'train_psnr': 24.8884, 'val_psnr': 23.7154, 'best_val_psnr': 23.7154}
# {'epoch': 929, 'epoch_time_sec': 12.55, 'lr': 2.246056576531721e-06, 'train_loss': 0.012012, 'train_psnr': 24.8911, 'val_psnr': 23.7154, 'best_val_psnr': 23.7154}
# {'epoch': 930, 'epoch_time_sec': 12.69, 'lr': 2.2113464381450116e-06, 'train_loss': 0.012032, 'train_psnr': 24.88, 'val_psnr': 23.7154, 'best_val_psnr': 23.7154}
# {'epoch': 931, 'epoch_time_sec': 12.51, 'lr': 2.1771206071909337e-06, 'train_loss': 0.012019, 'train_psnr': 24.8873, 'val_psnr': 23.7155, 'best_val_psnr': 23.7155}
# {'epoch': 932, 'epoch_time_sec': 12.79, 'lr': 2.1433794269349027e-06, 'train_loss': 0.012028, 'train_psnr': 24.8826, 'val_psnr': 23.7155, 'best_val_psnr': 23.7155}
# {'epoch': 933, 'epoch_time_sec': 12.59, 'lr': 2.110123235781543e-06, 'train_loss': 0.01202, 'train_psnr': 24.8844, 'val_psnr': 23.7154, 'best_val_psnr': 23.7155}
# {'epoch': 934, 'epoch_time_sec': 12.66, 'lr': 2.077352367271354e-06, 'train_loss': 0.012039, 'train_psnr': 24.8768, 'val_psnr': 23.7155, 'best_val_psnr': 23.7155}
# {'epoch': 935, 'epoch_time_sec': 12.9, 'lr': 2.045067150077295e-06, 'train_loss': 0.012021, 'train_psnr': 24.886, 'val_psnr': 23.7155, 'best_val_psnr': 23.7155}
# {'epoch': 936, 'epoch_time_sec': 12.77, 'lr': 2.013267908001523e-06, 'train_loss': 0.012026, 'train_psnr': 24.8826, 'val_psnr': 23.7155, 'best_val_psnr': 23.7155}
# {'epoch': 937, 'epoch_time_sec': 12.73, 'lr': 1.9819549599721707e-06, 'train_loss': 0.012032, 'train_psnr': 24.8805, 'val_psnr': 23.7155, 'best_val_psnr': 23.7155}
# {'epoch': 938, 'epoch_time_sec': 12.77, 'lr': 1.9511286200400938e-06, 'train_loss': 0.012021, 'train_psnr': 24.8849, 'val_psnr': 23.7155, 'best_val_psnr': 23.7155}
# {'epoch': 939, 'epoch_time_sec': 12.72, 'lr': 1.9207891973757607e-06, 'train_loss': 0.012035, 'train_psnr': 24.8809, 'val_psnr': 23.7156, 'best_val_psnr': 23.7156}
# {'epoch': 940, 'epoch_time_sec': 12.58, 'lr': 1.8909369962661413e-06, 'train_loss': 0.012017, 'train_psnr': 24.8901, 'val_psnr': 23.7156, 'best_val_psnr': 23.7156}
# {'epoch': 941, 'epoch_time_sec': 12.59, 'lr': 1.8615723161116468e-06, 'train_loss': 0.012021, 'train_psnr': 24.8849, 'val_psnr': 23.7155, 'best_val_psnr': 23.7156}
# {'epoch': 942, 'epoch_time_sec': 12.73, 'lr': 1.832695451423134e-06, 'train_loss': 0.01203, 'train_psnr': 24.881, 'val_psnr': 23.7155, 'best_val_psnr': 23.7156}
# {'epoch': 943, 'epoch_time_sec': 12.61, 'lr': 1.8043066918189649e-06, 'train_loss': 0.012028, 'train_psnr': 24.8821, 'val_psnr': 23.7156, 'best_val_psnr': 23.7156}
# {'epoch': 944, 'epoch_time_sec': 12.82, 'lr': 1.7764063220220562e-06, 'train_loss': 0.012041, 'train_psnr': 24.8762, 'val_psnr': 23.7156, 'best_val_psnr': 23.7156}
# {'epoch': 945, 'epoch_time_sec': 12.74, 'lr': 1.7489946218570986e-06, 'train_loss': 0.012025, 'train_psnr': 24.8841, 'val_psnr': 23.7156, 'best_val_psnr': 23.7156}
# {'epoch': 946, 'epoch_time_sec': 12.65, 'lr': 1.7220718662476712e-06, 'train_loss': 0.012024, 'train_psnr': 24.8833, 'val_psnr': 23.7156, 'best_val_psnr': 23.7156}
# {'epoch': 947, 'epoch_time_sec': 12.68, 'lr': 1.695638325213537e-06, 'train_loss': 0.012038, 'train_psnr': 24.8797, 'val_psnr': 23.7156, 'best_val_psnr': 23.7156}
# {'epoch': 948, 'epoch_time_sec': 13.04, 'lr': 1.669694263867913e-06, 'train_loss': 0.012023, 'train_psnr': 24.8843, 'val_psnr': 23.7156, 'best_val_psnr': 23.7156}
# {'epoch': 949, 'epoch_time_sec': 12.9, 'lr': 1.6442399424148262e-06, 'train_loss': 0.01202, 'train_psnr': 24.8852, 'val_psnr': 23.7156, 'best_val_psnr': 23.7156}
# {'epoch': 950, 'epoch_time_sec': 12.72, 'lr': 1.6192756161464757e-06, 'train_loss': 0.01203, 'train_psnr': 24.8836, 'val_psnr': 23.7156, 'best_val_psnr': 23.7156}
# {'epoch': 951, 'epoch_time_sec': 12.79, 'lr': 1.5948015354407148e-06, 'train_loss': 0.012035, 'train_psnr': 24.8797, 'val_psnr': 23.7157, 'best_val_psnr': 23.7157}
# {'epoch': 952, 'epoch_time_sec': 12.86, 'lr': 1.5708179457584867e-06, 'train_loss': 0.012038, 'train_psnr': 24.8784, 'val_psnr': 23.7157, 'best_val_psnr': 23.7157}
# {'epoch': 953, 'epoch_time_sec': 12.55, 'lr': 1.5473250876414151e-06, 'train_loss': 0.012028, 'train_psnr': 24.8803, 'val_psnr': 23.7157, 'best_val_psnr': 23.7157}
# {'epoch': 954, 'epoch_time_sec': 12.54, 'lr': 1.5243231967093603e-06, 'train_loss': 0.012017, 'train_psnr': 24.8864, 'val_psnr': 23.7157, 'best_val_psnr': 23.7157}
# {'epoch': 955, 'epoch_time_sec': 12.86, 'lr': 1.5018125036580666e-06, 'train_loss': 0.012029, 'train_psnr': 24.8817, 'val_psnr': 23.7157, 'best_val_psnr': 23.7157}
# {'epoch': 956, 'epoch_time_sec': 12.82, 'lr': 1.4797932342568365e-06, 'train_loss': 0.012035, 'train_psnr': 24.8813, 'val_psnr': 23.7157, 'best_val_psnr': 23.7157}
# {'epoch': 957, 'epoch_time_sec': 12.77, 'lr': 1.4582656093462854e-06, 'train_loss': 0.012038, 'train_psnr': 24.8777, 'val_psnr': 23.7157, 'best_val_psnr': 23.7157}
# {'epoch': 958, 'epoch_time_sec': 12.81, 'lr': 1.4372298448361194e-06, 'train_loss': 0.012025, 'train_psnr': 24.8832, 'val_psnr': 23.7157, 'best_val_psnr': 23.7157}
# {'epoch': 959, 'epoch_time_sec': 12.51, 'lr': 1.4166861517029539e-06, 'train_loss': 0.012027, 'train_psnr': 24.8813, 'val_psnr': 23.7157, 'best_val_psnr': 23.7157}
# {'epoch': 960, 'epoch_time_sec': 12.65, 'lr': 1.3966347359882206e-06, 'train_loss': 0.012015, 'train_psnr': 24.8903, 'val_psnr': 23.7157, 'best_val_psnr': 23.7157}
# {'epoch': 961, 'epoch_time_sec': 12.9, 'lr': 1.3770757987961e-06, 'train_loss': 0.012036, 'train_psnr': 24.8797, 'val_psnr': 23.7157, 'best_val_psnr': 23.7157}
# {'epoch': 962, 'epoch_time_sec': 12.89, 'lr': 1.3580095362914783e-06, 'train_loss': 0.012022, 'train_psnr': 24.8855, 'val_psnr': 23.7157, 'best_val_psnr': 23.7157}
# {'epoch': 963, 'epoch_time_sec': 12.84, 'lr': 1.3394361396980114e-06, 'train_loss': 0.012023, 'train_psnr': 24.8852, 'val_psnr': 23.7157, 'best_val_psnr': 23.7157}
# {'epoch': 964, 'epoch_time_sec': 12.85, 'lr': 1.3213557952961814e-06, 'train_loss': 0.012037, 'train_psnr': 24.8788, 'val_psnr': 23.7158, 'best_val_psnr': 23.7158}
# {'epoch': 965, 'epoch_time_sec': 12.82, 'lr': 1.303768684421459e-06, 'train_loss': 0.012023, 'train_psnr': 24.8855, 'val_psnr': 23.7158, 'best_val_psnr': 23.7158}
# {'epoch': 966, 'epoch_time_sec': 12.67, 'lr': 1.2866749834624422e-06, 'train_loss': 0.012016, 'train_psnr': 24.8886, 'val_psnr': 23.7158, 'best_val_psnr': 23.7158}
# {'epoch': 967, 'epoch_time_sec': 12.85, 'lr': 1.2700748638591405e-06, 'train_loss': 0.012025, 'train_psnr': 24.8833, 'val_psnr': 23.7158, 'best_val_psnr': 23.7158}
# {'epoch': 968, 'epoch_time_sec': 12.57, 'lr': 1.2539684921011898e-06, 'train_loss': 0.012028, 'train_psnr': 24.8832, 'val_psnr': 23.7158, 'best_val_psnr': 23.7158}
# {'epoch': 969, 'epoch_time_sec': 12.73, 'lr': 1.2383560297262574e-06, 'train_loss': 0.012019, 'train_psnr': 24.8867, 'val_psnr': 23.7158, 'best_val_psnr': 23.7158}
# {'epoch': 970, 'epoch_time_sec': 12.67, 'lr': 1.223237633318351e-06, 'train_loss': 0.012019, 'train_psnr': 24.8867, 'val_psnr': 23.7158, 'best_val_psnr': 23.7158}
# {'epoch': 971, 'epoch_time_sec': 12.68, 'lr': 1.2086134545063002e-06, 'train_loss': 0.012025, 'train_psnr': 24.8838, 'val_psnr': 23.7158, 'best_val_psnr': 23.7158}
# {'epoch': 972, 'epoch_time_sec': 12.6, 'lr': 1.1944836399622138e-06, 'train_loss': 0.012021, 'train_psnr': 24.8847, 'val_psnr': 23.7158, 'best_val_psnr': 23.7158}
# {'epoch': 973, 'epoch_time_sec': 12.86, 'lr': 1.1808483314e-06, 'train_loss': 0.01202, 'train_psnr': 24.8858, 'val_psnr': 23.7158, 'best_val_psnr': 23.7158}
# {'epoch': 974, 'epoch_time_sec': 12.56, 'lr': 1.167707665573972e-06, 'train_loss': 0.012025, 'train_psnr': 24.8855, 'val_psnr': 23.7158, 'best_val_psnr': 23.7158}
# {'epoch': 975, 'epoch_time_sec': 12.61, 'lr': 1.1550617742774511e-06, 'train_loss': 0.012017, 'train_psnr': 24.8875, 'val_psnr': 23.7158, 'best_val_psnr': 23.7158}
# {'epoch': 976, 'epoch_time_sec': 12.83, 'lr': 1.1429107843414532e-06, 'train_loss': 0.012048, 'train_psnr': 24.8781, 'val_psnr': 23.7158, 'best_val_psnr': 23.7158}
# {'epoch': 977, 'epoch_time_sec': 13.06, 'lr': 1.13125481763342e-06, 'train_loss': 0.012036, 'train_psnr': 24.8798, 'val_psnr': 23.7158, 'best_val_psnr': 23.7158}
# {'epoch': 978, 'epoch_time_sec': 12.81, 'lr': 1.1200939910560045e-06, 'train_loss': 0.01202, 'train_psnr': 24.8849, 'val_psnr': 23.7158, 'best_val_psnr': 23.7158}
# {'epoch': 979, 'epoch_time_sec': 12.89, 'lr': 1.109428416545877e-06, 'train_loss': 0.012018, 'train_psnr': 24.8875, 'val_psnr': 23.7158, 'best_val_psnr': 23.7158}
# {'epoch': 980, 'epoch_time_sec': 12.9, 'lr': 1.0992582010726118e-06, 'train_loss': 0.012017, 'train_psnr': 24.8868, 'val_psnr': 23.7159, 'best_val_psnr': 23.7159}
# {'epoch': 981, 'epoch_time_sec': 12.69, 'lr': 1.0895834466376297e-06, 'train_loss': 0.012021, 'train_psnr': 24.8857, 'val_psnr': 23.7158, 'best_val_psnr': 23.7159}
# {'epoch': 982, 'epoch_time_sec': 12.87, 'lr': 1.0804042502731554e-06, 'train_loss': 0.012015, 'train_psnr': 24.8879, 'val_psnr': 23.7158, 'best_val_psnr': 23.7159}
# {'epoch': 983, 'epoch_time_sec': 12.65, 'lr': 1.0717207040412505e-06, 'train_loss': 0.012031, 'train_psnr': 24.8807, 'val_psnr': 23.7158, 'best_val_psnr': 23.7159}
# {'epoch': 984, 'epoch_time_sec': 12.77, 'lr': 1.0635328950328885e-06, 'train_loss': 0.01202, 'train_psnr': 24.8853, 'val_psnr': 23.7158, 'best_val_psnr': 23.7159}
# {'epoch': 985, 'epoch_time_sec': 12.6, 'lr': 1.0558409053670824e-06, 'train_loss': 0.012035, 'train_psnr': 24.8807, 'val_psnr': 23.7158, 'best_val_psnr': 23.7159}
# {'epoch': 986, 'epoch_time_sec': 12.79, 'lr': 1.0486448121900769e-06, 'train_loss': 0.012031, 'train_psnr': 24.8814, 'val_psnr': 23.7158, 'best_val_psnr': 23.7159}
# {'epoch': 987, 'epoch_time_sec': 12.77, 'lr': 1.041944687674545e-06, 'train_loss': 0.012036, 'train_psnr': 24.879, 'val_psnr': 23.7159, 'best_val_psnr': 23.7159}
# {'epoch': 988, 'epoch_time_sec': 12.78, 'lr': 1.0357405990188802e-06, 'train_loss': 0.012013, 'train_psnr': 24.8891, 'val_psnr': 23.7159, 'best_val_psnr': 23.7159}
# {'epoch': 989, 'epoch_time_sec': 12.62, 'lr': 1.0300326084465257e-06, 'train_loss': 0.012016, 'train_psnr': 24.8895, 'val_psnr': 23.7159, 'best_val_psnr': 23.7159}
# {'epoch': 990, 'epoch_time_sec': 12.64, 'lr': 1.0248207732053525e-06, 'train_loss': 0.012022, 'train_psnr': 24.8842, 'val_psnr': 23.7159, 'best_val_psnr': 23.7159}
# {'epoch': 991, 'epoch_time_sec': 12.66, 'lr': 1.0201051455670618e-06, 'train_loss': 0.012016, 'train_psnr': 24.8888, 'val_psnr': 23.7159, 'best_val_psnr': 23.7159}
# {'epoch': 992, 'epoch_time_sec': 12.65, 'lr': 1.0158857728266893e-06, 'train_loss': 0.012017, 'train_psnr': 24.8877, 'val_psnr': 23.7159, 'best_val_psnr': 23.7159}
# {'epoch': 993, 'epoch_time_sec': 12.79, 'lr': 1.0121626973021224e-06, 'train_loss': 0.012026, 'train_psnr': 24.8836, 'val_psnr': 23.7159, 'best_val_psnr': 23.7159}
# {'epoch': 994, 'epoch_time_sec': 13.0, 'lr': 1.0089359563336653e-06, 'train_loss': 0.012022, 'train_psnr': 24.8875, 'val_psnr': 23.7159, 'best_val_psnr': 23.7159}
# {'epoch': 995, 'epoch_time_sec': 12.91, 'lr': 1.006205582283677e-06, 'train_loss': 0.012022, 'train_psnr': 24.886, 'val_psnr': 23.7159, 'best_val_psnr': 23.7159}
# {'epoch': 996, 'epoch_time_sec': 12.81, 'lr': 1.0039716025362351e-06, 'train_loss': 0.012018, 'train_psnr': 24.8859, 'val_psnr': 23.7159, 'best_val_psnr': 23.7159}
# {'epoch': 997, 'epoch_time_sec': 12.65, 'lr': 1.0022340394968736e-06, 'train_loss': 0.01204, 'train_psnr': 24.8767, 'val_psnr': 23.7159, 'best_val_psnr': 23.7159}
# {'epoch': 998, 'epoch_time_sec': 12.8, 'lr': 1.0009929105923555e-06, 'train_loss': 0.012018, 'train_psnr': 24.8873, 'val_psnr': 23.7159, 'best_val_psnr': 23.7159}
# {'epoch': 999, 'epoch_time_sec': 12.75, 'lr': 1.000248228270488e-06, 'train_loss': 0.01203, 'train_psnr': 24.8835, 'val_psnr': 23.7159, 'best_val_psnr': 23.7159}
# {'epoch': 1000, 'epoch_time_sec': 12.69, 'lr': 1e-06, 'train_loss': 0.012036, 'train_psnr': 24.8802, 'val_psnr': 23.7159, 'best_val_psnr': 23.7159}

# %% [markdown]
# ## 4. Validation

# %%
best_model = build_eval_model_from_checkpoint(best_ckpt_path, device)
preview_info = write_val_preview(best_model, val_loader, preview_dir, device)
best_val_psnr = evaluate_psnr(best_model, val_loader, device)
validation_summary = {
    'input_psnr': input_psnr,
    'val_psnr': best_val_psnr,
    'delta_psnr': best_val_psnr - input_psnr,
}
print({
    'validation_summary': validation_summary,
    'preview': preview_info,
    'best_checkpoint_path': str(best_ckpt_path),
})
# Out:
# {'validation_summary': {'input_psnr': 23.133060299266468, 'val_psnr': 23.715922251614657, 'delta_psnr': 0.582861952348189}, 'preview': {'sample_name': '0000', 'input': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/072607_2504_base/exports/val_preview/val_preview_input.png', 'prediction': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/072607_2504_base/exports/val_preview/val_preview_pred.png', 'target': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/072607_2504_base/exports/val_preview/val_preview_target.png'}, 'best_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/072607_2504_base/checkpoints/best.pth'}

# %% [markdown]
# ## 5. Export and Submission Artifacts
#
# ONNX export is included here. MXQ conversion stays in a separate workflow.

# %%
onnx_path = exports_dir / f'{cfg.model_id}.onnx'
export_model = build_eval_model_from_checkpoint(best_ckpt_path, device)
dummy = torch.randn(1, 3, 256, 256, device=device)

torch.onnx.export(
    export_model,
    dummy,
    str(onnx_path),
    input_names=['input'],
    output_names=['output'],
    opset_version=17,
    dynamo=False,
)

onnx_model = onnx.load(str(onnx_path))
onnx.checker.check_model(onnx_model)
node_ops = [node.op_type for node in onnx_model.graph.node]
op_histogram = {op: node_ops.count(op) for op in sorted(set(node_ops))}
print({
    'onnx_path': str(onnx_path),
    'graph_op_count': len(node_ops),
    'op_histogram': op_histogram,
})

parity_result = {
    'attempted': False,
    'onnxruntime_available': False,
    'max_abs_diff': None,
}
try:
    import onnxruntime as ort

    parity_result['attempted'] = True
    parity_result['onnxruntime_available'] = True
    cpu_model = build_eval_model_from_checkpoint(best_ckpt_path, torch.device('cpu')).cpu().eval()
    parity_input = torch.randn(1, 3, 256, 256)
    with torch.no_grad():
        torch_out = cpu_model(parity_input).detach().cpu().numpy()
    ort_session = ort.InferenceSession(str(onnx_path), providers=['CPUExecutionProvider'])
    ort_out = ort_session.run(['output'], {'input': parity_input.numpy()})[0]
    parity_result['max_abs_diff'] = float(np.max(np.abs(torch_out - ort_out)))
except ImportError:
    print('onnxruntime not installed; skipping CPU parity check')
print(parity_result)

summary = {
    'model_id': cfg.model_id,
    'run_root': str(run_root),
    'best_checkpoint_path': str(best_ckpt_path),
    'last_checkpoint_path': str(last_ckpt_path),
    'onnx_path': str(onnx_path),
    'metrics_csv_path': str(metrics_csv_path),
    'validation': validation_summary,
    'preview': preview_info,
    'onnx_parity': parity_result,
    'mxq_scope': 'Not handled in this notebook; separate workflow.',
}
summary_path.write_text(json.dumps(summary, indent=2), encoding='utf-8')
print(summary)
# Out:
# /tmp/ipykernel_32899/1798986534.py:5: DeprecationWarning: You are using the legacy TorchScript-based ONNX export. Starting in PyTorch 2.9, the new torch.export-based ONNX exporter has become the default. Learn more about the new export logic: https://docs.pytorch.org/docs/stable/onnx_export.html. For exporting control flow: https://pytorch.org/tutorials/beginner/onnx/export_control_flow_model_to_onnx_tutorial.html
#   torch.onnx.export(
# {'onnx_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/072607_2504_base/exports/tinysrcnn_noadd_lrelu.onnx', 'graph_op_count': 9, 'op_histogram': {'Conv': 5, 'LeakyRelu': 4}}
# {'attempted': True, 'onnxruntime_available': True, 'max_abs_diff': 9.5367431640625e-07}
# {'model_id': 'tinysrcnn_noadd_lrelu', 'run_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/072607_2504_base', 'best_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/072607_2504_base/checkpoints/best.pth', 'last_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/072607_2504_base/checkpoints/last.pth', 'onnx_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/072607_2504_base/exports/tinysrcnn_noadd_lrelu.onnx', 'metrics_csv_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/072607_2504_base/metrics.csv', 'validation': {'input_psnr': 23.133060299266468, 'val_psnr': 23.715922251614657, 'delta_psnr': 0.582861952348189}, 'preview': {'sample_name': '0000', 'input': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/072607_2504_base/exports/val_preview/val_preview_input.png', 'prediction': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/072607_2504_base/exports/val_preview/val_preview_pred.png', 'target': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/072607_2504_base/exports/val_preview/val_preview_target.png'}, 'onnx_parity': {'attempted': True, 'onnxruntime_available': True, 'max_abs_diff': 9.5367431640625e-07}, 'mxq_scope': 'Not handled in this notebook; separate workflow.'}
