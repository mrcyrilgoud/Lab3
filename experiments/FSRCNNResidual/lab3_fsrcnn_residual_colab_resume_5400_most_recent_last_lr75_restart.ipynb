# %% [markdown]
# # Lab 3 - FSRCNN Residual 96/40/m8 Resume Current Last LR 7.5e-5 Warm Restart (Colab)

# %% [markdown]
# ## 1. Setup

# %%
try:
    import google.colab  # type: ignore
    IN_COLAB_BOOTSTRAP = True
except Exception:
    IN_COLAB_BOOTSTRAP = False

if IN_COLAB_BOOTSTRAP:
    # %pip install -q onnx onnxruntime

import csv
import json
import math
import os
import random
import sys
import time
from contextlib import nullcontext
from dataclasses import asdict, dataclass
from datetime import datetime
from pathlib import Path
from typing import Any

import numpy as np
import onnx
import torch
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
from torch.utils.data import DataLoader, Dataset

IMAGE_SUFFIXES = {'.png', '.jpg', '.jpeg', '.bmp'}
DRIVE_ROOT = Path('/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3')
DRIVE_DATA_ROOT = DRIVE_ROOT / 'Data'
DRIVE_RUNS_ROOT = DRIVE_ROOT / 'runs'

try:
    BICUBIC_RESAMPLE = Image.Resampling.BICUBIC
except AttributeError:
    BICUBIC_RESAMPLE = Image.BICUBIC

try:
    FLIP_LEFT_RIGHT = Image.Transpose.FLIP_LEFT_RIGHT
    FLIP_TOP_BOTTOM = Image.Transpose.FLIP_TOP_BOTTOM
    ROTATE_90 = Image.Transpose.ROTATE_90
    ROTATE_180 = Image.Transpose.ROTATE_180
    ROTATE_270 = Image.Transpose.ROTATE_270
except AttributeError:
    FLIP_LEFT_RIGHT = Image.FLIP_LEFT_RIGHT
    FLIP_TOP_BOTTOM = Image.FLIP_TOP_BOTTOM
    ROTATE_90 = Image.ROTATE_90
    ROTATE_180 = Image.ROTATE_180
    ROTATE_270 = Image.ROTATE_270


def set_global_seed(seed: int) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


def now_stamp() -> str:
    return datetime.now().strftime('%H%M%S_%d%m')


def is_colab_runtime() -> bool:
    try:
        import google.colab  # type: ignore  # noqa: F401
        return True
    except Exception:
        return False


def auto_num_workers(in_colab: bool) -> int:
    if sys.platform == 'darwin':
        return 0
    cpu_count = max(os.cpu_count() or 2, 2)
    if in_colab:
        return min(4, max(cpu_count - 1, 2))
    return min(2, cpu_count)


def resolve_repo_root(start: Path) -> Path:
    current = start.resolve()
    for candidate in [current, *current.parents]:
        if (candidate / 'Data').exists() and (candidate / 'runs').exists():
            return candidate
    for candidate in [current, *current.parents]:
        if (candidate / 'Data').exists():
            return candidate
    raise FileNotFoundError(f'Could not locate repo root from {start.resolve()}')


def make_unique_run_root(runs_root: Path, run_slug: str) -> Path:
    safe_slug = ''.join(ch if ch.isalnum() or ch in '_-' else '_' for ch in run_slug).strip('_')
    candidate = runs_root / f'{now_stamp()}_{safe_slug}'
    while candidate.exists():
        time.sleep(1.1)
        candidate = runs_root / f'{now_stamp()}_{safe_slug}'
    return candidate


def write_json(path: Path, payload: dict[str, Any]) -> None:
    path.parent.mkdir(parents=True, exist_ok=True)
    path.write_text(json.dumps(payload, indent=2, sort_keys=True) + '\n', encoding='utf-8')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 95.5 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 135.8 MB/s eta 0:00:0000:010:01

# %% [markdown]
# ## 2. Configuration

# %%
@dataclass
class RunConfig:
    model_id: str = 'fsrcnn_residual_96_40_m8'
    run_slug: str = 'fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart'
    enable_resume: bool = True
    resume_checkpoint_path: str | None = (
        '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/'
        'runs/163626_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart/checkpoints/last.pth'
    )

    seed: int = 1337
    train_patch_size: int = 256
    eval_size: int = 256
    batch_size: int = 16
    epochs: int = 5400

    lr: float = 7.5e-5
    min_lr: float = 2e-6
    warmup_epochs: int = 5
    weight_decay: float = 1e-4
    load_optimizer_state: bool = False

    num_workers: int | None = 2
    prefetch_factor: int = 2
    use_amp: bool = True
    use_ema: bool = True
    ema_decay: float = 0.999

cfg = RunConfig()
in_colab = is_colab_runtime()
if in_colab:
    from google.colab import drive  # type: ignore

    drive.mount('/content/drive', force_remount=False)
    data_root = DRIVE_DATA_ROOT
    runs_root = DRIVE_RUNS_ROOT
    if not data_root.exists():
        raise FileNotFoundError(f'Google Drive data root not found: {data_root}')
else:
    repo_root = resolve_repo_root(Path.cwd())
    data_root = repo_root / 'Data'
    runs_root = repo_root / 'runs'
    if not data_root.exists():
        raise FileNotFoundError(f'Data root not found: {data_root}')

runs_root.mkdir(parents=True, exist_ok=True)
if cfg.num_workers is None:
    cfg.num_workers = auto_num_workers(in_colab)
if not cfg.enable_resume:
    cfg.resume_checkpoint_path = None

run_root = make_unique_run_root(runs_root, cfg.run_slug)
checkpoints_dir = run_root / 'checkpoints'
exports_dir = run_root / 'exports'
preview_dir = exports_dir / 'val_preview'
summary_path = run_root / 'summary.json'
metrics_csv_path = run_root / 'metrics.csv'
history_json_path = run_root / 'history.json'
run_manifest_path = run_root / 'run_manifest.json'
run_log_paths = {'metrics_csv': str(metrics_csv_path), 'history_json': str(history_json_path), 'summary_json': str(summary_path), 'run_manifest': str(run_manifest_path)}

for directory in [run_root, checkpoints_dir, exports_dir, preview_dir]:
    directory.mkdir(parents=True, exist_ok=True)

set_global_seed(cfg.seed)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
cuda_enabled = device.type == 'cuda'
gpu_name = torch.cuda.get_device_name(0) if cuda_enabled else None
if cuda_enabled:
    torch.backends.cudnn.benchmark = True
    if hasattr(torch.backends.cuda.matmul, 'allow_tf32'):
        torch.backends.cuda.matmul.allow_tf32 = True

print({
    'device': str(device),
    'in_colab': in_colab,
    'data_root': str(data_root),
    'run_root': str(run_root),
    'gpu_name': gpu_name,
    'config': asdict(cfg),
})
# Out:
# Mounted at /content/drive
# {'device': 'cuda', 'in_colab': True, 'data_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/Data', 'run_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/182012_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart', 'gpu_name': 'NVIDIA L4', 'config': {'model_id': 'fsrcnn_residual_96_40_m8', 'run_slug': 'fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart', 'enable_resume': True, 'resume_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/163626_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart/checkpoints/last.pth', 'seed': 1337, 'train_patch_size': 256, 'eval_size': 256, 'batch_size': 16, 'epochs': 5400, 'lr': 7.5e-05, 'min_lr': 2e-06, 'warmup_epochs': 5, 'weight_decay': 0.0001, 'load_optimizer_state': False, 'num_workers': 2, 'prefetch_factor': 2, 'use_amp': True, 'use_ema': True, 'ema_decay': 0.999}}

# %% [markdown]
# ## 3. Data

# %%
L3_TRAIN_SPLITS = (
    ('LR_HR/L3_HR_train1', 'L3_LR/L3_L3_train1', 'L3_HR_train1'),
    ('LR_HR/L3_HR_train2', 'L3_LR/L3_L3_train2', 'L3_HR_train2'),
    ('LR_HR/L3_HR_train3', 'L3_LR/L3_LR_train3', 'L3_HR_train3'),
    ('LR_HR/L3_HR_train4', 'L3_LR/L3_LR_train4', 'L3_HR_train4'),
    ('LR_HR/L3_HR_train', 'L3_LR/L3_LR_train', 'L3_HR_train'),
)
L3_VAL_DIRS = ('L3_HR_valid', 'L3_LR_valid')


def scan_image_directory(directory: Path) -> dict[str, Path]:
    if not directory.exists():
        raise FileNotFoundError(f'Missing directory: {directory}')
    return {
        path.stem: path
        for path in directory.iterdir()
        if path.is_file() and path.suffix.lower() in IMAGE_SUFFIXES
    }


def collect_split_pairs(hr_dir: Path, lr_dir: Path, split_name: str) -> list[tuple[Path, Path, str]]:
    hr_map = scan_image_directory(hr_dir)
    lr_map = scan_image_directory(lr_dir)
    shared = sorted(set(hr_map) & set(lr_map))
    if not shared:
        raise FileNotFoundError(f'No paired files found for {split_name}: HR={hr_dir}, LR={lr_dir}')
    hr_only = sorted(set(hr_map) - set(lr_map))
    lr_only = sorted(set(lr_map) - set(hr_map))
    if hr_only or lr_only:
        print({'split': split_name, 'hr_only_count': len(hr_only), 'lr_only_count': len(lr_only)})
    pairs: list[tuple[Path, Path, str]] = []
    for stem in shared:
        name = stem if split_name == 'val' else f'{split_name}/{stem}'
        pairs.append((lr_map[stem], hr_map[stem], name))
    return pairs


def collect_all_pairs(data_root: Path) -> tuple[list[tuple[Path, Path, str]], list[tuple[Path, Path, str]]]:
    train_pairs: list[tuple[Path, Path, str]] = []
    for hr_rel, lr_rel, split_name in L3_TRAIN_SPLITS:
        hr_dir = data_root / hr_rel
        lr_dir = data_root / lr_rel
        if hr_dir.exists() and lr_dir.exists():
            train_pairs.extend(collect_split_pairs(hr_dir, lr_dir, split_name))
        else:
            print({'skipped_missing_train_split': split_name, 'hr_dir': str(hr_dir), 'lr_dir': str(lr_dir)})
    val_pairs = collect_split_pairs(data_root / L3_VAL_DIRS[0], data_root / L3_VAL_DIRS[1], 'val')
    return train_pairs, val_pairs


class PairedSRDataset(Dataset):
    def __init__(self, pairs: list[tuple[Path, Path, str]], *, train: bool, patch_size: int, eval_size: int, seed: int):
        self.pairs = pairs
        self.train = train
        self.patch_size = patch_size
        self.eval_size = eval_size
        self.seed = seed
        self.epoch = 0

    def set_epoch(self, epoch: int) -> None:
        self.epoch = epoch

    @staticmethod
    def to_tensor(img: Image.Image) -> torch.Tensor:
        arr = np.asarray(img, dtype=np.float32) / 255.0
        return torch.from_numpy(arr).permute(2, 0, 1).contiguous()

    def augment_pair(self, lr: Image.Image, hr: Image.Image, index: int) -> tuple[Image.Image, Image.Image]:
        rng = random.Random((self.seed * 1_000_003) + (self.epoch * 9_973) + index)
        width, height = lr.size
        patch = self.patch_size
        if width < patch or height < patch:
            lr = lr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            hr = hr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            width, height = lr.size
        left = rng.randint(0, width - patch)
        top = rng.randint(0, height - patch)
        box = (left, top, left + patch, top + patch)
        lr = lr.crop(box)
        hr = hr.crop(box)
        if rng.random() < 0.5:
            lr = lr.transpose(FLIP_LEFT_RIGHT)
            hr = hr.transpose(FLIP_LEFT_RIGHT)
        if rng.random() < 0.5:
            lr = lr.transpose(FLIP_TOP_BOTTOM)
            hr = hr.transpose(FLIP_TOP_BOTTOM)
        rot = rng.choice([0, 1, 2, 3])
        if rot:
            rotate_ops = [ROTATE_90, ROTATE_180, ROTATE_270]
            lr = lr.transpose(rotate_ops[rot - 1])
            hr = hr.transpose(rotate_ops[rot - 1])
        return lr, hr

    def __len__(self) -> int:
        return len(self.pairs)

    def __getitem__(self, index: int) -> dict[str, Any]:
        lr_path, hr_path, name = self.pairs[index]
        lr = Image.open(lr_path).convert('RGB')
        hr = Image.open(hr_path).convert('RGB')
        if self.train:
            lr, hr = self.augment_pair(lr, hr, index)
        elif lr.size != (self.eval_size, self.eval_size):
            lr = lr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            hr = hr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
        return {'lr': self.to_tensor(lr), 'hr': self.to_tensor(hr), 'name': name}

train_pairs, val_pairs = collect_all_pairs(data_root)
if not train_pairs:
    raise FileNotFoundError(f'No training pairs found under {data_root}')
if not val_pairs:
    raise FileNotFoundError(f'No validation pairs found under {data_root}')

train_ds = PairedSRDataset(train_pairs, train=True, patch_size=cfg.train_patch_size, eval_size=cfg.eval_size, seed=cfg.seed)
val_ds = PairedSRDataset(val_pairs, train=False, patch_size=cfg.train_patch_size, eval_size=cfg.eval_size, seed=cfg.seed)

loader_num_workers = int(cfg.num_workers or 0)
train_loader_kwargs = {
    'dataset': train_ds,
    'batch_size': cfg.batch_size,
    'shuffle': True,
    'num_workers': loader_num_workers,
    'pin_memory': cuda_enabled,
}
val_loader_kwargs = {
    'dataset': val_ds,
    'batch_size': 1,
    'shuffle': False,
    'num_workers': loader_num_workers,
    'pin_memory': cuda_enabled,
}
if loader_num_workers > 0:
    train_loader_kwargs['persistent_workers'] = True
    val_loader_kwargs['persistent_workers'] = True
    train_loader_kwargs['prefetch_factor'] = cfg.prefetch_factor
    val_loader_kwargs['prefetch_factor'] = cfg.prefetch_factor

train_loader = DataLoader(**train_loader_kwargs)
val_loader = DataLoader(**val_loader_kwargs)

sample = train_ds[0]
print({
    'data_root': str(data_root),
    'train_pairs': len(train_pairs),
    'val_pairs': len(val_pairs),
    'train_preview': [name for _, _, name in train_pairs[:5]],
    'val_preview': [name for _, _, name in val_pairs[:5]],
    'sample_lr_shape': tuple(sample['lr'].shape),
    'sample_hr_shape': tuple(sample['hr'].shape),
})
assert tuple(sample['lr'].shape) == (3, cfg.eval_size, cfg.eval_size)
assert tuple(sample['hr'].shape) == (3, cfg.eval_size, cfg.eval_size)
# Out:
# {'data_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/Data', 'train_pairs': 2217, 'val_pairs': 110, 'train_preview': ['L3_HR_train1/0000', 'L3_HR_train1/0001', 'L3_HR_train1/00010', 'L3_HR_train1/000100', 'L3_HR_train1/000101'], 'val_preview': ['0000', '00010', '000100', '000102', '000104'], 'sample_lr_shape': (3, 256, 256), 'sample_hr_shape': (3, 256, 256)}

# %% [markdown]
# ## 4. Model

# %%
class FSRCNNResidualNoUpscale(nn.Module):
    """FSRCNN-style residual refiner for 256x256 RGB input/output."""

    def __init__(self, channels: int = 96, shrink_channels: int = 40, mapping_layers: int = 8, slope: float = 0.10):
        super().__init__()
        self.channels = channels
        self.shrink_channels = shrink_channels
        self.mapping_layers = mapping_layers
        self.slope = slope

        self.features = nn.Sequential(*self._feature_layers())
        self.tail = nn.Conv2d(channels, 3, 3, padding=1, bias=True)
        self.init_tail_small()

    def _activation(self) -> nn.Module:
        return nn.LeakyReLU(self.slope, inplace=False)

    def _feature_layers(self) -> list[nn.Module]:
        stem = [
            nn.Conv2d(3, self.channels, 5, padding=2, bias=True),
            self._activation(),
        ]
        shrink = [
            nn.Conv2d(self.channels, self.shrink_channels, 1, padding=0, bias=True),
            self._activation(),
        ]
        mapping: list[nn.Module] = []
        for _ in range(self.mapping_layers):
            mapping.extend([
                nn.Conv2d(self.shrink_channels, self.shrink_channels, 3, padding=1, bias=True),
                self._activation(),
            ])
        expand = [
            nn.Conv2d(self.shrink_channels, self.channels, 1, padding=0, bias=True),
            self._activation(),
        ]
        return [*stem, *shrink, *mapping, *expand]

    def architecture_summary(self) -> dict[str, str | int]:
        return {
            'stem': f'Conv5x5 3->{self.channels} + LeakyReLU',
            'shrink': f'Conv1x1 {self.channels}->{self.shrink_channels} + LeakyReLU',
            'mapping': f'{self.mapping_layers}x Conv3x3 {self.shrink_channels}->{self.shrink_channels} + LeakyReLU',
            'expand': f'Conv1x1 {self.shrink_channels}->{self.channels} + LeakyReLU',
            'tail': f'Conv3x3 {self.channels}->3 residual delta',
            'forward': 'output = input + residual_delta',
        }

    def init_tail_small(self) -> None:
        nn.init.kaiming_normal_(self.tail.weight, nonlinearity='linear')
        self.tail.weight.data.mul_(1e-3)
        if self.tail.bias is not None:
            nn.init.zeros_(self.tail.bias)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return x + self.tail(self.features(x))


def count_parameters(module: nn.Module) -> int:
    return int(sum(param.numel() for param in module.parameters()))


def operator_audit(module: nn.Module) -> dict[str, int]:
    counts: dict[str, int] = {}
    for child in module.modules():
        if len(list(child.children())) != 0:
            continue
        name = child.__class__.__name__
        counts[name] = counts.get(name, 0) + 1
    return dict(sorted(counts.items()))

model = FSRCNNResidualNoUpscale().to(device)
eval_model = FSRCNNResidualNoUpscale().to(device)
param_count = count_parameters(model)
op_counts = operator_audit(model)
dummy = torch.zeros(1, 3, cfg.eval_size, cfg.eval_size, device=device)
with torch.no_grad():
    dummy_out = model(dummy)

print({
    'model_id': cfg.model_id,
    'params': param_count,
    'operator_audit': op_counts,
    'input_shape': tuple(dummy.shape),
    'output_shape': tuple(dummy_out.shape),
    'architecture': model.architecture_summary(),
})
assert param_count == 133_227, param_count
assert tuple(dummy_out.shape) == (1, 3, cfg.eval_size, cfg.eval_size)
assert set(op_counts).issubset({'Conv2d', 'LeakyReLU'}), op_counts
# Out:
# {'model_id': 'fsrcnn_residual_96_40_m8', 'params': 133227, 'operator_audit': {'Conv2d': 12, 'LeakyReLU': 11}, 'input_shape': (1, 3, 256, 256), 'output_shape': (1, 3, 256, 256), 'architecture': {'stem': 'Conv5x5 3->96 + LeakyReLU', 'shrink': 'Conv1x1 96->40 + LeakyReLU', 'mapping': '8x Conv3x3 40->40 + LeakyReLU', 'expand': 'Conv1x1 40->96 + LeakyReLU', 'tail': 'Conv3x3 96->3 residual delta', 'forward': 'output = input + residual_delta'}}

# %% [markdown]
# ## 5. Training And Validation

# %%
class EMA:
    def __init__(self, model: nn.Module, decay: float):
        self.decay = decay
        self.shadow = {k: v.detach().clone() for k, v in model.state_dict().items()}

    @torch.no_grad()
    def update(self, model: nn.Module) -> None:
        for key, value in model.state_dict().items():
            self.shadow[key].mul_(self.decay).add_(value.detach(), alpha=1.0 - self.decay)

    @torch.no_grad()
    def copy_to(self, model: nn.Module) -> None:
        model.load_state_dict(self.shadow, strict=True)


def make_grad_scaler(enabled: bool):
    if hasattr(torch, 'amp') and hasattr(torch.amp, 'GradScaler'):
        return torch.amp.GradScaler('cuda', enabled=enabled)
    return torch.cuda.amp.GradScaler(enabled=enabled)


def autocast_context(device_type: str, enabled: bool):
    if not enabled:
        return nullcontext()
    if hasattr(torch, 'amp') and hasattr(torch.amp, 'autocast'):
        return torch.amp.autocast(device_type=device_type, enabled=enabled)
    return torch.cuda.amp.autocast(enabled=enabled)


@torch.no_grad()
def batch_psnr(pred: torch.Tensor, target: torch.Tensor) -> float:
    mse = F.mse_loss(pred, target, reduction='none').mean(dim=(1, 2, 3))
    psnr = 10.0 * torch.log10(1.0 / torch.clamp(mse, min=1e-12))
    return float(psnr.mean().item())


def compute_loss(pred: torch.Tensor, lr: torch.Tensor, hr: torch.Tensor) -> torch.Tensor:
    mse = F.mse_loss(pred, hr)
    residual_l1 = F.l1_loss(pred - lr, hr - lr)
    return 0.8 * mse + 0.2 * residual_l1


def lr_at_epoch(
    epoch_idx: int,
    *,
    base_lr: float,
    min_lr: float,
    warmup_epochs: int,
    total_epochs: int,
    schedule_start_epoch: int = 0,
) -> float:
    step = epoch_idx - schedule_start_epoch + 1
    span = max(1, total_epochs - schedule_start_epoch)

    if warmup_epochs > 0 and step <= warmup_epochs:
        return base_lr * step / warmup_epochs

    progress = (step - warmup_epochs) / max(1, span - warmup_epochs)
    progress = min(max(progress, 0.0), 1.0)
    cosine = 0.5 * (1.0 + math.cos(math.pi * progress))
    return min_lr + cosine * (base_lr - min_lr)

def evaluate_metrics(model: nn.Module, loader: DataLoader, device: torch.device) -> dict[str, float]:
    model.eval()
    pred_meter = 0.0
    input_meter = 0.0
    count = 0
    for batch in loader:
        lr = batch['lr'].to(device, non_blocking=cuda_enabled)
        hr = batch['hr'].to(device, non_blocking=cuda_enabled)
        pred = model(lr).clamp(0.0, 1.0)
        pred_meter += batch_psnr(pred, hr)
        input_meter += batch_psnr(lr, hr)
        count += 1
    val_psnr = pred_meter / max(count, 1)
    input_psnr = input_meter / max(count, 1)
    return {'val_psnr': float(val_psnr), 'input_psnr': float(input_psnr), 'delta_psnr': float(val_psnr - input_psnr)}


def tensor_to_uint8_image(x: torch.Tensor) -> Image.Image:
    x = x.detach().cpu().clamp(0.0, 1.0)
    arr = (x.permute(1, 2, 0).numpy() * 255.0).round().astype(np.uint8)
    return Image.fromarray(arr)


@torch.no_grad()
def write_val_preview(model: nn.Module, loader: DataLoader, out_dir: Path, device: torch.device) -> dict[str, str]:
    out_dir.mkdir(parents=True, exist_ok=True)
    batch = next(iter(loader))
    lr = batch['lr'].to(device, non_blocking=cuda_enabled)
    hr = batch['hr'].to(device, non_blocking=cuda_enabled)
    pred = model(lr).clamp(0.0, 1.0)
    name = batch['name'][0]
    lr_path = out_dir / 'val_preview_input.png'
    pred_path = out_dir / 'val_preview_pred.png'
    hr_path = out_dir / 'val_preview_target.png'
    tensor_to_uint8_image(lr[0]).save(lr_path)
    tensor_to_uint8_image(pred[0]).save(pred_path)
    tensor_to_uint8_image(hr[0]).save(hr_path)
    return {'sample_name': str(name), 'input': str(lr_path), 'prediction': str(pred_path), 'target': str(hr_path)}


def checkpoint_payload(model: nn.Module, ema: EMA | None, optimizer: torch.optim.Optimizer, epoch: int, best_val_psnr: float, row: dict[str, Any]) -> dict[str, Any]:
    return {
        'config': asdict(cfg),
        'epoch': int(epoch),
        'model_state_dict': model.state_dict(),
        'ema_state_dict': ema.shadow if ema is not None else None,
        'optimizer_state_dict': optimizer.state_dict(),
        'best_val_psnr': float(best_val_psnr),
        'latest_metrics': row,
        'model_params': param_count,
        'operator_audit': op_counts,
    }


def load_checkpoint_for_eval(checkpoint_path: Path, device: torch.device) -> nn.Module:
    checkpoint = torch.load(checkpoint_path, map_location=device)
    loaded = FSRCNNResidualNoUpscale().to(device)
    state = checkpoint.get('ema_state_dict') or checkpoint['model_state_dict']
    loaded.load_state_dict(state, strict=True)
    loaded.eval()
    return loaded

optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)
scaler = make_grad_scaler(cfg.use_amp and cuda_enabled)
ema = EMA(model, cfg.ema_decay) if cfg.use_ema else None
best_val_psnr = float('-inf')
start_epoch = 0

metrics_header = ['epoch', 'epoch_time_sec', 'lr', 'train_loss', 'train_psnr', 'val_psnr', 'input_psnr', 'delta_psnr', 'best_val_psnr']
best_ckpt_path = checkpoints_dir / 'best.pth'
last_ckpt_path = checkpoints_dir / 'last.pth'
resume_info: dict[str, Any] = {

    'enabled': cfg.enable_resume,

    'checkpoint_path': cfg.resume_checkpoint_path,

}

optimizer_state_loaded = False




if cfg.enable_resume:

    if cfg.resume_checkpoint_path is None:

        raise ValueError('cfg.enable_resume=True requires cfg.resume_checkpoint_path')

    resume_checkpoint_path = Path(cfg.resume_checkpoint_path)

    if not resume_checkpoint_path.exists():

        raise FileNotFoundError(f'Resume checkpoint not found: {resume_checkpoint_path}')

    resume_checkpoint = torch.load(resume_checkpoint_path, map_location=device)

    model.load_state_dict(resume_checkpoint['model_state_dict'], strict=True)

    if cfg.load_optimizer_state and 'optimizer_state_dict' in resume_checkpoint:

        optimizer.load_state_dict(resume_checkpoint['optimizer_state_dict'])

        optimizer_state_loaded = True


    if ema is not None and resume_checkpoint.get('ema_state_dict') is not None:

        ema.shadow = {key: value.detach().clone().to(device) for key, value in resume_checkpoint['ema_state_dict'].items()}

    best_val_psnr = float(resume_checkpoint.get('best_val_psnr', best_val_psnr))

    start_epoch = int(resume_checkpoint.get('epoch', 0))

    resume_info.update({

        'checkpoint_path': str(resume_checkpoint_path),

        'checkpoint_epoch': start_epoch,

        'checkpoint_best_val_psnr': best_val_psnr,

        'checkpoint_latest_metrics': resume_checkpoint.get('latest_metrics'),

        'checkpoint_config': resume_checkpoint.get('config'),

        'checkpoint_model_params': resume_checkpoint.get('model_params'),

        'checkpoint_operator_audit': resume_checkpoint.get('operator_audit'),

        'optimizer_state_loaded': optimizer_state_loaded,

        'load_optimizer_state': cfg.load_optimizer_state,



    })

    print({

        'resume_checkpoint_path': str(resume_checkpoint_path),

        'resumed_from_epoch': start_epoch,

        'target_total_epochs': cfg.epochs,






        **run_log_paths,

        'best_val_psnr': best_val_psnr,

    })



if start_epoch >= cfg.epochs:
    raise ValueError(f'Resume checkpoint epoch {start_epoch} is already >= target epochs {cfg.epochs}')

lr_schedule_info = {

    'type': 'resume_local_cosine_warm_restart',

    'base_lr': cfg.lr,

    'min_lr': cfg.min_lr,

    'warmup_epochs': cfg.warmup_epochs,

    'schedule_start_epoch': start_epoch,

    'target_total_epochs': cfg.epochs,

    'load_optimizer_state': cfg.load_optimizer_state,

    'optimizer_state_loaded': optimizer_state_loaded,

}



history = {
    'metadata': {
        'config': asdict(cfg),
        'run_root': str(run_root),
        'resume_checkpoint_path': cfg.resume_checkpoint_path,
        'resume': resume_info,

        'lr_schedule': lr_schedule_info,

        'start_epoch': start_epoch,
        'target_total_epochs': cfg.epochs,
        **run_log_paths,
        'device': str(device),
        'gpu_name': gpu_name,
        'torch_version': torch.__version__,
        'cuda_version': torch.version.cuda,
    },
    'epochs': [],
}
write_json(history_json_path, history)
write_json(run_manifest_path, history['metadata'])

with metrics_csv_path.open('w', newline='', encoding='utf-8') as f:
    csv.DictWriter(f, fieldnames=metrics_header).writeheader()

for epoch in range(start_epoch, cfg.epochs):
    train_ds.set_epoch(epoch)
    epoch_lr = lr_at_epoch(

        epoch,

        base_lr=cfg.lr,

        min_lr=cfg.min_lr,

        warmup_epochs=cfg.warmup_epochs,

        total_epochs=cfg.epochs,

        schedule_start_epoch=start_epoch,

    )
    for group in optimizer.param_groups:
        group['lr'] = epoch_lr

    epoch_start = time.time()
    model.train()
    train_loss_sum = 0.0
    train_psnr_sum = 0.0
    train_batches = 0

    for batch in train_loader:
        lr = batch['lr'].to(device, non_blocking=cuda_enabled)
        hr = batch['hr'].to(device, non_blocking=cuda_enabled)
        optimizer.zero_grad(set_to_none=True)
        with autocast_context(device.type, enabled=(cfg.use_amp and cuda_enabled)):
            pred = model(lr)
            loss = compute_loss(pred, lr, hr)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        if ema is not None:
            ema.update(model)
        train_loss_sum += float(loss.item())
        train_psnr_sum += batch_psnr(pred.detach().clamp(0.0, 1.0), hr)
        train_batches += 1

    if ema is not None:
        ema.copy_to(eval_model)
    else:
        eval_model.load_state_dict(model.state_dict())
    eval_model.eval()

    avg_train_loss = train_loss_sum / max(train_batches, 1)
    avg_train_psnr = train_psnr_sum / max(train_batches, 1)
    val_metrics = evaluate_metrics(eval_model, val_loader, device)
    is_best = val_metrics['val_psnr'] > best_val_psnr
    if is_best:
        best_val_psnr = val_metrics['val_psnr']
    row = {
        'epoch': epoch + 1,
        'epoch_time_sec': round(time.time() - epoch_start, 2),
        'lr': epoch_lr,
        'train_loss': round(avg_train_loss, 6),
        'train_psnr': round(avg_train_psnr, 4),
        'val_psnr': round(val_metrics['val_psnr'], 4),
        'input_psnr': round(val_metrics['input_psnr'], 4),
        'delta_psnr': round(val_metrics['delta_psnr'], 4),
        'best_val_psnr': round(best_val_psnr, 4),
    }
    print(row)
    history['epochs'].append(row)
    write_json(history_json_path, history)
    with metrics_csv_path.open('a', newline='', encoding='utf-8') as f:
        csv.DictWriter(f, fieldnames=metrics_header).writerow(row)
    payload = checkpoint_payload(model, ema, optimizer, epoch + 1, best_val_psnr, row)
    torch.save(payload, last_ckpt_path)
    if is_best:
        torch.save(payload, best_ckpt_path)
# Out:
# {'resume_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/163626_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart/checkpoints/last.pth', 'resumed_from_epoch': 4934, 'target_total_epochs': 5400, 'metrics_csv': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/182012_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart/metrics.csv', 'history_json': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/182012_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart/history.json', 'summary_json': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/182012_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart/summary.json', 'run_manifest': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/182012_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart/run_manifest.json', 'best_val_psnr': 24.047440060702236}
# {'epoch': 4935, 'epoch_time_sec': 1936.14, 'lr': 1.4999999999999999e-05, 'train_loss': 0.01158, 'train_psnr': 25.1625, 'val_psnr': 24.0474, 'input_psnr': 23.1331, 'delta_psnr': 0.9143, 'best_val_psnr': 24.0474}
# {'epoch': 4936, 'epoch_time_sec': 19.95, 'lr': 2.9999999999999997e-05, 'train_loss': 0.011578, 'train_psnr': 25.1622, 'val_psnr': 24.0477, 'input_psnr': 23.1331, 'delta_psnr': 0.9147, 'best_val_psnr': 24.0477}
# {'epoch': 4937, 'epoch_time_sec': 19.78, 'lr': 4.4999999999999996e-05, 'train_loss': 0.011582, 'train_psnr': 25.1622, 'val_psnr': 24.0481, 'input_psnr': 23.1331, 'delta_psnr': 0.915, 'best_val_psnr': 24.0481}
# {'epoch': 4938, 'epoch_time_sec': 19.68, 'lr': 5.9999999999999995e-05, 'train_loss': 0.01159, 'train_psnr': 25.1559, 'val_psnr': 24.0482, 'input_psnr': 23.1331, 'delta_psnr': 0.9152, 'best_val_psnr': 24.0482}
# {'epoch': 4939, 'epoch_time_sec': 19.67, 'lr': 7.5e-05, 'train_loss': 0.011593, 'train_psnr': 25.1547, 'val_psnr': 24.0484, 'input_psnr': 23.1331, 'delta_psnr': 0.9153, 'best_val_psnr': 24.0484}
# {'epoch': 4940, 'epoch_time_sec': 19.76, 'lr': 7.499915246218845e-05, 'train_loss': 0.011612, 'train_psnr': 25.1465, 'val_psnr': 24.0488, 'input_psnr': 23.1331, 'delta_psnr': 0.9157, 'best_val_psnr': 24.0488}
# {'epoch': 4941, 'epoch_time_sec': 19.81, 'lr': 7.499660988811385e-05, 'train_loss': 0.01159, 'train_psnr': 25.1553, 'val_psnr': 24.0486, 'input_psnr': 23.1331, 'delta_psnr': 0.9156, 'best_val_psnr': 24.0488}
# {'epoch': 4942, 'epoch_time_sec': 19.82, 'lr': 7.499237239585442e-05, 'train_loss': 0.011588, 'train_psnr': 25.1592, 'val_psnr': 24.0487, 'input_psnr': 23.1331, 'delta_psnr': 0.9156, 'best_val_psnr': 24.0488}
# {'epoch': 4943, 'epoch_time_sec': 19.75, 'lr': 7.49864401822011e-05, 'train_loss': 0.01161, 'train_psnr': 25.1497, 'val_psnr': 24.0487, 'input_psnr': 23.1331, 'delta_psnr': 0.9156, 'best_val_psnr': 24.0488}
# {'epoch': 4944, 'epoch_time_sec': 19.73, 'lr': 7.497881352264846e-05, 'train_loss': 0.011588, 'train_psnr': 25.1595, 'val_psnr': 24.0487, 'input_psnr': 23.1331, 'delta_psnr': 0.9156, 'best_val_psnr': 24.0488}
# {'epoch': 4945, 'epoch_time_sec': 19.72, 'lr': 7.496949277138178e-05, 'train_loss': 0.011581, 'train_psnr': 25.1623, 'val_psnr': 24.0488, 'input_psnr': 23.1331, 'delta_psnr': 0.9157, 'best_val_psnr': 24.0488}
# {'epoch': 4946, 'epoch_time_sec': 19.78, 'lr': 7.495847836126081e-05, 'train_loss': 0.011591, 'train_psnr': 25.1563, 'val_psnr': 24.0488, 'input_psnr': 23.1331, 'delta_psnr': 0.9157, 'best_val_psnr': 24.0488}
# {'epoch': 4947, 'epoch_time_sec': 19.74, 'lr': 7.494577080379942e-05, 'train_loss': 0.011594, 'train_psnr': 25.1544, 'val_psnr': 24.0488, 'input_psnr': 23.1331, 'delta_psnr': 0.9157, 'best_val_psnr': 24.0488}
# {'epoch': 4948, 'epoch_time_sec': 19.74, 'lr': 7.493137068914202e-05, 'train_loss': 0.011589, 'train_psnr': 25.157, 'val_psnr': 24.0488, 'input_psnr': 23.1331, 'delta_psnr': 0.9157, 'best_val_psnr': 24.0488}
# {'epoch': 4949, 'epoch_time_sec': 19.77, 'lr': 7.491527868603615e-05, 'train_loss': 0.011598, 'train_psnr': 25.1519, 'val_psnr': 24.0489, 'input_psnr': 23.1331, 'delta_psnr': 0.9158, 'best_val_psnr': 24.0489}
# {'epoch': 4950, 'epoch_time_sec': 19.76, 'lr': 7.489749554180125e-05, 'train_loss': 0.011589, 'train_psnr': 25.1577, 'val_psnr': 24.0489, 'input_psnr': 23.1331, 'delta_psnr': 0.9159, 'best_val_psnr': 24.0489}
# {'epoch': 4951, 'epoch_time_sec': 19.77, 'lr': 7.48780220822942e-05, 'train_loss': 0.011582, 'train_psnr': 25.1595, 'val_psnr': 24.049, 'input_psnr': 23.1331, 'delta_psnr': 0.9159, 'best_val_psnr': 24.049}
# {'epoch': 4952, 'epoch_time_sec': 19.76, 'lr': 7.485685921187076e-05, 'train_loss': 0.011582, 'train_psnr': 25.1611, 'val_psnr': 24.049, 'input_psnr': 23.1331, 'delta_psnr': 0.9159, 'best_val_psnr': 24.049}
# {'epoch': 4953, 'epoch_time_sec': 19.8, 'lr': 7.483400791334372e-05, 'train_loss': 0.011583, 'train_psnr': 25.1636, 'val_psnr': 24.049, 'input_psnr': 23.1331, 'delta_psnr': 0.916, 'best_val_psnr': 24.049}
# {'epoch': 4954, 'epoch_time_sec': 19.78, 'lr': 7.480946924793716e-05, 'train_loss': 0.011592, 'train_psnr': 25.1568, 'val_psnr': 24.0489, 'input_psnr': 23.1331, 'delta_psnr': 0.9158, 'best_val_psnr': 24.049}
# {'epoch': 4955, 'epoch_time_sec': 19.72, 'lr': 7.47832443552372e-05, 'train_loss': 0.011592, 'train_psnr': 25.1561, 'val_psnr': 24.0488, 'input_psnr': 23.1331, 'delta_psnr': 0.9158, 'best_val_psnr': 24.049}
# {'epoch': 4956, 'epoch_time_sec': 19.76, 'lr': 7.475533445313906e-05, 'train_loss': 0.011594, 'train_psnr': 25.1538, 'val_psnr': 24.0489, 'input_psnr': 23.1331, 'delta_psnr': 0.9158, 'best_val_psnr': 24.049}
# {'epoch': 4957, 'epoch_time_sec': 19.79, 'lr': 7.472574083779057e-05, 'train_loss': 0.011583, 'train_psnr': 25.1641, 'val_psnr': 24.0489, 'input_psnr': 23.1331, 'delta_psnr': 0.9158, 'best_val_psnr': 24.049}
# {'epoch': 4958, 'epoch_time_sec': 19.78, 'lr': 7.469446488353188e-05, 'train_loss': 0.011588, 'train_psnr': 25.1589, 'val_psnr': 24.049, 'input_psnr': 23.1331, 'delta_psnr': 0.9159, 'best_val_psnr': 24.049}
# {'epoch': 4959, 'epoch_time_sec': 19.8, 'lr': 7.46615080428317e-05, 'train_loss': 0.011584, 'train_psnr': 25.1592, 'val_psnr': 24.0489, 'input_psnr': 23.1331, 'delta_psnr': 0.9158, 'best_val_psnr': 24.049}
# {'epoch': 4960, 'epoch_time_sec': 19.73, 'lr': 7.462687184621981e-05, 'train_loss': 0.011603, 'train_psnr': 25.1539, 'val_psnr': 24.0487, 'input_psnr': 23.1331, 'delta_psnr': 0.9156, 'best_val_psnr': 24.049}
# {'epoch': 4961, 'epoch_time_sec': 19.75, 'lr': 7.459055790221603e-05, 'train_loss': 0.011588, 'train_psnr': 25.1574, 'val_psnr': 24.0486, 'input_psnr': 23.1331, 'delta_psnr': 0.9155, 'best_val_psnr': 24.049}
# {'epoch': 4962, 'epoch_time_sec': 19.79, 'lr': 7.455256789725543e-05, 'train_loss': 0.011576, 'train_psnr': 25.1651, 'val_psnr': 24.0485, 'input_psnr': 23.1331, 'delta_psnr': 0.9154, 'best_val_psnr': 24.049}
# {'epoch': 4963, 'epoch_time_sec': 19.77, 'lr': 7.451290359561011e-05, 'train_loss': 0.011583, 'train_psnr': 25.1629, 'val_psnr': 24.0486, 'input_psnr': 23.1331, 'delta_psnr': 0.9155, 'best_val_psnr': 24.049}
# {'epoch': 4964, 'epoch_time_sec': 19.78, 'lr': 7.447156683930723e-05, 'train_loss': 0.011577, 'train_psnr': 25.1676, 'val_psnr': 24.0486, 'input_psnr': 23.1331, 'delta_psnr': 0.9155, 'best_val_psnr': 24.049}
# {'epoch': 4965, 'epoch_time_sec': 19.77, 'lr': 7.442855954804342e-05, 'train_loss': 0.011597, 'train_psnr': 25.1553, 'val_psnr': 24.0486, 'input_psnr': 23.1331, 'delta_psnr': 0.9155, 'best_val_psnr': 24.049}
# {'epoch': 4966, 'epoch_time_sec': 19.75, 'lr': 7.438388371909574e-05, 'train_loss': 0.011609, 'train_psnr': 25.153, 'val_psnr': 24.0486, 'input_psnr': 23.1331, 'delta_psnr': 0.9156, 'best_val_psnr': 24.049}
# {'epoch': 4967, 'epoch_time_sec': 19.78, 'lr': 7.433754142722875e-05, 'train_loss': 0.011597, 'train_psnr': 25.1553, 'val_psnr': 24.0487, 'input_psnr': 23.1331, 'delta_psnr': 0.9157, 'best_val_psnr': 24.049}
# {'epoch': 4968, 'epoch_time_sec': 19.72, 'lr': 7.428953482459838e-05, 'train_loss': 0.01157, 'train_psnr': 25.1687, 'val_psnr': 24.0487, 'input_psnr': 23.1331, 'delta_psnr': 0.9156, 'best_val_psnr': 24.049}
# {'epoch': 4969, 'epoch_time_sec': 19.76, 'lr': 7.423986614065175e-05, 'train_loss': 0.011589, 'train_psnr': 25.1571, 'val_psnr': 24.0485, 'input_psnr': 23.1331, 'delta_psnr': 0.9155, 'best_val_psnr': 24.049}
# {'epoch': 4970, 'epoch_time_sec': 19.77, 'lr': 7.418853768202384e-05, 'train_loss': 0.011581, 'train_psnr': 25.1619, 'val_psnr': 24.0485, 'input_psnr': 23.1331, 'delta_psnr': 0.9154, 'best_val_psnr': 24.049}
# {'epoch': 4971, 'epoch_time_sec': 19.79, 'lr': 7.413555183243022e-05, 'train_loss': 0.011606, 'train_psnr': 25.1508, 'val_psnr': 24.0483, 'input_psnr': 23.1331, 'delta_psnr': 0.9153, 'best_val_psnr': 24.049}
# {'epoch': 4972, 'epoch_time_sec': 19.78, 'lr': 7.408091105255644e-05, 'train_loss': 0.011579, 'train_psnr': 25.1656, 'val_psnr': 24.0482, 'input_psnr': 23.1331, 'delta_psnr': 0.9152, 'best_val_psnr': 24.049}
# {'epoch': 4973, 'epoch_time_sec': 19.73, 'lr': 7.40246178799437e-05, 'train_loss': 0.011576, 'train_psnr': 25.1641, 'val_psnr': 24.0482, 'input_psnr': 23.1331, 'delta_psnr': 0.9151, 'best_val_psnr': 24.049}
# {'epoch': 4974, 'epoch_time_sec': 19.73, 'lr': 7.396667492887101e-05, 'train_loss': 0.01159, 'train_psnr': 25.1588, 'val_psnr': 24.0482, 'input_psnr': 23.1331, 'delta_psnr': 0.9151, 'best_val_psnr': 24.049}
# {'epoch': 4975, 'epoch_time_sec': 19.74, 'lr': 7.390708489023385e-05, 'train_loss': 0.011576, 'train_psnr': 25.1653, 'val_psnr': 24.0483, 'input_psnr': 23.1331, 'delta_psnr': 0.9152, 'best_val_psnr': 24.049}
# {'epoch': 4976, 'epoch_time_sec': 19.74, 'lr': 7.384585053141909e-05, 'train_loss': 0.011588, 'train_psnr': 25.1593, 'val_psnr': 24.0481, 'input_psnr': 23.1331, 'delta_psnr': 0.9151, 'best_val_psnr': 24.049}
# {'epoch': 4977, 'epoch_time_sec': 19.82, 'lr': 7.37829746961766e-05, 'train_loss': 0.01157, 'train_psnr': 25.1687, 'val_psnr': 24.0482, 'input_psnr': 23.1331, 'delta_psnr': 0.9152, 'best_val_psnr': 24.049}
# {'epoch': 4978, 'epoch_time_sec': 19.72, 'lr': 7.371846030448706e-05, 'train_loss': 0.011597, 'train_psnr': 25.1561, 'val_psnr': 24.0484, 'input_psnr': 23.1331, 'delta_psnr': 0.9153, 'best_val_psnr': 24.049}
# {'epoch': 4979, 'epoch_time_sec': 19.75, 'lr': 7.365231035242642e-05, 'train_loss': 0.011577, 'train_psnr': 25.1645, 'val_psnr': 24.0484, 'input_psnr': 23.1331, 'delta_psnr': 0.9154, 'best_val_psnr': 24.049}
# {'epoch': 4980, 'epoch_time_sec': 19.75, 'lr': 7.35845279120268e-05, 'train_loss': 0.011582, 'train_psnr': 25.1625, 'val_psnr': 24.0484, 'input_psnr': 23.1331, 'delta_psnr': 0.9153, 'best_val_psnr': 24.049}
# {'epoch': 4981, 'epoch_time_sec': 19.74, 'lr': 7.351511613113372e-05, 'train_loss': 0.011581, 'train_psnr': 25.1602, 'val_psnr': 24.0484, 'input_psnr': 23.1331, 'delta_psnr': 0.9154, 'best_val_psnr': 24.049}
# {'epoch': 4982, 'epoch_time_sec': 19.73, 'lr': 7.344407823326001e-05, 'train_loss': 0.011588, 'train_psnr': 25.1583, 'val_psnr': 24.0483, 'input_psnr': 23.1331, 'delta_psnr': 0.9153, 'best_val_psnr': 24.049}
# {'epoch': 4983, 'epoch_time_sec': 19.78, 'lr': 7.337141751743604e-05, 'train_loss': 0.011594, 'train_psnr': 25.1564, 'val_psnr': 24.0485, 'input_psnr': 23.1331, 'delta_psnr': 0.9154, 'best_val_psnr': 24.049}
# {'epoch': 4984, 'epoch_time_sec': 19.77, 'lr': 7.329713735805658e-05, 'train_loss': 0.011596, 'train_psnr': 25.1555, 'val_psnr': 24.0485, 'input_psnr': 23.1331, 'delta_psnr': 0.9154, 'best_val_psnr': 24.049}
# {'epoch': 4985, 'epoch_time_sec': 19.78, 'lr': 7.3221241204724e-05, 'train_loss': 0.011575, 'train_psnr': 25.1663, 'val_psnr': 24.0486, 'input_psnr': 23.1331, 'delta_psnr': 0.9155, 'best_val_psnr': 24.049}
# {'epoch': 4986, 'epoch_time_sec': 19.75, 'lr': 7.314373258208813e-05, 'train_loss': 0.011573, 'train_psnr': 25.1683, 'val_psnr': 24.0487, 'input_psnr': 23.1331, 'delta_psnr': 0.9157, 'best_val_psnr': 24.049}
# {'epoch': 4987, 'epoch_time_sec': 19.73, 'lr': 7.306461508968263e-05, 'train_loss': 0.011578, 'train_psnr': 25.1631, 'val_psnr': 24.0488, 'input_psnr': 23.1331, 'delta_psnr': 0.9157, 'best_val_psnr': 24.049}
# {'epoch': 4988, 'epoch_time_sec': 19.77, 'lr': 7.298389240175768e-05, 'train_loss': 0.011569, 'train_psnr': 25.1694, 'val_psnr': 24.0489, 'input_psnr': 23.1331, 'delta_psnr': 0.9158, 'best_val_psnr': 24.049}
# {'epoch': 4989, 'epoch_time_sec': 19.8, 'lr': 7.290156826710945e-05, 'train_loss': 0.011582, 'train_psnr': 25.1621, 'val_psnr': 24.049, 'input_psnr': 23.1331, 'delta_psnr': 0.9159, 'best_val_psnr': 24.049}
# {'epoch': 4990, 'epoch_time_sec': 19.74, 'lr': 7.281764650890601e-05, 'train_loss': 0.011598, 'train_psnr': 25.1572, 'val_psnr': 24.0489, 'input_psnr': 23.1331, 'delta_psnr': 0.9158, 'best_val_psnr': 24.049}
# {'epoch': 4991, 'epoch_time_sec': 19.79, 'lr': 7.273213102450974e-05, 'train_loss': 0.011573, 'train_psnr': 25.1686, 'val_psnr': 24.0489, 'input_psnr': 23.1331, 'delta_psnr': 0.9159, 'best_val_psnr': 24.049}
# {'epoch': 4992, 'epoch_time_sec': 19.71, 'lr': 7.264502578529634e-05, 'train_loss': 0.011578, 'train_psnr': 25.1637, 'val_psnr': 24.0491, 'input_psnr': 23.1331, 'delta_psnr': 0.9161, 'best_val_psnr': 24.0491}
# {'epoch': 4993, 'epoch_time_sec': 19.75, 'lr': 7.255633483647036e-05, 'train_loss': 0.011578, 'train_psnr': 25.1625, 'val_psnr': 24.049, 'input_psnr': 23.1331, 'delta_psnr': 0.916, 'best_val_psnr': 24.0491}
# {'epoch': 4994, 'epoch_time_sec': 19.79, 'lr': 7.246606229687746e-05, 'train_loss': 0.01157, 'train_psnr': 25.168, 'val_psnr': 24.0491, 'input_psnr': 23.1331, 'delta_psnr': 0.916, 'best_val_psnr': 24.0491}
# {'epoch': 4995, 'epoch_time_sec': 19.78, 'lr': 7.237421235881302e-05, 'train_loss': 0.011583, 'train_psnr': 25.1629, 'val_psnr': 24.049, 'input_psnr': 23.1331, 'delta_psnr': 0.916, 'best_val_psnr': 24.0491}
# {'epoch': 4996, 'epoch_time_sec': 19.74, 'lr': 7.228078928782747e-05, 'train_loss': 0.011581, 'train_psnr': 25.1621, 'val_psnr': 24.049, 'input_psnr': 23.1331, 'delta_psnr': 0.9159, 'best_val_psnr': 24.0491}
# {'epoch': 4997, 'epoch_time_sec': 19.78, 'lr': 7.218579742252822e-05, 'train_loss': 0.011575, 'train_psnr': 25.1658, 'val_psnr': 24.0491, 'input_psnr': 23.1331, 'delta_psnr': 0.9161, 'best_val_psnr': 24.0491}
# {'epoch': 4998, 'epoch_time_sec': 19.75, 'lr': 7.208924117437815e-05, 'train_loss': 0.011575, 'train_psnr': 25.1657, 'val_psnr': 24.0489, 'input_psnr': 23.1331, 'delta_psnr': 0.9159, 'best_val_psnr': 24.0491}
# {'epoch': 4999, 'epoch_time_sec': 19.71, 'lr': 7.199112502749074e-05, 'train_loss': 0.01157, 'train_psnr': 25.1681, 'val_psnr': 24.049, 'input_psnr': 23.1331, 'delta_psnr': 0.9159, 'best_val_psnr': 24.0491}
# {'epoch': 5000, 'epoch_time_sec': 19.77, 'lr': 7.189145353842187e-05, 'train_loss': 0.011571, 'train_psnr': 25.1677, 'val_psnr': 24.0489, 'input_psnr': 23.1331, 'delta_psnr': 0.9159, 'best_val_psnr': 24.0491}
# {'epoch': 5001, 'epoch_time_sec': 19.78, 'lr': 7.179023133595814e-05, 'train_loss': 0.011599, 'train_psnr': 25.1557, 'val_psnr': 24.049, 'input_psnr': 23.1331, 'delta_psnr': 0.9159, 'best_val_psnr': 24.0491}
# {'epoch': 5002, 'epoch_time_sec': 19.77, 'lr': 7.168746312090197e-05, 'train_loss': 0.011571, 'train_psnr': 25.1667, 'val_psnr': 24.0489, 'input_psnr': 23.1331, 'delta_psnr': 0.9158, 'best_val_psnr': 24.0491}
# {'epoch': 5003, 'epoch_time_sec': 19.72, 'lr': 7.158315366585324e-05, 'train_loss': 0.011589, 'train_psnr': 25.1595, 'val_psnr': 24.049, 'input_psnr': 23.1331, 'delta_psnr': 0.9159, 'best_val_psnr': 24.0491}
# {'epoch': 5004, 'epoch_time_sec': 19.75, 'lr': 7.14773078149877e-05, 'train_loss': 0.011576, 'train_psnr': 25.167, 'val_psnr': 24.049, 'input_psnr': 23.1331, 'delta_psnr': 0.916, 'best_val_psnr': 24.0491}
# {'epoch': 5005, 'epoch_time_sec': 19.75, 'lr': 7.136993048383198e-05, 'train_loss': 0.011568, 'train_psnr': 25.1705, 'val_psnr': 24.0489, 'input_psnr': 23.1331, 'delta_psnr': 0.9158, 'best_val_psnr': 24.0491}
# {'epoch': 5006, 'epoch_time_sec': 19.74, 'lr': 7.126102665903528e-05, 'train_loss': 0.011574, 'train_psnr': 25.1659, 'val_psnr': 24.0489, 'input_psnr': 23.1331, 'delta_psnr': 0.9158, 'best_val_psnr': 24.0491}
# {'epoch': 5007, 'epoch_time_sec': 19.74, 'lr': 7.115060139813784e-05, 'train_loss': 0.011575, 'train_psnr': 25.1652, 'val_psnr': 24.0491, 'input_psnr': 23.1331, 'delta_psnr': 0.916, 'best_val_psnr': 24.0491}
# {'epoch': 5008, 'epoch_time_sec': 19.79, 'lr': 7.103865982933605e-05, 'train_loss': 0.011587, 'train_psnr': 25.1624, 'val_psnr': 24.0491, 'input_psnr': 23.1331, 'delta_psnr': 0.9161, 'best_val_psnr': 24.0491}
# {'epoch': 5009, 'epoch_time_sec': 19.75, 'lr': 7.092520715124428e-05, 'train_loss': 0.011581, 'train_psnr': 25.1667, 'val_psnr': 24.0491, 'input_psnr': 23.1331, 'delta_psnr': 0.916, 'best_val_psnr': 24.0491}
# {'epoch': 5010, 'epoch_time_sec': 19.77, 'lr': 7.081024863265344e-05, 'train_loss': 0.011579, 'train_psnr': 25.1628, 'val_psnr': 24.0489, 'input_psnr': 23.1331, 'delta_psnr': 0.9158, 'best_val_psnr': 24.0491}
# {'epoch': 5011, 'epoch_time_sec': 19.76, 'lr': 7.069378961228639e-05, 'train_loss': 0.01157, 'train_psnr': 25.1691, 'val_psnr': 24.049, 'input_psnr': 23.1331, 'delta_psnr': 0.9159, 'best_val_psnr': 24.0491}
# {'epoch': 5012, 'epoch_time_sec': 19.74, 'lr': 7.057583549854982e-05, 'train_loss': 0.011579, 'train_psnr': 25.1656, 'val_psnr': 24.049, 'input_psnr': 23.1331, 'delta_psnr': 0.9159, 'best_val_psnr': 24.0491}
# {'epoch': 5013, 'epoch_time_sec': 19.74, 'lr': 7.04563917692833e-05, 'train_loss': 0.011576, 'train_psnr': 25.1672, 'val_psnr': 24.0489, 'input_psnr': 23.1331, 'delta_psnr': 0.9158, 'best_val_psnr': 24.0491}
# {'epoch': 5014, 'epoch_time_sec': 19.76, 'lr': 7.033546397150474e-05, 'train_loss': 0.011569, 'train_psnr': 25.1686, 'val_psnr': 24.0491, 'input_psnr': 23.1331, 'delta_psnr': 0.916, 'best_val_psnr': 24.0491}
# {'epoch': 5015, 'epoch_time_sec': 19.76, 'lr': 7.021305772115281e-05, 'train_loss': 0.011579, 'train_psnr': 25.1656, 'val_psnr': 24.0491, 'input_psnr': 23.1331, 'delta_psnr': 0.916, 'best_val_psnr': 24.0491}
# {'epoch': 5016, 'epoch_time_sec': 19.79, 'lr': 7.008917870282619e-05, 'train_loss': 0.011572, 'train_psnr': 25.1679, 'val_psnr': 24.0491, 'input_psnr': 23.1331, 'delta_psnr': 0.9161, 'best_val_psnr': 24.0491}
# {'epoch': 5017, 'epoch_time_sec': 19.73, 'lr': 6.996383266951951e-05, 'train_loss': 0.011584, 'train_psnr': 25.162, 'val_psnr': 24.0493, 'input_psnr': 23.1331, 'delta_psnr': 0.9162, 'best_val_psnr': 24.0493}
# {'epoch': 5018, 'epoch_time_sec': 19.78, 'lr': 6.983702544235619e-05, 'train_loss': 0.011577, 'train_psnr': 25.1657, 'val_psnr': 24.0493, 'input_psnr': 23.1331, 'delta_psnr': 0.9162, 'best_val_psnr': 24.0493}
# {'epoch': 5019, 'epoch_time_sec': 19.79, 'lr': 6.970876291031816e-05, 'train_loss': 0.011585, 'train_psnr': 25.1608, 'val_psnr': 24.0491, 'input_psnr': 23.1331, 'delta_psnr': 0.9161, 'best_val_psnr': 24.0493}
# {'epoch': 5020, 'epoch_time_sec': 19.79, 'lr': 6.957905102997231e-05, 'train_loss': 0.011568, 'train_psnr': 25.1694, 'val_psnr': 24.0492, 'input_psnr': 23.1331, 'delta_psnr': 0.9162, 'best_val_psnr': 24.0493}
# {'epoch': 5021, 'epoch_time_sec': 19.78, 'lr': 6.944789582519388e-05, 'train_loss': 0.011566, 'train_psnr': 25.1718, 'val_psnr': 24.0492, 'input_psnr': 23.1331, 'delta_psnr': 0.9162, 'best_val_psnr': 24.0493}
# {'epoch': 5022, 'epoch_time_sec': 19.76, 'lr': 6.931530338688668e-05, 'train_loss': 0.011581, 'train_psnr': 25.1622, 'val_psnr': 24.0492, 'input_psnr': 23.1331, 'delta_psnr': 0.9161, 'best_val_psnr': 24.0493}
# {'epoch': 5023, 'epoch_time_sec': 19.78, 'lr': 6.918127987270036e-05, 'train_loss': 0.011565, 'train_psnr': 25.1709, 'val_psnr': 24.0493, 'input_psnr': 23.1331, 'delta_psnr': 0.9162, 'best_val_psnr': 24.0493}
# {'epoch': 5024, 'epoch_time_sec': 19.79, 'lr': 6.904583150674425e-05, 'train_loss': 0.011588, 'train_psnr': 25.1615, 'val_psnr': 24.0494, 'input_psnr': 23.1331, 'delta_psnr': 0.9163, 'best_val_psnr': 24.0494}
# {'epoch': 5025, 'epoch_time_sec': 19.72, 'lr': 6.890896457929845e-05, 'train_loss': 0.011567, 'train_psnr': 25.1706, 'val_psnr': 24.0495, 'input_psnr': 23.1331, 'delta_psnr': 0.9164, 'best_val_psnr': 24.0495}
# {'epoch': 5026, 'epoch_time_sec': 19.76, 'lr': 6.877068544652164e-05, 'train_loss': 0.011583, 'train_psnr': 25.1635, 'val_psnr': 24.0495, 'input_psnr': 23.1331, 'delta_psnr': 0.9164, 'best_val_psnr': 24.0495}
# {'epoch': 5027, 'epoch_time_sec': 19.78, 'lr': 6.863100053015594e-05, 'train_loss': 0.011571, 'train_psnr': 25.1677, 'val_psnr': 24.0496, 'input_psnr': 23.1331, 'delta_psnr': 0.9166, 'best_val_psnr': 24.0496}
# {'epoch': 5028, 'epoch_time_sec': 19.8, 'lr': 6.848991631722867e-05, 'train_loss': 0.011576, 'train_psnr': 25.166, 'val_psnr': 24.0495, 'input_psnr': 23.1331, 'delta_psnr': 0.9164, 'best_val_psnr': 24.0496}
# {'epoch': 5029, 'epoch_time_sec': 19.74, 'lr': 6.834743935975106e-05, 'train_loss': 0.011566, 'train_psnr': 25.1713, 'val_psnr': 24.0495, 'input_psnr': 23.1331, 'delta_psnr': 0.9164, 'best_val_psnr': 24.0496}
# {'epoch': 5030, 'epoch_time_sec': 19.74, 'lr': 6.820357627441398e-05, 'train_loss': 0.011566, 'train_psnr': 25.1713, 'val_psnr': 24.0495, 'input_psnr': 23.1331, 'delta_psnr': 0.9165, 'best_val_psnr': 24.0496}
# {'epoch': 5031, 'epoch_time_sec': 19.76, 'lr': 6.805833374228072e-05, 'train_loss': 0.011578, 'train_psnr': 25.1635, 'val_psnr': 24.0495, 'input_psnr': 23.1331, 'delta_psnr': 0.9164, 'best_val_psnr': 24.0496}
# {'epoch': 5032, 'epoch_time_sec': 19.79, 'lr': 6.791171850847661e-05, 'train_loss': 0.011572, 'train_psnr': 25.1669, 'val_psnr': 24.0495, 'input_psnr': 23.1331, 'delta_psnr': 0.9164, 'best_val_psnr': 24.0496}
# {'epoch': 5033, 'epoch_time_sec': 19.76, 'lr': 6.776373738187589e-05, 'train_loss': 0.01158, 'train_psnr': 25.1652, 'val_psnr': 24.0493, 'input_psnr': 23.1331, 'delta_psnr': 0.9162, 'best_val_psnr': 24.0496}
# {'epoch': 5034, 'epoch_time_sec': 19.74, 'lr': 6.761439723478541e-05, 'train_loss': 0.011592, 'train_psnr': 25.1596, 'val_psnr': 24.0494, 'input_psnr': 23.1331, 'delta_psnr': 0.9164, 'best_val_psnr': 24.0496}
# {'epoch': 5035, 'epoch_time_sec': 19.78, 'lr': 6.746370500262552e-05, 'train_loss': 0.011582, 'train_psnr': 25.1656, 'val_psnr': 24.0494, 'input_psnr': 23.1331, 'delta_psnr': 0.9163, 'best_val_psnr': 24.0496}
# {'epoch': 5036, 'epoch_time_sec': 19.76, 'lr': 6.7311667683608e-05, 'train_loss': 0.011569, 'train_psnr': 25.1712, 'val_psnr': 24.0496, 'input_psnr': 23.1331, 'delta_psnr': 0.9165, 'best_val_psnr': 24.0496}
# {'epoch': 5037, 'epoch_time_sec': 19.76, 'lr': 6.715829233841099e-05, 'train_loss': 0.011564, 'train_psnr': 25.1728, 'val_psnr': 24.0496, 'input_psnr': 23.1331, 'delta_psnr': 0.9165, 'best_val_psnr': 24.0496}
# {'epoch': 5038, 'epoch_time_sec': 19.78, 'lr': 6.700358608985121e-05, 'train_loss': 0.011569, 'train_psnr': 25.1708, 'val_psnr': 24.0496, 'input_psnr': 23.1331, 'delta_psnr': 0.9165, 'best_val_psnr': 24.0496}
# {'epoch': 5039, 'epoch_time_sec': 19.76, 'lr': 6.6847556122553e-05, 'train_loss': 0.011567, 'train_psnr': 25.1706, 'val_psnr': 24.0497, 'input_psnr': 23.1331, 'delta_psnr': 0.9167, 'best_val_psnr': 24.0497}
# {'epoch': 5040, 'epoch_time_sec': 19.82, 'lr': 6.669020968261489e-05, 'train_loss': 0.011568, 'train_psnr': 25.1697, 'val_psnr': 24.0497, 'input_psnr': 23.1331, 'delta_psnr': 0.9167, 'best_val_psnr': 24.0497}
# {'epoch': 5041, 'epoch_time_sec': 19.78, 'lr': 6.653155407727288e-05, 'train_loss': 0.011568, 'train_psnr': 25.1695, 'val_psnr': 24.0499, 'input_psnr': 23.1331, 'delta_psnr': 0.9168, 'best_val_psnr': 24.0499}
# {'epoch': 5042, 'epoch_time_sec': 19.73, 'lr': 6.637159667456116e-05, 'train_loss': 0.011572, 'train_psnr': 25.1705, 'val_psnr': 24.05, 'input_psnr': 23.1331, 'delta_psnr': 0.917, 'best_val_psnr': 24.05}
# {'epoch': 5043, 'epoch_time_sec': 19.76, 'lr': 6.621034490297003e-05, 'train_loss': 0.011579, 'train_psnr': 25.1648, 'val_psnr': 24.0499, 'input_psnr': 23.1331, 'delta_psnr': 0.9168, 'best_val_psnr': 24.05}
# {'epoch': 5044, 'epoch_time_sec': 19.78, 'lr': 6.604780625110075e-05, 'train_loss': 0.011569, 'train_psnr': 25.1681, 'val_psnr': 24.0499, 'input_psnr': 23.1331, 'delta_psnr': 0.9169, 'best_val_psnr': 24.05}
# {'epoch': 5045, 'epoch_time_sec': 19.75, 'lr': 6.58839882673179e-05, 'train_loss': 0.011563, 'train_psnr': 25.1741, 'val_psnr': 24.0499, 'input_psnr': 23.1331, 'delta_psnr': 0.9169, 'best_val_psnr': 24.05}
# {'epoch': 5046, 'epoch_time_sec': 19.73, 'lr': 6.571889855939875e-05, 'train_loss': 0.011578, 'train_psnr': 25.167, 'val_psnr': 24.0499, 'input_psnr': 23.1331, 'delta_psnr': 0.9169, 'best_val_psnr': 24.05}
# {'epoch': 5047, 'epoch_time_sec': 19.72, 'lr': 6.555254479418e-05, 'train_loss': 0.011569, 'train_psnr': 25.1691, 'val_psnr': 24.0498, 'input_psnr': 23.1331, 'delta_psnr': 0.9167, 'best_val_psnr': 24.05}
# {'epoch': 5048, 'epoch_time_sec': 19.81, 'lr': 6.538493469720173e-05, 'train_loss': 0.011565, 'train_psnr': 25.1714, 'val_psnr': 24.0498, 'input_psnr': 23.1331, 'delta_psnr': 0.9167, 'best_val_psnr': 24.05}
# {'epoch': 5049, 'epoch_time_sec': 19.73, 'lr': 6.521607605234856e-05, 'train_loss': 0.01157, 'train_psnr': 25.1695, 'val_psnr': 24.0498, 'input_psnr': 23.1331, 'delta_psnr': 0.9167, 'best_val_psnr': 24.05}
# {'epoch': 5050, 'epoch_time_sec': 19.74, 'lr': 6.504597670148827e-05, 'train_loss': 0.011569, 'train_psnr': 25.1681, 'val_psnr': 24.0499, 'input_psnr': 23.1331, 'delta_psnr': 0.9168, 'best_val_psnr': 24.05}
# {'epoch': 5051, 'epoch_time_sec': 19.75, 'lr': 6.487464454410747e-05, 'train_loss': 0.011564, 'train_psnr': 25.1724, 'val_psnr': 24.0498, 'input_psnr': 23.1331, 'delta_psnr': 0.9168, 'best_val_psnr': 24.05}
# {'epoch': 5052, 'epoch_time_sec': 19.81, 'lr': 6.470208753694494e-05, 'train_loss': 0.011575, 'train_psnr': 25.1673, 'val_psnr': 24.0498, 'input_psnr': 23.1331, 'delta_psnr': 0.9168, 'best_val_psnr': 24.05}
# {'epoch': 5053, 'epoch_time_sec': 19.8, 'lr': 6.452831369362192e-05, 'train_loss': 0.011586, 'train_psnr': 25.1629, 'val_psnr': 24.0499, 'input_psnr': 23.1331, 'delta_psnr': 0.9168, 'best_val_psnr': 24.05}
# {'epoch': 5054, 'epoch_time_sec': 19.74, 'lr': 6.435333108427007e-05, 'train_loss': 0.011578, 'train_psnr': 25.1649, 'val_psnr': 24.05, 'input_psnr': 23.1331, 'delta_psnr': 0.9169, 'best_val_psnr': 24.05}
# {'epoch': 5055, 'epoch_time_sec': 19.74, 'lr': 6.417714783515667e-05, 'train_loss': 0.011564, 'train_psnr': 25.1723, 'val_psnr': 24.05, 'input_psnr': 23.1331, 'delta_psnr': 0.9169, 'best_val_psnr': 24.05}
# {'epoch': 5056, 'epoch_time_sec': 19.76, 'lr': 6.399977212830724e-05, 'train_loss': 0.011557, 'train_psnr': 25.1765, 'val_psnr': 24.0501, 'input_psnr': 23.1331, 'delta_psnr': 0.917, 'best_val_psnr': 24.0501}
# {'epoch': 5057, 'epoch_time_sec': 19.77, 'lr': 6.382121220112551e-05, 'train_loss': 0.01158, 'train_psnr': 25.165, 'val_psnr': 24.0501, 'input_psnr': 23.1331, 'delta_psnr': 0.9171, 'best_val_psnr': 24.0501}
# {'epoch': 5058, 'epoch_time_sec': 19.76, 'lr': 6.364147634601093e-05, 'train_loss': 0.011563, 'train_psnr': 25.1731, 'val_psnr': 24.0501, 'input_psnr': 23.1331, 'delta_psnr': 0.9171, 'best_val_psnr': 24.0501}
# {'epoch': 5059, 'epoch_time_sec': 19.75, 'lr': 6.346057290997355e-05, 'train_loss': 0.011568, 'train_psnr': 25.1706, 'val_psnr': 24.05, 'input_psnr': 23.1331, 'delta_psnr': 0.917, 'best_val_psnr': 24.0501}
# {'epoch': 5060, 'epoch_time_sec': 19.74, 'lr': 6.327851029424637e-05, 'train_loss': 0.011564, 'train_psnr': 25.1717, 'val_psnr': 24.0501, 'input_psnr': 23.1331, 'delta_psnr': 0.917, 'best_val_psnr': 24.0501}
# {'epoch': 5061, 'epoch_time_sec': 19.77, 'lr': 6.309529695389517e-05, 'train_loss': 0.011576, 'train_psnr': 25.1656, 'val_psnr': 24.0501, 'input_psnr': 23.1331, 'delta_psnr': 0.9171, 'best_val_psnr': 24.0501}
# {'epoch': 5062, 'epoch_time_sec': 19.78, 'lr': 6.291094139742593e-05, 'train_loss': 0.011572, 'train_psnr': 25.1683, 'val_psnr': 24.0501, 'input_psnr': 23.1331, 'delta_psnr': 0.9171, 'best_val_psnr': 24.0501}
# {'epoch': 5063, 'epoch_time_sec': 19.79, 'lr': 6.272545218638959e-05, 'train_loss': 0.011566, 'train_psnr': 25.1732, 'val_psnr': 24.0503, 'input_psnr': 23.1331, 'delta_psnr': 0.9172, 'best_val_psnr': 24.0503}
# {'epoch': 5064, 'epoch_time_sec': 19.75, 'lr': 6.253883793498449e-05, 'train_loss': 0.011568, 'train_psnr': 25.1695, 'val_psnr': 24.0503, 'input_psnr': 23.1331, 'delta_psnr': 0.9172, 'best_val_psnr': 24.0503}
# {'epoch': 5065, 'epoch_time_sec': 19.76, 'lr': 6.235110730965637e-05, 'train_loss': 0.01157, 'train_psnr': 25.1706, 'val_psnr': 24.0504, 'input_psnr': 23.1331, 'delta_psnr': 0.9173, 'best_val_psnr': 24.0504}
# {'epoch': 5066, 'epoch_time_sec': 19.74, 'lr': 6.21622690286958e-05, 'train_loss': 0.011557, 'train_psnr': 25.1754, 'val_psnr': 24.0503, 'input_psnr': 23.1331, 'delta_psnr': 0.9173, 'best_val_psnr': 24.0504}
# {'epoch': 5067, 'epoch_time_sec': 19.8, 'lr': 6.197233186183339e-05, 'train_loss': 0.011561, 'train_psnr': 25.1744, 'val_psnr': 24.0504, 'input_psnr': 23.1331, 'delta_psnr': 0.9173, 'best_val_psnr': 24.0504}
# {'epoch': 5068, 'epoch_time_sec': 19.77, 'lr': 6.178130462983246e-05, 'train_loss': 0.011571, 'train_psnr': 25.1715, 'val_psnr': 24.0504, 'input_psnr': 23.1331, 'delta_psnr': 0.9173, 'best_val_psnr': 24.0504}
# {'epoch': 5069, 'epoch_time_sec': 19.74, 'lr': 6.158919620407944e-05, 'train_loss': 0.011557, 'train_psnr': 25.1753, 'val_psnr': 24.0504, 'input_psnr': 23.1331, 'delta_psnr': 0.9174, 'best_val_psnr': 24.0504}
# {'epoch': 5070, 'epoch_time_sec': 19.73, 'lr': 6.139601550617183e-05, 'train_loss': 0.011564, 'train_psnr': 25.1724, 'val_psnr': 24.0505, 'input_psnr': 23.1331, 'delta_psnr': 0.9174, 'best_val_psnr': 24.0505}
# {'epoch': 5071, 'epoch_time_sec': 19.77, 'lr': 6.120177150750395e-05, 'train_loss': 0.011561, 'train_psnr': 25.1756, 'val_psnr': 24.0506, 'input_psnr': 23.1331, 'delta_psnr': 0.9175, 'best_val_psnr': 24.0506}
# {'epoch': 5072, 'epoch_time_sec': 19.76, 'lr': 6.1006473228850236e-05, 'train_loss': 0.011574, 'train_psnr': 25.1689, 'val_psnr': 24.0506, 'input_psnr': 23.1331, 'delta_psnr': 0.9175, 'best_val_psnr': 24.0506}
# {'epoch': 5073, 'epoch_time_sec': 19.79, 'lr': 6.0810129739946334e-05, 'train_loss': 0.011569, 'train_psnr': 25.1702, 'val_psnr': 24.0505, 'input_psnr': 23.1331, 'delta_psnr': 0.9174, 'best_val_psnr': 24.0506}
# {'epoch': 5074, 'epoch_time_sec': 19.77, 'lr': 6.06127501590679e-05, 'train_loss': 0.011567, 'train_psnr': 25.1714, 'val_psnr': 24.0505, 'input_psnr': 23.1331, 'delta_psnr': 0.9174, 'best_val_psnr': 24.0506}
# {'epoch': 5075, 'epoch_time_sec': 19.77, 'lr': 6.0414343652607186e-05, 'train_loss': 0.011571, 'train_psnr': 25.1715, 'val_psnr': 24.0506, 'input_psnr': 23.1331, 'delta_psnr': 0.9175, 'best_val_psnr': 24.0506}
# {'epoch': 5076, 'epoch_time_sec': 19.76, 'lr': 6.021491943464725e-05, 'train_loss': 0.011566, 'train_psnr': 25.1721, 'val_psnr': 24.0507, 'input_psnr': 23.1331, 'delta_psnr': 0.9176, 'best_val_psnr': 24.0507}
# {'epoch': 5077, 'epoch_time_sec': 19.77, 'lr': 6.001448676653414e-05, 'train_loss': 0.011559, 'train_psnr': 25.1755, 'val_psnr': 24.0508, 'input_psnr': 23.1331, 'delta_psnr': 0.9177, 'best_val_psnr': 24.0508}
# {'epoch': 5078, 'epoch_time_sec': 19.8, 'lr': 5.981305495644676e-05, 'train_loss': 0.011567, 'train_psnr': 25.1715, 'val_psnr': 24.0507, 'input_psnr': 23.1331, 'delta_psnr': 0.9176, 'best_val_psnr': 24.0508}
# {'epoch': 5079, 'epoch_time_sec': 19.79, 'lr': 5.961063335896458e-05, 'train_loss': 0.011559, 'train_psnr': 25.1748, 'val_psnr': 24.0507, 'input_psnr': 23.1331, 'delta_psnr': 0.9177, 'best_val_psnr': 24.0508}
# {'epoch': 5080, 'epoch_time_sec': 19.77, 'lr': 5.940723137463322e-05, 'train_loss': 0.011567, 'train_psnr': 25.1697, 'val_psnr': 24.0508, 'input_psnr': 23.1331, 'delta_psnr': 0.9177, 'best_val_psnr': 24.0508}
# {'epoch': 5081, 'epoch_time_sec': 19.75, 'lr': 5.920285844952793e-05, 'train_loss': 0.011566, 'train_psnr': 25.1726, 'val_psnr': 24.0509, 'input_psnr': 23.1331, 'delta_psnr': 0.9178, 'best_val_psnr': 24.0509}
# {'epoch': 5082, 'epoch_time_sec': 19.78, 'lr': 5.899752407481479e-05, 'train_loss': 0.01156, 'train_psnr': 25.1761, 'val_psnr': 24.0509, 'input_psnr': 23.1331, 'delta_psnr': 0.9178, 'best_val_psnr': 24.0509}
# {'epoch': 5083, 'epoch_time_sec': 19.78, 'lr': 5.879123778631007e-05, 'train_loss': 0.011568, 'train_psnr': 25.1703, 'val_psnr': 24.0509, 'input_psnr': 23.1331, 'delta_psnr': 0.9178, 'best_val_psnr': 24.0509}
# {'epoch': 5084, 'epoch_time_sec': 19.75, 'lr': 5.858400916403732e-05, 'train_loss': 0.011555, 'train_psnr': 25.1774, 'val_psnr': 24.0507, 'input_psnr': 23.1331, 'delta_psnr': 0.9177, 'best_val_psnr': 24.0509}
# {'epoch': 5085, 'epoch_time_sec': 19.76, 'lr': 5.837584783178243e-05, 'train_loss': 0.011566, 'train_psnr': 25.1711, 'val_psnr': 24.0507, 'input_psnr': 23.1331, 'delta_psnr': 0.9177, 'best_val_psnr': 24.0509}
# {'epoch': 5086, 'epoch_time_sec': 19.78, 'lr': 5.8166763456646784e-05, 'train_loss': 0.011558, 'train_psnr': 25.1761, 'val_psnr': 24.0509, 'input_psnr': 23.1331, 'delta_psnr': 0.9178, 'best_val_psnr': 24.0509}
# {'epoch': 5087, 'epoch_time_sec': 19.77, 'lr': 5.795676574859825e-05, 'train_loss': 0.011575, 'train_psnr': 25.1694, 'val_psnr': 24.0509, 'input_psnr': 23.1331, 'delta_psnr': 0.9179, 'best_val_psnr': 24.0509}
# {'epoch': 5088, 'epoch_time_sec': 19.77, 'lr': 5.774586446002029e-05, 'train_loss': 0.011556, 'train_psnr': 25.1787, 'val_psnr': 24.0509, 'input_psnr': 23.1331, 'delta_psnr': 0.9179, 'best_val_psnr': 24.0509}
# {'epoch': 5089, 'epoch_time_sec': 19.75, 'lr': 5.753406938525899e-05, 'train_loss': 0.011567, 'train_psnr': 25.1733, 'val_psnr': 24.0509, 'input_psnr': 23.1331, 'delta_psnr': 0.9179, 'best_val_psnr': 24.0509}
# {'epoch': 5090, 'epoch_time_sec': 19.76, 'lr': 5.73213903601683e-05, 'train_loss': 0.011565, 'train_psnr': 25.1726, 'val_psnr': 24.0508, 'input_psnr': 23.1331, 'delta_psnr': 0.9178, 'best_val_psnr': 24.0509}
# {'epoch': 5091, 'epoch_time_sec': 19.75, 'lr': 5.710783726165317e-05, 'train_loss': 0.011554, 'train_psnr': 25.1769, 'val_psnr': 24.051, 'input_psnr': 23.1331, 'delta_psnr': 0.9179, 'best_val_psnr': 24.051}
# {'epoch': 5092, 'epoch_time_sec': 19.76, 'lr': 5.6893420007210915e-05, 'train_loss': 0.01158, 'train_psnr': 25.1662, 'val_psnr': 24.0509, 'input_psnr': 23.1331, 'delta_psnr': 0.9179, 'best_val_psnr': 24.051}
# {'epoch': 5093, 'epoch_time_sec': 19.77, 'lr': 5.6678148554470586e-05, 'train_loss': 0.011556, 'train_psnr': 25.1782, 'val_psnr': 24.0511, 'input_psnr': 23.1331, 'delta_psnr': 0.918, 'best_val_psnr': 24.0511}
# {'epoch': 5094, 'epoch_time_sec': 19.73, 'lr': 5.6462032900730604e-05, 'train_loss': 0.011563, 'train_psnr': 25.1748, 'val_psnr': 24.051, 'input_psnr': 23.1331, 'delta_psnr': 0.918, 'best_val_psnr': 24.0511}
# {'epoch': 5095, 'epoch_time_sec': 19.77, 'lr': 5.624508308249443e-05, 'train_loss': 0.011554, 'train_psnr': 25.1777, 'val_psnr': 24.051, 'input_psnr': 23.1331, 'delta_psnr': 0.918, 'best_val_psnr': 24.0511}
# {'epoch': 5096, 'epoch_time_sec': 19.77, 'lr': 5.6027309175004484e-05, 'train_loss': 0.011556, 'train_psnr': 25.177, 'val_psnr': 24.0511, 'input_psnr': 23.1331, 'delta_psnr': 0.918, 'best_val_psnr': 24.0511}
# {'epoch': 5097, 'epoch_time_sec': 19.72, 'lr': 5.5808721291774245e-05, 'train_loss': 0.011581, 'train_psnr': 25.1656, 'val_psnr': 24.0511, 'input_psnr': 23.1331, 'delta_psnr': 0.9181, 'best_val_psnr': 24.0511}
# {'epoch': 5098, 'epoch_time_sec': 19.75, 'lr': 5.5589329584118575e-05, 'train_loss': 0.011554, 'train_psnr': 25.1796, 'val_psnr': 24.0512, 'input_psnr': 23.1331, 'delta_psnr': 0.9181, 'best_val_psnr': 24.0512}
# {'epoch': 5099, 'epoch_time_sec': 19.76, 'lr': 5.536914424068227e-05, 'train_loss': 0.011554, 'train_psnr': 25.1775, 'val_psnr': 24.0511, 'input_psnr': 23.1331, 'delta_psnr': 0.9181, 'best_val_psnr': 24.0512}
# {'epoch': 5100, 'epoch_time_sec': 19.78, 'lr': 5.514817548696694e-05, 'train_loss': 0.011559, 'train_psnr': 25.1769, 'val_psnr': 24.0512, 'input_psnr': 23.1331, 'delta_psnr': 0.9181, 'best_val_psnr': 24.0512}
# {'epoch': 5101, 'epoch_time_sec': 19.78, 'lr': 5.492643358485608e-05, 'train_loss': 0.011563, 'train_psnr': 25.1748, 'val_psnr': 24.0512, 'input_psnr': 23.1331, 'delta_psnr': 0.9182, 'best_val_psnr': 24.0512}
# {'epoch': 5102, 'epoch_time_sec': 19.79, 'lr': 5.470392883213855e-05, 'train_loss': 0.011566, 'train_psnr': 25.1725, 'val_psnr': 24.0512, 'input_psnr': 23.1331, 'delta_psnr': 0.9181, 'best_val_psnr': 24.0512}
# {'epoch': 5103, 'epoch_time_sec': 19.76, 'lr': 5.448067156203028e-05, 'train_loss': 0.011559, 'train_psnr': 25.1759, 'val_psnr': 24.0513, 'input_psnr': 23.1331, 'delta_psnr': 0.9182, 'best_val_psnr': 24.0513}
# {'epoch': 5104, 'epoch_time_sec': 19.75, 'lr': 5.425667214269447e-05, 'train_loss': 0.011554, 'train_psnr': 25.1779, 'val_psnr': 24.0512, 'input_psnr': 23.1331, 'delta_psnr': 0.9181, 'best_val_psnr': 24.0513}
# {'epoch': 5105, 'epoch_time_sec': 19.73, 'lr': 5.403194097676005e-05, 'train_loss': 0.011559, 'train_psnr': 25.1776, 'val_psnr': 24.0512, 'input_psnr': 23.1331, 'delta_psnr': 0.9181, 'best_val_psnr': 24.0513}
# {'epoch': 5106, 'epoch_time_sec': 19.79, 'lr': 5.380648850083852e-05, 'train_loss': 0.011571, 'train_psnr': 25.173, 'val_psnr': 24.0512, 'input_psnr': 23.1331, 'delta_psnr': 0.9181, 'best_val_psnr': 24.0513}
# {'epoch': 5107, 'epoch_time_sec': 19.77, 'lr': 5.358032518503938e-05, 'train_loss': 0.011551, 'train_psnr': 25.1795, 'val_psnr': 24.0513, 'input_psnr': 23.1331, 'delta_psnr': 0.9182, 'best_val_psnr': 24.0513}
# {'epoch': 5108, 'epoch_time_sec': 19.74, 'lr': 5.335346153248382e-05, 'train_loss': 0.011556, 'train_psnr': 25.1747, 'val_psnr': 24.0513, 'input_psnr': 23.1331, 'delta_psnr': 0.9182, 'best_val_psnr': 24.0513}
# {'epoch': 5109, 'epoch_time_sec': 19.72, 'lr': 5.3125908078816986e-05, 'train_loss': 0.011555, 'train_psnr': 25.1783, 'val_psnr': 24.0514, 'input_psnr': 23.1331, 'delta_psnr': 0.9183, 'best_val_psnr': 24.0514}
# {'epoch': 5110, 'epoch_time_sec': 19.73, 'lr': 5.289767539171864e-05, 'train_loss': 0.011555, 'train_psnr': 25.1772, 'val_psnr': 24.0513, 'input_psnr': 23.1331, 'delta_psnr': 0.9183, 'best_val_psnr': 24.0514}
# {'epoch': 5111, 'epoch_time_sec': 19.76, 'lr': 5.2668774070412475e-05, 'train_loss': 0.01157, 'train_psnr': 25.1724, 'val_psnr': 24.0514, 'input_psnr': 23.1331, 'delta_psnr': 0.9184, 'best_val_psnr': 24.0514}
# {'epoch': 5112, 'epoch_time_sec': 19.77, 'lr': 5.2439214745173816e-05, 'train_loss': 0.011559, 'train_psnr': 25.1759, 'val_psnr': 24.0514, 'input_psnr': 23.1331, 'delta_psnr': 0.9184, 'best_val_psnr': 24.0514}
# {'epoch': 5113, 'epoch_time_sec': 19.73, 'lr': 5.220900807683601e-05, 'train_loss': 0.011558, 'train_psnr': 25.1765, 'val_psnr': 24.0514, 'input_psnr': 23.1331, 'delta_psnr': 0.9183, 'best_val_psnr': 24.0514}
# {'epoch': 5114, 'epoch_time_sec': 19.71, 'lr': 5.197816475629524e-05, 'train_loss': 0.011549, 'train_psnr': 25.1811, 'val_psnr': 24.0515, 'input_psnr': 23.1331, 'delta_psnr': 0.9184, 'best_val_psnr': 24.0515}
# {'epoch': 5115, 'epoch_time_sec': 19.71, 'lr': 5.174669550401414e-05, 'train_loss': 0.011551, 'train_psnr': 25.1814, 'val_psnr': 24.0515, 'input_psnr': 23.1331, 'delta_psnr': 0.9184, 'best_val_psnr': 24.0515}
# {'epoch': 5116, 'epoch_time_sec': 19.77, 'lr': 5.1514611069523854e-05, 'train_loss': 0.011552, 'train_psnr': 25.1785, 'val_psnr': 24.0513, 'input_psnr': 23.1331, 'delta_psnr': 0.9183, 'best_val_psnr': 24.0515}
# {'epoch': 5117, 'epoch_time_sec': 19.76, 'lr': 5.128192223092487e-05, 'train_loss': 0.011555, 'train_psnr': 25.1794, 'val_psnr': 24.0514, 'input_psnr': 23.1331, 'delta_psnr': 0.9183, 'best_val_psnr': 24.0515}
# {'epoch': 5118, 'epoch_time_sec': 19.79, 'lr': 5.104863979438642e-05, 'train_loss': 0.011569, 'train_psnr': 25.1707, 'val_psnr': 24.0513, 'input_psnr': 23.1331, 'delta_psnr': 0.9182, 'best_val_psnr': 24.0515}
# {'epoch': 5119, 'epoch_time_sec': 19.73, 'lr': 5.0814774593644744e-05, 'train_loss': 0.011565, 'train_psnr': 25.174, 'val_psnr': 24.0513, 'input_psnr': 23.1331, 'delta_psnr': 0.9183, 'best_val_psnr': 24.0515}
# {'epoch': 5120, 'epoch_time_sec': 19.73, 'lr': 5.0580337489499854e-05, 'train_loss': 0.011568, 'train_psnr': 25.1721, 'val_psnr': 24.0513, 'input_psnr': 23.1331, 'delta_psnr': 0.9182, 'best_val_psnr': 24.0515}
# {'epoch': 5121, 'epoch_time_sec': 19.76, 'lr': 5.0345339369311204e-05, 'train_loss': 0.011556, 'train_psnr': 25.1761, 'val_psnr': 24.0513, 'input_psnr': 23.1331, 'delta_psnr': 0.9183, 'best_val_psnr': 24.0515}
# {'epoch': 5122, 'epoch_time_sec': 19.77, 'lr': 5.0109791146492086e-05, 'train_loss': 0.011555, 'train_psnr': 25.1772, 'val_psnr': 24.0514, 'input_psnr': 23.1331, 'delta_psnr': 0.9183, 'best_val_psnr': 24.0515}
# {'epoch': 5123, 'epoch_time_sec': 19.79, 'lr': 4.987370376000279e-05, 'train_loss': 0.011554, 'train_psnr': 25.1783, 'val_psnr': 24.0514, 'input_psnr': 23.1331, 'delta_psnr': 0.9183, 'best_val_psnr': 24.0515}
# {'epoch': 5124, 'epoch_time_sec': 19.76, 'lr': 4.963708817384261e-05, 'train_loss': 0.011556, 'train_psnr': 25.1775, 'val_psnr': 24.0515, 'input_psnr': 23.1331, 'delta_psnr': 0.9184, 'best_val_psnr': 24.0515}
# {'epoch': 5125, 'epoch_time_sec': 19.75, 'lr': 4.939995537654062e-05, 'train_loss': 0.011561, 'train_psnr': 25.1745, 'val_psnr': 24.0515, 'input_psnr': 23.1331, 'delta_psnr': 0.9184, 'best_val_psnr': 24.0515}
# {'epoch': 5126, 'epoch_time_sec': 19.75, 'lr': 4.916231638064544e-05, 'train_loss': 0.011557, 'train_psnr': 25.1777, 'val_psnr': 24.0514, 'input_psnr': 23.1331, 'delta_psnr': 0.9184, 'best_val_psnr': 24.0515}
# {'epoch': 5127, 'epoch_time_sec': 19.73, 'lr': 4.892418222221376e-05, 'train_loss': 0.01156, 'train_psnr': 25.1758, 'val_psnr': 24.0514, 'input_psnr': 23.1331, 'delta_psnr': 0.9183, 'best_val_psnr': 24.0515}
# {'epoch': 5128, 'epoch_time_sec': 19.77, 'lr': 4.8685563960297826e-05, 'train_loss': 0.011566, 'train_psnr': 25.175, 'val_psnr': 24.0516, 'input_psnr': 23.1331, 'delta_psnr': 0.9185, 'best_val_psnr': 24.0516}
# {'epoch': 5129, 'epoch_time_sec': 19.76, 'lr': 4.844647267643184e-05, 'train_loss': 0.011562, 'train_psnr': 25.1765, 'val_psnr': 24.0516, 'input_psnr': 23.1331, 'delta_psnr': 0.9186, 'best_val_psnr': 24.0516}
# {'epoch': 5130, 'epoch_time_sec': 19.76, 'lr': 4.820691947411738e-05, 'train_loss': 0.011568, 'train_psnr': 25.1749, 'val_psnr': 24.0516, 'input_psnr': 23.1331, 'delta_psnr': 0.9186, 'best_val_psnr': 24.0516}
# {'epoch': 5131, 'epoch_time_sec': 19.74, 'lr': 4.79669154783077e-05, 'train_loss': 0.01158, 'train_psnr': 25.1693, 'val_psnr': 24.0517, 'input_psnr': 23.1331, 'delta_psnr': 0.9187, 'best_val_psnr': 24.0517}
# {'epoch': 5132, 'epoch_time_sec': 19.81, 'lr': 4.772647183489109e-05, 'train_loss': 0.011569, 'train_psnr': 25.1724, 'val_psnr': 24.0517, 'input_psnr': 23.1331, 'delta_psnr': 0.9187, 'best_val_psnr': 24.0517}
# {'epoch': 5133, 'epoch_time_sec': 19.79, 'lr': 4.7485599710173255e-05, 'train_loss': 0.011554, 'train_psnr': 25.1779, 'val_psnr': 24.0518, 'input_psnr': 23.1331, 'delta_psnr': 0.9187, 'best_val_psnr': 24.0518}
# {'epoch': 5134, 'epoch_time_sec': 19.73, 'lr': 4.724431029035878e-05, 'train_loss': 0.011557, 'train_psnr': 25.1785, 'val_psnr': 24.0519, 'input_psnr': 23.1331, 'delta_psnr': 0.9188, 'best_val_psnr': 24.0519}
# {'epoch': 5135, 'epoch_time_sec': 19.74, 'lr': 4.700261478103159e-05, 'train_loss': 0.011565, 'train_psnr': 25.1739, 'val_psnr': 24.0519, 'input_psnr': 23.1331, 'delta_psnr': 0.9188, 'best_val_psnr': 24.0519}
# {'epoch': 5136, 'epoch_time_sec': 19.72, 'lr': 4.676052440663461e-05, 'train_loss': 0.011556, 'train_psnr': 25.1793, 'val_psnr': 24.052, 'input_psnr': 23.1331, 'delta_psnr': 0.919, 'best_val_psnr': 24.052}
# {'epoch': 5137, 'epoch_time_sec': 19.77, 'lr': 4.6518050409948437e-05, 'train_loss': 0.011557, 'train_psnr': 25.178, 'val_psnr': 24.0521, 'input_psnr': 23.1331, 'delta_psnr': 0.9191, 'best_val_psnr': 24.0521}
# {'epoch': 5138, 'epoch_time_sec': 19.8, 'lr': 4.6275204051569254e-05, 'train_loss': 0.011555, 'train_psnr': 25.1767, 'val_psnr': 24.0521, 'input_psnr': 23.1331, 'delta_psnr': 0.919, 'best_val_psnr': 24.0521}
# {'epoch': 5139, 'epoch_time_sec': 19.79, 'lr': 4.6031996609385905e-05, 'train_loss': 0.011543, 'train_psnr': 25.185, 'val_psnr': 24.0522, 'input_psnr': 23.1331, 'delta_psnr': 0.9191, 'best_val_psnr': 24.0522}
# {'epoch': 5140, 'epoch_time_sec': 19.75, 'lr': 4.57884393780561e-05, 'train_loss': 0.011546, 'train_psnr': 25.1839, 'val_psnr': 24.0522, 'input_psnr': 23.1331, 'delta_psnr': 0.9191, 'best_val_psnr': 24.0522}
# {'epoch': 5141, 'epoch_time_sec': 19.71, 'lr': 4.55445436684819e-05, 'train_loss': 0.011567, 'train_psnr': 25.1719, 'val_psnr': 24.0522, 'input_psnr': 23.1331, 'delta_psnr': 0.9192, 'best_val_psnr': 24.0522}
# {'epoch': 5142, 'epoch_time_sec': 19.76, 'lr': 4.5300320807284475e-05, 'train_loss': 0.01154, 'train_psnr': 25.1851, 'val_psnr': 24.0522, 'input_psnr': 23.1331, 'delta_psnr': 0.9191, 'best_val_psnr': 24.0522}
# {'epoch': 5143, 'epoch_time_sec': 19.78, 'lr': 4.505578213627801e-05, 'train_loss': 0.011549, 'train_psnr': 25.1803, 'val_psnr': 24.0523, 'input_psnr': 23.1331, 'delta_psnr': 0.9192, 'best_val_psnr': 24.0523}
# {'epoch': 5144, 'epoch_time_sec': 19.74, 'lr': 4.481093901194308e-05, 'train_loss': 0.011543, 'train_psnr': 25.1853, 'val_psnr': 24.0522, 'input_psnr': 23.1331, 'delta_psnr': 0.9192, 'best_val_psnr': 24.0523}
# {'epoch': 5145, 'epoch_time_sec': 19.79, 'lr': 4.4565802804899155e-05, 'train_loss': 0.011553, 'train_psnr': 25.1785, 'val_psnr': 24.0521, 'input_psnr': 23.1331, 'delta_psnr': 0.9191, 'best_val_psnr': 24.0523}
# {'epoch': 5146, 'epoch_time_sec': 19.79, 'lr': 4.432038489937663e-05, 'train_loss': 0.011557, 'train_psnr': 25.1757, 'val_psnr': 24.0522, 'input_psnr': 23.1331, 'delta_psnr': 0.9191, 'best_val_psnr': 24.0523}
# {'epoch': 5147, 'epoch_time_sec': 19.82, 'lr': 4.407469669268809e-05, 'train_loss': 0.011542, 'train_psnr': 25.1863, 'val_psnr': 24.052, 'input_psnr': 23.1331, 'delta_psnr': 0.9189, 'best_val_psnr': 24.0523}
# {'epoch': 5148, 'epoch_time_sec': 19.77, 'lr': 4.382874959469899e-05, 'train_loss': 0.011567, 'train_psnr': 25.1748, 'val_psnr': 24.052, 'input_psnr': 23.1331, 'delta_psnr': 0.9189, 'best_val_psnr': 24.0523}
# {'epoch': 5149, 'epoch_time_sec': 19.72, 'lr': 4.358255502729786e-05, 'train_loss': 0.011556, 'train_psnr': 25.1771, 'val_psnr': 24.052, 'input_psnr': 23.1331, 'delta_psnr': 0.9189, 'best_val_psnr': 24.0523}
# {'epoch': 5150, 'epoch_time_sec': 19.79, 'lr': 4.333612442386578e-05, 'train_loss': 0.011544, 'train_psnr': 25.1855, 'val_psnr': 24.052, 'input_psnr': 23.1331, 'delta_psnr': 0.919, 'best_val_psnr': 24.0523}
# {'epoch': 5151, 'epoch_time_sec': 19.78, 'lr': 4.3089469228745445e-05, 'train_loss': 0.011551, 'train_psnr': 25.1814, 'val_psnr': 24.052, 'input_psnr': 23.1331, 'delta_psnr': 0.9189, 'best_val_psnr': 24.0523}
# {'epoch': 5152, 'epoch_time_sec': 19.8, 'lr': 4.28426008967097e-05, 'train_loss': 0.011558, 'train_psnr': 25.178, 'val_psnr': 24.0521, 'input_psnr': 23.1331, 'delta_psnr': 0.919, 'best_val_psnr': 24.0523}
# {'epoch': 5153, 'epoch_time_sec': 19.71, 'lr': 4.2595530892429554e-05, 'train_loss': 0.011541, 'train_psnr': 25.1866, 'val_psnr': 24.0521, 'input_psnr': 23.1331, 'delta_psnr': 0.919, 'best_val_psnr': 24.0523}
# {'epoch': 5154, 'epoch_time_sec': 19.73, 'lr': 4.234827068994175e-05, 'train_loss': 0.011544, 'train_psnr': 25.1849, 'val_psnr': 24.0522, 'input_psnr': 23.1331, 'delta_psnr': 0.9191, 'best_val_psnr': 24.0523}
# {'epoch': 5155, 'epoch_time_sec': 19.78, 'lr': 4.210083177211593e-05, 'train_loss': 0.011548, 'train_psnr': 25.1821, 'val_psnr': 24.0522, 'input_psnr': 23.1331, 'delta_psnr': 0.9191, 'best_val_psnr': 24.0523}
# {'epoch': 5156, 'epoch_time_sec': 19.77, 'lr': 4.185322563012136e-05, 'train_loss': 0.011555, 'train_psnr': 25.1788, 'val_psnr': 24.0524, 'input_psnr': 23.1331, 'delta_psnr': 0.9193, 'best_val_psnr': 24.0524}
# {'epoch': 5157, 'epoch_time_sec': 19.76, 'lr': 4.160546376289325e-05, 'train_loss': 0.011548, 'train_psnr': 25.182, 'val_psnr': 24.0524, 'input_psnr': 23.1331, 'delta_psnr': 0.9193, 'best_val_psnr': 24.0524}
# {'epoch': 5158, 'epoch_time_sec': 19.72, 'lr': 4.1357557676598745e-05, 'train_loss': 0.011547, 'train_psnr': 25.1808, 'val_psnr': 24.0524, 'input_psnr': 23.1331, 'delta_psnr': 0.9193, 'best_val_psnr': 24.0524}
# {'epoch': 5159, 'epoch_time_sec': 19.74, 'lr': 4.1109518884102625e-05, 'train_loss': 0.011546, 'train_psnr': 25.1825, 'val_psnr': 24.0523, 'input_psnr': 23.1331, 'delta_psnr': 0.9192, 'best_val_psnr': 24.0524}
# ...
# {'epoch': 5325, 'epoch_time_sec': 19.76, 'lr': 6.664536028495256e-06, 'train_loss': 0.011539, 'train_psnr': 25.1901, 'val_psnr': 24.0541, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0541}
# {'epoch': 5326, 'epoch_time_sec': 19.77, 'lr': 6.543608230716692e-06, 'train_loss': 0.01154, 'train_psnr': 25.1909, 'val_psnr': 24.0541, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0541}
# {'epoch': 5327, 'epoch_time_sec': 19.77, 'lr': 6.424164501450168e-06, 'train_loss': 0.011532, 'train_psnr': 25.193, 'val_psnr': 24.0541, 'input_psnr': 23.1331, 'delta_psnr': 0.921, 'best_val_psnr': 24.0541}
# {'epoch': 5328, 'epoch_time_sec': 19.76, 'lr': 6.30621038771361e-06, 'train_loss': 0.011529, 'train_psnr': 25.1933, 'val_psnr': 24.0541, 'input_psnr': 23.1331, 'delta_psnr': 0.921, 'best_val_psnr': 24.0541}
# {'epoch': 5329, 'epoch_time_sec': 19.77, 'lr': 6.189751367346545e-06, 'train_loss': 0.011522, 'train_psnr': 25.1971, 'val_psnr': 24.054, 'input_psnr': 23.1331, 'delta_psnr': 0.921, 'best_val_psnr': 24.0541}
# {'epoch': 5330, 'epoch_time_sec': 19.75, 'lr': 6.074792848755715e-06, 'train_loss': 0.011529, 'train_psnr': 25.1935, 'val_psnr': 24.0541, 'input_psnr': 23.1331, 'delta_psnr': 0.921, 'best_val_psnr': 24.0541}
# {'epoch': 5331, 'epoch_time_sec': 19.8, 'lr': 5.9613401706639415e-06, 'train_loss': 0.011526, 'train_psnr': 25.1965, 'val_psnr': 24.0541, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0541}
# {'epoch': 5332, 'epoch_time_sec': 19.77, 'lr': 5.849398601862156e-06, 'train_loss': 0.011528, 'train_psnr': 25.1932, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5333, 'epoch_time_sec': 19.74, 'lr': 5.738973340964714e-06, 'train_loss': 0.011534, 'train_psnr': 25.1913, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5334, 'epoch_time_sec': 19.79, 'lr': 5.6300695161680146e-06, 'train_loss': 0.01153, 'train_psnr': 25.1954, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5335, 'epoch_time_sec': 19.79, 'lr': 5.5226921850122875e-06, 'train_loss': 0.011529, 'train_psnr': 25.195, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5336, 'epoch_time_sec': 19.77, 'lr': 5.416846334146747e-06, 'train_loss': 0.011524, 'train_psnr': 25.1969, 'val_psnr': 24.0541, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5337, 'epoch_time_sec': 19.71, 'lr': 5.312536879098027e-06, 'train_loss': 0.011522, 'train_psnr': 25.1968, 'val_psnr': 24.0541, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5338, 'epoch_time_sec': 19.71, 'lr': 5.209768664041852e-06, 'train_loss': 0.011543, 'train_psnr': 25.1927, 'val_psnr': 24.0541, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5339, 'epoch_time_sec': 19.78, 'lr': 5.1085464615781205e-06, 'train_loss': 0.011521, 'train_psnr': 25.1981, 'val_psnr': 24.0541, 'input_psnr': 23.1331, 'delta_psnr': 0.921, 'best_val_psnr': 24.0542}
# {'epoch': 5340, 'epoch_time_sec': 19.77, 'lr': 5.008874972509251e-06, 'train_loss': 0.011529, 'train_psnr': 25.192, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5341, 'epoch_time_sec': 19.8, 'lr': 4.910758825621844e-06, 'train_loss': 0.011522, 'train_psnr': 25.197, 'val_psnr': 24.0541, 'input_psnr': 23.1331, 'delta_psnr': 0.921, 'best_val_psnr': 24.0542}
# {'epoch': 5342, 'epoch_time_sec': 19.75, 'lr': 4.814202577471769e-06, 'train_loss': 0.011528, 'train_psnr': 25.1949, 'val_psnr': 24.0541, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5343, 'epoch_time_sec': 19.75, 'lr': 4.7192107121725164e-06, 'train_loss': 0.011521, 'train_psnr': 25.1974, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5344, 'epoch_time_sec': 19.71, 'lr': 4.625787641186967e-06, 'train_loss': 0.011526, 'train_psnr': 25.1952, 'val_psnr': 24.0541, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5345, 'epoch_time_sec': 19.79, 'lr': 4.533937703122524e-06, 'train_loss': 0.011527, 'train_psnr': 25.194, 'val_psnr': 24.0541, 'input_psnr': 23.1331, 'delta_psnr': 0.921, 'best_val_psnr': 24.0542}
# {'epoch': 5346, 'epoch_time_sec': 19.77, 'lr': 4.443665163529633e-06, 'train_loss': 0.011523, 'train_psnr': 25.1959, 'val_psnr': 24.0541, 'input_psnr': 23.1331, 'delta_psnr': 0.921, 'best_val_psnr': 24.0542}
# {'epoch': 5347, 'epoch_time_sec': 19.76, 'lr': 4.354974214703662e-06, 'train_loss': 0.011529, 'train_psnr': 25.1972, 'val_psnr': 24.0541, 'input_psnr': 23.1331, 'delta_psnr': 0.921, 'best_val_psnr': 24.0542}
# {'epoch': 5348, 'epoch_time_sec': 19.74, 'lr': 4.267868975490248e-06, 'train_loss': 0.011525, 'train_psnr': 25.195, 'val_psnr': 24.0541, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5349, 'epoch_time_sec': 19.8, 'lr': 4.182353491093974e-06, 'train_loss': 0.011518, 'train_psnr': 25.1992, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5350, 'epoch_time_sec': 19.75, 'lr': 4.0984317328905416e-06, 'train_loss': 0.011518, 'train_psnr': 25.199, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5351, 'epoch_time_sec': 19.8, 'lr': 4.016107598242323e-06, 'train_loss': 0.011522, 'train_psnr': 25.1969, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5352, 'epoch_time_sec': 19.71, 'lr': 3.935384910317373e-06, 'train_loss': 0.01153, 'train_psnr': 25.1922, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5353, 'epoch_time_sec': 19.78, 'lr': 3.8562674179118595e-06, 'train_loss': 0.011523, 'train_psnr': 25.1966, 'val_psnr': 24.0541, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5354, 'epoch_time_sec': 19.74, 'lr': 3.7787587952760077e-06, 'train_loss': 0.011522, 'train_psnr': 25.1975, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5355, 'epoch_time_sec': 19.74, 'lr': 3.7028626419434245e-06, 'train_loss': 0.011532, 'train_psnr': 25.1915, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5356, 'epoch_time_sec': 19.79, 'lr': 3.628582482563947e-06, 'train_loss': 0.011525, 'train_psnr': 25.1945, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5357, 'epoch_time_sec': 19.77, 'lr': 3.555921766739982e-06, 'train_loss': 0.011525, 'train_psnr': 25.1963, 'val_psnr': 24.0541, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5358, 'epoch_time_sec': 19.75, 'lr': 3.48488386886627e-06, 'train_loss': 0.011531, 'train_psnr': 25.1934, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5359, 'epoch_time_sec': 19.76, 'lr': 3.4154720879731915e-06, 'train_loss': 0.011532, 'train_psnr': 25.1943, 'val_psnr': 24.0541, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5360, 'epoch_time_sec': 19.75, 'lr': 3.3476896475735675e-06, 'train_loss': 0.011543, 'train_psnr': 25.1894, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5361, 'epoch_time_sec': 19.75, 'lr': 3.281539695512939e-06, 'train_loss': 0.011539, 'train_psnr': 25.1913, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0542}
# {'epoch': 5362, 'epoch_time_sec': 19.78, 'lr': 3.217025303823389e-06, 'train_loss': 0.01153, 'train_psnr': 25.1921, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5363, 'epoch_time_sec': 19.7, 'lr': 3.154149468580892e-06, 'train_loss': 0.011527, 'train_psnr': 25.195, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5364, 'epoch_time_sec': 19.69, 'lr': 3.0929151097661444e-06, 'train_loss': 0.011519, 'train_psnr': 25.1975, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5365, 'epoch_time_sec': 19.78, 'lr': 3.033325071128981e-06, 'train_loss': 0.011525, 'train_psnr': 25.1961, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5366, 'epoch_time_sec': 19.75, 'lr': 2.9753821200562988e-06, 'train_loss': 0.01152, 'train_psnr': 25.1989, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0542}
# {'epoch': 5367, 'epoch_time_sec': 19.72, 'lr': 2.9190889474435483e-06, 'train_loss': 0.01152, 'train_psnr': 25.199, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0542}
# {'epoch': 5368, 'epoch_time_sec': 19.8, 'lr': 2.864448167569767e-06, 'train_loss': 0.011525, 'train_psnr': 25.1965, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0542}
# {'epoch': 5369, 'epoch_time_sec': 19.75, 'lr': 2.811462317976152e-06, 'train_loss': 0.011521, 'train_psnr': 25.1968, 'val_psnr': 24.0543, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0543}
# {'epoch': 5370, 'epoch_time_sec': 19.74, 'lr': 2.7601338593482395e-06, 'train_loss': 0.011522, 'train_psnr': 25.1964, 'val_psnr': 24.0543, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0543}
# {'epoch': 5371, 'epoch_time_sec': 19.75, 'lr': 2.7104651754016212e-06, 'train_loss': 0.01153, 'train_psnr': 25.1916, 'val_psnr': 24.0543, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0543}
# {'epoch': 5372, 'epoch_time_sec': 19.76, 'lr': 2.662458572771238e-06, 'train_loss': 0.011518, 'train_psnr': 25.199, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0543}
# {'epoch': 5373, 'epoch_time_sec': 19.76, 'lr': 2.6161162809042627e-06, 'train_loss': 0.011533, 'train_psnr': 25.192, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0543}
# {'epoch': 5374, 'epoch_time_sec': 19.78, 'lr': 2.571440451956568e-06, 'train_loss': 0.011532, 'train_psnr': 25.1935, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0543}
# {'epoch': 5375, 'epoch_time_sec': 19.74, 'lr': 2.528433160692768e-06, 'train_loss': 0.01152, 'train_psnr': 25.1967, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0543}
# {'epoch': 5376, 'epoch_time_sec': 19.78, 'lr': 2.4870964043898854e-06, 'train_loss': 0.011522, 'train_psnr': 25.1976, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0543}
# {'epoch': 5377, 'epoch_time_sec': 19.76, 'lr': 2.447432102744571e-06, 'train_loss': 0.011522, 'train_psnr': 25.1965, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0543}
# {'epoch': 5378, 'epoch_time_sec': 19.77, 'lr': 2.409442097783972e-06, 'train_loss': 0.011533, 'train_psnr': 25.1967, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0543}
# {'epoch': 5379, 'epoch_time_sec': 19.74, 'lr': 2.3731281537801734e-06, 'train_loss': 0.011527, 'train_psnr': 25.1957, 'val_psnr': 24.0543, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0543}
# {'epoch': 5380, 'epoch_time_sec': 19.73, 'lr': 2.3384919571682924e-06, 'train_loss': 0.011522, 'train_psnr': 25.1961, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0543}
# {'epoch': 5381, 'epoch_time_sec': 19.73, 'lr': 2.30553511646811e-06, 'train_loss': 0.011525, 'train_psnr': 25.1971, 'val_psnr': 24.0543, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0543}
# {'epoch': 5382, 'epoch_time_sec': 19.81, 'lr': 2.2742591622094254e-06, 'train_loss': 0.011529, 'train_psnr': 25.194, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0543}
# {'epoch': 5383, 'epoch_time_sec': 19.77, 'lr': 2.244665546860936e-06, 'train_loss': 0.011521, 'train_psnr': 25.199, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0543}
# {'epoch': 5384, 'epoch_time_sec': 19.79, 'lr': 2.216755644762804e-06, 'train_loss': 0.01152, 'train_psnr': 25.1989, 'val_psnr': 24.0543, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0543}
# {'epoch': 5385, 'epoch_time_sec': 19.74, 'lr': 2.1905307520628356e-06, 'train_loss': 0.011521, 'train_psnr': 25.1982, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0543}
# {'epoch': 5386, 'epoch_time_sec': 19.75, 'lr': 2.1659920866562684e-06, 'train_loss': 0.011523, 'train_psnr': 25.198, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0543}
# {'epoch': 5387, 'epoch_time_sec': 19.76, 'lr': 2.143140788129229e-06, 'train_loss': 0.011539, 'train_psnr': 25.1893, 'val_psnr': 24.0541, 'input_psnr': 23.1331, 'delta_psnr': 0.921, 'best_val_psnr': 24.0543}
# {'epoch': 5388, 'epoch_time_sec': 19.76, 'lr': 2.121977917705798e-06, 'train_loss': 0.01152, 'train_psnr': 25.1975, 'val_psnr': 24.0541, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0543}
# {'epoch': 5389, 'epoch_time_sec': 19.72, 'lr': 2.1025044581987407e-06, 'train_loss': 0.011522, 'train_psnr': 25.1953, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0543}
# {'epoch': 5390, 'epoch_time_sec': 19.73, 'lr': 2.084721313963849e-06, 'train_loss': 0.011539, 'train_psnr': 25.1906, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0543}
# {'epoch': 5391, 'epoch_time_sec': 19.77, 'lr': 2.0686293108579578e-06, 'train_loss': 0.011519, 'train_psnr': 25.2009, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0543}
# {'epoch': 5392, 'epoch_time_sec': 19.73, 'lr': 2.054229196200573e-06, 'train_loss': 0.011539, 'train_psnr': 25.1909, 'val_psnr': 24.0543, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0543}
# {'epoch': 5393, 'epoch_time_sec': 19.77, 'lr': 2.041521638739184e-06, 'train_loss': 0.011524, 'train_psnr': 25.195, 'val_psnr': 24.0543, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0543}
# {'epoch': 5394, 'epoch_time_sec': 19.77, 'lr': 2.030507228618201e-06, 'train_loss': 0.01153, 'train_psnr': 25.193, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0543}
# {'epoch': 5395, 'epoch_time_sec': 19.78, 'lr': 2.0211864773515477e-06, 'train_loss': 0.011536, 'train_psnr': 25.192, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0543}
# {'epoch': 5396, 'epoch_time_sec': 19.75, 'lr': 2.013559817798892e-06, 'train_loss': 0.011541, 'train_psnr': 25.193, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0543}
# {'epoch': 5397, 'epoch_time_sec': 19.76, 'lr': 2.007627604145579e-06, 'train_loss': 0.011542, 'train_psnr': 25.1886, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0543}
# {'epoch': 5398, 'epoch_time_sec': 19.79, 'lr': 2.0033901118861434e-06, 'train_loss': 0.011537, 'train_psnr': 25.1913, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0543}
# {'epoch': 5399, 'epoch_time_sec': 19.81, 'lr': 2.00084753781154e-06, 'train_loss': 0.011537, 'train_psnr': 25.1924, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0543}
# {'epoch': 5400, 'epoch_time_sec': 19.77, 'lr': 2e-06, 'train_loss': 0.011521, 'train_psnr': 25.1968, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0543}

# %% [markdown]
# ## 6. Validation Summary

# %%
export_model = load_checkpoint_for_eval(best_ckpt_path, device)
validation_summary = evaluate_metrics(export_model, val_loader, device)
preview_info = write_val_preview(export_model, val_loader, preview_dir, device)
print({'validation_summary': validation_summary, 'best_checkpoint_path': str(best_ckpt_path), 'last_checkpoint_path': str(last_ckpt_path), 'preview': preview_info})
# Out:
# {'validation_summary': {'val_psnr': 24.054289835149593, 'input_psnr': 23.133060299266468, 'delta_psnr': 0.9212295358831248}, 'best_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/182012_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart/checkpoints/best.pth', 'last_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/182012_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart/checkpoints/last.pth', 'preview': {'sample_name': '0000', 'input': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/182012_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart/exports/val_preview/val_preview_input.png', 'prediction': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/182012_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart/exports/val_preview/val_preview_pred.png', 'target': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/182012_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart/exports/val_preview/val_preview_target.png'}}

# %% [markdown]
# ## 7. Export And Submission Artifacts

# %%
def load_or_create_calibration_summary(calibration_dir: Path, pairs: list[tuple[Path, Path, str]], count: int, eval_size: int) -> dict[str, Any]:
    manifest_path = calibration_dir / 'manifest.json'
    if manifest_path.exists():
        manifest = json.loads(manifest_path.read_text(encoding='utf-8'))
        item_count = int(manifest.get('count') or len(manifest.get('items', [])))
        if item_count <= 0 or manifest.get('derived_from_training') is not True:
            raise ValueError(f'Invalid training-derived calibration manifest: {manifest_path}')
        return {'calibration_dir': str(calibration_dir), 'manifest_path': str(manifest_path), 'count': item_count, 'source': manifest.get('source'), 'derived_from_training': True, 'reused_existing_dataset': True}

    calibration_dir.mkdir(parents=True, exist_ok=True) 
    items: list[dict[str, Any]] = []
    for index, (lr_path, _, name) in enumerate(pairs[:count]):
        image = Image.open(lr_path).convert('RGB')
        if image.size != (eval_size, eval_size):
            image = image.resize((eval_size, eval_size), BICUBIC_RESAMPLE)
        image_path = calibration_dir / f'{index:03d}_{Path(name).name}.png'
        image.save(image_path)
        items.append({'index': index, 'name': name, 'source_lr': str(lr_path), 'image_path': str(image_path), 'derived_from_training': True})
    manifest = {'count': len(items), 'source': 'training_pairs', 'eval_size': eval_size, 'derived_from_training': True, 'items': items}
    write_json(manifest_path, manifest)
    return {'calibration_dir': str(calibration_dir), 'manifest_path': str(manifest_path), 'count': len(items), 'source': 'training_pairs', 'derived_from_training': True, 'reused_existing_dataset': False}

conversion_script = """#!/usr/bin/env python3
from __future__ import annotations

import argparse
import json
import shlex
import subprocess
from pathlib import Path


def parse_args() -> argparse.Namespace:
    parser = argparse.ArgumentParser(description='Lab 3 ONNX-to-MXQ handoff script for FSRCNN residual.')
    parser.add_argument('--onnx', type=Path, required=True)
    parser.add_argument('--calibration-dir', type=Path, required=True)
    parser.add_argument('--output', type=Path, required=True)
    parser.add_argument('--command-template', default='', help='Optional command with {onnx}, {calibration}, {output} placeholders.')
    parser.add_argument('--dry-run', action='store_true')
    return parser.parse_args()


def main() -> None:
    args = parse_args()
    args.onnx = args.onnx.resolve()
    args.calibration_dir = args.calibration_dir.resolve()
    args.output = args.output.resolve()
    if not args.onnx.exists():
        raise FileNotFoundError(f'ONNX file not found: {args.onnx}')
    if not args.calibration_dir.exists():
        raise FileNotFoundError(f'Calibration directory not found: {args.calibration_dir}')
    payload = {
        'onnx': str(args.onnx),
        'calibration_dir': str(args.calibration_dir),
        'output': str(args.output),
        'status': 'handoff_only',
        'command_template': args.command_template,
    }
    if args.command_template:
        command = args.command_template.format(
            onnx=shlex.quote(str(args.onnx)),
            calibration=shlex.quote(str(args.calibration_dir)),
            output=shlex.quote(str(args.output)),
        )
        payload['command'] = command
        if not args.dry_run:
            completed = subprocess.run(command, shell=True, check=False, capture_output=True, text=True)
            payload.update({'status': 'completed' if completed.returncode == 0 else 'failed', 'returncode': completed.returncode, 'stdout': completed.stdout, 'stderr': completed.stderr})
    args.output.parent.mkdir(parents=True, exist_ok=True)
    handoff_path = args.output.with_suffix('.handoff.json')
    handoff_path.write_text(json.dumps(payload, indent=2, sort_keys=True) + '\n', encoding='utf-8')
    print(json.dumps(payload, indent=2, sort_keys=True))


if __name__ == '__main__':
    main()
"""

onnx_path = exports_dir / f'{cfg.model_id}.onnx'
mxq_target_path = exports_dir / f'{cfg.model_id}.mxq'
conversion_script_path = exports_dir / 'convert_fsrcnn_residual_mxq.py'
conversion_script_path.write_text(conversion_script, encoding='utf-8')

cpu_export_model = load_checkpoint_for_eval(best_ckpt_path, torch.device('cpu')).cpu().eval()
dummy = torch.randn(1, 3, cfg.eval_size, cfg.eval_size)
torch.onnx.export(cpu_export_model, dummy, str(onnx_path), input_names=['input'], output_names=['output'], opset_version=17, dynamo=False)

onnx_model = onnx.load(str(onnx_path))
onnx.checker.check_model(onnx_model)
node_ops = [node.op_type for node in onnx_model.graph.node]
op_histogram = {op: node_ops.count(op) for op in sorted(set(node_ops))}
onnx_summary = {'onnx_path': str(onnx_path), 'checked': True, 'graph_op_count': len(node_ops), 'op_histogram': op_histogram}
print(onnx_summary)

parity_result = {'attempted': False, 'onnxruntime_available': False, 'max_abs_diff': None, 'mean_abs_diff': None}
try:
    import onnxruntime as ort
    parity_result['attempted'] = True
    parity_result['onnxruntime_available'] = True
    parity_input = torch.randn(1, 3, cfg.eval_size, cfg.eval_size)
    with torch.no_grad():
        torch_out = cpu_export_model(parity_input).detach().cpu().numpy()
    ort_session = ort.InferenceSession(str(onnx_path), providers=['CPUExecutionProvider'])
    ort_out = ort_session.run(['output'], {'input': parity_input.numpy()})[0]
    diff = np.abs(torch_out - ort_out)
    parity_result['max_abs_diff'] = float(diff.max())
    parity_result['mean_abs_diff'] = float(diff.mean())
except ImportError:
    print('onnxruntime not installed; skipping CPU parity check')
print(parity_result)

calibration_dir = exports_dir / 'calibration'
calibration_summary = load_or_create_calibration_summary(calibration_dir, train_pairs, 128, cfg.eval_size)
mxq_command = f'python {conversion_script_path} --onnx {onnx_path} --calibration-dir {calibration_dir} --output {mxq_target_path} --dry-run'
mxq_handoff = {
    'conversion_script_path': str(conversion_script_path),
    'onnx_input_path': str(onnx_path),
    'calibration_manifest_path': calibration_summary['manifest_path'],
    'mxq_target_path': str(mxq_target_path),
    'command': mxq_command,
    'requested_compile': False,
}
summary = {
    'model_id': cfg.model_id,
    'run_root': str(run_root),
    'config': asdict(cfg),

    'resume': resume_info,

    'lr_schedule': lr_schedule_info,


    'data': {'data_root': str(data_root), 'train_pairs': len(train_pairs), 'val_pairs': len(val_pairs), 'train_splits': L3_TRAIN_SPLITS, 'val_dirs': L3_VAL_DIRS},
    'model': {'params': param_count, 'operator_audit': op_counts, 'input_shape': [1, 3, cfg.eval_size, cfg.eval_size], 'output_shape': [1, 3, cfg.eval_size, cfg.eval_size]},
    'validation': validation_summary,
    'preview': preview_info,
    'artifacts': {
        'best_checkpoint': str(best_ckpt_path),
        'last_checkpoint': str(last_ckpt_path),
        'onnx': str(onnx_path),
        'calibration_manifest': calibration_summary['manifest_path'],
        'conversion_script': str(conversion_script_path),
        'mxq_target': str(mxq_target_path),
        **run_log_paths,
    },
    'runtime': {
        'device': str(device),
        'gpu_name': gpu_name,
    },
    'onnx': onnx_summary,
    'onnx_parity': parity_result,
    'calibration': calibration_summary,
    'mxq_handoff': mxq_handoff,
}
write_json(summary_path, summary)
print({'summary_path': str(summary_path), **summary['artifacts']})
# Out:
# /tmp/ipykernel_18584/2373125837.py:86: DeprecationWarning: You are using the legacy TorchScript-based ONNX export. Starting in PyTorch 2.9, the new torch.export-based ONNX exporter has become the default. Learn more about the new export logic: https://docs.pytorch.org/docs/stable/onnx_export.html. For exporting control flow: https://pytorch.org/tutorials/beginner/onnx/export_control_flow_model_to_onnx_tutorial.html
#   torch.onnx.export(cpu_export_model, dummy, str(onnx_path), input_names=['input'], output_names=['output'], opset_version=17, dynamo=False)
# {'onnx_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/182012_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart/exports/fsrcnn_residual_96_40_m8.onnx', 'checked': True, 'graph_op_count': 24, 'op_histogram': {'Add': 1, 'Conv': 12, 'LeakyRelu': 11}}
# {'attempted': True, 'onnxruntime_available': True, 'max_abs_diff': 9.5367431640625e-07, 'mean_abs_diff': 1.572275323269423e-07}
# {'summary_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/182012_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart/summary.json', 'best_checkpoint': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/182012_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart/checkpoints/best.pth', 'last_checkpoint': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/182012_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart/checkpoints/last.pth', 'onnx': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/182012_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart/exports/fsrcnn_residual_96_40_m8.onnx', 'calibration_manifest': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/182012_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart/exports/calibration/manifest.json', 'conversion_script': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/182012_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart/exports/convert_fsrcnn_residual_mxq.py', 'mxq_target': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/182012_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart/exports/fsrcnn_residual_96_40_m8.mxq', 'metrics_csv': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/182012_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart/metrics.csv', 'history_json': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/182012_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart/history.json', 'summary_json': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/182012_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart/summary.json', 'run_manifest': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/182012_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart/run_manifest.json'}
