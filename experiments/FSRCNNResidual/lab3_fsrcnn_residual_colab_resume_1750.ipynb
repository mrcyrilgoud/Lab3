# %% [markdown]
# # Lab 3 - FSRCNN Residual 96/40/m8 Resume 1750 (Colab)
#
# - Model ID: `fsrcnn_residual_96_40_m8`
# - Goal: resume fixed-resolution super-resolution/restoration training from the 232518_2504 checkpoint
# - Expected input/output: `256x256x3`
# - Runtime target: Google Colab with Google Drive
# - Dataset layout: TinySRCNN legacy Lab 3 Drive folders
# - NPU-facing operators: `Conv`, `LeakyRelu`, and final residual `Add`

# %% [markdown]
# ## 1. Setup

# %%
try:
    import google.colab  # type: ignore
    IN_COLAB_BOOTSTRAP = True
except Exception:
    IN_COLAB_BOOTSTRAP = False

if IN_COLAB_BOOTSTRAP:
    # %pip install -q onnx onnxruntime

import csv
import json
import math
import os
import random
import sys
import time
from contextlib import nullcontext
from dataclasses import asdict, dataclass
from datetime import datetime
from pathlib import Path
from typing import Any

import numpy as np
import onnx
import torch
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
from torch.utils.data import DataLoader, Dataset

IMAGE_SUFFIXES = {'.png', '.jpg', '.jpeg', '.bmp'}
DRIVE_ROOT = Path('/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3')
DRIVE_DATA_ROOT = DRIVE_ROOT / 'Data'
DRIVE_RUNS_ROOT = DRIVE_ROOT / 'runs'

try:
    BICUBIC_RESAMPLE = Image.Resampling.BICUBIC
except AttributeError:
    BICUBIC_RESAMPLE = Image.BICUBIC

try:
    FLIP_LEFT_RIGHT = Image.Transpose.FLIP_LEFT_RIGHT
    FLIP_TOP_BOTTOM = Image.Transpose.FLIP_TOP_BOTTOM
    ROTATE_90 = Image.Transpose.ROTATE_90
    ROTATE_180 = Image.Transpose.ROTATE_180
    ROTATE_270 = Image.Transpose.ROTATE_270
except AttributeError:
    FLIP_LEFT_RIGHT = Image.FLIP_LEFT_RIGHT
    FLIP_TOP_BOTTOM = Image.FLIP_TOP_BOTTOM
    ROTATE_90 = Image.ROTATE_90
    ROTATE_180 = Image.ROTATE_180
    ROTATE_270 = Image.ROTATE_270


def set_global_seed(seed: int) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


def now_stamp() -> str:
    return datetime.now().strftime('%H%M%S_%d%m')


def is_colab_runtime() -> bool:
    try:
        import google.colab  # type: ignore  # noqa: F401
        return True
    except Exception:
        return False


def auto_num_workers(in_colab: bool) -> int:
    if sys.platform == 'darwin':
        return 0
    cpu_count = max(os.cpu_count() or 2, 2)
    if in_colab:
        return min(4, max(cpu_count - 1, 2))
    return min(2, cpu_count)


def resolve_repo_root(start: Path) -> Path:
    current = start.resolve()
    for candidate in [current, *current.parents]:
        if (candidate / 'Data').exists() and (candidate / 'runs').exists():
            return candidate
    for candidate in [current, *current.parents]:
        if (candidate / 'Data').exists():
            return candidate
    raise FileNotFoundError(f'Could not locate repo root from {start.resolve()}')


def make_unique_run_root(runs_root: Path, run_slug: str) -> Path:
    safe_slug = ''.join(ch if ch.isalnum() or ch in '_-' else '_' for ch in run_slug).strip('_')
    candidate = runs_root / f'{now_stamp()}_{safe_slug}'
    while candidate.exists():
        time.sleep(1.1)
        candidate = runs_root / f'{now_stamp()}_{safe_slug}'
    return candidate


def write_json(path: Path, payload: dict[str, Any]) -> None:
    path.parent.mkdir(parents=True, exist_ok=True)
    path.write_text(json.dumps(payload, indent=2, sort_keys=True) + '\n', encoding='utf-8')

# %% [markdown]
# ## 2. Configuration

# %%
@dataclass
class RunConfig:
    model_id: str = 'fsrcnn_residual_96_40_m8'
    run_slug: str = 'fsrcnn_residual_96_40_m8'
    enable_resume: bool = True
    resume_checkpoint_path: str | None = '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/232518_2504_fsrcnn_residual_96_40_m8/checkpoints/last.pth'
    seed: int = 1337
    train_patch_size: int = 256
    eval_size: int = 256
    batch_size: int = 16
    epochs: int = 1750
    lr: float = 1e-4
    min_lr: float = 1e-6
    weight_decay: float = 1e-4
    warmup_epochs: int = 8
    num_workers: int | None = 2
    prefetch_factor: int = 2
    use_amp: bool = True
    use_ema: bool = True
    ema_decay: float = 0.999
    calibration_count: int = 128

cfg = RunConfig()
in_colab = is_colab_runtime()
if in_colab:
    from google.colab import drive  # type: ignore

    drive.mount('/content/drive', force_remount=False)
    data_root = DRIVE_DATA_ROOT
    runs_root = DRIVE_RUNS_ROOT
    if not data_root.exists():
        raise FileNotFoundError(f'Google Drive data root not found: {data_root}')
else:
    repo_root = resolve_repo_root(Path.cwd())
    data_root = repo_root / 'Data'
    runs_root = repo_root / 'runs'
    if not data_root.exists():
        raise FileNotFoundError(f'Data root not found: {data_root}')

runs_root.mkdir(parents=True, exist_ok=True)
if cfg.num_workers is None:
    cfg.num_workers = auto_num_workers(in_colab)
if not cfg.enable_resume:
    cfg.resume_checkpoint_path = None

run_root = make_unique_run_root(runs_root, cfg.run_slug)
checkpoints_dir = run_root / 'checkpoints'
exports_dir = run_root / 'exports'
preview_dir = exports_dir / 'val_preview'
calibration_dir = exports_dir / 'calibration'
summary_path = run_root / 'summary.json'
metrics_csv_path = run_root / 'metrics.csv'

for directory in [run_root, checkpoints_dir, exports_dir, preview_dir, calibration_dir]:
    directory.mkdir(parents=True, exist_ok=True)

set_global_seed(cfg.seed)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
if device.type == 'cuda':
    torch.backends.cudnn.benchmark = True
    if hasattr(torch.backends.cuda.matmul, 'allow_tf32'):
        torch.backends.cuda.matmul.allow_tf32 = True

print({
    'device': str(device),
    'in_colab': in_colab,
    'data_root': str(data_root),
    'run_root': str(run_root),
    'config': asdict(cfg),
})
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# {'device': 'cuda', 'in_colab': True, 'data_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/Data', 'run_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/085328_2604_fsrcnn_residual_96_40_m8', 'config': {'model_id': 'fsrcnn_residual_96_40_m8', 'run_slug': 'fsrcnn_residual_96_40_m8', 'enable_resume': True, 'resume_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/232518_2504_fsrcnn_residual_96_40_m8/checkpoints/last.pth', 'seed': 1337, 'train_patch_size': 256, 'eval_size': 256, 'batch_size': 16, 'epochs': 1750, 'lr': 0.0001, 'min_lr': 1e-06, 'weight_decay': 0.0001, 'warmup_epochs': 8, 'num_workers': 2, 'prefetch_factor': 2, 'use_amp': True, 'use_ema': True, 'ema_decay': 0.999, 'calibration_count': 128}}

# %% [markdown]
# ## 3. Data

# %%
L3_TRAIN_SPLITS = (
    ('LR_HR/L3_HR_train1', 'L3_LR/L3_L3_train1', 'L3_HR_train1'),
    ('LR_HR/L3_HR_train2', 'L3_LR/L3_L3_train2', 'L3_HR_train2'),
    ('LR_HR/L3_HR_train3', 'L3_LR/L3_LR_train3', 'L3_HR_train3'),
    ('LR_HR/L3_HR_train4', 'L3_LR/L3_LR_train4', 'L3_HR_train4'),
    ('LR_HR/L3_HR_train', 'L3_LR/L3_LR_train', 'L3_HR_train'),
)
L3_VAL_DIRS = ('L3_HR_valid', 'L3_LR_valid')


def scan_image_directory(directory: Path) -> dict[str, Path]:
    if not directory.exists():
        raise FileNotFoundError(f'Missing directory: {directory}')
    return {
        path.stem: path
        for path in directory.iterdir()
        if path.is_file() and path.suffix.lower() in IMAGE_SUFFIXES
    }


def collect_split_pairs(hr_dir: Path, lr_dir: Path, split_name: str) -> list[tuple[Path, Path, str]]:
    hr_map = scan_image_directory(hr_dir)
    lr_map = scan_image_directory(lr_dir)
    shared = sorted(set(hr_map) & set(lr_map))
    if not shared:
        raise FileNotFoundError(f'No paired files found for {split_name}: HR={hr_dir}, LR={lr_dir}')
    hr_only = sorted(set(hr_map) - set(lr_map))
    lr_only = sorted(set(lr_map) - set(hr_map))
    if hr_only or lr_only:
        print({'split': split_name, 'hr_only_count': len(hr_only), 'lr_only_count': len(lr_only)})
    pairs: list[tuple[Path, Path, str]] = []
    for stem in shared:
        name = stem if split_name == 'val' else f'{split_name}/{stem}'
        pairs.append((lr_map[stem], hr_map[stem], name))
    return pairs


def collect_all_pairs(data_root: Path) -> tuple[list[tuple[Path, Path, str]], list[tuple[Path, Path, str]]]:
    train_pairs: list[tuple[Path, Path, str]] = []
    for hr_rel, lr_rel, split_name in L3_TRAIN_SPLITS:
        hr_dir = data_root / hr_rel
        lr_dir = data_root / lr_rel
        if hr_dir.exists() and lr_dir.exists():
            train_pairs.extend(collect_split_pairs(hr_dir, lr_dir, split_name))
        else:
            print({'skipped_missing_train_split': split_name, 'hr_dir': str(hr_dir), 'lr_dir': str(lr_dir)})
    val_pairs = collect_split_pairs(data_root / L3_VAL_DIRS[0], data_root / L3_VAL_DIRS[1], 'val')
    return train_pairs, val_pairs


class PairedSRDataset(Dataset):
    def __init__(self, pairs: list[tuple[Path, Path, str]], *, train: bool, patch_size: int, eval_size: int, seed: int):
        self.pairs = pairs
        self.train = train
        self.patch_size = patch_size
        self.eval_size = eval_size
        self.seed = seed
        self.epoch = 0

    def set_epoch(self, epoch: int) -> None:
        self.epoch = epoch

    @staticmethod
    def to_tensor(img: Image.Image) -> torch.Tensor:
        arr = np.asarray(img, dtype=np.float32) / 255.0
        return torch.from_numpy(arr).permute(2, 0, 1).contiguous()

    def augment_pair(self, lr: Image.Image, hr: Image.Image, index: int) -> tuple[Image.Image, Image.Image]:
        rng = random.Random((self.seed * 1_000_003) + (self.epoch * 9_973) + index)
        width, height = lr.size
        patch = self.patch_size
        if width < patch or height < patch:
            lr = lr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            hr = hr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            width, height = lr.size
        left = rng.randint(0, width - patch)
        top = rng.randint(0, height - patch)
        box = (left, top, left + patch, top + patch)
        lr = lr.crop(box)
        hr = hr.crop(box)
        if rng.random() < 0.5:
            lr = lr.transpose(FLIP_LEFT_RIGHT)
            hr = hr.transpose(FLIP_LEFT_RIGHT)
        if rng.random() < 0.5:
            lr = lr.transpose(FLIP_TOP_BOTTOM)
            hr = hr.transpose(FLIP_TOP_BOTTOM)
        rot = rng.choice([0, 1, 2, 3])
        if rot:
            rotate_ops = [ROTATE_90, ROTATE_180, ROTATE_270]
            lr = lr.transpose(rotate_ops[rot - 1])
            hr = hr.transpose(rotate_ops[rot - 1])
        return lr, hr

    def __len__(self) -> int:
        return len(self.pairs)

    def __getitem__(self, index: int) -> dict[str, Any]:
        lr_path, hr_path, name = self.pairs[index]
        lr = Image.open(lr_path).convert('RGB')
        hr = Image.open(hr_path).convert('RGB')
        if self.train:
            lr, hr = self.augment_pair(lr, hr, index)
        elif lr.size != (self.eval_size, self.eval_size):
            lr = lr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            hr = hr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
        return {'lr': self.to_tensor(lr), 'hr': self.to_tensor(hr), 'name': name}

train_pairs, val_pairs = collect_all_pairs(data_root)
if not train_pairs:
    raise FileNotFoundError(f'No training pairs found under {data_root}')
if not val_pairs:
    raise FileNotFoundError(f'No validation pairs found under {data_root}')

train_ds = PairedSRDataset(train_pairs, train=True, patch_size=cfg.train_patch_size, eval_size=cfg.eval_size, seed=cfg.seed)
val_ds = PairedSRDataset(val_pairs, train=False, patch_size=cfg.train_patch_size, eval_size=cfg.eval_size, seed=cfg.seed)

loader_num_workers = int(cfg.num_workers or 0)
train_loader_kwargs = {'dataset': train_ds, 'batch_size': cfg.batch_size, 'shuffle': True, 'num_workers': loader_num_workers, 'pin_memory': device.type == 'cuda'}
val_loader_kwargs = {'dataset': val_ds, 'batch_size': 1, 'shuffle': False, 'num_workers': loader_num_workers, 'pin_memory': device.type == 'cuda'}
if loader_num_workers > 0:
    train_loader_kwargs['persistent_workers'] = True
    val_loader_kwargs['persistent_workers'] = True
    train_loader_kwargs['prefetch_factor'] = cfg.prefetch_factor
    val_loader_kwargs['prefetch_factor'] = cfg.prefetch_factor

train_loader = DataLoader(**train_loader_kwargs)
val_loader = DataLoader(**val_loader_kwargs)

sample = train_ds[0]
print({
    'data_root': str(data_root),
    'train_pairs': len(train_pairs),
    'val_pairs': len(val_pairs),
    'train_preview': [name for _, _, name in train_pairs[:5]],
    'val_preview': [name for _, _, name in val_pairs[:5]],
    'sample_lr_shape': tuple(sample['lr'].shape),
    'sample_hr_shape': tuple(sample['hr'].shape),
})
assert tuple(sample['lr'].shape) == (3, cfg.eval_size, cfg.eval_size)
assert tuple(sample['hr'].shape) == (3, cfg.eval_size, cfg.eval_size)
# Out:
# {'data_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/Data', 'train_pairs': 2217, 'val_pairs': 110, 'train_preview': ['L3_HR_train1/0000', 'L3_HR_train1/0001', 'L3_HR_train1/00010', 'L3_HR_train1/000100', 'L3_HR_train1/000101'], 'val_preview': ['0000', '00010', '000100', '000102', '000104'], 'sample_lr_shape': (3, 256, 256), 'sample_hr_shape': (3, 256, 256)}

# %% [markdown]
# ## 4. Model

# %%
class FSRCNNResidualNoUpscale(nn.Module):
    def __init__(self, channels: int = 96, shrink_channels: int = 40, mapping_layers: int = 8, slope: float = 0.10):
        super().__init__()
        self.channels = channels
        self.shrink_channels = shrink_channels
        self.mapping_layers = mapping_layers
        self.slope = slope

        # Keep this one Sequential so checkpoint keys stay compatible with earlier runs.
        self.features = nn.Sequential(*self._feature_layers())
        self.tail = nn.Conv2d(channels, 3, 3, padding=1, bias=True)
        self.init_tail_small()

    def _activation(self) -> nn.Module:
        return nn.LeakyReLU(self.slope, inplace=False)

    def _feature_layers(self) -> list[nn.Module]:
        stem = [
            nn.Conv2d(3, self.channels, 5, padding=2, bias=True),
            self._activation(),
        ]
        shrink = [
            nn.Conv2d(self.channels, self.shrink_channels, 1, padding=0, bias=True),
            self._activation(),
        ]
        mapping: list[nn.Module] = []
        for _ in range(self.mapping_layers):
            mapping.extend([
                nn.Conv2d(self.shrink_channels, self.shrink_channels, 3, padding=1, bias=True),
                self._activation(),
            ])
        expand = [
            nn.Conv2d(self.shrink_channels, self.channels, 1, padding=0, bias=True),
            self._activation(),
        ]
        return [*stem, *shrink, *mapping, *expand]

    def architecture_summary(self) -> dict[str, str | int]:
        return {
            'stem': f'Conv5x5 3->{self.channels} + LeakyReLU',
            'shrink': f'Conv1x1 {self.channels}->{self.shrink_channels} + LeakyReLU',
            'mapping': f'{self.mapping_layers}x Conv3x3 {self.shrink_channels}->{self.shrink_channels} + LeakyReLU',
            'expand': f'Conv1x1 {self.shrink_channels}->{self.channels} + LeakyReLU',
            'tail': f'Conv3x3 {self.channels}->3 predicts residual delta',
            'forward': 'output = input + tail(features(input))',
        }

    def init_tail_small(self) -> None:
        nn.init.kaiming_normal_(self.tail.weight, nonlinearity='linear')
        self.tail.weight.data.mul_(1e-3)
        if self.tail.bias is not None:
            nn.init.zeros_(self.tail.bias)

    def predict_delta(self, x: torch.Tensor) -> torch.Tensor:
        return self.tail(self.features(x))

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return x + self.predict_delta(x)


def count_parameters(module: nn.Module) -> int:
    return int(sum(param.numel() for param in module.parameters()))


def operator_audit(module: nn.Module) -> dict[str, int]:
    counts: dict[str, int] = {}
    for child in module.modules():
        if len(list(child.children())) != 0:
            continue
        name = child.__class__.__name__
        counts[name] = counts.get(name, 0) + 1
    return dict(sorted(counts.items()))

model = FSRCNNResidualNoUpscale().to(device)
eval_model = FSRCNNResidualNoUpscale().to(device)
param_count = count_parameters(model)
op_counts = operator_audit(model)
dummy = torch.zeros(1, 3, cfg.eval_size, cfg.eval_size, device=device)
with torch.no_grad():
    dummy_out = model(dummy)

print({
    'model_id': cfg.model_id,
    'params': param_count,
    'operator_audit': op_counts,
    'input_shape': tuple(dummy.shape),
    'output_shape': tuple(dummy_out.shape),
    'architecture': model.architecture_summary(),
})
assert param_count == 133_227, param_count
assert tuple(dummy_out.shape) == (1, 3, cfg.eval_size, cfg.eval_size)
assert set(op_counts).issubset({'Conv2d', 'LeakyReLU'}), op_counts
# Out:
# {'model_id': 'fsrcnn_residual_96_40_m8', 'params': 133227, 'operator_audit': {'Conv2d': 12, 'LeakyReLU': 11}, 'input_shape': (1, 3, 256, 256), 'output_shape': (1, 3, 256, 256), 'architecture': {'stem': 'Conv5x5 3->96 + LeakyReLU', 'shrink': 'Conv1x1 96->40 + LeakyReLU', 'mapping': '8x Conv3x3 40->40 + LeakyReLU', 'expand': 'Conv1x1 40->96 + LeakyReLU', 'tail': 'Conv3x3 96->3 predicts residual delta', 'forward': 'output = input + tail(features(input))'}}

# %% [markdown]
# ## 5. Training And Validation
#
# Train with AMP, EMA, AdamW, cosine learning rate decay, PSNR validation, checkpointing, and validation previews.

# %%
class EMA:
    def __init__(self, model: nn.Module, decay: float):
        self.decay = decay
        self.shadow = {k: v.detach().clone() for k, v in model.state_dict().items()}

    @torch.no_grad()
    def update(self, model: nn.Module) -> None:
        for key, value in model.state_dict().items():
            self.shadow[key].mul_(self.decay).add_(value.detach(), alpha=1.0 - self.decay)

    @torch.no_grad()
    def copy_to(self, model: nn.Module) -> None:
        model.load_state_dict(self.shadow, strict=True)


def make_grad_scaler(enabled: bool):
    if hasattr(torch, 'amp') and hasattr(torch.amp, 'GradScaler'):
        return torch.amp.GradScaler('cuda', enabled=enabled)
    return torch.cuda.amp.GradScaler(enabled=enabled)


def autocast_context(device_type: str, enabled: bool):
    if not enabled:
        return nullcontext()
    if hasattr(torch, 'amp') and hasattr(torch.amp, 'autocast'):
        return torch.amp.autocast(device_type=device_type, enabled=enabled)
    return torch.cuda.amp.autocast(enabled=enabled)


@torch.no_grad()
def batch_psnr(pred: torch.Tensor, target: torch.Tensor) -> float:
    mse = F.mse_loss(pred, target, reduction='none').mean(dim=(1, 2, 3))
    psnr = 10.0 * torch.log10(1.0 / torch.clamp(mse, min=1e-12))
    return float(psnr.mean().item())


def compute_loss(pred: torch.Tensor, lr: torch.Tensor, hr: torch.Tensor) -> torch.Tensor:
    mse = F.mse_loss(pred, hr)
    residual_l1 = F.l1_loss(pred - lr, hr - lr)
    return 0.8 * mse + 0.2 * residual_l1


def lr_at_epoch(epoch_idx: int, *, base_lr: float, min_lr: float, warmup_epochs: int, total_epochs: int) -> float:
    step = epoch_idx + 1
    if warmup_epochs > 0 and step <= warmup_epochs:
        return base_lr * step / max(1, warmup_epochs)
    progress = max(0.0, (step - warmup_epochs) / max(1, total_epochs - warmup_epochs))
    cosine = 0.5 * (1.0 + math.cos(math.pi * min(progress, 1.0)))
    return min_lr + cosine * (base_lr - min_lr)


@torch.inference_mode()
def evaluate_metrics(model: nn.Module, loader: DataLoader, device: torch.device) -> dict[str, float]:
    model.eval()
    pred_meter = 0.0
    input_meter = 0.0
    count = 0
    for batch in loader:
        lr = batch['lr'].to(device, non_blocking=(device.type == 'cuda'))
        hr = batch['hr'].to(device, non_blocking=(device.type == 'cuda'))
        pred = model(lr).clamp(0.0, 1.0)
        pred_meter += batch_psnr(pred, hr)
        input_meter += batch_psnr(lr, hr)
        count += 1
    val_psnr = pred_meter / max(count, 1)
    input_psnr = input_meter / max(count, 1)
    return {'val_psnr': float(val_psnr), 'input_psnr': float(input_psnr), 'delta_psnr': float(val_psnr - input_psnr)}


def tensor_to_uint8_image(x: torch.Tensor) -> Image.Image:
    x = x.detach().cpu().clamp(0.0, 1.0)
    arr = (x.permute(1, 2, 0).numpy() * 255.0).round().astype(np.uint8)
    return Image.fromarray(arr)


@torch.no_grad()
def write_val_preview(model: nn.Module, loader: DataLoader, out_dir: Path, device: torch.device) -> dict[str, str]:
    out_dir.mkdir(parents=True, exist_ok=True)
    batch = next(iter(loader))
    lr = batch['lr'].to(device, non_blocking=(device.type == 'cuda'))
    hr = batch['hr'].to(device, non_blocking=(device.type == 'cuda'))
    pred = model(lr).clamp(0.0, 1.0)
    name = batch['name'][0]
    lr_path = out_dir / 'val_preview_input.png'
    pred_path = out_dir / 'val_preview_pred.png'
    hr_path = out_dir / 'val_preview_target.png'
    tensor_to_uint8_image(lr[0]).save(lr_path)
    tensor_to_uint8_image(pred[0]).save(pred_path)
    tensor_to_uint8_image(hr[0]).save(hr_path)
    return {'sample_name': str(name), 'input': str(lr_path), 'prediction': str(pred_path), 'target': str(hr_path)}


def checkpoint_payload(model: nn.Module, ema: EMA | None, optimizer: torch.optim.Optimizer, epoch: int, best_val_psnr: float, row: dict[str, Any]) -> dict[str, Any]:
    return {
        'config': asdict(cfg),
        'epoch': int(epoch),
        'model_state_dict': model.state_dict(),
        'ema_state_dict': ema.shadow if ema is not None else None,
        'optimizer_state_dict': optimizer.state_dict(),
        'best_val_psnr': float(best_val_psnr),
        'latest_metrics': row,
        'model_params': param_count,
        'operator_audit': op_counts,
    }


def load_checkpoint_for_eval(checkpoint_path: Path, device: torch.device) -> nn.Module:
    checkpoint = torch.load(checkpoint_path, map_location=device)
    loaded = FSRCNNResidualNoUpscale().to(device)
    state = checkpoint.get('ema_state_dict') or checkpoint['model_state_dict']
    loaded.load_state_dict(state, strict=True)
    loaded.eval()
    return loaded

optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)
scaler = make_grad_scaler(cfg.use_amp and device.type == 'cuda')
ema = EMA(model, cfg.ema_decay) if cfg.use_ema else None
best_val_psnr = float('-inf')
start_epoch = 0

metrics_header = ['epoch', 'epoch_time_sec', 'lr', 'train_loss', 'train_psnr', 'val_psnr', 'input_psnr', 'delta_psnr', 'best_val_psnr']
best_ckpt_path = checkpoints_dir / 'best.pth'
last_ckpt_path = checkpoints_dir / 'last.pth'

if cfg.enable_resume:
    if cfg.resume_checkpoint_path is None:
        raise ValueError('cfg.enable_resume=True requires cfg.resume_checkpoint_path')
    resume_checkpoint_path = Path(cfg.resume_checkpoint_path)
    if not resume_checkpoint_path.exists():
        raise FileNotFoundError(f'Resume checkpoint not found: {resume_checkpoint_path}')
    resume_checkpoint = torch.load(resume_checkpoint_path, map_location=device)
    model.load_state_dict(resume_checkpoint['model_state_dict'], strict=True)
    if 'optimizer_state_dict' in resume_checkpoint:
        optimizer.load_state_dict(resume_checkpoint['optimizer_state_dict'])
    if ema is not None and resume_checkpoint.get('ema_state_dict') is not None:
        ema.shadow = {key: value.detach().clone().to(device) for key, value in resume_checkpoint['ema_state_dict'].items()}
    best_val_psnr = float(resume_checkpoint.get('best_val_psnr', best_val_psnr))
    start_epoch = int(resume_checkpoint.get('epoch', 0))
    print({
        'resume_checkpoint_path': str(resume_checkpoint_path),
        'resumed_from_epoch': start_epoch,
        'target_total_epochs': cfg.epochs,
        'best_val_psnr': best_val_psnr,
    })

if start_epoch >= cfg.epochs:
    raise ValueError(f'Resume checkpoint epoch {start_epoch} is already >= target epochs {cfg.epochs}')

with metrics_csv_path.open('w', newline='', encoding='utf-8') as f:
    csv.DictWriter(f, fieldnames=metrics_header).writeheader()

for epoch in range(start_epoch, cfg.epochs):
    train_ds.set_epoch(epoch)
    epoch_lr = lr_at_epoch(epoch, base_lr=cfg.lr, min_lr=cfg.min_lr, warmup_epochs=cfg.warmup_epochs, total_epochs=cfg.epochs)
    for group in optimizer.param_groups:
        group['lr'] = epoch_lr

    epoch_start = time.time()
    model.train()
    train_loss_sum = 0.0
    train_psnr_sum = 0.0
    train_batches = 0

    for batch in train_loader:
        lr = batch['lr'].to(device, non_blocking=(device.type == 'cuda'))
        hr = batch['hr'].to(device, non_blocking=(device.type == 'cuda'))
        optimizer.zero_grad(set_to_none=True)
        with autocast_context(device.type, enabled=(cfg.use_amp and device.type == 'cuda')):
            pred = model(lr)
            loss = compute_loss(pred, lr, hr)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        if ema is not None:
            ema.update(model)
        train_loss_sum += float(loss.item())
        train_psnr_sum += batch_psnr(pred.detach().clamp(0.0, 1.0), hr)
        train_batches += 1

    if ema is not None:
        ema.copy_to(eval_model)
    else:
        eval_model.load_state_dict(model.state_dict())
    eval_model.eval()

    avg_train_loss = train_loss_sum / max(train_batches, 1)
    avg_train_psnr = train_psnr_sum / max(train_batches, 1)
    val_metrics = evaluate_metrics(eval_model, val_loader, device)
    is_best = val_metrics['val_psnr'] > best_val_psnr
    if is_best:
        best_val_psnr = val_metrics['val_psnr']
    row = {
        'epoch': epoch + 1,
        'epoch_time_sec': round(time.time() - epoch_start, 2),
        'lr': epoch_lr,
        'train_loss': round(avg_train_loss, 6),
        'train_psnr': round(avg_train_psnr, 4),
        'val_psnr': round(val_metrics['val_psnr'], 4),
        'input_psnr': round(val_metrics['input_psnr'], 4),
        'delta_psnr': round(val_metrics['delta_psnr'], 4),
        'best_val_psnr': round(best_val_psnr, 4),
    }
    print(row)
    with metrics_csv_path.open('a', newline='', encoding='utf-8') as f:
        csv.DictWriter(f, fieldnames=metrics_header).writerow(row)
    payload = checkpoint_payload(model, ema, optimizer, epoch + 1, best_val_psnr, row)
    torch.save(payload, last_ckpt_path)
    if is_best:
        torch.save(payload, best_ckpt_path)
# Out:
# {'resume_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/232518_2504_fsrcnn_residual_96_40_m8/checkpoints/last.pth', 'resumed_from_epoch': 797, 'target_total_epochs': 1750, 'best_val_psnr': 23.973237471147016}
# {'epoch': 798, 'epoch_time_sec': 111.77, 'lr': 5.770520386714073e-05, 'train_loss': 0.011692, 'train_psnr': 25.095, 'val_psnr': 23.9733, 'input_psnr': 23.1331, 'delta_psnr': 0.8402, 'best_val_psnr': 23.9733}
# {'epoch': 799, 'epoch_time_sec': 82.95, 'lr': 5.761687268850723e-05, 'train_loss': 0.01168, 'train_psnr': 25.1004, 'val_psnr': 23.9738, 'input_psnr': 23.1331, 'delta_psnr': 0.8407, 'best_val_psnr': 23.9738}
# {'epoch': 800, 'epoch_time_sec': 83.0, 'lr': 5.752851836299038e-05, 'train_loss': 0.011679, 'train_psnr': 25.1028, 'val_psnr': 23.9743, 'input_psnr': 23.1331, 'delta_psnr': 0.8412, 'best_val_psnr': 23.9743}
# {'epoch': 801, 'epoch_time_sec': 83.23, 'lr': 5.744014117795336e-05, 'train_loss': 0.011679, 'train_psnr': 25.1018, 'val_psnr': 23.9748, 'input_psnr': 23.1331, 'delta_psnr': 0.8417, 'best_val_psnr': 23.9748}
# {'epoch': 802, 'epoch_time_sec': 83.1, 'lr': 5.735174142083368e-05, 'train_loss': 0.011676, 'train_psnr': 25.1033, 'val_psnr': 23.9752, 'input_psnr': 23.1331, 'delta_psnr': 0.8421, 'best_val_psnr': 23.9752}
# {'epoch': 803, 'epoch_time_sec': 82.73, 'lr': 5.726331937914235e-05, 'train_loss': 0.011698, 'train_psnr': 25.0942, 'val_psnr': 23.9757, 'input_psnr': 23.1331, 'delta_psnr': 0.8427, 'best_val_psnr': 23.9757}
# {'epoch': 804, 'epoch_time_sec': 83.03, 'lr': 5.7174875340462784e-05, 'train_loss': 0.011674, 'train_psnr': 25.1037, 'val_psnr': 23.976, 'input_psnr': 23.1331, 'delta_psnr': 0.843, 'best_val_psnr': 23.976}
# {'epoch': 805, 'epoch_time_sec': 83.1, 'lr': 5.708640959244996e-05, 'train_loss': 0.011674, 'train_psnr': 25.106, 'val_psnr': 23.9765, 'input_psnr': 23.1331, 'delta_psnr': 0.8435, 'best_val_psnr': 23.9765}
# {'epoch': 806, 'epoch_time_sec': 82.92, 'lr': 5.699792242282944e-05, 'train_loss': 0.011691, 'train_psnr': 25.0996, 'val_psnr': 23.9768, 'input_psnr': 23.1331, 'delta_psnr': 0.8438, 'best_val_psnr': 23.9768}
# {'epoch': 807, 'epoch_time_sec': 82.94, 'lr': 5.6909414119396496e-05, 'train_loss': 0.011676, 'train_psnr': 25.105, 'val_psnr': 23.9772, 'input_psnr': 23.1331, 'delta_psnr': 0.8441, 'best_val_psnr': 23.9772}
# {'epoch': 808, 'epoch_time_sec': 83.26, 'lr': 5.682088497001514e-05, 'train_loss': 0.011669, 'train_psnr': 25.1087, 'val_psnr': 23.9774, 'input_psnr': 23.1331, 'delta_psnr': 0.8444, 'best_val_psnr': 23.9774}
# {'epoch': 809, 'epoch_time_sec': 83.07, 'lr': 5.673233526261713e-05, 'train_loss': 0.011681, 'train_psnr': 25.102, 'val_psnr': 23.9777, 'input_psnr': 23.1331, 'delta_psnr': 0.8446, 'best_val_psnr': 23.9777}
# {'epoch': 810, 'epoch_time_sec': 82.9, 'lr': 5.6643765285201135e-05, 'train_loss': 0.011685, 'train_psnr': 25.0993, 'val_psnr': 23.978, 'input_psnr': 23.1331, 'delta_psnr': 0.8449, 'best_val_psnr': 23.978}
# {'epoch': 811, 'epoch_time_sec': 83.07, 'lr': 5.6555175325831744e-05, 'train_loss': 0.011678, 'train_psnr': 25.1028, 'val_psnr': 23.9783, 'input_psnr': 23.1331, 'delta_psnr': 0.8452, 'best_val_psnr': 23.9783}
# {'epoch': 812, 'epoch_time_sec': 83.64, 'lr': 5.646656567263849e-05, 'train_loss': 0.011683, 'train_psnr': 25.1006, 'val_psnr': 23.9784, 'input_psnr': 23.1331, 'delta_psnr': 0.8453, 'best_val_psnr': 23.9784}
# {'epoch': 813, 'epoch_time_sec': 83.13, 'lr': 5.6377936613815035e-05, 'train_loss': 0.011678, 'train_psnr': 25.103, 'val_psnr': 23.9786, 'input_psnr': 23.1331, 'delta_psnr': 0.8456, 'best_val_psnr': 23.9786}
# {'epoch': 814, 'epoch_time_sec': 83.15, 'lr': 5.628928843761809e-05, 'train_loss': 0.01167, 'train_psnr': 25.1066, 'val_psnr': 23.9788, 'input_psnr': 23.1331, 'delta_psnr': 0.8458, 'best_val_psnr': 23.9788}
# {'epoch': 815, 'epoch_time_sec': 82.77, 'lr': 5.620062143236657e-05, 'train_loss': 0.011669, 'train_psnr': 25.1078, 'val_psnr': 23.979, 'input_psnr': 23.1331, 'delta_psnr': 0.8459, 'best_val_psnr': 23.979}
# {'epoch': 816, 'epoch_time_sec': 83.16, 'lr': 5.611193588644063e-05, 'train_loss': 0.011671, 'train_psnr': 25.11, 'val_psnr': 23.9793, 'input_psnr': 23.1331, 'delta_psnr': 0.8462, 'best_val_psnr': 23.9793}
# {'epoch': 817, 'epoch_time_sec': 83.18, 'lr': 5.602323208828072e-05, 'train_loss': 0.011682, 'train_psnr': 25.1018, 'val_psnr': 23.9796, 'input_psnr': 23.1331, 'delta_psnr': 0.8465, 'best_val_psnr': 23.9796}
# {'epoch': 818, 'epoch_time_sec': 83.1, 'lr': 5.5934510326386676e-05, 'train_loss': 0.011674, 'train_psnr': 25.1056, 'val_psnr': 23.9795, 'input_psnr': 23.1331, 'delta_psnr': 0.8464, 'best_val_psnr': 23.9796}
# {'epoch': 819, 'epoch_time_sec': 83.01, 'lr': 5.5845770889316715e-05, 'train_loss': 0.01167, 'train_psnr': 25.1071, 'val_psnr': 23.9798, 'input_psnr': 23.1331, 'delta_psnr': 0.8468, 'best_val_psnr': 23.9798}
# {'epoch': 820, 'epoch_time_sec': 82.97, 'lr': 5.575701406568658e-05, 'train_loss': 0.011671, 'train_psnr': 25.1092, 'val_psnr': 23.9799, 'input_psnr': 23.1331, 'delta_psnr': 0.8469, 'best_val_psnr': 23.9799}
# {'epoch': 821, 'epoch_time_sec': 83.2, 'lr': 5.566824014416855e-05, 'train_loss': 0.011675, 'train_psnr': 25.1066, 'val_psnr': 23.9801, 'input_psnr': 23.1331, 'delta_psnr': 0.847, 'best_val_psnr': 23.9801}
# {'epoch': 822, 'epoch_time_sec': 83.1, 'lr': 5.55794494134905e-05, 'train_loss': 0.011671, 'train_psnr': 25.1054, 'val_psnr': 23.9802, 'input_psnr': 23.1331, 'delta_psnr': 0.8471, 'best_val_psnr': 23.9802}
# {'epoch': 823, 'epoch_time_sec': 82.97, 'lr': 5.549064216243498e-05, 'train_loss': 0.011689, 'train_psnr': 25.1017, 'val_psnr': 23.9803, 'input_psnr': 23.1331, 'delta_psnr': 0.8472, 'best_val_psnr': 23.9803}
# {'epoch': 824, 'epoch_time_sec': 82.95, 'lr': 5.540181867983832e-05, 'train_loss': 0.011669, 'train_psnr': 25.1079, 'val_psnr': 23.9804, 'input_psnr': 23.1331, 'delta_psnr': 0.8473, 'best_val_psnr': 23.9804}
# {'epoch': 825, 'epoch_time_sec': 82.95, 'lr': 5.531297925458955e-05, 'train_loss': 0.011663, 'train_psnr': 25.1127, 'val_psnr': 23.9805, 'input_psnr': 23.1331, 'delta_psnr': 0.8474, 'best_val_psnr': 23.9805}
# {'epoch': 826, 'epoch_time_sec': 83.1, 'lr': 5.522412417562962e-05, 'train_loss': 0.01167, 'train_psnr': 25.1093, 'val_psnr': 23.9807, 'input_psnr': 23.1331, 'delta_psnr': 0.8477, 'best_val_psnr': 23.9807}
# {'epoch': 827, 'epoch_time_sec': 83.23, 'lr': 5.5135253731950374e-05, 'train_loss': 0.01166, 'train_psnr': 25.1158, 'val_psnr': 23.9807, 'input_psnr': 23.1331, 'delta_psnr': 0.8477, 'best_val_psnr': 23.9807}
# {'epoch': 828, 'epoch_time_sec': 83.0, 'lr': 5.504636821259361e-05, 'train_loss': 0.011682, 'train_psnr': 25.1034, 'val_psnr': 23.9809, 'input_psnr': 23.1331, 'delta_psnr': 0.8479, 'best_val_psnr': 23.9809}
# {'epoch': 829, 'epoch_time_sec': 82.76, 'lr': 5.4957467906650196e-05, 'train_loss': 0.011695, 'train_psnr': 25.0994, 'val_psnr': 23.9811, 'input_psnr': 23.1331, 'delta_psnr': 0.848, 'best_val_psnr': 23.9811}
# {'epoch': 830, 'epoch_time_sec': 83.06, 'lr': 5.486855310325906e-05, 'train_loss': 0.011681, 'train_psnr': 25.1035, 'val_psnr': 23.9812, 'input_psnr': 23.1331, 'delta_psnr': 0.8481, 'best_val_psnr': 23.9812}
# {'epoch': 831, 'epoch_time_sec': 82.88, 'lr': 5.4779624091606294e-05, 'train_loss': 0.011658, 'train_psnr': 25.1156, 'val_psnr': 23.9812, 'input_psnr': 23.1331, 'delta_psnr': 0.8482, 'best_val_psnr': 23.9812}
# {'epoch': 832, 'epoch_time_sec': 82.97, 'lr': 5.469068116092419e-05, 'train_loss': 0.01167, 'train_psnr': 25.1069, 'val_psnr': 23.9812, 'input_psnr': 23.1331, 'delta_psnr': 0.8481, 'best_val_psnr': 23.9812}
# {'epoch': 833, 'epoch_time_sec': 83.03, 'lr': 5.4601724600490335e-05, 'train_loss': 0.011665, 'train_psnr': 25.1107, 'val_psnr': 23.9814, 'input_psnr': 23.1331, 'delta_psnr': 0.8483, 'best_val_psnr': 23.9814}
# {'epoch': 834, 'epoch_time_sec': 83.23, 'lr': 5.451275469962662e-05, 'train_loss': 0.011681, 'train_psnr': 25.1043, 'val_psnr': 23.9815, 'input_psnr': 23.1331, 'delta_psnr': 0.8485, 'best_val_psnr': 23.9815}
# {'epoch': 835, 'epoch_time_sec': 83.26, 'lr': 5.4423771747698323e-05, 'train_loss': 0.011663, 'train_psnr': 25.1131, 'val_psnr': 23.9816, 'input_psnr': 23.1331, 'delta_psnr': 0.8486, 'best_val_psnr': 23.9816}
# {'epoch': 836, 'epoch_time_sec': 83.11, 'lr': 5.433477603411321e-05, 'train_loss': 0.011664, 'train_psnr': 25.1109, 'val_psnr': 23.9817, 'input_psnr': 23.1331, 'delta_psnr': 0.8487, 'best_val_psnr': 23.9817}
# {'epoch': 837, 'epoch_time_sec': 83.08, 'lr': 5.424576784832049e-05, 'train_loss': 0.011673, 'train_psnr': 25.1068, 'val_psnr': 23.9819, 'input_psnr': 23.1331, 'delta_psnr': 0.8488, 'best_val_psnr': 23.9819}
# {'epoch': 838, 'epoch_time_sec': 83.0, 'lr': 5.415674747980999e-05, 'train_loss': 0.011657, 'train_psnr': 25.1157, 'val_psnr': 23.982, 'input_psnr': 23.1331, 'delta_psnr': 0.8489, 'best_val_psnr': 23.982}
# {'epoch': 839, 'epoch_time_sec': 82.98, 'lr': 5.4067715218111125e-05, 'train_loss': 0.011668, 'train_psnr': 25.1104, 'val_psnr': 23.9821, 'input_psnr': 23.1331, 'delta_psnr': 0.8491, 'best_val_psnr': 23.9821}
# {'epoch': 840, 'epoch_time_sec': 83.29, 'lr': 5.3978671352792e-05, 'train_loss': 0.011656, 'train_psnr': 25.1156, 'val_psnr': 23.9823, 'input_psnr': 23.1331, 'delta_psnr': 0.8493, 'best_val_psnr': 23.9823}
# {'epoch': 841, 'epoch_time_sec': 82.98, 'lr': 5.38896161734585e-05, 'train_loss': 0.011679, 'train_psnr': 25.1056, 'val_psnr': 23.9825, 'input_psnr': 23.1331, 'delta_psnr': 0.8494, 'best_val_psnr': 23.9825}
# {'epoch': 842, 'epoch_time_sec': 83.07, 'lr': 5.380054996975323e-05, 'train_loss': 0.011664, 'train_psnr': 25.1109, 'val_psnr': 23.9825, 'input_psnr': 23.1331, 'delta_psnr': 0.8494, 'best_val_psnr': 23.9825}
# {'epoch': 843, 'epoch_time_sec': 83.02, 'lr': 5.371147303135473e-05, 'train_loss': 0.011665, 'train_psnr': 25.1104, 'val_psnr': 23.9825, 'input_psnr': 23.1331, 'delta_psnr': 0.8494, 'best_val_psnr': 23.9825}
# {'epoch': 844, 'epoch_time_sec': 83.12, 'lr': 5.362238564797638e-05, 'train_loss': 0.011667, 'train_psnr': 25.108, 'val_psnr': 23.9826, 'input_psnr': 23.1331, 'delta_psnr': 0.8496, 'best_val_psnr': 23.9826}
# {'epoch': 845, 'epoch_time_sec': 83.05, 'lr': 5.353328810936561e-05, 'train_loss': 0.01167, 'train_psnr': 25.1085, 'val_psnr': 23.9827, 'input_psnr': 23.1331, 'delta_psnr': 0.8497, 'best_val_psnr': 23.9827}
# {'epoch': 846, 'epoch_time_sec': 83.02, 'lr': 5.3444180705302805e-05, 'train_loss': 0.011679, 'train_psnr': 25.1046, 'val_psnr': 23.9829, 'input_psnr': 23.1331, 'delta_psnr': 0.8498, 'best_val_psnr': 23.9829}
# {'epoch': 847, 'epoch_time_sec': 83.11, 'lr': 5.3355063725600466e-05, 'train_loss': 0.011673, 'train_psnr': 25.1083, 'val_psnr': 23.9831, 'input_psnr': 23.1331, 'delta_psnr': 0.85, 'best_val_psnr': 23.9831}
# {'epoch': 848, 'epoch_time_sec': 83.07, 'lr': 5.3265937460102255e-05, 'train_loss': 0.011657, 'train_psnr': 25.1157, 'val_psnr': 23.9831, 'input_psnr': 23.1331, 'delta_psnr': 0.8501, 'best_val_psnr': 23.9831}
# {'epoch': 849, 'epoch_time_sec': 82.96, 'lr': 5.3176802198682035e-05, 'train_loss': 0.011657, 'train_psnr': 25.1167, 'val_psnr': 23.9833, 'input_psnr': 23.1331, 'delta_psnr': 0.8502, 'best_val_psnr': 23.9833}
# {'epoch': 850, 'epoch_time_sec': 82.94, 'lr': 5.308765823124289e-05, 'train_loss': 0.011664, 'train_psnr': 25.1109, 'val_psnr': 23.9834, 'input_psnr': 23.1331, 'delta_psnr': 0.8504, 'best_val_psnr': 23.9834}
# {'epoch': 851, 'epoch_time_sec': 83.1, 'lr': 5.2998505847716236e-05, 'train_loss': 0.011652, 'train_psnr': 25.118, 'val_psnr': 23.9836, 'input_psnr': 23.1331, 'delta_psnr': 0.8505, 'best_val_psnr': 23.9836}
# {'epoch': 852, 'epoch_time_sec': 82.97, 'lr': 5.290934533806087e-05, 'train_loss': 0.011667, 'train_psnr': 25.1086, 'val_psnr': 23.9838, 'input_psnr': 23.1331, 'delta_psnr': 0.8507, 'best_val_psnr': 23.9838}
# {'epoch': 853, 'epoch_time_sec': 83.3, 'lr': 5.282017699226203e-05, 'train_loss': 0.011682, 'train_psnr': 25.1058, 'val_psnr': 23.9838, 'input_psnr': 23.1331, 'delta_psnr': 0.8507, 'best_val_psnr': 23.9838}
# {'epoch': 854, 'epoch_time_sec': 83.12, 'lr': 5.273100110033043e-05, 'train_loss': 0.011655, 'train_psnr': 25.1169, 'val_psnr': 23.9839, 'input_psnr': 23.1331, 'delta_psnr': 0.8508, 'best_val_psnr': 23.9839}
# {'epoch': 855, 'epoch_time_sec': 82.96, 'lr': 5.264181795230131e-05, 'train_loss': 0.011661, 'train_psnr': 25.1126, 'val_psnr': 23.9841, 'input_psnr': 23.1331, 'delta_psnr': 0.851, 'best_val_psnr': 23.9841}
# {'epoch': 856, 'epoch_time_sec': 83.03, 'lr': 5.2552627838233504e-05, 'train_loss': 0.01166, 'train_psnr': 25.1129, 'val_psnr': 23.9841, 'input_psnr': 23.1331, 'delta_psnr': 0.851, 'best_val_psnr': 23.9841}
# {'epoch': 857, 'epoch_time_sec': 82.76, 'lr': 5.246343104820854e-05, 'train_loss': 0.011653, 'train_psnr': 25.1167, 'val_psnr': 23.9841, 'input_psnr': 23.1331, 'delta_psnr': 0.8511, 'best_val_psnr': 23.9841}
# {'epoch': 858, 'epoch_time_sec': 82.96, 'lr': 5.2374227872329665e-05, 'train_loss': 0.011665, 'train_psnr': 25.1126, 'val_psnr': 23.9843, 'input_psnr': 23.1331, 'delta_psnr': 0.8512, 'best_val_psnr': 23.9843}
# {'epoch': 859, 'epoch_time_sec': 83.66, 'lr': 5.2285018600720836e-05, 'train_loss': 0.011661, 'train_psnr': 25.1127, 'val_psnr': 23.9843, 'input_psnr': 23.1331, 'delta_psnr': 0.8512, 'best_val_psnr': 23.9843}
# {'epoch': 860, 'epoch_time_sec': 82.99, 'lr': 5.219580352352587e-05, 'train_loss': 0.011652, 'train_psnr': 25.1177, 'val_psnr': 23.9845, 'input_psnr': 23.1331, 'delta_psnr': 0.8514, 'best_val_psnr': 23.9845}
# {'epoch': 861, 'epoch_time_sec': 83.09, 'lr': 5.210658293090749e-05, 'train_loss': 0.011656, 'train_psnr': 25.1156, 'val_psnr': 23.9844, 'input_psnr': 23.1331, 'delta_psnr': 0.8514, 'best_val_psnr': 23.9845}
# {'epoch': 862, 'epoch_time_sec': 83.02, 'lr': 5.20173571130463e-05, 'train_loss': 0.01165, 'train_psnr': 25.119, 'val_psnr': 23.9846, 'input_psnr': 23.1331, 'delta_psnr': 0.8515, 'best_val_psnr': 23.9846}
# {'epoch': 863, 'epoch_time_sec': 82.95, 'lr': 5.1928126360139964e-05, 'train_loss': 0.011654, 'train_psnr': 25.1168, 'val_psnr': 23.9846, 'input_psnr': 23.1331, 'delta_psnr': 0.8515, 'best_val_psnr': 23.9846}
# {'epoch': 864, 'epoch_time_sec': 83.0, 'lr': 5.183889096240216e-05, 'train_loss': 0.011678, 'train_psnr': 25.1064, 'val_psnr': 23.9847, 'input_psnr': 23.1331, 'delta_psnr': 0.8516, 'best_val_psnr': 23.9847}
# {'epoch': 865, 'epoch_time_sec': 83.06, 'lr': 5.174965121006164e-05, 'train_loss': 0.011654, 'train_psnr': 25.1151, 'val_psnr': 23.9846, 'input_psnr': 23.1331, 'delta_psnr': 0.8516, 'best_val_psnr': 23.9847}
# {'epoch': 866, 'epoch_time_sec': 83.32, 'lr': 5.16604073933614e-05, 'train_loss': 0.011675, 'train_psnr': 25.1066, 'val_psnr': 23.9846, 'input_psnr': 23.1331, 'delta_psnr': 0.8516, 'best_val_psnr': 23.9847}
# {'epoch': 867, 'epoch_time_sec': 83.04, 'lr': 5.1571159802557585e-05, 'train_loss': 0.011656, 'train_psnr': 25.1173, 'val_psnr': 23.9848, 'input_psnr': 23.1331, 'delta_psnr': 0.8517, 'best_val_psnr': 23.9848}
# {'epoch': 868, 'epoch_time_sec': 83.01, 'lr': 5.148190872791866e-05, 'train_loss': 0.01165, 'train_psnr': 25.1199, 'val_psnr': 23.9848, 'input_psnr': 23.1331, 'delta_psnr': 0.8517, 'best_val_psnr': 23.9848}
# {'epoch': 869, 'epoch_time_sec': 83.08, 'lr': 5.139265445972438e-05, 'train_loss': 0.011656, 'train_psnr': 25.1159, 'val_psnr': 23.985, 'input_psnr': 23.1331, 'delta_psnr': 0.8519, 'best_val_psnr': 23.985}
# {'epoch': 870, 'epoch_time_sec': 82.8, 'lr': 5.130339728826493e-05, 'train_loss': 0.011657, 'train_psnr': 25.1135, 'val_psnr': 23.9851, 'input_psnr': 23.1331, 'delta_psnr': 0.8521, 'best_val_psnr': 23.9851}
# {'epoch': 871, 'epoch_time_sec': 83.0, 'lr': 5.121413750383991e-05, 'train_loss': 0.011666, 'train_psnr': 25.1133, 'val_psnr': 23.9852, 'input_psnr': 23.1331, 'delta_psnr': 0.8522, 'best_val_psnr': 23.9852}
# {'epoch': 872, 'epoch_time_sec': 83.21, 'lr': 5.112487539675741e-05, 'train_loss': 0.011659, 'train_psnr': 25.1183, 'val_psnr': 23.9854, 'input_psnr': 23.1331, 'delta_psnr': 0.8523, 'best_val_psnr': 23.9854}
# {'epoch': 873, 'epoch_time_sec': 83.26, 'lr': 5.103561125733309e-05, 'train_loss': 0.011652, 'train_psnr': 25.1179, 'val_psnr': 23.9854, 'input_psnr': 23.1331, 'delta_psnr': 0.8524, 'best_val_psnr': 23.9854}
# {'epoch': 874, 'epoch_time_sec': 83.17, 'lr': 5.0946345375889255e-05, 'train_loss': 0.01165, 'train_psnr': 25.1195, 'val_psnr': 23.9854, 'input_psnr': 23.1331, 'delta_psnr': 0.8524, 'best_val_psnr': 23.9854}
# {'epoch': 875, 'epoch_time_sec': 83.06, 'lr': 5.08570780427538e-05, 'train_loss': 0.01166, 'train_psnr': 25.1158, 'val_psnr': 23.9855, 'input_psnr': 23.1331, 'delta_psnr': 0.8524, 'best_val_psnr': 23.9855}
# {'epoch': 876, 'epoch_time_sec': 83.05, 'lr': 5.07678095482594e-05, 'train_loss': 0.011657, 'train_psnr': 25.1169, 'val_psnr': 23.9855, 'input_psnr': 23.1331, 'delta_psnr': 0.8525, 'best_val_psnr': 23.9855}
# {'epoch': 877, 'epoch_time_sec': 83.03, 'lr': 5.067854018274246e-05, 'train_loss': 0.011651, 'train_psnr': 25.1181, 'val_psnr': 23.9856, 'input_psnr': 23.1331, 'delta_psnr': 0.8526, 'best_val_psnr': 23.9856}
# {'epoch': 878, 'epoch_time_sec': 83.08, 'lr': 5.0589270236542284e-05, 'train_loss': 0.011665, 'train_psnr': 25.1118, 'val_psnr': 23.9857, 'input_psnr': 23.1331, 'delta_psnr': 0.8527, 'best_val_psnr': 23.9857}
# {'epoch': 879, 'epoch_time_sec': 83.24, 'lr': 5.05e-05, 'train_loss': 0.011653, 'train_psnr': 25.1175, 'val_psnr': 23.9857, 'input_psnr': 23.1331, 'delta_psnr': 0.8527, 'best_val_psnr': 23.9857}
# {'epoch': 880, 'epoch_time_sec': 83.06, 'lr': 5.041072976345772e-05, 'train_loss': 0.011666, 'train_psnr': 25.1115, 'val_psnr': 23.9858, 'input_psnr': 23.1331, 'delta_psnr': 0.8528, 'best_val_psnr': 23.9858}
# {'epoch': 881, 'epoch_time_sec': 83.01, 'lr': 5.032145981725754e-05, 'train_loss': 0.011662, 'train_psnr': 25.113, 'val_psnr': 23.9859, 'input_psnr': 23.1331, 'delta_psnr': 0.8529, 'best_val_psnr': 23.9859}
# {'epoch': 882, 'epoch_time_sec': 83.01, 'lr': 5.023219045174061e-05, 'train_loss': 0.011666, 'train_psnr': 25.1109, 'val_psnr': 23.9859, 'input_psnr': 23.1331, 'delta_psnr': 0.8528, 'best_val_psnr': 23.9859}
# {'epoch': 883, 'epoch_time_sec': 83.52, 'lr': 5.014292195724622e-05, 'train_loss': 0.011654, 'train_psnr': 25.1169, 'val_psnr': 23.986, 'input_psnr': 23.1331, 'delta_psnr': 0.853, 'best_val_psnr': 23.986}
# {'epoch': 884, 'epoch_time_sec': 83.09, 'lr': 5.0053654624110754e-05, 'train_loss': 0.011647, 'train_psnr': 25.1214, 'val_psnr': 23.9861, 'input_psnr': 23.1331, 'delta_psnr': 0.853, 'best_val_psnr': 23.9861}
# {'epoch': 885, 'epoch_time_sec': 83.14, 'lr': 4.99643887426669e-05, 'train_loss': 0.011654, 'train_psnr': 25.1173, 'val_psnr': 23.9861, 'input_psnr': 23.1331, 'delta_psnr': 0.853, 'best_val_psnr': 23.9861}
# {'epoch': 886, 'epoch_time_sec': 82.82, 'lr': 4.98751246032426e-05, 'train_loss': 0.011643, 'train_psnr': 25.1225, 'val_psnr': 23.9863, 'input_psnr': 23.1331, 'delta_psnr': 0.8532, 'best_val_psnr': 23.9863}
# {'epoch': 887, 'epoch_time_sec': 82.87, 'lr': 4.9785862496160096e-05, 'train_loss': 0.011671, 'train_psnr': 25.1101, 'val_psnr': 23.9864, 'input_psnr': 23.1331, 'delta_psnr': 0.8533, 'best_val_psnr': 23.9864}
# {'epoch': 888, 'epoch_time_sec': 82.92, 'lr': 4.969660271173509e-05, 'train_loss': 0.01165, 'train_psnr': 25.1196, 'val_psnr': 23.9864, 'input_psnr': 23.1331, 'delta_psnr': 0.8534, 'best_val_psnr': 23.9864}
# {'epoch': 889, 'epoch_time_sec': 83.12, 'lr': 4.960734554027563e-05, 'train_loss': 0.011662, 'train_psnr': 25.114, 'val_psnr': 23.9866, 'input_psnr': 23.1331, 'delta_psnr': 0.8535, 'best_val_psnr': 23.9866}
# {'epoch': 890, 'epoch_time_sec': 83.04, 'lr': 4.951809127208135e-05, 'train_loss': 0.011655, 'train_psnr': 25.1155, 'val_psnr': 23.9866, 'input_psnr': 23.1331, 'delta_psnr': 0.8535, 'best_val_psnr': 23.9866}
# {'epoch': 891, 'epoch_time_sec': 83.23, 'lr': 4.9428840197442424e-05, 'train_loss': 0.011658, 'train_psnr': 25.1155, 'val_psnr': 23.9866, 'input_psnr': 23.1331, 'delta_psnr': 0.8536, 'best_val_psnr': 23.9866}
# {'epoch': 892, 'epoch_time_sec': 83.19, 'lr': 4.933959260663861e-05, 'train_loss': 0.011643, 'train_psnr': 25.1232, 'val_psnr': 23.9867, 'input_psnr': 23.1331, 'delta_psnr': 0.8537, 'best_val_psnr': 23.9867}
# {'epoch': 893, 'epoch_time_sec': 83.06, 'lr': 4.925034878993837e-05, 'train_loss': 0.011644, 'train_psnr': 25.1228, 'val_psnr': 23.9868, 'input_psnr': 23.1331, 'delta_psnr': 0.8538, 'best_val_psnr': 23.9868}
# {'epoch': 894, 'epoch_time_sec': 82.76, 'lr': 4.916110903759786e-05, 'train_loss': 0.011661, 'train_psnr': 25.1123, 'val_psnr': 23.9868, 'input_psnr': 23.1331, 'delta_psnr': 0.8538, 'best_val_psnr': 23.9868}
# {'epoch': 895, 'epoch_time_sec': 83.02, 'lr': 4.9071873639860025e-05, 'train_loss': 0.011651, 'train_psnr': 25.1182, 'val_psnr': 23.9869, 'input_psnr': 23.1331, 'delta_psnr': 0.8539, 'best_val_psnr': 23.9869}
# {'epoch': 896, 'epoch_time_sec': 83.03, 'lr': 4.89826428869537e-05, 'train_loss': 0.01166, 'train_psnr': 25.1155, 'val_psnr': 23.9871, 'input_psnr': 23.1331, 'delta_psnr': 0.854, 'best_val_psnr': 23.9871}
# {'epoch': 897, 'epoch_time_sec': 82.94, 'lr': 4.889341706909252e-05, 'train_loss': 0.011667, 'train_psnr': 25.1126, 'val_psnr': 23.987, 'input_psnr': 23.1331, 'delta_psnr': 0.854, 'best_val_psnr': 23.9871}
# {'epoch': 898, 'epoch_time_sec': 83.19, 'lr': 4.880419647647414e-05, 'train_loss': 0.011658, 'train_psnr': 25.1185, 'val_psnr': 23.9871, 'input_psnr': 23.1331, 'delta_psnr': 0.8541, 'best_val_psnr': 23.9871}
# {'epoch': 899, 'epoch_time_sec': 82.98, 'lr': 4.8714981399279166e-05, 'train_loss': 0.011661, 'train_psnr': 25.1147, 'val_psnr': 23.9873, 'input_psnr': 23.1331, 'delta_psnr': 0.8542, 'best_val_psnr': 23.9873}
# {'epoch': 900, 'epoch_time_sec': 82.98, 'lr': 4.862577212767033e-05, 'train_loss': 0.011644, 'train_psnr': 25.1231, 'val_psnr': 23.9873, 'input_psnr': 23.1331, 'delta_psnr': 0.8543, 'best_val_psnr': 23.9873}
# {'epoch': 901, 'epoch_time_sec': 82.9, 'lr': 4.853656895179146e-05, 'train_loss': 0.01165, 'train_psnr': 25.1203, 'val_psnr': 23.9874, 'input_psnr': 23.1331, 'delta_psnr': 0.8543, 'best_val_psnr': 23.9874}
# {'epoch': 902, 'epoch_time_sec': 83.04, 'lr': 4.8447372161766504e-05, 'train_loss': 0.011651, 'train_psnr': 25.12, 'val_psnr': 23.9875, 'input_psnr': 23.1331, 'delta_psnr': 0.8544, 'best_val_psnr': 23.9875}
# {'epoch': 903, 'epoch_time_sec': 83.06, 'lr': 4.8358182047698714e-05, 'train_loss': 0.011649, 'train_psnr': 25.1204, 'val_psnr': 23.9875, 'input_psnr': 23.1331, 'delta_psnr': 0.8544, 'best_val_psnr': 23.9875}
# {'epoch': 904, 'epoch_time_sec': 83.25, 'lr': 4.826899889966958e-05, 'train_loss': 0.011643, 'train_psnr': 25.123, 'val_psnr': 23.9877, 'input_psnr': 23.1331, 'delta_psnr': 0.8546, 'best_val_psnr': 23.9877}
# {'epoch': 905, 'epoch_time_sec': 82.96, 'lr': 4.817982300773796e-05, 'train_loss': 0.011659, 'train_psnr': 25.1164, 'val_psnr': 23.9879, 'input_psnr': 23.1331, 'delta_psnr': 0.8548, 'best_val_psnr': 23.9879}
# {'epoch': 906, 'epoch_time_sec': 83.47, 'lr': 4.8090654661939136e-05, 'train_loss': 0.011656, 'train_psnr': 25.1175, 'val_psnr': 23.9878, 'input_psnr': 23.1331, 'delta_psnr': 0.8547, 'best_val_psnr': 23.9879}
# {'epoch': 907, 'epoch_time_sec': 83.24, 'lr': 4.800149415228377e-05, 'train_loss': 0.011647, 'train_psnr': 25.1186, 'val_psnr': 23.9878, 'input_psnr': 23.1331, 'delta_psnr': 0.8547, 'best_val_psnr': 23.9879}
# {'epoch': 908, 'epoch_time_sec': 82.85, 'lr': 4.791234176875713e-05, 'train_loss': 0.011645, 'train_psnr': 25.1229, 'val_psnr': 23.9878, 'input_psnr': 23.1331, 'delta_psnr': 0.8547, 'best_val_psnr': 23.9879}
# {'epoch': 909, 'epoch_time_sec': 83.1, 'lr': 4.7823197801317974e-05, 'train_loss': 0.011655, 'train_psnr': 25.1198, 'val_psnr': 23.988, 'input_psnr': 23.1331, 'delta_psnr': 0.8549, 'best_val_psnr': 23.988}
# {'epoch': 910, 'epoch_time_sec': 83.07, 'lr': 4.7734062539897734e-05, 'train_loss': 0.011648, 'train_psnr': 25.1206, 'val_psnr': 23.9881, 'input_psnr': 23.1331, 'delta_psnr': 0.855, 'best_val_psnr': 23.9881}
# {'epoch': 911, 'epoch_time_sec': 83.3, 'lr': 4.764493627439954e-05, 'train_loss': 0.011638, 'train_psnr': 25.1257, 'val_psnr': 23.9882, 'input_psnr': 23.1331, 'delta_psnr': 0.8551, 'best_val_psnr': 23.9882}
# {'epoch': 912, 'epoch_time_sec': 83.03, 'lr': 4.7555819294697204e-05, 'train_loss': 0.011648, 'train_psnr': 25.1209, 'val_psnr': 23.9881, 'input_psnr': 23.1331, 'delta_psnr': 0.8551, 'best_val_psnr': 23.9882}
# {'epoch': 913, 'epoch_time_sec': 83.04, 'lr': 4.7466711890634416e-05, 'train_loss': 0.011648, 'train_psnr': 25.1188, 'val_psnr': 23.9882, 'input_psnr': 23.1331, 'delta_psnr': 0.8552, 'best_val_psnr': 23.9882}
# {'epoch': 914, 'epoch_time_sec': 83.02, 'lr': 4.737761435202363e-05, 'train_loss': 0.011643, 'train_psnr': 25.1238, 'val_psnr': 23.9883, 'input_psnr': 23.1331, 'delta_psnr': 0.8553, 'best_val_psnr': 23.9883}
# {'epoch': 915, 'epoch_time_sec': 82.74, 'lr': 4.728852696864528e-05, 'train_loss': 0.011655, 'train_psnr': 25.1181, 'val_psnr': 23.9884, 'input_psnr': 23.1331, 'delta_psnr': 0.8553, 'best_val_psnr': 23.9884}
# {'epoch': 916, 'epoch_time_sec': 82.71, 'lr': 4.719945003024678e-05, 'train_loss': 0.011667, 'train_psnr': 25.1124, 'val_psnr': 23.9883, 'input_psnr': 23.1331, 'delta_psnr': 0.8552, 'best_val_psnr': 23.9884}
# {'epoch': 917, 'epoch_time_sec': 83.28, 'lr': 4.711038382654151e-05, 'train_loss': 0.011662, 'train_psnr': 25.1125, 'val_psnr': 23.9883, 'input_psnr': 23.1331, 'delta_psnr': 0.8553, 'best_val_psnr': 23.9884}
# {'epoch': 918, 'epoch_time_sec': 83.03, 'lr': 4.7021328647208015e-05, 'train_loss': 0.011641, 'train_psnr': 25.1239, 'val_psnr': 23.9884, 'input_psnr': 23.1331, 'delta_psnr': 0.8554, 'best_val_psnr': 23.9884}
# {'epoch': 919, 'epoch_time_sec': 83.02, 'lr': 4.6932284781888884e-05, 'train_loss': 0.01164, 'train_psnr': 25.1244, 'val_psnr': 23.9885, 'input_psnr': 23.1331, 'delta_psnr': 0.8554, 'best_val_psnr': 23.9885}
# {'epoch': 920, 'epoch_time_sec': 83.04, 'lr': 4.684325252019001e-05, 'train_loss': 0.011659, 'train_psnr': 25.116, 'val_psnr': 23.9885, 'input_psnr': 23.1331, 'delta_psnr': 0.8555, 'best_val_psnr': 23.9885}
# {'epoch': 921, 'epoch_time_sec': 83.01, 'lr': 4.6754232151679526e-05, 'train_loss': 0.011641, 'train_psnr': 25.1245, 'val_psnr': 23.9886, 'input_psnr': 23.1331, 'delta_psnr': 0.8555, 'best_val_psnr': 23.9886}
# {'epoch': 922, 'epoch_time_sec': 82.81, 'lr': 4.66652239658868e-05, 'train_loss': 0.011648, 'train_psnr': 25.1202, 'val_psnr': 23.9886, 'input_psnr': 23.1331, 'delta_psnr': 0.8555, 'best_val_psnr': 23.9886}
# {'epoch': 923, 'epoch_time_sec': 83.23, 'lr': 4.657622825230168e-05, 'train_loss': 0.011644, 'train_psnr': 25.1213, 'val_psnr': 23.9887, 'input_psnr': 23.1331, 'delta_psnr': 0.8556, 'best_val_psnr': 23.9887}
# {'epoch': 924, 'epoch_time_sec': 82.99, 'lr': 4.648724530037338e-05, 'train_loss': 0.011656, 'train_psnr': 25.1161, 'val_psnr': 23.9887, 'input_psnr': 23.1331, 'delta_psnr': 0.8557, 'best_val_psnr': 23.9887}
# {'epoch': 925, 'epoch_time_sec': 83.15, 'lr': 4.639827539950966e-05, 'train_loss': 0.01165, 'train_psnr': 25.1194, 'val_psnr': 23.9888, 'input_psnr': 23.1331, 'delta_psnr': 0.8557, 'best_val_psnr': 23.9888}
# {'epoch': 926, 'epoch_time_sec': 82.97, 'lr': 4.6309318839075815e-05, 'train_loss': 0.011648, 'train_psnr': 25.1225, 'val_psnr': 23.9889, 'input_psnr': 23.1331, 'delta_psnr': 0.8559, 'best_val_psnr': 23.9889}
# {'epoch': 927, 'epoch_time_sec': 82.92, 'lr': 4.6220375908393715e-05, 'train_loss': 0.011645, 'train_psnr': 25.1213, 'val_psnr': 23.9889, 'input_psnr': 23.1331, 'delta_psnr': 0.8559, 'best_val_psnr': 23.9889}
# {'epoch': 928, 'epoch_time_sec': 83.03, 'lr': 4.613144689674095e-05, 'train_loss': 0.011649, 'train_psnr': 25.1222, 'val_psnr': 23.9891, 'input_psnr': 23.1331, 'delta_psnr': 0.856, 'best_val_psnr': 23.9891}
# {'epoch': 929, 'epoch_time_sec': 82.96, 'lr': 4.6042532093349806e-05, 'train_loss': 0.01164, 'train_psnr': 25.1243, 'val_psnr': 23.9891, 'input_psnr': 23.1331, 'delta_psnr': 0.8561, 'best_val_psnr': 23.9891}
# {'epoch': 930, 'epoch_time_sec': 83.62, 'lr': 4.595363178740639e-05, 'train_loss': 0.011637, 'train_psnr': 25.1267, 'val_psnr': 23.9893, 'input_psnr': 23.1331, 'delta_psnr': 0.8562, 'best_val_psnr': 23.9893}
# {'epoch': 931, 'epoch_time_sec': 82.96, 'lr': 4.586474626804964e-05, 'train_loss': 0.011652, 'train_psnr': 25.1216, 'val_psnr': 23.9893, 'input_psnr': 23.1331, 'delta_psnr': 0.8562, 'best_val_psnr': 23.9893}
# {'epoch': 932, 'epoch_time_sec': 82.95, 'lr': 4.577587582437038e-05, 'train_loss': 0.01164, 'train_psnr': 25.1246, 'val_psnr': 23.9894, 'input_psnr': 23.1331, 'delta_psnr': 0.8563, 'best_val_psnr': 23.9894}
# {'epoch': 933, 'epoch_time_sec': 83.05, 'lr': 4.568702074541047e-05, 'train_loss': 0.011647, 'train_psnr': 25.121, 'val_psnr': 23.9892, 'input_psnr': 23.1331, 'delta_psnr': 0.8561, 'best_val_psnr': 23.9894}
# {'epoch': 934, 'epoch_time_sec': 83.04, 'lr': 4.55981813201617e-05, 'train_loss': 0.011643, 'train_psnr': 25.1249, 'val_psnr': 23.9895, 'input_psnr': 23.1331, 'delta_psnr': 0.8565, 'best_val_psnr': 23.9895}
# {'epoch': 935, 'epoch_time_sec': 83.0, 'lr': 4.550935783756501e-05, 'train_loss': 0.011658, 'train_psnr': 25.1176, 'val_psnr': 23.9896, 'input_psnr': 23.1331, 'delta_psnr': 0.8565, 'best_val_psnr': 23.9896}
# {'epoch': 936, 'epoch_time_sec': 83.28, 'lr': 4.542055058650951e-05, 'train_loss': 0.011647, 'train_psnr': 25.1229, 'val_psnr': 23.9895, 'input_psnr': 23.1331, 'delta_psnr': 0.8565, 'best_val_psnr': 23.9896}
# {'epoch': 937, 'epoch_time_sec': 82.99, 'lr': 4.533175985583145e-05, 'train_loss': 0.011648, 'train_psnr': 25.1204, 'val_psnr': 23.9897, 'input_psnr': 23.1331, 'delta_psnr': 0.8566, 'best_val_psnr': 23.9897}
# {'epoch': 938, 'epoch_time_sec': 83.05, 'lr': 4.524298593431344e-05, 'train_loss': 0.011647, 'train_psnr': 25.1233, 'val_psnr': 23.9897, 'input_psnr': 23.1331, 'delta_psnr': 0.8567, 'best_val_psnr': 23.9897}
# {'epoch': 939, 'epoch_time_sec': 83.03, 'lr': 4.51542291106833e-05, 'train_loss': 0.011645, 'train_psnr': 25.123, 'val_psnr': 23.9898, 'input_psnr': 23.1331, 'delta_psnr': 0.8568, 'best_val_psnr': 23.9898}
# {'epoch': 940, 'epoch_time_sec': 83.14, 'lr': 4.506548967361333e-05, 'train_loss': 0.011639, 'train_psnr': 25.1251, 'val_psnr': 23.99, 'input_psnr': 23.1331, 'delta_psnr': 0.8569, 'best_val_psnr': 23.99}
# {'epoch': 941, 'epoch_time_sec': 83.07, 'lr': 4.4976767911719284e-05, 'train_loss': 0.011648, 'train_psnr': 25.1213, 'val_psnr': 23.9899, 'input_psnr': 23.1331, 'delta_psnr': 0.8568, 'best_val_psnr': 23.99}
# {'epoch': 942, 'epoch_time_sec': 83.17, 'lr': 4.488806411355938e-05, 'train_loss': 0.011638, 'train_psnr': 25.1262, 'val_psnr': 23.99, 'input_psnr': 23.1331, 'delta_psnr': 0.8569, 'best_val_psnr': 23.99}
# {'epoch': 943, 'epoch_time_sec': 83.32, 'lr': 4.4799378567633454e-05, 'train_loss': 0.011651, 'train_psnr': 25.1182, 'val_psnr': 23.9899, 'input_psnr': 23.1331, 'delta_psnr': 0.8569, 'best_val_psnr': 23.99}
# {'epoch': 944, 'epoch_time_sec': 82.63, 'lr': 4.471071156238192e-05, 'train_loss': 0.011645, 'train_psnr': 25.1227, 'val_psnr': 23.9901, 'input_psnr': 23.1331, 'delta_psnr': 0.8571, 'best_val_psnr': 23.9901}
# {'epoch': 945, 'epoch_time_sec': 82.9, 'lr': 4.4622063386184967e-05, 'train_loss': 0.011641, 'train_psnr': 25.1257, 'val_psnr': 23.9902, 'input_psnr': 23.1331, 'delta_psnr': 0.8571, 'best_val_psnr': 23.9902}
# {'epoch': 946, 'epoch_time_sec': 83.07, 'lr': 4.453343432736151e-05, 'train_loss': 0.011644, 'train_psnr': 25.1231, 'val_psnr': 23.9903, 'input_psnr': 23.1331, 'delta_psnr': 0.8572, 'best_val_psnr': 23.9903}
# {'epoch': 947, 'epoch_time_sec': 82.98, 'lr': 4.444482467416827e-05, 'train_loss': 0.011633, 'train_psnr': 25.1286, 'val_psnr': 23.9903, 'input_psnr': 23.1331, 'delta_psnr': 0.8573, 'best_val_psnr': 23.9903}
# {'epoch': 948, 'epoch_time_sec': 83.03, 'lr': 4.4356234714798867e-05, 'train_loss': 0.011643, 'train_psnr': 25.1224, 'val_psnr': 23.9904, 'input_psnr': 23.1331, 'delta_psnr': 0.8573, 'best_val_psnr': 23.9904}
# {'epoch': 949, 'epoch_time_sec': 83.36, 'lr': 4.426766473738287e-05, 'train_loss': 0.011638, 'train_psnr': 25.126, 'val_psnr': 23.9905, 'input_psnr': 23.1331, 'delta_psnr': 0.8574, 'best_val_psnr': 23.9905}
# {'epoch': 950, 'epoch_time_sec': 83.01, 'lr': 4.417911502998486e-05, 'train_loss': 0.011653, 'train_psnr': 25.1207, 'val_psnr': 23.9906, 'input_psnr': 23.1331, 'delta_psnr': 0.8575, 'best_val_psnr': 23.9906}
# {'epoch': 951, 'epoch_time_sec': 83.0, 'lr': 4.4090585880603506e-05, 'train_loss': 0.011638, 'train_psnr': 25.1281, 'val_psnr': 23.9906, 'input_psnr': 23.1331, 'delta_psnr': 0.8576, 'best_val_psnr': 23.9906}
# {'epoch': 952, 'epoch_time_sec': 82.8, 'lr': 4.400207757717056e-05, 'train_loss': 0.011645, 'train_psnr': 25.1256, 'val_psnr': 23.9907, 'input_psnr': 23.1331, 'delta_psnr': 0.8576, 'best_val_psnr': 23.9907}
# {'epoch': 953, 'epoch_time_sec': 83.48, 'lr': 4.3913590407550064e-05, 'train_loss': 0.011645, 'train_psnr': 25.1228, 'val_psnr': 23.9906, 'input_psnr': 23.1331, 'delta_psnr': 0.8575, 'best_val_psnr': 23.9907}
# {'epoch': 954, 'epoch_time_sec': 83.09, 'lr': 4.382512465953722e-05, 'train_loss': 0.011637, 'train_psnr': 25.1256, 'val_psnr': 23.9907, 'input_psnr': 23.1331, 'delta_psnr': 0.8577, 'best_val_psnr': 23.9907}
# {'epoch': 955, 'epoch_time_sec': 83.34, 'lr': 4.373668062085764e-05, 'train_loss': 0.011657, 'train_psnr': 25.1178, 'val_psnr': 23.9908, 'input_psnr': 23.1331, 'delta_psnr': 0.8577, 'best_val_psnr': 23.9908}
# {'epoch': 956, 'epoch_time_sec': 83.08, 'lr': 4.3648258579166325e-05, 'train_loss': 0.011632, 'train_psnr': 25.1308, 'val_psnr': 23.9909, 'input_psnr': 23.1331, 'delta_psnr': 0.8578, 'best_val_psnr': 23.9909}
# {'epoch': 957, 'epoch_time_sec': 83.04, 'lr': 4.355985882204665e-05, 'train_loss': 0.011642, 'train_psnr': 25.1264, 'val_psnr': 23.991, 'input_psnr': 23.1331, 'delta_psnr': 0.8579, 'best_val_psnr': 23.991}
# {'epoch': 958, 'epoch_time_sec': 82.94, 'lr': 4.347148163700964e-05, 'train_loss': 0.011635, 'train_psnr': 25.1278, 'val_psnr': 23.991, 'input_psnr': 23.1331, 'delta_psnr': 0.8579, 'best_val_psnr': 23.991}
# {'epoch': 959, 'epoch_time_sec': 82.78, 'lr': 4.338312731149277e-05, 'train_loss': 0.011638, 'train_psnr': 25.1267, 'val_psnr': 23.991, 'input_psnr': 23.1331, 'delta_psnr': 0.8579, 'best_val_psnr': 23.991}
# {'epoch': 960, 'epoch_time_sec': 82.88, 'lr': 4.329479613285927e-05, 'train_loss': 0.011661, 'train_psnr': 25.1162, 'val_psnr': 23.9909, 'input_psnr': 23.1331, 'delta_psnr': 0.8578, 'best_val_psnr': 23.991}
# {'epoch': 961, 'epoch_time_sec': 82.95, 'lr': 4.320648838839706e-05, 'train_loss': 0.011636, 'train_psnr': 25.1277, 'val_psnr': 23.991, 'input_psnr': 23.1331, 'delta_psnr': 0.858, 'best_val_psnr': 23.991}
# {'epoch': 962, 'epoch_time_sec': 83.35, 'lr': 4.31182043653178e-05, 'train_loss': 0.011636, 'train_psnr': 25.1265, 'val_psnr': 23.991, 'input_psnr': 23.1331, 'delta_psnr': 0.858, 'best_val_psnr': 23.991}
# {'epoch': 963, 'epoch_time_sec': 83.09, 'lr': 4.302994435075608e-05, 'train_loss': 0.01164, 'train_psnr': 25.1273, 'val_psnr': 23.9911, 'input_psnr': 23.1331, 'delta_psnr': 0.858, 'best_val_psnr': 23.9911}
# {'epoch': 964, 'epoch_time_sec': 83.08, 'lr': 4.294170863176831e-05, 'train_loss': 0.011641, 'train_psnr': 25.1259, 'val_psnr': 23.9911, 'input_psnr': 23.1331, 'delta_psnr': 0.858, 'best_val_psnr': 23.9911}
# {'epoch': 965, 'epoch_time_sec': 83.13, 'lr': 4.285349749533194e-05, 'train_loss': 0.011646, 'train_psnr': 25.1239, 'val_psnr': 23.9911, 'input_psnr': 23.1331, 'delta_psnr': 0.8581, 'best_val_psnr': 23.9911}
# {'epoch': 966, 'epoch_time_sec': 82.95, 'lr': 4.276531122834449e-05, 'train_loss': 0.011637, 'train_psnr': 25.1271, 'val_psnr': 23.9913, 'input_psnr': 23.1331, 'delta_psnr': 0.8582, 'best_val_psnr': 23.9913}
# {'epoch': 967, 'epoch_time_sec': 83.02, 'lr': 4.267715011762252e-05, 'train_loss': 0.011635, 'train_psnr': 25.1277, 'val_psnr': 23.9914, 'input_psnr': 23.1331, 'delta_psnr': 0.8583, 'best_val_psnr': 23.9914}
# {'epoch': 968, 'epoch_time_sec': 83.38, 'lr': 4.258901444990085e-05, 'train_loss': 0.011639, 'train_psnr': 25.1282, 'val_psnr': 23.9913, 'input_psnr': 23.1331, 'delta_psnr': 0.8583, 'best_val_psnr': 23.9914}
# {'epoch': 969, 'epoch_time_sec': 83.04, 'lr': 4.2500904511831465e-05, 'train_loss': 0.011651, 'train_psnr': 25.1227, 'val_psnr': 23.9913, 'input_psnr': 23.1331, 'delta_psnr': 0.8583, 'best_val_psnr': 23.9914}
# {'epoch': 970, 'epoch_time_sec': 83.03, 'lr': 4.241282058998275e-05, 'train_loss': 0.011635, 'train_psnr': 25.1277, 'val_psnr': 23.9913, 'input_psnr': 23.1331, 'delta_psnr': 0.8583, 'best_val_psnr': 23.9914}
# {'epoch': 971, 'epoch_time_sec': 82.95, 'lr': 4.232476297083845e-05, 'train_loss': 0.011633, 'train_psnr': 25.1273, 'val_psnr': 23.9915, 'input_psnr': 23.1331, 'delta_psnr': 0.8584, 'best_val_psnr': 23.9915}
# {'epoch': 972, 'epoch_time_sec': 82.95, 'lr': 4.2236731940796716e-05, 'train_loss': 0.011638, 'train_psnr': 25.1267, 'val_psnr': 23.9915, 'input_psnr': 23.1331, 'delta_psnr': 0.8584, 'best_val_psnr': 23.9915}
# {'epoch': 973, 'epoch_time_sec': 83.07, 'lr': 4.2148727786169285e-05, 'train_loss': 0.011635, 'train_psnr': 25.1279, 'val_psnr': 23.9916, 'input_psnr': 23.1331, 'delta_psnr': 0.8585, 'best_val_psnr': 23.9916}
# {'epoch': 974, 'epoch_time_sec': 82.91, 'lr': 4.206075079318044e-05, 'train_loss': 0.01165, 'train_psnr': 25.123, 'val_psnr': 23.9916, 'input_psnr': 23.1331, 'delta_psnr': 0.8586, 'best_val_psnr': 23.9916}
# {'epoch': 975, 'epoch_time_sec': 83.06, 'lr': 4.1972801247966146e-05, 'train_loss': 0.011639, 'train_psnr': 25.1264, 'val_psnr': 23.9916, 'input_psnr': 23.1331, 'delta_psnr': 0.8586, 'best_val_psnr': 23.9916}
# {'epoch': 976, 'epoch_time_sec': 83.22, 'lr': 4.188487943657311e-05, 'train_loss': 0.011639, 'train_psnr': 25.1268, 'val_psnr': 23.9917, 'input_psnr': 23.1331, 'delta_psnr': 0.8587, 'best_val_psnr': 23.9917}
# {'epoch': 977, 'epoch_time_sec': 83.4, 'lr': 4.179698564495779e-05, 'train_loss': 0.01163, 'train_psnr': 25.1315, 'val_psnr': 23.9917, 'input_psnr': 23.1331, 'delta_psnr': 0.8587, 'best_val_psnr': 23.9917}
# {'epoch': 978, 'epoch_time_sec': 83.11, 'lr': 4.170912015898556e-05, 'train_loss': 0.011631, 'train_psnr': 25.1318, 'val_psnr': 23.9918, 'input_psnr': 23.1331, 'delta_psnr': 0.8588, 'best_val_psnr': 23.9918}
# {'epoch': 979, 'epoch_time_sec': 83.07, 'lr': 4.16212832644297e-05, 'train_loss': 0.011632, 'train_psnr': 25.1286, 'val_psnr': 23.9918, 'input_psnr': 23.1331, 'delta_psnr': 0.8587, 'best_val_psnr': 23.9918}
# {'epoch': 980, 'epoch_time_sec': 82.71, 'lr': 4.1533475246970524e-05, 'train_loss': 0.011635, 'train_psnr': 25.1303, 'val_psnr': 23.9918, 'input_psnr': 23.1331, 'delta_psnr': 0.8588, 'best_val_psnr': 23.9918}
# {'epoch': 981, 'epoch_time_sec': 83.22, 'lr': 4.144569639219443e-05, 'train_loss': 0.011647, 'train_psnr': 25.1218, 'val_psnr': 23.9918, 'input_psnr': 23.1331, 'delta_psnr': 0.8588, 'best_val_psnr': 23.9918}
# {'epoch': 982, 'epoch_time_sec': 83.21, 'lr': 4.135794698559291e-05, 'train_loss': 0.011647, 'train_psnr': 25.1233, 'val_psnr': 23.9919, 'input_psnr': 23.1331, 'delta_psnr': 0.8589, 'best_val_psnr': 23.9919}
# {'epoch': 983, 'epoch_time_sec': 83.17, 'lr': 4.127022731256179e-05, 'train_loss': 0.011645, 'train_psnr': 25.1239, 'val_psnr': 23.9919, 'input_psnr': 23.1331, 'delta_psnr': 0.8588, 'best_val_psnr': 23.9919}
# {'epoch': 984, 'epoch_time_sec': 83.21, 'lr': 4.118253765840007e-05, 'train_loss': 0.011636, 'train_psnr': 25.127, 'val_psnr': 23.9921, 'input_psnr': 23.1331, 'delta_psnr': 0.859, 'best_val_psnr': 23.9921}
# {'epoch': 985, 'epoch_time_sec': 83.03, 'lr': 4.109487830830916e-05, 'train_loss': 0.011637, 'train_psnr': 25.1259, 'val_psnr': 23.9921, 'input_psnr': 23.1331, 'delta_psnr': 0.859, 'best_val_psnr': 23.9921}
# {'epoch': 986, 'epoch_time_sec': 82.95, 'lr': 4.1007249547391976e-05, 'train_loss': 0.011635, 'train_psnr': 25.1278, 'val_psnr': 23.9922, 'input_psnr': 23.1331, 'delta_psnr': 0.8591, 'best_val_psnr': 23.9922}
# {'epoch': 987, 'epoch_time_sec': 83.22, 'lr': 4.091965166065184e-05, 'train_loss': 0.011636, 'train_psnr': 25.1276, 'val_psnr': 23.9922, 'input_psnr': 23.1331, 'delta_psnr': 0.8591, 'best_val_psnr': 23.9922}
# {'epoch': 988, 'epoch_time_sec': 83.06, 'lr': 4.083208493299175e-05, 'train_loss': 0.011641, 'train_psnr': 25.1258, 'val_psnr': 23.9923, 'input_psnr': 23.1331, 'delta_psnr': 0.8592, 'best_val_psnr': 23.9923}
# {'epoch': 989, 'epoch_time_sec': 83.03, 'lr': 4.074454964921327e-05, 'train_loss': 0.011638, 'train_psnr': 25.1268, 'val_psnr': 23.9923, 'input_psnr': 23.1331, 'delta_psnr': 0.8593, 'best_val_psnr': 23.9923}
# {'epoch': 990, 'epoch_time_sec': 82.98, 'lr': 4.065704609401578e-05, 'train_loss': 0.011639, 'train_psnr': 25.1266, 'val_psnr': 23.9923, 'input_psnr': 23.1331, 'delta_psnr': 0.8592, 'best_val_psnr': 23.9923}
# {'epoch': 991, 'epoch_time_sec': 82.99, 'lr': 4.056957455199543e-05, 'train_loss': 0.011648, 'train_psnr': 25.124, 'val_psnr': 23.9924, 'input_psnr': 23.1331, 'delta_psnr': 0.8593, 'best_val_psnr': 23.9924}
# {'epoch': 992, 'epoch_time_sec': 83.05, 'lr': 4.0482135307644236e-05, 'train_loss': 0.011642, 'train_psnr': 25.1272, 'val_psnr': 23.9925, 'input_psnr': 23.1331, 'delta_psnr': 0.8594, 'best_val_psnr': 23.9925}
# {'epoch': 993, 'epoch_time_sec': 83.0, 'lr': 4.039472864534922e-05, 'train_loss': 0.011649, 'train_psnr': 25.1248, 'val_psnr': 23.9925, 'input_psnr': 23.1331, 'delta_psnr': 0.8594, 'best_val_psnr': 23.9925}
# {'epoch': 994, 'epoch_time_sec': 83.35, 'lr': 4.030735484939136e-05, 'train_loss': 0.011661, 'train_psnr': 25.1192, 'val_psnr': 23.9926, 'input_psnr': 23.1331, 'delta_psnr': 0.8595, 'best_val_psnr': 23.9926}
# {'epoch': 995, 'epoch_time_sec': 82.84, 'lr': 4.022001420394479e-05, 'train_loss': 0.011648, 'train_psnr': 25.1231, 'val_psnr': 23.9927, 'input_psnr': 23.1331, 'delta_psnr': 0.8597, 'best_val_psnr': 23.9927}
# {'epoch': 996, 'epoch_time_sec': 83.04, 'lr': 4.013270699307586e-05, 'train_loss': 0.011634, 'train_psnr': 25.1278, 'val_psnr': 23.9927, 'input_psnr': 23.1331, 'delta_psnr': 0.8596, 'best_val_psnr': 23.9927}
# {'epoch': 997, 'epoch_time_sec': 83.04, 'lr': 4.004543350074208e-05, 'train_loss': 0.011638, 'train_psnr': 25.1277, 'val_psnr': 23.9928, 'input_psnr': 23.1331, 'delta_psnr': 0.8598, 'best_val_psnr': 23.9928}
# {'epoch': 998, 'epoch_time_sec': 83.04, 'lr': 3.9958194010791366e-05, 'train_loss': 0.011645, 'train_psnr': 25.1242, 'val_psnr': 23.9929, 'input_psnr': 23.1331, 'delta_psnr': 0.8598, 'best_val_psnr': 23.9929}
# {'epoch': 999, 'epoch_time_sec': 82.93, 'lr': 3.9870988806961023e-05, 'train_loss': 0.01163, 'train_psnr': 25.1321, 'val_psnr': 23.9929, 'input_psnr': 23.1331, 'delta_psnr': 0.8599, 'best_val_psnr': 23.9929}
# {'epoch': 1000, 'epoch_time_sec': 83.6, 'lr': 3.978381817287685e-05, 'train_loss': 0.011641, 'train_psnr': 25.1264, 'val_psnr': 23.993, 'input_psnr': 23.1331, 'delta_psnr': 0.86, 'best_val_psnr': 23.993}
# {'epoch': 1001, 'epoch_time_sec': 83.09, 'lr': 3.969668239205223e-05, 'train_loss': 0.011636, 'train_psnr': 25.1261, 'val_psnr': 23.993, 'input_psnr': 23.1331, 'delta_psnr': 0.8599, 'best_val_psnr': 23.993}
# {'epoch': 1002, 'epoch_time_sec': 83.02, 'lr': 3.9609581747887127e-05, 'train_loss': 0.011625, 'train_psnr': 25.1346, 'val_psnr': 23.9931, 'input_psnr': 23.1331, 'delta_psnr': 0.8601, 'best_val_psnr': 23.9931}
# {'epoch': 1003, 'epoch_time_sec': 83.14, 'lr': 3.952251652366729e-05, 'train_loss': 0.011625, 'train_psnr': 25.1354, 'val_psnr': 23.9931, 'input_psnr': 23.1331, 'delta_psnr': 0.8601, 'best_val_psnr': 23.9931}
# {'epoch': 1004, 'epoch_time_sec': 83.06, 'lr': 3.943548700256324e-05, 'train_loss': 0.011645, 'train_psnr': 25.1239, 'val_psnr': 23.9932, 'input_psnr': 23.1331, 'delta_psnr': 0.8601, 'best_val_psnr': 23.9932}
# {'epoch': 1005, 'epoch_time_sec': 82.91, 'lr': 3.9348493467629386e-05, 'train_loss': 0.011621, 'train_psnr': 25.1351, 'val_psnr': 23.9933, 'input_psnr': 23.1331, 'delta_psnr': 0.8602, 'best_val_psnr': 23.9933}
# {'epoch': 1006, 'epoch_time_sec': 83.07, 'lr': 3.9261536201803115e-05, 'train_loss': 0.01163, 'train_psnr': 25.1301, 'val_psnr': 23.9934, 'input_psnr': 23.1331, 'delta_psnr': 0.8603, 'best_val_psnr': 23.9934}
# {'epoch': 1007, 'epoch_time_sec': 83.38, 'lr': 3.917461548790378e-05, 'train_loss': 0.011625, 'train_psnr': 25.1345, 'val_psnr': 23.9935, 'input_psnr': 23.1331, 'delta_psnr': 0.8604, 'best_val_psnr': 23.9935}
# {'epoch': 1008, 'epoch_time_sec': 82.97, 'lr': 3.908773160863197e-05, 'train_loss': 0.011635, 'train_psnr': 25.1283, 'val_psnr': 23.9935, 'input_psnr': 23.1331, 'delta_psnr': 0.8604, 'best_val_psnr': 23.9935}
# {'epoch': 1009, 'epoch_time_sec': 83.03, 'lr': 3.900088484656834e-05, 'train_loss': 0.011638, 'train_psnr': 25.1254, 'val_psnr': 23.9936, 'input_psnr': 23.1331, 'delta_psnr': 0.8605, 'best_val_psnr': 23.9936}
# {'epoch': 1010, 'epoch_time_sec': 83.0, 'lr': 3.891407548417292e-05, 'train_loss': 0.01162, 'train_psnr': 25.1377, 'val_psnr': 23.9935, 'input_psnr': 23.1331, 'delta_psnr': 0.8604, 'best_val_psnr': 23.9936}
# {'epoch': 1011, 'epoch_time_sec': 83.05, 'lr': 3.882730380378409e-05, 'train_loss': 0.011645, 'train_psnr': 25.1257, 'val_psnr': 23.9936, 'input_psnr': 23.1331, 'delta_psnr': 0.8605, 'best_val_psnr': 23.9936}
# {'epoch': 1012, 'epoch_time_sec': 83.27, 'lr': 3.874057008761763e-05, 'train_loss': 0.011638, 'train_psnr': 25.1263, 'val_psnr': 23.9934, 'input_psnr': 23.1331, 'delta_psnr': 0.8604, 'best_val_psnr': 23.9936}
# {'epoch': 1013, 'epoch_time_sec': 83.28, 'lr': 3.8653874617765904e-05, 'train_loss': 0.011625, 'train_psnr': 25.1353, 'val_psnr': 23.9936, 'input_psnr': 23.1331, 'delta_psnr': 0.8605, 'best_val_psnr': 23.9936}
# {'epoch': 1014, 'epoch_time_sec': 83.0, 'lr': 3.856721767619681e-05, 'train_loss': 0.011634, 'train_psnr': 25.1296, 'val_psnr': 23.9936, 'input_psnr': 23.1331, 'delta_psnr': 0.8605, 'best_val_psnr': 23.9936}
# {'epoch': 1015, 'epoch_time_sec': 82.99, 'lr': 3.8480599544753e-05, 'train_loss': 0.01164, 'train_psnr': 25.1274, 'val_psnr': 23.9936, 'input_psnr': 23.1331, 'delta_psnr': 0.8605, 'best_val_psnr': 23.9936}
# {'epoch': 1016, 'epoch_time_sec': 82.98, 'lr': 3.839402050515089e-05, 'train_loss': 0.011622, 'train_psnr': 25.1365, 'val_psnr': 23.9937, 'input_psnr': 23.1331, 'delta_psnr': 0.8606, 'best_val_psnr': 23.9937}
# {'epoch': 1017, 'epoch_time_sec': 82.74, 'lr': 3.8307480838979714e-05, 'train_loss': 0.011626, 'train_psnr': 25.134, 'val_psnr': 23.9937, 'input_psnr': 23.1331, 'delta_psnr': 0.8607, 'best_val_psnr': 23.9937}
# {'epoch': 1018, 'epoch_time_sec': 82.99, 'lr': 3.822098082770072e-05, 'train_loss': 0.01163, 'train_psnr': 25.1316, 'val_psnr': 23.9939, 'input_psnr': 23.1331, 'delta_psnr': 0.8608, 'best_val_psnr': 23.9939}
# {'epoch': 1019, 'epoch_time_sec': 83.06, 'lr': 3.813452075264609e-05, 'train_loss': 0.011634, 'train_psnr': 25.1287, 'val_psnr': 23.994, 'input_psnr': 23.1331, 'delta_psnr': 0.8609, 'best_val_psnr': 23.994}
# {'epoch': 1020, 'epoch_time_sec': 83.12, 'lr': 3.8048100895018176e-05, 'train_loss': 0.011628, 'train_psnr': 25.1327, 'val_psnr': 23.9939, 'input_psnr': 23.1331, 'delta_psnr': 0.8609, 'best_val_psnr': 23.994}
# {'epoch': 1021, 'epoch_time_sec': 83.2, 'lr': 3.7961721535888564e-05, 'train_loss': 0.011627, 'train_psnr': 25.1321, 'val_psnr': 23.9941, 'input_psnr': 23.1331, 'delta_psnr': 0.8611, 'best_val_psnr': 23.9941}
# {'epoch': 1022, 'epoch_time_sec': 83.1, 'lr': 3.787538295619702e-05, 'train_loss': 0.011626, 'train_psnr': 25.1333, 'val_psnr': 23.9942, 'input_psnr': 23.1331, 'delta_psnr': 0.8611, 'best_val_psnr': 23.9942}
# {'epoch': 1023, 'epoch_time_sec': 83.1, 'lr': 3.778908543675077e-05, 'train_loss': 0.011629, 'train_psnr': 25.1357, 'val_psnr': 23.9943, 'input_psnr': 23.1331, 'delta_psnr': 0.8612, 'best_val_psnr': 23.9943}
# {'epoch': 1024, 'epoch_time_sec': 83.37, 'lr': 3.770282925822344e-05, 'train_loss': 0.011641, 'train_psnr': 25.128, 'val_psnr': 23.9943, 'input_psnr': 23.1331, 'delta_psnr': 0.8612, 'best_val_psnr': 23.9943}
# {'epoch': 1025, 'epoch_time_sec': 83.1, 'lr': 3.7616614701154236e-05, 'train_loss': 0.011623, 'train_psnr': 25.1358, 'val_psnr': 23.9943, 'input_psnr': 23.1331, 'delta_psnr': 0.8613, 'best_val_psnr': 23.9943}
# {'epoch': 1026, 'epoch_time_sec': 83.34, 'lr': 3.753044204594699e-05, 'train_loss': 0.011633, 'train_psnr': 25.1301, 'val_psnr': 23.9942, 'input_psnr': 23.1331, 'delta_psnr': 0.8612, 'best_val_psnr': 23.9943}
# ...
# {'epoch': 1063, 'epoch_time_sec': 62.57, 'lr': 3.4374060369953604e-05, 'train_loss': 0.01163, 'train_psnr': 25.131, 'val_psnr': 23.9956, 'input_psnr': 23.1331, 'delta_psnr': 0.8625, 'best_val_psnr': 23.9956}
# {'epoch': 1064, 'epoch_time_sec': 62.65, 'lr': 3.4289686335270473e-05, 'train_loss': 0.01163, 'train_psnr': 25.133, 'val_psnr': 23.9956, 'input_psnr': 23.1331, 'delta_psnr': 0.8626, 'best_val_psnr': 23.9956}
# {'epoch': 1065, 'epoch_time_sec': 62.67, 'lr': 3.4205365022935505e-05, 'train_loss': 0.011619, 'train_psnr': 25.1374, 'val_psnr': 23.9956, 'input_psnr': 23.1331, 'delta_psnr': 0.8626, 'best_val_psnr': 23.9956}
# {'epoch': 1066, 'epoch_time_sec': 62.27, 'lr': 3.4121096707194946e-05, 'train_loss': 0.011626, 'train_psnr': 25.1358, 'val_psnr': 23.9957, 'input_psnr': 23.1331, 'delta_psnr': 0.8627, 'best_val_psnr': 23.9957}
# {'epoch': 1067, 'epoch_time_sec': 62.7, 'lr': 3.4036881662122654e-05, 'train_loss': 0.011627, 'train_psnr': 25.1319, 'val_psnr': 23.9958, 'input_psnr': 23.1331, 'delta_psnr': 0.8627, 'best_val_psnr': 23.9958}
# {'epoch': 1068, 'epoch_time_sec': 63.04, 'lr': 3.395272016161927e-05, 'train_loss': 0.011631, 'train_psnr': 25.1312, 'val_psnr': 23.9959, 'input_psnr': 23.1331, 'delta_psnr': 0.8628, 'best_val_psnr': 23.9959}
# {'epoch': 1069, 'epoch_time_sec': 62.66, 'lr': 3.3868612479411245e-05, 'train_loss': 0.011634, 'train_psnr': 25.1316, 'val_psnr': 23.9959, 'input_psnr': 23.1331, 'delta_psnr': 0.8628, 'best_val_psnr': 23.9959}
# {'epoch': 1070, 'epoch_time_sec': 63.08, 'lr': 3.378455888905001e-05, 'train_loss': 0.011624, 'train_psnr': 25.1346, 'val_psnr': 23.9959, 'input_psnr': 23.1331, 'delta_psnr': 0.8629, 'best_val_psnr': 23.9959}
# {'epoch': 1071, 'epoch_time_sec': 62.92, 'lr': 3.370055966391109e-05, 'train_loss': 0.011636, 'train_psnr': 25.1302, 'val_psnr': 23.9961, 'input_psnr': 23.1331, 'delta_psnr': 0.863, 'best_val_psnr': 23.9961}
# {'epoch': 1072, 'epoch_time_sec': 62.65, 'lr': 3.361661507719313e-05, 'train_loss': 0.011631, 'train_psnr': 25.1303, 'val_psnr': 23.996, 'input_psnr': 23.1331, 'delta_psnr': 0.863, 'best_val_psnr': 23.9961}
# {'epoch': 1073, 'epoch_time_sec': 62.7, 'lr': 3.3532725401917154e-05, 'train_loss': 0.01163, 'train_psnr': 25.1327, 'val_psnr': 23.996, 'input_psnr': 23.1331, 'delta_psnr': 0.863, 'best_val_psnr': 23.9961}
# {'epoch': 1074, 'epoch_time_sec': 63.05, 'lr': 3.344889091092552e-05, 'train_loss': 0.011633, 'train_psnr': 25.1299, 'val_psnr': 23.9961, 'input_psnr': 23.1331, 'delta_psnr': 0.863, 'best_val_psnr': 23.9961}
# {'epoch': 1075, 'epoch_time_sec': 62.69, 'lr': 3.336511187688115e-05, 'train_loss': 0.011626, 'train_psnr': 25.1342, 'val_psnr': 23.9961, 'input_psnr': 23.1331, 'delta_psnr': 0.8631, 'best_val_psnr': 23.9961}
# {'epoch': 1076, 'epoch_time_sec': 62.7, 'lr': 3.328138857226659e-05, 'train_loss': 0.011627, 'train_psnr': 25.1324, 'val_psnr': 23.9961, 'input_psnr': 23.1331, 'delta_psnr': 0.863, 'best_val_psnr': 23.9961}
# {'epoch': 1077, 'epoch_time_sec': 62.78, 'lr': 3.319772126938308e-05, 'train_loss': 0.011626, 'train_psnr': 25.1333, 'val_psnr': 23.9962, 'input_psnr': 23.1331, 'delta_psnr': 0.8631, 'best_val_psnr': 23.9962}
# {'epoch': 1078, 'epoch_time_sec': 62.51, 'lr': 3.311411024034981e-05, 'train_loss': 0.011622, 'train_psnr': 25.1365, 'val_psnr': 23.9962, 'input_psnr': 23.1331, 'delta_psnr': 0.8631, 'best_val_psnr': 23.9962}
# {'epoch': 1079, 'epoch_time_sec': 62.56, 'lr': 3.3030555757102875e-05, 'train_loss': 0.011621, 'train_psnr': 25.1357, 'val_psnr': 23.9963, 'input_psnr': 23.1331, 'delta_psnr': 0.8632, 'best_val_psnr': 23.9963}
# {'epoch': 1080, 'epoch_time_sec': 63.02, 'lr': 3.294705809139448e-05, 'train_loss': 0.011628, 'train_psnr': 25.1343, 'val_psnr': 23.9963, 'input_psnr': 23.1331, 'delta_psnr': 0.8632, 'best_val_psnr': 23.9963}
# {'epoch': 1081, 'epoch_time_sec': 62.74, 'lr': 3.2863617514792075e-05, 'train_loss': 0.01164, 'train_psnr': 25.1321, 'val_psnr': 23.9963, 'input_psnr': 23.1331, 'delta_psnr': 0.8632, 'best_val_psnr': 23.9963}
# {'epoch': 1082, 'epoch_time_sec': 62.75, 'lr': 3.2780234298677364e-05, 'train_loss': 0.011636, 'train_psnr': 25.1293, 'val_psnr': 23.9963, 'input_psnr': 23.1331, 'delta_psnr': 0.8633, 'best_val_psnr': 23.9963}
# {'epoch': 1083, 'epoch_time_sec': 62.64, 'lr': 3.2696908714245554e-05, 'train_loss': 0.011617, 'train_psnr': 25.1379, 'val_psnr': 23.9962, 'input_psnr': 23.1331, 'delta_psnr': 0.8632, 'best_val_psnr': 23.9963}
# {'epoch': 1084, 'epoch_time_sec': 62.61, 'lr': 3.2613641032504355e-05, 'train_loss': 0.011626, 'train_psnr': 25.1323, 'val_psnr': 23.9964, 'input_psnr': 23.1331, 'delta_psnr': 0.8633, 'best_val_psnr': 23.9964}
# {'epoch': 1085, 'epoch_time_sec': 62.73, 'lr': 3.25304315242732e-05, 'train_loss': 0.011628, 'train_psnr': 25.1332, 'val_psnr': 23.9964, 'input_psnr': 23.1331, 'delta_psnr': 0.8633, 'best_val_psnr': 23.9964}
# {'epoch': 1086, 'epoch_time_sec': 63.03, 'lr': 3.2447280460182316e-05, 'train_loss': 0.011625, 'train_psnr': 25.1376, 'val_psnr': 23.9964, 'input_psnr': 23.1331, 'delta_psnr': 0.8634, 'best_val_psnr': 23.9964}
# {'epoch': 1087, 'epoch_time_sec': 62.63, 'lr': 3.236418811067181e-05, 'train_loss': 0.01162, 'train_psnr': 25.1357, 'val_psnr': 23.9965, 'input_psnr': 23.1331, 'delta_psnr': 0.8634, 'best_val_psnr': 23.9965}
# {'epoch': 1088, 'epoch_time_sec': 62.67, 'lr': 3.2281154745990895e-05, 'train_loss': 0.011641, 'train_psnr': 25.1257, 'val_psnr': 23.9963, 'input_psnr': 23.1331, 'delta_psnr': 0.8633, 'best_val_psnr': 23.9965}
# {'epoch': 1089, 'epoch_time_sec': 62.68, 'lr': 3.219818063619684e-05, 'train_loss': 0.011627, 'train_psnr': 25.1344, 'val_psnr': 23.9965, 'input_psnr': 23.1331, 'delta_psnr': 0.8634, 'best_val_psnr': 23.9965}
# {'epoch': 1090, 'epoch_time_sec': 62.02, 'lr': 3.2115266051154265e-05, 'train_loss': 0.011648, 'train_psnr': 25.1261, 'val_psnr': 23.9964, 'input_psnr': 23.1331, 'delta_psnr': 0.8634, 'best_val_psnr': 23.9965}
# {'epoch': 1091, 'epoch_time_sec': 62.47, 'lr': 3.2032411260534214e-05, 'train_loss': 0.011621, 'train_psnr': 25.1361, 'val_psnr': 23.9965, 'input_psnr': 23.1331, 'delta_psnr': 0.8634, 'best_val_psnr': 23.9965}
# {'epoch': 1092, 'epoch_time_sec': 62.84, 'lr': 3.194961653381318e-05, 'train_loss': 0.011618, 'train_psnr': 25.1372, 'val_psnr': 23.9966, 'input_psnr': 23.1331, 'delta_psnr': 0.8635, 'best_val_psnr': 23.9966}
# {'epoch': 1093, 'epoch_time_sec': 63.1, 'lr': 3.186688214027237e-05, 'train_loss': 0.01162, 'train_psnr': 25.1372, 'val_psnr': 23.9966, 'input_psnr': 23.1331, 'delta_psnr': 0.8636, 'best_val_psnr': 23.9966}
# {'epoch': 1094, 'epoch_time_sec': 62.97, 'lr': 3.178420834899672e-05, 'train_loss': 0.01162, 'train_psnr': 25.1364, 'val_psnr': 23.9967, 'input_psnr': 23.1331, 'delta_psnr': 0.8636, 'best_val_psnr': 23.9967}
# {'epoch': 1095, 'epoch_time_sec': 62.71, 'lr': 3.170159542887408e-05, 'train_loss': 0.011619, 'train_psnr': 25.1398, 'val_psnr': 23.9967, 'input_psnr': 23.1331, 'delta_psnr': 0.8636, 'best_val_psnr': 23.9967}
# {'epoch': 1096, 'epoch_time_sec': 62.74, 'lr': 3.1619043648594345e-05, 'train_loss': 0.011614, 'train_psnr': 25.1409, 'val_psnr': 23.9967, 'input_psnr': 23.1331, 'delta_psnr': 0.8637, 'best_val_psnr': 23.9967}
# {'epoch': 1097, 'epoch_time_sec': 62.46, 'lr': 3.1536553276648506e-05, 'train_loss': 0.011628, 'train_psnr': 25.1334, 'val_psnr': 23.9968, 'input_psnr': 23.1331, 'delta_psnr': 0.8637, 'best_val_psnr': 23.9968}
# {'epoch': 1098, 'epoch_time_sec': 63.03, 'lr': 3.145412458132789e-05, 'train_loss': 0.011633, 'train_psnr': 25.1333, 'val_psnr': 23.9968, 'input_psnr': 23.1331, 'delta_psnr': 0.8638, 'best_val_psnr': 23.9968}
# {'epoch': 1099, 'epoch_time_sec': 62.66, 'lr': 3.137175783072319e-05, 'train_loss': 0.011634, 'train_psnr': 25.1311, 'val_psnr': 23.9969, 'input_psnr': 23.1331, 'delta_psnr': 0.8638, 'best_val_psnr': 23.9969}
# {'epoch': 1100, 'epoch_time_sec': 62.63, 'lr': 3.128945329272363e-05, 'train_loss': 0.011627, 'train_psnr': 25.134, 'val_psnr': 23.9971, 'input_psnr': 23.1331, 'delta_psnr': 0.864, 'best_val_psnr': 23.9971}
# {'epoch': 1101, 'epoch_time_sec': 62.68, 'lr': 3.120721123501614e-05, 'train_loss': 0.011632, 'train_psnr': 25.1302, 'val_psnr': 23.9971, 'input_psnr': 23.1331, 'delta_psnr': 0.864, 'best_val_psnr': 23.9971}
# {'epoch': 1102, 'epoch_time_sec': 62.46, 'lr': 3.112503192508436e-05, 'train_loss': 0.011612, 'train_psnr': 25.1423, 'val_psnr': 23.9971, 'input_psnr': 23.1331, 'delta_psnr': 0.8641, 'best_val_psnr': 23.9971}
# {'epoch': 1103, 'epoch_time_sec': 62.84, 'lr': 3.104291563020789e-05, 'train_loss': 0.011617, 'train_psnr': 25.1383, 'val_psnr': 23.9972, 'input_psnr': 23.1331, 'delta_psnr': 0.8641, 'best_val_psnr': 23.9972}
# {'epoch': 1104, 'epoch_time_sec': 62.81, 'lr': 3.096086261746142e-05, 'train_loss': 0.01163, 'train_psnr': 25.1327, 'val_psnr': 23.9973, 'input_psnr': 23.1331, 'delta_psnr': 0.8642, 'best_val_psnr': 23.9973}
# {'epoch': 1105, 'epoch_time_sec': 62.69, 'lr': 3.087887315371375e-05, 'train_loss': 0.011616, 'train_psnr': 25.1408, 'val_psnr': 23.9973, 'input_psnr': 23.1331, 'delta_psnr': 0.8642, 'best_val_psnr': 23.9973}
# {'epoch': 1106, 'epoch_time_sec': 62.65, 'lr': 3.079694750562707e-05, 'train_loss': 0.011623, 'train_psnr': 25.1351, 'val_psnr': 23.9973, 'input_psnr': 23.1331, 'delta_psnr': 0.8642, 'best_val_psnr': 23.9973}
# {'epoch': 1107, 'epoch_time_sec': 62.68, 'lr': 3.071508593965592e-05, 'train_loss': 0.011618, 'train_psnr': 25.1367, 'val_psnr': 23.9973, 'input_psnr': 23.1331, 'delta_psnr': 0.8643, 'best_val_psnr': 23.9973}
# {'epoch': 1108, 'epoch_time_sec': 62.65, 'lr': 3.06332887220465e-05, 'train_loss': 0.011622, 'train_psnr': 25.1358, 'val_psnr': 23.9973, 'input_psnr': 23.1331, 'delta_psnr': 0.8643, 'best_val_psnr': 23.9973}
# {'epoch': 1109, 'epoch_time_sec': 62.89, 'lr': 3.05515561188357e-05, 'train_loss': 0.011624, 'train_psnr': 25.1353, 'val_psnr': 23.9974, 'input_psnr': 23.1331, 'delta_psnr': 0.8643, 'best_val_psnr': 23.9974}
# {'epoch': 1110, 'epoch_time_sec': 62.78, 'lr': 3.0469888395850248e-05, 'train_loss': 0.011619, 'train_psnr': 25.1395, 'val_psnr': 23.9974, 'input_psnr': 23.1331, 'delta_psnr': 0.8643, 'best_val_psnr': 23.9974}
# {'epoch': 1111, 'epoch_time_sec': 62.7, 'lr': 3.038828581870587e-05, 'train_loss': 0.011607, 'train_psnr': 25.1447, 'val_psnr': 23.9974, 'input_psnr': 23.1331, 'delta_psnr': 0.8644, 'best_val_psnr': 23.9974}
# {'epoch': 1112, 'epoch_time_sec': 62.72, 'lr': 3.03067486528064e-05, 'train_loss': 0.011614, 'train_psnr': 25.1395, 'val_psnr': 23.9975, 'input_psnr': 23.1331, 'delta_psnr': 0.8644, 'best_val_psnr': 23.9975}
# {'epoch': 1113, 'epoch_time_sec': 62.47, 'lr': 3.022527716334293e-05, 'train_loss': 0.01163, 'train_psnr': 25.1313, 'val_psnr': 23.9975, 'input_psnr': 23.1331, 'delta_psnr': 0.8645, 'best_val_psnr': 23.9975}
# {'epoch': 1114, 'epoch_time_sec': 62.74, 'lr': 3.0143871615292975e-05, 'train_loss': 0.011624, 'train_psnr': 25.1346, 'val_psnr': 23.9976, 'input_psnr': 23.1331, 'delta_psnr': 0.8646, 'best_val_psnr': 23.9976}
# {'epoch': 1115, 'epoch_time_sec': 63.01, 'lr': 3.0062532273419525e-05, 'train_loss': 0.011623, 'train_psnr': 25.1363, 'val_psnr': 23.9976, 'input_psnr': 23.1331, 'delta_psnr': 0.8645, 'best_val_psnr': 23.9976}
# {'epoch': 1116, 'epoch_time_sec': 62.52, 'lr': 2.9981259402270297e-05, 'train_loss': 0.011616, 'train_psnr': 25.1394, 'val_psnr': 23.9976, 'input_psnr': 23.1331, 'delta_psnr': 0.8645, 'best_val_psnr': 23.9976}
# {'epoch': 1117, 'epoch_time_sec': 63.22, 'lr': 2.990005326617678e-05, 'train_loss': 0.011626, 'train_psnr': 25.1355, 'val_psnr': 23.9978, 'input_psnr': 23.1331, 'delta_psnr': 0.8647, 'best_val_psnr': 23.9978}
# {'epoch': 1118, 'epoch_time_sec': 62.69, 'lr': 2.981891412925343e-05, 'train_loss': 0.011616, 'train_psnr': 25.14, 'val_psnr': 23.9977, 'input_psnr': 23.1331, 'delta_psnr': 0.8647, 'best_val_psnr': 23.9978}
# {'epoch': 1119, 'epoch_time_sec': 62.78, 'lr': 2.9737842255396812e-05, 'train_loss': 0.01162, 'train_psnr': 25.1379, 'val_psnr': 23.9978, 'input_psnr': 23.1331, 'delta_psnr': 0.8648, 'best_val_psnr': 23.9978}
# {'epoch': 1120, 'epoch_time_sec': 62.66, 'lr': 2.9656837908284693e-05, 'train_loss': 0.011637, 'train_psnr': 25.1305, 'val_psnr': 23.9978, 'input_psnr': 23.1331, 'delta_psnr': 0.8647, 'best_val_psnr': 23.9978}
# {'epoch': 1121, 'epoch_time_sec': 63.01, 'lr': 2.9575901351375262e-05, 'train_loss': 0.011622, 'train_psnr': 25.1363, 'val_psnr': 23.9978, 'input_psnr': 23.1331, 'delta_psnr': 0.8648, 'best_val_psnr': 23.9978}
# {'epoch': 1122, 'epoch_time_sec': 62.65, 'lr': 2.949503284790615e-05, 'train_loss': 0.011624, 'train_psnr': 25.1362, 'val_psnr': 23.9979, 'input_psnr': 23.1331, 'delta_psnr': 0.8648, 'best_val_psnr': 23.9979}
# {'epoch': 1123, 'epoch_time_sec': 62.68, 'lr': 2.941423266089372e-05, 'train_loss': 0.011617, 'train_psnr': 25.139, 'val_psnr': 23.9979, 'input_psnr': 23.1331, 'delta_psnr': 0.8649, 'best_val_psnr': 23.9979}
# {'epoch': 1124, 'epoch_time_sec': 62.68, 'lr': 2.9333501053132146e-05, 'train_loss': 0.011614, 'train_psnr': 25.1416, 'val_psnr': 23.9979, 'input_psnr': 23.1331, 'delta_psnr': 0.8649, 'best_val_psnr': 23.9979}
# {'epoch': 1125, 'epoch_time_sec': 62.66, 'lr': 2.9252838287192487e-05, 'train_loss': 0.01162, 'train_psnr': 25.136, 'val_psnr': 23.998, 'input_psnr': 23.1331, 'delta_psnr': 0.8649, 'best_val_psnr': 23.998}
# {'epoch': 1126, 'epoch_time_sec': 62.1, 'lr': 2.917224462542197e-05, 'train_loss': 0.011618, 'train_psnr': 25.1383, 'val_psnr': 23.998, 'input_psnr': 23.1331, 'delta_psnr': 0.8649, 'best_val_psnr': 23.998}
# {'epoch': 1127, 'epoch_time_sec': 62.98, 'lr': 2.9091720329943032e-05, 'train_loss': 0.011624, 'train_psnr': 25.1384, 'val_psnr': 23.998, 'input_psnr': 23.1331, 'delta_psnr': 0.865, 'best_val_psnr': 23.998}
# {'epoch': 1128, 'epoch_time_sec': 62.7, 'lr': 2.901126566265253e-05, 'train_loss': 0.011623, 'train_psnr': 25.1364, 'val_psnr': 23.9981, 'input_psnr': 23.1331, 'delta_psnr': 0.865, 'best_val_psnr': 23.9981}
# {'epoch': 1129, 'epoch_time_sec': 62.69, 'lr': 2.8930880885220848e-05, 'train_loss': 0.011609, 'train_psnr': 25.1418, 'val_psnr': 23.9981, 'input_psnr': 23.1331, 'delta_psnr': 0.8651, 'best_val_psnr': 23.9981}
# {'epoch': 1130, 'epoch_time_sec': 62.67, 'lr': 2.885056625909103e-05, 'train_loss': 0.011626, 'train_psnr': 25.1364, 'val_psnr': 23.9982, 'input_psnr': 23.1331, 'delta_psnr': 0.8651, 'best_val_psnr': 23.9982}
# {'epoch': 1131, 'epoch_time_sec': 62.75, 'lr': 2.877032204547803e-05, 'train_loss': 0.011614, 'train_psnr': 25.1392, 'val_psnr': 23.9982, 'input_psnr': 23.1331, 'delta_psnr': 0.8651, 'best_val_psnr': 23.9982}
# {'epoch': 1132, 'epoch_time_sec': 62.68, 'lr': 2.869014850536771e-05, 'train_loss': 0.01162, 'train_psnr': 25.1357, 'val_psnr': 23.9982, 'input_psnr': 23.1331, 'delta_psnr': 0.8651, 'best_val_psnr': 23.9982}
# {'epoch': 1133, 'epoch_time_sec': 62.99, 'lr': 2.8610045899516134e-05, 'train_loss': 0.011611, 'train_psnr': 25.142, 'val_psnr': 23.9982, 'input_psnr': 23.1331, 'delta_psnr': 0.8652, 'best_val_psnr': 23.9982}
# {'epoch': 1134, 'epoch_time_sec': 62.63, 'lr': 2.853001448844867e-05, 'train_loss': 0.011624, 'train_psnr': 25.1355, 'val_psnr': 23.9983, 'input_psnr': 23.1331, 'delta_psnr': 0.8652, 'best_val_psnr': 23.9983}
# {'epoch': 1135, 'epoch_time_sec': 62.69, 'lr': 2.8450054532459027e-05, 'train_loss': 0.011612, 'train_psnr': 25.1414, 'val_psnr': 23.9983, 'input_psnr': 23.1331, 'delta_psnr': 0.8653, 'best_val_psnr': 23.9983}
# {'epoch': 1136, 'epoch_time_sec': 62.61, 'lr': 2.8370166291608695e-05, 'train_loss': 0.011625, 'train_psnr': 25.1352, 'val_psnr': 23.9984, 'input_psnr': 23.1331, 'delta_psnr': 0.8653, 'best_val_psnr': 23.9984}
# {'epoch': 1137, 'epoch_time_sec': 62.76, 'lr': 2.8290350025725735e-05, 'train_loss': 0.011619, 'train_psnr': 25.1352, 'val_psnr': 23.9984, 'input_psnr': 23.1331, 'delta_psnr': 0.8654, 'best_val_psnr': 23.9984}
# {'epoch': 1138, 'epoch_time_sec': 62.5, 'lr': 2.8210605994404216e-05, 'train_loss': 0.011614, 'train_psnr': 25.1408, 'val_psnr': 23.9985, 'input_psnr': 23.1331, 'delta_psnr': 0.8654, 'best_val_psnr': 23.9985}

# %% [markdown]
# ## 6. Validation Summary
#
# Load the best checkpoint, compute validation PSNR against the raw LR baseline, and write preview images.

# %%
export_model = load_checkpoint_for_eval(best_ckpt_path, device)
validation_summary = evaluate_metrics(export_model, val_loader, device)
preview_info = write_val_preview(export_model, val_loader, preview_dir, device)
print({'validation_summary': validation_summary, 'best_checkpoint_path': str(best_ckpt_path), 'last_checkpoint_path': str(last_ckpt_path), 'preview': preview_info})

# %% [markdown]
# ## 7. Export And Submission Artifacts
#
# Export ONNX, run ONNX checker and ONNX Runtime parity, export training-derived calibration images, generate an MXQ handoff script, and write a final summary.

# %%
def export_calibration_images(pairs: list[tuple[Path, Path, str]], out_dir: Path, count: int, eval_size: int) -> dict[str, Any]:
    out_dir.mkdir(parents=True, exist_ok=True)
    selected = pairs[: min(count, len(pairs))]
    manifest_items: list[dict[str, Any]] = []
    for index, (lr_path, _, name) in enumerate(selected):
        image = Image.open(lr_path).convert('RGB')
        if image.size != (eval_size, eval_size):
            image = image.resize((eval_size, eval_size), BICUBIC_RESAMPLE)
        image_path = out_dir / f'{index:03d}_{Path(name).name}.png'
        image.save(image_path)
        manifest_items.append({'index': index, 'name': name, 'source_lr': str(lr_path), 'image_path': str(image_path), 'derived_from_training': True})
    manifest = {'count': len(manifest_items), 'source': 'training_pairs', 'eval_size': eval_size, 'derived_from_training': True, 'items': manifest_items}
    manifest_path = out_dir / 'manifest.json'
    write_json(manifest_path, manifest)
    return {'calibration_dir': str(out_dir), 'manifest_path': str(manifest_path), 'count': len(manifest_items), 'derived_from_training': True}

conversion_script = """#!/usr/bin/env python3
from __future__ import annotations

import argparse
import json
import shlex
import subprocess
from pathlib import Path


def parse_args() -> argparse.Namespace:
    parser = argparse.ArgumentParser(description='Lab 3 ONNX-to-MXQ handoff script for FSRCNN residual.')
    parser.add_argument('--onnx', type=Path, required=True)
    parser.add_argument('--calibration-dir', type=Path, required=True)
    parser.add_argument('--output', type=Path, required=True)
    parser.add_argument('--command-template', default='', help='Optional command with {onnx}, {calibration}, {output} placeholders.')
    parser.add_argument('--dry-run', action='store_true')
    return parser.parse_args()


def main() -> None:
    args = parse_args()
    args.onnx = args.onnx.resolve()
    args.calibration_dir = args.calibration_dir.resolve()
    args.output = args.output.resolve()
    if not args.onnx.exists():
        raise FileNotFoundError(f'ONNX file not found: {args.onnx}')
    if not args.calibration_dir.exists():
        raise FileNotFoundError(f'Calibration directory not found: {args.calibration_dir}')
    payload = {
        'onnx': str(args.onnx),
        'calibration_dir': str(args.calibration_dir),
        'output': str(args.output),
        'status': 'handoff_only',
        'command_template': args.command_template,
    }
    if args.command_template:
        command = args.command_template.format(
            onnx=shlex.quote(str(args.onnx)),
            calibration=shlex.quote(str(args.calibration_dir)),
            output=shlex.quote(str(args.output)),
        )
        payload['command'] = command
        if not args.dry_run:
            completed = subprocess.run(command, shell=True, check=False, capture_output=True, text=True)
            payload.update({'status': 'completed' if completed.returncode == 0 else 'failed', 'returncode': completed.returncode, 'stdout': completed.stdout, 'stderr': completed.stderr})
    args.output.parent.mkdir(parents=True, exist_ok=True)
    handoff_path = args.output.with_suffix('.handoff.json')
    handoff_path.write_text(json.dumps(payload, indent=2, sort_keys=True) + '\n', encoding='utf-8')
    print(json.dumps(payload, indent=2, sort_keys=True))


if __name__ == '__main__':
    main()
"""

onnx_path = exports_dir / f'{cfg.model_id}.onnx'
mxq_target_path = exports_dir / f'{cfg.model_id}.mxq'
conversion_script_path = exports_dir / 'convert_fsrcnn_residual_mxq.py'
conversion_script_path.write_text(conversion_script, encoding='utf-8')

cpu_export_model = load_checkpoint_for_eval(best_ckpt_path, torch.device('cpu')).cpu().eval()
dummy = torch.randn(1, 3, cfg.eval_size, cfg.eval_size)
torch.onnx.export(cpu_export_model, dummy, str(onnx_path), input_names=['input'], output_names=['output'], opset_version=17, dynamo=False)

onnx_model = onnx.load(str(onnx_path))
onnx.checker.check_model(onnx_model)
node_ops = [node.op_type for node in onnx_model.graph.node]
op_histogram = {op: node_ops.count(op) for op in sorted(set(node_ops))}
onnx_summary = {'onnx_path': str(onnx_path), 'checked': True, 'graph_op_count': len(node_ops), 'op_histogram': op_histogram}
print(onnx_summary)

parity_result = {'attempted': False, 'onnxruntime_available': False, 'max_abs_diff': None, 'mean_abs_diff': None}
try:
    import onnxruntime as ort
    parity_result['attempted'] = True
    parity_result['onnxruntime_available'] = True
    parity_input = torch.randn(1, 3, cfg.eval_size, cfg.eval_size)
    with torch.no_grad():
        torch_out = cpu_export_model(parity_input).detach().cpu().numpy()
    ort_session = ort.InferenceSession(str(onnx_path), providers=['CPUExecutionProvider'])
    ort_out = ort_session.run(['output'], {'input': parity_input.numpy()})[0]
    diff = np.abs(torch_out - ort_out)
    parity_result['max_abs_diff'] = float(diff.max())
    parity_result['mean_abs_diff'] = float(diff.mean())
except ImportError:
    print('onnxruntime not installed; skipping CPU parity check')
print(parity_result)

calibration_summary = export_calibration_images(train_pairs, calibration_dir, cfg.calibration_count, cfg.eval_size)
mxq_command = f'python {conversion_script_path} --onnx {onnx_path} --calibration-dir {calibration_dir} --output {mxq_target_path} --dry-run'
mxq_handoff = {
    'conversion_script_path': str(conversion_script_path),
    'onnx_input_path': str(onnx_path),
    'calibration_manifest_path': calibration_summary['manifest_path'],
    'mxq_target_path': str(mxq_target_path),
    'command': mxq_command,
    'requested_compile': False,
}
summary = {
    'model_id': cfg.model_id,
    'run_root': str(run_root),
    'config': asdict(cfg),
    'data': {'data_root': str(data_root), 'train_pairs': len(train_pairs), 'val_pairs': len(val_pairs), 'train_splits': L3_TRAIN_SPLITS, 'val_dirs': L3_VAL_DIRS},
    'model': {'params': param_count, 'operator_audit': op_counts, 'input_shape': [1, 3, cfg.eval_size, cfg.eval_size], 'output_shape': [1, 3, cfg.eval_size, cfg.eval_size]},
    'validation': validation_summary,
    'preview': preview_info,
    'artifacts': {
        'best_checkpoint': str(best_ckpt_path),
        'last_checkpoint': str(last_ckpt_path),
        'onnx': str(onnx_path),
        'calibration_manifest': calibration_summary['manifest_path'],
        'conversion_script': str(conversion_script_path),
        'mxq_target': str(mxq_target_path),
        'metrics_csv': str(metrics_csv_path),
    },
    'onnx': onnx_summary,
    'onnx_parity': parity_result,
    'calibration': calibration_summary,
    'mxq_handoff': mxq_handoff,
}
write_json(summary_path, summary)
print({'summary_path': str(summary_path), **summary['artifacts']})
