# %% [markdown]
# # Lab 3 - FSRCNN Residual 96/40/m8 Resume 5400 LR 1.5e-4 (Colab)

# %% [markdown]
# ## 1. Setup

# %%
try:
    import google.colab  # type: ignore
    IN_COLAB_BOOTSTRAP = True
except Exception:
    IN_COLAB_BOOTSTRAP = False

if IN_COLAB_BOOTSTRAP:
    # %pip install -q onnx onnxruntime

import csv
import json
import math
import os
import random
import sys
import time
from contextlib import nullcontext
from dataclasses import asdict, dataclass
from datetime import datetime
from pathlib import Path
from typing import Any

import numpy as np
import onnx
import torch
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
from torch.utils.data import DataLoader, Dataset

IMAGE_SUFFIXES = {'.png', '.jpg', '.jpeg', '.bmp'}
DRIVE_ROOT = Path('/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3')
DRIVE_DATA_ROOT = DRIVE_ROOT / 'Data'
DRIVE_RUNS_ROOT = DRIVE_ROOT / 'runs'

try:
    BICUBIC_RESAMPLE = Image.Resampling.BICUBIC
except AttributeError:
    BICUBIC_RESAMPLE = Image.BICUBIC

try:
    FLIP_LEFT_RIGHT = Image.Transpose.FLIP_LEFT_RIGHT
    FLIP_TOP_BOTTOM = Image.Transpose.FLIP_TOP_BOTTOM
    ROTATE_90 = Image.Transpose.ROTATE_90
    ROTATE_180 = Image.Transpose.ROTATE_180
    ROTATE_270 = Image.Transpose.ROTATE_270
except AttributeError:
    FLIP_LEFT_RIGHT = Image.FLIP_LEFT_RIGHT
    FLIP_TOP_BOTTOM = Image.FLIP_TOP_BOTTOM
    ROTATE_90 = Image.ROTATE_90
    ROTATE_180 = Image.ROTATE_180
    ROTATE_270 = Image.ROTATE_270


def set_global_seed(seed: int) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


def now_stamp() -> str:
    return datetime.now().strftime('%H%M%S_%d%m')


def is_colab_runtime() -> bool:
    try:
        import google.colab  # type: ignore  # noqa: F401
        return True
    except Exception:
        return False


def auto_num_workers(in_colab: bool) -> int:
    if sys.platform == 'darwin':
        return 0
    cpu_count = max(os.cpu_count() or 2, 2)
    if in_colab:
        return min(4, max(cpu_count - 1, 2))
    return min(2, cpu_count)


def resolve_repo_root(start: Path) -> Path:
    current = start.resolve()
    for candidate in [current, *current.parents]:
        if (candidate / 'Data').exists() and (candidate / 'runs').exists():
            return candidate
    for candidate in [current, *current.parents]:
        if (candidate / 'Data').exists():
            return candidate
    raise FileNotFoundError(f'Could not locate repo root from {start.resolve()}')


def make_unique_run_root(runs_root: Path, run_slug: str) -> Path:
    safe_slug = ''.join(ch if ch.isalnum() or ch in '_-' else '_' for ch in run_slug).strip('_')
    candidate = runs_root / f'{now_stamp()}_{safe_slug}'
    while candidate.exists():
        time.sleep(1.1)
        candidate = runs_root / f'{now_stamp()}_{safe_slug}'
    return candidate


def write_json(path: Path, payload: dict[str, Any]) -> None:
    path.parent.mkdir(parents=True, exist_ok=True)
    path.write_text(json.dumps(payload, indent=2, sort_keys=True) + '\n', encoding='utf-8')

# %% [markdown]
# ## 2. Configuration

# %%
@dataclass
class RunConfig:
    model_id: str = 'fsrcnn_residual_96_40_m8'
    run_slug: str = 'fsrcnn_residual_96_40_m8_resume5400_lr150'
    enable_resume: bool = True
    resume_checkpoint_path: str | None = (
        '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/'
        'runs/174208_2704_fsrcnn_residual_96_40_m8/checkpoints/last.pth'
    )
    seed: int = 1337
    train_patch_size: int = 256
    eval_size: int = 256
    batch_size: int = 16
    epochs: int = 5400
    lr: float = 1.5e-4
    min_lr: float = 1e-6
    weight_decay: float = 1e-4
    warmup_epochs: int = 8
    num_workers: int | None = 2
    prefetch_factor: int = 2
    use_amp: bool = True
    use_ema: bool = True
    ema_decay: float = 0.999

cfg = RunConfig()
in_colab = is_colab_runtime()
if in_colab:
    from google.colab import drive  # type: ignore

    drive.mount('/content/drive', force_remount=False)
    data_root = DRIVE_DATA_ROOT
    runs_root = DRIVE_RUNS_ROOT
    if not data_root.exists():
        raise FileNotFoundError(f'Google Drive data root not found: {data_root}')
else:
    repo_root = resolve_repo_root(Path.cwd())
    data_root = repo_root / 'Data'
    runs_root = repo_root / 'runs'
    if not data_root.exists():
        raise FileNotFoundError(f'Data root not found: {data_root}')

runs_root.mkdir(parents=True, exist_ok=True)
if cfg.num_workers is None:
    cfg.num_workers = auto_num_workers(in_colab)
if not cfg.enable_resume:
    cfg.resume_checkpoint_path = None

run_root = make_unique_run_root(runs_root, cfg.run_slug)
checkpoints_dir = run_root / 'checkpoints'
exports_dir = run_root / 'exports'
preview_dir = exports_dir / 'val_preview'
summary_path = run_root / 'summary.json'
metrics_csv_path = run_root / 'metrics.csv'
history_json_path = run_root / 'history.json'
run_manifest_path = run_root / 'run_manifest.json'
run_log_paths = {'metrics_csv': str(metrics_csv_path), 'history_json': str(history_json_path), 'summary_json': str(summary_path), 'run_manifest': str(run_manifest_path)}

for directory in [run_root, checkpoints_dir, exports_dir, preview_dir]:
    directory.mkdir(parents=True, exist_ok=True)

set_global_seed(cfg.seed)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
cuda_enabled = device.type == 'cuda'
gpu_name = torch.cuda.get_device_name(0) if cuda_enabled else None
if cuda_enabled:
    torch.backends.cudnn.benchmark = True
    if hasattr(torch.backends.cuda.matmul, 'allow_tf32'):
        torch.backends.cuda.matmul.allow_tf32 = True

print({
    'device': str(device),
    'in_colab': in_colab,
    'data_root': str(data_root),
    'run_root': str(run_root),
    'gpu_name': gpu_name,
    'config': asdict(cfg),
})
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# {'device': 'cuda', 'in_colab': True, 'data_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/Data', 'run_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/062445_2804_fsrcnn_residual_96_40_m8_resume5400_lr150', 'gpu_name': 'NVIDIA L4', 'config': {'model_id': 'fsrcnn_residual_96_40_m8', 'run_slug': 'fsrcnn_residual_96_40_m8_resume5400_lr150', 'enable_resume': True, 'resume_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/174208_2704_fsrcnn_residual_96_40_m8/checkpoints/last.pth', 'seed': 1337, 'train_patch_size': 256, 'eval_size': 256, 'batch_size': 16, 'epochs': 5400, 'lr': 0.00015, 'min_lr': 1e-06, 'weight_decay': 0.0001, 'warmup_epochs': 8, 'num_workers': 2, 'prefetch_factor': 2, 'use_amp': True, 'use_ema': True, 'ema_decay': 0.999}}

# %% [markdown]
# ## 3. Data

# %%
L3_TRAIN_SPLITS = (
    ('LR_HR/L3_HR_train1', 'L3_LR/L3_L3_train1', 'L3_HR_train1'),
    ('LR_HR/L3_HR_train2', 'L3_LR/L3_L3_train2', 'L3_HR_train2'),
    ('LR_HR/L3_HR_train3', 'L3_LR/L3_LR_train3', 'L3_HR_train3'),
    ('LR_HR/L3_HR_train4', 'L3_LR/L3_LR_train4', 'L3_HR_train4'),
    ('LR_HR/L3_HR_train', 'L3_LR/L3_LR_train', 'L3_HR_train'),
)
L3_VAL_DIRS = ('L3_HR_valid', 'L3_LR_valid')


def scan_image_directory(directory: Path) -> dict[str, Path]:
    if not directory.exists():
        raise FileNotFoundError(f'Missing directory: {directory}')
    return {
        path.stem: path
        for path in directory.iterdir()
        if path.is_file() and path.suffix.lower() in IMAGE_SUFFIXES
    }


def collect_split_pairs(hr_dir: Path, lr_dir: Path, split_name: str) -> list[tuple[Path, Path, str]]:
    hr_map = scan_image_directory(hr_dir)
    lr_map = scan_image_directory(lr_dir)
    shared = sorted(set(hr_map) & set(lr_map))
    if not shared:
        raise FileNotFoundError(f'No paired files found for {split_name}: HR={hr_dir}, LR={lr_dir}')
    hr_only = sorted(set(hr_map) - set(lr_map))
    lr_only = sorted(set(lr_map) - set(hr_map))
    if hr_only or lr_only:
        print({'split': split_name, 'hr_only_count': len(hr_only), 'lr_only_count': len(lr_only)})
    pairs: list[tuple[Path, Path, str]] = []
    for stem in shared:
        name = stem if split_name == 'val' else f'{split_name}/{stem}'
        pairs.append((lr_map[stem], hr_map[stem], name))
    return pairs


def collect_all_pairs(data_root: Path) -> tuple[list[tuple[Path, Path, str]], list[tuple[Path, Path, str]]]:
    train_pairs: list[tuple[Path, Path, str]] = []
    for hr_rel, lr_rel, split_name in L3_TRAIN_SPLITS:
        hr_dir = data_root / hr_rel
        lr_dir = data_root / lr_rel
        if hr_dir.exists() and lr_dir.exists():
            train_pairs.extend(collect_split_pairs(hr_dir, lr_dir, split_name))
        else:
            print({'skipped_missing_train_split': split_name, 'hr_dir': str(hr_dir), 'lr_dir': str(lr_dir)})
    val_pairs = collect_split_pairs(data_root / L3_VAL_DIRS[0], data_root / L3_VAL_DIRS[1], 'val')
    return train_pairs, val_pairs


class PairedSRDataset(Dataset):
    def __init__(self, pairs: list[tuple[Path, Path, str]], *, train: bool, patch_size: int, eval_size: int, seed: int):
        self.pairs = pairs
        self.train = train
        self.patch_size = patch_size
        self.eval_size = eval_size
        self.seed = seed
        self.epoch = 0

    def set_epoch(self, epoch: int) -> None:
        self.epoch = epoch

    @staticmethod
    def to_tensor(img: Image.Image) -> torch.Tensor:
        arr = np.asarray(img, dtype=np.float32) / 255.0
        return torch.from_numpy(arr).permute(2, 0, 1).contiguous()

    def augment_pair(self, lr: Image.Image, hr: Image.Image, index: int) -> tuple[Image.Image, Image.Image]:
        rng = random.Random((self.seed * 1_000_003) + (self.epoch * 9_973) + index)
        width, height = lr.size
        patch = self.patch_size
        if width < patch or height < patch:
            lr = lr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            hr = hr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            width, height = lr.size
        left = rng.randint(0, width - patch)
        top = rng.randint(0, height - patch)
        box = (left, top, left + patch, top + patch)
        lr = lr.crop(box)
        hr = hr.crop(box)
        if rng.random() < 0.5:
            lr = lr.transpose(FLIP_LEFT_RIGHT)
            hr = hr.transpose(FLIP_LEFT_RIGHT)
        if rng.random() < 0.5:
            lr = lr.transpose(FLIP_TOP_BOTTOM)
            hr = hr.transpose(FLIP_TOP_BOTTOM)
        rot = rng.choice([0, 1, 2, 3])
        if rot:
            rotate_ops = [ROTATE_90, ROTATE_180, ROTATE_270]
            lr = lr.transpose(rotate_ops[rot - 1])
            hr = hr.transpose(rotate_ops[rot - 1])
        return lr, hr

    def __len__(self) -> int:
        return len(self.pairs)

    def __getitem__(self, index: int) -> dict[str, Any]:
        lr_path, hr_path, name = self.pairs[index]
        lr = Image.open(lr_path).convert('RGB')
        hr = Image.open(hr_path).convert('RGB')
        if self.train:
            lr, hr = self.augment_pair(lr, hr, index)
        elif lr.size != (self.eval_size, self.eval_size):
            lr = lr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            hr = hr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
        return {'lr': self.to_tensor(lr), 'hr': self.to_tensor(hr), 'name': name}

train_pairs, val_pairs = collect_all_pairs(data_root)
if not train_pairs:
    raise FileNotFoundError(f'No training pairs found under {data_root}')
if not val_pairs:
    raise FileNotFoundError(f'No validation pairs found under {data_root}')

train_ds = PairedSRDataset(train_pairs, train=True, patch_size=cfg.train_patch_size, eval_size=cfg.eval_size, seed=cfg.seed)
val_ds = PairedSRDataset(val_pairs, train=False, patch_size=cfg.train_patch_size, eval_size=cfg.eval_size, seed=cfg.seed)

loader_num_workers = int(cfg.num_workers or 0)
train_loader_kwargs = {
    'dataset': train_ds,
    'batch_size': cfg.batch_size,
    'shuffle': True,
    'num_workers': loader_num_workers,
    'pin_memory': cuda_enabled,
}
val_loader_kwargs = {
    'dataset': val_ds,
    'batch_size': 1,
    'shuffle': False,
    'num_workers': loader_num_workers,
    'pin_memory': cuda_enabled,
}
if loader_num_workers > 0:
    train_loader_kwargs['persistent_workers'] = True
    val_loader_kwargs['persistent_workers'] = True
    train_loader_kwargs['prefetch_factor'] = cfg.prefetch_factor
    val_loader_kwargs['prefetch_factor'] = cfg.prefetch_factor

train_loader = DataLoader(**train_loader_kwargs)
val_loader = DataLoader(**val_loader_kwargs)

sample = train_ds[0]
print({
    'data_root': str(data_root),
    'train_pairs': len(train_pairs),
    'val_pairs': len(val_pairs),
    'train_preview': [name for _, _, name in train_pairs[:5]],
    'val_preview': [name for _, _, name in val_pairs[:5]],
    'sample_lr_shape': tuple(sample['lr'].shape),
    'sample_hr_shape': tuple(sample['hr'].shape),
})
assert tuple(sample['lr'].shape) == (3, cfg.eval_size, cfg.eval_size)
assert tuple(sample['hr'].shape) == (3, cfg.eval_size, cfg.eval_size)
# Out:
# {'data_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/Data', 'train_pairs': 2217, 'val_pairs': 110, 'train_preview': ['L3_HR_train1/0000', 'L3_HR_train1/0001', 'L3_HR_train1/00010', 'L3_HR_train1/000100', 'L3_HR_train1/000101'], 'val_preview': ['0000', '00010', '000100', '000102', '000104'], 'sample_lr_shape': (3, 256, 256), 'sample_hr_shape': (3, 256, 256)}

# %% [markdown]
# ## 4. Model

# %%
class FSRCNNResidualNoUpscale(nn.Module):
    """FSRCNN-style residual refiner for 256x256 RGB input/output."""

    def __init__(self, channels: int = 96, shrink_channels: int = 40, mapping_layers: int = 8, slope: float = 0.10):
        super().__init__()
        self.channels = channels
        self.shrink_channels = shrink_channels
        self.mapping_layers = mapping_layers
        self.slope = slope

        self.features = nn.Sequential(*self._feature_layers())
        self.tail = nn.Conv2d(channels, 3, 3, padding=1, bias=True)
        self.init_tail_small()

    def _activation(self) -> nn.Module:
        return nn.LeakyReLU(self.slope, inplace=False)

    def _feature_layers(self) -> list[nn.Module]:
        stem = [
            nn.Conv2d(3, self.channels, 5, padding=2, bias=True),
            self._activation(),
        ]
        shrink = [
            nn.Conv2d(self.channels, self.shrink_channels, 1, padding=0, bias=True),
            self._activation(),
        ]
        mapping: list[nn.Module] = []
        for _ in range(self.mapping_layers):
            mapping.extend([
                nn.Conv2d(self.shrink_channels, self.shrink_channels, 3, padding=1, bias=True),
                self._activation(),
            ])
        expand = [
            nn.Conv2d(self.shrink_channels, self.channels, 1, padding=0, bias=True),
            self._activation(),
        ]
        return [*stem, *shrink, *mapping, *expand]

    def architecture_summary(self) -> dict[str, str | int]:
        return {
            'stem': f'Conv5x5 3->{self.channels} + LeakyReLU',
            'shrink': f'Conv1x1 {self.channels}->{self.shrink_channels} + LeakyReLU',
            'mapping': f'{self.mapping_layers}x Conv3x3 {self.shrink_channels}->{self.shrink_channels} + LeakyReLU',
            'expand': f'Conv1x1 {self.shrink_channels}->{self.channels} + LeakyReLU',
            'tail': f'Conv3x3 {self.channels}->3 residual delta',
            'forward': 'output = input + residual_delta',
        }

    def init_tail_small(self) -> None:
        nn.init.kaiming_normal_(self.tail.weight, nonlinearity='linear')
        self.tail.weight.data.mul_(1e-3)
        if self.tail.bias is not None:
            nn.init.zeros_(self.tail.bias)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return x + self.tail(self.features(x))


def count_parameters(module: nn.Module) -> int:
    return int(sum(param.numel() for param in module.parameters()))


def operator_audit(module: nn.Module) -> dict[str, int]:
    counts: dict[str, int] = {}
    for child in module.modules():
        if len(list(child.children())) != 0:
            continue
        name = child.__class__.__name__
        counts[name] = counts.get(name, 0) + 1
    return dict(sorted(counts.items()))

model = FSRCNNResidualNoUpscale().to(device)
eval_model = FSRCNNResidualNoUpscale().to(device)
param_count = count_parameters(model)
op_counts = operator_audit(model)
dummy = torch.zeros(1, 3, cfg.eval_size, cfg.eval_size, device=device)
with torch.no_grad():
    dummy_out = model(dummy)

print({
    'model_id': cfg.model_id,
    'params': param_count,
    'operator_audit': op_counts,
    'input_shape': tuple(dummy.shape),
    'output_shape': tuple(dummy_out.shape),
    'architecture': model.architecture_summary(),
})
assert param_count == 133_227, param_count
assert tuple(dummy_out.shape) == (1, 3, cfg.eval_size, cfg.eval_size)
assert set(op_counts).issubset({'Conv2d', 'LeakyReLU'}), op_counts
# Out:
# {'model_id': 'fsrcnn_residual_96_40_m8', 'params': 133227, 'operator_audit': {'Conv2d': 12, 'LeakyReLU': 11}, 'input_shape': (1, 3, 256, 256), 'output_shape': (1, 3, 256, 256), 'architecture': {'stem': 'Conv5x5 3->96 + LeakyReLU', 'shrink': 'Conv1x1 96->40 + LeakyReLU', 'mapping': '8x Conv3x3 40->40 + LeakyReLU', 'expand': 'Conv1x1 40->96 + LeakyReLU', 'tail': 'Conv3x3 96->3 residual delta', 'forward': 'output = input + residual_delta'}}

# %% [markdown]
# ## 5. Training And Validation

# %%
class EMA:
    def __init__(self, model: nn.Module, decay: float):
        self.decay = decay
        self.shadow = {k: v.detach().clone() for k, v in model.state_dict().items()}

    @torch.no_grad()
    def update(self, model: nn.Module) -> None:
        for key, value in model.state_dict().items():
            self.shadow[key].mul_(self.decay).add_(value.detach(), alpha=1.0 - self.decay)

    @torch.no_grad()
    def copy_to(self, model: nn.Module) -> None:
        model.load_state_dict(self.shadow, strict=True)


def make_grad_scaler(enabled: bool):
    if hasattr(torch, 'amp') and hasattr(torch.amp, 'GradScaler'):
        return torch.amp.GradScaler('cuda', enabled=enabled)
    return torch.cuda.amp.GradScaler(enabled=enabled)


def autocast_context(device_type: str, enabled: bool):
    if not enabled:
        return nullcontext()
    if hasattr(torch, 'amp') and hasattr(torch.amp, 'autocast'):
        return torch.amp.autocast(device_type=device_type, enabled=enabled)
    return torch.cuda.amp.autocast(enabled=enabled)


@torch.no_grad()
def batch_psnr(pred: torch.Tensor, target: torch.Tensor) -> float:
    mse = F.mse_loss(pred, target, reduction='none').mean(dim=(1, 2, 3))
    psnr = 10.0 * torch.log10(1.0 / torch.clamp(mse, min=1e-12))
    return float(psnr.mean().item())


def compute_loss(pred: torch.Tensor, lr: torch.Tensor, hr: torch.Tensor) -> torch.Tensor:
    mse = F.mse_loss(pred, hr)
    residual_l1 = F.l1_loss(pred - lr, hr - lr)
    return 0.8 * mse + 0.2 * residual_l1


def lr_at_epoch(epoch_idx: int, *, base_lr: float, min_lr: float, warmup_epochs: int, total_epochs: int) -> float:
    step = epoch_idx + 1
    if warmup_epochs > 0 and step <= warmup_epochs:
        return base_lr * step / max(1, warmup_epochs)
    progress = max(0.0, (step - warmup_epochs) / max(1, total_epochs - warmup_epochs))
    cosine = 0.5 * (1.0 + math.cos(math.pi * min(progress, 1.0)))
    return min_lr + cosine * (base_lr - min_lr)


@torch.inference_mode()
def evaluate_metrics(model: nn.Module, loader: DataLoader, device: torch.device) -> dict[str, float]:
    model.eval()
    pred_meter = 0.0
    input_meter = 0.0
    count = 0
    for batch in loader:
        lr = batch['lr'].to(device, non_blocking=cuda_enabled)
        hr = batch['hr'].to(device, non_blocking=cuda_enabled)
        pred = model(lr).clamp(0.0, 1.0)
        pred_meter += batch_psnr(pred, hr)
        input_meter += batch_psnr(lr, hr)
        count += 1
    val_psnr = pred_meter / max(count, 1)
    input_psnr = input_meter / max(count, 1)
    return {'val_psnr': float(val_psnr), 'input_psnr': float(input_psnr), 'delta_psnr': float(val_psnr - input_psnr)}


def tensor_to_uint8_image(x: torch.Tensor) -> Image.Image:
    x = x.detach().cpu().clamp(0.0, 1.0)
    arr = (x.permute(1, 2, 0).numpy() * 255.0).round().astype(np.uint8)
    return Image.fromarray(arr)


@torch.no_grad()
def write_val_preview(model: nn.Module, loader: DataLoader, out_dir: Path, device: torch.device) -> dict[str, str]:
    out_dir.mkdir(parents=True, exist_ok=True)
    batch = next(iter(loader))
    lr = batch['lr'].to(device, non_blocking=cuda_enabled)
    hr = batch['hr'].to(device, non_blocking=cuda_enabled)
    pred = model(lr).clamp(0.0, 1.0)
    name = batch['name'][0]
    lr_path = out_dir / 'val_preview_input.png'
    pred_path = out_dir / 'val_preview_pred.png'
    hr_path = out_dir / 'val_preview_target.png'
    tensor_to_uint8_image(lr[0]).save(lr_path)
    tensor_to_uint8_image(pred[0]).save(pred_path)
    tensor_to_uint8_image(hr[0]).save(hr_path)
    return {'sample_name': str(name), 'input': str(lr_path), 'prediction': str(pred_path), 'target': str(hr_path)}


def checkpoint_payload(model: nn.Module, ema: EMA | None, optimizer: torch.optim.Optimizer, epoch: int, best_val_psnr: float, row: dict[str, Any]) -> dict[str, Any]:
    return {
        'config': asdict(cfg),
        'epoch': int(epoch),
        'model_state_dict': model.state_dict(),
        'ema_state_dict': ema.shadow if ema is not None else None,
        'optimizer_state_dict': optimizer.state_dict(),
        'best_val_psnr': float(best_val_psnr),
        'latest_metrics': row,
        'model_params': param_count,
        'operator_audit': op_counts,
    }


def load_checkpoint_for_eval(checkpoint_path: Path, device: torch.device) -> nn.Module:
    checkpoint = torch.load(checkpoint_path, map_location=device)
    loaded = FSRCNNResidualNoUpscale().to(device)
    state = checkpoint.get('ema_state_dict') or checkpoint['model_state_dict']
    loaded.load_state_dict(state, strict=True)
    loaded.eval()
    return loaded

optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)
scaler = make_grad_scaler(cfg.use_amp and cuda_enabled)
ema = EMA(model, cfg.ema_decay) if cfg.use_ema else None
best_val_psnr = float('-inf')
start_epoch = 0

metrics_header = ['epoch', 'epoch_time_sec', 'lr', 'train_loss', 'train_psnr', 'val_psnr', 'input_psnr', 'delta_psnr', 'best_val_psnr']
best_ckpt_path = checkpoints_dir / 'best.pth'
last_ckpt_path = checkpoints_dir / 'last.pth'
resume_info: dict[str, Any] = {
    'enabled': cfg.enable_resume,
    'checkpoint_path': cfg.resume_checkpoint_path,
}

if cfg.enable_resume:
    if cfg.resume_checkpoint_path is None:
        raise ValueError('cfg.enable_resume=True requires cfg.resume_checkpoint_path')
    resume_checkpoint_path = Path(cfg.resume_checkpoint_path)
    if not resume_checkpoint_path.exists():
        raise FileNotFoundError(f'Resume checkpoint not found: {resume_checkpoint_path}')
    resume_checkpoint = torch.load(resume_checkpoint_path, map_location=device)
    model.load_state_dict(resume_checkpoint['model_state_dict'], strict=True)
    if 'optimizer_state_dict' in resume_checkpoint:
        optimizer.load_state_dict(resume_checkpoint['optimizer_state_dict'])
    if ema is not None and resume_checkpoint.get('ema_state_dict') is not None:
        ema.shadow = {key: value.detach().clone().to(device) for key, value in resume_checkpoint['ema_state_dict'].items()}
    best_val_psnr = float(resume_checkpoint.get('best_val_psnr', best_val_psnr))
    start_epoch = int(resume_checkpoint.get('epoch', 0))
    resume_info.update({
        'checkpoint_path': str(resume_checkpoint_path),
        'checkpoint_epoch': start_epoch,
        'checkpoint_best_val_psnr': best_val_psnr,
        'checkpoint_latest_metrics': resume_checkpoint.get('latest_metrics'),
        'checkpoint_config': resume_checkpoint.get('config'),
        'checkpoint_model_params': resume_checkpoint.get('model_params'),
        'checkpoint_operator_audit': resume_checkpoint.get('operator_audit'),
    })
    print({
        'resume_checkpoint_path': str(resume_checkpoint_path),
        'resumed_from_epoch': start_epoch,
        'target_total_epochs': cfg.epochs,
        **run_log_paths,
        'best_val_psnr': best_val_psnr,
    })

if start_epoch >= cfg.epochs:
    raise ValueError(f'Resume checkpoint epoch {start_epoch} is already >= target epochs {cfg.epochs}')

history = {
    'metadata': {
        'config': asdict(cfg),
        'run_root': str(run_root),
        'resume_checkpoint_path': cfg.resume_checkpoint_path,
        'resume': resume_info,
        'start_epoch': start_epoch,
        'target_total_epochs': cfg.epochs,
        **run_log_paths,
        'device': str(device),
        'gpu_name': gpu_name,
        'torch_version': torch.__version__,
        'cuda_version': torch.version.cuda,
    },
    'epochs': [],
}
write_json(history_json_path, history)
write_json(run_manifest_path, history['metadata'])

with metrics_csv_path.open('w', newline='', encoding='utf-8') as f:
    csv.DictWriter(f, fieldnames=metrics_header).writeheader()

for epoch in range(start_epoch, cfg.epochs):
    train_ds.set_epoch(epoch)
    epoch_lr = lr_at_epoch(epoch, base_lr=cfg.lr, min_lr=cfg.min_lr, warmup_epochs=cfg.warmup_epochs, total_epochs=cfg.epochs)
    for group in optimizer.param_groups:
        group['lr'] = epoch_lr

    epoch_start = time.time()
    model.train()
    train_loss_sum = 0.0
    train_psnr_sum = 0.0
    train_batches = 0

    for batch in train_loader:
        lr = batch['lr'].to(device, non_blocking=cuda_enabled)
        hr = batch['hr'].to(device, non_blocking=cuda_enabled)
        optimizer.zero_grad(set_to_none=True)
        with autocast_context(device.type, enabled=(cfg.use_amp and cuda_enabled)):
            pred = model(lr)
            loss = compute_loss(pred, lr, hr)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        if ema is not None:
            ema.update(model)
        train_loss_sum += float(loss.item())
        train_psnr_sum += batch_psnr(pred.detach().clamp(0.0, 1.0), hr)
        train_batches += 1

    if ema is not None:
        ema.copy_to(eval_model)
    else:
        eval_model.load_state_dict(model.state_dict())
    eval_model.eval()

    avg_train_loss = train_loss_sum / max(train_batches, 1)
    avg_train_psnr = train_psnr_sum / max(train_batches, 1)
    val_metrics = evaluate_metrics(eval_model, val_loader, device)
    is_best = val_metrics['val_psnr'] > best_val_psnr
    if is_best:
        best_val_psnr = val_metrics['val_psnr']
    row = {
        'epoch': epoch + 1,
        'epoch_time_sec': round(time.time() - epoch_start, 2),
        'lr': epoch_lr,
        'train_loss': round(avg_train_loss, 6),
        'train_psnr': round(avg_train_psnr, 4),
        'val_psnr': round(val_metrics['val_psnr'], 4),
        'input_psnr': round(val_metrics['input_psnr'], 4),
        'delta_psnr': round(val_metrics['delta_psnr'], 4),
        'best_val_psnr': round(best_val_psnr, 4),
    }
    print(row)
    history['epochs'].append(row)
    write_json(history_json_path, history)
    with metrics_csv_path.open('a', newline='', encoding='utf-8') as f:
        csv.DictWriter(f, fieldnames=metrics_header).writerow(row)
    payload = checkpoint_payload(model, ema, optimizer, epoch + 1, best_val_psnr, row)
    torch.save(payload, last_ckpt_path)
    if is_best:
        torch.save(payload, best_ckpt_path)
# Out:
# {'resume_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/174208_2704_fsrcnn_residual_96_40_m8/checkpoints/last.pth', 'resumed_from_epoch': 4000, 'target_total_epochs': 5400, 'metrics_csv': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/062445_2804_fsrcnn_residual_96_40_m8_resume5400_lr150/metrics.csv', 'history_json': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/062445_2804_fsrcnn_residual_96_40_m8_resume5400_lr150/history.json', 'summary_json': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/062445_2804_fsrcnn_residual_96_40_m8_resume5400_lr150/summary.json', 'run_manifest': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/062445_2804_fsrcnn_residual_96_40_m8_resume5400_lr150/run_manifest.json', 'best_val_psnr': 24.03870879086581}
# {'epoch': 4001, 'epoch_time_sec': 63.17, 'lr': 2.4408919569776354e-05, 'train_loss': 0.011599, 'train_psnr': 25.1499, 'val_psnr': 24.0385, 'input_psnr': 23.1331, 'delta_psnr': 0.9054, 'best_val_psnr': 24.0387}
# {'epoch': 4002, 'epoch_time_sec': 41.93, 'lr': 2.4377336756209395e-05, 'train_loss': 0.01159, 'train_psnr': 25.1538, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 4003, 'epoch_time_sec': 41.89, 'lr': 2.434577129719562e-05, 'train_loss': 0.011585, 'train_psnr': 25.1579, 'val_psnr': 24.0387, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 4004, 'epoch_time_sec': 41.63, 'lr': 2.431422320345049e-05, 'train_loss': 0.011586, 'train_psnr': 25.1569, 'val_psnr': 24.0387, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 4005, 'epoch_time_sec': 41.82, 'lr': 2.4282692485683642e-05, 'train_loss': 0.011584, 'train_psnr': 25.1586, 'val_psnr': 24.0387, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 4006, 'epoch_time_sec': 41.64, 'lr': 2.425117915459871e-05, 'train_loss': 0.011604, 'train_psnr': 25.1495, 'val_psnr': 24.0388, 'input_psnr': 23.1331, 'delta_psnr': 0.9057, 'best_val_psnr': 24.0388}
# {'epoch': 4007, 'epoch_time_sec': 41.92, 'lr': 2.4219683220893597e-05, 'train_loss': 0.011581, 'train_psnr': 25.1593, 'val_psnr': 24.0385, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0388}
# {'epoch': 4008, 'epoch_time_sec': 41.78, 'lr': 2.418820469526009e-05, 'train_loss': 0.011583, 'train_psnr': 25.1597, 'val_psnr': 24.0387, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0388}
# {'epoch': 4009, 'epoch_time_sec': 41.88, 'lr': 2.4156743588384196e-05, 'train_loss': 0.011596, 'train_psnr': 25.1553, 'val_psnr': 24.0388, 'input_psnr': 23.1331, 'delta_psnr': 0.9058, 'best_val_psnr': 24.0388}
# {'epoch': 4010, 'epoch_time_sec': 42.29, 'lr': 2.412529991094601e-05, 'train_loss': 0.011582, 'train_psnr': 25.1601, 'val_psnr': 24.0387, 'input_psnr': 23.1331, 'delta_psnr': 0.9057, 'best_val_psnr': 24.0388}
# {'epoch': 4011, 'epoch_time_sec': 42.21, 'lr': 2.409387367361968e-05, 'train_loss': 0.011575, 'train_psnr': 25.1644, 'val_psnr': 24.0388, 'input_psnr': 23.1331, 'delta_psnr': 0.9058, 'best_val_psnr': 24.0388}
# {'epoch': 4012, 'epoch_time_sec': 41.78, 'lr': 2.406246488707338e-05, 'train_loss': 0.011588, 'train_psnr': 25.1564, 'val_psnr': 24.0388, 'input_psnr': 23.1331, 'delta_psnr': 0.9058, 'best_val_psnr': 24.0388}
# {'epoch': 4013, 'epoch_time_sec': 42.01, 'lr': 2.4031073561969478e-05, 'train_loss': 0.011595, 'train_psnr': 25.1524, 'val_psnr': 24.0388, 'input_psnr': 23.1331, 'delta_psnr': 0.9057, 'best_val_psnr': 24.0388}
# {'epoch': 4014, 'epoch_time_sec': 41.8, 'lr': 2.3999699708964307e-05, 'train_loss': 0.011587, 'train_psnr': 25.1571, 'val_psnr': 24.0387, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0388}
# {'epoch': 4015, 'epoch_time_sec': 42.07, 'lr': 2.3968343338708384e-05, 'train_loss': 0.011591, 'train_psnr': 25.1561, 'val_psnr': 24.0389, 'input_psnr': 23.1331, 'delta_psnr': 0.9058, 'best_val_psnr': 24.0389}
# {'epoch': 4016, 'epoch_time_sec': 41.83, 'lr': 2.393700446184614e-05, 'train_loss': 0.011586, 'train_psnr': 25.1573, 'val_psnr': 24.0388, 'input_psnr': 23.1331, 'delta_psnr': 0.9057, 'best_val_psnr': 24.0389}
# {'epoch': 4017, 'epoch_time_sec': 41.81, 'lr': 2.3905683089016167e-05, 'train_loss': 0.01158, 'train_psnr': 25.16, 'val_psnr': 24.0388, 'input_psnr': 23.1331, 'delta_psnr': 0.9058, 'best_val_psnr': 24.0389}
# {'epoch': 4018, 'epoch_time_sec': 41.99, 'lr': 2.387437923085113e-05, 'train_loss': 0.011577, 'train_psnr': 25.162, 'val_psnr': 24.0389, 'input_psnr': 23.1331, 'delta_psnr': 0.9058, 'best_val_psnr': 24.0389}
# {'epoch': 4019, 'epoch_time_sec': 41.8, 'lr': 2.3843092897977724e-05, 'train_loss': 0.011578, 'train_psnr': 25.1652, 'val_psnr': 24.0391, 'input_psnr': 23.1331, 'delta_psnr': 0.906, 'best_val_psnr': 24.0391}
# {'epoch': 4020, 'epoch_time_sec': 42.64, 'lr': 2.3811824101016604e-05, 'train_loss': 0.011589, 'train_psnr': 25.1574, 'val_psnr': 24.0391, 'input_psnr': 23.1331, 'delta_psnr': 0.906, 'best_val_psnr': 24.0391}
# {'epoch': 4021, 'epoch_time_sec': 42.42, 'lr': 2.3780572850582633e-05, 'train_loss': 0.011581, 'train_psnr': 25.1611, 'val_psnr': 24.039, 'input_psnr': 23.1331, 'delta_psnr': 0.9059, 'best_val_psnr': 24.0391}
# {'epoch': 4022, 'epoch_time_sec': 41.87, 'lr': 2.374933915728458e-05, 'train_loss': 0.011578, 'train_psnr': 25.1619, 'val_psnr': 24.0391, 'input_psnr': 23.1331, 'delta_psnr': 0.906, 'best_val_psnr': 24.0391}
# {'epoch': 4023, 'epoch_time_sec': 42.02, 'lr': 2.3718123031725394e-05, 'train_loss': 0.011581, 'train_psnr': 25.1631, 'val_psnr': 24.0392, 'input_psnr': 23.1331, 'delta_psnr': 0.9061, 'best_val_psnr': 24.0392}
# {'epoch': 4024, 'epoch_time_sec': 41.72, 'lr': 2.3686924484501905e-05, 'train_loss': 0.011582, 'train_psnr': 25.1621, 'val_psnr': 24.0392, 'input_psnr': 23.1331, 'delta_psnr': 0.9061, 'best_val_psnr': 24.0392}
# {'epoch': 4025, 'epoch_time_sec': 41.83, 'lr': 2.3655743526205038e-05, 'train_loss': 0.01158, 'train_psnr': 25.1594, 'val_psnr': 24.039, 'input_psnr': 23.1331, 'delta_psnr': 0.906, 'best_val_psnr': 24.0392}
# {'epoch': 4026, 'epoch_time_sec': 41.73, 'lr': 2.3624580167419826e-05, 'train_loss': 0.011596, 'train_psnr': 25.1567, 'val_psnr': 24.0391, 'input_psnr': 23.1331, 'delta_psnr': 0.906, 'best_val_psnr': 24.0392}
# {'epoch': 4027, 'epoch_time_sec': 41.88, 'lr': 2.359343441872522e-05, 'train_loss': 0.011577, 'train_psnr': 25.1636, 'val_psnr': 24.0391, 'input_psnr': 23.1331, 'delta_psnr': 0.9061, 'best_val_psnr': 24.0392}
# {'epoch': 4028, 'epoch_time_sec': 42.06, 'lr': 2.3562306290694236e-05, 'train_loss': 0.011572, 'train_psnr': 25.1668, 'val_psnr': 24.0392, 'input_psnr': 23.1331, 'delta_psnr': 0.9061, 'best_val_psnr': 24.0392}
# {'epoch': 4029, 'epoch_time_sec': 41.87, 'lr': 2.3531195793893904e-05, 'train_loss': 0.01158, 'train_psnr': 25.1625, 'val_psnr': 24.0392, 'input_psnr': 23.1331, 'delta_psnr': 0.9061, 'best_val_psnr': 24.0392}
# {'epoch': 4030, 'epoch_time_sec': 42.53, 'lr': 2.3500102938885245e-05, 'train_loss': 0.011569, 'train_psnr': 25.17, 'val_psnr': 24.0392, 'input_psnr': 23.1331, 'delta_psnr': 0.9061, 'best_val_psnr': 24.0392}
# {'epoch': 4031, 'epoch_time_sec': 42.44, 'lr': 2.3469027736223395e-05, 'train_loss': 0.011593, 'train_psnr': 25.1569, 'val_psnr': 24.0393, 'input_psnr': 23.1331, 'delta_psnr': 0.9062, 'best_val_psnr': 24.0393}
# {'epoch': 4032, 'epoch_time_sec': 41.98, 'lr': 2.3437970196457328e-05, 'train_loss': 0.011605, 'train_psnr': 25.1536, 'val_psnr': 24.0392, 'input_psnr': 23.1331, 'delta_psnr': 0.9061, 'best_val_psnr': 24.0393}
# {'epoch': 4033, 'epoch_time_sec': 41.92, 'lr': 2.340693033013014e-05, 'train_loss': 0.011589, 'train_psnr': 25.1585, 'val_psnr': 24.0393, 'input_psnr': 23.1331, 'delta_psnr': 0.9062, 'best_val_psnr': 24.0393}
# {'epoch': 4034, 'epoch_time_sec': 41.94, 'lr': 2.3375908147778924e-05, 'train_loss': 0.011567, 'train_psnr': 25.169, 'val_psnr': 24.0393, 'input_psnr': 23.1331, 'delta_psnr': 0.9062, 'best_val_psnr': 24.0393}
# {'epoch': 4035, 'epoch_time_sec': 41.92, 'lr': 2.334490365993473e-05, 'train_loss': 0.011583, 'train_psnr': 25.1586, 'val_psnr': 24.0391, 'input_psnr': 23.1331, 'delta_psnr': 0.906, 'best_val_psnr': 24.0393}
# {'epoch': 4036, 'epoch_time_sec': 41.86, 'lr': 2.3313916877122618e-05, 'train_loss': 0.011578, 'train_psnr': 25.1629, 'val_psnr': 24.0391, 'input_psnr': 23.1331, 'delta_psnr': 0.906, 'best_val_psnr': 24.0393}
# {'epoch': 4037, 'epoch_time_sec': 41.89, 'lr': 2.3282947809861637e-05, 'train_loss': 0.011592, 'train_psnr': 25.1576, 'val_psnr': 24.0392, 'input_psnr': 23.1331, 'delta_psnr': 0.9061, 'best_val_psnr': 24.0393}
# {'epoch': 4038, 'epoch_time_sec': 41.94, 'lr': 2.325199646866482e-05, 'train_loss': 0.011573, 'train_psnr': 25.1666, 'val_psnr': 24.0391, 'input_psnr': 23.1331, 'delta_psnr': 0.9061, 'best_val_psnr': 24.0393}
# {'epoch': 4039, 'epoch_time_sec': 41.89, 'lr': 2.3221062864039176e-05, 'train_loss': 0.011573, 'train_psnr': 25.1649, 'val_psnr': 24.0392, 'input_psnr': 23.1331, 'delta_psnr': 0.9061, 'best_val_psnr': 24.0393}
# {'epoch': 4040, 'epoch_time_sec': 42.12, 'lr': 2.319014700648571e-05, 'train_loss': 0.011586, 'train_psnr': 25.1586, 'val_psnr': 24.0392, 'input_psnr': 23.1331, 'delta_psnr': 0.9061, 'best_val_psnr': 24.0393}
# {'epoch': 4041, 'epoch_time_sec': 42.5, 'lr': 2.3159248906499374e-05, 'train_loss': 0.011571, 'train_psnr': 25.1669, 'val_psnr': 24.0392, 'input_psnr': 23.1331, 'delta_psnr': 0.9061, 'best_val_psnr': 24.0393}
# {'epoch': 4042, 'epoch_time_sec': 41.97, 'lr': 2.3128368574569146e-05, 'train_loss': 0.011579, 'train_psnr': 25.1632, 'val_psnr': 24.0391, 'input_psnr': 23.1331, 'delta_psnr': 0.9061, 'best_val_psnr': 24.0393}
# {'epoch': 4043, 'epoch_time_sec': 41.67, 'lr': 2.3097506021177924e-05, 'train_loss': 0.011571, 'train_psnr': 25.1662, 'val_psnr': 24.0392, 'input_psnr': 23.1331, 'delta_psnr': 0.9061, 'best_val_psnr': 24.0393}
# {'epoch': 4044, 'epoch_time_sec': 41.95, 'lr': 2.3066661256802586e-05, 'train_loss': 0.011591, 'train_psnr': 25.1581, 'val_psnr': 24.0393, 'input_psnr': 23.1331, 'delta_psnr': 0.9062, 'best_val_psnr': 24.0393}
# {'epoch': 4045, 'epoch_time_sec': 41.81, 'lr': 2.3035834291913968e-05, 'train_loss': 0.011574, 'train_psnr': 25.1647, 'val_psnr': 24.0393, 'input_psnr': 23.1331, 'delta_psnr': 0.9063, 'best_val_psnr': 24.0393}
# {'epoch': 4046, 'epoch_time_sec': 41.77, 'lr': 2.300502513697685e-05, 'train_loss': 0.011576, 'train_psnr': 25.1636, 'val_psnr': 24.0394, 'input_psnr': 23.1331, 'delta_psnr': 0.9063, 'best_val_psnr': 24.0394}
# {'epoch': 4047, 'epoch_time_sec': 41.79, 'lr': 2.2974233802450006e-05, 'train_loss': 0.01158, 'train_psnr': 25.1598, 'val_psnr': 24.0394, 'input_psnr': 23.1331, 'delta_psnr': 0.9063, 'best_val_psnr': 24.0394}
# {'epoch': 4048, 'epoch_time_sec': 41.96, 'lr': 2.2943460298786114e-05, 'train_loss': 0.011582, 'train_psnr': 25.1609, 'val_psnr': 24.0394, 'input_psnr': 23.1331, 'delta_psnr': 0.9063, 'best_val_psnr': 24.0394}
# {'epoch': 4049, 'epoch_time_sec': 41.94, 'lr': 2.291270463643181e-05, 'train_loss': 0.011592, 'train_psnr': 25.1568, 'val_psnr': 24.0394, 'input_psnr': 23.1331, 'delta_psnr': 0.9063, 'best_val_psnr': 24.0394}
# {'epoch': 4050, 'epoch_time_sec': 42.53, 'lr': 2.2881966825827727e-05, 'train_loss': 0.011588, 'train_psnr': 25.1594, 'val_psnr': 24.0395, 'input_psnr': 23.1331, 'delta_psnr': 0.9064, 'best_val_psnr': 24.0395}
# {'epoch': 4051, 'epoch_time_sec': 42.58, 'lr': 2.285124687740837e-05, 'train_loss': 0.011571, 'train_psnr': 25.1664, 'val_psnr': 24.0394, 'input_psnr': 23.1331, 'delta_psnr': 0.9063, 'best_val_psnr': 24.0395}
# {'epoch': 4052, 'epoch_time_sec': 41.98, 'lr': 2.2820544801602213e-05, 'train_loss': 0.011571, 'train_psnr': 25.1674, 'val_psnr': 24.0394, 'input_psnr': 23.1331, 'delta_psnr': 0.9063, 'best_val_psnr': 24.0395}
# {'epoch': 4053, 'epoch_time_sec': 42.0, 'lr': 2.2789860608831644e-05, 'train_loss': 0.011577, 'train_psnr': 25.1626, 'val_psnr': 24.0395, 'input_psnr': 23.1331, 'delta_psnr': 0.9064, 'best_val_psnr': 24.0395}
# {'epoch': 4054, 'epoch_time_sec': 41.88, 'lr': 2.2759194309513002e-05, 'train_loss': 0.011565, 'train_psnr': 25.1697, 'val_psnr': 24.0395, 'input_psnr': 23.1331, 'delta_psnr': 0.9065, 'best_val_psnr': 24.0395}
# {'epoch': 4055, 'epoch_time_sec': 41.88, 'lr': 2.2728545914056537e-05, 'train_loss': 0.01158, 'train_psnr': 25.1609, 'val_psnr': 24.0396, 'input_psnr': 23.1331, 'delta_psnr': 0.9065, 'best_val_psnr': 24.0396}
# {'epoch': 4056, 'epoch_time_sec': 41.58, 'lr': 2.269791543286641e-05, 'train_loss': 0.011595, 'train_psnr': 25.1572, 'val_psnr': 24.0395, 'input_psnr': 23.1331, 'delta_psnr': 0.9065, 'best_val_psnr': 24.0396}
# {'epoch': 4057, 'epoch_time_sec': 41.9, 'lr': 2.2667302876340742e-05, 'train_loss': 0.011571, 'train_psnr': 25.1671, 'val_psnr': 24.0396, 'input_psnr': 23.1331, 'delta_psnr': 0.9065, 'best_val_psnr': 24.0396}
# {'epoch': 4058, 'epoch_time_sec': 41.97, 'lr': 2.2636708254871538e-05, 'train_loss': 0.011576, 'train_psnr': 25.1633, 'val_psnr': 24.0396, 'input_psnr': 23.1331, 'delta_psnr': 0.9066, 'best_val_psnr': 24.0396}
# {'epoch': 4059, 'epoch_time_sec': 42.14, 'lr': 2.2606131578844717e-05, 'train_loss': 0.01157, 'train_psnr': 25.166, 'val_psnr': 24.0396, 'input_psnr': 23.1331, 'delta_psnr': 0.9066, 'best_val_psnr': 24.0396}
# {'epoch': 4060, 'epoch_time_sec': 42.53, 'lr': 2.2575572858640102e-05, 'train_loss': 0.011567, 'train_psnr': 25.1677, 'val_psnr': 24.0397, 'input_psnr': 23.1331, 'delta_psnr': 0.9067, 'best_val_psnr': 24.0397}
# {'epoch': 4061, 'epoch_time_sec': 42.63, 'lr': 2.2545032104631428e-05, 'train_loss': 0.01158, 'train_psnr': 25.1633, 'val_psnr': 24.0397, 'input_psnr': 23.1331, 'delta_psnr': 0.9066, 'best_val_psnr': 24.0397}
# {'epoch': 4062, 'epoch_time_sec': 41.89, 'lr': 2.2514509327186348e-05, 'train_loss': 0.011578, 'train_psnr': 25.1621, 'val_psnr': 24.0397, 'input_psnr': 23.1331, 'delta_psnr': 0.9066, 'best_val_psnr': 24.0397}
# {'epoch': 4063, 'epoch_time_sec': 41.92, 'lr': 2.2484004536666368e-05, 'train_loss': 0.011567, 'train_psnr': 25.1694, 'val_psnr': 24.0396, 'input_psnr': 23.1331, 'delta_psnr': 0.9065, 'best_val_psnr': 24.0397}
# {'epoch': 4064, 'epoch_time_sec': 41.91, 'lr': 2.2453517743426914e-05, 'train_loss': 0.011572, 'train_psnr': 25.1654, 'val_psnr': 24.0396, 'input_psnr': 23.1331, 'delta_psnr': 0.9065, 'best_val_psnr': 24.0397}
# {'epoch': 4065, 'epoch_time_sec': 41.93, 'lr': 2.242304895781733e-05, 'train_loss': 0.011565, 'train_psnr': 25.1701, 'val_psnr': 24.0396, 'input_psnr': 23.1331, 'delta_psnr': 0.9065, 'best_val_psnr': 24.0397}
# {'epoch': 4066, 'epoch_time_sec': 41.7, 'lr': 2.2392598190180822e-05, 'train_loss': 0.011569, 'train_psnr': 25.1674, 'val_psnr': 24.0395, 'input_psnr': 23.1331, 'delta_psnr': 0.9065, 'best_val_psnr': 24.0397}
# {'epoch': 4067, 'epoch_time_sec': 42.05, 'lr': 2.2362165450854457e-05, 'train_loss': 0.011595, 'train_psnr': 25.156, 'val_psnr': 24.0396, 'input_psnr': 23.1331, 'delta_psnr': 0.9065, 'best_val_psnr': 24.0397}
# {'epoch': 4068, 'epoch_time_sec': 41.9, 'lr': 2.233175075016922e-05, 'train_loss': 0.011574, 'train_psnr': 25.1632, 'val_psnr': 24.0396, 'input_psnr': 23.1331, 'delta_psnr': 0.9066, 'best_val_psnr': 24.0397}
# {'epoch': 4069, 'epoch_time_sec': 42.07, 'lr': 2.230135409844994e-05, 'train_loss': 0.011589, 'train_psnr': 25.1581, 'val_psnr': 24.0396, 'input_psnr': 23.1331, 'delta_psnr': 0.9066, 'best_val_psnr': 24.0397}
# {'epoch': 4070, 'epoch_time_sec': 42.42, 'lr': 2.2270975506015337e-05, 'train_loss': 0.01157, 'train_psnr': 25.1691, 'val_psnr': 24.0396, 'input_psnr': 23.1331, 'delta_psnr': 0.9066, 'best_val_psnr': 24.0397}
# {'epoch': 4071, 'epoch_time_sec': 42.57, 'lr': 2.2240614983177996e-05, 'train_loss': 0.011565, 'train_psnr': 25.1712, 'val_psnr': 24.0395, 'input_psnr': 23.1331, 'delta_psnr': 0.9065, 'best_val_psnr': 24.0397}
# {'epoch': 4072, 'epoch_time_sec': 41.77, 'lr': 2.221027254024436e-05, 'train_loss': 0.011571, 'train_psnr': 25.166, 'val_psnr': 24.0396, 'input_psnr': 23.1331, 'delta_psnr': 0.9065, 'best_val_psnr': 24.0397}
# {'epoch': 4073, 'epoch_time_sec': 41.92, 'lr': 2.217994818751478e-05, 'train_loss': 0.011572, 'train_psnr': 25.1649, 'val_psnr': 24.0397, 'input_psnr': 23.1331, 'delta_psnr': 0.9066, 'best_val_psnr': 24.0397}
# {'epoch': 4074, 'epoch_time_sec': 41.82, 'lr': 2.214964193528343e-05, 'train_loss': 0.011583, 'train_psnr': 25.1632, 'val_psnr': 24.0397, 'input_psnr': 23.1331, 'delta_psnr': 0.9067, 'best_val_psnr': 24.0397}
# {'epoch': 4075, 'epoch_time_sec': 42.08, 'lr': 2.2119353793838274e-05, 'train_loss': 0.011574, 'train_psnr': 25.1685, 'val_psnr': 24.0398, 'input_psnr': 23.1331, 'delta_psnr': 0.9067, 'best_val_psnr': 24.0398}
# {'epoch': 4076, 'epoch_time_sec': 42.09, 'lr': 2.208908377346126e-05, 'train_loss': 0.011568, 'train_psnr': 25.1688, 'val_psnr': 24.0396, 'input_psnr': 23.1331, 'delta_psnr': 0.9066, 'best_val_psnr': 24.0398}
# {'epoch': 4077, 'epoch_time_sec': 41.89, 'lr': 2.205883188442809e-05, 'train_loss': 0.011565, 'train_psnr': 25.1702, 'val_psnr': 24.0396, 'input_psnr': 23.1331, 'delta_psnr': 0.9066, 'best_val_psnr': 24.0398}
# {'epoch': 4078, 'epoch_time_sec': 41.84, 'lr': 2.202859813700835e-05, 'train_loss': 0.011576, 'train_psnr': 25.1662, 'val_psnr': 24.0396, 'input_psnr': 23.1331, 'delta_psnr': 0.9066, 'best_val_psnr': 24.0398}
# {'epoch': 4079, 'epoch_time_sec': 41.86, 'lr': 2.199838254146545e-05, 'train_loss': 0.011574, 'train_psnr': 25.1665, 'val_psnr': 24.0397, 'input_psnr': 23.1331, 'delta_psnr': 0.9066, 'best_val_psnr': 24.0398}
# {'epoch': 4080, 'epoch_time_sec': 42.21, 'lr': 2.1968185108056626e-05, 'train_loss': 0.011569, 'train_psnr': 25.1673, 'val_psnr': 24.0397, 'input_psnr': 23.1331, 'delta_psnr': 0.9066, 'best_val_psnr': 24.0398}
# {'epoch': 4081, 'epoch_time_sec': 42.66, 'lr': 2.1938005847032997e-05, 'train_loss': 0.011578, 'train_psnr': 25.1641, 'val_psnr': 24.0397, 'input_psnr': 23.1331, 'delta_psnr': 0.9066, 'best_val_psnr': 24.0398}
# {'epoch': 4082, 'epoch_time_sec': 41.69, 'lr': 2.1907844768639507e-05, 'train_loss': 0.011571, 'train_psnr': 25.1668, 'val_psnr': 24.0396, 'input_psnr': 23.1331, 'delta_psnr': 0.9066, 'best_val_psnr': 24.0398}
# {'epoch': 4083, 'epoch_time_sec': 41.85, 'lr': 2.1877701883114814e-05, 'train_loss': 0.011583, 'train_psnr': 25.1616, 'val_psnr': 24.0398, 'input_psnr': 23.1331, 'delta_psnr': 0.9067, 'best_val_psnr': 24.0398}
# {'epoch': 4084, 'epoch_time_sec': 41.89, 'lr': 2.184757720069157e-05, 'train_loss': 0.011576, 'train_psnr': 25.1646, 'val_psnr': 24.0397, 'input_psnr': 23.1331, 'delta_psnr': 0.9067, 'best_val_psnr': 24.0398}
# {'epoch': 4085, 'epoch_time_sec': 41.97, 'lr': 2.1817470731596113e-05, 'train_loss': 0.011583, 'train_psnr': 25.1605, 'val_psnr': 24.0397, 'input_psnr': 23.1331, 'delta_psnr': 0.9067, 'best_val_psnr': 24.0398}
# {'epoch': 4086, 'epoch_time_sec': 41.88, 'lr': 2.1787382486048737e-05, 'train_loss': 0.011569, 'train_psnr': 25.1677, 'val_psnr': 24.0397, 'input_psnr': 23.1331, 'delta_psnr': 0.9067, 'best_val_psnr': 24.0398}
# {'epoch': 4087, 'epoch_time_sec': 41.85, 'lr': 2.1757312474263378e-05, 'train_loss': 0.011567, 'train_psnr': 25.1694, 'val_psnr': 24.0397, 'input_psnr': 23.1331, 'delta_psnr': 0.9066, 'best_val_psnr': 24.0398}
# {'epoch': 4088, 'epoch_time_sec': 41.89, 'lr': 2.1727260706447875e-05, 'train_loss': 0.011575, 'train_psnr': 25.1649, 'val_psnr': 24.0397, 'input_psnr': 23.1331, 'delta_psnr': 0.9066, 'best_val_psnr': 24.0398}
# {'epoch': 4089, 'epoch_time_sec': 41.94, 'lr': 2.1697227192803916e-05, 'train_loss': 0.011563, 'train_psnr': 25.1706, 'val_psnr': 24.0398, 'input_psnr': 23.1331, 'delta_psnr': 0.9067, 'best_val_psnr': 24.0398}
# {'epoch': 4090, 'epoch_time_sec': 42.47, 'lr': 2.1667211943526942e-05, 'train_loss': 0.011589, 'train_psnr': 25.1591, 'val_psnr': 24.0398, 'input_psnr': 23.1331, 'delta_psnr': 0.9067, 'best_val_psnr': 24.0398}
# {'epoch': 4091, 'epoch_time_sec': 42.36, 'lr': 2.1637214968806136e-05, 'train_loss': 0.011568, 'train_psnr': 25.1692, 'val_psnr': 24.0398, 'input_psnr': 23.1331, 'delta_psnr': 0.9067, 'best_val_psnr': 24.0398}
# {'epoch': 4092, 'epoch_time_sec': 41.7, 'lr': 2.1607236278824592e-05, 'train_loss': 0.011581, 'train_psnr': 25.1625, 'val_psnr': 24.0398, 'input_psnr': 23.1331, 'delta_psnr': 0.9067, 'best_val_psnr': 24.0398}
# {'epoch': 4093, 'epoch_time_sec': 42.08, 'lr': 2.15772758837591e-05, 'train_loss': 0.011572, 'train_psnr': 25.1658, 'val_psnr': 24.0398, 'input_psnr': 23.1331, 'delta_psnr': 0.9067, 'best_val_psnr': 24.0398}
# {'epoch': 4094, 'epoch_time_sec': 41.86, 'lr': 2.154733379378036e-05, 'train_loss': 0.011576, 'train_psnr': 25.1648, 'val_psnr': 24.0398, 'input_psnr': 23.1331, 'delta_psnr': 0.9068, 'best_val_psnr': 24.0398}
# {'epoch': 4095, 'epoch_time_sec': 41.82, 'lr': 2.15174100190527e-05, 'train_loss': 0.011562, 'train_psnr': 25.1717, 'val_psnr': 24.0399, 'input_psnr': 23.1331, 'delta_psnr': 0.9068, 'best_val_psnr': 24.0399}
# {'epoch': 4096, 'epoch_time_sec': 42.02, 'lr': 2.1487504569734318e-05, 'train_loss': 0.011566, 'train_psnr': 25.1695, 'val_psnr': 24.0399, 'input_psnr': 23.1331, 'delta_psnr': 0.9068, 'best_val_psnr': 24.0399}
# {'epoch': 4097, 'epoch_time_sec': 41.79, 'lr': 2.145761745597723e-05, 'train_loss': 0.01158, 'train_psnr': 25.1615, 'val_psnr': 24.0399, 'input_psnr': 23.1331, 'delta_psnr': 0.9069, 'best_val_psnr': 24.0399}
# {'epoch': 4098, 'epoch_time_sec': 41.65, 'lr': 2.1427748687927166e-05, 'train_loss': 0.011569, 'train_psnr': 25.1675, 'val_psnr': 24.0399, 'input_psnr': 23.1331, 'delta_psnr': 0.9069, 'best_val_psnr': 24.0399}
# {'epoch': 4099, 'epoch_time_sec': 42.06, 'lr': 2.1397898275723595e-05, 'train_loss': 0.011577, 'train_psnr': 25.1653, 'val_psnr': 24.0399, 'input_psnr': 23.1331, 'delta_psnr': 0.9069, 'best_val_psnr': 24.0399}
# {'epoch': 4100, 'epoch_time_sec': 42.33, 'lr': 2.136806622949986e-05, 'train_loss': 0.01159, 'train_psnr': 25.159, 'val_psnr': 24.04, 'input_psnr': 23.1331, 'delta_psnr': 0.907, 'best_val_psnr': 24.04}
# {'epoch': 4101, 'epoch_time_sec': 42.45, 'lr': 2.133825255938299e-05, 'train_loss': 0.011579, 'train_psnr': 25.1662, 'val_psnr': 24.0399, 'input_psnr': 23.1331, 'delta_psnr': 0.9069, 'best_val_psnr': 24.04}
# {'epoch': 4102, 'epoch_time_sec': 41.7, 'lr': 2.13084572754938e-05, 'train_loss': 0.011573, 'train_psnr': 25.1672, 'val_psnr': 24.04, 'input_psnr': 23.1331, 'delta_psnr': 0.907, 'best_val_psnr': 24.04}
# {'epoch': 4103, 'epoch_time_sec': 41.68, 'lr': 2.1278680387946865e-05, 'train_loss': 0.011563, 'train_psnr': 25.1716, 'val_psnr': 24.04, 'input_psnr': 23.1331, 'delta_psnr': 0.9069, 'best_val_psnr': 24.04}
# {'epoch': 4104, 'epoch_time_sec': 41.87, 'lr': 2.1248921906850485e-05, 'train_loss': 0.011569, 'train_psnr': 25.1685, 'val_psnr': 24.0399, 'input_psnr': 23.1331, 'delta_psnr': 0.9069, 'best_val_psnr': 24.04}
# {'epoch': 4105, 'epoch_time_sec': 41.92, 'lr': 2.1219181842306774e-05, 'train_loss': 0.011572, 'train_psnr': 25.1668, 'val_psnr': 24.0399, 'input_psnr': 23.1331, 'delta_psnr': 0.9068, 'best_val_psnr': 24.04}
# {'epoch': 4106, 'epoch_time_sec': 41.79, 'lr': 2.118946020441156e-05, 'train_loss': 0.011569, 'train_psnr': 25.1684, 'val_psnr': 24.0399, 'input_psnr': 23.1331, 'delta_psnr': 0.9068, 'best_val_psnr': 24.04}
# {'epoch': 4107, 'epoch_time_sec': 42.06, 'lr': 2.115975700325439e-05, 'train_loss': 0.011564, 'train_psnr': 25.1701, 'val_psnr': 24.04, 'input_psnr': 23.1331, 'delta_psnr': 0.9069, 'best_val_psnr': 24.04}
# {'epoch': 4108, 'epoch_time_sec': 41.95, 'lr': 2.1130072248918585e-05, 'train_loss': 0.011575, 'train_psnr': 25.1668, 'val_psnr': 24.0401, 'input_psnr': 23.1331, 'delta_psnr': 0.907, 'best_val_psnr': 24.0401}
# {'epoch': 4109, 'epoch_time_sec': 41.9, 'lr': 2.11004059514812e-05, 'train_loss': 0.011577, 'train_psnr': 25.1657, 'val_psnr': 24.0401, 'input_psnr': 23.1331, 'delta_psnr': 0.907, 'best_val_psnr': 24.0401}
# {'epoch': 4110, 'epoch_time_sec': 42.52, 'lr': 2.107075812101302e-05, 'train_loss': 0.011564, 'train_psnr': 25.1687, 'val_psnr': 24.0401, 'input_psnr': 23.1331, 'delta_psnr': 0.907, 'best_val_psnr': 24.0401}
# {'epoch': 4111, 'epoch_time_sec': 42.47, 'lr': 2.104112876757855e-05, 'train_loss': 0.011565, 'train_psnr': 25.1706, 'val_psnr': 24.04, 'input_psnr': 23.1331, 'delta_psnr': 0.907, 'best_val_psnr': 24.0401}
# {'epoch': 4112, 'epoch_time_sec': 41.66, 'lr': 2.1011517901236022e-05, 'train_loss': 0.011574, 'train_psnr': 25.1679, 'val_psnr': 24.0401, 'input_psnr': 23.1331, 'delta_psnr': 0.907, 'best_val_psnr': 24.0401}
# {'epoch': 4113, 'epoch_time_sec': 41.73, 'lr': 2.0981925532037445e-05, 'train_loss': 0.011569, 'train_psnr': 25.169, 'val_psnr': 24.0401, 'input_psnr': 23.1331, 'delta_psnr': 0.907, 'best_val_psnr': 24.0401}
# {'epoch': 4114, 'epoch_time_sec': 41.8, 'lr': 2.095235167002848e-05, 'train_loss': 0.011559, 'train_psnr': 25.1736, 'val_psnr': 24.0402, 'input_psnr': 23.1331, 'delta_psnr': 0.9071, 'best_val_psnr': 24.0402}
# {'epoch': 4115, 'epoch_time_sec': 42.14, 'lr': 2.092279632524854e-05, 'train_loss': 0.011571, 'train_psnr': 25.1675, 'val_psnr': 24.0401, 'input_psnr': 23.1331, 'delta_psnr': 0.9071, 'best_val_psnr': 24.0402}
# {'epoch': 4116, 'epoch_time_sec': 42.02, 'lr': 2.089325950773074e-05, 'train_loss': 0.01157, 'train_psnr': 25.1661, 'val_psnr': 24.0401, 'input_psnr': 23.1331, 'delta_psnr': 0.907, 'best_val_psnr': 24.0402}
# {'epoch': 4117, 'epoch_time_sec': 41.93, 'lr': 2.086374122750191e-05, 'train_loss': 0.011566, 'train_psnr': 25.1705, 'val_psnr': 24.0402, 'input_psnr': 23.1331, 'delta_psnr': 0.9071, 'best_val_psnr': 24.0402}
# {'epoch': 4118, 'epoch_time_sec': 42.07, 'lr': 2.0834241494582592e-05, 'train_loss': 0.011577, 'train_psnr': 25.165, 'val_psnr': 24.0401, 'input_psnr': 23.1331, 'delta_psnr': 0.9071, 'best_val_psnr': 24.0402}
# {'epoch': 4119, 'epoch_time_sec': 42.14, 'lr': 2.080476031898703e-05, 'train_loss': 0.011588, 'train_psnr': 25.1601, 'val_psnr': 24.0402, 'input_psnr': 23.1331, 'delta_psnr': 0.9071, 'best_val_psnr': 24.0402}
# {'epoch': 4120, 'epoch_time_sec': 42.39, 'lr': 2.0775297710723136e-05, 'train_loss': 0.011583, 'train_psnr': 25.1607, 'val_psnr': 24.0402, 'input_psnr': 23.1331, 'delta_psnr': 0.9071, 'best_val_psnr': 24.0402}
# {'epoch': 4121, 'epoch_time_sec': 42.79, 'lr': 2.074585367979259e-05, 'train_loss': 0.011563, 'train_psnr': 25.1714, 'val_psnr': 24.0402, 'input_psnr': 23.1331, 'delta_psnr': 0.9072, 'best_val_psnr': 24.0402}
# {'epoch': 4122, 'epoch_time_sec': 41.92, 'lr': 2.071642823619071e-05, 'train_loss': 0.01156, 'train_psnr': 25.1719, 'val_psnr': 24.0402, 'input_psnr': 23.1331, 'delta_psnr': 0.9071, 'best_val_psnr': 24.0402}
# {'epoch': 4123, 'epoch_time_sec': 41.85, 'lr': 2.0687021389906516e-05, 'train_loss': 0.011579, 'train_psnr': 25.1642, 'val_psnr': 24.0401, 'input_psnr': 23.1331, 'delta_psnr': 0.9071, 'best_val_psnr': 24.0402}
# {'epoch': 4124, 'epoch_time_sec': 42.05, 'lr': 2.065763315092271e-05, 'train_loss': 0.011564, 'train_psnr': 25.1707, 'val_psnr': 24.0401, 'input_psnr': 23.1331, 'delta_psnr': 0.9071, 'best_val_psnr': 24.0402}
# {'epoch': 4125, 'epoch_time_sec': 41.87, 'lr': 2.06282635292157e-05, 'train_loss': 0.011567, 'train_psnr': 25.1685, 'val_psnr': 24.0401, 'input_psnr': 23.1331, 'delta_psnr': 0.907, 'best_val_psnr': 24.0402}
# {'epoch': 4126, 'epoch_time_sec': 42.02, 'lr': 2.0598912534755552e-05, 'train_loss': 0.011568, 'train_psnr': 25.1678, 'val_psnr': 24.0401, 'input_psnr': 23.1331, 'delta_psnr': 0.9071, 'best_val_psnr': 24.0402}
# {'epoch': 4127, 'epoch_time_sec': 42.06, 'lr': 2.0569580177506006e-05, 'train_loss': 0.01158, 'train_psnr': 25.1624, 'val_psnr': 24.0402, 'input_psnr': 23.1331, 'delta_psnr': 0.9071, 'best_val_psnr': 24.0402}
# {'epoch': 4128, 'epoch_time_sec': 41.9, 'lr': 2.0540266467424474e-05, 'train_loss': 0.011572, 'train_psnr': 25.1668, 'val_psnr': 24.0403, 'input_psnr': 23.1331, 'delta_psnr': 0.9072, 'best_val_psnr': 24.0403}
# {'epoch': 4129, 'epoch_time_sec': 41.9, 'lr': 2.0510971414462082e-05, 'train_loss': 0.011571, 'train_psnr': 25.1691, 'val_psnr': 24.0402, 'input_psnr': 23.1331, 'delta_psnr': 0.9072, 'best_val_psnr': 24.0403}
# {'epoch': 4130, 'epoch_time_sec': 42.32, 'lr': 2.0481695028563574e-05, 'train_loss': 0.011566, 'train_psnr': 25.1689, 'val_psnr': 24.0402, 'input_psnr': 23.1331, 'delta_psnr': 0.9072, 'best_val_psnr': 24.0403}
# {'epoch': 4131, 'epoch_time_sec': 42.35, 'lr': 2.045243731966738e-05, 'train_loss': 0.011568, 'train_psnr': 25.1704, 'val_psnr': 24.0402, 'input_psnr': 23.1331, 'delta_psnr': 0.9072, 'best_val_psnr': 24.0403}
# {'epoch': 4132, 'epoch_time_sec': 42.33, 'lr': 2.042319829770556e-05, 'train_loss': 0.011562, 'train_psnr': 25.1712, 'val_psnr': 24.0403, 'input_psnr': 23.1331, 'delta_psnr': 0.9072, 'best_val_psnr': 24.0403}
# {'epoch': 4133, 'epoch_time_sec': 41.78, 'lr': 2.039397797260387e-05, 'train_loss': 0.011561, 'train_psnr': 25.1727, 'val_psnr': 24.0403, 'input_psnr': 23.1331, 'delta_psnr': 0.9073, 'best_val_psnr': 24.0403}
# {'epoch': 4134, 'epoch_time_sec': 41.84, 'lr': 2.0364776354281694e-05, 'train_loss': 0.011575, 'train_psnr': 25.1679, 'val_psnr': 24.0403, 'input_psnr': 23.1331, 'delta_psnr': 0.9072, 'best_val_psnr': 24.0403}
# {'epoch': 4135, 'epoch_time_sec': 41.93, 'lr': 2.0335593452652045e-05, 'train_loss': 0.011562, 'train_psnr': 25.1719, 'val_psnr': 24.0403, 'input_psnr': 23.1331, 'delta_psnr': 0.9072, 'best_val_psnr': 24.0403}
# {'epoch': 4136, 'epoch_time_sec': 41.82, 'lr': 2.030642927762167e-05, 'train_loss': 0.011568, 'train_psnr': 25.1684, 'val_psnr': 24.0403, 'input_psnr': 23.1331, 'delta_psnr': 0.9073, 'best_val_psnr': 24.0403}
# {'epoch': 4137, 'epoch_time_sec': 41.95, 'lr': 2.0277283839090885e-05, 'train_loss': 0.011568, 'train_psnr': 25.1711, 'val_psnr': 24.0404, 'input_psnr': 23.1331, 'delta_psnr': 0.9073, 'best_val_psnr': 24.0404}
# {'epoch': 4138, 'epoch_time_sec': 41.89, 'lr': 2.0248157146953602e-05, 'train_loss': 0.011577, 'train_psnr': 25.1664, 'val_psnr': 24.0403, 'input_psnr': 23.1331, 'delta_psnr': 0.9073, 'best_val_psnr': 24.0404}
# {'epoch': 4139, 'epoch_time_sec': 41.89, 'lr': 2.0219049211097488e-05, 'train_loss': 0.011568, 'train_psnr': 25.1704, 'val_psnr': 24.0402, 'input_psnr': 23.1331, 'delta_psnr': 0.9072, 'best_val_psnr': 24.0404}
# {'epoch': 4140, 'epoch_time_sec': 42.02, 'lr': 2.0189960041403752e-05, 'train_loss': 0.011568, 'train_psnr': 25.1683, 'val_psnr': 24.0403, 'input_psnr': 23.1331, 'delta_psnr': 0.9073, 'best_val_psnr': 24.0404}
# {'epoch': 4141, 'epoch_time_sec': 42.83, 'lr': 2.0160889647747273e-05, 'train_loss': 0.011572, 'train_psnr': 25.1686, 'val_psnr': 24.0403, 'input_psnr': 23.1331, 'delta_psnr': 0.9073, 'best_val_psnr': 24.0404}
# {'epoch': 4142, 'epoch_time_sec': 42.19, 'lr': 2.0131838039996543e-05, 'train_loss': 0.01157, 'train_psnr': 25.1688, 'val_psnr': 24.0404, 'input_psnr': 23.1331, 'delta_psnr': 0.9073, 'best_val_psnr': 24.0404}
# {'epoch': 4143, 'epoch_time_sec': 41.83, 'lr': 2.010280522801366e-05, 'train_loss': 0.011563, 'train_psnr': 25.1712, 'val_psnr': 24.0404, 'input_psnr': 23.1331, 'delta_psnr': 0.9073, 'best_val_psnr': 24.0404}
# {'epoch': 4144, 'epoch_time_sec': 41.84, 'lr': 2.007379122165439e-05, 'train_loss': 0.011572, 'train_psnr': 25.167, 'val_psnr': 24.0404, 'input_psnr': 23.1331, 'delta_psnr': 0.9073, 'best_val_psnr': 24.0404}
# {'epoch': 4145, 'epoch_time_sec': 41.75, 'lr': 2.00447960307681e-05, 'train_loss': 0.011562, 'train_psnr': 25.1713, 'val_psnr': 24.0403, 'input_psnr': 23.1331, 'delta_psnr': 0.9073, 'best_val_psnr': 24.0404}
# {'epoch': 4146, 'epoch_time_sec': 41.89, 'lr': 2.001581966519768e-05, 'train_loss': 0.011571, 'train_psnr': 25.1667, 'val_psnr': 24.0403, 'input_psnr': 23.1331, 'delta_psnr': 0.9073, 'best_val_psnr': 24.0404}
# {'epoch': 4147, 'epoch_time_sec': 42.06, 'lr': 1.9986862134779777e-05, 'train_loss': 0.011569, 'train_psnr': 25.1688, 'val_psnr': 24.0404, 'input_psnr': 23.1331, 'delta_psnr': 0.9074, 'best_val_psnr': 24.0404}
# {'epoch': 4148, 'epoch_time_sec': 41.86, 'lr': 1.995792344934454e-05, 'train_loss': 0.011564, 'train_psnr': 25.1719, 'val_psnr': 24.0404, 'input_psnr': 23.1331, 'delta_psnr': 0.9073, 'best_val_psnr': 24.0404}
# {'epoch': 4149, 'epoch_time_sec': 41.93, 'lr': 1.9929003618715765e-05, 'train_loss': 0.011568, 'train_psnr': 25.1688, 'val_psnr': 24.0404, 'input_psnr': 23.1331, 'delta_psnr': 0.9073, 'best_val_psnr': 24.0404}
# {'epoch': 4150, 'epoch_time_sec': 41.93, 'lr': 1.990010265271082e-05, 'train_loss': 0.011557, 'train_psnr': 25.1748, 'val_psnr': 24.0404, 'input_psnr': 23.1331, 'delta_psnr': 0.9074, 'best_val_psnr': 24.0404}
# {'epoch': 4151, 'epoch_time_sec': 42.53, 'lr': 1.987122056114068e-05, 'train_loss': 0.011568, 'train_psnr': 25.1683, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9074, 'best_val_psnr': 24.0405}
# {'epoch': 4152, 'epoch_time_sec': 42.7, 'lr': 1.9842357353809942e-05, 'train_loss': 0.011563, 'train_psnr': 25.1718, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9075, 'best_val_psnr': 24.0405}
# {'epoch': 4153, 'epoch_time_sec': 41.94, 'lr': 1.9813513040516776e-05, 'train_loss': 0.011578, 'train_psnr': 25.1656, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9074, 'best_val_psnr': 24.0405}
# {'epoch': 4154, 'epoch_time_sec': 41.97, 'lr': 1.9784687631052863e-05, 'train_loss': 0.011562, 'train_psnr': 25.1741, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9074, 'best_val_psnr': 24.0405}
# {'epoch': 4155, 'epoch_time_sec': 41.88, 'lr': 1.9755881135203592e-05, 'train_loss': 0.011571, 'train_psnr': 25.1702, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9075, 'best_val_psnr': 24.0405}
# {'epoch': 4156, 'epoch_time_sec': 42.03, 'lr': 1.972709356274783e-05, 'train_loss': 0.011568, 'train_psnr': 25.1691, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9075, 'best_val_psnr': 24.0405}
# {'epoch': 4157, 'epoch_time_sec': 42.0, 'lr': 1.9698324923458138e-05, 'train_loss': 0.011563, 'train_psnr': 25.1709, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9075, 'best_val_psnr': 24.0405}
# {'epoch': 4158, 'epoch_time_sec': 41.73, 'lr': 1.9669575227100494e-05, 'train_loss': 0.011583, 'train_psnr': 25.1633, 'val_psnr': 24.0404, 'input_psnr': 23.1331, 'delta_psnr': 0.9074, 'best_val_psnr': 24.0405}
# {'epoch': 4159, 'epoch_time_sec': 41.87, 'lr': 1.9640844483434534e-05, 'train_loss': 0.011559, 'train_psnr': 25.1743, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9075, 'best_val_psnr': 24.0405}
# {'epoch': 4160, 'epoch_time_sec': 41.94, 'lr': 1.961213270221349e-05, 'train_loss': 0.011568, 'train_psnr': 25.1704, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9074, 'best_val_psnr': 24.0405}
# {'epoch': 4161, 'epoch_time_sec': 42.32, 'lr': 1.9583439893184116e-05, 'train_loss': 0.01156, 'train_psnr': 25.1728, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9074, 'best_val_psnr': 24.0405}
# {'epoch': 4162, 'epoch_time_sec': 42.85, 'lr': 1.955476606608667e-05, 'train_loss': 0.011562, 'train_psnr': 25.1726, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9075, 'best_val_psnr': 24.0405}
# {'epoch': 4163, 'epoch_time_sec': 42.07, 'lr': 1.9526111230655087e-05, 'train_loss': 0.011587, 'train_psnr': 25.1608, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9074, 'best_val_psnr': 24.0405}
# {'epoch': 4164, 'epoch_time_sec': 42.01, 'lr': 1.9497475396616773e-05, 'train_loss': 0.011559, 'train_psnr': 25.1747, 'val_psnr': 24.0404, 'input_psnr': 23.1331, 'delta_psnr': 0.9074, 'best_val_psnr': 24.0405}
# {'epoch': 4165, 'epoch_time_sec': 41.82, 'lr': 1.9468858573692692e-05, 'train_loss': 0.011561, 'train_psnr': 25.1715, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9074, 'best_val_psnr': 24.0405}
# {'epoch': 4166, 'epoch_time_sec': 41.9, 'lr': 1.9440260771597374e-05, 'train_loss': 0.011566, 'train_psnr': 25.1723, 'val_psnr': 24.0406, 'input_psnr': 23.1331, 'delta_psnr': 0.9075, 'best_val_psnr': 24.0406}
# {'epoch': 4167, 'epoch_time_sec': 41.85, 'lr': 1.941168200003886e-05, 'train_loss': 0.011569, 'train_psnr': 25.1697, 'val_psnr': 24.0404, 'input_psnr': 23.1331, 'delta_psnr': 0.9074, 'best_val_psnr': 24.0406}
# {'epoch': 4168, 'epoch_time_sec': 41.77, 'lr': 1.9383122268718795e-05, 'train_loss': 0.011572, 'train_psnr': 25.168, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9075, 'best_val_psnr': 24.0406}
# {'epoch': 4169, 'epoch_time_sec': 41.91, 'lr': 1.9354581587332318e-05, 'train_loss': 0.011563, 'train_psnr': 25.1717, 'val_psnr': 24.0404, 'input_psnr': 23.1331, 'delta_psnr': 0.9074, 'best_val_psnr': 24.0406}
# {'epoch': 4170, 'epoch_time_sec': 41.93, 'lr': 1.932605996556803e-05, 'train_loss': 0.01156, 'train_psnr': 25.173, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9074, 'best_val_psnr': 24.0406}
# {'epoch': 4171, 'epoch_time_sec': 42.02, 'lr': 1.929755741310822e-05, 'train_loss': 0.011567, 'train_psnr': 25.1717, 'val_psnr': 24.0406, 'input_psnr': 23.1331, 'delta_psnr': 0.9075, 'best_val_psnr': 24.0406}
# {'epoch': 4172, 'epoch_time_sec': 42.93, 'lr': 1.9269073939628574e-05, 'train_loss': 0.011576, 'train_psnr': 25.169, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9074, 'best_val_psnr': 24.0406}
# {'epoch': 4173, 'epoch_time_sec': 42.0, 'lr': 1.924060955479836e-05, 'train_loss': 0.011562, 'train_psnr': 25.172, 'val_psnr': 24.0404, 'input_psnr': 23.1331, 'delta_psnr': 0.9074, 'best_val_psnr': 24.0406}
# {'epoch': 4174, 'epoch_time_sec': 41.83, 'lr': 1.921216426828034e-05, 'train_loss': 0.011558, 'train_psnr': 25.1726, 'val_psnr': 24.0406, 'input_psnr': 23.1331, 'delta_psnr': 0.9075, 'best_val_psnr': 24.0406}
# {'epoch': 4175, 'epoch_time_sec': 41.88, 'lr': 1.9183738089730792e-05, 'train_loss': 0.011564, 'train_psnr': 25.1712, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9075, 'best_val_psnr': 24.0406}
# {'epoch': 4176, 'epoch_time_sec': 41.87, 'lr': 1.9155331028799555e-05, 'train_loss': 0.011561, 'train_psnr': 25.1724, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9075, 'best_val_psnr': 24.0406}
# {'epoch': 4177, 'epoch_time_sec': 41.98, 'lr': 1.912694309512994e-05, 'train_loss': 0.011575, 'train_psnr': 25.1679, 'val_psnr': 24.0406, 'input_psnr': 23.1331, 'delta_psnr': 0.9075, 'best_val_psnr': 24.0406}
# {'epoch': 4178, 'epoch_time_sec': 41.84, 'lr': 1.909857429835871e-05, 'train_loss': 0.011566, 'train_psnr': 25.1703, 'val_psnr': 24.0406, 'input_psnr': 23.1331, 'delta_psnr': 0.9075, 'best_val_psnr': 24.0406}
# {'epoch': 4179, 'epoch_time_sec': 41.9, 'lr': 1.907022464811625e-05, 'train_loss': 0.011566, 'train_psnr': 25.1711, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9075, 'best_val_psnr': 24.0406}
# {'epoch': 4180, 'epoch_time_sec': 42.03, 'lr': 1.9041894154026363e-05, 'train_loss': 0.011556, 'train_psnr': 25.1752, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9075, 'best_val_psnr': 24.0406}
# {'epoch': 4181, 'epoch_time_sec': 42.27, 'lr': 1.901358282570636e-05, 'train_loss': 0.011556, 'train_psnr': 25.1768, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9075, 'best_val_psnr': 24.0406}
# {'epoch': 4182, 'epoch_time_sec': 42.67, 'lr': 1.8985290672767077e-05, 'train_loss': 0.011561, 'train_psnr': 25.1711, 'val_psnr': 24.0404, 'input_psnr': 23.1331, 'delta_psnr': 0.9074, 'best_val_psnr': 24.0406}
# {'epoch': 4183, 'epoch_time_sec': 42.36, 'lr': 1.8957017704812783e-05, 'train_loss': 0.011562, 'train_psnr': 25.1737, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9074, 'best_val_psnr': 24.0406}
# {'epoch': 4184, 'epoch_time_sec': 41.96, 'lr': 1.892876393144131e-05, 'train_loss': 0.011575, 'train_psnr': 25.1655, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9075, 'best_val_psnr': 24.0406}
# {'epoch': 4185, 'epoch_time_sec': 41.91, 'lr': 1.8900529362243925e-05, 'train_loss': 0.011574, 'train_psnr': 25.1667, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9074, 'best_val_psnr': 24.0406}
# {'epoch': 4186, 'epoch_time_sec': 41.92, 'lr': 1.887231400680538e-05, 'train_loss': 0.011572, 'train_psnr': 25.168, 'val_psnr': 24.0404, 'input_psnr': 23.1331, 'delta_psnr': 0.9074, 'best_val_psnr': 24.0406}
# {'epoch': 4187, 'epoch_time_sec': 41.88, 'lr': 1.884411787470391e-05, 'train_loss': 0.011561, 'train_psnr': 25.1724, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9074, 'best_val_psnr': 24.0406}
# {'epoch': 4188, 'epoch_time_sec': 41.85, 'lr': 1.881594097551122e-05, 'train_loss': 0.011566, 'train_psnr': 25.1691, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9075, 'best_val_psnr': 24.0406}
# {'epoch': 4189, 'epoch_time_sec': 42.05, 'lr': 1.87877833187925e-05, 'train_loss': 0.011561, 'train_psnr': 25.1728, 'val_psnr': 24.0406, 'input_psnr': 23.1331, 'delta_psnr': 0.9075, 'best_val_psnr': 24.0406}
# {'epoch': 4190, 'epoch_time_sec': 41.83, 'lr': 1.8759644914106392e-05, 'train_loss': 0.011564, 'train_psnr': 25.1718, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9075, 'best_val_psnr': 24.0406}
# {'epoch': 4191, 'epoch_time_sec': 42.12, 'lr': 1.8731525771004995e-05, 'train_loss': 0.01157, 'train_psnr': 25.1685, 'val_psnr': 24.0406, 'input_psnr': 23.1331, 'delta_psnr': 0.9076, 'best_val_psnr': 24.0406}
# {'epoch': 4192, 'epoch_time_sec': 42.68, 'lr': 1.8703425899033912e-05, 'train_loss': 0.011563, 'train_psnr': 25.1724, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9075, 'best_val_psnr': 24.0406}
# {'epoch': 4193, 'epoch_time_sec': 42.59, 'lr': 1.8675345307732166e-05, 'train_loss': 0.011568, 'train_psnr': 25.1695, 'val_psnr': 24.0405, 'input_psnr': 23.1331, 'delta_psnr': 0.9074, 'best_val_psnr': 24.0406}
# {'epoch': 4194, 'epoch_time_sec': 41.81, 'lr': 1.8647284006632234e-05, 'train_loss': 0.011577, 'train_psnr': 25.1679, 'val_psnr': 24.0406, 'input_psnr': 23.1331, 'delta_psnr': 0.9075, 'best_val_psnr': 24.0406}
# {'epoch': 4195, 'epoch_time_sec': 42.04, 'lr': 1.861924200526006e-05, 'train_loss': 0.01157, 'train_psnr': 25.1707, 'val_psnr': 24.0406, 'input_psnr': 23.1331, 'delta_psnr': 0.9076, 'best_val_psnr': 24.0406}
# {'epoch': 4196, 'epoch_time_sec': 41.72, 'lr': 1.8591219313135034e-05, 'train_loss': 0.011576, 'train_psnr': 25.1684, 'val_psnr': 24.0406, 'input_psnr': 23.1331, 'delta_psnr': 0.9076, 'best_val_psnr': 24.0406}
# {'epoch': 4197, 'epoch_time_sec': 41.96, 'lr': 1.856321593976998e-05, 'train_loss': 0.011591, 'train_psnr': 25.162, 'val_psnr': 24.0406, 'input_psnr': 23.1331, 'delta_psnr': 0.9075, 'best_val_psnr': 24.0406}
# {'epoch': 4198, 'epoch_time_sec': 42.01, 'lr': 1.853523189467118e-05, 'train_loss': 0.011576, 'train_psnr': 25.1661, 'val_psnr': 24.0406, 'input_psnr': 23.1331, 'delta_psnr': 0.9075, 'best_val_psnr': 24.0406}
# {'epoch': 4199, 'epoch_time_sec': 41.86, 'lr': 1.8507267187338315e-05, 'train_loss': 0.011562, 'train_psnr': 25.1715, 'val_psnr': 24.0407, 'input_psnr': 23.1331, 'delta_psnr': 0.9076, 'best_val_psnr': 24.0407}
# {'epoch': 4200, 'epoch_time_sec': 41.86, 'lr': 1.8479321827264606e-05, 'train_loss': 0.011568, 'train_psnr': 25.1704, 'val_psnr': 24.0407, 'input_psnr': 23.1331, 'delta_psnr': 0.9076, 'best_val_psnr': 24.0407}
# {'epoch': 4201, 'epoch_time_sec': 42.06, 'lr': 1.8451395823936545e-05, 'train_loss': 0.011573, 'train_psnr': 25.1674, 'val_psnr': 24.0407, 'input_psnr': 23.1331, 'delta_psnr': 0.9077, 'best_val_psnr': 24.0407}
# {'epoch': 4202, 'epoch_time_sec': 42.41, 'lr': 1.84234891868342e-05, 'train_loss': 0.011559, 'train_psnr': 25.1749, 'val_psnr': 24.0407, 'input_psnr': 23.1331, 'delta_psnr': 0.9077, 'best_val_psnr': 24.0407}
# {'epoch': 4203, 'epoch_time_sec': 42.37, 'lr': 1.8395601925431e-05, 'train_loss': 0.011569, 'train_psnr': 25.1694, 'val_psnr': 24.0406, 'input_psnr': 23.1331, 'delta_psnr': 0.9076, 'best_val_psnr': 24.0407}
# {'epoch': 4204, 'epoch_time_sec': 41.87, 'lr': 1.836773404919378e-05, 'train_loss': 0.011563, 'train_psnr': 25.1706, 'val_psnr': 24.0406, 'input_psnr': 23.1331, 'delta_psnr': 0.9076, 'best_val_psnr': 24.0407}
# {'epoch': 4205, 'epoch_time_sec': 41.76, 'lr': 1.8339885567582835e-05, 'train_loss': 0.011554, 'train_psnr': 25.1771, 'val_psnr': 24.0407, 'input_psnr': 23.1331, 'delta_psnr': 0.9077, 'best_val_psnr': 24.0407}
# {'epoch': 4206, 'epoch_time_sec': 42.01, 'lr': 1.8312056490051843e-05, 'train_loss': 0.011554, 'train_psnr': 25.1783, 'val_psnr': 24.0407, 'input_psnr': 23.1331, 'delta_psnr': 0.9076, 'best_val_psnr': 24.0407}
# {'epoch': 4207, 'epoch_time_sec': 41.78, 'lr': 1.8284246826047905e-05, 'train_loss': 0.011571, 'train_psnr': 25.1682, 'val_psnr': 24.0408, 'input_psnr': 23.1331, 'delta_psnr': 0.9077, 'best_val_psnr': 24.0408}
# {'epoch': 4208, 'epoch_time_sec': 41.96, 'lr': 1.825645658501159e-05, 'train_loss': 0.011552, 'train_psnr': 25.1772, 'val_psnr': 24.0408, 'input_psnr': 23.1331, 'delta_psnr': 0.9078, 'best_val_psnr': 24.0408}
# {'epoch': 4209, 'epoch_time_sec': 41.92, 'lr': 1.8228685776376728e-05, 'train_loss': 0.01156, 'train_psnr': 25.1719, 'val_psnr': 24.0408, 'input_psnr': 23.1331, 'delta_psnr': 0.9078, 'best_val_psnr': 24.0408}
# {'epoch': 4210, 'epoch_time_sec': 42.03, 'lr': 1.8200934409570723e-05, 'train_loss': 0.011555, 'train_psnr': 25.1764, 'val_psnr': 24.0408, 'input_psnr': 23.1331, 'delta_psnr': 0.9077, 'best_val_psnr': 24.0408}
# {'epoch': 4211, 'epoch_time_sec': 42.06, 'lr': 1.817320249401427e-05, 'train_loss': 0.011562, 'train_psnr': 25.1717, 'val_psnr': 24.0408, 'input_psnr': 23.1331, 'delta_psnr': 0.9077, 'best_val_psnr': 24.0408}
# {'epoch': 4212, 'epoch_time_sec': 42.32, 'lr': 1.81454900391215e-05, 'train_loss': 0.011568, 'train_psnr': 25.1676, 'val_psnr': 24.0409, 'input_psnr': 23.1331, 'delta_psnr': 0.9078, 'best_val_psnr': 24.0409}
# {'epoch': 4213, 'epoch_time_sec': 42.62, 'lr': 1.8117797054299918e-05, 'train_loss': 0.01155, 'train_psnr': 25.1803, 'val_psnr': 24.0407, 'input_psnr': 23.1331, 'delta_psnr': 0.9077, 'best_val_psnr': 24.0409}
# {'epoch': 4214, 'epoch_time_sec': 42.02, 'lr': 1.8090123548950413e-05, 'train_loss': 0.011572, 'train_psnr': 25.1702, 'val_psnr': 24.0408, 'input_psnr': 23.1331, 'delta_psnr': 0.9077, 'best_val_psnr': 24.0409}
# {'epoch': 4215, 'epoch_time_sec': 42.04, 'lr': 1.806246953246733e-05, 'train_loss': 0.011567, 'train_psnr': 25.1691, 'val_psnr': 24.0408, 'input_psnr': 23.1331, 'delta_psnr': 0.9077, 'best_val_psnr': 24.0409}
# {'epoch': 4216, 'epoch_time_sec': 41.69, 'lr': 1.8034835014238334e-05, 'train_loss': 0.011554, 'train_psnr': 25.1782, 'val_psnr': 24.0408, 'input_psnr': 23.1331, 'delta_psnr': 0.9078, 'best_val_psnr': 24.0409}
# {'epoch': 4217, 'epoch_time_sec': 42.01, 'lr': 1.8007220003644424e-05, 'train_loss': 0.011563, 'train_psnr': 25.1722, 'val_psnr': 24.0408, 'input_psnr': 23.1331, 'delta_psnr': 0.9077, 'best_val_psnr': 24.0409}
# {'epoch': 4218, 'epoch_time_sec': 41.83, 'lr': 1.7979624510060105e-05, 'train_loss': 0.011568, 'train_psnr': 25.17, 'val_psnr': 24.0407, 'input_psnr': 23.1331, 'delta_psnr': 0.9077, 'best_val_psnr': 24.0409}
# {'epoch': 4219, 'epoch_time_sec': 42.05, 'lr': 1.7952048542853158e-05, 'train_loss': 0.011552, 'train_psnr': 25.1792, 'val_psnr': 24.0408, 'input_psnr': 23.1331, 'delta_psnr': 0.9078, 'best_val_psnr': 24.0409}
# {'epoch': 4220, 'epoch_time_sec': 41.8, 'lr': 1.7924492111384777e-05, 'train_loss': 0.01156, 'train_psnr': 25.1737, 'val_psnr': 24.0409, 'input_psnr': 23.1331, 'delta_psnr': 0.9078, 'best_val_psnr': 24.0409}
# {'epoch': 4221, 'epoch_time_sec': 42.02, 'lr': 1.7896955225009507e-05, 'train_loss': 0.01156, 'train_psnr': 25.174, 'val_psnr': 24.0408, 'input_psnr': 23.1331, 'delta_psnr': 0.9078, 'best_val_psnr': 24.0409}
# {'epoch': 4222, 'epoch_time_sec': 42.21, 'lr': 1.7869437893075246e-05, 'train_loss': 0.011566, 'train_psnr': 25.1707, 'val_psnr': 24.0409, 'input_psnr': 23.1331, 'delta_psnr': 0.9079, 'best_val_psnr': 24.0409}
# {'epoch': 4223, 'epoch_time_sec': 42.92, 'lr': 1.7841940124923308e-05, 'train_loss': 0.011562, 'train_psnr': 25.173, 'val_psnr': 24.0409, 'input_psnr': 23.1331, 'delta_psnr': 0.9079, 'best_val_psnr': 24.0409}
# {'epoch': 4224, 'epoch_time_sec': 42.05, 'lr': 1.781446192988834e-05, 'train_loss': 0.011556, 'train_psnr': 25.1749, 'val_psnr': 24.041, 'input_psnr': 23.1331, 'delta_psnr': 0.9079, 'best_val_psnr': 24.041}
# {'epoch': 4225, 'epoch_time_sec': 42.05, 'lr': 1.7787003317298253e-05, 'train_loss': 0.011558, 'train_psnr': 25.1746, 'val_psnr': 24.0409, 'input_psnr': 23.1331, 'delta_psnr': 0.9078, 'best_val_psnr': 24.041}
# ...
# {'epoch': 4856, 'epoch_time_sec': 41.97, 'lr': 4.710950821163829e-06, 'train_loss': 0.011554, 'train_psnr': 25.1796, 'val_psnr': 24.0433, 'input_psnr': 23.1331, 'delta_psnr': 0.9103, 'best_val_psnr': 24.0435}
# {'epoch': 4857, 'epoch_time_sec': 42.42, 'lr': 4.697434044965731e-06, 'train_loss': 0.011545, 'train_psnr': 25.182, 'val_psnr': 24.0434, 'input_psnr': 23.1331, 'delta_psnr': 0.9103, 'best_val_psnr': 24.0435}
# {'epoch': 4858, 'epoch_time_sec': 42.92, 'lr': 4.683941304035319e-06, 'train_loss': 0.011539, 'train_psnr': 25.1854, 'val_psnr': 24.0434, 'input_psnr': 23.1331, 'delta_psnr': 0.9103, 'best_val_psnr': 24.0435}
# {'epoch': 4859, 'epoch_time_sec': 41.93, 'lr': 4.670472602952955e-06, 'train_loss': 0.011546, 'train_psnr': 25.1836, 'val_psnr': 24.0434, 'input_psnr': 23.1331, 'delta_psnr': 0.9103, 'best_val_psnr': 24.0435}
# {'epoch': 4860, 'epoch_time_sec': 42.07, 'lr': 4.657027946290856e-06, 'train_loss': 0.011547, 'train_psnr': 25.1825, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9104, 'best_val_psnr': 24.0435}
# {'epoch': 4861, 'epoch_time_sec': 41.92, 'lr': 4.643607338613039e-06, 'train_loss': 0.011543, 'train_psnr': 25.1837, 'val_psnr': 24.0434, 'input_psnr': 23.1331, 'delta_psnr': 0.9104, 'best_val_psnr': 24.0435}
# {'epoch': 4862, 'epoch_time_sec': 42.03, 'lr': 4.630210784475411e-06, 'train_loss': 0.011536, 'train_psnr': 25.1879, 'val_psnr': 24.0434, 'input_psnr': 23.1331, 'delta_psnr': 0.9104, 'best_val_psnr': 24.0435}
# {'epoch': 4863, 'epoch_time_sec': 42.07, 'lr': 4.616838288425661e-06, 'train_loss': 0.011551, 'train_psnr': 25.1822, 'val_psnr': 24.0434, 'input_psnr': 23.1331, 'delta_psnr': 0.9104, 'best_val_psnr': 24.0435}
# {'epoch': 4864, 'epoch_time_sec': 41.94, 'lr': 4.603489855003351e-06, 'train_loss': 0.011549, 'train_psnr': 25.1835, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9104, 'best_val_psnr': 24.0435}
# {'epoch': 4865, 'epoch_time_sec': 42.02, 'lr': 4.590165488739845e-06, 'train_loss': 0.011538, 'train_psnr': 25.1861, 'val_psnr': 24.0434, 'input_psnr': 23.1331, 'delta_psnr': 0.9103, 'best_val_psnr': 24.0435}
# {'epoch': 4866, 'epoch_time_sec': 42.03, 'lr': 4.576865194158368e-06, 'train_loss': 0.011549, 'train_psnr': 25.1818, 'val_psnr': 24.0434, 'input_psnr': 23.1331, 'delta_psnr': 0.9104, 'best_val_psnr': 24.0435}
# {'epoch': 4867, 'epoch_time_sec': 42.08, 'lr': 4.5635889757739486e-06, 'train_loss': 0.011533, 'train_psnr': 25.1897, 'val_psnr': 24.0434, 'input_psnr': 23.1331, 'delta_psnr': 0.9104, 'best_val_psnr': 24.0435}
# {'epoch': 4868, 'epoch_time_sec': 42.56, 'lr': 4.550336838093443e-06, 'train_loss': 0.011543, 'train_psnr': 25.1852, 'val_psnr': 24.0434, 'input_psnr': 23.1331, 'delta_psnr': 0.9103, 'best_val_psnr': 24.0435}
# {'epoch': 4869, 'epoch_time_sec': 42.21, 'lr': 4.537108785615554e-06, 'train_loss': 0.011539, 'train_psnr': 25.1874, 'val_psnr': 24.0434, 'input_psnr': 23.1331, 'delta_psnr': 0.9103, 'best_val_psnr': 24.0435}
# {'epoch': 4870, 'epoch_time_sec': 41.99, 'lr': 4.523904822830777e-06, 'train_loss': 0.011538, 'train_psnr': 25.1877, 'val_psnr': 24.0434, 'input_psnr': 23.1331, 'delta_psnr': 0.9104, 'best_val_psnr': 24.0435}
# {'epoch': 4871, 'epoch_time_sec': 41.96, 'lr': 4.5107249542214605e-06, 'train_loss': 0.011532, 'train_psnr': 25.1913, 'val_psnr': 24.0434, 'input_psnr': 23.1331, 'delta_psnr': 0.9103, 'best_val_psnr': 24.0435}
# {'epoch': 4872, 'epoch_time_sec': 50.58, 'lr': 4.49756918426175e-06, 'train_loss': 0.011552, 'train_psnr': 25.1803, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9104, 'best_val_psnr': 24.0435}
# {'epoch': 4873, 'epoch_time_sec': 59.73, 'lr': 4.484437517417618e-06, 'train_loss': 0.011535, 'train_psnr': 25.1888, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0435}
# {'epoch': 4874, 'epoch_time_sec': 65.03, 'lr': 4.471329958146879e-06, 'train_loss': 0.011542, 'train_psnr': 25.1838, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9104, 'best_val_psnr': 24.0435}
# {'epoch': 4875, 'epoch_time_sec': 64.66, 'lr': 4.458246510899099e-06, 'train_loss': 0.011561, 'train_psnr': 25.1804, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0435}
# {'epoch': 4876, 'epoch_time_sec': 65.04, 'lr': 4.445187180115748e-06, 'train_loss': 0.011548, 'train_psnr': 25.182, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0435}
# {'epoch': 4877, 'epoch_time_sec': 65.02, 'lr': 4.432151970230029e-06, 'train_loss': 0.011549, 'train_psnr': 25.1845, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0435}
# {'epoch': 4878, 'epoch_time_sec': 65.02, 'lr': 4.4191408856670145e-06, 'train_loss': 0.011532, 'train_psnr': 25.1909, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9104, 'best_val_psnr': 24.0435}
# {'epoch': 4879, 'epoch_time_sec': 65.11, 'lr': 4.406153930843544e-06, 'train_loss': 0.01155, 'train_psnr': 25.1814, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0435}
# {'epoch': 4880, 'epoch_time_sec': 65.09, 'lr': 4.393191110168289e-06, 'train_loss': 0.01154, 'train_psnr': 25.1874, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9104, 'best_val_psnr': 24.0435}
# {'epoch': 4881, 'epoch_time_sec': 65.17, 'lr': 4.380252428041722e-06, 'train_loss': 0.011549, 'train_psnr': 25.1836, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0435}
# {'epoch': 4882, 'epoch_time_sec': 64.85, 'lr': 4.3673378888561435e-06, 'train_loss': 0.011528, 'train_psnr': 25.1922, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0435}
# {'epoch': 4883, 'epoch_time_sec': 65.1, 'lr': 4.354447496995601e-06, 'train_loss': 0.011551, 'train_psnr': 25.1812, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0435}
# {'epoch': 4884, 'epoch_time_sec': 65.05, 'lr': 4.3415812568360095e-06, 'train_loss': 0.011538, 'train_psnr': 25.1901, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0435}
# {'epoch': 4885, 'epoch_time_sec': 65.02, 'lr': 4.328739172745048e-06, 'train_loss': 0.011542, 'train_psnr': 25.1852, 'val_psnr': 24.0436, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0436}
# {'epoch': 4886, 'epoch_time_sec': 64.85, 'lr': 4.315921249082204e-06, 'train_loss': 0.011542, 'train_psnr': 25.1866, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0436}
# {'epoch': 4887, 'epoch_time_sec': 64.82, 'lr': 4.3031274901987714e-06, 'train_loss': 0.011545, 'train_psnr': 25.1858, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0436}
# {'epoch': 4888, 'epoch_time_sec': 64.99, 'lr': 4.2903579004378125e-06, 'train_loss': 0.011534, 'train_psnr': 25.1893, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0436}
# {'epoch': 4889, 'epoch_time_sec': 65.07, 'lr': 4.2776124841342356e-06, 'train_loss': 0.011537, 'train_psnr': 25.1886, 'val_psnr': 24.0436, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0436}
# {'epoch': 4890, 'epoch_time_sec': 65.06, 'lr': 4.264891245614701e-06, 'train_loss': 0.011537, 'train_psnr': 25.1875, 'val_psnr': 24.0436, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0436}
# {'epoch': 4891, 'epoch_time_sec': 65.0, 'lr': 4.25219418919765e-06, 'train_loss': 0.01154, 'train_psnr': 25.1862, 'val_psnr': 24.0436, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0436}
# {'epoch': 4892, 'epoch_time_sec': 65.13, 'lr': 4.239521319193372e-06, 'train_loss': 0.011549, 'train_psnr': 25.1832, 'val_psnr': 24.0436, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0436}
# {'epoch': 4893, 'epoch_time_sec': 65.05, 'lr': 4.226872639903891e-06, 'train_loss': 0.011546, 'train_psnr': 25.1829, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9104, 'best_val_psnr': 24.0436}
# {'epoch': 4894, 'epoch_time_sec': 65.08, 'lr': 4.2142481556230475e-06, 'train_loss': 0.011554, 'train_psnr': 25.179, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0436}
# {'epoch': 4895, 'epoch_time_sec': 65.04, 'lr': 4.2016478706364605e-06, 'train_loss': 0.011538, 'train_psnr': 25.1872, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0436}
# {'epoch': 4896, 'epoch_time_sec': 64.96, 'lr': 4.189071789221529e-06, 'train_loss': 0.011527, 'train_psnr': 25.1938, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9104, 'best_val_psnr': 24.0436}
# {'epoch': 4897, 'epoch_time_sec': 65.07, 'lr': 4.1765199156474534e-06, 'train_loss': 0.011548, 'train_psnr': 25.1824, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0436}
# {'epoch': 4898, 'epoch_time_sec': 65.14, 'lr': 4.1639922541752066e-06, 'train_loss': 0.011538, 'train_psnr': 25.1871, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9104, 'best_val_psnr': 24.0436}
# {'epoch': 4899, 'epoch_time_sec': 65.04, 'lr': 4.151488809057512e-06, 'train_loss': 0.011547, 'train_psnr': 25.1846, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9104, 'best_val_psnr': 24.0436}
# {'epoch': 4900, 'epoch_time_sec': 65.01, 'lr': 4.139009584538925e-06, 'train_loss': 0.011531, 'train_psnr': 25.1908, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0436}
# {'epoch': 4901, 'epoch_time_sec': 64.99, 'lr': 4.1265545848557515e-06, 'train_loss': 0.011531, 'train_psnr': 25.1916, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9104, 'best_val_psnr': 24.0436}
# {'epoch': 4902, 'epoch_time_sec': 64.5, 'lr': 4.1141238142360676e-06, 'train_loss': 0.011552, 'train_psnr': 25.1794, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9104, 'best_val_psnr': 24.0436}
# {'epoch': 4903, 'epoch_time_sec': 65.26, 'lr': 4.101717276899739e-06, 'train_loss': 0.011527, 'train_psnr': 25.1941, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9104, 'best_val_psnr': 24.0436}
# {'epoch': 4904, 'epoch_time_sec': 65.18, 'lr': 4.089334977058391e-06, 'train_loss': 0.011533, 'train_psnr': 25.1885, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0436}
# {'epoch': 4905, 'epoch_time_sec': 65.05, 'lr': 4.0769769189154355e-06, 'train_loss': 0.011549, 'train_psnr': 25.1822, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9104, 'best_val_psnr': 24.0436}
# {'epoch': 4906, 'epoch_time_sec': 65.17, 'lr': 4.064643106666073e-06, 'train_loss': 0.01154, 'train_psnr': 25.186, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9104, 'best_val_psnr': 24.0436}
# {'epoch': 4907, 'epoch_time_sec': 65.14, 'lr': 4.052333544497197e-06, 'train_loss': 0.011548, 'train_psnr': 25.1846, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0436}
# {'epoch': 4908, 'epoch_time_sec': 65.05, 'lr': 4.0400482365875575e-06, 'train_loss': 0.011544, 'train_psnr': 25.1832, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0436}
# {'epoch': 4909, 'epoch_time_sec': 64.67, 'lr': 4.027787187107629e-06, 'train_loss': 0.011549, 'train_psnr': 25.1824, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0436}
# {'epoch': 4910, 'epoch_time_sec': 65.08, 'lr': 4.015550400219643e-06, 'train_loss': 0.011546, 'train_psnr': 25.1827, 'val_psnr': 24.0436, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0436}
# {'epoch': 4911, 'epoch_time_sec': 65.13, 'lr': 4.003337880077626e-06, 'train_loss': 0.01154, 'train_psnr': 25.1853, 'val_psnr': 24.0436, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0436}
# {'epoch': 4912, 'epoch_time_sec': 65.15, 'lr': 3.9911496308273306e-06, 'train_loss': 0.011545, 'train_psnr': 25.1824, 'val_psnr': 24.0436, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0436}
# {'epoch': 4913, 'epoch_time_sec': 65.11, 'lr': 3.978985656606306e-06, 'train_loss': 0.011544, 'train_psnr': 25.185, 'val_psnr': 24.0436, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0436}
# {'epoch': 4914, 'epoch_time_sec': 65.1, 'lr': 3.966845961543841e-06, 'train_loss': 0.011557, 'train_psnr': 25.1788, 'val_psnr': 24.0436, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0436}
# {'epoch': 4915, 'epoch_time_sec': 65.01, 'lr': 3.954730549760965e-06, 'train_loss': 0.01154, 'train_psnr': 25.1866, 'val_psnr': 24.0436, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0436}
# {'epoch': 4916, 'epoch_time_sec': 64.61, 'lr': 3.942639425370498e-06, 'train_loss': 0.011538, 'train_psnr': 25.189, 'val_psnr': 24.0436, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0436}
# {'epoch': 4917, 'epoch_time_sec': 64.87, 'lr': 3.930572592477002e-06, 'train_loss': 0.011534, 'train_psnr': 25.1882, 'val_psnr': 24.0436, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0436}
# {'epoch': 4918, 'epoch_time_sec': 64.85, 'lr': 3.91853005517678e-06, 'train_loss': 0.011539, 'train_psnr': 25.1863, 'val_psnr': 24.0436, 'input_psnr': 23.1331, 'delta_psnr': 0.9106, 'best_val_psnr': 24.0436}
# {'epoch': 4919, 'epoch_time_sec': 65.13, 'lr': 3.906511817557911e-06, 'train_loss': 0.011531, 'train_psnr': 25.1909, 'val_psnr': 24.0436, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0436}
# {'epoch': 4920, 'epoch_time_sec': 65.13, 'lr': 3.894517883700203e-06, 'train_loss': 0.011551, 'train_psnr': 25.1802, 'val_psnr': 24.0437, 'input_psnr': 23.1331, 'delta_psnr': 0.9106, 'best_val_psnr': 24.0437}
# {'epoch': 4921, 'epoch_time_sec': 65.15, 'lr': 3.882548257675234e-06, 'train_loss': 0.011541, 'train_psnr': 25.1858, 'val_psnr': 24.0437, 'input_psnr': 23.1331, 'delta_psnr': 0.9106, 'best_val_psnr': 24.0437}
# {'epoch': 4922, 'epoch_time_sec': 65.0, 'lr': 3.870602943546321e-06, 'train_loss': 0.011542, 'train_psnr': 25.1868, 'val_psnr': 24.0436, 'input_psnr': 23.1331, 'delta_psnr': 0.9106, 'best_val_psnr': 24.0437}
# {'epoch': 4923, 'epoch_time_sec': 65.1, 'lr': 3.858681945368498e-06, 'train_loss': 0.011551, 'train_psnr': 25.1817, 'val_psnr': 24.0436, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0437}
# {'epoch': 4924, 'epoch_time_sec': 65.07, 'lr': 3.846785267188607e-06, 'train_loss': 0.01153, 'train_psnr': 25.1929, 'val_psnr': 24.0437, 'input_psnr': 23.1331, 'delta_psnr': 0.9106, 'best_val_psnr': 24.0437}
# {'epoch': 4925, 'epoch_time_sec': 65.11, 'lr': 3.8349129130451825e-06, 'train_loss': 0.011532, 'train_psnr': 25.1899, 'val_psnr': 24.0437, 'input_psnr': 23.1331, 'delta_psnr': 0.9106, 'best_val_psnr': 24.0437}
# {'epoch': 4926, 'epoch_time_sec': 65.07, 'lr': 3.823064886968529e-06, 'train_loss': 0.011538, 'train_psnr': 25.1872, 'val_psnr': 24.0437, 'input_psnr': 23.1331, 'delta_psnr': 0.9106, 'best_val_psnr': 24.0437}
# {'epoch': 4927, 'epoch_time_sec': 65.1, 'lr': 3.811241192980674e-06, 'train_loss': 0.01155, 'train_psnr': 25.1853, 'val_psnr': 24.0436, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0437}
# {'epoch': 4928, 'epoch_time_sec': 65.14, 'lr': 3.7994418350953867e-06, 'train_loss': 0.011544, 'train_psnr': 25.1849, 'val_psnr': 24.0435, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0437}
# {'epoch': 4929, 'epoch_time_sec': 65.13, 'lr': 3.787666817318202e-06, 'train_loss': 0.011549, 'train_psnr': 25.1832, 'val_psnr': 24.0436, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0437}
# {'epoch': 4930, 'epoch_time_sec': 65.06, 'lr': 3.7759161436463737e-06, 'train_loss': 0.011534, 'train_psnr': 25.1883, 'val_psnr': 24.0436, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0437}
# {'epoch': 4931, 'epoch_time_sec': 65.13, 'lr': 3.7641898180688583e-06, 'train_loss': 0.011541, 'train_psnr': 25.1859, 'val_psnr': 24.0436, 'input_psnr': 23.1331, 'delta_psnr': 0.9105, 'best_val_psnr': 24.0437}

# %% [markdown]
# ## 6. Validation Summary

# %%
export_model = load_checkpoint_for_eval(best_ckpt_path, device)
validation_summary = evaluate_metrics(export_model, val_loader, device)
preview_info = write_val_preview(export_model, val_loader, preview_dir, device)
print({'validation_summary': validation_summary, 'best_checkpoint_path': str(best_ckpt_path), 'last_checkpoint_path': str(last_ckpt_path), 'preview': preview_info})

# %% [markdown]
# ## 7. Export And Submission Artifacts

# %%
def load_or_create_calibration_summary(calibration_dir: Path, pairs: list[tuple[Path, Path, str]], count: int, eval_size: int) -> dict[str, Any]:
    manifest_path = calibration_dir / 'manifest.json'
    if manifest_path.exists():
        manifest = json.loads(manifest_path.read_text(encoding='utf-8'))
        item_count = int(manifest.get('count') or len(manifest.get('items', [])))
        if item_count <= 0 or manifest.get('derived_from_training') is not True:
            raise ValueError(f'Invalid training-derived calibration manifest: {manifest_path}')
        return {'calibration_dir': str(calibration_dir), 'manifest_path': str(manifest_path), 'count': item_count, 'source': manifest.get('source'), 'derived_from_training': True, 'reused_existing_dataset': True}

    calibration_dir.mkdir(parents=True, exist_ok=True)
    items: list[dict[str, Any]] = []
    for index, (lr_path, _, name) in enumerate(pairs[:count]):
        image = Image.open(lr_path).convert('RGB')
        if image.size != (eval_size, eval_size):
            image = image.resize((eval_size, eval_size), BICUBIC_RESAMPLE)
        image_path = calibration_dir / f'{index:03d}_{Path(name).name}.png'
        image.save(image_path)
        items.append({'index': index, 'name': name, 'source_lr': str(lr_path), 'image_path': str(image_path), 'derived_from_training': True})
    manifest = {'count': len(items), 'source': 'training_pairs', 'eval_size': eval_size, 'derived_from_training': True, 'items': items}
    write_json(manifest_path, manifest)
    return {'calibration_dir': str(calibration_dir), 'manifest_path': str(manifest_path), 'count': len(items), 'source': 'training_pairs', 'derived_from_training': True, 'reused_existing_dataset': False}

conversion_script = """#!/usr/bin/env python3
from __future__ import annotations

import argparse
import json
import shlex
import subprocess
from pathlib import Path


def parse_args() -> argparse.Namespace:
    parser = argparse.ArgumentParser(description='Lab 3 ONNX-to-MXQ handoff script for FSRCNN residual.')
    parser.add_argument('--onnx', type=Path, required=True)
    parser.add_argument('--calibration-dir', type=Path, required=True)
    parser.add_argument('--output', type=Path, required=True)
    parser.add_argument('--command-template', default='', help='Optional command with {onnx}, {calibration}, {output} placeholders.')
    parser.add_argument('--dry-run', action='store_true')
    return parser.parse_args()


def main() -> None:
    args = parse_args()
    args.onnx = args.onnx.resolve()
    args.calibration_dir = args.calibration_dir.resolve()
    args.output = args.output.resolve()
    if not args.onnx.exists():
        raise FileNotFoundError(f'ONNX file not found: {args.onnx}')
    if not args.calibration_dir.exists():
        raise FileNotFoundError(f'Calibration directory not found: {args.calibration_dir}')
    payload = {
        'onnx': str(args.onnx),
        'calibration_dir': str(args.calibration_dir),
        'output': str(args.output),
        'status': 'handoff_only',
        'command_template': args.command_template,
    }
    if args.command_template:
        command = args.command_template.format(
            onnx=shlex.quote(str(args.onnx)),
            calibration=shlex.quote(str(args.calibration_dir)),
            output=shlex.quote(str(args.output)),
        )
        payload['command'] = command
        if not args.dry_run:
            completed = subprocess.run(command, shell=True, check=False, capture_output=True, text=True)
            payload.update({'status': 'completed' if completed.returncode == 0 else 'failed', 'returncode': completed.returncode, 'stdout': completed.stdout, 'stderr': completed.stderr})
    args.output.parent.mkdir(parents=True, exist_ok=True)
    handoff_path = args.output.with_suffix('.handoff.json')
    handoff_path.write_text(json.dumps(payload, indent=2, sort_keys=True) + '\n', encoding='utf-8')
    print(json.dumps(payload, indent=2, sort_keys=True))


if __name__ == '__main__':
    main()
"""

onnx_path = exports_dir / f'{cfg.model_id}.onnx'
mxq_target_path = exports_dir / f'{cfg.model_id}.mxq'
conversion_script_path = exports_dir / 'convert_fsrcnn_residual_mxq.py'
conversion_script_path.write_text(conversion_script, encoding='utf-8')

cpu_export_model = load_checkpoint_for_eval(best_ckpt_path, torch.device('cpu')).cpu().eval()
dummy = torch.randn(1, 3, cfg.eval_size, cfg.eval_size)
torch.onnx.export(cpu_export_model, dummy, str(onnx_path), input_names=['input'], output_names=['output'], opset_version=17, dynamo=False)

onnx_model = onnx.load(str(onnx_path))
onnx.checker.check_model(onnx_model)
node_ops = [node.op_type for node in onnx_model.graph.node]
op_histogram = {op: node_ops.count(op) for op in sorted(set(node_ops))}
onnx_summary = {'onnx_path': str(onnx_path), 'checked': True, 'graph_op_count': len(node_ops), 'op_histogram': op_histogram}
print(onnx_summary)

parity_result = {'attempted': False, 'onnxruntime_available': False, 'max_abs_diff': None, 'mean_abs_diff': None}
try:
    import onnxruntime as ort
    parity_result['attempted'] = True
    parity_result['onnxruntime_available'] = True
    parity_input = torch.randn(1, 3, cfg.eval_size, cfg.eval_size)
    with torch.no_grad():
        torch_out = cpu_export_model(parity_input).detach().cpu().numpy()
    ort_session = ort.InferenceSession(str(onnx_path), providers=['CPUExecutionProvider'])
    ort_out = ort_session.run(['output'], {'input': parity_input.numpy()})[0]
    diff = np.abs(torch_out - ort_out)
    parity_result['max_abs_diff'] = float(diff.max())
    parity_result['mean_abs_diff'] = float(diff.mean())
except ImportError:
    print('onnxruntime not installed; skipping CPU parity check')
print(parity_result)

calibration_dir = exports_dir / 'calibration'
calibration_summary = load_or_create_calibration_summary(calibration_dir, train_pairs, 128, cfg.eval_size)
mxq_command = f'python {conversion_script_path} --onnx {onnx_path} --calibration-dir {calibration_dir} --output {mxq_target_path} --dry-run'
mxq_handoff = {
    'conversion_script_path': str(conversion_script_path),
    'onnx_input_path': str(onnx_path),
    'calibration_manifest_path': calibration_summary['manifest_path'],
    'mxq_target_path': str(mxq_target_path),
    'command': mxq_command,
    'requested_compile': False,
}
summary = {
    'model_id': cfg.model_id,
    'run_root': str(run_root),
    'config': asdict(cfg),
    'data': {'data_root': str(data_root), 'train_pairs': len(train_pairs), 'val_pairs': len(val_pairs), 'train_splits': L3_TRAIN_SPLITS, 'val_dirs': L3_VAL_DIRS},
    'model': {'params': param_count, 'operator_audit': op_counts, 'input_shape': [1, 3, cfg.eval_size, cfg.eval_size], 'output_shape': [1, 3, cfg.eval_size, cfg.eval_size]},
    'validation': validation_summary,
    'preview': preview_info,
    'artifacts': {
        'best_checkpoint': str(best_ckpt_path),
        'last_checkpoint': str(last_ckpt_path),
        'onnx': str(onnx_path),
        'calibration_manifest': calibration_summary['manifest_path'],
        'conversion_script': str(conversion_script_path),
        'mxq_target': str(mxq_target_path),
        **run_log_paths,
    },
    'runtime': {
        'device': str(device),
        'gpu_name': gpu_name,
    },
    'onnx': onnx_summary,
    'onnx_parity': parity_result,
    'calibration': calibration_summary,
    'mxq_handoff': mxq_handoff,
}
write_json(summary_path, summary)
print({'summary_path': str(summary_path), **summary['artifacts']})
