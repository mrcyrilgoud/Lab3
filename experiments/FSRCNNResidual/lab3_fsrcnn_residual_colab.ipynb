# %% [markdown]
# # Lab 3 - FSRCNN Residual 96/40/m8 (Colab)
#
# - Model ID: `fsrcnn_residual_96_40_m8`
# - Goal: fixed-resolution super-resolution/restoration with an FSRCNN-inspired shrink-map-expand residual CNN
# - Expected input/output: `256x256x3`
# - Runtime target: Google Colab with Google Drive
# - Dataset layout: TinySRCNN legacy Lab 3 Drive folders
# - NPU-facing operators: `Conv`, `LeakyRelu`, and final residual `Add`

# %% [markdown]
# ## 1. Setup

# %%
try:
    import google.colab  # type: ignore
    IN_COLAB_BOOTSTRAP = True
except Exception:
    IN_COLAB_BOOTSTRAP = False

if IN_COLAB_BOOTSTRAP:
    # %pip install -q onnx onnxruntime

import csv
import json
import math
import os
import random
import sys
import time
from contextlib import nullcontext
from dataclasses import asdict, dataclass
from datetime import datetime
from pathlib import Path
from typing import Any

import numpy as np
import onnx
import torch
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
from torch.utils.data import DataLoader, Dataset

IMAGE_SUFFIXES = {'.png', '.jpg', '.jpeg', '.bmp'}
DRIVE_ROOT = Path('/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3')
DRIVE_DATA_ROOT = DRIVE_ROOT / 'Data'
DRIVE_RUNS_ROOT = DRIVE_ROOT / 'runs'

try:
    BICUBIC_RESAMPLE = Image.Resampling.BICUBIC
except AttributeError:
    BICUBIC_RESAMPLE = Image.BICUBIC

try:
    FLIP_LEFT_RIGHT = Image.Transpose.FLIP_LEFT_RIGHT
    FLIP_TOP_BOTTOM = Image.Transpose.FLIP_TOP_BOTTOM
    ROTATE_90 = Image.Transpose.ROTATE_90
    ROTATE_180 = Image.Transpose.ROTATE_180
    ROTATE_270 = Image.Transpose.ROTATE_270
except AttributeError:
    FLIP_LEFT_RIGHT = Image.FLIP_LEFT_RIGHT
    FLIP_TOP_BOTTOM = Image.FLIP_TOP_BOTTOM
    ROTATE_90 = Image.ROTATE_90
    ROTATE_180 = Image.ROTATE_180
    ROTATE_270 = Image.ROTATE_270


def set_global_seed(seed: int) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


def now_stamp() -> str:
    return datetime.now().strftime('%H%M%S_%d%m')


def is_colab_runtime() -> bool:
    try:
        import google.colab  # type: ignore  # noqa: F401
        return True
    except Exception:
        return False


def auto_num_workers(in_colab: bool) -> int:
    if sys.platform == 'darwin':
        return 0
    cpu_count = max(os.cpu_count() or 2, 2)
    if in_colab:
        return min(4, max(cpu_count - 1, 2))
    return min(2, cpu_count)


def resolve_repo_root(start: Path) -> Path:
    current = start.resolve()
    for candidate in [current, *current.parents]:
        if (candidate / 'Data').exists() and (candidate / 'runs').exists():
            return candidate
    for candidate in [current, *current.parents]:
        if (candidate / 'Data').exists():
            return candidate
    raise FileNotFoundError(f'Could not locate repo root from {start.resolve()}')


def make_unique_run_root(runs_root: Path, run_slug: str) -> Path:
    safe_slug = ''.join(ch if ch.isalnum() or ch in '_-' else '_' for ch in run_slug).strip('_')
    candidate = runs_root / f'{now_stamp()}_{safe_slug}'
    while candidate.exists():
        time.sleep(1.1)
        candidate = runs_root / f'{now_stamp()}_{safe_slug}'
    return candidate


def write_json(path: Path, payload: dict[str, Any]) -> None:
    path.parent.mkdir(parents=True, exist_ok=True)
    path.write_text(json.dumps(payload, indent=2, sort_keys=True) + '\n', encoding='utf-8')

# %% [markdown]
# ## 2. Configuration

# %%
@dataclass
class RunConfig:
    model_id: str = 'fsrcnn_residual_96_40_m8'
    run_slug: str = 'fsrcnn_residual_96_40_m8'
    enable_resume: bool = False
    resume_checkpoint_path: str | None = None
    seed: int = 1337
    train_patch_size: int = 256
    eval_size: int = 256
    batch_size: int = 16
    epochs: int = 5000
    lr: float = 1e-4
    min_lr: float = 1e-6
    weight_decay: float = 1e-4
    warmup_epochs: int = 8
    num_workers: int | None = 2
    prefetch_factor: int = 2
    use_amp: bool = True
    use_ema: bool = True
    ema_decay: float = 0.999
    calibration_count: int = 128

cfg = RunConfig()
in_colab = is_colab_runtime()
if in_colab:
    from google.colab import drive  # type: ignore

    drive.mount('/content/drive', force_remount=False)
    data_root = DRIVE_DATA_ROOT
    runs_root = DRIVE_RUNS_ROOT
    if not data_root.exists():
        raise FileNotFoundError(f'Google Drive data root not found: {data_root}')
else:
    repo_root = resolve_repo_root(Path.cwd())
    data_root = repo_root / 'Data'
    runs_root = repo_root / 'runs'
    if not data_root.exists():
        raise FileNotFoundError(f'Data root not found: {data_root}')

runs_root.mkdir(parents=True, exist_ok=True)
if cfg.num_workers is None:
    cfg.num_workers = auto_num_workers(in_colab)
if not cfg.enable_resume:
    cfg.resume_checkpoint_path = None

run_root = make_unique_run_root(runs_root, cfg.run_slug)
checkpoints_dir = run_root / 'checkpoints'
exports_dir = run_root / 'exports'
preview_dir = exports_dir / 'val_preview'
calibration_dir = exports_dir / 'calibration'
summary_path = run_root / 'summary.json'
metrics_csv_path = run_root / 'metrics.csv'

for directory in [run_root, checkpoints_dir, exports_dir, preview_dir, calibration_dir]:
    directory.mkdir(parents=True, exist_ok=True)

set_global_seed(cfg.seed)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
if device.type == 'cuda':
    torch.backends.cudnn.benchmark = True
    if hasattr(torch.backends.cuda.matmul, 'allow_tf32'):
        torch.backends.cuda.matmul.allow_tf32 = True

print({
    'device': str(device),
    'in_colab': in_colab,
    'data_root': str(data_root),
    'run_root': str(run_root),
    'config': asdict(cfg),
})
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# {'device': 'cuda', 'in_colab': True, 'data_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/Data', 'run_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/232518_2504_fsrcnn_residual_96_40_m8', 'config': {'model_id': 'fsrcnn_residual_96_40_m8', 'run_slug': 'fsrcnn_residual_96_40_m8', 'enable_resume': False, 'resume_checkpoint_path': None, 'seed': 1337, 'train_patch_size': 256, 'eval_size': 256, 'batch_size': 16, 'epochs': 5000, 'lr': 0.0001, 'min_lr': 1e-06, 'weight_decay': 0.0001, 'warmup_epochs': 8, 'num_workers': 2, 'prefetch_factor': 2, 'use_amp': True, 'use_ema': True, 'ema_decay': 0.999, 'calibration_count': 128}}

# %% [markdown]
# ## 3. Data

# %%
L3_TRAIN_SPLITS = (
    ('LR_HR/L3_HR_train1', 'L3_LR/L3_L3_train1', 'L3_HR_train1'),
    ('LR_HR/L3_HR_train2', 'L3_LR/L3_L3_train2', 'L3_HR_train2'),
    ('LR_HR/L3_HR_train3', 'L3_LR/L3_LR_train3', 'L3_HR_train3'),
    ('LR_HR/L3_HR_train4', 'L3_LR/L3_LR_train4', 'L3_HR_train4'),
    ('LR_HR/L3_HR_train', 'L3_LR/L3_LR_train', 'L3_HR_train'),
)
L3_VAL_DIRS = ('L3_HR_valid', 'L3_LR_valid')


def scan_image_directory(directory: Path) -> dict[str, Path]:
    if not directory.exists():
        raise FileNotFoundError(f'Missing directory: {directory}')
    return {
        path.stem: path
        for path in directory.iterdir()
        if path.is_file() and path.suffix.lower() in IMAGE_SUFFIXES
    }


def collect_split_pairs(hr_dir: Path, lr_dir: Path, split_name: str) -> list[tuple[Path, Path, str]]:
    hr_map = scan_image_directory(hr_dir)
    lr_map = scan_image_directory(lr_dir)
    shared = sorted(set(hr_map) & set(lr_map))
    if not shared:
        raise FileNotFoundError(f'No paired files found for {split_name}: HR={hr_dir}, LR={lr_dir}')
    hr_only = sorted(set(hr_map) - set(lr_map))
    lr_only = sorted(set(lr_map) - set(hr_map))
    if hr_only or lr_only:
        print({'split': split_name, 'hr_only_count': len(hr_only), 'lr_only_count': len(lr_only)})
    pairs: list[tuple[Path, Path, str]] = []
    for stem in shared:
        name = stem if split_name == 'val' else f'{split_name}/{stem}'
        pairs.append((lr_map[stem], hr_map[stem], name))
    return pairs


def collect_all_pairs(data_root: Path) -> tuple[list[tuple[Path, Path, str]], list[tuple[Path, Path, str]]]:
    train_pairs: list[tuple[Path, Path, str]] = []
    for hr_rel, lr_rel, split_name in L3_TRAIN_SPLITS:
        hr_dir = data_root / hr_rel
        lr_dir = data_root / lr_rel
        if hr_dir.exists() and lr_dir.exists():
            train_pairs.extend(collect_split_pairs(hr_dir, lr_dir, split_name))
        else:
            print({'skipped_missing_train_split': split_name, 'hr_dir': str(hr_dir), 'lr_dir': str(lr_dir)})
    val_pairs = collect_split_pairs(data_root / L3_VAL_DIRS[0], data_root / L3_VAL_DIRS[1], 'val')
    return train_pairs, val_pairs


class PairedSRDataset(Dataset):
    def __init__(self, pairs: list[tuple[Path, Path, str]], *, train: bool, patch_size: int, eval_size: int, seed: int):
        self.pairs = pairs
        self.train = train
        self.patch_size = patch_size
        self.eval_size = eval_size
        self.seed = seed
        self.epoch = 0

    def set_epoch(self, epoch: int) -> None:
        self.epoch = epoch

    @staticmethod
    def to_tensor(img: Image.Image) -> torch.Tensor:
        arr = np.asarray(img, dtype=np.float32) / 255.0
        return torch.from_numpy(arr).permute(2, 0, 1).contiguous()

    def augment_pair(self, lr: Image.Image, hr: Image.Image, index: int) -> tuple[Image.Image, Image.Image]:
        rng = random.Random((self.seed * 1_000_003) + (self.epoch * 9_973) + index)
        width, height = lr.size
        patch = self.patch_size
        if width < patch or height < patch:
            lr = lr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            hr = hr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            width, height = lr.size
        left = rng.randint(0, width - patch)
        top = rng.randint(0, height - patch)
        box = (left, top, left + patch, top + patch)
        lr = lr.crop(box)
        hr = hr.crop(box)
        if rng.random() < 0.5:
            lr = lr.transpose(FLIP_LEFT_RIGHT)
            hr = hr.transpose(FLIP_LEFT_RIGHT)
        if rng.random() < 0.5:
            lr = lr.transpose(FLIP_TOP_BOTTOM)
            hr = hr.transpose(FLIP_TOP_BOTTOM)
        rot = rng.choice([0, 1, 2, 3])
        if rot:
            rotate_ops = [ROTATE_90, ROTATE_180, ROTATE_270]
            lr = lr.transpose(rotate_ops[rot - 1])
            hr = hr.transpose(rotate_ops[rot - 1])
        return lr, hr

    def __len__(self) -> int:
        return len(self.pairs)

    def __getitem__(self, index: int) -> dict[str, Any]:
        lr_path, hr_path, name = self.pairs[index]
        lr = Image.open(lr_path).convert('RGB')
        hr = Image.open(hr_path).convert('RGB')
        if self.train:
            lr, hr = self.augment_pair(lr, hr, index)
        elif lr.size != (self.eval_size, self.eval_size):
            lr = lr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            hr = hr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
        return {'lr': self.to_tensor(lr), 'hr': self.to_tensor(hr), 'name': name}

train_pairs, val_pairs = collect_all_pairs(data_root)
if not train_pairs:
    raise FileNotFoundError(f'No training pairs found under {data_root}')
if not val_pairs:
    raise FileNotFoundError(f'No validation pairs found under {data_root}')

train_ds = PairedSRDataset(train_pairs, train=True, patch_size=cfg.train_patch_size, eval_size=cfg.eval_size, seed=cfg.seed)
val_ds = PairedSRDataset(val_pairs, train=False, patch_size=cfg.train_patch_size, eval_size=cfg.eval_size, seed=cfg.seed)

loader_num_workers = int(cfg.num_workers or 0)
train_loader_kwargs = {'dataset': train_ds, 'batch_size': cfg.batch_size, 'shuffle': True, 'num_workers': loader_num_workers, 'pin_memory': device.type == 'cuda'}
val_loader_kwargs = {'dataset': val_ds, 'batch_size': 1, 'shuffle': False, 'num_workers': loader_num_workers, 'pin_memory': device.type == 'cuda'}
if loader_num_workers > 0:
    train_loader_kwargs['persistent_workers'] = True
    val_loader_kwargs['persistent_workers'] = True
    train_loader_kwargs['prefetch_factor'] = cfg.prefetch_factor
    val_loader_kwargs['prefetch_factor'] = cfg.prefetch_factor

train_loader = DataLoader(**train_loader_kwargs)
val_loader = DataLoader(**val_loader_kwargs)

sample = train_ds[0]
print({
    'data_root': str(data_root),
    'train_pairs': len(train_pairs),
    'val_pairs': len(val_pairs),
    'train_preview': [name for _, _, name in train_pairs[:5]],
    'val_preview': [name for _, _, name in val_pairs[:5]],
    'sample_lr_shape': tuple(sample['lr'].shape),
    'sample_hr_shape': tuple(sample['hr'].shape),
})
assert tuple(sample['lr'].shape) == (3, cfg.eval_size, cfg.eval_size)
assert tuple(sample['hr'].shape) == (3, cfg.eval_size, cfg.eval_size)
# Out:
# {'data_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/Data', 'train_pairs': 2217, 'val_pairs': 110, 'train_preview': ['L3_HR_train1/0000', 'L3_HR_train1/0001', 'L3_HR_train1/00010', 'L3_HR_train1/000100', 'L3_HR_train1/000101'], 'val_preview': ['0000', '00010', '000100', '000102', '000104'], 'sample_lr_shape': (3, 256, 256), 'sample_hr_shape': (3, 256, 256)}

# %% [markdown]
# ## 4. Model

# %%
class FSRCNNResidualNoUpscale(nn.Module):
    def __init__(self, channels: int = 96, shrink_channels: int = 40, mapping_layers: int = 8, slope: float = 0.10):
        super().__init__()
        layers: list[nn.Module] = [
            nn.Conv2d(3, channels, 5, padding=2, bias=True),
            nn.LeakyReLU(slope, inplace=False),
            nn.Conv2d(channels, shrink_channels, 1, padding=0, bias=True),
            nn.LeakyReLU(slope, inplace=False),
        ]
        for _ in range(mapping_layers):
            layers.extend([
                nn.Conv2d(shrink_channels, shrink_channels, 3, padding=1, bias=True),
                nn.LeakyReLU(slope, inplace=False),
            ])
        layers.extend([
            nn.Conv2d(shrink_channels, channels, 1, padding=0, bias=True),
            nn.LeakyReLU(slope, inplace=False),
        ])
        self.features = nn.Sequential(*layers)
        self.tail = nn.Conv2d(channels, 3, 3, padding=1, bias=True)
        self.init_tail_small()

    def init_tail_small(self) -> None:
        nn.init.kaiming_normal_(self.tail.weight, nonlinearity='linear')
        self.tail.weight.data.mul_(1e-3)
        if self.tail.bias is not None:
            nn.init.zeros_(self.tail.bias)

    def predict_delta(self, x: torch.Tensor) -> torch.Tensor:
        return self.tail(self.features(x))

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return x + self.predict_delta(x)


def count_parameters(module: nn.Module) -> int:
    return int(sum(param.numel() for param in module.parameters()))


def operator_audit(module: nn.Module) -> dict[str, int]:
    counts: dict[str, int] = {}
    for child in module.modules():
        if len(list(child.children())) != 0:
            continue
        name = child.__class__.__name__
        counts[name] = counts.get(name, 0) + 1
    return dict(sorted(counts.items()))

model = FSRCNNResidualNoUpscale().to(device)
eval_model = FSRCNNResidualNoUpscale().to(device)
param_count = count_parameters(model)
op_counts = operator_audit(model)
dummy = torch.zeros(1, 3, cfg.eval_size, cfg.eval_size, device=device)
with torch.no_grad():
    dummy_out = model(dummy)

print({
    'model_id': cfg.model_id,
    'params': param_count,
    'operator_audit': op_counts,
    'input_shape': tuple(dummy.shape),
    'output_shape': tuple(dummy_out.shape),
    'architecture': 'Conv5x5 3->96, Conv1x1 96->40, 8x Conv3x3 40->40, Conv1x1 40->96, Conv3x3 96->3, residual add',
})
assert param_count == 133_227, param_count
assert tuple(dummy_out.shape) == (1, 3, cfg.eval_size, cfg.eval_size)
assert set(op_counts).issubset({'Conv2d', 'LeakyReLU'}), op_counts
# Out:
# {'model_id': 'fsrcnn_residual_96_40_m8', 'params': 133227, 'operator_audit': {'Conv2d': 12, 'LeakyReLU': 11}, 'input_shape': (1, 3, 256, 256), 'output_shape': (1, 3, 256, 256), 'architecture': 'Conv5x5 3->96, Conv1x1 96->40, 8x Conv3x3 40->40, Conv1x1 40->96, Conv3x3 96->3, residual add'}

# %% [markdown]
# ## 5. Training And Validation
#
# Train with AMP, EMA, AdamW, cosine learning rate decay, PSNR validation, checkpointing, and validation previews.

# %%
class EMA:
    def __init__(self, model: nn.Module, decay: float):
        self.decay = decay
        self.shadow = {k: v.detach().clone() for k, v in model.state_dict().items()}

    @torch.no_grad()
    def update(self, model: nn.Module) -> None:
        for key, value in model.state_dict().items():
            self.shadow[key].mul_(self.decay).add_(value.detach(), alpha=1.0 - self.decay)

    @torch.no_grad()
    def copy_to(self, model: nn.Module) -> None:
        model.load_state_dict(self.shadow, strict=True)


def make_grad_scaler(enabled: bool):
    if hasattr(torch, 'amp') and hasattr(torch.amp, 'GradScaler'):
        return torch.amp.GradScaler('cuda', enabled=enabled)
    return torch.cuda.amp.GradScaler(enabled=enabled)


def autocast_context(device_type: str, enabled: bool):
    if not enabled:
        return nullcontext()
    if hasattr(torch, 'amp') and hasattr(torch.amp, 'autocast'):
        return torch.amp.autocast(device_type=device_type, enabled=enabled)
    return torch.cuda.amp.autocast(enabled=enabled)


@torch.no_grad()
def batch_psnr(pred: torch.Tensor, target: torch.Tensor) -> float:
    mse = F.mse_loss(pred, target, reduction='none').mean(dim=(1, 2, 3))
    psnr = 10.0 * torch.log10(1.0 / torch.clamp(mse, min=1e-12))
    return float(psnr.mean().item())


def compute_loss(pred: torch.Tensor, lr: torch.Tensor, hr: torch.Tensor) -> torch.Tensor:
    mse = F.mse_loss(pred, hr)
    residual_l1 = F.l1_loss(pred - lr, hr - lr)
    return 0.8 * mse + 0.2 * residual_l1


def lr_at_epoch(epoch_idx: int, *, base_lr: float, min_lr: float, warmup_epochs: int, total_epochs: int) -> float:
    step = epoch_idx + 1
    if warmup_epochs > 0 and step <= warmup_epochs:
        return base_lr * step / max(1, warmup_epochs)
    progress = max(0.0, (step - warmup_epochs) / max(1, total_epochs - warmup_epochs))
    cosine = 0.5 * (1.0 + math.cos(math.pi * min(progress, 1.0)))
    return min_lr + cosine * (base_lr - min_lr)


@torch.inference_mode()
def evaluate_metrics(model: nn.Module, loader: DataLoader, device: torch.device) -> dict[str, float]:
    model.eval()
    pred_meter = 0.0
    input_meter = 0.0
    count = 0
    for batch in loader:
        lr = batch['lr'].to(device, non_blocking=(device.type == 'cuda'))
        hr = batch['hr'].to(device, non_blocking=(device.type == 'cuda'))
        pred = model(lr).clamp(0.0, 1.0)
        pred_meter += batch_psnr(pred, hr)
        input_meter += batch_psnr(lr, hr)
        count += 1
    val_psnr = pred_meter / max(count, 1)
    input_psnr = input_meter / max(count, 1)
    return {'val_psnr': float(val_psnr), 'input_psnr': float(input_psnr), 'delta_psnr': float(val_psnr - input_psnr)}


def tensor_to_uint8_image(x: torch.Tensor) -> Image.Image:
    x = x.detach().cpu().clamp(0.0, 1.0)
    arr = (x.permute(1, 2, 0).numpy() * 255.0).round().astype(np.uint8)
    return Image.fromarray(arr)


@torch.no_grad()
def write_val_preview(model: nn.Module, loader: DataLoader, out_dir: Path, device: torch.device) -> dict[str, str]:
    out_dir.mkdir(parents=True, exist_ok=True)
    batch = next(iter(loader))
    lr = batch['lr'].to(device, non_blocking=(device.type == 'cuda'))
    hr = batch['hr'].to(device, non_blocking=(device.type == 'cuda'))
    pred = model(lr).clamp(0.0, 1.0)
    name = batch['name'][0]
    lr_path = out_dir / 'val_preview_input.png'
    pred_path = out_dir / 'val_preview_pred.png'
    hr_path = out_dir / 'val_preview_target.png'
    tensor_to_uint8_image(lr[0]).save(lr_path)
    tensor_to_uint8_image(pred[0]).save(pred_path)
    tensor_to_uint8_image(hr[0]).save(hr_path)
    return {'sample_name': str(name), 'input': str(lr_path), 'prediction': str(pred_path), 'target': str(hr_path)}


def checkpoint_payload(model: nn.Module, ema: EMA | None, optimizer: torch.optim.Optimizer, epoch: int, best_val_psnr: float, row: dict[str, Any]) -> dict[str, Any]:
    return {
        'config': asdict(cfg),
        'epoch': int(epoch),
        'model_state_dict': model.state_dict(),
        'ema_state_dict': ema.shadow if ema is not None else None,
        'optimizer_state_dict': optimizer.state_dict(),
        'best_val_psnr': float(best_val_psnr),
        'latest_metrics': row,
        'model_params': param_count,
        'operator_audit': op_counts,
    }


def load_checkpoint_for_eval(checkpoint_path: Path, device: torch.device) -> nn.Module:
    checkpoint = torch.load(checkpoint_path, map_location=device)
    loaded = FSRCNNResidualNoUpscale().to(device)
    state = checkpoint.get('ema_state_dict') or checkpoint['model_state_dict']
    loaded.load_state_dict(state, strict=True)
    loaded.eval()
    return loaded

optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)
scaler = make_grad_scaler(cfg.use_amp and device.type == 'cuda')
ema = EMA(model, cfg.ema_decay) if cfg.use_ema else None
best_val_psnr = float('-inf')
start_epoch = 0

metrics_header = ['epoch', 'epoch_time_sec', 'lr', 'train_loss', 'train_psnr', 'val_psnr', 'input_psnr', 'delta_psnr', 'best_val_psnr']
best_ckpt_path = checkpoints_dir / 'best.pth'
last_ckpt_path = checkpoints_dir / 'last.pth'
with metrics_csv_path.open('w', newline='', encoding='utf-8') as f:
    csv.DictWriter(f, fieldnames=metrics_header).writeheader()

for epoch in range(start_epoch, cfg.epochs):
    train_ds.set_epoch(epoch)
    epoch_lr = lr_at_epoch(epoch, base_lr=cfg.lr, min_lr=cfg.min_lr, warmup_epochs=cfg.warmup_epochs, total_epochs=cfg.epochs)
    for group in optimizer.param_groups:
        group['lr'] = epoch_lr

    epoch_start = time.time()
    model.train()
    train_loss_sum = 0.0
    train_psnr_sum = 0.0
    train_batches = 0

    for batch in train_loader:
        lr = batch['lr'].to(device, non_blocking=(device.type == 'cuda'))
        hr = batch['hr'].to(device, non_blocking=(device.type == 'cuda'))
        optimizer.zero_grad(set_to_none=True)
        with autocast_context(device.type, enabled=(cfg.use_amp and device.type == 'cuda')):
            pred = model(lr)
            loss = compute_loss(pred, lr, hr)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        if ema is not None:
            ema.update(model)
        train_loss_sum += float(loss.item())
        train_psnr_sum += batch_psnr(pred.detach().clamp(0.0, 1.0), hr)
        train_batches += 1

    if ema is not None:
        ema.copy_to(eval_model)
    else:
        eval_model.load_state_dict(model.state_dict())
    eval_model.eval()

    avg_train_loss = train_loss_sum / max(train_batches, 1)
    avg_train_psnr = train_psnr_sum / max(train_batches, 1)
    val_metrics = evaluate_metrics(eval_model, val_loader, device)
    is_best = val_metrics['val_psnr'] > best_val_psnr
    if is_best:
        best_val_psnr = val_metrics['val_psnr']
    row = {
        'epoch': epoch + 1,
        'epoch_time_sec': round(time.time() - epoch_start, 2),
        'lr': epoch_lr,
        'train_loss': round(avg_train_loss, 6),
        'train_psnr': round(avg_train_psnr, 4),
        'val_psnr': round(val_metrics['val_psnr'], 4),
        'input_psnr': round(val_metrics['input_psnr'], 4),
        'delta_psnr': round(val_metrics['delta_psnr'], 4),
        'best_val_psnr': round(best_val_psnr, 4),
    }
    print(row)
    with metrics_csv_path.open('a', newline='', encoding='utf-8') as f:
        csv.DictWriter(f, fieldnames=metrics_header).writerow(row)
    payload = checkpoint_payload(model, ema, optimizer, epoch + 1, best_val_psnr, row)
    torch.save(payload, last_ckpt_path)
    if is_best:
        torch.save(payload, best_ckpt_path)
# Out:
# {'epoch': 1, 'epoch_time_sec': 62.4, 'lr': 1.25e-05, 'train_loss': 0.013215, 'train_psnr': 24.3186, 'val_psnr': 23.1333, 'input_psnr': 23.1331, 'delta_psnr': 0.0003, 'best_val_psnr': 23.1333}
# {'epoch': 2, 'epoch_time_sec': 42.09, 'lr': 2.5e-05, 'train_loss': 0.013207, 'train_psnr': 24.3222, 'val_psnr': 23.1336, 'input_psnr': 23.1331, 'delta_psnr': 0.0005, 'best_val_psnr': 23.1336}
# {'epoch': 3, 'epoch_time_sec': 41.64, 'lr': 3.7500000000000003e-05, 'train_loss': 0.013207, 'train_psnr': 24.323, 'val_psnr': 23.1339, 'input_psnr': 23.1331, 'delta_psnr': 0.0008, 'best_val_psnr': 23.1339}
# {'epoch': 4, 'epoch_time_sec': 41.62, 'lr': 5e-05, 'train_loss': 0.013208, 'train_psnr': 24.321, 'val_psnr': 23.1342, 'input_psnr': 23.1331, 'delta_psnr': 0.0011, 'best_val_psnr': 23.1342}
# {'epoch': 5, 'epoch_time_sec': 41.89, 'lr': 6.25e-05, 'train_loss': 0.013199, 'train_psnr': 24.3265, 'val_psnr': 23.1355, 'input_psnr': 23.1331, 'delta_psnr': 0.0024, 'best_val_psnr': 23.1355}
# {'epoch': 6, 'epoch_time_sec': 42.03, 'lr': 7.500000000000001e-05, 'train_loss': 0.01318, 'train_psnr': 24.3451, 'val_psnr': 23.1363, 'input_psnr': 23.1331, 'delta_psnr': 0.0033, 'best_val_psnr': 23.1363}
# {'epoch': 7, 'epoch_time_sec': 42.18, 'lr': 8.75e-05, 'train_loss': 0.012984, 'train_psnr': 24.4349, 'val_psnr': 23.1365, 'input_psnr': 23.1331, 'delta_psnr': 0.0034, 'best_val_psnr': 23.1365}
# {'epoch': 8, 'epoch_time_sec': 42.04, 'lr': 0.0001, 'train_loss': 0.012855, 'train_psnr': 24.4975, 'val_psnr': 23.1366, 'input_psnr': 23.1331, 'delta_psnr': 0.0035, 'best_val_psnr': 23.1366}
# {'epoch': 9, 'epoch_time_sec': 42.16, 'lr': 9.999999019774986e-05, 'train_loss': 0.012801, 'train_psnr': 24.5276, 'val_psnr': 23.1369, 'input_psnr': 23.1331, 'delta_psnr': 0.0039, 'best_val_psnr': 23.1369}
# {'epoch': 10, 'epoch_time_sec': 42.23, 'lr': 9.999996079100332e-05, 'train_loss': 0.012746, 'train_psnr': 24.5521, 'val_psnr': 23.1381, 'input_psnr': 23.1331, 'delta_psnr': 0.005, 'best_val_psnr': 23.1381}
# {'epoch': 11, 'epoch_time_sec': 42.27, 'lr': 9.999991177977202e-05, 'train_loss': 0.012701, 'train_psnr': 24.5755, 'val_psnr': 23.1412, 'input_psnr': 23.1331, 'delta_psnr': 0.0081, 'best_val_psnr': 23.1412}
# {'epoch': 12, 'epoch_time_sec': 42.11, 'lr': 9.999984316407539e-05, 'train_loss': 0.012687, 'train_psnr': 24.5812, 'val_psnr': 23.1473, 'input_psnr': 23.1331, 'delta_psnr': 0.0142, 'best_val_psnr': 23.1473}
# {'epoch': 13, 'epoch_time_sec': 41.95, 'lr': 9.999975494394058e-05, 'train_loss': 0.012667, 'train_psnr': 24.5918, 'val_psnr': 23.1566, 'input_psnr': 23.1331, 'delta_psnr': 0.0235, 'best_val_psnr': 23.1566}
# {'epoch': 14, 'epoch_time_sec': 42.15, 'lr': 9.999964711940254e-05, 'train_loss': 0.012636, 'train_psnr': 24.6068, 'val_psnr': 23.1683, 'input_psnr': 23.1331, 'delta_psnr': 0.0352, 'best_val_psnr': 23.1683}
# {'epoch': 15, 'epoch_time_sec': 42.14, 'lr': 9.999951969050398e-05, 'train_loss': 0.012623, 'train_psnr': 24.6135, 'val_psnr': 23.1824, 'input_psnr': 23.1331, 'delta_psnr': 0.0494, 'best_val_psnr': 23.1824}
# {'epoch': 16, 'epoch_time_sec': 42.21, 'lr': 9.999937265729538e-05, 'train_loss': 0.012601, 'train_psnr': 24.6245, 'val_psnr': 23.1995, 'input_psnr': 23.1331, 'delta_psnr': 0.0664, 'best_val_psnr': 23.1995}
# {'epoch': 17, 'epoch_time_sec': 42.37, 'lr': 9.999920601983494e-05, 'train_loss': 0.012579, 'train_psnr': 24.6343, 'val_psnr': 23.2192, 'input_psnr': 23.1331, 'delta_psnr': 0.0861, 'best_val_psnr': 23.2192}
# {'epoch': 18, 'epoch_time_sec': 42.21, 'lr': 9.999901977818868e-05, 'train_loss': 0.012561, 'train_psnr': 24.6442, 'val_psnr': 23.2407, 'input_psnr': 23.1331, 'delta_psnr': 0.1077, 'best_val_psnr': 23.2407}
# {'epoch': 19, 'epoch_time_sec': 42.24, 'lr': 9.999881393243034e-05, 'train_loss': 0.012554, 'train_psnr': 24.6511, 'val_psnr': 23.2634, 'input_psnr': 23.1331, 'delta_psnr': 0.1303, 'best_val_psnr': 23.2634}
# {'epoch': 20, 'epoch_time_sec': 42.28, 'lr': 9.999858848264148e-05, 'train_loss': 0.012549, 'train_psnr': 24.6526, 'val_psnr': 23.2863, 'input_psnr': 23.1331, 'delta_psnr': 0.1532, 'best_val_psnr': 23.2863}
# {'epoch': 21, 'epoch_time_sec': 42.2, 'lr': 9.999834342891135e-05, 'train_loss': 0.012524, 'train_psnr': 24.6641, 'val_psnr': 23.3091, 'input_psnr': 23.1331, 'delta_psnr': 0.1761, 'best_val_psnr': 23.3091}
# {'epoch': 22, 'epoch_time_sec': 42.44, 'lr': 9.999807877133706e-05, 'train_loss': 0.012502, 'train_psnr': 24.6729, 'val_psnr': 23.3317, 'input_psnr': 23.1331, 'delta_psnr': 0.1987, 'best_val_psnr': 23.3317}
# {'epoch': 23, 'epoch_time_sec': 42.48, 'lr': 9.999779451002334e-05, 'train_loss': 0.012483, 'train_psnr': 24.6843, 'val_psnr': 23.3538, 'input_psnr': 23.1331, 'delta_psnr': 0.2208, 'best_val_psnr': 23.3538}
# {'epoch': 24, 'epoch_time_sec': 42.48, 'lr': 9.999749064508286e-05, 'train_loss': 0.012471, 'train_psnr': 24.6873, 'val_psnr': 23.3749, 'input_psnr': 23.1331, 'delta_psnr': 0.2418, 'best_val_psnr': 23.3749}
# {'epoch': 25, 'epoch_time_sec': 42.7, 'lr': 9.999716717663591e-05, 'train_loss': 0.012447, 'train_psnr': 24.6967, 'val_psnr': 23.3948, 'input_psnr': 23.1331, 'delta_psnr': 0.2617, 'best_val_psnr': 23.3948}
# {'epoch': 26, 'epoch_time_sec': 42.53, 'lr': 9.999682410481063e-05, 'train_loss': 0.012451, 'train_psnr': 24.6984, 'val_psnr': 23.4133, 'input_psnr': 23.1331, 'delta_psnr': 0.2803, 'best_val_psnr': 23.4133}
# {'epoch': 27, 'epoch_time_sec': 42.08, 'lr': 9.999646142974287e-05, 'train_loss': 0.01242, 'train_psnr': 24.7101, 'val_psnr': 23.4304, 'input_psnr': 23.1331, 'delta_psnr': 0.2974, 'best_val_psnr': 23.4304}
# {'epoch': 28, 'epoch_time_sec': 42.28, 'lr': 9.99960791515763e-05, 'train_loss': 0.012406, 'train_psnr': 24.7185, 'val_psnr': 23.4463, 'input_psnr': 23.1331, 'delta_psnr': 0.3132, 'best_val_psnr': 23.4463}
# {'epoch': 29, 'epoch_time_sec': 42.35, 'lr': 9.999567727046228e-05, 'train_loss': 0.012401, 'train_psnr': 24.7206, 'val_psnr': 23.4609, 'input_psnr': 23.1331, 'delta_psnr': 0.3278, 'best_val_psnr': 23.4609}
# {'epoch': 30, 'epoch_time_sec': 42.25, 'lr': 9.999525578656e-05, 'train_loss': 0.012381, 'train_psnr': 24.7313, 'val_psnr': 23.4741, 'input_psnr': 23.1331, 'delta_psnr': 0.3411, 'best_val_psnr': 23.4741}
# {'epoch': 31, 'epoch_time_sec': 42.11, 'lr': 9.99948147000364e-05, 'train_loss': 0.012397, 'train_psnr': 24.7236, 'val_psnr': 23.4863, 'input_psnr': 23.1331, 'delta_psnr': 0.3533, 'best_val_psnr': 23.4863}
# {'epoch': 32, 'epoch_time_sec': 42.4, 'lr': 9.999435401106615e-05, 'train_loss': 0.012402, 'train_psnr': 24.724, 'val_psnr': 23.4974, 'input_psnr': 23.1331, 'delta_psnr': 0.3643, 'best_val_psnr': 23.4974}
# {'epoch': 33, 'epoch_time_sec': 42.31, 'lr': 9.999387371983172e-05, 'train_loss': 0.012386, 'train_psnr': 24.7279, 'val_psnr': 23.507, 'input_psnr': 23.1331, 'delta_psnr': 0.374, 'best_val_psnr': 23.507}
# {'epoch': 34, 'epoch_time_sec': 42.3, 'lr': 9.999337382652331e-05, 'train_loss': 0.012348, 'train_psnr': 24.7468, 'val_psnr': 23.516, 'input_psnr': 23.1331, 'delta_psnr': 0.3829, 'best_val_psnr': 23.516}
# {'epoch': 35, 'epoch_time_sec': 42.2, 'lr': 9.999285433133892e-05, 'train_loss': 0.012356, 'train_psnr': 24.7404, 'val_psnr': 23.524, 'input_psnr': 23.1331, 'delta_psnr': 0.3909, 'best_val_psnr': 23.524}
# {'epoch': 36, 'epoch_time_sec': 42.03, 'lr': 9.99923152344843e-05, 'train_loss': 0.012338, 'train_psnr': 24.7504, 'val_psnr': 23.5314, 'input_psnr': 23.1331, 'delta_psnr': 0.3984, 'best_val_psnr': 23.5314}
# {'epoch': 37, 'epoch_time_sec': 42.32, 'lr': 9.999175653617295e-05, 'train_loss': 0.012353, 'train_psnr': 24.7448, 'val_psnr': 23.5381, 'input_psnr': 23.1331, 'delta_psnr': 0.405, 'best_val_psnr': 23.5381}
# {'epoch': 38, 'epoch_time_sec': 42.26, 'lr': 9.999117823662615e-05, 'train_loss': 0.012327, 'train_psnr': 24.7574, 'val_psnr': 23.5442, 'input_psnr': 23.1331, 'delta_psnr': 0.4112, 'best_val_psnr': 23.5442}
# {'epoch': 39, 'epoch_time_sec': 42.23, 'lr': 9.999058033607294e-05, 'train_loss': 0.012327, 'train_psnr': 24.7546, 'val_psnr': 23.5496, 'input_psnr': 23.1331, 'delta_psnr': 0.4165, 'best_val_psnr': 23.5496}
# {'epoch': 40, 'epoch_time_sec': 42.13, 'lr': 9.998996283475009e-05, 'train_loss': 0.012327, 'train_psnr': 24.7564, 'val_psnr': 23.5548, 'input_psnr': 23.1331, 'delta_psnr': 0.4217, 'best_val_psnr': 23.5548}
# {'epoch': 41, 'epoch_time_sec': 42.16, 'lr': 9.998932573290218e-05, 'train_loss': 0.012304, 'train_psnr': 24.7678, 'val_psnr': 23.5596, 'input_psnr': 23.1331, 'delta_psnr': 0.4266, 'best_val_psnr': 23.5596}
# {'epoch': 42, 'epoch_time_sec': 42.18, 'lr': 9.998866903078155e-05, 'train_loss': 0.012309, 'train_psnr': 24.766, 'val_psnr': 23.5643, 'input_psnr': 23.1331, 'delta_psnr': 0.4313, 'best_val_psnr': 23.5643}
# {'epoch': 43, 'epoch_time_sec': 42.38, 'lr': 9.998799272864827e-05, 'train_loss': 0.012297, 'train_psnr': 24.7707, 'val_psnr': 23.5685, 'input_psnr': 23.1331, 'delta_psnr': 0.4355, 'best_val_psnr': 23.5685}
# {'epoch': 44, 'epoch_time_sec': 42.37, 'lr': 9.99872968267702e-05, 'train_loss': 0.012309, 'train_psnr': 24.7672, 'val_psnr': 23.5727, 'input_psnr': 23.1331, 'delta_psnr': 0.4397, 'best_val_psnr': 23.5727}
# {'epoch': 45, 'epoch_time_sec': 42.26, 'lr': 9.998658132542294e-05, 'train_loss': 0.012287, 'train_psnr': 24.7766, 'val_psnr': 23.5767, 'input_psnr': 23.1331, 'delta_psnr': 0.4436, 'best_val_psnr': 23.5767}
# {'epoch': 46, 'epoch_time_sec': 42.25, 'lr': 9.998584622488986e-05, 'train_loss': 0.012284, 'train_psnr': 24.7779, 'val_psnr': 23.5805, 'input_psnr': 23.1331, 'delta_psnr': 0.4475, 'best_val_psnr': 23.5805}
# {'epoch': 47, 'epoch_time_sec': 42.34, 'lr': 9.998509152546211e-05, 'train_loss': 0.012285, 'train_psnr': 24.7755, 'val_psnr': 23.5841, 'input_psnr': 23.1331, 'delta_psnr': 0.451, 'best_val_psnr': 23.5841}
# {'epoch': 48, 'epoch_time_sec': 42.46, 'lr': 9.99843172274386e-05, 'train_loss': 0.012287, 'train_psnr': 24.7767, 'val_psnr': 23.5876, 'input_psnr': 23.1331, 'delta_psnr': 0.4545, 'best_val_psnr': 23.5876}
# {'epoch': 49, 'epoch_time_sec': 42.64, 'lr': 9.998352333112596e-05, 'train_loss': 0.01229, 'train_psnr': 24.7752, 'val_psnr': 23.5909, 'input_psnr': 23.1331, 'delta_psnr': 0.4578, 'best_val_psnr': 23.5909}
# {'epoch': 50, 'epoch_time_sec': 42.67, 'lr': 9.998270983683865e-05, 'train_loss': 0.01228, 'train_psnr': 24.7813, 'val_psnr': 23.5942, 'input_psnr': 23.1331, 'delta_psnr': 0.4612, 'best_val_psnr': 23.5942}
# {'epoch': 51, 'epoch_time_sec': 42.29, 'lr': 9.998187674489883e-05, 'train_loss': 0.012257, 'train_psnr': 24.7916, 'val_psnr': 23.5973, 'input_psnr': 23.1331, 'delta_psnr': 0.4643, 'best_val_psnr': 23.5973}
# {'epoch': 52, 'epoch_time_sec': 42.24, 'lr': 9.998102405563643e-05, 'train_loss': 0.012245, 'train_psnr': 24.7978, 'val_psnr': 23.6006, 'input_psnr': 23.1331, 'delta_psnr': 0.4675, 'best_val_psnr': 23.6006}
# {'epoch': 53, 'epoch_time_sec': 42.44, 'lr': 9.99801517693892e-05, 'train_loss': 0.012249, 'train_psnr': 24.7945, 'val_psnr': 23.6037, 'input_psnr': 23.1331, 'delta_psnr': 0.4706, 'best_val_psnr': 23.6037}
# {'epoch': 54, 'epoch_time_sec': 42.27, 'lr': 9.997925988650259e-05, 'train_loss': 0.012231, 'train_psnr': 24.8042, 'val_psnr': 23.6068, 'input_psnr': 23.1331, 'delta_psnr': 0.4737, 'best_val_psnr': 23.6068}
# {'epoch': 55, 'epoch_time_sec': 42.26, 'lr': 9.997834840732984e-05, 'train_loss': 0.012242, 'train_psnr': 24.7978, 'val_psnr': 23.6098, 'input_psnr': 23.1331, 'delta_psnr': 0.4767, 'best_val_psnr': 23.6098}
# {'epoch': 56, 'epoch_time_sec': 42.31, 'lr': 9.99774173322319e-05, 'train_loss': 0.01225, 'train_psnr': 24.7973, 'val_psnr': 23.6127, 'input_psnr': 23.1331, 'delta_psnr': 0.4796, 'best_val_psnr': 23.6127}
# {'epoch': 57, 'epoch_time_sec': 42.16, 'lr': 9.997646666157758e-05, 'train_loss': 0.012216, 'train_psnr': 24.811, 'val_psnr': 23.6156, 'input_psnr': 23.1331, 'delta_psnr': 0.4825, 'best_val_psnr': 23.6156}
# {'epoch': 58, 'epoch_time_sec': 42.29, 'lr': 9.997549639574335e-05, 'train_loss': 0.012214, 'train_psnr': 24.8099, 'val_psnr': 23.6185, 'input_psnr': 23.1331, 'delta_psnr': 0.4855, 'best_val_psnr': 23.6185}
# {'epoch': 59, 'epoch_time_sec': 42.28, 'lr': 9.997450653511352e-05, 'train_loss': 0.012204, 'train_psnr': 24.8142, 'val_psnr': 23.6216, 'input_psnr': 23.1331, 'delta_psnr': 0.4885, 'best_val_psnr': 23.6216}
# {'epoch': 60, 'epoch_time_sec': 42.18, 'lr': 9.99734970800801e-05, 'train_loss': 0.012188, 'train_psnr': 24.8213, 'val_psnr': 23.6246, 'input_psnr': 23.1331, 'delta_psnr': 0.4916, 'best_val_psnr': 23.6246}
# {'epoch': 61, 'epoch_time_sec': 42.24, 'lr': 9.99724680310429e-05, 'train_loss': 0.012194, 'train_psnr': 24.82, 'val_psnr': 23.6278, 'input_psnr': 23.1331, 'delta_psnr': 0.4948, 'best_val_psnr': 23.6278}
# {'epoch': 62, 'epoch_time_sec': 42.17, 'lr': 9.997141938840947e-05, 'train_loss': 0.012189, 'train_psnr': 24.8204, 'val_psnr': 23.631, 'input_psnr': 23.1331, 'delta_psnr': 0.498, 'best_val_psnr': 23.631}
# {'epoch': 63, 'epoch_time_sec': 42.37, 'lr': 9.997035115259511e-05, 'train_loss': 0.012173, 'train_psnr': 24.8285, 'val_psnr': 23.6345, 'input_psnr': 23.1331, 'delta_psnr': 0.5014, 'best_val_psnr': 23.6345}
# {'epoch': 64, 'epoch_time_sec': 42.21, 'lr': 9.996926332402291e-05, 'train_loss': 0.012166, 'train_psnr': 24.8322, 'val_psnr': 23.6378, 'input_psnr': 23.1331, 'delta_psnr': 0.5047, 'best_val_psnr': 23.6378}
# {'epoch': 65, 'epoch_time_sec': 42.42, 'lr': 9.99681559031237e-05, 'train_loss': 0.012157, 'train_psnr': 24.8362, 'val_psnr': 23.6412, 'input_psnr': 23.1331, 'delta_psnr': 0.5081, 'best_val_psnr': 23.6412}
# {'epoch': 66, 'epoch_time_sec': 42.37, 'lr': 9.996702889033607e-05, 'train_loss': 0.012162, 'train_psnr': 24.8335, 'val_psnr': 23.6446, 'input_psnr': 23.1331, 'delta_psnr': 0.5115, 'best_val_psnr': 23.6446}
# {'epoch': 67, 'epoch_time_sec': 42.15, 'lr': 9.996588228610642e-05, 'train_loss': 0.012175, 'train_psnr': 24.829, 'val_psnr': 23.648, 'input_psnr': 23.1331, 'delta_psnr': 0.515, 'best_val_psnr': 23.648}
# {'epoch': 68, 'epoch_time_sec': 42.37, 'lr': 9.996471609088878e-05, 'train_loss': 0.012142, 'train_psnr': 24.842, 'val_psnr': 23.6513, 'input_psnr': 23.1331, 'delta_psnr': 0.5183, 'best_val_psnr': 23.6513}
# {'epoch': 69, 'epoch_time_sec': 42.34, 'lr': 9.99635303051451e-05, 'train_loss': 0.012159, 'train_psnr': 24.836, 'val_psnr': 23.6546, 'input_psnr': 23.1331, 'delta_psnr': 0.5215, 'best_val_psnr': 23.6546}
# {'epoch': 70, 'epoch_time_sec': 42.39, 'lr': 9.996232492934498e-05, 'train_loss': 0.012138, 'train_psnr': 24.8473, 'val_psnr': 23.6578, 'input_psnr': 23.1331, 'delta_psnr': 0.5247, 'best_val_psnr': 23.6578}
# {'epoch': 71, 'epoch_time_sec': 42.32, 'lr': 9.996109996396579e-05, 'train_loss': 0.01213, 'train_psnr': 24.8504, 'val_psnr': 23.6608, 'input_psnr': 23.1331, 'delta_psnr': 0.5277, 'best_val_psnr': 23.6608}
# {'epoch': 72, 'epoch_time_sec': 42.22, 'lr': 9.995985540949269e-05, 'train_loss': 0.012127, 'train_psnr': 24.8512, 'val_psnr': 23.6639, 'input_psnr': 23.1331, 'delta_psnr': 0.5308, 'best_val_psnr': 23.6639}
# {'epoch': 73, 'epoch_time_sec': 42.47, 'lr': 9.995859126641862e-05, 'train_loss': 0.012127, 'train_psnr': 24.8493, 'val_psnr': 23.6668, 'input_psnr': 23.1331, 'delta_psnr': 0.5338, 'best_val_psnr': 23.6668}
# {'epoch': 74, 'epoch_time_sec': 42.43, 'lr': 9.99573075352442e-05, 'train_loss': 0.012134, 'train_psnr': 24.8498, 'val_psnr': 23.6696, 'input_psnr': 23.1331, 'delta_psnr': 0.5365, 'best_val_psnr': 23.6696}
# {'epoch': 75, 'epoch_time_sec': 42.78, 'lr': 9.995600421647788e-05, 'train_loss': 0.012126, 'train_psnr': 24.8554, 'val_psnr': 23.6722, 'input_psnr': 23.1331, 'delta_psnr': 0.5392, 'best_val_psnr': 23.6722}
# {'epoch': 76, 'epoch_time_sec': 42.64, 'lr': 9.995468131063581e-05, 'train_loss': 0.012114, 'train_psnr': 24.8564, 'val_psnr': 23.6747, 'input_psnr': 23.1331, 'delta_psnr': 0.5417, 'best_val_psnr': 23.6747}
# {'epoch': 77, 'epoch_time_sec': 42.27, 'lr': 9.995333881824197e-05, 'train_loss': 0.012106, 'train_psnr': 24.8616, 'val_psnr': 23.6772, 'input_psnr': 23.1331, 'delta_psnr': 0.5442, 'best_val_psnr': 23.6772}
# {'epoch': 78, 'epoch_time_sec': 42.32, 'lr': 9.995197673982803e-05, 'train_loss': 0.012116, 'train_psnr': 24.8577, 'val_psnr': 23.6796, 'input_psnr': 23.1331, 'delta_psnr': 0.5466, 'best_val_psnr': 23.6796}
# {'epoch': 79, 'epoch_time_sec': 42.28, 'lr': 9.995059507593343e-05, 'train_loss': 0.012103, 'train_psnr': 24.8646, 'val_psnr': 23.682, 'input_psnr': 23.1331, 'delta_psnr': 0.549, 'best_val_psnr': 23.682}
# {'epoch': 80, 'epoch_time_sec': 42.28, 'lr': 9.994919382710541e-05, 'train_loss': 0.012096, 'train_psnr': 24.8666, 'val_psnr': 23.6842, 'input_psnr': 23.1331, 'delta_psnr': 0.5511, 'best_val_psnr': 23.6842}
# {'epoch': 81, 'epoch_time_sec': 42.3, 'lr': 9.99477729938989e-05, 'train_loss': 0.012104, 'train_psnr': 24.8639, 'val_psnr': 23.6864, 'input_psnr': 23.1331, 'delta_psnr': 0.5534, 'best_val_psnr': 23.6864}
# {'epoch': 82, 'epoch_time_sec': 42.34, 'lr': 9.994633257687665e-05, 'train_loss': 0.012091, 'train_psnr': 24.8692, 'val_psnr': 23.6886, 'input_psnr': 23.1331, 'delta_psnr': 0.5555, 'best_val_psnr': 23.6886}
# {'epoch': 83, 'epoch_time_sec': 42.32, 'lr': 9.994487257660913e-05, 'train_loss': 0.0121, 'train_psnr': 24.8658, 'val_psnr': 23.6906, 'input_psnr': 23.1331, 'delta_psnr': 0.5576, 'best_val_psnr': 23.6906}
# {'epoch': 84, 'epoch_time_sec': 42.27, 'lr': 9.994339299367456e-05, 'train_loss': 0.012091, 'train_psnr': 24.8699, 'val_psnr': 23.6928, 'input_psnr': 23.1331, 'delta_psnr': 0.5598, 'best_val_psnr': 23.6928}
# {'epoch': 85, 'epoch_time_sec': 42.22, 'lr': 9.994189382865895e-05, 'train_loss': 0.012097, 'train_psnr': 24.8664, 'val_psnr': 23.6948, 'input_psnr': 23.1331, 'delta_psnr': 0.5617, 'best_val_psnr': 23.6948}
# {'epoch': 86, 'epoch_time_sec': 42.3, 'lr': 9.994037508215604e-05, 'train_loss': 0.012077, 'train_psnr': 24.8766, 'val_psnr': 23.6967, 'input_psnr': 23.1331, 'delta_psnr': 0.5637, 'best_val_psnr': 23.6967}
# {'epoch': 87, 'epoch_time_sec': 42.18, 'lr': 9.993883675476733e-05, 'train_loss': 0.012069, 'train_psnr': 24.881, 'val_psnr': 23.6987, 'input_psnr': 23.1331, 'delta_psnr': 0.5657, 'best_val_psnr': 23.6987}
# {'epoch': 88, 'epoch_time_sec': 42.33, 'lr': 9.993727884710205e-05, 'train_loss': 0.012084, 'train_psnr': 24.8729, 'val_psnr': 23.7005, 'input_psnr': 23.1331, 'delta_psnr': 0.5675, 'best_val_psnr': 23.7005}
# {'epoch': 89, 'epoch_time_sec': 42.46, 'lr': 9.993570135977725e-05, 'train_loss': 0.012061, 'train_psnr': 24.8843, 'val_psnr': 23.7024, 'input_psnr': 23.1331, 'delta_psnr': 0.5693, 'best_val_psnr': 23.7024}
# {'epoch': 90, 'epoch_time_sec': 42.29, 'lr': 9.993410429341767e-05, 'train_loss': 0.012087, 'train_psnr': 24.8747, 'val_psnr': 23.7044, 'input_psnr': 23.1331, 'delta_psnr': 0.5713, 'best_val_psnr': 23.7044}
# {'epoch': 91, 'epoch_time_sec': 42.25, 'lr': 9.993248764865584e-05, 'train_loss': 0.012068, 'train_psnr': 24.8822, 'val_psnr': 23.7061, 'input_psnr': 23.1331, 'delta_psnr': 0.5731, 'best_val_psnr': 23.7061}
# {'epoch': 92, 'epoch_time_sec': 42.22, 'lr': 9.993085142613203e-05, 'train_loss': 0.012074, 'train_psnr': 24.8799, 'val_psnr': 23.7079, 'input_psnr': 23.1331, 'delta_psnr': 0.5748, 'best_val_psnr': 23.7079}
# {'epoch': 93, 'epoch_time_sec': 42.31, 'lr': 9.992919562649426e-05, 'train_loss': 0.012063, 'train_psnr': 24.8839, 'val_psnr': 23.7096, 'input_psnr': 23.1331, 'delta_psnr': 0.5766, 'best_val_psnr': 23.7096}
# {'epoch': 94, 'epoch_time_sec': 42.26, 'lr': 9.992752025039832e-05, 'train_loss': 0.012065, 'train_psnr': 24.8843, 'val_psnr': 23.7113, 'input_psnr': 23.1331, 'delta_psnr': 0.5783, 'best_val_psnr': 23.7113}
# {'epoch': 95, 'epoch_time_sec': 42.31, 'lr': 9.992582529850773e-05, 'train_loss': 0.012047, 'train_psnr': 24.8926, 'val_psnr': 23.7131, 'input_psnr': 23.1331, 'delta_psnr': 0.58, 'best_val_psnr': 23.7131}
# {'epoch': 96, 'epoch_time_sec': 42.35, 'lr': 9.99241107714938e-05, 'train_loss': 0.012048, 'train_psnr': 24.8925, 'val_psnr': 23.7148, 'input_psnr': 23.1331, 'delta_psnr': 0.5817, 'best_val_psnr': 23.7148}
# {'epoch': 97, 'epoch_time_sec': 42.36, 'lr': 9.992237667003554e-05, 'train_loss': 0.012059, 'train_psnr': 24.8865, 'val_psnr': 23.7165, 'input_psnr': 23.1331, 'delta_psnr': 0.5834, 'best_val_psnr': 23.7165}
# {'epoch': 98, 'epoch_time_sec': 42.27, 'lr': 9.992062299481977e-05, 'train_loss': 0.012047, 'train_psnr': 24.8925, 'val_psnr': 23.7181, 'input_psnr': 23.1331, 'delta_psnr': 0.585, 'best_val_psnr': 23.7181}
# {'epoch': 99, 'epoch_time_sec': 42.33, 'lr': 9.991884974654101e-05, 'train_loss': 0.012054, 'train_psnr': 24.8915, 'val_psnr': 23.7197, 'input_psnr': 23.1331, 'delta_psnr': 0.5867, 'best_val_psnr': 23.7197}
# {'epoch': 100, 'epoch_time_sec': 42.54, 'lr': 9.991705692590157e-05, 'train_loss': 0.012062, 'train_psnr': 24.8874, 'val_psnr': 23.7214, 'input_psnr': 23.1331, 'delta_psnr': 0.5883, 'best_val_psnr': 23.7214}
# {'epoch': 101, 'epoch_time_sec': 42.69, 'lr': 9.991524453361151e-05, 'train_loss': 0.012048, 'train_psnr': 24.8958, 'val_psnr': 23.7229, 'input_psnr': 23.1331, 'delta_psnr': 0.5899, 'best_val_psnr': 23.7229}
# {'epoch': 102, 'epoch_time_sec': 42.61, 'lr': 9.99134125703886e-05, 'train_loss': 0.012036, 'train_psnr': 24.9005, 'val_psnr': 23.7245, 'input_psnr': 23.1331, 'delta_psnr': 0.5914, 'best_val_psnr': 23.7245}
# {'epoch': 103, 'epoch_time_sec': 42.24, 'lr': 9.991156103695841e-05, 'train_loss': 0.01203, 'train_psnr': 24.9022, 'val_psnr': 23.726, 'input_psnr': 23.1331, 'delta_psnr': 0.5929, 'best_val_psnr': 23.726}
# {'epoch': 104, 'epoch_time_sec': 42.24, 'lr': 9.990968993405422e-05, 'train_loss': 0.012038, 'train_psnr': 24.8996, 'val_psnr': 23.7274, 'input_psnr': 23.1331, 'delta_psnr': 0.5943, 'best_val_psnr': 23.7274}
# {'epoch': 105, 'epoch_time_sec': 42.26, 'lr': 9.99077992624171e-05, 'train_loss': 0.01203, 'train_psnr': 24.903, 'val_psnr': 23.7289, 'input_psnr': 23.1331, 'delta_psnr': 0.5959, 'best_val_psnr': 23.7289}
# {'epoch': 106, 'epoch_time_sec': 42.26, 'lr': 9.990588902279585e-05, 'train_loss': 0.012026, 'train_psnr': 24.9052, 'val_psnr': 23.7304, 'input_psnr': 23.1331, 'delta_psnr': 0.5973, 'best_val_psnr': 23.7304}
# {'epoch': 107, 'epoch_time_sec': 42.35, 'lr': 9.990395921594701e-05, 'train_loss': 0.012023, 'train_psnr': 24.9061, 'val_psnr': 23.7319, 'input_psnr': 23.1331, 'delta_psnr': 0.5988, 'best_val_psnr': 23.7319}
# {'epoch': 108, 'epoch_time_sec': 42.36, 'lr': 9.99020098426349e-05, 'train_loss': 0.012026, 'train_psnr': 24.9054, 'val_psnr': 23.7335, 'input_psnr': 23.1331, 'delta_psnr': 0.6004, 'best_val_psnr': 23.7335}
# {'epoch': 109, 'epoch_time_sec': 42.3, 'lr': 9.990004090363156e-05, 'train_loss': 0.012032, 'train_psnr': 24.9031, 'val_psnr': 23.7348, 'input_psnr': 23.1331, 'delta_psnr': 0.6017, 'best_val_psnr': 23.7348}
# {'epoch': 110, 'epoch_time_sec': 42.21, 'lr': 9.989805239971679e-05, 'train_loss': 0.012018, 'train_psnr': 24.9068, 'val_psnr': 23.7362, 'input_psnr': 23.1331, 'delta_psnr': 0.6032, 'best_val_psnr': 23.7362}
# {'epoch': 111, 'epoch_time_sec': 42.17, 'lr': 9.989604433167812e-05, 'train_loss': 0.012011, 'train_psnr': 24.9132, 'val_psnr': 23.7377, 'input_psnr': 23.1331, 'delta_psnr': 0.6046, 'best_val_psnr': 23.7377}
# {'epoch': 112, 'epoch_time_sec': 42.27, 'lr': 9.989401670031088e-05, 'train_loss': 0.012025, 'train_psnr': 24.9083, 'val_psnr': 23.7391, 'input_psnr': 23.1331, 'delta_psnr': 0.606, 'best_val_psnr': 23.7391}
# {'epoch': 113, 'epoch_time_sec': 42.22, 'lr': 9.98919695064181e-05, 'train_loss': 0.012012, 'train_psnr': 24.9132, 'val_psnr': 23.7405, 'input_psnr': 23.1331, 'delta_psnr': 0.6074, 'best_val_psnr': 23.7405}
# {'epoch': 114, 'epoch_time_sec': 42.36, 'lr': 9.988990275081055e-05, 'train_loss': 0.012009, 'train_psnr': 24.9135, 'val_psnr': 23.7418, 'input_psnr': 23.1331, 'delta_psnr': 0.6087, 'best_val_psnr': 23.7418}
# {'epoch': 115, 'epoch_time_sec': 42.2, 'lr': 9.98878164343068e-05, 'train_loss': 0.012013, 'train_psnr': 24.9122, 'val_psnr': 23.743, 'input_psnr': 23.1331, 'delta_psnr': 0.6099, 'best_val_psnr': 23.743}
# {'epoch': 116, 'epoch_time_sec': 42.23, 'lr': 9.988571055773313e-05, 'train_loss': 0.012011, 'train_psnr': 24.9117, 'val_psnr': 23.7442, 'input_psnr': 23.1331, 'delta_psnr': 0.6112, 'best_val_psnr': 23.7442}
# {'epoch': 117, 'epoch_time_sec': 42.26, 'lr': 9.988358512192356e-05, 'train_loss': 0.012006, 'train_psnr': 24.9163, 'val_psnr': 23.7455, 'input_psnr': 23.1331, 'delta_psnr': 0.6124, 'best_val_psnr': 23.7455}
# {'epoch': 118, 'epoch_time_sec': 42.29, 'lr': 9.988144012771989e-05, 'train_loss': 0.01201, 'train_psnr': 24.9144, 'val_psnr': 23.7467, 'input_psnr': 23.1331, 'delta_psnr': 0.6137, 'best_val_psnr': 23.7467}
# {'epoch': 119, 'epoch_time_sec': 42.23, 'lr': 9.987927557597163e-05, 'train_loss': 0.012021, 'train_psnr': 24.91, 'val_psnr': 23.7481, 'input_psnr': 23.1331, 'delta_psnr': 0.615, 'best_val_psnr': 23.7481}
# {'epoch': 120, 'epoch_time_sec': 42.3, 'lr': 9.987709146753605e-05, 'train_loss': 0.012018, 'train_psnr': 24.9097, 'val_psnr': 23.7492, 'input_psnr': 23.1331, 'delta_psnr': 0.6162, 'best_val_psnr': 23.7492}
# {'epoch': 121, 'epoch_time_sec': 42.29, 'lr': 9.987488780327819e-05, 'train_loss': 0.011993, 'train_psnr': 24.9218, 'val_psnr': 23.7504, 'input_psnr': 23.1331, 'delta_psnr': 0.6174, 'best_val_psnr': 23.7504}
# {'epoch': 122, 'epoch_time_sec': 42.33, 'lr': 9.987266458407078e-05, 'train_loss': 0.01199, 'train_psnr': 24.9243, 'val_psnr': 23.7517, 'input_psnr': 23.1331, 'delta_psnr': 0.6187, 'best_val_psnr': 23.7517}
# {'epoch': 123, 'epoch_time_sec': 42.33, 'lr': 9.987042181079436e-05, 'train_loss': 0.012001, 'train_psnr': 24.9189, 'val_psnr': 23.7529, 'input_psnr': 23.1331, 'delta_psnr': 0.6198, 'best_val_psnr': 23.7529}
# {'epoch': 124, 'epoch_time_sec': 42.44, 'lr': 9.986815948433715e-05, 'train_loss': 0.011989, 'train_psnr': 24.9247, 'val_psnr': 23.7541, 'input_psnr': 23.1331, 'delta_psnr': 0.621, 'best_val_psnr': 23.7541}
# {'epoch': 125, 'epoch_time_sec': 42.39, 'lr': 9.986587760559518e-05, 'train_loss': 0.011986, 'train_psnr': 24.9259, 'val_psnr': 23.7554, 'input_psnr': 23.1331, 'delta_psnr': 0.6223, 'best_val_psnr': 23.7554}
# {'epoch': 126, 'epoch_time_sec': 42.7, 'lr': 9.986357617547215e-05, 'train_loss': 0.011988, 'train_psnr': 24.9248, 'val_psnr': 23.7566, 'input_psnr': 23.1331, 'delta_psnr': 0.6235, 'best_val_psnr': 23.7566}
# {'epoch': 127, 'epoch_time_sec': 42.67, 'lr': 9.986125519487958e-05, 'train_loss': 0.011998, 'train_psnr': 24.92, 'val_psnr': 23.7577, 'input_psnr': 23.1331, 'delta_psnr': 0.6247, 'best_val_psnr': 23.7577}
# {'epoch': 128, 'epoch_time_sec': 42.29, 'lr': 9.985891466473667e-05, 'train_loss': 0.011989, 'train_psnr': 24.9248, 'val_psnr': 23.7589, 'input_psnr': 23.1331, 'delta_psnr': 0.6258, 'best_val_psnr': 23.7589}
# {'epoch': 129, 'epoch_time_sec': 42.21, 'lr': 9.985655458597038e-05, 'train_loss': 0.011985, 'train_psnr': 24.9294, 'val_psnr': 23.7603, 'input_psnr': 23.1331, 'delta_psnr': 0.6272, 'best_val_psnr': 23.7603}
# {'epoch': 130, 'epoch_time_sec': 42.26, 'lr': 9.985417495951546e-05, 'train_loss': 0.011983, 'train_psnr': 24.9274, 'val_psnr': 23.7613, 'input_psnr': 23.1331, 'delta_psnr': 0.6283, 'best_val_psnr': 23.7613}
# {'epoch': 131, 'epoch_time_sec': 42.28, 'lr': 9.985177578631434e-05, 'train_loss': 0.011981, 'train_psnr': 24.9311, 'val_psnr': 23.7626, 'input_psnr': 23.1331, 'delta_psnr': 0.6295, 'best_val_psnr': 23.7626}
# {'epoch': 132, 'epoch_time_sec': 42.32, 'lr': 9.98493570673172e-05, 'train_loss': 0.01197, 'train_psnr': 24.9339, 'val_psnr': 23.7637, 'input_psnr': 23.1331, 'delta_psnr': 0.6306, 'best_val_psnr': 23.7637}
# {'epoch': 133, 'epoch_time_sec': 42.27, 'lr': 9.984691880348199e-05, 'train_loss': 0.01197, 'train_psnr': 24.9352, 'val_psnr': 23.7649, 'input_psnr': 23.1331, 'delta_psnr': 0.6318, 'best_val_psnr': 23.7649}
# {'epoch': 134, 'epoch_time_sec': 42.26, 'lr': 9.984446099577439e-05, 'train_loss': 0.01198, 'train_psnr': 24.9323, 'val_psnr': 23.7659, 'input_psnr': 23.1331, 'delta_psnr': 0.6328, 'best_val_psnr': 23.7659}
# {'epoch': 135, 'epoch_time_sec': 42.24, 'lr': 9.984198364516781e-05, 'train_loss': 0.011963, 'train_psnr': 24.9381, 'val_psnr': 23.7671, 'input_psnr': 23.1331, 'delta_psnr': 0.634, 'best_val_psnr': 23.7671}
# {'epoch': 136, 'epoch_time_sec': 42.13, 'lr': 9.98394867526434e-05, 'train_loss': 0.01197, 'train_psnr': 24.9359, 'val_psnr': 23.7681, 'input_psnr': 23.1331, 'delta_psnr': 0.6351, 'best_val_psnr': 23.7681}
# {'epoch': 137, 'epoch_time_sec': 42.39, 'lr': 9.983697031919007e-05, 'train_loss': 0.01197, 'train_psnr': 24.936, 'val_psnr': 23.7693, 'input_psnr': 23.1331, 'delta_psnr': 0.6362, 'best_val_psnr': 23.7693}
# {'epoch': 138, 'epoch_time_sec': 42.24, 'lr': 9.983443434580443e-05, 'train_loss': 0.01198, 'train_psnr': 24.9323, 'val_psnr': 23.7703, 'input_psnr': 23.1331, 'delta_psnr': 0.6372, 'best_val_psnr': 23.7703}
# {'epoch': 139, 'epoch_time_sec': 42.38, 'lr': 9.983187883349088e-05, 'train_loss': 0.01197, 'train_psnr': 24.9366, 'val_psnr': 23.7714, 'input_psnr': 23.1331, 'delta_psnr': 0.6383, 'best_val_psnr': 23.7714}
# {'epoch': 140, 'epoch_time_sec': 42.26, 'lr': 9.982930378326152e-05, 'train_loss': 0.011968, 'train_psnr': 24.937, 'val_psnr': 23.7725, 'input_psnr': 23.1331, 'delta_psnr': 0.6395, 'best_val_psnr': 23.7725}
# {'epoch': 141, 'epoch_time_sec': 42.32, 'lr': 9.982670919613619e-05, 'train_loss': 0.011972, 'train_psnr': 24.937, 'val_psnr': 23.7736, 'input_psnr': 23.1331, 'delta_psnr': 0.6406, 'best_val_psnr': 23.7736}
# {'epoch': 142, 'epoch_time_sec': 42.25, 'lr': 9.98240950731425e-05, 'train_loss': 0.011961, 'train_psnr': 24.9404, 'val_psnr': 23.7748, 'input_psnr': 23.1331, 'delta_psnr': 0.6417, 'best_val_psnr': 23.7748}
# {'epoch': 143, 'epoch_time_sec': 42.36, 'lr': 9.982146141531578e-05, 'train_loss': 0.011955, 'train_psnr': 24.9429, 'val_psnr': 23.7759, 'input_psnr': 23.1331, 'delta_psnr': 0.6428, 'best_val_psnr': 23.7759}
# {'epoch': 144, 'epoch_time_sec': 42.35, 'lr': 9.981880822369905e-05, 'train_loss': 0.011961, 'train_psnr': 24.9415, 'val_psnr': 23.7768, 'input_psnr': 23.1331, 'delta_psnr': 0.6438, 'best_val_psnr': 23.7768}
# {'epoch': 145, 'epoch_time_sec': 42.23, 'lr': 9.981613549934314e-05, 'train_loss': 0.011954, 'train_psnr': 24.9436, 'val_psnr': 23.7779, 'input_psnr': 23.1331, 'delta_psnr': 0.6449, 'best_val_psnr': 23.7779}
# {'epoch': 146, 'epoch_time_sec': 42.28, 'lr': 9.981344324330658e-05, 'train_loss': 0.011958, 'train_psnr': 24.9405, 'val_psnr': 23.7789, 'input_psnr': 23.1331, 'delta_psnr': 0.6459, 'best_val_psnr': 23.7789}
# {'epoch': 147, 'epoch_time_sec': 42.24, 'lr': 9.981073145665564e-05, 'train_loss': 0.011954, 'train_psnr': 24.9436, 'val_psnr': 23.7799, 'input_psnr': 23.1331, 'delta_psnr': 0.6469, 'best_val_psnr': 23.7799}
# {'epoch': 148, 'epoch_time_sec': 42.27, 'lr': 9.98080001404643e-05, 'train_loss': 0.011953, 'train_psnr': 24.9455, 'val_psnr': 23.7809, 'input_psnr': 23.1331, 'delta_psnr': 0.6478, 'best_val_psnr': 23.7809}
# {'epoch': 149, 'epoch_time_sec': 42.35, 'lr': 9.980524929581434e-05, 'train_loss': 0.01195, 'train_psnr': 24.9464, 'val_psnr': 23.7819, 'input_psnr': 23.1331, 'delta_psnr': 0.6488, 'best_val_psnr': 23.7819}
# {'epoch': 150, 'epoch_time_sec': 42.44, 'lr': 9.980247892379521e-05, 'train_loss': 0.011942, 'train_psnr': 24.9493, 'val_psnr': 23.7828, 'input_psnr': 23.1331, 'delta_psnr': 0.6497, 'best_val_psnr': 23.7828}
# {'epoch': 151, 'epoch_time_sec': 42.49, 'lr': 9.979968902550412e-05, 'train_loss': 0.011946, 'train_psnr': 24.9466, 'val_psnr': 23.7837, 'input_psnr': 23.1331, 'delta_psnr': 0.6507, 'best_val_psnr': 23.7837}
# {'epoch': 152, 'epoch_time_sec': 42.81, 'lr': 9.9796879602046e-05, 'train_loss': 0.011949, 'train_psnr': 24.9458, 'val_psnr': 23.7847, 'input_psnr': 23.1331, 'delta_psnr': 0.6517, 'best_val_psnr': 23.7847}
# {'epoch': 153, 'epoch_time_sec': 42.48, 'lr': 9.979405065453355e-05, 'train_loss': 0.011955, 'train_psnr': 24.9461, 'val_psnr': 23.7857, 'input_psnr': 23.1331, 'delta_psnr': 0.6526, 'best_val_psnr': 23.7857}
# {'epoch': 154, 'epoch_time_sec': 42.23, 'lr': 9.979120218408716e-05, 'train_loss': 0.011935, 'train_psnr': 24.9549, 'val_psnr': 23.7867, 'input_psnr': 23.1331, 'delta_psnr': 0.6537, 'best_val_psnr': 23.7867}
# {'epoch': 155, 'epoch_time_sec': 42.29, 'lr': 9.978833419183496e-05, 'train_loss': 0.011946, 'train_psnr': 24.9509, 'val_psnr': 23.7877, 'input_psnr': 23.1331, 'delta_psnr': 0.6546, 'best_val_psnr': 23.7877}
# {'epoch': 156, 'epoch_time_sec': 42.24, 'lr': 9.978544667891283e-05, 'train_loss': 0.011945, 'train_psnr': 24.9491, 'val_psnr': 23.7885, 'input_psnr': 23.1331, 'delta_psnr': 0.6554, 'best_val_psnr': 23.7885}
# {'epoch': 157, 'epoch_time_sec': 42.25, 'lr': 9.978253964646437e-05, 'train_loss': 0.011935, 'train_psnr': 24.9528, 'val_psnr': 23.7894, 'input_psnr': 23.1331, 'delta_psnr': 0.6564, 'best_val_psnr': 23.7894}
# {'epoch': 158, 'epoch_time_sec': 42.3, 'lr': 9.977961309564093e-05, 'train_loss': 0.011956, 'train_psnr': 24.9454, 'val_psnr': 23.7903, 'input_psnr': 23.1331, 'delta_psnr': 0.6573, 'best_val_psnr': 23.7903}
# {'epoch': 159, 'epoch_time_sec': 42.21, 'lr': 9.977666702760153e-05, 'train_loss': 0.011928, 'train_psnr': 24.9585, 'val_psnr': 23.7913, 'input_psnr': 23.1331, 'delta_psnr': 0.6582, 'best_val_psnr': 23.7913}
# {'epoch': 160, 'epoch_time_sec': 42.33, 'lr': 9.977370144351298e-05, 'train_loss': 0.011934, 'train_psnr': 24.9569, 'val_psnr': 23.7924, 'input_psnr': 23.1331, 'delta_psnr': 0.6593, 'best_val_psnr': 23.7924}
# {'epoch': 161, 'epoch_time_sec': 42.23, 'lr': 9.977071634454983e-05, 'train_loss': 0.01193, 'train_psnr': 24.957, 'val_psnr': 23.7932, 'input_psnr': 23.1331, 'delta_psnr': 0.6601, 'best_val_psnr': 23.7932}
# {'epoch': 162, 'epoch_time_sec': 42.33, 'lr': 9.97677117318943e-05, 'train_loss': 0.011935, 'train_psnr': 24.9536, 'val_psnr': 23.7941, 'input_psnr': 23.1331, 'delta_psnr': 0.661, 'best_val_psnr': 23.7941}
# {'epoch': 163, 'epoch_time_sec': 42.17, 'lr': 9.976468760673636e-05, 'train_loss': 0.011952, 'train_psnr': 24.9478, 'val_psnr': 23.7949, 'input_psnr': 23.1331, 'delta_psnr': 0.6619, 'best_val_psnr': 23.7949}
# {'epoch': 164, 'epoch_time_sec': 42.36, 'lr': 9.976164397027375e-05, 'train_loss': 0.011921, 'train_psnr': 24.9633, 'val_psnr': 23.7958, 'input_psnr': 23.1331, 'delta_psnr': 0.6627, 'best_val_psnr': 23.7958}
# {'epoch': 165, 'epoch_time_sec': 42.39, 'lr': 9.975858082371187e-05, 'train_loss': 0.011925, 'train_psnr': 24.9583, 'val_psnr': 23.7967, 'input_psnr': 23.1331, 'delta_psnr': 0.6637, 'best_val_psnr': 23.7967}
# {'epoch': 166, 'epoch_time_sec': 42.37, 'lr': 9.97554981682639e-05, 'train_loss': 0.011925, 'train_psnr': 24.9617, 'val_psnr': 23.7978, 'input_psnr': 23.1331, 'delta_psnr': 0.6647, 'best_val_psnr': 23.7978}
# {'epoch': 167, 'epoch_time_sec': 42.21, 'lr': 9.975239600515073e-05, 'train_loss': 0.011932, 'train_psnr': 24.957, 'val_psnr': 23.7986, 'input_psnr': 23.1331, 'delta_psnr': 0.6656, 'best_val_psnr': 23.7986}
# {'epoch': 168, 'epoch_time_sec': 42.28, 'lr': 9.974927433560096e-05, 'train_loss': 0.011931, 'train_psnr': 24.9579, 'val_psnr': 23.7995, 'input_psnr': 23.1331, 'delta_psnr': 0.6664, 'best_val_psnr': 23.7995}
# {'epoch': 169, 'epoch_time_sec': 42.28, 'lr': 9.974613316085093e-05, 'train_loss': 0.011921, 'train_psnr': 24.9624, 'val_psnr': 23.8004, 'input_psnr': 23.1331, 'delta_psnr': 0.6673, 'best_val_psnr': 23.8004}
# {'epoch': 170, 'epoch_time_sec': 42.3, 'lr': 9.974297248214472e-05, 'train_loss': 0.01192, 'train_psnr': 24.9614, 'val_psnr': 23.8012, 'input_psnr': 23.1331, 'delta_psnr': 0.6682, 'best_val_psnr': 23.8012}
# {'epoch': 171, 'epoch_time_sec': 42.29, 'lr': 9.973979230073411e-05, 'train_loss': 0.011921, 'train_psnr': 24.9644, 'val_psnr': 23.8019, 'input_psnr': 23.1331, 'delta_psnr': 0.6689, 'best_val_psnr': 23.8019}
# {'epoch': 172, 'epoch_time_sec': 42.29, 'lr': 9.97365926178786e-05, 'train_loss': 0.011931, 'train_psnr': 24.9607, 'val_psnr': 23.8027, 'input_psnr': 23.1331, 'delta_psnr': 0.6697, 'best_val_psnr': 23.8027}
# {'epoch': 173, 'epoch_time_sec': 42.35, 'lr': 9.973337343484544e-05, 'train_loss': 0.011909, 'train_psnr': 24.9687, 'val_psnr': 23.8036, 'input_psnr': 23.1331, 'delta_psnr': 0.6705, 'best_val_psnr': 23.8036}
# {'epoch': 174, 'epoch_time_sec': 42.28, 'lr': 9.973013475290958e-05, 'train_loss': 0.011913, 'train_psnr': 24.9641, 'val_psnr': 23.8043, 'input_psnr': 23.1331, 'delta_psnr': 0.6713, 'best_val_psnr': 23.8043}
# {'epoch': 175, 'epoch_time_sec': 42.23, 'lr': 9.97268765733537e-05, 'train_loss': 0.011911, 'train_psnr': 24.9668, 'val_psnr': 23.8051, 'input_psnr': 23.1331, 'delta_psnr': 0.672, 'best_val_psnr': 23.8051}
# {'epoch': 176, 'epoch_time_sec': 42.42, 'lr': 9.972359889746822e-05, 'train_loss': 0.01191, 'train_psnr': 24.9678, 'val_psnr': 23.806, 'input_psnr': 23.1331, 'delta_psnr': 0.6729, 'best_val_psnr': 23.806}
# {'epoch': 177, 'epoch_time_sec': 42.7, 'lr': 9.972030172655126e-05, 'train_loss': 0.011928, 'train_psnr': 24.9612, 'val_psnr': 23.8068, 'input_psnr': 23.1331, 'delta_psnr': 0.6738, 'best_val_psnr': 23.8068}
# {'epoch': 178, 'epoch_time_sec': 42.78, 'lr': 9.971698506190864e-05, 'train_loss': 0.011915, 'train_psnr': 24.9658, 'val_psnr': 23.8076, 'input_psnr': 23.1331, 'delta_psnr': 0.6745, 'best_val_psnr': 23.8076}
# {'epoch': 179, 'epoch_time_sec': 42.33, 'lr': 9.971364890485396e-05, 'train_loss': 0.011909, 'train_psnr': 24.9689, 'val_psnr': 23.8083, 'input_psnr': 23.1331, 'delta_psnr': 0.6752, 'best_val_psnr': 23.8083}
# {'epoch': 180, 'epoch_time_sec': 42.34, 'lr': 9.97102932567085e-05, 'train_loss': 0.011906, 'train_psnr': 24.9714, 'val_psnr': 23.8092, 'input_psnr': 23.1331, 'delta_psnr': 0.6762, 'best_val_psnr': 23.8092}
# {'epoch': 181, 'epoch_time_sec': 42.2, 'lr': 9.970691811880125e-05, 'train_loss': 0.011898, 'train_psnr': 24.9762, 'val_psnr': 23.8099, 'input_psnr': 23.1331, 'delta_psnr': 0.6769, 'best_val_psnr': 23.8099}
# {'epoch': 182, 'epoch_time_sec': 42.3, 'lr': 9.970352349246897e-05, 'train_loss': 0.011902, 'train_psnr': 24.971, 'val_psnr': 23.8106, 'input_psnr': 23.1331, 'delta_psnr': 0.6775, 'best_val_psnr': 23.8106}
# {'epoch': 183, 'epoch_time_sec': 42.29, 'lr': 9.970010937905606e-05, 'train_loss': 0.011902, 'train_psnr': 24.9747, 'val_psnr': 23.8115, 'input_psnr': 23.1331, 'delta_psnr': 0.6784, 'best_val_psnr': 23.8115}
# {'epoch': 184, 'epoch_time_sec': 42.26, 'lr': 9.96966757799147e-05, 'train_loss': 0.011916, 'train_psnr': 24.9657, 'val_psnr': 23.8122, 'input_psnr': 23.1331, 'delta_psnr': 0.6791, 'best_val_psnr': 23.8122}
# {'epoch': 185, 'epoch_time_sec': 42.24, 'lr': 9.969322269640478e-05, 'train_loss': 0.011919, 'train_psnr': 24.9653, 'val_psnr': 23.8129, 'input_psnr': 23.1331, 'delta_psnr': 0.6798, 'best_val_psnr': 23.8129}
# {'epoch': 186, 'epoch_time_sec': 42.22, 'lr': 9.968975012989388e-05, 'train_loss': 0.011911, 'train_psnr': 24.969, 'val_psnr': 23.8136, 'input_psnr': 23.1331, 'delta_psnr': 0.6805, 'best_val_psnr': 23.8136}
# {'epoch': 187, 'epoch_time_sec': 42.33, 'lr': 9.968625808175732e-05, 'train_loss': 0.0119, 'train_psnr': 24.9727, 'val_psnr': 23.8143, 'input_psnr': 23.1331, 'delta_psnr': 0.6812, 'best_val_psnr': 23.8143}
# {'epoch': 188, 'epoch_time_sec': 42.28, 'lr': 9.968274655337812e-05, 'train_loss': 0.011901, 'train_psnr': 24.9729, 'val_psnr': 23.8151, 'input_psnr': 23.1331, 'delta_psnr': 0.682, 'best_val_psnr': 23.8151}
# {'epoch': 189, 'epoch_time_sec': 42.24, 'lr': 9.967921554614703e-05, 'train_loss': 0.011895, 'train_psnr': 24.976, 'val_psnr': 23.8158, 'input_psnr': 23.1331, 'delta_psnr': 0.6828, 'best_val_psnr': 23.8158}
# {'epoch': 190, 'epoch_time_sec': 42.2, 'lr': 9.96756650614625e-05, 'train_loss': 0.011895, 'train_psnr': 24.9769, 'val_psnr': 23.8166, 'input_psnr': 23.1331, 'delta_psnr': 0.6836, 'best_val_psnr': 23.8166}
# {'epoch': 191, 'epoch_time_sec': 42.24, 'lr': 9.967209510073071e-05, 'train_loss': 0.011903, 'train_psnr': 24.9731, 'val_psnr': 23.8174, 'input_psnr': 23.1331, 'delta_psnr': 0.6843, 'best_val_psnr': 23.8174}
# {'epoch': 192, 'epoch_time_sec': 42.25, 'lr': 9.966850566536553e-05, 'train_loss': 0.0119, 'train_psnr': 24.9753, 'val_psnr': 23.8181, 'input_psnr': 23.1331, 'delta_psnr': 0.685, 'best_val_psnr': 23.8181}
# {'epoch': 193, 'epoch_time_sec': 42.24, 'lr': 9.966489675678858e-05, 'train_loss': 0.011899, 'train_psnr': 24.9745, 'val_psnr': 23.8187, 'input_psnr': 23.1331, 'delta_psnr': 0.6857, 'best_val_psnr': 23.8187}
# {'epoch': 194, 'epoch_time_sec': 42.27, 'lr': 9.966126837642916e-05, 'train_loss': 0.011906, 'train_psnr': 24.9747, 'val_psnr': 23.8195, 'input_psnr': 23.1331, 'delta_psnr': 0.6864, 'best_val_psnr': 23.8195}
# {'epoch': 195, 'epoch_time_sec': 42.33, 'lr': 9.96576205257243e-05, 'train_loss': 0.011902, 'train_psnr': 24.9751, 'val_psnr': 23.8203, 'input_psnr': 23.1331, 'delta_psnr': 0.6872, 'best_val_psnr': 23.8203}
# {'epoch': 196, 'epoch_time_sec': 42.35, 'lr': 9.96539532061187e-05, 'train_loss': 0.011903, 'train_psnr': 24.9763, 'val_psnr': 23.821, 'input_psnr': 23.1331, 'delta_psnr': 0.688, 'best_val_psnr': 23.821}
# {'epoch': 197, 'epoch_time_sec': 42.37, 'lr': 9.965026641906482e-05, 'train_loss': 0.011921, 'train_psnr': 24.968, 'val_psnr': 23.8216, 'input_psnr': 23.1331, 'delta_psnr': 0.6886, 'best_val_psnr': 23.8216}
# {'epoch': 198, 'epoch_time_sec': 42.28, 'lr': 9.964656016602283e-05, 'train_loss': 0.011902, 'train_psnr': 24.9755, 'val_psnr': 23.8223, 'input_psnr': 23.1331, 'delta_psnr': 0.6893, 'best_val_psnr': 23.8223}
# {'epoch': 199, 'epoch_time_sec': 42.37, 'lr': 9.96428344484606e-05, 'train_loss': 0.011888, 'train_psnr': 24.9796, 'val_psnr': 23.823, 'input_psnr': 23.1331, 'delta_psnr': 0.6899, 'best_val_psnr': 23.823}
# {'epoch': 200, 'epoch_time_sec': 42.3, 'lr': 9.963908926785367e-05, 'train_loss': 0.011893, 'train_psnr': 24.9789, 'val_psnr': 23.8236, 'input_psnr': 23.1331, 'delta_psnr': 0.6906, 'best_val_psnr': 23.8236}
# {'epoch': 201, 'epoch_time_sec': 42.45, 'lr': 9.963532462568535e-05, 'train_loss': 0.011898, 'train_psnr': 24.976, 'val_psnr': 23.8243, 'input_psnr': 23.1331, 'delta_psnr': 0.6912, 'best_val_psnr': 23.8243}
# {'epoch': 202, 'epoch_time_sec': 42.49, 'lr': 9.963154052344661e-05, 'train_loss': 0.011887, 'train_psnr': 24.9821, 'val_psnr': 23.8248, 'input_psnr': 23.1331, 'delta_psnr': 0.6918, 'best_val_psnr': 23.8248}
# {'epoch': 203, 'epoch_time_sec': 42.81, 'lr': 9.962773696263615e-05, 'train_loss': 0.011885, 'train_psnr': 24.9834, 'val_psnr': 23.8254, 'input_psnr': 23.1331, 'delta_psnr': 0.6924, 'best_val_psnr': 23.8254}
# {'epoch': 204, 'epoch_time_sec': 42.39, 'lr': 9.962391394476037e-05, 'train_loss': 0.011884, 'train_psnr': 24.981, 'val_psnr': 23.826, 'input_psnr': 23.1331, 'delta_psnr': 0.693, 'best_val_psnr': 23.826}
# {'epoch': 205, 'epoch_time_sec': 42.32, 'lr': 9.962007147133338e-05, 'train_loss': 0.011872, 'train_psnr': 24.9897, 'val_psnr': 23.8268, 'input_psnr': 23.1331, 'delta_psnr': 0.6937, 'best_val_psnr': 23.8268}
# {'epoch': 206, 'epoch_time_sec': 42.3, 'lr': 9.961620954387702e-05, 'train_loss': 0.011874, 'train_psnr': 24.9887, 'val_psnr': 23.8275, 'input_psnr': 23.1331, 'delta_psnr': 0.6944, 'best_val_psnr': 23.8275}
# {'epoch': 207, 'epoch_time_sec': 42.24, 'lr': 9.961232816392074e-05, 'train_loss': 0.011889, 'train_psnr': 24.9813, 'val_psnr': 23.8283, 'input_psnr': 23.1331, 'delta_psnr': 0.6952, 'best_val_psnr': 23.8283}
# {'epoch': 208, 'epoch_time_sec': 42.25, 'lr': 9.960842733300186e-05, 'train_loss': 0.011872, 'train_psnr': 24.9886, 'val_psnr': 23.8288, 'input_psnr': 23.1331, 'delta_psnr': 0.6958, 'best_val_psnr': 23.8288}
# {'epoch': 209, 'epoch_time_sec': 42.17, 'lr': 9.960450705266521e-05, 'train_loss': 0.011874, 'train_psnr': 24.9879, 'val_psnr': 23.8295, 'input_psnr': 23.1331, 'delta_psnr': 0.6964, 'best_val_psnr': 23.8295}
# {'epoch': 210, 'epoch_time_sec': 42.29, 'lr': 9.960056732446346e-05, 'train_loss': 0.011871, 'train_psnr': 24.9907, 'val_psnr': 23.8301, 'input_psnr': 23.1331, 'delta_psnr': 0.6971, 'best_val_psnr': 23.8301}
# {'epoch': 211, 'epoch_time_sec': 42.27, 'lr': 9.959660814995696e-05, 'train_loss': 0.011877, 'train_psnr': 24.9875, 'val_psnr': 23.8308, 'input_psnr': 23.1331, 'delta_psnr': 0.6977, 'best_val_psnr': 23.8308}
# {'epoch': 212, 'epoch_time_sec': 42.11, 'lr': 9.959262953071374e-05, 'train_loss': 0.011884, 'train_psnr': 24.9815, 'val_psnr': 23.8314, 'input_psnr': 23.1331, 'delta_psnr': 0.6983, 'best_val_psnr': 23.8314}
# {'epoch': 213, 'epoch_time_sec': 42.22, 'lr': 9.958863146830948e-05, 'train_loss': 0.011863, 'train_psnr': 24.9954, 'val_psnr': 23.8318, 'input_psnr': 23.1331, 'delta_psnr': 0.6987, 'best_val_psnr': 23.8318}
# {'epoch': 214, 'epoch_time_sec': 42.28, 'lr': 9.958461396432768e-05, 'train_loss': 0.011888, 'train_psnr': 24.9841, 'val_psnr': 23.8324, 'input_psnr': 23.1331, 'delta_psnr': 0.6994, 'best_val_psnr': 23.8324}
# {'epoch': 215, 'epoch_time_sec': 42.27, 'lr': 9.958057702035945e-05, 'train_loss': 0.011876, 'train_psnr': 24.987, 'val_psnr': 23.833, 'input_psnr': 23.1331, 'delta_psnr': 0.6999, 'best_val_psnr': 23.833}
# {'epoch': 216, 'epoch_time_sec': 42.24, 'lr': 9.957652063800363e-05, 'train_loss': 0.011865, 'train_psnr': 24.995, 'val_psnr': 23.8337, 'input_psnr': 23.1331, 'delta_psnr': 0.7006, 'best_val_psnr': 23.8337}
# {'epoch': 217, 'epoch_time_sec': 42.27, 'lr': 9.957244481886672e-05, 'train_loss': 0.011874, 'train_psnr': 24.9898, 'val_psnr': 23.8342, 'input_psnr': 23.1331, 'delta_psnr': 0.7012, 'best_val_psnr': 23.8342}
# {'epoch': 218, 'epoch_time_sec': 42.26, 'lr': 9.9568349564563e-05, 'train_loss': 0.011877, 'train_psnr': 24.989, 'val_psnr': 23.8348, 'input_psnr': 23.1331, 'delta_psnr': 0.7018, 'best_val_psnr': 23.8348}
# {'epoch': 219, 'epoch_time_sec': 42.31, 'lr': 9.956423487671435e-05, 'train_loss': 0.011859, 'train_psnr': 24.9967, 'val_psnr': 23.8353, 'input_psnr': 23.1331, 'delta_psnr': 0.7022, 'best_val_psnr': 23.8353}
# {'epoch': 220, 'epoch_time_sec': 42.4, 'lr': 9.956010075695043e-05, 'train_loss': 0.011869, 'train_psnr': 24.9919, 'val_psnr': 23.8359, 'input_psnr': 23.1331, 'delta_psnr': 0.7028, 'best_val_psnr': 23.8359}
# {'epoch': 221, 'epoch_time_sec': 42.29, 'lr': 9.955594720690855e-05, 'train_loss': 0.011863, 'train_psnr': 24.9963, 'val_psnr': 23.8364, 'input_psnr': 23.1331, 'delta_psnr': 0.7033, 'best_val_psnr': 23.8364}
# {'epoch': 222, 'epoch_time_sec': 42.24, 'lr': 9.955177422823371e-05, 'train_loss': 0.011874, 'train_psnr': 24.9888, 'val_psnr': 23.8372, 'input_psnr': 23.1331, 'delta_psnr': 0.7041, 'best_val_psnr': 23.8372}
# {'epoch': 223, 'epoch_time_sec': 42.13, 'lr': 9.954758182257864e-05, 'train_loss': 0.011865, 'train_psnr': 24.9938, 'val_psnr': 23.8376, 'input_psnr': 23.1331, 'delta_psnr': 0.7046, 'best_val_psnr': 23.8376}
# {'epoch': 224, 'epoch_time_sec': 42.22, 'lr': 9.954336999160374e-05, 'train_loss': 0.011859, 'train_psnr': 24.996, 'val_psnr': 23.8383, 'input_psnr': 23.1331, 'delta_psnr': 0.7052, 'best_val_psnr': 23.8383}
# {'epoch': 225, 'epoch_time_sec': 42.47, 'lr': 9.95391387369771e-05, 'train_loss': 0.011865, 'train_psnr': 24.9935, 'val_psnr': 23.8388, 'input_psnr': 23.1331, 'delta_psnr': 0.7058, 'best_val_psnr': 23.8388}
# {'epoch': 226, 'epoch_time_sec': 42.42, 'lr': 9.953488806037453e-05, 'train_loss': 0.011858, 'train_psnr': 25.0018, 'val_psnr': 23.8395, 'input_psnr': 23.1331, 'delta_psnr': 0.7065, 'best_val_psnr': 23.8395}
# {'epoch': 227, 'epoch_time_sec': 42.68, 'lr': 9.953061796347949e-05, 'train_loss': 0.011873, 'train_psnr': 24.9923, 'val_psnr': 23.8401, 'input_psnr': 23.1331, 'delta_psnr': 0.707, 'best_val_psnr': 23.8401}
# {'epoch': 228, 'epoch_time_sec': 42.67, 'lr': 9.952632844798318e-05, 'train_loss': 0.011855, 'train_psnr': 24.9993, 'val_psnr': 23.8406, 'input_psnr': 23.1331, 'delta_psnr': 0.7076, 'best_val_psnr': 23.8406}
# {'epoch': 229, 'epoch_time_sec': 42.26, 'lr': 9.952201951558442e-05, 'train_loss': 0.011865, 'train_psnr': 24.9944, 'val_psnr': 23.8412, 'input_psnr': 23.1331, 'delta_psnr': 0.7081, 'best_val_psnr': 23.8412}
# {'epoch': 230, 'epoch_time_sec': 42.3, 'lr': 9.95176911679898e-05, 'train_loss': 0.011866, 'train_psnr': 24.9989, 'val_psnr': 23.8418, 'input_psnr': 23.1331, 'delta_psnr': 0.7087, 'best_val_psnr': 23.8418}
# {'epoch': 231, 'epoch_time_sec': 42.21, 'lr': 9.951334340691355e-05, 'train_loss': 0.011855, 'train_psnr': 24.9979, 'val_psnr': 23.8422, 'input_psnr': 23.1331, 'delta_psnr': 0.7092, 'best_val_psnr': 23.8422}
# {'epoch': 232, 'epoch_time_sec': 42.18, 'lr': 9.950897623407762e-05, 'train_loss': 0.011848, 'train_psnr': 25.0036, 'val_psnr': 23.8428, 'input_psnr': 23.1331, 'delta_psnr': 0.7098, 'best_val_psnr': 23.8428}
# ...
# {'epoch': 680, 'epoch_time_sec': 42.24, 'lr': 9.563904237660847e-05, 'train_loss': 0.011684, 'train_psnr': 25.1005, 'val_psnr': 23.9597, 'input_psnr': 23.1331, 'delta_psnr': 0.8266, 'best_val_psnr': 23.9597}
# {'epoch': 681, 'epoch_time_sec': 42.2, 'lr': 9.56262484191906e-05, 'train_loss': 0.011676, 'train_psnr': 25.1054, 'val_psnr': 23.9598, 'input_psnr': 23.1331, 'delta_psnr': 0.8267, 'best_val_psnr': 23.9598}
# {'epoch': 682, 'epoch_time_sec': 42.19, 'lr': 9.561343658949902e-05, 'train_loss': 0.011662, 'train_psnr': 25.1124, 'val_psnr': 23.96, 'input_psnr': 23.1331, 'delta_psnr': 0.827, 'best_val_psnr': 23.96}
# {'epoch': 683, 'epoch_time_sec': 42.15, 'lr': 9.56006068926078e-05, 'train_loss': 0.011684, 'train_psnr': 25.1031, 'val_psnr': 23.9601, 'input_psnr': 23.1331, 'delta_psnr': 0.8271, 'best_val_psnr': 23.9601}
# {'epoch': 684, 'epoch_time_sec': 42.18, 'lr': 9.55877593335982e-05, 'train_loss': 0.011694, 'train_psnr': 25.0991, 'val_psnr': 23.9603, 'input_psnr': 23.1331, 'delta_psnr': 0.8272, 'best_val_psnr': 23.9603}
# {'epoch': 685, 'epoch_time_sec': 42.25, 'lr': 9.55748939175585e-05, 'train_loss': 0.011668, 'train_psnr': 25.1081, 'val_psnr': 23.9605, 'input_psnr': 23.1331, 'delta_psnr': 0.8274, 'best_val_psnr': 23.9605}
# {'epoch': 686, 'epoch_time_sec': 42.23, 'lr': 9.556201064958403e-05, 'train_loss': 0.011684, 'train_psnr': 25.101, 'val_psnr': 23.9606, 'input_psnr': 23.1331, 'delta_psnr': 0.8275, 'best_val_psnr': 23.9606}
# {'epoch': 687, 'epoch_time_sec': 42.14, 'lr': 9.554910953477723e-05, 'train_loss': 0.011671, 'train_psnr': 25.1075, 'val_psnr': 23.9607, 'input_psnr': 23.1331, 'delta_psnr': 0.8277, 'best_val_psnr': 23.9607}
# {'epoch': 688, 'epoch_time_sec': 42.27, 'lr': 9.553619057824759e-05, 'train_loss': 0.011675, 'train_psnr': 25.1058, 'val_psnr': 23.9609, 'input_psnr': 23.1331, 'delta_psnr': 0.8278, 'best_val_psnr': 23.9609}
# {'epoch': 689, 'epoch_time_sec': 42.28, 'lr': 9.552325378511166e-05, 'train_loss': 0.011698, 'train_psnr': 25.0936, 'val_psnr': 23.961, 'input_psnr': 23.1331, 'delta_psnr': 0.828, 'best_val_psnr': 23.961}
# {'epoch': 690, 'epoch_time_sec': 42.32, 'lr': 9.551029916049309e-05, 'train_loss': 0.011666, 'train_psnr': 25.11, 'val_psnr': 23.961, 'input_psnr': 23.1331, 'delta_psnr': 0.828, 'best_val_psnr': 23.961}
# {'epoch': 691, 'epoch_time_sec': 42.28, 'lr': 9.549732670952254e-05, 'train_loss': 0.011678, 'train_psnr': 25.1032, 'val_psnr': 23.9612, 'input_psnr': 23.1331, 'delta_psnr': 0.8281, 'best_val_psnr': 23.9612}
# {'epoch': 692, 'epoch_time_sec': 42.41, 'lr': 9.548433643733774e-05, 'train_loss': 0.01167, 'train_psnr': 25.1095, 'val_psnr': 23.9613, 'input_psnr': 23.1331, 'delta_psnr': 0.8283, 'best_val_psnr': 23.9613}
# {'epoch': 693, 'epoch_time_sec': 42.66, 'lr': 9.547132834908355e-05, 'train_loss': 0.011669, 'train_psnr': 25.1125, 'val_psnr': 23.9614, 'input_psnr': 23.1331, 'delta_psnr': 0.8283, 'best_val_psnr': 23.9614}
# {'epoch': 694, 'epoch_time_sec': 42.94, 'lr': 9.545830244991179e-05, 'train_loss': 0.01167, 'train_psnr': 25.1083, 'val_psnr': 23.9615, 'input_psnr': 23.1331, 'delta_psnr': 0.8284, 'best_val_psnr': 23.9615}
# {'epoch': 695, 'epoch_time_sec': 42.36, 'lr': 9.544525874498138e-05, 'train_loss': 0.011676, 'train_psnr': 25.1074, 'val_psnr': 23.9617, 'input_psnr': 23.1331, 'delta_psnr': 0.8286, 'best_val_psnr': 23.9617}
# {'epoch': 696, 'epoch_time_sec': 42.18, 'lr': 9.543219723945829e-05, 'train_loss': 0.011688, 'train_psnr': 25.1035, 'val_psnr': 23.9619, 'input_psnr': 23.1331, 'delta_psnr': 0.8289, 'best_val_psnr': 23.9619}
# {'epoch': 697, 'epoch_time_sec': 42.24, 'lr': 9.541911793851552e-05, 'train_loss': 0.011672, 'train_psnr': 25.1059, 'val_psnr': 23.962, 'input_psnr': 23.1331, 'delta_psnr': 0.8289, 'best_val_psnr': 23.962}
# {'epoch': 698, 'epoch_time_sec': 42.2, 'lr': 9.540602084733317e-05, 'train_loss': 0.011667, 'train_psnr': 25.1088, 'val_psnr': 23.9621, 'input_psnr': 23.1331, 'delta_psnr': 0.8291, 'best_val_psnr': 23.9621}
# {'epoch': 699, 'epoch_time_sec': 42.25, 'lr': 9.539290597109832e-05, 'train_loss': 0.011673, 'train_psnr': 25.1055, 'val_psnr': 23.962, 'input_psnr': 23.1331, 'delta_psnr': 0.829, 'best_val_psnr': 23.9621}
# {'epoch': 700, 'epoch_time_sec': 42.1, 'lr': 9.537977331500511e-05, 'train_loss': 0.011664, 'train_psnr': 25.1109, 'val_psnr': 23.9624, 'input_psnr': 23.1331, 'delta_psnr': 0.8293, 'best_val_psnr': 23.9624}
# {'epoch': 701, 'epoch_time_sec': 42.29, 'lr': 9.536662288425478e-05, 'train_loss': 0.011678, 'train_psnr': 25.1045, 'val_psnr': 23.9625, 'input_psnr': 23.1331, 'delta_psnr': 0.8294, 'best_val_psnr': 23.9625}
# {'epoch': 702, 'epoch_time_sec': 42.25, 'lr': 9.535345468405552e-05, 'train_loss': 0.011683, 'train_psnr': 25.1052, 'val_psnr': 23.9627, 'input_psnr': 23.1331, 'delta_psnr': 0.8297, 'best_val_psnr': 23.9627}
# {'epoch': 703, 'epoch_time_sec': 42.11, 'lr': 9.534026871962265e-05, 'train_loss': 0.011673, 'train_psnr': 25.1049, 'val_psnr': 23.9629, 'input_psnr': 23.1331, 'delta_psnr': 0.8299, 'best_val_psnr': 23.9629}
# {'epoch': 704, 'epoch_time_sec': 42.09, 'lr': 9.532706499617843e-05, 'train_loss': 0.011691, 'train_psnr': 25.1051, 'val_psnr': 23.9633, 'input_psnr': 23.1331, 'delta_psnr': 0.8302, 'best_val_psnr': 23.9633}
# {'epoch': 705, 'epoch_time_sec': 42.16, 'lr': 9.531384351895224e-05, 'train_loss': 0.011671, 'train_psnr': 25.1083, 'val_psnr': 23.9633, 'input_psnr': 23.1331, 'delta_psnr': 0.8302, 'best_val_psnr': 23.9633}
# {'epoch': 706, 'epoch_time_sec': 42.29, 'lr': 9.530060429318042e-05, 'train_loss': 0.011672, 'train_psnr': 25.1066, 'val_psnr': 23.9634, 'input_psnr': 23.1331, 'delta_psnr': 0.8304, 'best_val_psnr': 23.9634}
# {'epoch': 707, 'epoch_time_sec': 42.22, 'lr': 9.52873473241064e-05, 'train_loss': 0.011685, 'train_psnr': 25.1028, 'val_psnr': 23.9636, 'input_psnr': 23.1331, 'delta_psnr': 0.8306, 'best_val_psnr': 23.9636}
# {'epoch': 708, 'epoch_time_sec': 42.13, 'lr': 9.527407261698058e-05, 'train_loss': 0.011668, 'train_psnr': 25.1088, 'val_psnr': 23.9636, 'input_psnr': 23.1331, 'delta_psnr': 0.8305, 'best_val_psnr': 23.9636}
# {'epoch': 709, 'epoch_time_sec': 42.21, 'lr': 9.526078017706044e-05, 'train_loss': 0.011667, 'train_psnr': 25.1121, 'val_psnr': 23.9638, 'input_psnr': 23.1331, 'delta_psnr': 0.8307, 'best_val_psnr': 23.9638}
# {'epoch': 710, 'epoch_time_sec': 42.22, 'lr': 9.524747000961046e-05, 'train_loss': 0.011684, 'train_psnr': 25.1048, 'val_psnr': 23.9639, 'input_psnr': 23.1331, 'delta_psnr': 0.8308, 'best_val_psnr': 23.9639}
# {'epoch': 711, 'epoch_time_sec': 42.22, 'lr': 9.52341421199021e-05, 'train_loss': 0.011661, 'train_psnr': 25.1134, 'val_psnr': 23.9639, 'input_psnr': 23.1331, 'delta_psnr': 0.8308, 'best_val_psnr': 23.9639}
# {'epoch': 712, 'epoch_time_sec': 42.23, 'lr': 9.522079651321392e-05, 'train_loss': 0.011678, 'train_psnr': 25.1052, 'val_psnr': 23.9641, 'input_psnr': 23.1331, 'delta_psnr': 0.831, 'best_val_psnr': 23.9641}
# {'epoch': 713, 'epoch_time_sec': 42.5, 'lr': 9.520743319483144e-05, 'train_loss': 0.011678, 'train_psnr': 25.104, 'val_psnr': 23.9641, 'input_psnr': 23.1331, 'delta_psnr': 0.8311, 'best_val_psnr': 23.9641}
# {'epoch': 714, 'epoch_time_sec': 42.79, 'lr': 9.519405217004721e-05, 'train_loss': 0.011675, 'train_psnr': 25.1053, 'val_psnr': 23.9643, 'input_psnr': 23.1331, 'delta_psnr': 0.8313, 'best_val_psnr': 23.9643}
# {'epoch': 715, 'epoch_time_sec': 42.4, 'lr': 9.51806534441608e-05, 'train_loss': 0.011674, 'train_psnr': 25.1053, 'val_psnr': 23.9643, 'input_psnr': 23.1331, 'delta_psnr': 0.8312, 'best_val_psnr': 23.9643}
# {'epoch': 716, 'epoch_time_sec': 42.19, 'lr': 9.516723702247876e-05, 'train_loss': 0.011673, 'train_psnr': 25.1062, 'val_psnr': 23.9645, 'input_psnr': 23.1331, 'delta_psnr': 0.8314, 'best_val_psnr': 23.9645}
# {'epoch': 717, 'epoch_time_sec': 42.19, 'lr': 9.515380291031469e-05, 'train_loss': 0.011661, 'train_psnr': 25.1131, 'val_psnr': 23.9646, 'input_psnr': 23.1331, 'delta_psnr': 0.8315, 'best_val_psnr': 23.9646}
# {'epoch': 718, 'epoch_time_sec': 42.15, 'lr': 9.514035111298916e-05, 'train_loss': 0.011674, 'train_psnr': 25.1051, 'val_psnr': 23.9647, 'input_psnr': 23.1331, 'delta_psnr': 0.8316, 'best_val_psnr': 23.9647}
# {'epoch': 719, 'epoch_time_sec': 42.29, 'lr': 9.512688163582977e-05, 'train_loss': 0.011664, 'train_psnr': 25.112, 'val_psnr': 23.9648, 'input_psnr': 23.1331, 'delta_psnr': 0.8317, 'best_val_psnr': 23.9648}
# {'epoch': 720, 'epoch_time_sec': 42.3, 'lr': 9.511339448417113e-05, 'train_loss': 0.011658, 'train_psnr': 25.1162, 'val_psnr': 23.9649, 'input_psnr': 23.1331, 'delta_psnr': 0.8319, 'best_val_psnr': 23.9649}
# {'epoch': 721, 'epoch_time_sec': 42.3, 'lr': 9.50998896633548e-05, 'train_loss': 0.011663, 'train_psnr': 25.1133, 'val_psnr': 23.9651, 'input_psnr': 23.1331, 'delta_psnr': 0.832, 'best_val_psnr': 23.9651}
# {'epoch': 722, 'epoch_time_sec': 42.23, 'lr': 9.508636717872939e-05, 'train_loss': 0.01168, 'train_psnr': 25.1038, 'val_psnr': 23.9651, 'input_psnr': 23.1331, 'delta_psnr': 0.832, 'best_val_psnr': 23.9651}
# {'epoch': 723, 'epoch_time_sec': 42.14, 'lr': 9.507282703565051e-05, 'train_loss': 0.01167, 'train_psnr': 25.1083, 'val_psnr': 23.9651, 'input_psnr': 23.1331, 'delta_psnr': 0.832, 'best_val_psnr': 23.9651}
# {'epoch': 724, 'epoch_time_sec': 42.2, 'lr': 9.505926923948068e-05, 'train_loss': 0.01166, 'train_psnr': 25.1134, 'val_psnr': 23.9653, 'input_psnr': 23.1331, 'delta_psnr': 0.8322, 'best_val_psnr': 23.9653}
# {'epoch': 725, 'epoch_time_sec': 42.16, 'lr': 9.504569379558954e-05, 'train_loss': 0.011669, 'train_psnr': 25.107, 'val_psnr': 23.9654, 'input_psnr': 23.1331, 'delta_psnr': 0.8324, 'best_val_psnr': 23.9654}
# {'epoch': 726, 'epoch_time_sec': 42.11, 'lr': 9.503210070935361e-05, 'train_loss': 0.011664, 'train_psnr': 25.1119, 'val_psnr': 23.9656, 'input_psnr': 23.1331, 'delta_psnr': 0.8326, 'best_val_psnr': 23.9656}
# {'epoch': 727, 'epoch_time_sec': 42.16, 'lr': 9.501848998615646e-05, 'train_loss': 0.01166, 'train_psnr': 25.1132, 'val_psnr': 23.9659, 'input_psnr': 23.1331, 'delta_psnr': 0.8328, 'best_val_psnr': 23.9659}
# {'epoch': 728, 'epoch_time_sec': 42.26, 'lr': 9.500486163138858e-05, 'train_loss': 0.011672, 'train_psnr': 25.1062, 'val_psnr': 23.9661, 'input_psnr': 23.1331, 'delta_psnr': 0.833, 'best_val_psnr': 23.9661}
# {'epoch': 729, 'epoch_time_sec': 42.2, 'lr': 9.499121565044756e-05, 'train_loss': 0.011661, 'train_psnr': 25.1129, 'val_psnr': 23.9661, 'input_psnr': 23.1331, 'delta_psnr': 0.8331, 'best_val_psnr': 23.9661}
# {'epoch': 730, 'epoch_time_sec': 42.23, 'lr': 9.497755204873783e-05, 'train_loss': 0.011661, 'train_psnr': 25.1124, 'val_psnr': 23.9664, 'input_psnr': 23.1331, 'delta_psnr': 0.8333, 'best_val_psnr': 23.9664}
# {'epoch': 731, 'epoch_time_sec': 42.14, 'lr': 9.49638708316709e-05, 'train_loss': 0.011665, 'train_psnr': 25.1113, 'val_psnr': 23.9664, 'input_psnr': 23.1331, 'delta_psnr': 0.8333, 'best_val_psnr': 23.9664}
# {'epoch': 732, 'epoch_time_sec': 42.15, 'lr': 9.495017200466522e-05, 'train_loss': 0.011674, 'train_psnr': 25.1085, 'val_psnr': 23.9663, 'input_psnr': 23.1331, 'delta_psnr': 0.8332, 'best_val_psnr': 23.9664}
# {'epoch': 733, 'epoch_time_sec': 42.44, 'lr': 9.493645557314621e-05, 'train_loss': 0.011666, 'train_psnr': 25.1115, 'val_psnr': 23.9665, 'input_psnr': 23.1331, 'delta_psnr': 0.8334, 'best_val_psnr': 23.9665}
# {'epoch': 734, 'epoch_time_sec': 42.64, 'lr': 9.492272154254628e-05, 'train_loss': 0.011682, 'train_psnr': 25.1024, 'val_psnr': 23.9666, 'input_psnr': 23.1331, 'delta_psnr': 0.8335, 'best_val_psnr': 23.9666}
# {'epoch': 735, 'epoch_time_sec': 42.69, 'lr': 9.490896991830479e-05, 'train_loss': 0.01167, 'train_psnr': 25.1092, 'val_psnr': 23.9667, 'input_psnr': 23.1331, 'delta_psnr': 0.8336, 'best_val_psnr': 23.9667}
# {'epoch': 736, 'epoch_time_sec': 42.36, 'lr': 9.489520070586807e-05, 'train_loss': 0.011665, 'train_psnr': 25.1121, 'val_psnr': 23.9668, 'input_psnr': 23.1331, 'delta_psnr': 0.8337, 'best_val_psnr': 23.9668}
# {'epoch': 737, 'epoch_time_sec': 42.12, 'lr': 9.488141391068946e-05, 'train_loss': 0.011671, 'train_psnr': 25.1086, 'val_psnr': 23.9669, 'input_psnr': 23.1331, 'delta_psnr': 0.8339, 'best_val_psnr': 23.9669}
# {'epoch': 738, 'epoch_time_sec': 42.22, 'lr': 9.486760953822919e-05, 'train_loss': 0.011669, 'train_psnr': 25.1117, 'val_psnr': 23.9672, 'input_psnr': 23.1331, 'delta_psnr': 0.8341, 'best_val_psnr': 23.9672}
# {'epoch': 739, 'epoch_time_sec': 42.19, 'lr': 9.48537875939545e-05, 'train_loss': 0.011662, 'train_psnr': 25.1112, 'val_psnr': 23.9671, 'input_psnr': 23.1331, 'delta_psnr': 0.8341, 'best_val_psnr': 23.9672}
# {'epoch': 740, 'epoch_time_sec': 42.17, 'lr': 9.483994808333957e-05, 'train_loss': 0.011666, 'train_psnr': 25.1092, 'val_psnr': 23.9673, 'input_psnr': 23.1331, 'delta_psnr': 0.8342, 'best_val_psnr': 23.9673}
# {'epoch': 741, 'epoch_time_sec': 42.22, 'lr': 9.482609101186557e-05, 'train_loss': 0.011673, 'train_psnr': 25.1089, 'val_psnr': 23.9673, 'input_psnr': 23.1331, 'delta_psnr': 0.8343, 'best_val_psnr': 23.9673}
# {'epoch': 742, 'epoch_time_sec': 42.14, 'lr': 9.481221638502056e-05, 'train_loss': 0.011661, 'train_psnr': 25.1135, 'val_psnr': 23.9676, 'input_psnr': 23.1331, 'delta_psnr': 0.8345, 'best_val_psnr': 23.9676}
# {'epoch': 743, 'epoch_time_sec': 42.15, 'lr': 9.479832420829965e-05, 'train_loss': 0.01166, 'train_psnr': 25.1136, 'val_psnr': 23.9678, 'input_psnr': 23.1331, 'delta_psnr': 0.8347, 'best_val_psnr': 23.9678}
# {'epoch': 744, 'epoch_time_sec': 42.12, 'lr': 9.47844144872048e-05, 'train_loss': 0.011657, 'train_psnr': 25.1159, 'val_psnr': 23.9678, 'input_psnr': 23.1331, 'delta_psnr': 0.8348, 'best_val_psnr': 23.9678}
# {'epoch': 745, 'epoch_time_sec': 42.29, 'lr': 9.477048722724498e-05, 'train_loss': 0.011673, 'train_psnr': 25.1066, 'val_psnr': 23.968, 'input_psnr': 23.1331, 'delta_psnr': 0.8349, 'best_val_psnr': 23.968}
# {'epoch': 746, 'epoch_time_sec': 42.29, 'lr': 9.475654243393606e-05, 'train_loss': 0.01165, 'train_psnr': 25.1188, 'val_psnr': 23.9681, 'input_psnr': 23.1331, 'delta_psnr': 0.835, 'best_val_psnr': 23.9681}
# {'epoch': 747, 'epoch_time_sec': 42.11, 'lr': 9.474258011280093e-05, 'train_loss': 0.011656, 'train_psnr': 25.1146, 'val_psnr': 23.9681, 'input_psnr': 23.1331, 'delta_psnr': 0.835, 'best_val_psnr': 23.9681}
# {'epoch': 748, 'epoch_time_sec': 42.29, 'lr': 9.472860026936933e-05, 'train_loss': 0.011654, 'train_psnr': 25.1177, 'val_psnr': 23.9683, 'input_psnr': 23.1331, 'delta_psnr': 0.8353, 'best_val_psnr': 23.9683}
# {'epoch': 749, 'epoch_time_sec': 42.14, 'lr': 9.4714602909178e-05, 'train_loss': 0.011659, 'train_psnr': 25.1154, 'val_psnr': 23.9686, 'input_psnr': 23.1331, 'delta_psnr': 0.8355, 'best_val_psnr': 23.9686}
# {'epoch': 750, 'epoch_time_sec': 42.23, 'lr': 9.470058803777063e-05, 'train_loss': 0.011674, 'train_psnr': 25.1081, 'val_psnr': 23.9686, 'input_psnr': 23.1331, 'delta_psnr': 0.8355, 'best_val_psnr': 23.9686}
# {'epoch': 751, 'epoch_time_sec': 42.27, 'lr': 9.468655566069779e-05, 'train_loss': 0.011681, 'train_psnr': 25.1043, 'val_psnr': 23.9687, 'input_psnr': 23.1331, 'delta_psnr': 0.8357, 'best_val_psnr': 23.9687}
# {'epoch': 752, 'epoch_time_sec': 42.15, 'lr': 9.467250578351699e-05, 'train_loss': 0.011666, 'train_psnr': 25.11, 'val_psnr': 23.9687, 'input_psnr': 23.1331, 'delta_psnr': 0.8357, 'best_val_psnr': 23.9687}
# {'epoch': 753, 'epoch_time_sec': 42.29, 'lr': 9.465843841179272e-05, 'train_loss': 0.01168, 'train_psnr': 25.1064, 'val_psnr': 23.9689, 'input_psnr': 23.1331, 'delta_psnr': 0.8358, 'best_val_psnr': 23.9689}
# {'epoch': 754, 'epoch_time_sec': 42.44, 'lr': 9.464435355109636e-05, 'train_loss': 0.011653, 'train_psnr': 25.1174, 'val_psnr': 23.9689, 'input_psnr': 23.1331, 'delta_psnr': 0.8358, 'best_val_psnr': 23.9689}
# {'epoch': 755, 'epoch_time_sec': 42.71, 'lr': 9.463025120700624e-05, 'train_loss': 0.011665, 'train_psnr': 25.113, 'val_psnr': 23.9691, 'input_psnr': 23.1331, 'delta_psnr': 0.8361, 'best_val_psnr': 23.9691}
# {'epoch': 756, 'epoch_time_sec': 42.88, 'lr': 9.461613138510758e-05, 'train_loss': 0.011665, 'train_psnr': 25.1123, 'val_psnr': 23.9692, 'input_psnr': 23.1331, 'delta_psnr': 0.8362, 'best_val_psnr': 23.9692}

# %% [markdown]
# ## 6. Validation Summary
#
# Load the best checkpoint, compute validation PSNR against the raw LR baseline, and write preview images.

# %%
export_model = load_checkpoint_for_eval(best_ckpt_path, device)
validation_summary = evaluate_metrics(export_model, val_loader, device)
preview_info = write_val_preview(export_model, val_loader, preview_dir, device)
print({'validation_summary': validation_summary, 'best_checkpoint_path': str(best_ckpt_path), 'last_checkpoint_path': str(last_ckpt_path), 'preview': preview_info})

# %% [markdown]
# ## 7. Export And Submission Artifacts
#
# Export ONNX, run ONNX checker and ONNX Runtime parity, export training-derived calibration images, generate an MXQ handoff script, and write a final summary.

# %%
def export_calibration_images(pairs: list[tuple[Path, Path, str]], out_dir: Path, count: int, eval_size: int) -> dict[str, Any]:
    out_dir.mkdir(parents=True, exist_ok=True)
    selected = pairs[: min(count, len(pairs))]
    manifest_items: list[dict[str, Any]] = []
    for index, (lr_path, _, name) in enumerate(selected):
        image = Image.open(lr_path).convert('RGB')
        if image.size != (eval_size, eval_size):
            image = image.resize((eval_size, eval_size), BICUBIC_RESAMPLE)
        image_path = out_dir / f'{index:03d}_{Path(name).name}.png'
        image.save(image_path)
        manifest_items.append({'index': index, 'name': name, 'source_lr': str(lr_path), 'image_path': str(image_path), 'derived_from_training': True})
    manifest = {'count': len(manifest_items), 'source': 'training_pairs', 'eval_size': eval_size, 'derived_from_training': True, 'items': manifest_items}
    manifest_path = out_dir / 'manifest.json'
    write_json(manifest_path, manifest)
    return {'calibration_dir': str(out_dir), 'manifest_path': str(manifest_path), 'count': len(manifest_items), 'derived_from_training': True}

conversion_script = """#!/usr/bin/env python3
from __future__ import annotations

import argparse
import json
import shlex
import subprocess
from pathlib import Path


def parse_args() -> argparse.Namespace:
    parser = argparse.ArgumentParser(description='Lab 3 ONNX-to-MXQ handoff script for FSRCNN residual.')
    parser.add_argument('--onnx', type=Path, required=True)
    parser.add_argument('--calibration-dir', type=Path, required=True)
    parser.add_argument('--output', type=Path, required=True)
    parser.add_argument('--command-template', default='', help='Optional command with {onnx}, {calibration}, {output} placeholders.')
    parser.add_argument('--dry-run', action='store_true')
    return parser.parse_args()


def main() -> None:
    args = parse_args()
    args.onnx = args.onnx.resolve()
    args.calibration_dir = args.calibration_dir.resolve()
    args.output = args.output.resolve()
    if not args.onnx.exists():
        raise FileNotFoundError(f'ONNX file not found: {args.onnx}')
    if not args.calibration_dir.exists():
        raise FileNotFoundError(f'Calibration directory not found: {args.calibration_dir}')
    payload = {
        'onnx': str(args.onnx),
        'calibration_dir': str(args.calibration_dir),
        'output': str(args.output),
        'status': 'handoff_only',
        'command_template': args.command_template,
    }
    if args.command_template:
        command = args.command_template.format(
            onnx=shlex.quote(str(args.onnx)),
            calibration=shlex.quote(str(args.calibration_dir)),
            output=shlex.quote(str(args.output)),
        )
        payload['command'] = command
        if not args.dry_run:
            completed = subprocess.run(command, shell=True, check=False, capture_output=True, text=True)
            payload.update({'status': 'completed' if completed.returncode == 0 else 'failed', 'returncode': completed.returncode, 'stdout': completed.stdout, 'stderr': completed.stderr})
    args.output.parent.mkdir(parents=True, exist_ok=True)
    handoff_path = args.output.with_suffix('.handoff.json')
    handoff_path.write_text(json.dumps(payload, indent=2, sort_keys=True) + '\n', encoding='utf-8')
    print(json.dumps(payload, indent=2, sort_keys=True))


if __name__ == '__main__':
    main()
"""

onnx_path = exports_dir / f'{cfg.model_id}.onnx'
mxq_target_path = exports_dir / f'{cfg.model_id}.mxq'
conversion_script_path = exports_dir / 'convert_fsrcnn_residual_mxq.py'
conversion_script_path.write_text(conversion_script, encoding='utf-8')

cpu_export_model = load_checkpoint_for_eval(best_ckpt_path, torch.device('cpu')).cpu().eval()
dummy = torch.randn(1, 3, cfg.eval_size, cfg.eval_size)
torch.onnx.export(cpu_export_model, dummy, str(onnx_path), input_names=['input'], output_names=['output'], opset_version=17, dynamo=False)

onnx_model = onnx.load(str(onnx_path))
onnx.checker.check_model(onnx_model)
node_ops = [node.op_type for node in onnx_model.graph.node]
op_histogram = {op: node_ops.count(op) for op in sorted(set(node_ops))}
onnx_summary = {'onnx_path': str(onnx_path), 'checked': True, 'graph_op_count': len(node_ops), 'op_histogram': op_histogram}
print(onnx_summary)

parity_result = {'attempted': False, 'onnxruntime_available': False, 'max_abs_diff': None, 'mean_abs_diff': None}
try:
    import onnxruntime as ort
    parity_result['attempted'] = True
    parity_result['onnxruntime_available'] = True
    parity_input = torch.randn(1, 3, cfg.eval_size, cfg.eval_size)
    with torch.no_grad():
        torch_out = cpu_export_model(parity_input).detach().cpu().numpy()
    ort_session = ort.InferenceSession(str(onnx_path), providers=['CPUExecutionProvider'])
    ort_out = ort_session.run(['output'], {'input': parity_input.numpy()})[0]
    diff = np.abs(torch_out - ort_out)
    parity_result['max_abs_diff'] = float(diff.max())
    parity_result['mean_abs_diff'] = float(diff.mean())
except ImportError:
    print('onnxruntime not installed; skipping CPU parity check')
print(parity_result)

calibration_summary = export_calibration_images(train_pairs, calibration_dir, cfg.calibration_count, cfg.eval_size)
mxq_command = f'python {conversion_script_path} --onnx {onnx_path} --calibration-dir {calibration_dir} --output {mxq_target_path} --dry-run'
mxq_handoff = {
    'conversion_script_path': str(conversion_script_path),
    'onnx_input_path': str(onnx_path),
    'calibration_manifest_path': calibration_summary['manifest_path'],
    'mxq_target_path': str(mxq_target_path),
    'command': mxq_command,
    'requested_compile': False,
}
summary = {
    'model_id': cfg.model_id,
    'run_root': str(run_root),
    'config': asdict(cfg),
    'data': {'data_root': str(data_root), 'train_pairs': len(train_pairs), 'val_pairs': len(val_pairs), 'train_splits': L3_TRAIN_SPLITS, 'val_dirs': L3_VAL_DIRS},
    'model': {'params': param_count, 'operator_audit': op_counts, 'input_shape': [1, 3, cfg.eval_size, cfg.eval_size], 'output_shape': [1, 3, cfg.eval_size, cfg.eval_size]},
    'validation': validation_summary,
    'preview': preview_info,
    'artifacts': {
        'best_checkpoint': str(best_ckpt_path),
        'last_checkpoint': str(last_ckpt_path),
        'onnx': str(onnx_path),
        'calibration_manifest': calibration_summary['manifest_path'],
        'conversion_script': str(conversion_script_path),
        'mxq_target': str(mxq_target_path),
        'metrics_csv': str(metrics_csv_path),
    },
    'onnx': onnx_summary,
    'onnx_parity': parity_result,
    'calibration': calibration_summary,
    'mxq_handoff': mxq_handoff,
}
write_json(summary_path, summary)
print({'summary_path': str(summary_path), **summary['artifacts']})
