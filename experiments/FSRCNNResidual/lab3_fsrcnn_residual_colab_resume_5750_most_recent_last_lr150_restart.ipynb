# %% [markdown]
# # Lab 3 - FSRCNN Residual 96/40/m8 Resume Most Recent Last LR 1.5e-4 Restart To 5750 (Colab)

# %% [markdown]
# ## 1. Setup

# %%
try:
    import google.colab  # type: ignore
    IN_COLAB_BOOTSTRAP = True
except Exception:
    IN_COLAB_BOOTSTRAP = False

if IN_COLAB_BOOTSTRAP:
    # %pip install -q onnx onnxruntime

import csv
import json
import math
import os
import random
import sys
import time
from contextlib import nullcontext
from dataclasses import asdict, dataclass
from datetime import datetime
from pathlib import Path
from typing import Any

import numpy as np
import onnx
import torch
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
from torch.utils.data import DataLoader, Dataset

IMAGE_SUFFIXES = {'.png', '.jpg', '.jpeg', '.bmp'}
DRIVE_ROOT = Path('/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3')
DRIVE_DATA_ROOT = DRIVE_ROOT / 'Data'
DRIVE_RUNS_ROOT = DRIVE_ROOT / 'runs'

try:
    BICUBIC_RESAMPLE = Image.Resampling.BICUBIC
except AttributeError:
    BICUBIC_RESAMPLE = Image.BICUBIC

try:
    FLIP_LEFT_RIGHT = Image.Transpose.FLIP_LEFT_RIGHT
    FLIP_TOP_BOTTOM = Image.Transpose.FLIP_TOP_BOTTOM
    ROTATE_90 = Image.Transpose.ROTATE_90
    ROTATE_180 = Image.Transpose.ROTATE_180
    ROTATE_270 = Image.Transpose.ROTATE_270
except AttributeError:
    FLIP_LEFT_RIGHT = Image.FLIP_LEFT_RIGHT
    FLIP_TOP_BOTTOM = Image.FLIP_TOP_BOTTOM
    ROTATE_90 = Image.ROTATE_90
    ROTATE_180 = Image.ROTATE_180
    ROTATE_270 = Image.ROTATE_270


def set_global_seed(seed: int) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


def now_stamp() -> str:
    return datetime.now().strftime('%H%M%S_%d%m')


def is_colab_runtime() -> bool:
    try:
        import google.colab  # type: ignore  # noqa: F401
        return True
    except Exception:
        return False


def auto_num_workers(in_colab: bool) -> int:
    if sys.platform == 'darwin':
        return 0
    cpu_count = max(os.cpu_count() or 2, 2)
    if in_colab:
        return min(4, max(cpu_count - 1, 2))
    return min(2, cpu_count)


def resolve_repo_root(start: Path) -> Path:
    current = start.resolve()
    for candidate in [current, *current.parents]:
        if (candidate / 'Data').exists() and (candidate / 'runs').exists():
            return candidate
    for candidate in [current, *current.parents]:
        if (candidate / 'Data').exists():
            return candidate
    raise FileNotFoundError(f'Could not locate repo root from {start.resolve()}')


def make_unique_run_root(runs_root: Path, run_slug: str) -> Path:
    safe_slug = ''.join(ch if ch.isalnum() or ch in '_-' else '_' for ch in run_slug).strip('_')
    candidate = runs_root / f'{now_stamp()}_{safe_slug}'
    while candidate.exists():
        time.sleep(1.1)
        candidate = runs_root / f'{now_stamp()}_{safe_slug}'
    return candidate


def write_json(path: Path, payload: dict[str, Any]) -> None:
    path.parent.mkdir(parents=True, exist_ok=True)
    path.write_text(json.dumps(payload, indent=2, sort_keys=True) + '\n', encoding='utf-8')

# %% [markdown]
# ## 2. Configuration

# %%
@dataclass
class RunConfig:
    model_id: str = 'fsrcnn_residual_96_40_m8'
    run_slug: str = 'fsrcnn_residual_96_40_m8_resume5750_most_recent_last_lr150_restart'
    enable_resume: bool = True
    resume_checkpoint_path: str | None = (
        '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/'
        'runs/182012_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart/checkpoints/last.pth'
    )

    seed: int = 1337
    train_patch_size: int = 256
    eval_size: int = 256
    batch_size: int = 16
    epochs: int = 5750

    lr: float = 1.5e-4
    min_lr: float = 1e-5
    warmup_epochs: int = 5
    weight_decay: float = 1e-4
    load_optimizer_state: bool = False

    num_workers: int | None = 2
    prefetch_factor: int = 2
    use_amp: bool = True
    use_ema: bool = True
    ema_decay: float = 0.999

cfg = RunConfig()
in_colab = is_colab_runtime()
if in_colab:
    from google.colab import drive  # type: ignore

    drive.mount('/content/drive', force_remount=False)
    data_root = DRIVE_DATA_ROOT
    runs_root = DRIVE_RUNS_ROOT
    if not data_root.exists():
        raise FileNotFoundError(f'Google Drive data root not found: {data_root}')
else:
    repo_root = resolve_repo_root(Path.cwd())
    data_root = repo_root / 'Data'
    runs_root = repo_root / 'runs'
    if not data_root.exists():
        raise FileNotFoundError(f'Data root not found: {data_root}')

runs_root.mkdir(parents=True, exist_ok=True)
if cfg.num_workers is None:
    cfg.num_workers = auto_num_workers(in_colab)
if not cfg.enable_resume:
    cfg.resume_checkpoint_path = None

run_root = make_unique_run_root(runs_root, cfg.run_slug)
checkpoints_dir = run_root / 'checkpoints'
exports_dir = run_root / 'exports'
preview_dir = exports_dir / 'val_preview'
summary_path = run_root / 'summary.json'
metrics_csv_path = run_root / 'metrics.csv'
history_json_path = run_root / 'history.json'
run_manifest_path = run_root / 'run_manifest.json'
run_log_paths = {'metrics_csv': str(metrics_csv_path), 'history_json': str(history_json_path), 'summary_json': str(summary_path), 'run_manifest': str(run_manifest_path)}

for directory in [run_root, checkpoints_dir, exports_dir, preview_dir]:
    directory.mkdir(parents=True, exist_ok=True)

set_global_seed(cfg.seed)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
cuda_enabled = device.type == 'cuda'
gpu_name = torch.cuda.get_device_name(0) if cuda_enabled else None
if cuda_enabled:
    torch.backends.cudnn.benchmark = True
    if hasattr(torch.backends.cuda.matmul, 'allow_tf32'):
        torch.backends.cuda.matmul.allow_tf32 = True

print({
    'device': str(device),
    'in_colab': in_colab,
    'data_root': str(data_root),
    'run_root': str(run_root),
    'gpu_name': gpu_name,
    'config': asdict(cfg),
})
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# {'device': 'cuda', 'in_colab': True, 'data_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/Data', 'run_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/220035_2804_fsrcnn_residual_96_40_m8_resume5750_most_recent_last_lr150_restart', 'gpu_name': 'NVIDIA L4', 'config': {'model_id': 'fsrcnn_residual_96_40_m8', 'run_slug': 'fsrcnn_residual_96_40_m8_resume5750_most_recent_last_lr150_restart', 'enable_resume': True, 'resume_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/182012_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart/checkpoints/last.pth', 'seed': 1337, 'train_patch_size': 256, 'eval_size': 256, 'batch_size': 16, 'epochs': 5750, 'lr': 0.00015, 'min_lr': 1e-05, 'warmup_epochs': 5, 'weight_decay': 0.0001, 'load_optimizer_state': False, 'num_workers': 2, 'prefetch_factor': 2, 'use_amp': True, 'use_ema': True, 'ema_decay': 0.999}}

# %% [markdown]
# ## 3. Data

# %%
L3_TRAIN_SPLITS = (
    ('LR_HR/L3_HR_train1', 'L3_LR/L3_L3_train1', 'L3_HR_train1'),
    ('LR_HR/L3_HR_train2', 'L3_LR/L3_L3_train2', 'L3_HR_train2'),
    ('LR_HR/L3_HR_train3', 'L3_LR/L3_LR_train3', 'L3_HR_train3'),
    ('LR_HR/L3_HR_train4', 'L3_LR/L3_LR_train4', 'L3_HR_train4'),
    ('LR_HR/L3_HR_train', 'L3_LR/L3_LR_train', 'L3_HR_train'),
)
L3_VAL_DIRS = ('L3_HR_valid', 'L3_LR_valid')


def scan_image_directory(directory: Path) -> dict[str, Path]:
    if not directory.exists():
        raise FileNotFoundError(f'Missing directory: {directory}')
    return {
        path.stem: path
        for path in directory.iterdir()
        if path.is_file() and path.suffix.lower() in IMAGE_SUFFIXES
    }


def collect_split_pairs(hr_dir: Path, lr_dir: Path, split_name: str) -> list[tuple[Path, Path, str]]:
    hr_map = scan_image_directory(hr_dir)
    lr_map = scan_image_directory(lr_dir)
    shared = sorted(set(hr_map) & set(lr_map))
    if not shared:
        raise FileNotFoundError(f'No paired files found for {split_name}: HR={hr_dir}, LR={lr_dir}')
    hr_only = sorted(set(hr_map) - set(lr_map))
    lr_only = sorted(set(lr_map) - set(hr_map))
    if hr_only or lr_only:
        print({'split': split_name, 'hr_only_count': len(hr_only), 'lr_only_count': len(lr_only)})
    pairs: list[tuple[Path, Path, str]] = []
    for stem in shared:
        name = stem if split_name == 'val' else f'{split_name}/{stem}'
        pairs.append((lr_map[stem], hr_map[stem], name))
    return pairs


def collect_all_pairs(data_root: Path) -> tuple[list[tuple[Path, Path, str]], list[tuple[Path, Path, str]]]:
    train_pairs: list[tuple[Path, Path, str]] = []
    for hr_rel, lr_rel, split_name in L3_TRAIN_SPLITS:
        hr_dir = data_root / hr_rel
        lr_dir = data_root / lr_rel
        if hr_dir.exists() and lr_dir.exists():
            train_pairs.extend(collect_split_pairs(hr_dir, lr_dir, split_name))
        else:
            print({'skipped_missing_train_split': split_name, 'hr_dir': str(hr_dir), 'lr_dir': str(lr_dir)})
    val_pairs = collect_split_pairs(data_root / L3_VAL_DIRS[0], data_root / L3_VAL_DIRS[1], 'val')
    return train_pairs, val_pairs


class PairedSRDataset(Dataset):
    def __init__(self, pairs: list[tuple[Path, Path, str]], *, train: bool, patch_size: int, eval_size: int, seed: int):
        self.pairs = pairs
        self.train = train
        self.patch_size = patch_size
        self.eval_size = eval_size
        self.seed = seed
        self.epoch = 0

    def set_epoch(self, epoch: int) -> None:
        self.epoch = epoch

    @staticmethod
    def to_tensor(img: Image.Image) -> torch.Tensor:
        arr = np.asarray(img, dtype=np.float32) / 255.0
        return torch.from_numpy(arr).permute(2, 0, 1).contiguous()

    def augment_pair(self, lr: Image.Image, hr: Image.Image, index: int) -> tuple[Image.Image, Image.Image]:
        rng = random.Random((self.seed * 1_000_003) + (self.epoch * 9_973) + index)
        width, height = lr.size
        patch = self.patch_size
        if width < patch or height < patch:
            lr = lr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            hr = hr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            width, height = lr.size
        left = rng.randint(0, width - patch)
        top = rng.randint(0, height - patch)
        box = (left, top, left + patch, top + patch)
        lr = lr.crop(box)
        hr = hr.crop(box)
        if rng.random() < 0.5:
            lr = lr.transpose(FLIP_LEFT_RIGHT)
            hr = hr.transpose(FLIP_LEFT_RIGHT)
        if rng.random() < 0.5:
            lr = lr.transpose(FLIP_TOP_BOTTOM)
            hr = hr.transpose(FLIP_TOP_BOTTOM)
        rot = rng.choice([0, 1, 2, 3])
        if rot:
            rotate_ops = [ROTATE_90, ROTATE_180, ROTATE_270]
            lr = lr.transpose(rotate_ops[rot - 1])
            hr = hr.transpose(rotate_ops[rot - 1])
        return lr, hr

    def __len__(self) -> int:
        return len(self.pairs)

    def __getitem__(self, index: int) -> dict[str, Any]:
        lr_path, hr_path, name = self.pairs[index]
        lr = Image.open(lr_path).convert('RGB')
        hr = Image.open(hr_path).convert('RGB')
        if self.train:
            lr, hr = self.augment_pair(lr, hr, index)
        elif lr.size != (self.eval_size, self.eval_size):
            lr = lr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            hr = hr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
        return {'lr': self.to_tensor(lr), 'hr': self.to_tensor(hr), 'name': name}

train_pairs, val_pairs = collect_all_pairs(data_root)
if not train_pairs:
    raise FileNotFoundError(f'No training pairs found under {data_root}')
if not val_pairs:
    raise FileNotFoundError(f'No validation pairs found under {data_root}')

train_ds = PairedSRDataset(train_pairs, train=True, patch_size=cfg.train_patch_size, eval_size=cfg.eval_size, seed=cfg.seed)
val_ds = PairedSRDataset(val_pairs, train=False, patch_size=cfg.train_patch_size, eval_size=cfg.eval_size, seed=cfg.seed)

loader_num_workers = int(cfg.num_workers or 0)
train_loader_kwargs = {
    'dataset': train_ds,
    'batch_size': cfg.batch_size,
    'shuffle': True,
    'num_workers': loader_num_workers,
    'pin_memory': cuda_enabled,
}
val_loader_kwargs = {
    'dataset': val_ds,
    'batch_size': 1,
    'shuffle': False,
    'num_workers': loader_num_workers,
    'pin_memory': cuda_enabled,
}
if loader_num_workers > 0:
    train_loader_kwargs['persistent_workers'] = True
    val_loader_kwargs['persistent_workers'] = True
    train_loader_kwargs['prefetch_factor'] = cfg.prefetch_factor
    val_loader_kwargs['prefetch_factor'] = cfg.prefetch_factor

train_loader = DataLoader(**train_loader_kwargs)
val_loader = DataLoader(**val_loader_kwargs)

sample = train_ds[0]
print({
    'data_root': str(data_root),
    'train_pairs': len(train_pairs),
    'val_pairs': len(val_pairs),
    'train_preview': [name for _, _, name in train_pairs[:5]],
    'val_preview': [name for _, _, name in val_pairs[:5]],
    'sample_lr_shape': tuple(sample['lr'].shape),
    'sample_hr_shape': tuple(sample['hr'].shape),
})
assert tuple(sample['lr'].shape) == (3, cfg.eval_size, cfg.eval_size)
assert tuple(sample['hr'].shape) == (3, cfg.eval_size, cfg.eval_size)
# Out:
# {'data_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/Data', 'train_pairs': 2217, 'val_pairs': 110, 'train_preview': ['L3_HR_train1/0000', 'L3_HR_train1/0001', 'L3_HR_train1/00010', 'L3_HR_train1/000100', 'L3_HR_train1/000101'], 'val_preview': ['0000', '00010', '000100', '000102', '000104'], 'sample_lr_shape': (3, 256, 256), 'sample_hr_shape': (3, 256, 256)}

# %% [markdown]
# ## 4. Model

# %%
class FSRCNNResidualNoUpscale(nn.Module):
    """FSRCNN-style residual refiner for 256x256 RGB input/output."""

    def __init__(self, channels: int = 96, shrink_channels: int = 40, mapping_layers: int = 8, slope: float = 0.10):
        super().__init__()
        self.channels = channels
        self.shrink_channels = shrink_channels
        self.mapping_layers = mapping_layers
        self.slope = slope

        self.features = nn.Sequential(*self._feature_layers())
        self.tail = nn.Conv2d(channels, 3, 3, padding=1, bias=True)
        self.init_tail_small()

    def _activation(self) -> nn.Module:
        return nn.LeakyReLU(self.slope, inplace=False)

    def _feature_layers(self) -> list[nn.Module]:
        stem = [
            nn.Conv2d(3, self.channels, 5, padding=2, bias=True),
            self._activation(),
        ]
        shrink = [
            nn.Conv2d(self.channels, self.shrink_channels, 1, padding=0, bias=True),
            self._activation(),
        ]
        mapping: list[nn.Module] = []
        for _ in range(self.mapping_layers):
            mapping.extend([
                nn.Conv2d(self.shrink_channels, self.shrink_channels, 3, padding=1, bias=True),
                self._activation(),
            ])
        expand = [
            nn.Conv2d(self.shrink_channels, self.channels, 1, padding=0, bias=True),
            self._activation(),
        ]
        return [*stem, *shrink, *mapping, *expand]

    def architecture_summary(self) -> dict[str, str | int]:
        return {
            'stem': f'Conv5x5 3->{self.channels} + LeakyReLU',
            'shrink': f'Conv1x1 {self.channels}->{self.shrink_channels} + LeakyReLU',
            'mapping': f'{self.mapping_layers}x Conv3x3 {self.shrink_channels}->{self.shrink_channels} + LeakyReLU',
            'expand': f'Conv1x1 {self.shrink_channels}->{self.channels} + LeakyReLU',
            'tail': f'Conv3x3 {self.channels}->3 residual delta',
            'forward': 'output = input + residual_delta',
        }

    def init_tail_small(self) -> None:
        nn.init.kaiming_normal_(self.tail.weight, nonlinearity='linear')
        self.tail.weight.data.mul_(1e-3)
        if self.tail.bias is not None:
            nn.init.zeros_(self.tail.bias)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return x + self.tail(self.features(x))


def count_parameters(module: nn.Module) -> int:
    return int(sum(param.numel() for param in module.parameters()))


def operator_audit(module: nn.Module) -> dict[str, int]:
    counts: dict[str, int] = {}
    for child in module.modules():
        if len(list(child.children())) != 0:
            continue
        name = child.__class__.__name__
        counts[name] = counts.get(name, 0) + 1
    return dict(sorted(counts.items()))

model = FSRCNNResidualNoUpscale().to(device)
eval_model = FSRCNNResidualNoUpscale().to(device)
param_count = count_parameters(model)
op_counts = operator_audit(model)
dummy = torch.zeros(1, 3, cfg.eval_size, cfg.eval_size, device=device)
with torch.no_grad():
    dummy_out = model(dummy)

print({
    'model_id': cfg.model_id,
    'params': param_count,
    'operator_audit': op_counts,
    'input_shape': tuple(dummy.shape),
    'output_shape': tuple(dummy_out.shape),
    'architecture': model.architecture_summary(),
})
assert param_count == 133_227, param_count
assert tuple(dummy_out.shape) == (1, 3, cfg.eval_size, cfg.eval_size)
assert set(op_counts).issubset({'Conv2d', 'LeakyReLU'}), op_counts
# Out:
# {'model_id': 'fsrcnn_residual_96_40_m8', 'params': 133227, 'operator_audit': {'Conv2d': 12, 'LeakyReLU': 11}, 'input_shape': (1, 3, 256, 256), 'output_shape': (1, 3, 256, 256), 'architecture': {'stem': 'Conv5x5 3->96 + LeakyReLU', 'shrink': 'Conv1x1 96->40 + LeakyReLU', 'mapping': '8x Conv3x3 40->40 + LeakyReLU', 'expand': 'Conv1x1 40->96 + LeakyReLU', 'tail': 'Conv3x3 96->3 residual delta', 'forward': 'output = input + residual_delta'}}

# %% [markdown]
# ## 5. Training And Validation

# %%
class EMA:
    def __init__(self, model: nn.Module, decay: float):
        self.decay = decay
        self.shadow = {k: v.detach().clone() for k, v in model.state_dict().items()}

    @torch.no_grad()
    def update(self, model: nn.Module) -> None:
        for key, value in model.state_dict().items():
            self.shadow[key].mul_(self.decay).add_(value.detach(), alpha=1.0 - self.decay)

    @torch.no_grad()
    def copy_to(self, model: nn.Module) -> None:
        model.load_state_dict(self.shadow, strict=True)


def make_grad_scaler(enabled: bool):
    if hasattr(torch, 'amp') and hasattr(torch.amp, 'GradScaler'):
        return torch.amp.GradScaler('cuda', enabled=enabled)
    return torch.cuda.amp.GradScaler(enabled=enabled)


def autocast_context(device_type: str, enabled: bool):
    if not enabled:
        return nullcontext()
    if hasattr(torch, 'amp') and hasattr(torch.amp, 'autocast'):
        return torch.amp.autocast(device_type=device_type, enabled=enabled)
    return torch.cuda.amp.autocast(enabled=enabled)


@torch.no_grad()
def batch_psnr(pred: torch.Tensor, target: torch.Tensor) -> float:
    mse = F.mse_loss(pred, target, reduction='none').mean(dim=(1, 2, 3))
    psnr = 10.0 * torch.log10(1.0 / torch.clamp(mse, min=1e-12))
    return float(psnr.mean().item())


def compute_loss(pred: torch.Tensor, lr: torch.Tensor, hr: torch.Tensor) -> torch.Tensor:
    mse = F.mse_loss(pred, hr)
    residual_l1 = F.l1_loss(pred - lr, hr - lr)
    return 0.8 * mse + 0.2 * residual_l1


def lr_at_epoch(
    epoch_idx: int,
    *,
    base_lr: float,
    min_lr: float,
    warmup_epochs: int,
    total_epochs: int,
    schedule_start_epoch: int = 0,
) -> float:
    step = epoch_idx - schedule_start_epoch + 1
    span = max(1, total_epochs - schedule_start_epoch)

    if warmup_epochs > 0 and step <= warmup_epochs:
        return base_lr * step / warmup_epochs

    progress = (step - warmup_epochs) / max(1, span - warmup_epochs)
    progress = min(max(progress, 0.0), 1.0)
    cosine = 0.5 * (1.0 + math.cos(math.pi * progress))
    return min_lr + cosine * (base_lr - min_lr)

def evaluate_metrics(model: nn.Module, loader: DataLoader, device: torch.device) -> dict[str, float]:
    model.eval()
    pred_meter = 0.0
    input_meter = 0.0
    count = 0
    for batch in loader:
        lr = batch['lr'].to(device, non_blocking=cuda_enabled)
        hr = batch['hr'].to(device, non_blocking=cuda_enabled)
        pred = model(lr).clamp(0.0, 1.0)
        pred_meter += batch_psnr(pred, hr)
        input_meter += batch_psnr(lr, hr)
        count += 1
    val_psnr = pred_meter / max(count, 1)
    input_psnr = input_meter / max(count, 1)
    return {'val_psnr': float(val_psnr), 'input_psnr': float(input_psnr), 'delta_psnr': float(val_psnr - input_psnr)}


def tensor_to_uint8_image(x: torch.Tensor) -> Image.Image:
    x = x.detach().cpu().clamp(0.0, 1.0)
    arr = (x.permute(1, 2, 0).numpy() * 255.0).round().astype(np.uint8)
    return Image.fromarray(arr)


@torch.no_grad()
def write_val_preview(model: nn.Module, loader: DataLoader, out_dir: Path, device: torch.device) -> dict[str, str]:
    out_dir.mkdir(parents=True, exist_ok=True)
    batch = next(iter(loader))
    lr = batch['lr'].to(device, non_blocking=cuda_enabled)
    hr = batch['hr'].to(device, non_blocking=cuda_enabled)
    pred = model(lr).clamp(0.0, 1.0)
    name = batch['name'][0]
    lr_path = out_dir / 'val_preview_input.png'
    pred_path = out_dir / 'val_preview_pred.png'
    hr_path = out_dir / 'val_preview_target.png'
    tensor_to_uint8_image(lr[0]).save(lr_path)
    tensor_to_uint8_image(pred[0]).save(pred_path)
    tensor_to_uint8_image(hr[0]).save(hr_path)
    return {'sample_name': str(name), 'input': str(lr_path), 'prediction': str(pred_path), 'target': str(hr_path)}


def checkpoint_payload(model: nn.Module, ema: EMA | None, optimizer: torch.optim.Optimizer, epoch: int, best_val_psnr: float, row: dict[str, Any]) -> dict[str, Any]:
    return {
        'config': asdict(cfg),
        'epoch': int(epoch),
        'model_state_dict': model.state_dict(),
        'ema_state_dict': ema.shadow if ema is not None else None,
        'optimizer_state_dict': optimizer.state_dict(),
        'best_val_psnr': float(best_val_psnr),
        'latest_metrics': row,
        'model_params': param_count,
        'operator_audit': op_counts,
    }


def load_checkpoint_for_eval(checkpoint_path: Path, device: torch.device) -> nn.Module:
    checkpoint = torch.load(checkpoint_path, map_location=device)
    loaded = FSRCNNResidualNoUpscale().to(device)
    state = checkpoint.get('ema_state_dict') or checkpoint['model_state_dict']
    loaded.load_state_dict(state, strict=True)
    loaded.eval()
    return loaded

optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)
scaler = make_grad_scaler(cfg.use_amp and cuda_enabled)
ema = EMA(model, cfg.ema_decay) if cfg.use_ema else None
best_val_psnr = float('-inf')
start_epoch = 0

metrics_header = ['epoch', 'epoch_time_sec', 'lr', 'train_loss', 'train_psnr', 'val_psnr', 'input_psnr', 'delta_psnr', 'best_val_psnr']
best_ckpt_path = checkpoints_dir / 'best.pth'
last_ckpt_path = checkpoints_dir / 'last.pth'
resume_info: dict[str, Any] = {

    'enabled': cfg.enable_resume,

    'checkpoint_path': cfg.resume_checkpoint_path,

}

optimizer_state_loaded = False




if cfg.enable_resume:

    if cfg.resume_checkpoint_path is None:

        raise ValueError('cfg.enable_resume=True requires cfg.resume_checkpoint_path')

    resume_checkpoint_path = Path(cfg.resume_checkpoint_path)

    if not resume_checkpoint_path.exists():

        raise FileNotFoundError(f'Resume checkpoint not found: {resume_checkpoint_path}')

    resume_checkpoint = torch.load(resume_checkpoint_path, map_location=device)

    model.load_state_dict(resume_checkpoint['model_state_dict'], strict=True)

    if cfg.load_optimizer_state and 'optimizer_state_dict' in resume_checkpoint:

        optimizer.load_state_dict(resume_checkpoint['optimizer_state_dict'])

        optimizer_state_loaded = True


    if ema is not None and resume_checkpoint.get('ema_state_dict') is not None:

        ema.shadow = {key: value.detach().clone().to(device) for key, value in resume_checkpoint['ema_state_dict'].items()}

    best_val_psnr = float(resume_checkpoint.get('best_val_psnr', best_val_psnr))

    start_epoch = int(resume_checkpoint.get('epoch', 0))

    resume_info.update({

        'checkpoint_path': str(resume_checkpoint_path),

        'checkpoint_epoch': start_epoch,

        'checkpoint_best_val_psnr': best_val_psnr,

        'checkpoint_latest_metrics': resume_checkpoint.get('latest_metrics'),

        'checkpoint_config': resume_checkpoint.get('config'),

        'checkpoint_model_params': resume_checkpoint.get('model_params'),

        'checkpoint_operator_audit': resume_checkpoint.get('operator_audit'),

        'optimizer_state_loaded': optimizer_state_loaded,

        'load_optimizer_state': cfg.load_optimizer_state,



    })

    print({

        'resume_checkpoint_path': str(resume_checkpoint_path),

        'resumed_from_epoch': start_epoch,

        'target_total_epochs': cfg.epochs,






        **run_log_paths,

        'best_val_psnr': best_val_psnr,

    })



if start_epoch >= cfg.epochs:
    raise ValueError(f'Resume checkpoint epoch {start_epoch} is already >= target epochs {cfg.epochs}')

lr_schedule_info = {

    'type': 'resume_local_cosine_warm_restart',

    'base_lr': cfg.lr,

    'min_lr': cfg.min_lr,

    'warmup_epochs': cfg.warmup_epochs,

    'schedule_start_epoch': start_epoch,

    'target_total_epochs': cfg.epochs,

    'load_optimizer_state': cfg.load_optimizer_state,

    'optimizer_state_loaded': optimizer_state_loaded,

}



history = {
    'metadata': {
        'config': asdict(cfg),
        'run_root': str(run_root),
        'resume_checkpoint_path': cfg.resume_checkpoint_path,
        'resume': resume_info,

        'lr_schedule': lr_schedule_info,

        'start_epoch': start_epoch,
        'target_total_epochs': cfg.epochs,
        **run_log_paths,
        'device': str(device),
        'gpu_name': gpu_name,
        'torch_version': torch.__version__,
        'cuda_version': torch.version.cuda,
    },
    'epochs': [],
}
write_json(history_json_path, history)
write_json(run_manifest_path, history['metadata'])

with metrics_csv_path.open('w', newline='', encoding='utf-8') as f:
    csv.DictWriter(f, fieldnames=metrics_header).writeheader()

for epoch in range(start_epoch, cfg.epochs):
    train_ds.set_epoch(epoch)
    epoch_lr = lr_at_epoch(

        epoch,

        base_lr=cfg.lr,

        min_lr=cfg.min_lr,

        warmup_epochs=cfg.warmup_epochs,

        total_epochs=cfg.epochs,

        schedule_start_epoch=start_epoch,

    )
    for group in optimizer.param_groups:
        group['lr'] = epoch_lr

    epoch_start = time.time()
    model.train()
    train_loss_sum = 0.0
    train_psnr_sum = 0.0
    train_batches = 0

    for batch in train_loader:
        lr = batch['lr'].to(device, non_blocking=cuda_enabled)
        hr = batch['hr'].to(device, non_blocking=cuda_enabled)
        optimizer.zero_grad(set_to_none=True)
        with autocast_context(device.type, enabled=(cfg.use_amp and cuda_enabled)):
            pred = model(lr)
            loss = compute_loss(pred, lr, hr)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        if ema is not None:
            ema.update(model)
        train_loss_sum += float(loss.item())
        train_psnr_sum += batch_psnr(pred.detach().clamp(0.0, 1.0), hr)
        train_batches += 1

    if ema is not None:
        ema.copy_to(eval_model)
    else:
        eval_model.load_state_dict(model.state_dict())
    eval_model.eval()

    avg_train_loss = train_loss_sum / max(train_batches, 1)
    avg_train_psnr = train_psnr_sum / max(train_batches, 1)
    val_metrics = evaluate_metrics(eval_model, val_loader, device)
    is_best = val_metrics['val_psnr'] > best_val_psnr
    if is_best:
        best_val_psnr = val_metrics['val_psnr']
    row = {
        'epoch': epoch + 1,
        'epoch_time_sec': round(time.time() - epoch_start, 2),
        'lr': epoch_lr,
        'train_loss': round(avg_train_loss, 6),
        'train_psnr': round(avg_train_psnr, 4),
        'val_psnr': round(val_metrics['val_psnr'], 4),
        'input_psnr': round(val_metrics['input_psnr'], 4),
        'delta_psnr': round(val_metrics['delta_psnr'], 4),
        'best_val_psnr': round(best_val_psnr, 4),
    }
    print(row)
    history['epochs'].append(row)
    write_json(history_json_path, history)
    with metrics_csv_path.open('a', newline='', encoding='utf-8') as f:
        csv.DictWriter(f, fieldnames=metrics_header).writerow(row)
    payload = checkpoint_payload(model, ema, optimizer, epoch + 1, best_val_psnr, row)
    torch.save(payload, last_ckpt_path)
    if is_best:
        torch.save(payload, best_ckpt_path)
# Out:
# {'resume_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/182012_2804_fsrcnn_residual_96_40_m8_resume5400_current_last_lr75_restart/checkpoints/last.pth', 'resumed_from_epoch': 5400, 'target_total_epochs': 5750, 'metrics_csv': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/220035_2804_fsrcnn_residual_96_40_m8_resume5750_most_recent_last_lr150_restart/metrics.csv', 'history_json': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/220035_2804_fsrcnn_residual_96_40_m8_resume5750_most_recent_last_lr150_restart/history.json', 'summary_json': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/220035_2804_fsrcnn_residual_96_40_m8_resume5750_most_recent_last_lr150_restart/summary.json', 'run_manifest': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/220035_2804_fsrcnn_residual_96_40_m8_resume5750_most_recent_last_lr150_restart/run_manifest.json', 'best_val_psnr': 24.054289835149593}
# {'epoch': 5401, 'epoch_time_sec': 37.33, 'lr': 2.9999999999999997e-05, 'train_loss': 0.011577, 'train_psnr': 25.164, 'val_psnr': 24.0541, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0543}
# {'epoch': 5402, 'epoch_time_sec': 19.86, 'lr': 5.9999999999999995e-05, 'train_loss': 0.011581, 'train_psnr': 25.1607, 'val_psnr': 24.0541, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0543}
# {'epoch': 5403, 'epoch_time_sec': 19.81, 'lr': 8.999999999999999e-05, 'train_loss': 0.011592, 'train_psnr': 25.156, 'val_psnr': 24.0541, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0543}
# {'epoch': 5404, 'epoch_time_sec': 19.72, 'lr': 0.00011999999999999999, 'train_loss': 0.011608, 'train_psnr': 25.1458, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0543}
# {'epoch': 5405, 'epoch_time_sec': 19.67, 'lr': 0.00015, 'train_loss': 0.011615, 'train_psnr': 25.1416, 'val_psnr': 24.054, 'input_psnr': 23.1331, 'delta_psnr': 0.9209, 'best_val_psnr': 24.0543}
# {'epoch': 5406, 'epoch_time_sec': 19.73, 'lr': 0.00014999709780493954, 'train_loss': 0.011633, 'train_psnr': 25.1358, 'val_psnr': 24.054, 'input_psnr': 23.1331, 'delta_psnr': 0.921, 'best_val_psnr': 24.0543}
# {'epoch': 5407, 'epoch_time_sec': 19.8, 'lr': 0.00014998839146040783, 'train_loss': 0.011609, 'train_psnr': 25.1455, 'val_psnr': 24.0534, 'input_psnr': 23.1331, 'delta_psnr': 0.9204, 'best_val_psnr': 24.0543}
# {'epoch': 5408, 'epoch_time_sec': 19.74, 'lr': 0.00014997388168833375, 'train_loss': 0.011609, 'train_psnr': 25.1479, 'val_psnr': 24.0533, 'input_psnr': 23.1331, 'delta_psnr': 0.9203, 'best_val_psnr': 24.0543}
# {'epoch': 5409, 'epoch_time_sec': 19.71, 'lr': 0.00014995356969186546, 'train_loss': 0.011609, 'train_psnr': 25.1509, 'val_psnr': 24.0534, 'input_psnr': 23.1331, 'delta_psnr': 0.9204, 'best_val_psnr': 24.0543}
# {'epoch': 5410, 'epoch_time_sec': 19.8, 'lr': 0.00014992745715527092, 'train_loss': 0.011608, 'train_psnr': 25.1473, 'val_psnr': 24.0534, 'input_psnr': 23.1331, 'delta_psnr': 0.9203, 'best_val_psnr': 24.0543}
# {'epoch': 5411, 'epoch_time_sec': 19.79, 'lr': 0.00014989554624379793, 'train_loss': 0.011599, 'train_psnr': 25.1526, 'val_psnr': 24.0533, 'input_psnr': 23.1331, 'delta_psnr': 0.9202, 'best_val_psnr': 24.0543}
# {'epoch': 5412, 'epoch_time_sec': 19.76, 'lr': 0.00014985783960349481, 'train_loss': 0.011611, 'train_psnr': 25.1473, 'val_psnr': 24.053, 'input_psnr': 23.1331, 'delta_psnr': 0.92, 'best_val_psnr': 24.0543}
# {'epoch': 5413, 'epoch_time_sec': 19.78, 'lr': 0.00014981434036099084, 'train_loss': 0.011612, 'train_psnr': 25.1444, 'val_psnr': 24.053, 'input_psnr': 23.1331, 'delta_psnr': 0.9199, 'best_val_psnr': 24.0543}
# {'epoch': 5414, 'epoch_time_sec': 19.72, 'lr': 0.00014976505212323707, 'train_loss': 0.011604, 'train_psnr': 25.1505, 'val_psnr': 24.0528, 'input_psnr': 23.1331, 'delta_psnr': 0.9197, 'best_val_psnr': 24.0543}
# {'epoch': 5415, 'epoch_time_sec': 19.75, 'lr': 0.00014970997897720717, 'train_loss': 0.011622, 'train_psnr': 25.1398, 'val_psnr': 24.0526, 'input_psnr': 23.1331, 'delta_psnr': 0.9196, 'best_val_psnr': 24.0543}
# {'epoch': 5416, 'epoch_time_sec': 19.75, 'lr': 0.0001496491254895587, 'train_loss': 0.011607, 'train_psnr': 25.1468, 'val_psnr': 24.0526, 'input_psnr': 23.1331, 'delta_psnr': 0.9196, 'best_val_psnr': 24.0543}
# {'epoch': 5417, 'epoch_time_sec': 19.76, 'lr': 0.00014958249670625424, 'train_loss': 0.011601, 'train_psnr': 25.1502, 'val_psnr': 24.0526, 'input_psnr': 23.1331, 'delta_psnr': 0.9195, 'best_val_psnr': 24.0543}
# {'epoch': 5418, 'epoch_time_sec': 19.78, 'lr': 0.00014951009815214312, 'train_loss': 0.011597, 'train_psnr': 25.1528, 'val_psnr': 24.0524, 'input_psnr': 23.1331, 'delta_psnr': 0.9194, 'best_val_psnr': 24.0543}
# {'epoch': 5419, 'epoch_time_sec': 19.75, 'lr': 0.00014943193583050318, 'train_loss': 0.011596, 'train_psnr': 25.1577, 'val_psnr': 24.0525, 'input_psnr': 23.1331, 'delta_psnr': 0.9194, 'best_val_psnr': 24.0543}
# {'epoch': 5420, 'epoch_time_sec': 19.77, 'lr': 0.00014934801622254313, 'train_loss': 0.011603, 'train_psnr': 25.1515, 'val_psnr': 24.0524, 'input_psnr': 23.1331, 'delta_psnr': 0.9194, 'best_val_psnr': 24.0543}
# {'epoch': 5421, 'epoch_time_sec': 19.73, 'lr': 0.00014925834628686505, 'train_loss': 0.011605, 'train_psnr': 25.1496, 'val_psnr': 24.0522, 'input_psnr': 23.1331, 'delta_psnr': 0.9191, 'best_val_psnr': 24.0543}
# {'epoch': 5422, 'epoch_time_sec': 19.75, 'lr': 0.00014916293345888727, 'train_loss': 0.011608, 'train_psnr': 25.1484, 'val_psnr': 24.0522, 'input_psnr': 23.1331, 'delta_psnr': 0.9191, 'best_val_psnr': 24.0543}
# {'epoch': 5423, 'epoch_time_sec': 19.79, 'lr': 0.00014906178565022812, 'train_loss': 0.011598, 'train_psnr': 25.1549, 'val_psnr': 24.0522, 'input_psnr': 23.1331, 'delta_psnr': 0.9191, 'best_val_psnr': 24.0543}
# {'epoch': 5424, 'epoch_time_sec': 19.79, 'lr': 0.00014895491124804954, 'train_loss': 0.011608, 'train_psnr': 25.1487, 'val_psnr': 24.0521, 'input_psnr': 23.1331, 'delta_psnr': 0.919, 'best_val_psnr': 24.0543}
# {'epoch': 5425, 'epoch_time_sec': 19.79, 'lr': 0.00014884231911436194, 'train_loss': 0.011594, 'train_psnr': 25.1549, 'val_psnr': 24.052, 'input_psnr': 23.1331, 'delta_psnr': 0.919, 'best_val_psnr': 24.0543}
# {'epoch': 5426, 'epoch_time_sec': 19.76, 'lr': 0.00014872401858528908, 'train_loss': 0.011612, 'train_psnr': 25.1492, 'val_psnr': 24.0519, 'input_psnr': 23.1331, 'delta_psnr': 0.9188, 'best_val_psnr': 24.0543}
# {'epoch': 5427, 'epoch_time_sec': 19.72, 'lr': 0.0001486000194702942, 'train_loss': 0.011603, 'train_psnr': 25.1504, 'val_psnr': 24.0517, 'input_psnr': 23.1331, 'delta_psnr': 0.9186, 'best_val_psnr': 24.0543}
# {'epoch': 5428, 'epoch_time_sec': 19.76, 'lr': 0.00014847033205136638, 'train_loss': 0.011588, 'train_psnr': 25.1606, 'val_psnr': 24.0518, 'input_psnr': 23.1331, 'delta_psnr': 0.9188, 'best_val_psnr': 24.0543}
# {'epoch': 5429, 'epoch_time_sec': 19.81, 'lr': 0.0001483349670821681, 'train_loss': 0.011597, 'train_psnr': 25.1548, 'val_psnr': 24.0519, 'input_psnr': 23.1331, 'delta_psnr': 0.9188, 'best_val_psnr': 24.0543}
# {'epoch': 5430, 'epoch_time_sec': 19.85, 'lr': 0.00014819393578714354, 'train_loss': 0.011599, 'train_psnr': 25.1565, 'val_psnr': 24.0518, 'input_psnr': 23.1331, 'delta_psnr': 0.9188, 'best_val_psnr': 24.0543}
# {'epoch': 5431, 'epoch_time_sec': 19.75, 'lr': 0.0001480472498605877, 'train_loss': 0.011615, 'train_psnr': 25.1466, 'val_psnr': 24.0519, 'input_psnr': 23.1331, 'delta_psnr': 0.9188, 'best_val_psnr': 24.0543}
# {'epoch': 5432, 'epoch_time_sec': 19.8, 'lr': 0.00014789492146567699, 'train_loss': 0.01162, 'train_psnr': 25.1476, 'val_psnr': 24.0517, 'input_psnr': 23.1331, 'delta_psnr': 0.9187, 'best_val_psnr': 24.0543}
# {'epoch': 5433, 'epoch_time_sec': 19.79, 'lr': 0.00014773696323346034, 'train_loss': 0.011613, 'train_psnr': 25.1474, 'val_psnr': 24.0516, 'input_psnr': 23.1331, 'delta_psnr': 0.9185, 'best_val_psnr': 24.0543}
# {'epoch': 5434, 'epoch_time_sec': 19.81, 'lr': 0.00014757338826181215, 'train_loss': 0.011581, 'train_psnr': 25.1628, 'val_psnr': 24.0516, 'input_psnr': 23.1331, 'delta_psnr': 0.9186, 'best_val_psnr': 24.0543}
# {'epoch': 5435, 'epoch_time_sec': 19.77, 'lr': 0.00014740421011434594, 'train_loss': 0.011594, 'train_psnr': 25.1548, 'val_psnr': 24.0515, 'input_psnr': 23.1331, 'delta_psnr': 0.9184, 'best_val_psnr': 24.0543}
# {'epoch': 5436, 'epoch_time_sec': 19.74, 'lr': 0.00014722944281928983, 'train_loss': 0.0116, 'train_psnr': 25.1508, 'val_psnr': 24.0514, 'input_psnr': 23.1331, 'delta_psnr': 0.9184, 'best_val_psnr': 24.0543}
# {'epoch': 5437, 'epoch_time_sec': 19.75, 'lr': 0.00014704910086832325, 'train_loss': 0.011612, 'train_psnr': 25.1497, 'val_psnr': 24.0513, 'input_psnr': 23.1331, 'delta_psnr': 0.9182, 'best_val_psnr': 24.0543}
# {'epoch': 5438, 'epoch_time_sec': 19.81, 'lr': 0.00014686319921537535, 'train_loss': 0.011593, 'train_psnr': 25.1589, 'val_psnr': 24.0511, 'input_psnr': 23.1331, 'delta_psnr': 0.9181, 'best_val_psnr': 24.0543}
# {'epoch': 5439, 'epoch_time_sec': 19.8, 'lr': 0.00014667175327538493, 'train_loss': 0.01159, 'train_psnr': 25.1586, 'val_psnr': 24.0512, 'input_psnr': 23.1331, 'delta_psnr': 0.9182, 'best_val_psnr': 24.0543}
# {'epoch': 5440, 'epoch_time_sec': 19.74, 'lr': 0.00014647477892302234, 'train_loss': 0.011604, 'train_psnr': 25.1505, 'val_psnr': 24.0511, 'input_psnr': 23.1331, 'delta_psnr': 0.9181, 'best_val_psnr': 24.0543}
# {'epoch': 5441, 'epoch_time_sec': 19.74, 'lr': 0.00014627229249137305, 'train_loss': 0.011587, 'train_psnr': 25.1609, 'val_psnr': 24.0512, 'input_psnr': 23.1331, 'delta_psnr': 0.9181, 'best_val_psnr': 24.0543}
# {'epoch': 5442, 'epoch_time_sec': 19.75, 'lr': 0.00014606431077058342, 'train_loss': 0.011588, 'train_psnr': 25.1608, 'val_psnr': 24.0515, 'input_psnr': 23.1331, 'delta_psnr': 0.9184, 'best_val_psnr': 24.0543}
# {'epoch': 5443, 'epoch_time_sec': 19.76, 'lr': 0.00014585085100646836, 'train_loss': 0.011586, 'train_psnr': 25.1609, 'val_psnr': 24.0515, 'input_psnr': 23.1331, 'delta_psnr': 0.9184, 'best_val_psnr': 24.0543}
# {'epoch': 5444, 'epoch_time_sec': 19.81, 'lr': 0.00014563193089908141, 'train_loss': 0.011604, 'train_psnr': 25.1535, 'val_psnr': 24.0519, 'input_psnr': 23.1331, 'delta_psnr': 0.9188, 'best_val_psnr': 24.0543}
# {'epoch': 5445, 'epoch_time_sec': 19.75, 'lr': 0.00014540756860124696, 'train_loss': 0.011596, 'train_psnr': 25.1541, 'val_psnr': 24.0516, 'input_psnr': 23.1331, 'delta_psnr': 0.9185, 'best_val_psnr': 24.0543}
# {'epoch': 5446, 'epoch_time_sec': 19.79, 'lr': 0.0001451777827170551, 'train_loss': 0.011586, 'train_psnr': 25.1609, 'val_psnr': 24.0518, 'input_psnr': 23.1331, 'delta_psnr': 0.9187, 'best_val_psnr': 24.0543}
# {'epoch': 5447, 'epoch_time_sec': 19.8, 'lr': 0.0001449425923003189, 'train_loss': 0.011596, 'train_psnr': 25.1537, 'val_psnr': 24.0519, 'input_psnr': 23.1331, 'delta_psnr': 0.9188, 'best_val_psnr': 24.0543}
# {'epoch': 5448, 'epoch_time_sec': 19.79, 'lr': 0.00014470201685299456, 'train_loss': 0.0116, 'train_psnr': 25.1526, 'val_psnr': 24.0518, 'input_psnr': 23.1331, 'delta_psnr': 0.9188, 'best_val_psnr': 24.0543}
# {'epoch': 5449, 'epoch_time_sec': 19.76, 'lr': 0.00014445607632356414, 'train_loss': 0.011606, 'train_psnr': 25.1499, 'val_psnr': 24.0518, 'input_psnr': 23.1331, 'delta_psnr': 0.9188, 'best_val_psnr': 24.0543}
# {'epoch': 5450, 'epoch_time_sec': 19.8, 'lr': 0.0001442047911053817, 'train_loss': 0.01161, 'train_psnr': 25.1475, 'val_psnr': 24.0515, 'input_psnr': 23.1331, 'delta_psnr': 0.9184, 'best_val_psnr': 24.0543}
# {'epoch': 5451, 'epoch_time_sec': 19.79, 'lr': 0.00014394818203498203, 'train_loss': 0.011587, 'train_psnr': 25.1602, 'val_psnr': 24.0517, 'input_psnr': 23.1331, 'delta_psnr': 0.9186, 'best_val_psnr': 24.0543}
# {'epoch': 5452, 'epoch_time_sec': 19.77, 'lr': 0.00014368627039035309, 'train_loss': 0.011592, 'train_psnr': 25.1577, 'val_psnr': 24.0518, 'input_psnr': 23.1331, 'delta_psnr': 0.9187, 'best_val_psnr': 24.0543}
# {'epoch': 5453, 'epoch_time_sec': 19.72, 'lr': 0.00014341907788917145, 'train_loss': 0.011593, 'train_psnr': 25.155, 'val_psnr': 24.0518, 'input_psnr': 23.1331, 'delta_psnr': 0.9188, 'best_val_psnr': 24.0543}
# {'epoch': 5454, 'epoch_time_sec': 19.79, 'lr': 0.00014314662668700156, 'train_loss': 0.011595, 'train_psnr': 25.1554, 'val_psnr': 24.0516, 'input_psnr': 23.1331, 'delta_psnr': 0.9185, 'best_val_psnr': 24.0543}
# {'epoch': 5455, 'epoch_time_sec': 19.8, 'lr': 0.0001428689393754587, 'train_loss': 0.01159, 'train_psnr': 25.1581, 'val_psnr': 24.0517, 'input_psnr': 23.1331, 'delta_psnr': 0.9187, 'best_val_psnr': 24.0543}
# {'epoch': 5456, 'epoch_time_sec': 19.79, 'lr': 0.00014258603898033558, 'train_loss': 0.01161, 'train_psnr': 25.1506, 'val_psnr': 24.0518, 'input_psnr': 23.1331, 'delta_psnr': 0.9187, 'best_val_psnr': 24.0543}
# {'epoch': 5457, 'epoch_time_sec': 19.78, 'lr': 0.00014229794895969297, 'train_loss': 0.011584, 'train_psnr': 25.1636, 'val_psnr': 24.0519, 'input_psnr': 23.1331, 'delta_psnr': 0.9189, 'best_val_psnr': 24.0543}
# {'epoch': 5458, 'epoch_time_sec': 19.76, 'lr': 0.00014200469320191478, 'train_loss': 0.011593, 'train_psnr': 25.1557, 'val_psnr': 24.0519, 'input_psnr': 23.1331, 'delta_psnr': 0.9189, 'best_val_psnr': 24.0543}
# {'epoch': 5459, 'epoch_time_sec': 19.77, 'lr': 0.000141706296023727, 'train_loss': 0.01159, 'train_psnr': 25.1561, 'val_psnr': 24.0518, 'input_psnr': 23.1331, 'delta_psnr': 0.9188, 'best_val_psnr': 24.0543}
# {'epoch': 5460, 'epoch_time_sec': 19.82, 'lr': 0.0001414027821681816, 'train_loss': 0.011578, 'train_psnr': 25.1646, 'val_psnr': 24.0518, 'input_psnr': 23.1331, 'delta_psnr': 0.9187, 'best_val_psnr': 24.0543}
# {'epoch': 5461, 'epoch_time_sec': 19.77, 'lr': 0.0001410941768026046, 'train_loss': 0.011595, 'train_psnr': 25.1559, 'val_psnr': 24.0519, 'input_psnr': 23.1331, 'delta_psnr': 0.9188, 'best_val_psnr': 24.0543}
# {'epoch': 5462, 'epoch_time_sec': 19.78, 'lr': 0.00014078050551650934, 'train_loss': 0.011592, 'train_psnr': 25.1579, 'val_psnr': 24.0517, 'input_psnr': 23.1331, 'delta_psnr': 0.9187, 'best_val_psnr': 24.0543}
# {'epoch': 5463, 'epoch_time_sec': 19.77, 'lr': 0.00014046179431947465, 'train_loss': 0.011583, 'train_psnr': 25.1618, 'val_psnr': 24.0521, 'input_psnr': 23.1331, 'delta_psnr': 0.9191, 'best_val_psnr': 24.0543}
# {'epoch': 5464, 'epoch_time_sec': 19.79, 'lr': 0.00014013806963898798, 'train_loss': 0.011588, 'train_psnr': 25.1586, 'val_psnr': 24.0519, 'input_psnr': 23.1331, 'delta_psnr': 0.9188, 'best_val_psnr': 24.0543}
# {'epoch': 5465, 'epoch_time_sec': 19.82, 'lr': 0.00013980935831825418, 'train_loss': 0.011576, 'train_psnr': 25.1663, 'val_psnr': 24.0519, 'input_psnr': 23.1331, 'delta_psnr': 0.9189, 'best_val_psnr': 24.0543}
# {'epoch': 5466, 'epoch_time_sec': 19.8, 'lr': 0.00013947568761396952, 'train_loss': 0.011582, 'train_psnr': 25.1633, 'val_psnr': 24.0521, 'input_psnr': 23.1331, 'delta_psnr': 0.919, 'best_val_psnr': 24.0543}
# {'epoch': 5467, 'epoch_time_sec': 19.76, 'lr': 0.00013913708519406175, 'train_loss': 0.011606, 'train_psnr': 25.1537, 'val_psnr': 24.0522, 'input_psnr': 23.1331, 'delta_psnr': 0.9191, 'best_val_psnr': 24.0543}
# {'epoch': 5468, 'epoch_time_sec': 19.75, 'lr': 0.00013879357913539574, 'train_loss': 0.011588, 'train_psnr': 25.1578, 'val_psnr': 24.0522, 'input_psnr': 23.1331, 'delta_psnr': 0.9191, 'best_val_psnr': 24.0543}
# {'epoch': 5469, 'epoch_time_sec': 19.77, 'lr': 0.00013844519792144538, 'train_loss': 0.0116, 'train_psnr': 25.1547, 'val_psnr': 24.0524, 'input_psnr': 23.1331, 'delta_psnr': 0.9193, 'best_val_psnr': 24.0543}
# {'epoch': 5470, 'epoch_time_sec': 19.76, 'lr': 0.00013809197043993174, 'train_loss': 0.011589, 'train_psnr': 25.1611, 'val_psnr': 24.0522, 'input_psnr': 23.1331, 'delta_psnr': 0.9191, 'best_val_psnr': 24.0543}
# {'epoch': 5471, 'epoch_time_sec': 19.75, 'lr': 0.00013773392598042777, 'train_loss': 0.011581, 'train_psnr': 25.1634, 'val_psnr': 24.0522, 'input_psnr': 23.1331, 'delta_psnr': 0.9191, 'best_val_psnr': 24.0543}
# {'epoch': 5472, 'epoch_time_sec': 19.76, 'lr': 0.00013737109423192953, 'train_loss': 0.011589, 'train_psnr': 25.16, 'val_psnr': 24.0521, 'input_psnr': 23.1331, 'delta_psnr': 0.919, 'best_val_psnr': 24.0543}
# {'epoch': 5473, 'epoch_time_sec': 19.8, 'lr': 0.0001370035052803944, 'train_loss': 0.011585, 'train_psnr': 25.1611, 'val_psnr': 24.0524, 'input_psnr': 23.1331, 'delta_psnr': 0.9193, 'best_val_psnr': 24.0543}
# {'epoch': 5474, 'epoch_time_sec': 19.8, 'lr': 0.0001366311896062463, 'train_loss': 0.011602, 'train_psnr': 25.1537, 'val_psnr': 24.0521, 'input_psnr': 23.1331, 'delta_psnr': 0.9191, 'best_val_psnr': 24.0543}
# {'epoch': 5475, 'epoch_time_sec': 19.76, 'lr': 0.00013625417808184846, 'train_loss': 0.011592, 'train_psnr': 25.1613, 'val_psnr': 24.0521, 'input_psnr': 23.1331, 'delta_psnr': 0.919, 'best_val_psnr': 24.0543}
# {'epoch': 5476, 'epoch_time_sec': 19.74, 'lr': 0.00013587250196894323, 'train_loss': 0.011585, 'train_psnr': 25.1608, 'val_psnr': 24.0521, 'input_psnr': 23.1331, 'delta_psnr': 0.919, 'best_val_psnr': 24.0543}
# {'epoch': 5477, 'epoch_time_sec': 19.75, 'lr': 0.00013548619291606006, 'train_loss': 0.011574, 'train_psnr': 25.1679, 'val_psnr': 24.0522, 'input_psnr': 23.1331, 'delta_psnr': 0.9191, 'best_val_psnr': 24.0543}
# {'epoch': 5478, 'epoch_time_sec': 19.75, 'lr': 0.0001350952829558911, 'train_loss': 0.011584, 'train_psnr': 25.1633, 'val_psnr': 24.0523, 'input_psnr': 23.1331, 'delta_psnr': 0.9192, 'best_val_psnr': 24.0543}
# {'epoch': 5479, 'epoch_time_sec': 19.81, 'lr': 0.000134699804502635, 'train_loss': 0.011586, 'train_psnr': 25.1624, 'val_psnr': 24.0522, 'input_psnr': 23.1331, 'delta_psnr': 0.9191, 'best_val_psnr': 24.0543}
# {'epoch': 5480, 'epoch_time_sec': 19.78, 'lr': 0.00013429979034930938, 'train_loss': 0.011577, 'train_psnr': 25.1655, 'val_psnr': 24.0522, 'input_psnr': 23.1331, 'delta_psnr': 0.9191, 'best_val_psnr': 24.0543}
# {'epoch': 5481, 'epoch_time_sec': 19.73, 'lr': 0.00013389527366503131, 'train_loss': 0.011587, 'train_psnr': 25.1613, 'val_psnr': 24.0523, 'input_psnr': 23.1331, 'delta_psnr': 0.9192, 'best_val_psnr': 24.0543}
# {'epoch': 5482, 'epoch_time_sec': 19.74, 'lr': 0.00013348628799226726, 'train_loss': 0.011584, 'train_psnr': 25.1621, 'val_psnr': 24.0524, 'input_psnr': 23.1331, 'delta_psnr': 0.9193, 'best_val_psnr': 24.0543}
# {'epoch': 5483, 'epoch_time_sec': 19.75, 'lr': 0.00013307286724405137, 'train_loss': 0.011592, 'train_psnr': 25.1588, 'val_psnr': 24.0524, 'input_psnr': 23.1331, 'delta_psnr': 0.9193, 'best_val_psnr': 24.0543}
# {'epoch': 5484, 'epoch_time_sec': 19.84, 'lr': 0.00013265504570117383, 'train_loss': 0.011581, 'train_psnr': 25.1642, 'val_psnr': 24.0526, 'input_psnr': 23.1331, 'delta_psnr': 0.9195, 'best_val_psnr': 24.0543}
# {'epoch': 5485, 'epoch_time_sec': 19.79, 'lr': 0.00013223285800933798, 'train_loss': 0.011589, 'train_psnr': 25.1587, 'val_psnr': 24.0527, 'input_psnr': 23.1331, 'delta_psnr': 0.9196, 'best_val_psnr': 24.0543}
# {'epoch': 5486, 'epoch_time_sec': 19.79, 'lr': 0.00013180633917628763, 'train_loss': 0.011584, 'train_psnr': 25.1608, 'val_psnr': 24.0527, 'input_psnr': 23.1331, 'delta_psnr': 0.9196, 'best_val_psnr': 24.0543}
# {'epoch': 5487, 'epoch_time_sec': 19.79, 'lr': 0.00013137552456890422, 'train_loss': 0.011576, 'train_psnr': 25.1677, 'val_psnr': 24.0526, 'input_psnr': 23.1331, 'delta_psnr': 0.9196, 'best_val_psnr': 24.0543}
# {'epoch': 5488, 'epoch_time_sec': 19.76, 'lr': 0.0001309404499102742, 'train_loss': 0.011585, 'train_psnr': 25.1604, 'val_psnr': 24.0526, 'input_psnr': 23.1331, 'delta_psnr': 0.9195, 'best_val_psnr': 24.0543}
# {'epoch': 5489, 'epoch_time_sec': 19.8, 'lr': 0.0001305011512767269, 'train_loss': 0.011569, 'train_psnr': 25.1695, 'val_psnr': 24.0526, 'input_psnr': 23.1331, 'delta_psnr': 0.9195, 'best_val_psnr': 24.0543}
# {'epoch': 5490, 'epoch_time_sec': 19.75, 'lr': 0.00013005766509484296, 'train_loss': 0.011598, 'train_psnr': 25.1568, 'val_psnr': 24.0527, 'input_psnr': 23.1331, 'delta_psnr': 0.9196, 'best_val_psnr': 24.0543}
# {'epoch': 5491, 'epoch_time_sec': 19.8, 'lr': 0.000129610028138434, 'train_loss': 0.011575, 'train_psnr': 25.1671, 'val_psnr': 24.0527, 'input_psnr': 23.1331, 'delta_psnr': 0.9197, 'best_val_psnr': 24.0543}
# {'epoch': 5492, 'epoch_time_sec': 19.77, 'lr': 0.0001291582775254933, 'train_loss': 0.011589, 'train_psnr': 25.1619, 'val_psnr': 24.0527, 'input_psnr': 23.1331, 'delta_psnr': 0.9197, 'best_val_psnr': 24.0543}
# {'epoch': 5493, 'epoch_time_sec': 19.83, 'lr': 0.0001287024507151179, 'train_loss': 0.011584, 'train_psnr': 25.1615, 'val_psnr': 24.0528, 'input_psnr': 23.1331, 'delta_psnr': 0.9197, 'best_val_psnr': 24.0543}
# {'epoch': 5494, 'epoch_time_sec': 19.78, 'lr': 0.00012824258550440262, 'train_loss': 0.011579, 'train_psnr': 25.1653, 'val_psnr': 24.0529, 'input_psnr': 23.1331, 'delta_psnr': 0.9198, 'best_val_psnr': 24.0543}
# {'epoch': 5495, 'epoch_time_sec': 19.74, 'lr': 0.00012777872002530579, 'train_loss': 0.01157, 'train_psnr': 25.1694, 'val_psnr': 24.0529, 'input_psnr': 23.1331, 'delta_psnr': 0.9198, 'best_val_psnr': 24.0543}
# {'epoch': 5496, 'epoch_time_sec': 19.78, 'lr': 0.0001273108927414875, 'train_loss': 0.011577, 'train_psnr': 25.1659, 'val_psnr': 24.0529, 'input_psnr': 23.1331, 'delta_psnr': 0.9198, 'best_val_psnr': 24.0543}
# {'epoch': 5497, 'epoch_time_sec': 19.78, 'lr': 0.00012683914244512008, 'train_loss': 0.011583, 'train_psnr': 25.1621, 'val_psnr': 24.053, 'input_psnr': 23.1331, 'delta_psnr': 0.9199, 'best_val_psnr': 24.0543}
# {'epoch': 5498, 'epoch_time_sec': 19.8, 'lr': 0.00012636350825367154, 'train_loss': 0.011577, 'train_psnr': 25.1646, 'val_psnr': 24.053, 'input_psnr': 23.1331, 'delta_psnr': 0.92, 'best_val_psnr': 24.0543}
# {'epoch': 5499, 'epoch_time_sec': 19.77, 'lr': 0.0001258840296066619, 'train_loss': 0.011588, 'train_psnr': 25.1613, 'val_psnr': 24.0528, 'input_psnr': 23.1331, 'delta_psnr': 0.9198, 'best_val_psnr': 24.0543}
# {'epoch': 5500, 'epoch_time_sec': 19.8, 'lr': 0.00012540074626239293, 'train_loss': 0.011593, 'train_psnr': 25.1596, 'val_psnr': 24.0531, 'input_psnr': 23.1331, 'delta_psnr': 0.92, 'best_val_psnr': 24.0543}
# {'epoch': 5501, 'epoch_time_sec': 19.79, 'lr': 0.00012491369829465126, 'train_loss': 0.011585, 'train_psnr': 25.1653, 'val_psnr': 24.0531, 'input_psnr': 23.1331, 'delta_psnr': 0.92, 'best_val_psnr': 24.0543}
# {'epoch': 5502, 'epoch_time_sec': 19.79, 'lr': 0.00012442292608938572, 'train_loss': 0.011569, 'train_psnr': 25.1723, 'val_psnr': 24.0533, 'input_psnr': 23.1331, 'delta_psnr': 0.9202, 'best_val_psnr': 24.0543}
# {'epoch': 5503, 'epoch_time_sec': 19.77, 'lr': 0.0001239284703413583, 'train_loss': 0.011574, 'train_psnr': 25.1678, 'val_psnr': 24.0533, 'input_psnr': 23.1331, 'delta_psnr': 0.9202, 'best_val_psnr': 24.0543}
# {'epoch': 5504, 'epoch_time_sec': 19.8, 'lr': 0.00012343037205076978, 'train_loss': 0.011584, 'train_psnr': 25.1626, 'val_psnr': 24.0532, 'input_psnr': 23.1331, 'delta_psnr': 0.9202, 'best_val_psnr': 24.0543}
# {'epoch': 5505, 'epoch_time_sec': 19.79, 'lr': 0.00012292867251986015, 'train_loss': 0.011572, 'train_psnr': 25.1699, 'val_psnr': 24.0533, 'input_psnr': 23.1331, 'delta_psnr': 0.9202, 'best_val_psnr': 24.0543}
# {'epoch': 5506, 'epoch_time_sec': 19.77, 'lr': 0.0001224234133494837, 'train_loss': 0.011565, 'train_psnr': 25.1732, 'val_psnr': 24.0535, 'input_psnr': 23.1331, 'delta_psnr': 0.9204, 'best_val_psnr': 24.0543}
# {'epoch': 5507, 'epoch_time_sec': 19.79, 'lr': 0.00012191463643565957, 'train_loss': 0.011569, 'train_psnr': 25.1694, 'val_psnr': 24.0537, 'input_psnr': 23.1331, 'delta_psnr': 0.9206, 'best_val_psnr': 24.0543}
# {'epoch': 5508, 'epoch_time_sec': 19.82, 'lr': 0.00012140238396609762, 'train_loss': 0.011577, 'train_psnr': 25.1681, 'val_psnr': 24.0539, 'input_psnr': 23.1331, 'delta_psnr': 0.9208, 'best_val_psnr': 24.0543}
# {'epoch': 5509, 'epoch_time_sec': 19.77, 'lr': 0.00012088669841670032, 'train_loss': 0.011582, 'train_psnr': 25.1642, 'val_psnr': 24.0537, 'input_psnr': 23.1331, 'delta_psnr': 0.9206, 'best_val_psnr': 24.0543}
# {'epoch': 5510, 'epoch_time_sec': 19.81, 'lr': 0.0001203676225480407, 'train_loss': 0.011578, 'train_psnr': 25.164, 'val_psnr': 24.0536, 'input_psnr': 23.1331, 'delta_psnr': 0.9206, 'best_val_psnr': 24.0543}
# {'epoch': 5511, 'epoch_time_sec': 19.79, 'lr': 0.00011984519940181646, 'train_loss': 0.011567, 'train_psnr': 25.1726, 'val_psnr': 24.0537, 'input_psnr': 23.1331, 'delta_psnr': 0.9206, 'best_val_psnr': 24.0543}
# {'epoch': 5512, 'epoch_time_sec': 19.82, 'lr': 0.0001193194722972812, 'train_loss': 0.011576, 'train_psnr': 25.1696, 'val_psnr': 24.0538, 'input_psnr': 23.1331, 'delta_psnr': 0.9207, 'best_val_psnr': 24.0543}
# {'epoch': 5513, 'epoch_time_sec': 19.77, 'lr': 0.00011879048482765223, 'train_loss': 0.01157, 'train_psnr': 25.1697, 'val_psnr': 24.0538, 'input_psnr': 23.1331, 'delta_psnr': 0.9208, 'best_val_psnr': 24.0543}
# {'epoch': 5514, 'epoch_time_sec': 19.8, 'lr': 0.00011825828085649585, 'train_loss': 0.011568, 'train_psnr': 25.1704, 'val_psnr': 24.0536, 'input_psnr': 23.1331, 'delta_psnr': 0.9205, 'best_val_psnr': 24.0543}
# {'epoch': 5515, 'epoch_time_sec': 19.78, 'lr': 0.00011772290451409028, 'train_loss': 0.01157, 'train_psnr': 25.1713, 'val_psnr': 24.0536, 'input_psnr': 23.1331, 'delta_psnr': 0.9206, 'best_val_psnr': 24.0543}
# {'epoch': 5516, 'epoch_time_sec': 19.74, 'lr': 0.00011718440019376622, 'train_loss': 0.011576, 'train_psnr': 25.1653, 'val_psnr': 24.0537, 'input_psnr': 23.1331, 'delta_psnr': 0.9207, 'best_val_psnr': 24.0543}
# {'epoch': 5517, 'epoch_time_sec': 19.77, 'lr': 0.00011664281254822597, 'train_loss': 0.011566, 'train_psnr': 25.1724, 'val_psnr': 24.0536, 'input_psnr': 23.1331, 'delta_psnr': 0.9205, 'best_val_psnr': 24.0543}
# {'epoch': 5518, 'epoch_time_sec': 19.8, 'lr': 0.00011609818648584063, 'train_loss': 0.01158, 'train_psnr': 25.1659, 'val_psnr': 24.0537, 'input_psnr': 23.1331, 'delta_psnr': 0.9206, 'best_val_psnr': 24.0543}
# {'epoch': 5519, 'epoch_time_sec': 19.78, 'lr': 0.00011555056716692642, 'train_loss': 0.011587, 'train_psnr': 25.1628, 'val_psnr': 24.0537, 'input_psnr': 23.1331, 'delta_psnr': 0.9207, 'best_val_psnr': 24.0543}
# {'epoch': 5520, 'epoch_time_sec': 19.79, 'lr': 0.00011499999999999999, 'train_loss': 0.011583, 'train_psnr': 25.1636, 'val_psnr': 24.0538, 'input_psnr': 23.1331, 'delta_psnr': 0.9208, 'best_val_psnr': 24.0543}
# {'epoch': 5521, 'epoch_time_sec': 19.8, 'lr': 0.00011444653063801314, 'train_loss': 0.011565, 'train_psnr': 25.1725, 'val_psnr': 24.054, 'input_psnr': 23.1331, 'delta_psnr': 0.9209, 'best_val_psnr': 24.0543}
# {'epoch': 5522, 'epoch_time_sec': 19.76, 'lr': 0.00011389020497456722, 'train_loss': 0.01156, 'train_psnr': 25.1761, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0543}
# {'epoch': 5523, 'epoch_time_sec': 19.75, 'lr': 0.00011333106914010777, 'train_loss': 0.011586, 'train_psnr': 25.1615, 'val_psnr': 24.0541, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0543}
# {'epoch': 5524, 'epoch_time_sec': 19.81, 'lr': 0.00011276916949809924, 'train_loss': 0.011568, 'train_psnr': 25.1715, 'val_psnr': 24.0543, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0543}
# {'epoch': 5525, 'epoch_time_sec': 19.81, 'lr': 0.00011220455264118065, 'train_loss': 0.011568, 'train_psnr': 25.1717, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9211, 'best_val_psnr': 24.0543}
# {'epoch': 5526, 'epoch_time_sec': 19.8, 'lr': 0.00011163726538730209, 'train_loss': 0.011567, 'train_psnr': 25.1714, 'val_psnr': 24.0543, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0543}
# {'epoch': 5527, 'epoch_time_sec': 19.78, 'lr': 0.0001110673547758426, 'train_loss': 0.011576, 'train_psnr': 25.166, 'val_psnr': 24.0543, 'input_psnr': 23.1331, 'delta_psnr': 0.9213, 'best_val_psnr': 24.0543}
# {'epoch': 5528, 'epoch_time_sec': 19.76, 'lr': 0.00011049486806370963, 'train_loss': 0.011575, 'train_psnr': 25.1676, 'val_psnr': 24.0543, 'input_psnr': 23.1331, 'delta_psnr': 0.9213, 'best_val_psnr': 24.0543}
# {'epoch': 5529, 'epoch_time_sec': 19.76, 'lr': 0.00010991985272142059, 'train_loss': 0.011567, 'train_psnr': 25.174, 'val_psnr': 24.0544, 'input_psnr': 23.1331, 'delta_psnr': 0.9214, 'best_val_psnr': 24.0544}
# {'epoch': 5530, 'epoch_time_sec': 19.79, 'lr': 0.00010934235642916648, 'train_loss': 0.011569, 'train_psnr': 25.1691, 'val_psnr': 24.0544, 'input_psnr': 23.1331, 'delta_psnr': 0.9214, 'best_val_psnr': 24.0544}
# {'epoch': 5531, 'epoch_time_sec': 19.79, 'lr': 0.00010876242707285837, 'train_loss': 0.01157, 'train_psnr': 25.1715, 'val_psnr': 24.0545, 'input_psnr': 23.1331, 'delta_psnr': 0.9215, 'best_val_psnr': 24.0545}
# {'epoch': 5532, 'epoch_time_sec': 19.76, 'lr': 0.0001081801127401566, 'train_loss': 0.011562, 'train_psnr': 25.1741, 'val_psnr': 24.0546, 'input_psnr': 23.1331, 'delta_psnr': 0.9215, 'best_val_psnr': 24.0546}
# {'epoch': 5533, 'epoch_time_sec': 19.81, 'lr': 0.00010759546171648352, 'train_loss': 0.011566, 'train_psnr': 25.1725, 'val_psnr': 24.0546, 'input_psnr': 23.1331, 'delta_psnr': 0.9215, 'best_val_psnr': 24.0546}
# {'epoch': 5534, 'epoch_time_sec': 19.81, 'lr': 0.00010700852248101947, 'train_loss': 0.011575, 'train_psnr': 25.1702, 'val_psnr': 24.0545, 'input_psnr': 23.1331, 'delta_psnr': 0.9215, 'best_val_psnr': 24.0546}
# {'epoch': 5535, 'epoch_time_sec': 19.8, 'lr': 0.00010641934370268299, 'train_loss': 0.011558, 'train_psnr': 25.1761, 'val_psnr': 24.0546, 'input_psnr': 23.1331, 'delta_psnr': 0.9216, 'best_val_psnr': 24.0546}
# {'epoch': 5536, 'epoch_time_sec': 19.78, 'lr': 0.00010582797423609528, 'train_loss': 0.011562, 'train_psnr': 25.1751, 'val_psnr': 24.0546, 'input_psnr': 23.1331, 'delta_psnr': 0.9215, 'best_val_psnr': 24.0546}
# {'epoch': 5537, 'epoch_time_sec': 19.78, 'lr': 0.00010523446311752902, 'train_loss': 0.011565, 'train_psnr': 25.1737, 'val_psnr': 24.0547, 'input_psnr': 23.1331, 'delta_psnr': 0.9217, 'best_val_psnr': 24.0547}
# {'epoch': 5538, 'epoch_time_sec': 19.78, 'lr': 0.00010463885956084241, 'train_loss': 0.011577, 'train_psnr': 25.1684, 'val_psnr': 24.0548, 'input_psnr': 23.1331, 'delta_psnr': 0.9217, 'best_val_psnr': 24.0548}
# {'epoch': 5539, 'epoch_time_sec': 19.8, 'lr': 0.00010404121295339829, 'train_loss': 0.011565, 'train_psnr': 25.175, 'val_psnr': 24.0548, 'input_psnr': 23.1331, 'delta_psnr': 0.9217, 'best_val_psnr': 24.0548}
# {'epoch': 5540, 'epoch_time_sec': 19.79, 'lr': 0.00010344157285196901, 'train_loss': 0.011564, 'train_psnr': 25.174, 'val_psnr': 24.0549, 'input_psnr': 23.1331, 'delta_psnr': 0.9219, 'best_val_psnr': 24.0549}
# {'epoch': 5541, 'epoch_time_sec': 19.8, 'lr': 0.0001028399889786272, 'train_loss': 0.011576, 'train_psnr': 25.1696, 'val_psnr': 24.0549, 'input_psnr': 23.1331, 'delta_psnr': 0.9219, 'best_val_psnr': 24.0549}
# {'epoch': 5542, 'epoch_time_sec': 19.79, 'lr': 0.00010223651121662267, 'train_loss': 0.011564, 'train_psnr': 25.1742, 'val_psnr': 24.055, 'input_psnr': 23.1331, 'delta_psnr': 0.9219, 'best_val_psnr': 24.055}
# {'epoch': 5543, 'epoch_time_sec': 19.77, 'lr': 0.00010163118960624632, 'train_loss': 0.011561, 'train_psnr': 25.1758, 'val_psnr': 24.0551, 'input_psnr': 23.1331, 'delta_psnr': 0.922, 'best_val_psnr': 24.0551}
# {'epoch': 5544, 'epoch_time_sec': 19.8, 'lr': 0.00010102407434068063, 'train_loss': 0.011566, 'train_psnr': 25.1729, 'val_psnr': 24.055, 'input_psnr': 23.1331, 'delta_psnr': 0.9219, 'best_val_psnr': 24.0551}
# {'epoch': 5545, 'epoch_time_sec': 19.77, 'lr': 0.00010041521576183774, 'train_loss': 0.011561, 'train_psnr': 25.1754, 'val_psnr': 24.0551, 'input_psnr': 23.1331, 'delta_psnr': 0.9221, 'best_val_psnr': 24.0551}
# {'epoch': 5546, 'epoch_time_sec': 19.76, 'lr': 9.980466435618509e-05, 'train_loss': 0.011564, 'train_psnr': 25.1724, 'val_psnr': 24.0552, 'input_psnr': 23.1331, 'delta_psnr': 0.9221, 'best_val_psnr': 24.0552}
# {'epoch': 5547, 'epoch_time_sec': 19.82, 'lr': 9.919247075055907e-05, 'train_loss': 0.011566, 'train_psnr': 25.1732, 'val_psnr': 24.0552, 'input_psnr': 23.1331, 'delta_psnr': 0.9221, 'best_val_psnr': 24.0552}
# {'epoch': 5548, 'epoch_time_sec': 19.81, 'lr': 9.857868570796706e-05, 'train_loss': 0.011557, 'train_psnr': 25.178, 'val_psnr': 24.0551, 'input_psnr': 23.1331, 'delta_psnr': 0.922, 'best_val_psnr': 24.0552}
# {'epoch': 5549, 'epoch_time_sec': 19.82, 'lr': 9.796336012337815e-05, 'train_loss': 0.011564, 'train_psnr': 25.1743, 'val_psnr': 24.0551, 'input_psnr': 23.1331, 'delta_psnr': 0.922, 'best_val_psnr': 24.0552}
# {'epoch': 5550, 'epoch_time_sec': 19.76, 'lr': 9.734654501950298e-05, 'train_loss': 0.01155, 'train_psnr': 25.1805, 'val_psnr': 24.0551, 'input_psnr': 23.1331, 'delta_psnr': 0.9221, 'best_val_psnr': 24.0552}
# {'epoch': 5551, 'epoch_time_sec': 19.79, 'lr': 9.672829154256293e-05, 'train_loss': 0.011563, 'train_psnr': 25.1724, 'val_psnr': 24.0552, 'input_psnr': 23.1331, 'delta_psnr': 0.9221, 'best_val_psnr': 24.0552}
# {'epoch': 5552, 'epoch_time_sec': 19.79, 'lr': 9.610865095804904e-05, 'train_loss': 0.011556, 'train_psnr': 25.1787, 'val_psnr': 24.0554, 'input_psnr': 23.1331, 'delta_psnr': 0.9223, 'best_val_psnr': 24.0554}
# {'epoch': 5553, 'epoch_time_sec': 19.82, 'lr': 9.548767464647114e-05, 'train_loss': 0.011572, 'train_psnr': 25.172, 'val_psnr': 24.0554, 'input_psnr': 23.1331, 'delta_psnr': 0.9223, 'best_val_psnr': 24.0554}
# {'epoch': 5554, 'epoch_time_sec': 19.8, 'lr': 9.486541409909732e-05, 'train_loss': 0.011554, 'train_psnr': 25.1815, 'val_psnr': 24.0555, 'input_psnr': 23.1331, 'delta_psnr': 0.9224, 'best_val_psnr': 24.0555}
# {'epoch': 5555, 'epoch_time_sec': 19.8, 'lr': 9.424192091368436e-05, 'train_loss': 0.011564, 'train_psnr': 25.1767, 'val_psnr': 24.0556, 'input_psnr': 23.1331, 'delta_psnr': 0.9225, 'best_val_psnr': 24.0556}
# {'epoch': 5556, 'epoch_time_sec': 19.78, 'lr': 9.361724679019922e-05, 'train_loss': 0.011565, 'train_psnr': 25.173, 'val_psnr': 24.0554, 'input_psnr': 23.1331, 'delta_psnr': 0.9223, 'best_val_psnr': 24.0556}
# {'epoch': 5557, 'epoch_time_sec': 19.78, 'lr': 9.299144352653203e-05, 'train_loss': 0.011552, 'train_psnr': 25.1797, 'val_psnr': 24.0555, 'input_psnr': 23.1331, 'delta_psnr': 0.9224, 'best_val_psnr': 24.0556}
# {'epoch': 5558, 'epoch_time_sec': 19.8, 'lr': 9.236456301420112e-05, 'train_loss': 0.011577, 'train_psnr': 25.1691, 'val_psnr': 24.0555, 'input_psnr': 23.1331, 'delta_psnr': 0.9225, 'best_val_psnr': 24.0556}
# {'epoch': 5559, 'epoch_time_sec': 19.81, 'lr': 9.173665723405006e-05, 'train_loss': 0.011551, 'train_psnr': 25.1819, 'val_psnr': 24.0557, 'input_psnr': 23.1331, 'delta_psnr': 0.9227, 'best_val_psnr': 24.0557}
# {'epoch': 5560, 'epoch_time_sec': 19.78, 'lr': 9.110777825193759e-05, 'train_loss': 0.011558, 'train_psnr': 25.1785, 'val_psnr': 24.0558, 'input_psnr': 23.1331, 'delta_psnr': 0.9227, 'best_val_psnr': 24.0558}
# {'epoch': 5561, 'epoch_time_sec': 19.77, 'lr': 9.047797821442009e-05, 'train_loss': 0.011554, 'train_psnr': 25.1785, 'val_psnr': 24.0558, 'input_psnr': 23.1331, 'delta_psnr': 0.9227, 'best_val_psnr': 24.0558}
# {'epoch': 5562, 'epoch_time_sec': 19.81, 'lr': 8.984730934442782e-05, 'train_loss': 0.011554, 'train_psnr': 25.1796, 'val_psnr': 24.0559, 'input_psnr': 23.1331, 'delta_psnr': 0.9228, 'best_val_psnr': 24.0559}
# {'epoch': 5563, 'epoch_time_sec': 19.82, 'lr': 8.921582393693446e-05, 'train_loss': 0.011577, 'train_psnr': 25.1685, 'val_psnr': 24.0558, 'input_psnr': 23.1331, 'delta_psnr': 0.9228, 'best_val_psnr': 24.0559}
# {'epoch': 5564, 'epoch_time_sec': 19.8, 'lr': 8.858357435462089e-05, 'train_loss': 0.01155, 'train_psnr': 25.1819, 'val_psnr': 24.0558, 'input_psnr': 23.1331, 'delta_psnr': 0.9227, 'best_val_psnr': 24.0559}
# {'epoch': 5565, 'epoch_time_sec': 19.77, 'lr': 8.795061302353323e-05, 'train_loss': 0.011548, 'train_psnr': 25.1824, 'val_psnr': 24.0559, 'input_psnr': 23.1331, 'delta_psnr': 0.9228, 'best_val_psnr': 24.0559}
# {'epoch': 5566, 'epoch_time_sec': 19.76, 'lr': 8.731699242873574e-05, 'train_loss': 0.011555, 'train_psnr': 25.1815, 'val_psnr': 24.056, 'input_psnr': 23.1331, 'delta_psnr': 0.923, 'best_val_psnr': 24.056}
# {'epoch': 5567, 'epoch_time_sec': 19.76, 'lr': 8.66827651099587e-05, 'train_loss': 0.011561, 'train_psnr': 25.177, 'val_psnr': 24.0561, 'input_psnr': 23.1331, 'delta_psnr': 0.923, 'best_val_psnr': 24.0561}
# {'epoch': 5568, 'epoch_time_sec': 19.74, 'lr': 8.60479836572419e-05, 'train_loss': 0.011566, 'train_psnr': 25.1735, 'val_psnr': 24.056, 'input_psnr': 23.1331, 'delta_psnr': 0.923, 'best_val_psnr': 24.0561}
# {'epoch': 5569, 'epoch_time_sec': 19.77, 'lr': 8.541270070657378e-05, 'train_loss': 0.011552, 'train_psnr': 25.1806, 'val_psnr': 24.056, 'input_psnr': 23.1331, 'delta_psnr': 0.923, 'best_val_psnr': 24.0561}
# {'epoch': 5570, 'epoch_time_sec': 19.85, 'lr': 8.477696893552696e-05, 'train_loss': 0.011549, 'train_psnr': 25.1814, 'val_psnr': 24.0561, 'input_psnr': 23.1331, 'delta_psnr': 0.9231, 'best_val_psnr': 24.0561}
# {'epoch': 5571, 'epoch_time_sec': 19.83, 'lr': 8.414084105889018e-05, 'train_loss': 0.011552, 'train_psnr': 25.1827, 'val_psnr': 24.0562, 'input_psnr': 23.1331, 'delta_psnr': 0.9231, 'best_val_psnr': 24.0562}
# {'epoch': 5572, 'epoch_time_sec': 19.78, 'lr': 8.350436982429724e-05, 'train_loss': 0.011563, 'train_psnr': 25.1781, 'val_psnr': 24.0562, 'input_psnr': 23.1331, 'delta_psnr': 0.9231, 'best_val_psnr': 24.0562}
# {'epoch': 5573, 'epoch_time_sec': 19.83, 'lr': 8.2867608007853e-05, 'train_loss': 0.011546, 'train_psnr': 25.1837, 'val_psnr': 24.0562, 'input_psnr': 23.1331, 'delta_psnr': 0.9231, 'best_val_psnr': 24.0562}
# {'epoch': 5574, 'epoch_time_sec': 19.78, 'lr': 8.223060840975746e-05, 'train_loss': 0.011553, 'train_psnr': 25.1782, 'val_psnr': 24.0562, 'input_psnr': 23.1331, 'delta_psnr': 0.9231, 'best_val_psnr': 24.0562}
# {'epoch': 5575, 'epoch_time_sec': 19.75, 'lr': 8.159342384992738e-05, 'train_loss': 0.01155, 'train_psnr': 25.1815, 'val_psnr': 24.0562, 'input_psnr': 23.1331, 'delta_psnr': 0.9231, 'best_val_psnr': 24.0562}
# {'epoch': 5576, 'epoch_time_sec': 19.76, 'lr': 8.095610716361657e-05, 'train_loss': 0.01155, 'train_psnr': 25.1815, 'val_psnr': 24.0562, 'input_psnr': 23.1331, 'delta_psnr': 0.9231, 'best_val_psnr': 24.0562}
# {'epoch': 5577, 'epoch_time_sec': 19.78, 'lr': 8.031871119703468e-05, 'train_loss': 0.011563, 'train_psnr': 25.1774, 'val_psnr': 24.0563, 'input_psnr': 23.1331, 'delta_psnr': 0.9232, 'best_val_psnr': 24.0563}
# {'epoch': 5578, 'epoch_time_sec': 19.83, 'lr': 7.96812888029653e-05, 'train_loss': 0.011557, 'train_psnr': 25.178, 'val_psnr': 24.0562, 'input_psnr': 23.1331, 'delta_psnr': 0.9232, 'best_val_psnr': 24.0563}
# {'epoch': 5579, 'epoch_time_sec': 19.79, 'lr': 7.904389283638343e-05, 'train_loss': 0.011551, 'train_psnr': 25.1814, 'val_psnr': 24.0561, 'input_psnr': 23.1331, 'delta_psnr': 0.923, 'best_val_psnr': 24.0563}
# {'epoch': 5580, 'epoch_time_sec': 19.79, 'lr': 7.840657615007259e-05, 'train_loss': 0.011544, 'train_psnr': 25.186, 'val_psnr': 24.0564, 'input_psnr': 23.1331, 'delta_psnr': 0.9233, 'best_val_psnr': 24.0564}
# {'epoch': 5581, 'epoch_time_sec': 19.75, 'lr': 7.776939159024253e-05, 'train_loss': 0.011542, 'train_psnr': 25.1875, 'val_psnr': 24.0565, 'input_psnr': 23.1331, 'delta_psnr': 0.9234, 'best_val_psnr': 24.0565}
# {'epoch': 5582, 'epoch_time_sec': 19.79, 'lr': 7.713239199214699e-05, 'train_loss': 0.011547, 'train_psnr': 25.182, 'val_psnr': 24.0564, 'input_psnr': 23.1331, 'delta_psnr': 0.9233, 'best_val_psnr': 24.0565}
# {'epoch': 5583, 'epoch_time_sec': 19.84, 'lr': 7.649563017570278e-05, 'train_loss': 0.011548, 'train_psnr': 25.185, 'val_psnr': 24.0564, 'input_psnr': 23.1331, 'delta_psnr': 0.9233, 'best_val_psnr': 24.0565}
# {'epoch': 5584, 'epoch_time_sec': 19.81, 'lr': 7.585915894110979e-05, 'train_loss': 0.011563, 'train_psnr': 25.1746, 'val_psnr': 24.0563, 'input_psnr': 23.1331, 'delta_psnr': 0.9232, 'best_val_psnr': 24.0565}
# {'epoch': 5585, 'epoch_time_sec': 19.8, 'lr': 7.522303106447304e-05, 'train_loss': 0.011563, 'train_psnr': 25.1764, 'val_psnr': 24.0563, 'input_psnr': 23.1331, 'delta_psnr': 0.9233, 'best_val_psnr': 24.0565}
# {'epoch': 5586, 'epoch_time_sec': 19.75, 'lr': 7.458729929342622e-05, 'train_loss': 0.01156, 'train_psnr': 25.1775, 'val_psnr': 24.0563, 'input_psnr': 23.1331, 'delta_psnr': 0.9233, 'best_val_psnr': 24.0565}
# {'epoch': 5587, 'epoch_time_sec': 19.8, 'lr': 7.39520163427581e-05, 'train_loss': 0.011547, 'train_psnr': 25.1829, 'val_psnr': 24.0564, 'input_psnr': 23.1331, 'delta_psnr': 0.9234, 'best_val_psnr': 24.0565}
# {'epoch': 5588, 'epoch_time_sec': 19.78, 'lr': 7.331723489004129e-05, 'train_loss': 0.011548, 'train_psnr': 25.1823, 'val_psnr': 24.0565, 'input_psnr': 23.1331, 'delta_psnr': 0.9235, 'best_val_psnr': 24.0565}
# {'epoch': 5589, 'epoch_time_sec': 19.77, 'lr': 7.268300757126426e-05, 'train_loss': 0.011544, 'train_psnr': 25.185, 'val_psnr': 24.0566, 'input_psnr': 23.1331, 'delta_psnr': 0.9235, 'best_val_psnr': 24.0566}
# {'epoch': 5590, 'epoch_time_sec': 19.79, 'lr': 7.204938697646674e-05, 'train_loss': 0.011548, 'train_psnr': 25.1841, 'val_psnr': 24.0567, 'input_psnr': 23.1331, 'delta_psnr': 0.9236, 'best_val_psnr': 24.0567}
# {'epoch': 5591, 'epoch_time_sec': 19.77, 'lr': 7.141642564537911e-05, 'train_loss': 0.011553, 'train_psnr': 25.1806, 'val_psnr': 24.0566, 'input_psnr': 23.1331, 'delta_psnr': 0.9236, 'best_val_psnr': 24.0567}
# {'epoch': 5592, 'epoch_time_sec': 19.75, 'lr': 7.078417606306551e-05, 'train_loss': 0.011548, 'train_psnr': 25.1836, 'val_psnr': 24.0567, 'input_psnr': 23.1331, 'delta_psnr': 0.9236, 'best_val_psnr': 24.0567}
# {'epoch': 5593, 'epoch_time_sec': 19.79, 'lr': 7.015269065557216e-05, 'train_loss': 0.011551, 'train_psnr': 25.1819, 'val_psnr': 24.0566, 'input_psnr': 23.1331, 'delta_psnr': 0.9236, 'best_val_psnr': 24.0567}
# {'epoch': 5594, 'epoch_time_sec': 19.82, 'lr': 6.952202178557992e-05, 'train_loss': 0.01156, 'train_psnr': 25.1791, 'val_psnr': 24.0567, 'input_psnr': 23.1331, 'delta_psnr': 0.9236, 'best_val_psnr': 24.0567}
# {'epoch': 5595, 'epoch_time_sec': 19.78, 'lr': 6.889222174806241e-05, 'train_loss': 0.011553, 'train_psnr': 25.183, 'val_psnr': 24.0569, 'input_psnr': 23.1331, 'delta_psnr': 0.9238, 'best_val_psnr': 24.0569}
# {'epoch': 5596, 'epoch_time_sec': 19.75, 'lr': 6.826334276594993e-05, 'train_loss': 0.011558, 'train_psnr': 25.1819, 'val_psnr': 24.057, 'input_psnr': 23.1331, 'delta_psnr': 0.9239, 'best_val_psnr': 24.057}
# {'epoch': 5597, 'epoch_time_sec': 19.78, 'lr': 6.763543698579888e-05, 'train_loss': 0.011569, 'train_psnr': 25.177, 'val_psnr': 24.0571, 'input_psnr': 23.1331, 'delta_psnr': 0.924, 'best_val_psnr': 24.0571}
# {'epoch': 5598, 'epoch_time_sec': 19.75, 'lr': 6.700855647346798e-05, 'train_loss': 0.011559, 'train_psnr': 25.1795, 'val_psnr': 24.0571, 'input_psnr': 23.1331, 'delta_psnr': 0.924, 'best_val_psnr': 24.0571}
# {'epoch': 5599, 'epoch_time_sec': 19.78, 'lr': 6.638275320980078e-05, 'train_loss': 0.011544, 'train_psnr': 25.184, 'val_psnr': 24.0572, 'input_psnr': 23.1331, 'delta_psnr': 0.9241, 'best_val_psnr': 24.0572}
# {'epoch': 5600, 'epoch_time_sec': 19.76, 'lr': 6.575807908631565e-05, 'train_loss': 0.01155, 'train_psnr': 25.1833, 'val_psnr': 24.0573, 'input_psnr': 23.1331, 'delta_psnr': 0.9242, 'best_val_psnr': 24.0573}
# {'epoch': 5601, 'epoch_time_sec': 19.75, 'lr': 6.513458590090268e-05, 'train_loss': 0.011555, 'train_psnr': 25.1802, 'val_psnr': 24.0573, 'input_psnr': 23.1331, 'delta_psnr': 0.9242, 'best_val_psnr': 24.0573}
# {'epoch': 5602, 'epoch_time_sec': 19.79, 'lr': 6.451232535352888e-05, 'train_loss': 0.011545, 'train_psnr': 25.1863, 'val_psnr': 24.0573, 'input_psnr': 23.1331, 'delta_psnr': 0.9242, 'best_val_psnr': 24.0573}
# {'epoch': 5603, 'epoch_time_sec': 19.8, 'lr': 6.389134904195096e-05, 'train_loss': 0.011548, 'train_psnr': 25.184, 'val_psnr': 24.0573, 'input_psnr': 23.1331, 'delta_psnr': 0.9243, 'best_val_psnr': 24.0573}
# {'epoch': 5604, 'epoch_time_sec': 19.82, 'lr': 6.327170845743707e-05, 'train_loss': 0.011544, 'train_psnr': 25.1841, 'val_psnr': 24.0573, 'input_psnr': 23.1331, 'delta_psnr': 0.9242, 'best_val_psnr': 24.0573}
# {'epoch': 5605, 'epoch_time_sec': 19.74, 'lr': 6.265345498049701e-05, 'train_loss': 0.011532, 'train_psnr': 25.1922, 'val_psnr': 24.0575, 'input_psnr': 23.1331, 'delta_psnr': 0.9244, 'best_val_psnr': 24.0575}
# {'epoch': 5606, 'epoch_time_sec': 19.76, 'lr': 6.203663987662186e-05, 'train_loss': 0.011538, 'train_psnr': 25.1898, 'val_psnr': 24.0575, 'input_psnr': 23.1331, 'delta_psnr': 0.9244, 'best_val_psnr': 24.0575}
# {'epoch': 5607, 'epoch_time_sec': 19.72, 'lr': 6.142131429203293e-05, 'train_loss': 0.011559, 'train_psnr': 25.1773, 'val_psnr': 24.0575, 'input_psnr': 23.1331, 'delta_psnr': 0.9245, 'best_val_psnr': 24.0575}
# {'epoch': 5608, 'epoch_time_sec': 19.75, 'lr': 6.0807529249440926e-05, 'train_loss': 0.011531, 'train_psnr': 25.1913, 'val_psnr': 24.0574, 'input_psnr': 23.1331, 'delta_psnr': 0.9244, 'best_val_psnr': 24.0575}
# {'epoch': 5609, 'epoch_time_sec': 19.77, 'lr': 6.019533564381489e-05, 'train_loss': 0.011537, 'train_psnr': 25.1882, 'val_psnr': 24.0575, 'input_psnr': 23.1331, 'delta_psnr': 0.9245, 'best_val_psnr': 24.0575}
# {'epoch': 5610, 'epoch_time_sec': 19.77, 'lr': 5.958478423816225e-05, 'train_loss': 0.011532, 'train_psnr': 25.193, 'val_psnr': 24.0576, 'input_psnr': 23.1331, 'delta_psnr': 0.9245, 'best_val_psnr': 24.0576}
# {'epoch': 5611, 'epoch_time_sec': 19.77, 'lr': 5.897592565931936e-05, 'train_loss': 0.011542, 'train_psnr': 25.1854, 'val_psnr': 24.0576, 'input_psnr': 23.1331, 'delta_psnr': 0.9246, 'best_val_psnr': 24.0576}
# {'epoch': 5612, 'epoch_time_sec': 19.76, 'lr': 5.8368810393753684e-05, 'train_loss': 0.011545, 'train_psnr': 25.1837, 'val_psnr': 24.0578, 'input_psnr': 23.1331, 'delta_psnr': 0.9248, 'best_val_psnr': 24.0578}
# {'epoch': 5613, 'epoch_time_sec': 19.77, 'lr': 5.7763488783377314e-05, 'train_loss': 0.011529, 'train_psnr': 25.1948, 'val_psnr': 24.0576, 'input_psnr': 23.1331, 'delta_psnr': 0.9246, 'best_val_psnr': 24.0578}
# {'epoch': 5614, 'epoch_time_sec': 19.77, 'lr': 5.71600110213728e-05, 'train_loss': 0.011554, 'train_psnr': 25.1829, 'val_psnr': 24.0577, 'input_psnr': 23.1331, 'delta_psnr': 0.9246, 'best_val_psnr': 24.0578}
# {'epoch': 5615, 'epoch_time_sec': 19.76, 'lr': 5.6558427148030965e-05, 'train_loss': 0.011544, 'train_psnr': 25.1849, 'val_psnr': 24.0577, 'input_psnr': 23.1331, 'delta_psnr': 0.9246, 'best_val_psnr': 24.0578}
# {'epoch': 5616, 'epoch_time_sec': 19.84, 'lr': 5.595878704660171e-05, 'train_loss': 0.011532, 'train_psnr': 25.1936, 'val_psnr': 24.0578, 'input_psnr': 23.1331, 'delta_psnr': 0.9247, 'best_val_psnr': 24.0578}
# {'epoch': 5617, 'epoch_time_sec': 19.78, 'lr': 5.536114043915759e-05, 'train_loss': 0.01154, 'train_psnr': 25.189, 'val_psnr': 24.0578, 'input_psnr': 23.1331, 'delta_psnr': 0.9247, 'best_val_psnr': 24.0578}
# {'epoch': 5618, 'epoch_time_sec': 19.75, 'lr': 5.476553688247097e-05, 'train_loss': 0.011545, 'train_psnr': 25.1869, 'val_psnr': 24.0579, 'input_psnr': 23.1331, 'delta_psnr': 0.9248, 'best_val_psnr': 24.0579}
# {'epoch': 5619, 'epoch_time_sec': 19.76, 'lr': 5.417202576390469e-05, 'train_loss': 0.011526, 'train_psnr': 25.1972, 'val_psnr': 24.0579, 'input_psnr': 23.1331, 'delta_psnr': 0.9248, 'best_val_psnr': 24.0579}
# {'epoch': 5620, 'epoch_time_sec': 19.77, 'lr': 5.3580656297316994e-05, 'train_loss': 0.011532, 'train_psnr': 25.1928, 'val_psnr': 24.0579, 'input_psnr': 23.1331, 'delta_psnr': 0.9248, 'best_val_psnr': 24.0579}
# {'epoch': 5621, 'epoch_time_sec': 19.81, 'lr': 5.299147751898051e-05, 'train_loss': 0.011534, 'train_psnr': 25.1916, 'val_psnr': 24.0579, 'input_psnr': 23.1331, 'delta_psnr': 0.9249, 'best_val_psnr': 24.0579}
# {'epoch': 5622, 'epoch_time_sec': 19.78, 'lr': 5.240453828351646e-05, 'train_loss': 0.011542, 'train_psnr': 25.1873, 'val_psnr': 24.0581, 'input_psnr': 23.1331, 'delta_psnr': 0.9251, 'best_val_psnr': 24.0581}
# {'epoch': 5623, 'epoch_time_sec': 19.8, 'lr': 5.181988725984336e-05, 'train_loss': 0.011533, 'train_psnr': 25.1918, 'val_psnr': 24.058, 'input_psnr': 23.1331, 'delta_psnr': 0.925, 'best_val_psnr': 24.0581}
# {'epoch': 5624, 'epoch_time_sec': 19.82, 'lr': 5.1237572927141626e-05, 'train_loss': 0.011533, 'train_psnr': 25.1904, 'val_psnr': 24.0581, 'input_psnr': 23.1331, 'delta_psnr': 0.925, 'best_val_psnr': 24.0581}
# ...
# {'epoch': 5675, 'epoch_time_sec': 19.76, 'lr': 2.5700209650690608e-05, 'train_loss': 0.011529, 'train_psnr': 25.1939, 'val_psnr': 24.0591, 'input_psnr': 23.1331, 'delta_psnr': 0.926, 'best_val_psnr': 24.0591}
# {'epoch': 5676, 'epoch_time_sec': 19.78, 'lr': 2.5300195497365006e-05, 'train_loss': 0.011528, 'train_psnr': 25.1957, 'val_psnr': 24.0591, 'input_psnr': 23.1331, 'delta_psnr': 0.9261, 'best_val_psnr': 24.0591}
# {'epoch': 5677, 'epoch_time_sec': 19.77, 'lr': 2.4904717044108914e-05, 'train_loss': 0.011531, 'train_psnr': 25.1931, 'val_psnr': 24.0591, 'input_psnr': 23.1331, 'delta_psnr': 0.9261, 'best_val_psnr': 24.0591}
# {'epoch': 5678, 'epoch_time_sec': 19.8, 'lr': 2.4513807083939937e-05, 'train_loss': 0.011526, 'train_psnr': 25.1969, 'val_psnr': 24.0592, 'input_psnr': 23.1331, 'delta_psnr': 0.9261, 'best_val_psnr': 24.0592}
# {'epoch': 5679, 'epoch_time_sec': 19.78, 'lr': 2.4127498031056738e-05, 'train_loss': 0.011524, 'train_psnr': 25.1962, 'val_psnr': 24.0592, 'input_psnr': 23.1331, 'delta_psnr': 0.9261, 'best_val_psnr': 24.0592}
# {'epoch': 5680, 'epoch_time_sec': 19.75, 'lr': 2.3745821918151524e-05, 'train_loss': 0.011525, 'train_psnr': 25.1957, 'val_psnr': 24.0592, 'input_psnr': 23.1331, 'delta_psnr': 0.9261, 'best_val_psnr': 24.0592}
# {'epoch': 5681, 'epoch_time_sec': 19.79, 'lr': 2.3368810393753687e-05, 'train_loss': 0.011521, 'train_psnr': 25.1999, 'val_psnr': 24.0592, 'input_psnr': 23.1331, 'delta_psnr': 0.9262, 'best_val_psnr': 24.0592}
# {'epoch': 5682, 'epoch_time_sec': 19.78, 'lr': 2.299649471960561e-05, 'train_loss': 0.01152, 'train_psnr': 25.1984, 'val_psnr': 24.0592, 'input_psnr': 23.1331, 'delta_psnr': 0.9262, 'best_val_psnr': 24.0592}
# {'epoch': 5683, 'epoch_time_sec': 19.8, 'lr': 2.2628905768070445e-05, 'train_loss': 0.011526, 'train_psnr': 25.1977, 'val_psnr': 24.0592, 'input_psnr': 23.1331, 'delta_psnr': 0.9262, 'best_val_psnr': 24.0592}
# {'epoch': 5684, 'epoch_time_sec': 19.78, 'lr': 2.22660740195722e-05, 'train_loss': 0.011538, 'train_psnr': 25.195, 'val_psnr': 24.0593, 'input_psnr': 23.1331, 'delta_psnr': 0.9262, 'best_val_psnr': 24.0593}
# {'epoch': 5685, 'epoch_time_sec': 19.82, 'lr': 2.1908029560068248e-05, 'train_loss': 0.011534, 'train_psnr': 25.1933, 'val_psnr': 24.0593, 'input_psnr': 23.1331, 'delta_psnr': 0.9262, 'best_val_psnr': 24.0593}
# {'epoch': 5686, 'epoch_time_sec': 19.75, 'lr': 2.155480207855463e-05, 'train_loss': 0.011515, 'train_psnr': 25.202, 'val_psnr': 24.0593, 'input_psnr': 23.1331, 'delta_psnr': 0.9262, 'best_val_psnr': 24.0593}
# {'epoch': 5687, 'epoch_time_sec': 19.73, 'lr': 2.1206420864604245e-05, 'train_loss': 0.011525, 'train_psnr': 25.1951, 'val_psnr': 24.0595, 'input_psnr': 23.1331, 'delta_psnr': 0.9264, 'best_val_psnr': 24.0595}
# {'epoch': 5688, 'epoch_time_sec': 19.78, 'lr': 2.0862914805938224e-05, 'train_loss': 0.011528, 'train_psnr': 25.1951, 'val_psnr': 24.0593, 'input_psnr': 23.1331, 'delta_psnr': 0.9263, 'best_val_psnr': 24.0595}
# {'epoch': 5689, 'epoch_time_sec': 19.81, 'lr': 2.052431238603046e-05, 'train_loss': 0.011524, 'train_psnr': 25.2001, 'val_psnr': 24.0594, 'input_psnr': 23.1331, 'delta_psnr': 0.9263, 'best_val_psnr': 24.0595}
# {'epoch': 5690, 'epoch_time_sec': 19.79, 'lr': 2.01906416817458e-05, 'train_loss': 0.011517, 'train_psnr': 25.1993, 'val_psnr': 24.0593, 'input_psnr': 23.1331, 'delta_psnr': 0.9263, 'best_val_psnr': 24.0595}
# {'epoch': 5691, 'epoch_time_sec': 19.75, 'lr': 1.9861930361012004e-05, 'train_loss': 0.011538, 'train_psnr': 25.1895, 'val_psnr': 24.0593, 'input_psnr': 23.1331, 'delta_psnr': 0.9262, 'best_val_psnr': 24.0595}
# {'epoch': 5692, 'epoch_time_sec': 19.79, 'lr': 1.9538205680525327e-05, 'train_loss': 0.011522, 'train_psnr': 25.1998, 'val_psnr': 24.0592, 'input_psnr': 23.1331, 'delta_psnr': 0.9262, 'best_val_psnr': 24.0595}
# {'epoch': 5693, 'epoch_time_sec': 19.78, 'lr': 1.921949448349065e-05, 'train_loss': 0.011546, 'train_psnr': 25.19, 'val_psnr': 24.0592, 'input_psnr': 23.1331, 'delta_psnr': 0.9261, 'best_val_psnr': 24.0595}
# {'epoch': 5694, 'epoch_time_sec': 19.79, 'lr': 1.8905823197395405e-05, 'train_loss': 0.01152, 'train_psnr': 25.199, 'val_psnr': 24.0593, 'input_psnr': 23.1331, 'delta_psnr': 0.9262, 'best_val_psnr': 24.0595}
# {'epoch': 5695, 'epoch_time_sec': 19.81, 'lr': 1.85972178318184e-05, 'train_loss': 0.011517, 'train_psnr': 25.2003, 'val_psnr': 24.0593, 'input_psnr': 23.1331, 'delta_psnr': 0.9263, 'best_val_psnr': 24.0595}
# {'epoch': 5696, 'epoch_time_sec': 19.78, 'lr': 1.829370397627299e-05, 'train_loss': 0.011516, 'train_psnr': 25.2016, 'val_psnr': 24.0594, 'input_psnr': 23.1331, 'delta_psnr': 0.9263, 'best_val_psnr': 24.0595}
# {'epoch': 5697, 'epoch_time_sec': 19.78, 'lr': 1.7995306798085227e-05, 'train_loss': 0.011519, 'train_psnr': 25.1997, 'val_psnr': 24.0594, 'input_psnr': 23.1331, 'delta_psnr': 0.9264, 'best_val_psnr': 24.0595}
# {'epoch': 5698, 'epoch_time_sec': 19.75, 'lr': 1.7702051040307015e-05, 'train_loss': 0.011516, 'train_psnr': 25.2031, 'val_psnr': 24.0594, 'input_psnr': 23.1331, 'delta_psnr': 0.9264, 'best_val_psnr': 24.0595}
# {'epoch': 5699, 'epoch_time_sec': 19.75, 'lr': 1.741396101966442e-05, 'train_loss': 0.011511, 'train_psnr': 25.2055, 'val_psnr': 24.0595, 'input_psnr': 23.1331, 'delta_psnr': 0.9264, 'best_val_psnr': 24.0595}
# {'epoch': 5700, 'epoch_time_sec': 19.78, 'lr': 1.7131060624541278e-05, 'train_loss': 0.011524, 'train_psnr': 25.1974, 'val_psnr': 24.0594, 'input_psnr': 23.1331, 'delta_psnr': 0.9264, 'best_val_psnr': 24.0595}
# {'epoch': 5701, 'epoch_time_sec': 19.79, 'lr': 1.6853373312998433e-05, 'train_loss': 0.011532, 'train_psnr': 25.1962, 'val_psnr': 24.0595, 'input_psnr': 23.1331, 'delta_psnr': 0.9264, 'best_val_psnr': 24.0595}
# {'epoch': 5702, 'epoch_time_sec': 19.8, 'lr': 1.6580922110828558e-05, 'train_loss': 0.011533, 'train_psnr': 25.1938, 'val_psnr': 24.0595, 'input_psnr': 23.1331, 'delta_psnr': 0.9264, 'best_val_psnr': 24.0595}
# {'epoch': 5703, 'epoch_time_sec': 19.74, 'lr': 1.63137296096469e-05, 'train_loss': 0.011524, 'train_psnr': 25.1978, 'val_psnr': 24.0595, 'input_psnr': 23.1331, 'delta_psnr': 0.9264, 'best_val_psnr': 24.0595}
# {'epoch': 5704, 'epoch_time_sec': 19.75, 'lr': 1.6051817965017933e-05, 'train_loss': 0.011528, 'train_psnr': 25.1948, 'val_psnr': 24.0595, 'input_psnr': 23.1331, 'delta_psnr': 0.9265, 'best_val_psnr': 24.0595}
# {'epoch': 5705, 'epoch_time_sec': 19.77, 'lr': 1.5795208894618302e-05, 'train_loss': 0.011508, 'train_psnr': 25.2073, 'val_psnr': 24.0596, 'input_psnr': 23.1331, 'delta_psnr': 0.9265, 'best_val_psnr': 24.0596}
# {'epoch': 5706, 'epoch_time_sec': 19.79, 'lr': 1.554392367643585e-05, 'train_loss': 0.011516, 'train_psnr': 25.2006, 'val_psnr': 24.0595, 'input_psnr': 23.1331, 'delta_psnr': 0.9265, 'best_val_psnr': 24.0596}
# {'epoch': 5707, 'epoch_time_sec': 19.77, 'lr': 1.529798314700546e-05, 'train_loss': 0.011526, 'train_psnr': 25.1971, 'val_psnr': 24.0596, 'input_psnr': 23.1331, 'delta_psnr': 0.9265, 'best_val_psnr': 24.0596}
# {'epoch': 5708, 'epoch_time_sec': 19.78, 'lr': 1.505740769968108e-05, 'train_loss': 0.011512, 'train_psnr': 25.2055, 'val_psnr': 24.0596, 'input_psnr': 23.1331, 'delta_psnr': 0.9265, 'best_val_psnr': 24.0596}
# {'epoch': 5709, 'epoch_time_sec': 19.83, 'lr': 1.482221728294489e-05, 'train_loss': 0.011518, 'train_psnr': 25.1999, 'val_psnr': 24.0596, 'input_psnr': 23.1331, 'delta_psnr': 0.9266, 'best_val_psnr': 24.0596}
# {'epoch': 5710, 'epoch_time_sec': 19.72, 'lr': 1.4592431398753028e-05, 'train_loss': 0.011513, 'train_psnr': 25.2016, 'val_psnr': 24.0596, 'input_psnr': 23.1331, 'delta_psnr': 0.9266, 'best_val_psnr': 24.0596}
# {'epoch': 5711, 'epoch_time_sec': 19.73, 'lr': 1.4368069100918583e-05, 'train_loss': 0.011518, 'train_psnr': 25.1999, 'val_psnr': 24.0596, 'input_psnr': 23.1331, 'delta_psnr': 0.9266, 'best_val_psnr': 24.0596}
# {'epoch': 5712, 'epoch_time_sec': 19.76, 'lr': 1.4149148993531627e-05, 'train_loss': 0.011521, 'train_psnr': 25.1994, 'val_psnr': 24.0596, 'input_psnr': 23.1331, 'delta_psnr': 0.9265, 'best_val_psnr': 24.0596}
# {'epoch': 5713, 'epoch_time_sec': 19.76, 'lr': 1.393568922941657e-05, 'train_loss': 0.011519, 'train_psnr': 25.2015, 'val_psnr': 24.0596, 'input_psnr': 23.1331, 'delta_psnr': 0.9265, 'best_val_psnr': 24.0596}
# {'epoch': 5714, 'epoch_time_sec': 19.8, 'lr': 1.3727707508626935e-05, 'train_loss': 0.011505, 'train_psnr': 25.2082, 'val_psnr': 24.0595, 'input_psnr': 23.1331, 'delta_psnr': 0.9265, 'best_val_psnr': 24.0596}
# {'epoch': 5715, 'epoch_time_sec': 19.81, 'lr': 1.3525221076977658e-05, 'train_loss': 0.01151, 'train_psnr': 25.204, 'val_psnr': 24.0596, 'input_psnr': 23.1331, 'delta_psnr': 0.9265, 'best_val_psnr': 24.0596}
# {'epoch': 5716, 'epoch_time_sec': 19.81, 'lr': 1.3328246724615048e-05, 'train_loss': 0.011527, 'train_psnr': 25.1956, 'val_psnr': 24.0597, 'input_psnr': 23.1331, 'delta_psnr': 0.9266, 'best_val_psnr': 24.0597}
# {'epoch': 5717, 'epoch_time_sec': 19.79, 'lr': 1.3136800784624638e-05, 'train_loss': 0.011522, 'train_psnr': 25.1984, 'val_psnr': 24.0597, 'input_psnr': 23.1331, 'delta_psnr': 0.9267, 'best_val_psnr': 24.0597}
# {'epoch': 5718, 'epoch_time_sec': 19.8, 'lr': 1.2950899131676725e-05, 'train_loss': 0.011519, 'train_psnr': 25.2007, 'val_psnr': 24.0597, 'input_psnr': 23.1331, 'delta_psnr': 0.9267, 'best_val_psnr': 24.0597}
# {'epoch': 5719, 'epoch_time_sec': 19.76, 'lr': 1.2770557180710165e-05, 'train_loss': 0.011513, 'train_psnr': 25.2037, 'val_psnr': 24.0597, 'input_psnr': 23.1331, 'delta_psnr': 0.9267, 'best_val_psnr': 24.0597}
# {'epoch': 5720, 'epoch_time_sec': 19.78, 'lr': 1.259578988565406e-05, 'train_loss': 0.011523, 'train_psnr': 25.2003, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9268, 'best_val_psnr': 24.0598}
# {'epoch': 5721, 'epoch_time_sec': 19.8, 'lr': 1.2426611738187842e-05, 'train_loss': 0.011514, 'train_psnr': 25.2032, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9267, 'best_val_psnr': 24.0598}
# {'epoch': 5722, 'epoch_time_sec': 19.8, 'lr': 1.2263036766539645e-05, 'train_loss': 0.011516, 'train_psnr': 25.2024, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9267, 'best_val_psnr': 24.0598}
# {'epoch': 5723, 'epoch_time_sec': 19.76, 'lr': 1.2105078534323013e-05, 'train_loss': 0.011533, 'train_psnr': 25.1942, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9267, 'best_val_psnr': 24.0598}
# {'epoch': 5724, 'epoch_time_sec': 19.74, 'lr': 1.195275013941229e-05, 'train_loss': 0.011517, 'train_psnr': 25.2013, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9267, 'best_val_psnr': 24.0598}
# {'epoch': 5725, 'epoch_time_sec': 19.76, 'lr': 1.1806064212856471e-05, 'train_loss': 0.011518, 'train_psnr': 25.2017, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9268, 'best_val_psnr': 24.0598}
# {'epoch': 5726, 'epoch_time_sec': 19.81, 'lr': 1.1665032917831881e-05, 'train_loss': 0.011513, 'train_psnr': 25.2039, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9268, 'best_val_psnr': 24.0598}
# {'epoch': 5727, 'epoch_time_sec': 19.76, 'lr': 1.1529667948633603e-05, 'train_loss': 0.01151, 'train_psnr': 25.2065, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9267, 'best_val_psnr': 24.0598}
# {'epoch': 5728, 'epoch_time_sec': 19.8, 'lr': 1.139998052970579e-05, 'train_loss': 0.011517, 'train_psnr': 25.2002, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9268, 'best_val_psnr': 24.0598}
# {'epoch': 5729, 'epoch_time_sec': 19.75, 'lr': 1.1275981414710904e-05, 'train_loss': 0.011514, 'train_psnr': 25.2027, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9267, 'best_val_psnr': 24.0598}
# {'epoch': 5730, 'epoch_time_sec': 19.75, 'lr': 1.115768088563806e-05, 'train_loss': 0.011517, 'train_psnr': 25.2047, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9268, 'best_val_psnr': 24.0598}
# {'epoch': 5731, 'epoch_time_sec': 19.8, 'lr': 1.1045088751950434e-05, 'train_loss': 0.01152, 'train_psnr': 25.1997, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9268, 'best_val_psnr': 24.0598}
# {'epoch': 5732, 'epoch_time_sec': 19.81, 'lr': 1.0938214349771866e-05, 'train_loss': 0.011505, 'train_psnr': 25.2062, 'val_psnr': 24.0599, 'input_psnr': 23.1331, 'delta_psnr': 0.9268, 'best_val_psnr': 24.0599}
# {'epoch': 5733, 'epoch_time_sec': 19.81, 'lr': 1.0837066541112696e-05, 'train_loss': 0.011521, 'train_psnr': 25.2013, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9267, 'best_val_psnr': 24.0599}
# {'epoch': 5734, 'epoch_time_sec': 19.76, 'lr': 1.0741653713134952e-05, 'train_loss': 0.011512, 'train_psnr': 25.2024, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9268, 'best_val_psnr': 24.0599}
# {'epoch': 5735, 'epoch_time_sec': 19.77, 'lr': 1.0651983777456849e-05, 'train_loss': 0.011517, 'train_psnr': 25.1986, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9268, 'best_val_psnr': 24.0599}
# {'epoch': 5736, 'epoch_time_sec': 19.76, 'lr': 1.0568064169496817e-05, 'train_loss': 0.011509, 'train_psnr': 25.2056, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9267, 'best_val_psnr': 24.0599}
# {'epoch': 5737, 'epoch_time_sec': 19.8, 'lr': 1.0489901847856884e-05, 'train_loss': 0.011521, 'train_psnr': 25.1996, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9267, 'best_val_psnr': 24.0599}
# {'epoch': 5738, 'epoch_time_sec': 19.79, 'lr': 1.0417503293745749e-05, 'train_loss': 0.011511, 'train_psnr': 25.204, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9268, 'best_val_psnr': 24.0599}
# {'epoch': 5739, 'epoch_time_sec': 19.77, 'lr': 1.035087451044129e-05, 'train_loss': 0.011521, 'train_psnr': 25.1998, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9267, 'best_val_psnr': 24.0599}
# {'epoch': 5740, 'epoch_time_sec': 19.78, 'lr': 1.0290021022792812e-05, 'train_loss': 0.011517, 'train_psnr': 25.199, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9267, 'best_val_psnr': 24.0599}
# {'epoch': 5741, 'epoch_time_sec': 19.77, 'lr': 1.023494787676293e-05, 'train_loss': 0.011512, 'train_psnr': 25.2041, 'val_psnr': 24.0599, 'input_psnr': 23.1331, 'delta_psnr': 0.9268, 'best_val_psnr': 24.0599}
# {'epoch': 5742, 'epoch_time_sec': 19.72, 'lr': 1.0185659639009146e-05, 'train_loss': 0.011525, 'train_psnr': 25.1986, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9268, 'best_val_psnr': 24.0599}
# {'epoch': 5743, 'epoch_time_sec': 19.8, 'lr': 1.0142160396505167e-05, 'train_loss': 0.011508, 'train_psnr': 25.2067, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9267, 'best_val_psnr': 24.0599}
# {'epoch': 5744, 'epoch_time_sec': 19.78, 'lr': 1.0104453756202043e-05, 'train_loss': 0.011519, 'train_psnr': 25.201, 'val_psnr': 24.0597, 'input_psnr': 23.1331, 'delta_psnr': 0.9267, 'best_val_psnr': 24.0599}
# {'epoch': 5745, 'epoch_time_sec': 19.78, 'lr': 1.0072542844729072e-05, 'train_loss': 0.011504, 'train_psnr': 25.2078, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9267, 'best_val_psnr': 24.0599}
# {'epoch': 5746, 'epoch_time_sec': 19.77, 'lr': 1.0046430308134524e-05, 'train_loss': 0.011529, 'train_psnr': 25.1954, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9268, 'best_val_psnr': 24.0599}
# {'epoch': 5747, 'epoch_time_sec': 19.8, 'lr': 1.0026118311666254e-05, 'train_loss': 0.011525, 'train_psnr': 25.1978, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9267, 'best_val_psnr': 24.0599}
# {'epoch': 5748, 'epoch_time_sec': 19.79, 'lr': 1.0011608539592144e-05, 'train_loss': 0.011533, 'train_psnr': 25.1938, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9267, 'best_val_psnr': 24.0599}
# {'epoch': 5749, 'epoch_time_sec': 19.74, 'lr': 1.0002902195060438e-05, 'train_loss': 0.01151, 'train_psnr': 25.204, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9267, 'best_val_psnr': 24.0599}
# {'epoch': 5750, 'epoch_time_sec': 19.77, 'lr': 1e-05, 'train_loss': 0.011516, 'train_psnr': 25.2029, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9267, 'best_val_psnr': 24.0599}

# %% [markdown]
# ## 6. Validation Summary

# %%
export_model = load_checkpoint_for_eval(best_ckpt_path, device)
validation_summary = evaluate_metrics(export_model, val_loader, device)
preview_info = write_val_preview(export_model, val_loader, preview_dir, device)
print({'validation_summary': validation_summary, 'best_checkpoint_path': str(best_ckpt_path), 'last_checkpoint_path': str(last_ckpt_path), 'preview': preview_info})
# Out:
# {'validation_summary': {'val_psnr': 24.059871517528187, 'input_psnr': 23.133060299266468, 'delta_psnr': 0.9268112182617188}, 'best_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/220035_2804_fsrcnn_residual_96_40_m8_resume5750_most_recent_last_lr150_restart/checkpoints/best.pth', 'last_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/220035_2804_fsrcnn_residual_96_40_m8_resume5750_most_recent_last_lr150_restart/checkpoints/last.pth', 'preview': {'sample_name': '0000', 'input': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/220035_2804_fsrcnn_residual_96_40_m8_resume5750_most_recent_last_lr150_restart/exports/val_preview/val_preview_input.png', 'prediction': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/220035_2804_fsrcnn_residual_96_40_m8_resume5750_most_recent_last_lr150_restart/exports/val_preview/val_preview_pred.png', 'target': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/220035_2804_fsrcnn_residual_96_40_m8_resume5750_most_recent_last_lr150_restart/exports/val_preview/val_preview_target.png'}}

# %% [markdown]
# ## 7. Export And Submission Artifacts

# %%
def load_or_create_calibration_summary(calibration_dir: Path, pairs: list[tuple[Path, Path, str]], count: int, eval_size: int) -> dict[str, Any]:
    manifest_path = calibration_dir / 'manifest.json'
    if manifest_path.exists():
        manifest = json.loads(manifest_path.read_text(encoding='utf-8'))
        item_count = int(manifest.get('count') or len(manifest.get('items', [])))
        if item_count <= 0 or manifest.get('derived_from_training') is not True:
            raise ValueError(f'Invalid training-derived calibration manifest: {manifest_path}')
        return {'calibration_dir': str(calibration_dir), 'manifest_path': str(manifest_path), 'count': item_count, 'source': manifest.get('source'), 'derived_from_training': True, 'reused_existing_dataset': True}

    calibration_dir.mkdir(parents=True, exist_ok=True) 
    items: list[dict[str, Any]] = []
    for index, (lr_path, _, name) in enumerate(pairs[:count]):
        image = Image.open(lr_path).convert('RGB')
        if image.size != (eval_size, eval_size):
            image = image.resize((eval_size, eval_size), BICUBIC_RESAMPLE)
        image_path = calibration_dir / f'{index:03d}_{Path(name).name}.png'
        image.save(image_path)
        items.append({'index': index, 'name': name, 'source_lr': str(lr_path), 'image_path': str(image_path), 'derived_from_training': True})
    manifest = {'count': len(items), 'source': 'training_pairs', 'eval_size': eval_size, 'derived_from_training': True, 'items': items}
    write_json(manifest_path, manifest)
    return {'calibration_dir': str(calibration_dir), 'manifest_path': str(manifest_path), 'count': len(items), 'source': 'training_pairs', 'derived_from_training': True, 'reused_existing_dataset': False}

conversion_script = """#!/usr/bin/env python3
from __future__ import annotations

import argparse
import json
import shlex
import subprocess
from pathlib import Path


def parse_args() -> argparse.Namespace:
    parser = argparse.ArgumentParser(description='Lab 3 ONNX-to-MXQ handoff script for FSRCNN residual.')
    parser.add_argument('--onnx', type=Path, required=True)
    parser.add_argument('--calibration-dir', type=Path, required=True)
    parser.add_argument('--output', type=Path, required=True)
    parser.add_argument('--command-template', default='', help='Optional command with {onnx}, {calibration}, {output} placeholders.')
    parser.add_argument('--dry-run', action='store_true')
    return parser.parse_args()


def main() -> None:
    args = parse_args()
    args.onnx = args.onnx.resolve()
    args.calibration_dir = args.calibration_dir.resolve()
    args.output = args.output.resolve()
    if not args.onnx.exists():
        raise FileNotFoundError(f'ONNX file not found: {args.onnx}')
    if not args.calibration_dir.exists():
        raise FileNotFoundError(f'Calibration directory not found: {args.calibration_dir}')
    payload = {
        'onnx': str(args.onnx),
        'calibration_dir': str(args.calibration_dir),
        'output': str(args.output),
        'status': 'handoff_only',
        'command_template': args.command_template,
    }
    if args.command_template:
        command = args.command_template.format(
            onnx=shlex.quote(str(args.onnx)),
            calibration=shlex.quote(str(args.calibration_dir)),
            output=shlex.quote(str(args.output)),
        )
        payload['command'] = command
        if not args.dry_run:
            completed = subprocess.run(command, shell=True, check=False, capture_output=True, text=True)
            payload.update({'status': 'completed' if completed.returncode == 0 else 'failed', 'returncode': completed.returncode, 'stdout': completed.stdout, 'stderr': completed.stderr})
    args.output.parent.mkdir(parents=True, exist_ok=True)
    handoff_path = args.output.with_suffix('.handoff.json')
    handoff_path.write_text(json.dumps(payload, indent=2, sort_keys=True) + '\n', encoding='utf-8')
    print(json.dumps(payload, indent=2, sort_keys=True))


if __name__ == '__main__':
    main()
"""

onnx_path = exports_dir / f'{cfg.model_id}.onnx'
mxq_target_path = exports_dir / f'{cfg.model_id}.mxq'
conversion_script_path = exports_dir / 'convert_fsrcnn_residual_mxq.py'
conversion_script_path.write_text(conversion_script, encoding='utf-8')

cpu_export_model = load_checkpoint_for_eval(best_ckpt_path, torch.device('cpu')).cpu().eval()
dummy = torch.randn(1, 3, cfg.eval_size, cfg.eval_size)
torch.onnx.export(cpu_export_model, dummy, str(onnx_path), input_names=['input'], output_names=['output'], opset_version=17, dynamo=False)

onnx_model = onnx.load(str(onnx_path))
onnx.checker.check_model(onnx_model)
node_ops = [node.op_type for node in onnx_model.graph.node]
op_histogram = {op: node_ops.count(op) for op in sorted(set(node_ops))}
onnx_summary = {'onnx_path': str(onnx_path), 'checked': True, 'graph_op_count': len(node_ops), 'op_histogram': op_histogram}
print(onnx_summary)

parity_result = {'attempted': False, 'onnxruntime_available': False, 'max_abs_diff': None, 'mean_abs_diff': None}
try:
    import onnxruntime as ort
    parity_result['attempted'] = True
    parity_result['onnxruntime_available'] = True
    parity_input = torch.randn(1, 3, cfg.eval_size, cfg.eval_size)
    with torch.no_grad():
        torch_out = cpu_export_model(parity_input).detach().cpu().numpy()
    ort_session = ort.InferenceSession(str(onnx_path), providers=['CPUExecutionProvider'])
    ort_out = ort_session.run(['output'], {'input': parity_input.numpy()})[0]
    diff = np.abs(torch_out - ort_out)
    parity_result['max_abs_diff'] = float(diff.max())
    parity_result['mean_abs_diff'] = float(diff.mean())
except ImportError:
    print('onnxruntime not installed; skipping CPU parity check')
print(parity_result)

calibration_dir = exports_dir / 'calibration'
calibration_summary = load_or_create_calibration_summary(calibration_dir, train_pairs, 128, cfg.eval_size)
mxq_command = f'python {conversion_script_path} --onnx {onnx_path} --calibration-dir {calibration_dir} --output {mxq_target_path} --dry-run'
mxq_handoff = {
    'conversion_script_path': str(conversion_script_path),
    'onnx_input_path': str(onnx_path),
    'calibration_manifest_path': calibration_summary['manifest_path'],
    'mxq_target_path': str(mxq_target_path),
    'command': mxq_command,
    'requested_compile': False,
}
summary = {
    'model_id': cfg.model_id,
    'run_root': str(run_root),
    'config': asdict(cfg),

    'resume': resume_info,

    'lr_schedule': lr_schedule_info,


    'data': {'data_root': str(data_root), 'train_pairs': len(train_pairs), 'val_pairs': len(val_pairs), 'train_splits': L3_TRAIN_SPLITS, 'val_dirs': L3_VAL_DIRS},
    'model': {'params': param_count, 'operator_audit': op_counts, 'input_shape': [1, 3, cfg.eval_size, cfg.eval_size], 'output_shape': [1, 3, cfg.eval_size, cfg.eval_size]},
    'validation': validation_summary,
    'preview': preview_info,
    'artifacts': {
        'best_checkpoint': str(best_ckpt_path),
        'last_checkpoint': str(last_ckpt_path),
        'onnx': str(onnx_path),
        'calibration_manifest': calibration_summary['manifest_path'],
        'conversion_script': str(conversion_script_path),
        'mxq_target': str(mxq_target_path),
        **run_log_paths,
    },
    'runtime': {
        'device': str(device),
        'gpu_name': gpu_name,
    },
    'onnx': onnx_summary,
    'onnx_parity': parity_result,
    'calibration': calibration_summary,
    'mxq_handoff': mxq_handoff,
}
write_json(summary_path, summary)
print({'summary_path': str(summary_path), **summary['artifacts']})
# Out:
# /tmp/ipykernel_73602/2373125837.py:86: DeprecationWarning: You are using the legacy TorchScript-based ONNX export. Starting in PyTorch 2.9, the new torch.export-based ONNX exporter has become the default. Learn more about the new export logic: https://docs.pytorch.org/docs/stable/onnx_export.html. For exporting control flow: https://pytorch.org/tutorials/beginner/onnx/export_control_flow_model_to_onnx_tutorial.html
#   torch.onnx.export(cpu_export_model, dummy, str(onnx_path), input_names=['input'], output_names=['output'], opset_version=17, dynamo=False)
# {'onnx_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/220035_2804_fsrcnn_residual_96_40_m8_resume5750_most_recent_last_lr150_restart/exports/fsrcnn_residual_96_40_m8.onnx', 'checked': True, 'graph_op_count': 24, 'op_histogram': {'Add': 1, 'Conv': 12, 'LeakyRelu': 11}}
# {'attempted': True, 'onnxruntime_available': True, 'max_abs_diff': 1.0728836059570312e-06, 'mean_abs_diff': 1.5801832375927916e-07}
# {'summary_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/220035_2804_fsrcnn_residual_96_40_m8_resume5750_most_recent_last_lr150_restart/summary.json', 'best_checkpoint': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/220035_2804_fsrcnn_residual_96_40_m8_resume5750_most_recent_last_lr150_restart/checkpoints/best.pth', 'last_checkpoint': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/220035_2804_fsrcnn_residual_96_40_m8_resume5750_most_recent_last_lr150_restart/checkpoints/last.pth', 'onnx': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/220035_2804_fsrcnn_residual_96_40_m8_resume5750_most_recent_last_lr150_restart/exports/fsrcnn_residual_96_40_m8.onnx', 'calibration_manifest': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/220035_2804_fsrcnn_residual_96_40_m8_resume5750_most_recent_last_lr150_restart/exports/calibration/manifest.json', 'conversion_script': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/220035_2804_fsrcnn_residual_96_40_m8_resume5750_most_recent_last_lr150_restart/exports/convert_fsrcnn_residual_mxq.py', 'mxq_target': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/220035_2804_fsrcnn_residual_96_40_m8_resume5750_most_recent_last_lr150_restart/exports/fsrcnn_residual_96_40_m8.mxq', 'metrics_csv': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/220035_2804_fsrcnn_residual_96_40_m8_resume5750_most_recent_last_lr150_restart/metrics.csv', 'history_json': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/220035_2804_fsrcnn_residual_96_40_m8_resume5750_most_recent_last_lr150_restart/history.json', 'summary_json': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/220035_2804_fsrcnn_residual_96_40_m8_resume5750_most_recent_last_lr150_restart/summary.json', 'run_manifest': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/220035_2804_fsrcnn_residual_96_40_m8_resume5750_most_recent_last_lr150_restart/run_manifest.json'}
