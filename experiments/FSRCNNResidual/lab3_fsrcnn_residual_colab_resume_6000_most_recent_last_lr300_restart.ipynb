# %% [markdown]
# # Lab 3 - FSRCNN Residual 96/40/m8 Resume Most Recent Last LR 1.5e-4 Restart To 5750 (Colab)

# %% [markdown]
# ## 1. Setup

# %%
try:
    import google.colab  # type: ignore
    IN_COLAB_BOOTSTRAP = True
except Exception:
    IN_COLAB_BOOTSTRAP = False

if IN_COLAB_BOOTSTRAP:
    # %pip install -q onnx onnxruntime

import csv
import json
import math
import os
import random
import sys
import time
from contextlib import nullcontext
from dataclasses import asdict, dataclass
from datetime import datetime
from pathlib import Path
from typing import Any

import numpy as np
import onnx
import torch
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
from torch.utils.data import DataLoader, Dataset

IMAGE_SUFFIXES = {'.png', '.jpg', '.jpeg', '.bmp'}
DRIVE_ROOT = Path('/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3')
DRIVE_DATA_ROOT = DRIVE_ROOT / 'Data'
DRIVE_RUNS_ROOT = DRIVE_ROOT / 'runs'

try:
    BICUBIC_RESAMPLE = Image.Resampling.BICUBIC
except AttributeError:
    BICUBIC_RESAMPLE = Image.BICUBIC

try:
    FLIP_LEFT_RIGHT = Image.Transpose.FLIP_LEFT_RIGHT
    FLIP_TOP_BOTTOM = Image.Transpose.FLIP_TOP_BOTTOM
    ROTATE_90 = Image.Transpose.ROTATE_90
    ROTATE_180 = Image.Transpose.ROTATE_180
    ROTATE_270 = Image.Transpose.ROTATE_270
except AttributeError:
    FLIP_LEFT_RIGHT = Image.FLIP_LEFT_RIGHT
    FLIP_TOP_BOTTOM = Image.FLIP_TOP_BOTTOM
    ROTATE_90 = Image.ROTATE_90
    ROTATE_180 = Image.ROTATE_180
    ROTATE_270 = Image.ROTATE_270


def set_global_seed(seed: int) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


def now_stamp() -> str:
    return datetime.now().strftime('%H%M%S_%d%m')


def is_colab_runtime() -> bool:
    try:
        import google.colab  # type: ignore  # noqa: F401
        return True
    except Exception:
        return False


def auto_num_workers(in_colab: bool) -> int:
    if sys.platform == 'darwin':
        return 0
    cpu_count = max(os.cpu_count() or 2, 2)
    if in_colab:
        return min(4, max(cpu_count - 1, 2))
    return min(2, cpu_count)


def resolve_repo_root(start: Path) -> Path:
    current = start.resolve()
    for candidate in [current, *current.parents]:
        if (candidate / 'Data').exists() and (candidate / 'runs').exists():
            return candidate
    for candidate in [current, *current.parents]:
        if (candidate / 'Data').exists():
            return candidate
    raise FileNotFoundError(f'Could not locate repo root from {start.resolve()}')


def make_unique_run_root(runs_root: Path, run_slug: str) -> Path:
    safe_slug = ''.join(ch if ch.isalnum() or ch in '_-' else '_' for ch in run_slug).strip('_')
    candidate = runs_root / f'{now_stamp()}_{safe_slug}'
    while candidate.exists():
        time.sleep(1.1)
        candidate = runs_root / f'{now_stamp()}_{safe_slug}'
    return candidate


def write_json(path: Path, payload: dict[str, Any]) -> None:
    path.parent.mkdir(parents=True, exist_ok=True)
    path.write_text(json.dumps(payload, indent=2, sort_keys=True) + '\n', encoding='utf-8')

# %% [markdown]
# ## 2. Configuration

# %%
@dataclass
class RunConfig:
    model_id: str = 'fsrcnn_residual_96_40_m8'
    run_slug: str = 'fsrcnn_residual_96_40_m8_resume6000_most_recent_last_lr300_restart'
    enable_resume: bool = True
    resume_checkpoint_path: str | None = (
        '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/'
        'runs/220035_2804_fsrcnn_residual_96_40_m8_resume5750_most_recent_last_lr150_restart/checkpoints/last.pth'
    )

    seed: int = 1337
    train_patch_size: int = 256
    eval_size: int = 256
    batch_size: int = 16
    epochs: int = 6000

    lr: float = 3e-4
    min_lr: float = 1e-5
    warmup_epochs: int = 5
    weight_decay: float = 1e-4
    load_optimizer_state: bool = False

    num_workers: int | None = 2
    prefetch_factor: int = 2
    use_amp: bool = True
    use_ema: bool = True
    ema_decay: float = 0.999

cfg = RunConfig()
in_colab = is_colab_runtime()
if in_colab:
    from google.colab import drive  # type: ignore

    drive.mount('/content/drive', force_remount=False)
    data_root = DRIVE_DATA_ROOT
    runs_root = DRIVE_RUNS_ROOT
    if not data_root.exists():
        raise FileNotFoundError(f'Google Drive data root not found: {data_root}')
else:
    repo_root = resolve_repo_root(Path.cwd())
    data_root = repo_root / 'Data'
    runs_root = repo_root / 'runs'
    if not data_root.exists():
        raise FileNotFoundError(f'Data root not found: {data_root}')

runs_root.mkdir(parents=True, exist_ok=True)
if cfg.num_workers is None:
    cfg.num_workers = auto_num_workers(in_colab)
if not cfg.enable_resume:
    cfg.resume_checkpoint_path = None

run_root = make_unique_run_root(runs_root, cfg.run_slug)
checkpoints_dir = run_root / 'checkpoints'
exports_dir = run_root / 'exports'
preview_dir = exports_dir / 'val_preview'
summary_path = run_root / 'summary.json'
metrics_csv_path = run_root / 'metrics.csv'
history_json_path = run_root / 'history.json'
run_manifest_path = run_root / 'run_manifest.json'
run_log_paths = {'metrics_csv': str(metrics_csv_path), 'history_json': str(history_json_path), 'summary_json': str(summary_path), 'run_manifest': str(run_manifest_path)}

for directory in [run_root, checkpoints_dir, exports_dir, preview_dir]:
    directory.mkdir(parents=True, exist_ok=True)

set_global_seed(cfg.seed)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
cuda_enabled = device.type == 'cuda'
gpu_name = torch.cuda.get_device_name(0) if cuda_enabled else None
if cuda_enabled:
    torch.backends.cudnn.benchmark = True
    if hasattr(torch.backends.cuda.matmul, 'allow_tf32'):
        torch.backends.cuda.matmul.allow_tf32 = True

print({
    'device': str(device),
    'in_colab': in_colab,
    'data_root': str(data_root),
    'run_root': str(run_root),
    'gpu_name': gpu_name,
    'config': asdict(cfg),
})
# Out:
# Mounted at /content/drive
# {'device': 'cuda', 'in_colab': True, 'data_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/Data', 'run_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/024428_2904_fsrcnn_residual_96_40_m8_resume6000_most_recent_last_lr300_restart', 'gpu_name': 'NVIDIA L4', 'config': {'model_id': 'fsrcnn_residual_96_40_m8', 'run_slug': 'fsrcnn_residual_96_40_m8_resume6000_most_recent_last_lr300_restart', 'enable_resume': True, 'resume_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/220035_2804_fsrcnn_residual_96_40_m8_resume5750_most_recent_last_lr150_restart/checkpoints/last.pth', 'seed': 1337, 'train_patch_size': 256, 'eval_size': 256, 'batch_size': 16, 'epochs': 6000, 'lr': 0.0003, 'min_lr': 1e-05, 'warmup_epochs': 5, 'weight_decay': 0.0001, 'load_optimizer_state': False, 'num_workers': 2, 'prefetch_factor': 2, 'use_amp': True, 'use_ema': True, 'ema_decay': 0.999}}

# %% [markdown]
# ## 3. Data

# %%
L3_TRAIN_SPLITS = (
    ('LR_HR/L3_HR_train1', 'L3_LR/L3_L3_train1', 'L3_HR_train1'),
    ('LR_HR/L3_HR_train2', 'L3_LR/L3_L3_train2', 'L3_HR_train2'),
    ('LR_HR/L3_HR_train3', 'L3_LR/L3_LR_train3', 'L3_HR_train3'),
    ('LR_HR/L3_HR_train4', 'L3_LR/L3_LR_train4', 'L3_HR_train4'),
    ('LR_HR/L3_HR_train', 'L3_LR/L3_LR_train', 'L3_HR_train'),
)
L3_VAL_DIRS = ('L3_HR_valid', 'L3_LR_valid')


def scan_image_directory(directory: Path) -> dict[str, Path]:
    if not directory.exists():
        raise FileNotFoundError(f'Missing directory: {directory}')
    return {
        path.stem: path
        for path in directory.iterdir()
        if path.is_file() and path.suffix.lower() in IMAGE_SUFFIXES
    }


def collect_split_pairs(hr_dir: Path, lr_dir: Path, split_name: str) -> list[tuple[Path, Path, str]]:
    hr_map = scan_image_directory(hr_dir)
    lr_map = scan_image_directory(lr_dir)
    shared = sorted(set(hr_map) & set(lr_map))
    if not shared:
        raise FileNotFoundError(f'No paired files found for {split_name}: HR={hr_dir}, LR={lr_dir}')
    hr_only = sorted(set(hr_map) - set(lr_map))
    lr_only = sorted(set(lr_map) - set(hr_map))
    if hr_only or lr_only:
        print({'split': split_name, 'hr_only_count': len(hr_only), 'lr_only_count': len(lr_only)})
    pairs: list[tuple[Path, Path, str]] = []
    for stem in shared:
        name = stem if split_name == 'val' else f'{split_name}/{stem}'
        pairs.append((lr_map[stem], hr_map[stem], name))
    return pairs


def collect_all_pairs(data_root: Path) -> tuple[list[tuple[Path, Path, str]], list[tuple[Path, Path, str]]]:
    train_pairs: list[tuple[Path, Path, str]] = []
    for hr_rel, lr_rel, split_name in L3_TRAIN_SPLITS:
        hr_dir = data_root / hr_rel
        lr_dir = data_root / lr_rel
        if hr_dir.exists() and lr_dir.exists():
            train_pairs.extend(collect_split_pairs(hr_dir, lr_dir, split_name))
        else:
            print({'skipped_missing_train_split': split_name, 'hr_dir': str(hr_dir), 'lr_dir': str(lr_dir)})
    val_pairs = collect_split_pairs(data_root / L3_VAL_DIRS[0], data_root / L3_VAL_DIRS[1], 'val')
    return train_pairs, val_pairs


class PairedSRDataset(Dataset):
    def __init__(self, pairs: list[tuple[Path, Path, str]], *, train: bool, patch_size: int, eval_size: int, seed: int):
        self.pairs = pairs
        self.train = train
        self.patch_size = patch_size
        self.eval_size = eval_size
        self.seed = seed
        self.epoch = 0

    def set_epoch(self, epoch: int) -> None:
        self.epoch = epoch

    @staticmethod
    def to_tensor(img: Image.Image) -> torch.Tensor:
        arr = np.asarray(img, dtype=np.float32) / 255.0
        return torch.from_numpy(arr).permute(2, 0, 1).contiguous()

    def augment_pair(self, lr: Image.Image, hr: Image.Image, index: int) -> tuple[Image.Image, Image.Image]:
        rng = random.Random((self.seed * 1_000_003) + (self.epoch * 9_973) + index)
        width, height = lr.size
        patch = self.patch_size
        if width < patch or height < patch:
            lr = lr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            hr = hr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            width, height = lr.size
        left = rng.randint(0, width - patch)
        top = rng.randint(0, height - patch)
        box = (left, top, left + patch, top + patch)
        lr = lr.crop(box)
        hr = hr.crop(box)
        if rng.random() < 0.5:
            lr = lr.transpose(FLIP_LEFT_RIGHT)
            hr = hr.transpose(FLIP_LEFT_RIGHT)
        if rng.random() < 0.5:
            lr = lr.transpose(FLIP_TOP_BOTTOM)
            hr = hr.transpose(FLIP_TOP_BOTTOM)
        rot = rng.choice([0, 1, 2, 3])
        if rot:
            rotate_ops = [ROTATE_90, ROTATE_180, ROTATE_270]
            lr = lr.transpose(rotate_ops[rot - 1])
            hr = hr.transpose(rotate_ops[rot - 1])
        return lr, hr

    def __len__(self) -> int:
        return len(self.pairs)

    def __getitem__(self, index: int) -> dict[str, Any]:
        lr_path, hr_path, name = self.pairs[index]
        lr = Image.open(lr_path).convert('RGB')
        hr = Image.open(hr_path).convert('RGB')
        if self.train:
            lr, hr = self.augment_pair(lr, hr, index)
        elif lr.size != (self.eval_size, self.eval_size):
            lr = lr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            hr = hr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
        return {'lr': self.to_tensor(lr), 'hr': self.to_tensor(hr), 'name': name}

train_pairs, val_pairs = collect_all_pairs(data_root)
if not train_pairs:
    raise FileNotFoundError(f'No training pairs found under {data_root}')
if not val_pairs:
    raise FileNotFoundError(f'No validation pairs found under {data_root}')

train_ds = PairedSRDataset(train_pairs, train=True, patch_size=cfg.train_patch_size, eval_size=cfg.eval_size, seed=cfg.seed)
val_ds = PairedSRDataset(val_pairs, train=False, patch_size=cfg.train_patch_size, eval_size=cfg.eval_size, seed=cfg.seed)

loader_num_workers = int(cfg.num_workers or 0)
train_loader_kwargs = {
    'dataset': train_ds,
    'batch_size': cfg.batch_size,
    'shuffle': True,
    'num_workers': loader_num_workers,
    'pin_memory': cuda_enabled,
}
val_loader_kwargs = {
    'dataset': val_ds,
    'batch_size': 1,
    'shuffle': False,
    'num_workers': loader_num_workers,
    'pin_memory': cuda_enabled,
}
if loader_num_workers > 0:
    train_loader_kwargs['persistent_workers'] = True
    val_loader_kwargs['persistent_workers'] = True
    train_loader_kwargs['prefetch_factor'] = cfg.prefetch_factor
    val_loader_kwargs['prefetch_factor'] = cfg.prefetch_factor

train_loader = DataLoader(**train_loader_kwargs)
val_loader = DataLoader(**val_loader_kwargs)

sample = train_ds[0]
print({
    'data_root': str(data_root),
    'train_pairs': len(train_pairs),
    'val_pairs': len(val_pairs),
    'train_preview': [name for _, _, name in train_pairs[:5]],
    'val_preview': [name for _, _, name in val_pairs[:5]],
    'sample_lr_shape': tuple(sample['lr'].shape),
    'sample_hr_shape': tuple(sample['hr'].shape),
})
assert tuple(sample['lr'].shape) == (3, cfg.eval_size, cfg.eval_size)
assert tuple(sample['hr'].shape) == (3, cfg.eval_size, cfg.eval_size)
# Out:
# {'data_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/Data', 'train_pairs': 2217, 'val_pairs': 110, 'train_preview': ['L3_HR_train1/0000', 'L3_HR_train1/0001', 'L3_HR_train1/00010', 'L3_HR_train1/000100', 'L3_HR_train1/000101'], 'val_preview': ['0000', '00010', '000100', '000102', '000104'], 'sample_lr_shape': (3, 256, 256), 'sample_hr_shape': (3, 256, 256)}

# %% [markdown]
# ## 4. Model

# %%
class FSRCNNResidualNoUpscale(nn.Module):
    """FSRCNN-style residual refiner for 256x256 RGB input/output."""

    def __init__(self, channels: int = 96, shrink_channels: int = 40, mapping_layers: int = 8, slope: float = 0.10):
        super().__init__()
        self.channels = channels
        self.shrink_channels = shrink_channels
        self.mapping_layers = mapping_layers
        self.slope = slope

        self.features = nn.Sequential(*self._feature_layers())
        self.tail = nn.Conv2d(channels, 3, 3, padding=1, bias=True)
        self.init_tail_small()

    def _activation(self) -> nn.Module:
        return nn.LeakyReLU(self.slope, inplace=False)

    def _feature_layers(self) -> list[nn.Module]:
        stem = [
            nn.Conv2d(3, self.channels, 5, padding=2, bias=True),
            self._activation(),
        ]
        shrink = [
            nn.Conv2d(self.channels, self.shrink_channels, 1, padding=0, bias=True),
            self._activation(),
        ]
        mapping: list[nn.Module] = []
        for _ in range(self.mapping_layers):
            mapping.extend([
                nn.Conv2d(self.shrink_channels, self.shrink_channels, 3, padding=1, bias=True),
                self._activation(),
            ])
        expand = [
            nn.Conv2d(self.shrink_channels, self.channels, 1, padding=0, bias=True),
            self._activation(),
        ]
        return [*stem, *shrink, *mapping, *expand]

    def architecture_summary(self) -> dict[str, str | int]:
        return {
            'stem': f'Conv5x5 3->{self.channels} + LeakyReLU',
            'shrink': f'Conv1x1 {self.channels}->{self.shrink_channels} + LeakyReLU',
            'mapping': f'{self.mapping_layers}x Conv3x3 {self.shrink_channels}->{self.shrink_channels} + LeakyReLU',
            'expand': f'Conv1x1 {self.shrink_channels}->{self.channels} + LeakyReLU',
            'tail': f'Conv3x3 {self.channels}->3 residual delta',
            'forward': 'output = input + residual_delta',
        }

    def init_tail_small(self) -> None:
        nn.init.kaiming_normal_(self.tail.weight, nonlinearity='linear')
        self.tail.weight.data.mul_(1e-3)
        if self.tail.bias is not None:
            nn.init.zeros_(self.tail.bias)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return x + self.tail(self.features(x))


def count_parameters(module: nn.Module) -> int:
    return int(sum(param.numel() for param in module.parameters()))


def operator_audit(module: nn.Module) -> dict[str, int]:
    counts: dict[str, int] = {}
    for child in module.modules():
        if len(list(child.children())) != 0:
            continue
        name = child.__class__.__name__
        counts[name] = counts.get(name, 0) + 1
    return dict(sorted(counts.items()))

model = FSRCNNResidualNoUpscale().to(device)
eval_model = FSRCNNResidualNoUpscale().to(device)
param_count = count_parameters(model)
op_counts = operator_audit(model)
dummy = torch.zeros(1, 3, cfg.eval_size, cfg.eval_size, device=device)
with torch.no_grad():
    dummy_out = model(dummy)

print({
    'model_id': cfg.model_id,
    'params': param_count,
    'operator_audit': op_counts,
    'input_shape': tuple(dummy.shape),
    'output_shape': tuple(dummy_out.shape),
    'architecture': model.architecture_summary(),
})
assert param_count == 133_227, param_count
assert tuple(dummy_out.shape) == (1, 3, cfg.eval_size, cfg.eval_size)
assert set(op_counts).issubset({'Conv2d', 'LeakyReLU'}), op_counts
# Out:
# {'model_id': 'fsrcnn_residual_96_40_m8', 'params': 133227, 'operator_audit': {'Conv2d': 12, 'LeakyReLU': 11}, 'input_shape': (1, 3, 256, 256), 'output_shape': (1, 3, 256, 256), 'architecture': {'stem': 'Conv5x5 3->96 + LeakyReLU', 'shrink': 'Conv1x1 96->40 + LeakyReLU', 'mapping': '8x Conv3x3 40->40 + LeakyReLU', 'expand': 'Conv1x1 40->96 + LeakyReLU', 'tail': 'Conv3x3 96->3 residual delta', 'forward': 'output = input + residual_delta'}}

# %% [markdown]
# ## 5. Training And Validation

# %%
class EMA:
    def __init__(self, model: nn.Module, decay: float):
        self.decay = decay
        self.shadow = {k: v.detach().clone() for k, v in model.state_dict().items()}

    @torch.no_grad()
    def update(self, model: nn.Module) -> None:
        for key, value in model.state_dict().items():
            self.shadow[key].mul_(self.decay).add_(value.detach(), alpha=1.0 - self.decay)

    @torch.no_grad()
    def copy_to(self, model: nn.Module) -> None:
        model.load_state_dict(self.shadow, strict=True)


def make_grad_scaler(enabled: bool):
    if hasattr(torch, 'amp') and hasattr(torch.amp, 'GradScaler'):
        return torch.amp.GradScaler('cuda', enabled=enabled)
    return torch.cuda.amp.GradScaler(enabled=enabled)


def autocast_context(device_type: str, enabled: bool):
    if not enabled:
        return nullcontext()
    if hasattr(torch, 'amp') and hasattr(torch.amp, 'autocast'):
        return torch.amp.autocast(device_type=device_type, enabled=enabled)
    return torch.cuda.amp.autocast(enabled=enabled)


@torch.no_grad()
def batch_psnr(pred: torch.Tensor, target: torch.Tensor) -> float:
    mse = F.mse_loss(pred, target, reduction='none').mean(dim=(1, 2, 3))
    psnr = 10.0 * torch.log10(1.0 / torch.clamp(mse, min=1e-12))
    return float(psnr.mean().item())


def compute_loss(pred: torch.Tensor, lr: torch.Tensor, hr: torch.Tensor) -> torch.Tensor:
    mse = F.mse_loss(pred, hr)
    residual_l1 = F.l1_loss(pred - lr, hr - lr)
    return 0.8 * mse + 0.2 * residual_l1


def lr_at_epoch(
    epoch_idx: int,
    *,
    base_lr: float,
    min_lr: float,
    warmup_epochs: int,
    total_epochs: int,
    schedule_start_epoch: int = 0,
) -> float:
    step = epoch_idx - schedule_start_epoch + 1
    span = max(1, total_epochs - schedule_start_epoch)

    if warmup_epochs > 0 and step <= warmup_epochs:
        return base_lr * step / warmup_epochs

    progress = (step - warmup_epochs) / max(1, span - warmup_epochs)
    progress = min(max(progress, 0.0), 1.0)
    cosine = 0.5 * (1.0 + math.cos(math.pi * progress))
    return min_lr + cosine * (base_lr - min_lr)

def evaluate_metrics(model: nn.Module, loader: DataLoader, device: torch.device) -> dict[str, float]:
    model.eval()
    pred_meter = 0.0
    input_meter = 0.0
    count = 0
    for batch in loader:
        lr = batch['lr'].to(device, non_blocking=cuda_enabled)
        hr = batch['hr'].to(device, non_blocking=cuda_enabled)
        pred = model(lr).clamp(0.0, 1.0)
        pred_meter += batch_psnr(pred, hr)
        input_meter += batch_psnr(lr, hr)
        count += 1
    val_psnr = pred_meter / max(count, 1)
    input_psnr = input_meter / max(count, 1)
    return {'val_psnr': float(val_psnr), 'input_psnr': float(input_psnr), 'delta_psnr': float(val_psnr - input_psnr)}


def tensor_to_uint8_image(x: torch.Tensor) -> Image.Image:
    x = x.detach().cpu().clamp(0.0, 1.0)
    arr = (x.permute(1, 2, 0).numpy() * 255.0).round().astype(np.uint8)
    return Image.fromarray(arr)


@torch.no_grad()
def write_val_preview(model: nn.Module, loader: DataLoader, out_dir: Path, device: torch.device) -> dict[str, str]:
    out_dir.mkdir(parents=True, exist_ok=True)
    batch = next(iter(loader))
    lr = batch['lr'].to(device, non_blocking=cuda_enabled)
    hr = batch['hr'].to(device, non_blocking=cuda_enabled)
    pred = model(lr).clamp(0.0, 1.0)
    name = batch['name'][0]
    lr_path = out_dir / 'val_preview_input.png'
    pred_path = out_dir / 'val_preview_pred.png'
    hr_path = out_dir / 'val_preview_target.png'
    tensor_to_uint8_image(lr[0]).save(lr_path)
    tensor_to_uint8_image(pred[0]).save(pred_path)
    tensor_to_uint8_image(hr[0]).save(hr_path)
    return {'sample_name': str(name), 'input': str(lr_path), 'prediction': str(pred_path), 'target': str(hr_path)}


def checkpoint_payload(model: nn.Module, ema: EMA | None, optimizer: torch.optim.Optimizer, epoch: int, best_val_psnr: float, row: dict[str, Any]) -> dict[str, Any]:
    return {
        'config': asdict(cfg),
        'epoch': int(epoch),
        'model_state_dict': model.state_dict(),
        'ema_state_dict': ema.shadow if ema is not None else None,
        'optimizer_state_dict': optimizer.state_dict(),
        'best_val_psnr': float(best_val_psnr),
        'latest_metrics': row,
        'model_params': param_count,
        'operator_audit': op_counts,
    }


def load_checkpoint_for_eval(checkpoint_path: Path, device: torch.device) -> nn.Module:
    checkpoint = torch.load(checkpoint_path, map_location=device)
    loaded = FSRCNNResidualNoUpscale().to(device)
    state = checkpoint.get('ema_state_dict') or checkpoint['model_state_dict']
    loaded.load_state_dict(state, strict=True)
    loaded.eval()
    return loaded

optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)
scaler = make_grad_scaler(cfg.use_amp and cuda_enabled)
ema = EMA(model, cfg.ema_decay) if cfg.use_ema else None
best_val_psnr = float('-inf')
start_epoch = 0

metrics_header = ['epoch', 'epoch_time_sec', 'lr', 'train_loss', 'train_psnr', 'val_psnr', 'input_psnr', 'delta_psnr', 'best_val_psnr']
best_ckpt_path = checkpoints_dir / 'best.pth'
last_ckpt_path = checkpoints_dir / 'last.pth'
resume_info: dict[str, Any] = {

    'enabled': cfg.enable_resume,

    'checkpoint_path': cfg.resume_checkpoint_path,

}

optimizer_state_loaded = False




if cfg.enable_resume:

    if cfg.resume_checkpoint_path is None:

        raise ValueError('cfg.enable_resume=True requires cfg.resume_checkpoint_path')

    resume_checkpoint_path = Path(cfg.resume_checkpoint_path)

    if not resume_checkpoint_path.exists():

        raise FileNotFoundError(f'Resume checkpoint not found: {resume_checkpoint_path}')

    resume_checkpoint = torch.load(resume_checkpoint_path, map_location=device)

    model.load_state_dict(resume_checkpoint['model_state_dict'], strict=True)

    if cfg.load_optimizer_state and 'optimizer_state_dict' in resume_checkpoint:

        optimizer.load_state_dict(resume_checkpoint['optimizer_state_dict'])

        optimizer_state_loaded = True


    if ema is not None and resume_checkpoint.get('ema_state_dict') is not None:

        ema.shadow = {key: value.detach().clone().to(device) for key, value in resume_checkpoint['ema_state_dict'].items()}

    best_val_psnr = float(resume_checkpoint.get('best_val_psnr', best_val_psnr))

    start_epoch = int(resume_checkpoint.get('epoch', 0))

    resume_info.update({

        'checkpoint_path': str(resume_checkpoint_path),

        'checkpoint_epoch': start_epoch,

        'checkpoint_best_val_psnr': best_val_psnr,

        'checkpoint_latest_metrics': resume_checkpoint.get('latest_metrics'),

        'checkpoint_config': resume_checkpoint.get('config'),

        'checkpoint_model_params': resume_checkpoint.get('model_params'),

        'checkpoint_operator_audit': resume_checkpoint.get('operator_audit'),

        'optimizer_state_loaded': optimizer_state_loaded,

        'load_optimizer_state': cfg.load_optimizer_state,



    })

    print({

        'resume_checkpoint_path': str(resume_checkpoint_path),

        'resumed_from_epoch': start_epoch,

        'target_total_epochs': cfg.epochs,






        **run_log_paths,

        'best_val_psnr': best_val_psnr,

    })



if start_epoch >= cfg.epochs:
    raise ValueError(f'Resume checkpoint epoch {start_epoch} is already >= target epochs {cfg.epochs}')

lr_schedule_info = {

    'type': 'resume_local_cosine_warm_restart',

    'base_lr': cfg.lr,

    'min_lr': cfg.min_lr,

    'warmup_epochs': cfg.warmup_epochs,

    'schedule_start_epoch': start_epoch,

    'target_total_epochs': cfg.epochs,

    'load_optimizer_state': cfg.load_optimizer_state,

    'optimizer_state_loaded': optimizer_state_loaded,

}



history = {
    'metadata': {
        'config': asdict(cfg),
        'run_root': str(run_root),
        'resume_checkpoint_path': cfg.resume_checkpoint_path,
        'resume': resume_info,

        'lr_schedule': lr_schedule_info,

        'start_epoch': start_epoch,
        'target_total_epochs': cfg.epochs,
        **run_log_paths,
        'device': str(device),
        'gpu_name': gpu_name,
        'torch_version': torch.__version__,
        'cuda_version': torch.version.cuda,
    },
    'epochs': [],
}
write_json(history_json_path, history)
write_json(run_manifest_path, history['metadata'])

with metrics_csv_path.open('w', newline='', encoding='utf-8') as f:
    csv.DictWriter(f, fieldnames=metrics_header).writeheader()

for epoch in range(start_epoch, cfg.epochs):
    train_ds.set_epoch(epoch)
    epoch_lr = lr_at_epoch(

        epoch,

        base_lr=cfg.lr,

        min_lr=cfg.min_lr,

        warmup_epochs=cfg.warmup_epochs,

        total_epochs=cfg.epochs,

        schedule_start_epoch=start_epoch,

    )
    for group in optimizer.param_groups:
        group['lr'] = epoch_lr

    epoch_start = time.time()
    model.train()
    train_loss_sum = 0.0
    train_psnr_sum = 0.0
    train_batches = 0

    for batch in train_loader:
        lr = batch['lr'].to(device, non_blocking=cuda_enabled)
        hr = batch['hr'].to(device, non_blocking=cuda_enabled)
        optimizer.zero_grad(set_to_none=True)
        with autocast_context(device.type, enabled=(cfg.use_amp and cuda_enabled)):
            pred = model(lr)
            loss = compute_loss(pred, lr, hr)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        if ema is not None:
            ema.update(model)
        train_loss_sum += float(loss.item())
        train_psnr_sum += batch_psnr(pred.detach().clamp(0.0, 1.0), hr)
        train_batches += 1

    if ema is not None:
        ema.copy_to(eval_model)
    else:
        eval_model.load_state_dict(model.state_dict())
    eval_model.eval()

    avg_train_loss = train_loss_sum / max(train_batches, 1)
    avg_train_psnr = train_psnr_sum / max(train_batches, 1)
    val_metrics = evaluate_metrics(eval_model, val_loader, device)
    is_best = val_metrics['val_psnr'] > best_val_psnr
    if is_best:
        best_val_psnr = val_metrics['val_psnr']
    row = {
        'epoch': epoch + 1,
        'epoch_time_sec': round(time.time() - epoch_start, 2),
        'lr': epoch_lr,
        'train_loss': round(avg_train_loss, 6),
        'train_psnr': round(avg_train_psnr, 4),
        'val_psnr': round(val_metrics['val_psnr'], 4),
        'input_psnr': round(val_metrics['input_psnr'], 4),
        'delta_psnr': round(val_metrics['delta_psnr'], 4),
        'best_val_psnr': round(best_val_psnr, 4),
    }
    print(row)
    history['epochs'].append(row)
    write_json(history_json_path, history)
    with metrics_csv_path.open('a', newline='', encoding='utf-8') as f:
        csv.DictWriter(f, fieldnames=metrics_header).writerow(row)
    payload = checkpoint_payload(model, ema, optimizer, epoch + 1, best_val_psnr, row)
    torch.save(payload, last_ckpt_path)
    if is_best:
        torch.save(payload, best_ckpt_path)
# Out:
# {'resume_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/220035_2804_fsrcnn_residual_96_40_m8_resume5750_most_recent_last_lr150_restart/checkpoints/last.pth', 'resumed_from_epoch': 5750, 'target_total_epochs': 6000, 'metrics_csv': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/024428_2904_fsrcnn_residual_96_40_m8_resume6000_most_recent_last_lr300_restart/metrics.csv', 'history_json': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/024428_2904_fsrcnn_residual_96_40_m8_resume6000_most_recent_last_lr300_restart/history.json', 'summary_json': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/024428_2904_fsrcnn_residual_96_40_m8_resume6000_most_recent_last_lr300_restart/summary.json', 'run_manifest': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/024428_2904_fsrcnn_residual_96_40_m8_resume6000_most_recent_last_lr300_restart/run_manifest.json', 'best_val_psnr': 24.059871517528187}
# {'epoch': 5751, 'epoch_time_sec': 1863.78, 'lr': 5.9999999999999995e-05, 'train_loss': 0.011582, 'train_psnr': 25.1611, 'val_psnr': 24.0597, 'input_psnr': 23.1331, 'delta_psnr': 0.9266, 'best_val_psnr': 24.0599}
# {'epoch': 5752, 'epoch_time_sec': 19.06, 'lr': 0.00011999999999999999, 'train_loss': 0.011594, 'train_psnr': 25.1534, 'val_psnr': 24.0596, 'input_psnr': 23.1331, 'delta_psnr': 0.9265, 'best_val_psnr': 24.0599}
# {'epoch': 5753, 'epoch_time_sec': 19.16, 'lr': 0.00017999999999999998, 'train_loss': 0.011613, 'train_psnr': 25.1456, 'val_psnr': 24.0599, 'input_psnr': 23.1331, 'delta_psnr': 0.9268, 'best_val_psnr': 24.0599}
# {'epoch': 5754, 'epoch_time_sec': 19.25, 'lr': 0.00023999999999999998, 'train_loss': 0.01163, 'train_psnr': 25.1338, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9267, 'best_val_psnr': 24.0599}
# {'epoch': 5755, 'epoch_time_sec': 19.31, 'lr': 0.0003, 'train_loss': 0.011637, 'train_psnr': 25.1305, 'val_psnr': 24.0597, 'input_psnr': 23.1331, 'delta_psnr': 0.9266, 'best_val_psnr': 24.0599}
# {'epoch': 5756, 'epoch_time_sec': 19.44, 'lr': 0.00029998807935835626, 'train_loss': 0.011675, 'train_psnr': 25.1093, 'val_psnr': 24.0587, 'input_psnr': 23.1331, 'delta_psnr': 0.9256, 'best_val_psnr': 24.0599}
# {'epoch': 5757, 'epoch_time_sec': 19.45, 'lr': 0.00029995231939344857, 'train_loss': 0.011648, 'train_psnr': 25.1241, 'val_psnr': 24.0577, 'input_psnr': 23.1331, 'delta_psnr': 0.9246, 'best_val_psnr': 24.0599}
# {'epoch': 5758, 'epoch_time_sec': 19.32, 'lr': 0.00029989272598502476, 'train_loss': 0.01164, 'train_psnr': 25.1293, 'val_psnr': 24.057, 'input_psnr': 23.1331, 'delta_psnr': 0.924, 'best_val_psnr': 24.0599}
# {'epoch': 5759, 'epoch_time_sec': 19.37, 'lr': 0.0002998093089315907, 'train_loss': 0.011644, 'train_psnr': 25.1298, 'val_psnr': 24.0565, 'input_psnr': 23.1331, 'delta_psnr': 0.9235, 'best_val_psnr': 24.0599}
# {'epoch': 5760, 'epoch_time_sec': 19.35, 'lr': 0.00029970208194879876, 'train_loss': 0.01164, 'train_psnr': 25.1293, 'val_psnr': 24.0558, 'input_psnr': 23.1331, 'delta_psnr': 0.9227, 'best_val_psnr': 24.0599}
# {'epoch': 5761, 'epoch_time_sec': 19.34, 'lr': 0.00029957106266719283, 'train_loss': 0.011629, 'train_psnr': 25.1359, 'val_psnr': 24.0551, 'input_psnr': 23.1331, 'delta_psnr': 0.922, 'best_val_psnr': 24.0599}
# {'epoch': 5762, 'epoch_time_sec': 19.38, 'lr': 0.00029941627262930964, 'train_loss': 0.011638, 'train_psnr': 25.1317, 'val_psnr': 24.0547, 'input_psnr': 23.1331, 'delta_psnr': 0.9216, 'best_val_psnr': 24.0599}
# {'epoch': 5763, 'epoch_time_sec': 19.41, 'lr': 0.00029923773728613627, 'train_loss': 0.011646, 'train_psnr': 25.126, 'val_psnr': 24.0539, 'input_psnr': 23.1331, 'delta_psnr': 0.9208, 'best_val_psnr': 24.0599}
# {'epoch': 5764, 'epoch_time_sec': 19.36, 'lr': 0.00029903548599292593, 'train_loss': 0.011642, 'train_psnr': 25.127, 'val_psnr': 24.0534, 'input_psnr': 23.1331, 'delta_psnr': 0.9204, 'best_val_psnr': 24.0599}
# {'epoch': 5765, 'epoch_time_sec': 19.41, 'lr': 0.00029880955200437063, 'train_loss': 0.011655, 'train_psnr': 25.1206, 'val_psnr': 24.0526, 'input_psnr': 23.1331, 'delta_psnr': 0.9195, 'best_val_psnr': 24.0599}
# {'epoch': 5766, 'epoch_time_sec': 19.41, 'lr': 0.00029855997246913424, 'train_loss': 0.011642, 'train_psnr': 25.1298, 'val_psnr': 24.0522, 'input_psnr': 23.1331, 'delta_psnr': 0.9192, 'best_val_psnr': 24.0599}
# {'epoch': 5767, 'epoch_time_sec': 19.37, 'lr': 0.00029828678842374354, 'train_loss': 0.011639, 'train_psnr': 25.1292, 'val_psnr': 24.0518, 'input_psnr': 23.1331, 'delta_psnr': 0.9187, 'best_val_psnr': 24.0599}
# {'epoch': 5768, 'epoch_time_sec': 19.42, 'lr': 0.0002979900447858414, 'train_loss': 0.01161, 'train_psnr': 25.147, 'val_psnr': 24.0519, 'input_psnr': 23.1331, 'delta_psnr': 0.9189, 'best_val_psnr': 24.0599}
# {'epoch': 5769, 'epoch_time_sec': 19.4, 'lr': 0.00029766979034680127, 'train_loss': 0.011629, 'train_psnr': 25.14, 'val_psnr': 24.052, 'input_psnr': 23.1331, 'delta_psnr': 0.9189, 'best_val_psnr': 24.0599}
# {'epoch': 5770, 'epoch_time_sec': 19.33, 'lr': 0.00029732607776370443, 'train_loss': 0.011645, 'train_psnr': 25.1268, 'val_psnr': 24.0513, 'input_psnr': 23.1331, 'delta_psnr': 0.9183, 'best_val_psnr': 24.0599}
# {'epoch': 5771, 'epoch_time_sec': 19.35, 'lr': 0.00029695896355068244, 'train_loss': 0.011634, 'train_psnr': 25.1337, 'val_psnr': 24.0507, 'input_psnr': 23.1331, 'delta_psnr': 0.9176, 'best_val_psnr': 24.0599}
# {'epoch': 5772, 'epoch_time_sec': 19.35, 'lr': 0.00029656850806962455, 'train_loss': 0.011632, 'train_psnr': 25.1346, 'val_psnr': 24.0506, 'input_psnr': 23.1331, 'delta_psnr': 0.9175, 'best_val_psnr': 24.0599}
# {'epoch': 5773, 'epoch_time_sec': 19.35, 'lr': 0.0002961547755202532, 'train_loss': 0.011623, 'train_psnr': 25.1414, 'val_psnr': 24.0505, 'input_psnr': 23.1331, 'delta_psnr': 0.9174, 'best_val_psnr': 24.0599}
# {'epoch': 5774, 'epoch_time_sec': 19.4, 'lr': 0.00029571783392956763, 'train_loss': 0.011625, 'train_psnr': 25.1395, 'val_psnr': 24.0506, 'input_psnr': 23.1331, 'delta_psnr': 0.9175, 'best_val_psnr': 24.0599}
# {'epoch': 5775, 'epoch_time_sec': 19.39, 'lr': 0.00029525775514065925, 'train_loss': 0.011624, 'train_psnr': 25.1375, 'val_psnr': 24.0502, 'input_psnr': 23.1331, 'delta_psnr': 0.9171, 'best_val_psnr': 24.0599}
# {'epoch': 5776, 'epoch_time_sec': 19.38, 'lr': 0.0002947746148008987, 'train_loss': 0.011638, 'train_psnr': 25.1346, 'val_psnr': 24.05, 'input_psnr': 23.1331, 'delta_psnr': 0.9169, 'best_val_psnr': 24.0599}
# {'epoch': 5777, 'epoch_time_sec': 19.4, 'lr': 0.0002942684923494978, 'train_loss': 0.011632, 'train_psnr': 25.1353, 'val_psnr': 24.0495, 'input_psnr': 23.1331, 'delta_psnr': 0.9165, 'best_val_psnr': 24.0599}
# {'epoch': 5778, 'epoch_time_sec': 19.35, 'lr': 0.00029373947100444774, 'train_loss': 0.011617, 'train_psnr': 25.1432, 'val_psnr': 24.0496, 'input_psnr': 23.1331, 'delta_psnr': 0.9165, 'best_val_psnr': 24.0599}
# {'epoch': 5779, 'epoch_time_sec': 19.38, 'lr': 0.00029318763774883663, 'train_loss': 0.011622, 'train_psnr': 25.1416, 'val_psnr': 24.0496, 'input_psnr': 23.1331, 'delta_psnr': 0.9166, 'best_val_psnr': 24.0599}
# {'epoch': 5780, 'epoch_time_sec': 19.33, 'lr': 0.0002926130833165469, 'train_loss': 0.011613, 'train_psnr': 25.1483, 'val_psnr': 24.0497, 'input_psnr': 23.1331, 'delta_psnr': 0.9166, 'best_val_psnr': 24.0599}
# {'epoch': 5781, 'epoch_time_sec': 19.41, 'lr': 0.0002920159021773372, 'train_loss': 0.011638, 'train_psnr': 25.1335, 'val_psnr': 24.0495, 'input_psnr': 23.1331, 'delta_psnr': 0.9165, 'best_val_psnr': 24.0599}
# {'epoch': 5782, 'epoch_time_sec': 19.35, 'lr': 0.0002913961925213089, 'train_loss': 0.011648, 'train_psnr': 25.1338, 'val_psnr': 24.0496, 'input_psnr': 23.1331, 'delta_psnr': 0.9165, 'best_val_psnr': 24.0599}
# {'epoch': 5783, 'epoch_time_sec': 19.34, 'lr': 0.00029075405624276186, 'train_loss': 0.011638, 'train_psnr': 25.133, 'val_psnr': 24.0495, 'input_psnr': 23.1331, 'delta_psnr': 0.9164, 'best_val_psnr': 24.0599}
# {'epoch': 5784, 'epoch_time_sec': 19.39, 'lr': 0.0002900895989234403, 'train_loss': 0.011613, 'train_psnr': 25.1462, 'val_psnr': 24.0494, 'input_psnr': 23.1331, 'delta_psnr': 0.9163, 'best_val_psnr': 24.0599}
# {'epoch': 5785, 'epoch_time_sec': 19.36, 'lr': 0.0002894029298151731, 'train_loss': 0.01162, 'train_psnr': 25.1416, 'val_psnr': 24.0493, 'input_psnr': 23.1331, 'delta_psnr': 0.9162, 'best_val_psnr': 24.0599}
# {'epoch': 5786, 'epoch_time_sec': 19.38, 'lr': 0.00028869416182191024, 'train_loss': 0.011633, 'train_psnr': 25.1343, 'val_psnr': 24.0489, 'input_psnr': 23.1331, 'delta_psnr': 0.9159, 'best_val_psnr': 24.0599}
# {'epoch': 5787, 'epoch_time_sec': 19.35, 'lr': 0.0002879634114811585, 'train_loss': 0.011635, 'train_psnr': 25.1364, 'val_psnr': 24.0488, 'input_psnr': 23.1331, 'delta_psnr': 0.9158, 'best_val_psnr': 24.0599}
# {'epoch': 5788, 'epoch_time_sec': 19.37, 'lr': 0.0002872107989448207, 'train_loss': 0.011616, 'train_psnr': 25.1458, 'val_psnr': 24.0488, 'input_psnr': 23.1331, 'delta_psnr': 0.9157, 'best_val_psnr': 24.0599}
# {'epoch': 5789, 'epoch_time_sec': 19.36, 'lr': 0.0002864364479594395, 'train_loss': 0.011614, 'train_psnr': 25.145, 'val_psnr': 24.0487, 'input_psnr': 23.1331, 'delta_psnr': 0.9156, 'best_val_psnr': 24.0599}
# {'epoch': 5790, 'epoch_time_sec': 19.32, 'lr': 0.00028564048584585073, 'train_loss': 0.011636, 'train_psnr': 25.1344, 'val_psnr': 24.0486, 'input_psnr': 23.1331, 'delta_psnr': 0.9155, 'best_val_psnr': 24.0599}
# {'epoch': 5791, 'epoch_time_sec': 19.41, 'lr': 0.0002848230434782492, 'train_loss': 0.011615, 'train_psnr': 25.1455, 'val_psnr': 24.0484, 'input_psnr': 23.1331, 'delta_psnr': 0.9153, 'best_val_psnr': 24.0599}
# {'epoch': 5792, 'epoch_time_sec': 19.35, 'lr': 0.0002839842552626697, 'train_loss': 0.011609, 'train_psnr': 25.1508, 'val_psnr': 24.0489, 'input_psnr': 23.1331, 'delta_psnr': 0.9159, 'best_val_psnr': 24.0599}
# {'epoch': 5793, 'epoch_time_sec': 19.36, 'lr': 0.0002831242591148879, 'train_loss': 0.011601, 'train_psnr': 25.1519, 'val_psnr': 24.0492, 'input_psnr': 23.1331, 'delta_psnr': 0.9161, 'best_val_psnr': 24.0599}
# {'epoch': 5794, 'epoch_time_sec': 19.37, 'lr': 0.00028224319643774373, 'train_loss': 0.011638, 'train_psnr': 25.1345, 'val_psnr': 24.0494, 'input_psnr': 23.1331, 'delta_psnr': 0.9164, 'best_val_psnr': 24.0599}
# {'epoch': 5795, 'epoch_time_sec': 19.34, 'lr': 0.00028134121209789144, 'train_loss': 0.011625, 'train_psnr': 25.1397, 'val_psnr': 24.0492, 'input_psnr': 23.1331, 'delta_psnr': 0.9162, 'best_val_psnr': 24.0599}
# {'epoch': 5796, 'epoch_time_sec': 19.38, 'lr': 0.00028041845440198056, 'train_loss': 0.011614, 'train_psnr': 25.145, 'val_psnr': 24.0492, 'input_psnr': 23.1331, 'delta_psnr': 0.9161, 'best_val_psnr': 24.0599}
# {'epoch': 5797, 'epoch_time_sec': 19.41, 'lr': 0.00027947507507227056, 'train_loss': 0.011627, 'train_psnr': 25.1357, 'val_psnr': 24.0492, 'input_psnr': 23.1331, 'delta_psnr': 0.9162, 'best_val_psnr': 24.0599}
# {'epoch': 5798, 'epoch_time_sec': 19.37, 'lr': 0.0002785112292216846, 'train_loss': 0.011625, 'train_psnr': 25.1391, 'val_psnr': 24.0493, 'input_psnr': 23.1331, 'delta_psnr': 0.9162, 'best_val_psnr': 24.0599}
# {'epoch': 5799, 'epoch_time_sec': 19.39, 'lr': 0.0002775270753283052, 'train_loss': 0.011627, 'train_psnr': 25.1409, 'val_psnr': 24.0493, 'input_psnr': 23.1331, 'delta_psnr': 0.9163, 'best_val_psnr': 24.0599}
# {'epoch': 5800, 'epoch_time_sec': 19.37, 'lr': 0.00027652277520931684, 'train_loss': 0.011623, 'train_psnr': 25.1407, 'val_psnr': 24.0493, 'input_psnr': 23.1331, 'delta_psnr': 0.9163, 'best_val_psnr': 24.0599}
# {'epoch': 5801, 'epoch_time_sec': 19.38, 'lr': 0.00027549849399440007, 'train_loss': 0.011615, 'train_psnr': 25.1443, 'val_psnr': 24.0493, 'input_psnr': 23.1331, 'delta_psnr': 0.9162, 'best_val_psnr': 24.0599}
# {'epoch': 5802, 'epoch_time_sec': 19.35, 'lr': 0.0002744544000985796, 'train_loss': 0.011614, 'train_psnr': 25.1457, 'val_psnr': 24.0493, 'input_psnr': 23.1331, 'delta_psnr': 0.9162, 'best_val_psnr': 24.0599}
# {'epoch': 5803, 'epoch_time_sec': 19.36, 'lr': 0.00027339066519453377, 'train_loss': 0.011612, 'train_psnr': 25.1455, 'val_psnr': 24.0494, 'input_psnr': 23.1331, 'delta_psnr': 0.9163, 'best_val_psnr': 24.0599}
# {'epoch': 5804, 'epoch_time_sec': 19.37, 'lr': 0.0002723074641843674, 'train_loss': 0.011606, 'train_psnr': 25.1499, 'val_psnr': 24.0495, 'input_psnr': 23.1331, 'delta_psnr': 0.9164, 'best_val_psnr': 24.0599}
# {'epoch': 5805, 'epoch_time_sec': 19.34, 'lr': 0.00027120497517085367, 'train_loss': 0.011616, 'train_psnr': 25.1428, 'val_psnr': 24.0494, 'input_psnr': 23.1331, 'delta_psnr': 0.9164, 'best_val_psnr': 24.0599}
# {'epoch': 5806, 'epoch_time_sec': 19.41, 'lr': 0.0002700833794281507, 'train_loss': 0.011627, 'train_psnr': 25.1419, 'val_psnr': 24.0495, 'input_psnr': 23.1331, 'delta_psnr': 0.9164, 'best_val_psnr': 24.0599}
# {'epoch': 5807, 'epoch_time_sec': 19.42, 'lr': 0.00026894286137199515, 'train_loss': 0.011611, 'train_psnr': 25.1485, 'val_psnr': 24.0493, 'input_psnr': 23.1331, 'delta_psnr': 0.9163, 'best_val_psnr': 24.0599}
# {'epoch': 5808, 'epoch_time_sec': 19.38, 'lr': 0.0002677836085293806, 'train_loss': 0.011621, 'train_psnr': 25.141, 'val_psnr': 24.0492, 'input_psnr': 23.1331, 'delta_psnr': 0.9161, 'best_val_psnr': 24.0599}
# {'epoch': 5809, 'epoch_time_sec': 19.38, 'lr': 0.00026660581150772387, 'train_loss': 0.01161, 'train_psnr': 25.145, 'val_psnr': 24.0488, 'input_psnr': 23.1331, 'delta_psnr': 0.9157, 'best_val_psnr': 24.0599}
# {'epoch': 5810, 'epoch_time_sec': 19.41, 'lr': 0.0002654096639635245, 'train_loss': 0.011596, 'train_psnr': 25.1555, 'val_psnr': 24.049, 'input_psnr': 23.1331, 'delta_psnr': 0.9159, 'best_val_psnr': 24.0599}
# {'epoch': 5811, 'epoch_time_sec': 19.35, 'lr': 0.00026419536257052357, 'train_loss': 0.011607, 'train_psnr': 25.1502, 'val_psnr': 24.0494, 'input_psnr': 23.1331, 'delta_psnr': 0.9163, 'best_val_psnr': 24.0599}
# {'epoch': 5812, 'epoch_time_sec': 19.43, 'lr': 0.000262963106987366, 'train_loss': 0.011614, 'train_psnr': 25.1449, 'val_psnr': 24.0495, 'input_psnr': 23.1331, 'delta_psnr': 0.9164, 'best_val_psnr': 24.0599}
# {'epoch': 5813, 'epoch_time_sec': 19.4, 'lr': 0.00026171309982477204, 'train_loss': 0.0116, 'train_psnr': 25.1534, 'val_psnr': 24.0499, 'input_psnr': 23.1331, 'delta_psnr': 0.9169, 'best_val_psnr': 24.0599}
# {'epoch': 5814, 'epoch_time_sec': 19.35, 'lr': 0.0002604455466122236, 'train_loss': 0.011601, 'train_psnr': 25.1526, 'val_psnr': 24.0498, 'input_psnr': 23.1331, 'delta_psnr': 0.9167, 'best_val_psnr': 24.0599}
# {'epoch': 5815, 'epoch_time_sec': 19.39, 'lr': 0.0002591606557641705, 'train_loss': 0.01159, 'train_psnr': 25.1587, 'val_psnr': 24.05, 'input_psnr': 23.1331, 'delta_psnr': 0.917, 'best_val_psnr': 24.0599}
# {'epoch': 5816, 'epoch_time_sec': 19.39, 'lr': 0.00025785863854576235, 'train_loss': 0.011605, 'train_psnr': 25.1504, 'val_psnr': 24.0501, 'input_psnr': 23.1331, 'delta_psnr': 0.9171, 'best_val_psnr': 24.0599}
# {'epoch': 5817, 'epoch_time_sec': 19.36, 'lr': 0.00025653970903811193, 'train_loss': 0.01162, 'train_psnr': 25.1457, 'val_psnr': 24.0502, 'input_psnr': 23.1331, 'delta_psnr': 0.9171, 'best_val_psnr': 24.0599}
# {'epoch': 5818, 'epoch_time_sec': 19.36, 'lr': 0.0002552040841030954, 'train_loss': 0.01161, 'train_psnr': 25.1453, 'val_psnr': 24.0501, 'input_psnr': 23.1331, 'delta_psnr': 0.917, 'best_val_psnr': 24.0599}
# {'epoch': 5819, 'epoch_time_sec': 19.42, 'lr': 0.0002538519833476949, 'train_loss': 0.011616, 'train_psnr': 25.1458, 'val_psnr': 24.0505, 'input_psnr': 23.1331, 'delta_psnr': 0.9174, 'best_val_psnr': 24.0599}
# {'epoch': 5820, 'epoch_time_sec': 19.35, 'lr': 0.0002524836290878909, 'train_loss': 0.011604, 'train_psnr': 25.1526, 'val_psnr': 24.0505, 'input_psnr': 23.1331, 'delta_psnr': 0.9175, 'best_val_psnr': 24.0599}
# {'epoch': 5821, 'epoch_time_sec': 19.38, 'lr': 0.0002510992463121078, 'train_loss': 0.011596, 'train_psnr': 25.1564, 'val_psnr': 24.0504, 'input_psnr': 23.1331, 'delta_psnr': 0.9173, 'best_val_psnr': 24.0599}
# {'epoch': 5822, 'epoch_time_sec': 19.42, 'lr': 0.000249699062644221, 'train_loss': 0.011599, 'train_psnr': 25.1551, 'val_psnr': 24.0506, 'input_psnr': 23.1331, 'delta_psnr': 0.9176, 'best_val_psnr': 24.0599}
# {'epoch': 5823, 'epoch_time_sec': 19.37, 'lr': 0.00024828330830613043, 'train_loss': 0.011601, 'train_psnr': 25.1513, 'val_psnr': 24.0509, 'input_psnr': 23.1331, 'delta_psnr': 0.9179, 'best_val_psnr': 24.0599}
# {'epoch': 5824, 'epoch_time_sec': 19.39, 'lr': 0.0002468522160799066, 'train_loss': 0.011621, 'train_psnr': 25.1443, 'val_psnr': 24.0508, 'input_psnr': 23.1331, 'delta_psnr': 0.9178, 'best_val_psnr': 24.0599}
# {'epoch': 5825, 'epoch_time_sec': 19.4, 'lr': 0.00024540602126951636, 'train_loss': 0.011608, 'train_psnr': 25.1534, 'val_psnr': 24.0506, 'input_psnr': 23.1331, 'delta_psnr': 0.9176, 'best_val_psnr': 24.0599}
# {'epoch': 5826, 'epoch_time_sec': 19.42, 'lr': 0.00024394496166213313, 'train_loss': 0.011601, 'train_psnr': 25.1538, 'val_psnr': 24.0507, 'input_psnr': 23.1331, 'delta_psnr': 0.9177, 'best_val_psnr': 24.0599}
# {'epoch': 5827, 'epoch_time_sec': 19.37, 'lr': 0.0002424692774890397, 'train_loss': 0.011581, 'train_psnr': 25.1651, 'val_psnr': 24.051, 'input_psnr': 23.1331, 'delta_psnr': 0.9179, 'best_val_psnr': 24.0599}
# {'epoch': 5828, 'epoch_time_sec': 19.43, 'lr': 0.00024097921138612868, 'train_loss': 0.011603, 'train_psnr': 25.1525, 'val_psnr': 24.051, 'input_psnr': 23.1331, 'delta_psnr': 0.918, 'best_val_psnr': 24.0599}
# {'epoch': 5829, 'epoch_time_sec': 19.38, 'lr': 0.00023947500835400738, 'train_loss': 0.011606, 'train_psnr': 25.1516, 'val_psnr': 24.051, 'input_psnr': 23.1331, 'delta_psnr': 0.9179, 'best_val_psnr': 24.0599}
# {'epoch': 5830, 'epoch_time_sec': 19.42, 'lr': 0.00023795691571771457, 'train_loss': 0.011586, 'train_psnr': 25.1617, 'val_psnr': 24.051, 'input_psnr': 23.1331, 'delta_psnr': 0.9179, 'best_val_psnr': 24.0599}
# {'epoch': 5831, 'epoch_time_sec': 19.37, 'lr': 0.0002364251830860543, 'train_loss': 0.0116, 'train_psnr': 25.154, 'val_psnr': 24.0511, 'input_psnr': 23.1331, 'delta_psnr': 0.918, 'best_val_psnr': 24.0599}
# {'epoch': 5832, 'epoch_time_sec': 19.4, 'lr': 0.00023488006231055483, 'train_loss': 0.011595, 'train_psnr': 25.1562, 'val_psnr': 24.0512, 'input_psnr': 23.1331, 'delta_psnr': 0.9181, 'best_val_psnr': 24.0599}
# {'epoch': 5833, 'epoch_time_sec': 19.34, 'lr': 0.00023332180744405838, 'train_loss': 0.011603, 'train_psnr': 25.1534, 'val_psnr': 24.0513, 'input_psnr': 23.1331, 'delta_psnr': 0.9183, 'best_val_psnr': 24.0599}
# {'epoch': 5834, 'epoch_time_sec': 19.39, 'lr': 0.00023175067469894913, 'train_loss': 0.011591, 'train_psnr': 25.1589, 'val_psnr': 24.0515, 'input_psnr': 23.1331, 'delta_psnr': 0.9185, 'best_val_psnr': 24.0599}
# {'epoch': 5835, 'epoch_time_sec': 19.4, 'lr': 0.00023016692240502613, 'train_loss': 0.011608, 'train_psnr': 25.149, 'val_psnr': 24.0516, 'input_psnr': 23.1331, 'delta_psnr': 0.9186, 'best_val_psnr': 24.0599}
# {'epoch': 5836, 'epoch_time_sec': 19.42, 'lr': 0.00022857081096702787, 'train_loss': 0.01159, 'train_psnr': 25.1571, 'val_psnr': 24.0518, 'input_psnr': 23.1331, 'delta_psnr': 0.9187, 'best_val_psnr': 24.0599}
# {'epoch': 5837, 'epoch_time_sec': 19.4, 'lr': 0.00022696260282181624, 'train_loss': 0.011599, 'train_psnr': 25.1559, 'val_psnr': 24.0515, 'input_psnr': 23.1331, 'delta_psnr': 0.9185, 'best_val_psnr': 24.0599}
# {'epoch': 5838, 'epoch_time_sec': 19.33, 'lr': 0.0002253425623952254, 'train_loss': 0.011599, 'train_psnr': 25.1528, 'val_psnr': 24.0515, 'input_psnr': 23.1331, 'delta_psnr': 0.9185, 'best_val_psnr': 24.0599}
# {'epoch': 5839, 'epoch_time_sec': 19.35, 'lr': 0.00022371095605858477, 'train_loss': 0.011574, 'train_psnr': 25.1672, 'val_psnr': 24.0518, 'input_psnr': 23.1331, 'delta_psnr': 0.9188, 'best_val_psnr': 24.0599}
# {'epoch': 5840, 'epoch_time_sec': 19.4, 'lr': 0.0002220680520849211, 'train_loss': 0.011607, 'train_psnr': 25.1532, 'val_psnr': 24.0519, 'input_psnr': 23.1331, 'delta_psnr': 0.9189, 'best_val_psnr': 24.0599}
# {'epoch': 5841, 'epoch_time_sec': 19.41, 'lr': 0.00022041412060484848, 'train_loss': 0.011582, 'train_psnr': 25.1636, 'val_psnr': 24.0522, 'input_psnr': 23.1331, 'delta_psnr': 0.9191, 'best_val_psnr': 24.0599}
# {'epoch': 5842, 'epoch_time_sec': 19.42, 'lr': 0.00021874943356215288, 'train_loss': 0.011604, 'train_psnr': 25.1548, 'val_psnr': 24.0524, 'input_psnr': 23.1331, 'delta_psnr': 0.9193, 'best_val_psnr': 24.0599}
# {'epoch': 5843, 'epoch_time_sec': 19.33, 'lr': 0.0002170742646690782, 'train_loss': 0.01159, 'train_psnr': 25.1599, 'val_psnr': 24.0526, 'input_psnr': 23.1331, 'delta_psnr': 0.9196, 'best_val_psnr': 24.0599}
# {'epoch': 5844, 'epoch_time_sec': 19.4, 'lr': 0.00021538888936132182, 'train_loss': 0.011584, 'train_psnr': 25.1644, 'val_psnr': 24.0527, 'input_psnr': 23.1331, 'delta_psnr': 0.9196, 'best_val_psnr': 24.0599}
# {'epoch': 5845, 'epoch_time_sec': 19.39, 'lr': 0.00021369358475274705, 'train_loss': 0.011582, 'train_psnr': 25.1636, 'val_psnr': 24.0528, 'input_psnr': 23.1331, 'delta_psnr': 0.9198, 'best_val_psnr': 24.0599}
# {'epoch': 5846, 'epoch_time_sec': 19.37, 'lr': 0.0002119886295898189, 'train_loss': 0.011586, 'train_psnr': 25.1622, 'val_psnr': 24.0529, 'input_psnr': 23.1331, 'delta_psnr': 0.9198, 'best_val_psnr': 24.0599}
# {'epoch': 5847, 'epoch_time_sec': 19.35, 'lr': 0.00021027430420577202, 'train_loss': 0.011591, 'train_psnr': 25.1593, 'val_psnr': 24.0529, 'input_psnr': 23.1331, 'delta_psnr': 0.9199, 'best_val_psnr': 24.0599}
# {'epoch': 5848, 'epoch_time_sec': 19.31, 'lr': 0.00020855089047451764, 'train_loss': 0.011581, 'train_psnr': 25.164, 'val_psnr': 24.053, 'input_psnr': 23.1331, 'delta_psnr': 0.9199, 'best_val_psnr': 24.0599}
# {'epoch': 5849, 'epoch_time_sec': 19.38, 'lr': 0.00020681867176429713, 'train_loss': 0.011596, 'train_psnr': 25.1583, 'val_psnr': 24.0529, 'input_psnr': 23.1331, 'delta_psnr': 0.9198, 'best_val_psnr': 24.0599}
# {'epoch': 5850, 'epoch_time_sec': 19.36, 'lr': 0.00020507793289108956, 'train_loss': 0.011598, 'train_psnr': 25.158, 'val_psnr': 24.053, 'input_psnr': 23.1331, 'delta_psnr': 0.9199, 'best_val_psnr': 24.0599}
# {'epoch': 5851, 'epoch_time_sec': 19.39, 'lr': 0.00020332896007178202, 'train_loss': 0.01159, 'train_psnr': 25.1637, 'val_psnr': 24.0531, 'input_psnr': 23.1331, 'delta_psnr': 0.9201, 'best_val_psnr': 24.0599}
# {'epoch': 5852, 'epoch_time_sec': 19.37, 'lr': 0.0002015720408771086, 'train_loss': 0.011577, 'train_psnr': 25.1687, 'val_psnr': 24.0534, 'input_psnr': 23.1331, 'delta_psnr': 0.9203, 'best_val_psnr': 24.0599}
# {'epoch': 5853, 'epoch_time_sec': 19.39, 'lr': 0.00019980746418436736, 'train_loss': 0.011575, 'train_psnr': 25.1687, 'val_psnr': 24.0536, 'input_psnr': 23.1331, 'delta_psnr': 0.9205, 'best_val_psnr': 24.0599}
# {'epoch': 5854, 'epoch_time_sec': 19.42, 'lr': 0.00019803552012992258, 'train_loss': 0.011586, 'train_psnr': 25.1623, 'val_psnr': 24.0534, 'input_psnr': 23.1331, 'delta_psnr': 0.9204, 'best_val_psnr': 24.0599}
# {'epoch': 5855, 'epoch_time_sec': 19.42, 'lr': 0.00019625650006149965, 'train_loss': 0.011574, 'train_psnr': 25.1699, 'val_psnr': 24.0538, 'input_psnr': 23.1331, 'delta_psnr': 0.9207, 'best_val_psnr': 24.0599}
# {'epoch': 5856, 'epoch_time_sec': 19.38, 'lr': 0.0001944706964902808, 'train_loss': 0.011572, 'train_psnr': 25.1706, 'val_psnr': 24.054, 'input_psnr': 23.1331, 'delta_psnr': 0.921, 'best_val_psnr': 24.0599}
# {'epoch': 5857, 'epoch_time_sec': 19.37, 'lr': 0.00019267840304280966, 'train_loss': 0.011574, 'train_psnr': 25.1678, 'val_psnr': 24.0542, 'input_psnr': 23.1331, 'delta_psnr': 0.9212, 'best_val_psnr': 24.0599}
# {'epoch': 5858, 'epoch_time_sec': 19.37, 'lr': 0.00019087991441271254, 'train_loss': 0.011577, 'train_psnr': 25.1685, 'val_psnr': 24.0547, 'input_psnr': 23.1331, 'delta_psnr': 0.9216, 'best_val_psnr': 24.0599}
# {'epoch': 5859, 'epoch_time_sec': 19.37, 'lr': 0.00018907552631224417, 'train_loss': 0.011583, 'train_psnr': 25.1656, 'val_psnr': 24.0547, 'input_psnr': 23.1331, 'delta_psnr': 0.9216, 'best_val_psnr': 24.0599}
# {'epoch': 5860, 'epoch_time_sec': 19.4, 'lr': 0.00018726553542366555, 'train_loss': 0.011575, 'train_psnr': 25.1666, 'val_psnr': 24.0547, 'input_psnr': 23.1331, 'delta_psnr': 0.9217, 'best_val_psnr': 24.0599}
# {'epoch': 5861, 'epoch_time_sec': 19.39, 'lr': 0.00018545023935046312, 'train_loss': 0.011563, 'train_psnr': 25.1763, 'val_psnr': 24.055, 'input_psnr': 23.1331, 'delta_psnr': 0.9219, 'best_val_psnr': 24.0599}
# {'epoch': 5862, 'epoch_time_sec': 19.35, 'lr': 0.0001836299365684157, 'train_loss': 0.011574, 'train_psnr': 25.1705, 'val_psnr': 24.0551, 'input_psnr': 23.1331, 'delta_psnr': 0.922, 'best_val_psnr': 24.0599}
# {'epoch': 5863, 'epoch_time_sec': 19.35, 'lr': 0.00018180492637651845, 'train_loss': 0.011573, 'train_psnr': 25.1699, 'val_psnr': 24.0551, 'input_psnr': 23.1331, 'delta_psnr': 0.9221, 'best_val_psnr': 24.0599}
# {'epoch': 5864, 'epoch_time_sec': 19.36, 'lr': 0.0001799755088477712, 'train_loss': 0.011571, 'train_psnr': 25.1709, 'val_psnr': 24.0551, 'input_psnr': 23.1331, 'delta_psnr': 0.922, 'best_val_psnr': 24.0599}
# {'epoch': 5865, 'epoch_time_sec': 19.39, 'lr': 0.00017814198477983996, 'train_loss': 0.01157, 'train_psnr': 25.1722, 'val_psnr': 24.0551, 'input_psnr': 23.1331, 'delta_psnr': 0.9221, 'best_val_psnr': 24.0599}
# {'epoch': 5866, 'epoch_time_sec': 19.38, 'lr': 0.0001763046556455986, 'train_loss': 0.011567, 'train_psnr': 25.1716, 'val_psnr': 24.0553, 'input_psnr': 23.1331, 'delta_psnr': 0.9223, 'best_val_psnr': 24.0599}
# {'epoch': 5867, 'epoch_time_sec': 19.33, 'lr': 0.00017446382354356, 'train_loss': 0.011563, 'train_psnr': 25.1751, 'val_psnr': 24.0555, 'input_psnr': 23.1331, 'delta_psnr': 0.9224, 'best_val_psnr': 24.0599}
# {'epoch': 5868, 'epoch_time_sec': 19.37, 'lr': 0.00017261979114820453, 'train_loss': 0.011576, 'train_psnr': 25.1688, 'val_psnr': 24.0555, 'input_psnr': 23.1331, 'delta_psnr': 0.9224, 'best_val_psnr': 24.0599}
# {'epoch': 5869, 'epoch_time_sec': 19.35, 'lr': 0.00017077286166021296, 'train_loss': 0.011585, 'train_psnr': 25.1647, 'val_psnr': 24.0556, 'input_psnr': 23.1331, 'delta_psnr': 0.9225, 'best_val_psnr': 24.0599}
# {'epoch': 5870, 'epoch_time_sec': 19.37, 'lr': 0.00016892333875661382, 'train_loss': 0.011582, 'train_psnr': 25.166, 'val_psnr': 24.0557, 'input_psnr': 23.1331, 'delta_psnr': 0.9226, 'best_val_psnr': 24.0599}
# {'epoch': 5871, 'epoch_time_sec': 19.38, 'lr': 0.00016707152654085194, 'train_loss': 0.011561, 'train_psnr': 25.1757, 'val_psnr': 24.0558, 'input_psnr': 23.1331, 'delta_psnr': 0.9228, 'best_val_psnr': 24.0599}
# {'epoch': 5872, 'epoch_time_sec': 19.36, 'lr': 0.0001652177294927868, 'train_loss': 0.01156, 'train_psnr': 25.1775, 'val_psnr': 24.056, 'input_psnr': 23.1331, 'delta_psnr': 0.9229, 'best_val_psnr': 24.0599}
# {'epoch': 5873, 'epoch_time_sec': 19.36, 'lr': 0.00016336225241862928, 'train_loss': 0.011587, 'train_psnr': 25.1615, 'val_psnr': 24.0559, 'input_psnr': 23.1331, 'delta_psnr': 0.9228, 'best_val_psnr': 24.0599}
# {'epoch': 5874, 'epoch_time_sec': 19.41, 'lr': 0.00016150540040082466, 'train_loss': 0.011566, 'train_psnr': 25.174, 'val_psnr': 24.056, 'input_psnr': 23.1331, 'delta_psnr': 0.923, 'best_val_psnr': 24.0599}
# {'epoch': 5875, 'epoch_time_sec': 19.4, 'lr': 0.00015964747874789, 'train_loss': 0.011557, 'train_psnr': 25.1795, 'val_psnr': 24.056, 'input_psnr': 23.1331, 'delta_psnr': 0.923, 'best_val_psnr': 24.0599}
# {'epoch': 5876, 'epoch_time_sec': 19.38, 'lr': 0.0001577887929442146, 'train_loss': 0.011563, 'train_psnr': 25.1739, 'val_psnr': 24.0562, 'input_psnr': 23.1331, 'delta_psnr': 0.9231, 'best_val_psnr': 24.0599}
# {'epoch': 5877, 'epoch_time_sec': 19.37, 'lr': 0.00015592964859983158, 'train_loss': 0.011571, 'train_psnr': 25.1699, 'val_psnr': 24.0562, 'input_psnr': 23.1331, 'delta_psnr': 0.9231, 'best_val_psnr': 24.0599}
# {'epoch': 5878, 'epoch_time_sec': 19.34, 'lr': 0.00015407035140016837, 'train_loss': 0.011566, 'train_psnr': 25.1743, 'val_psnr': 24.0563, 'input_psnr': 23.1331, 'delta_psnr': 0.9233, 'best_val_psnr': 24.0599}
# {'epoch': 5879, 'epoch_time_sec': 19.39, 'lr': 0.00015221120705578536, 'train_loss': 0.011557, 'train_psnr': 25.1803, 'val_psnr': 24.0566, 'input_psnr': 23.1331, 'delta_psnr': 0.9236, 'best_val_psnr': 24.0599}
# {'epoch': 5880, 'epoch_time_sec': 19.43, 'lr': 0.00015035252125210997, 'train_loss': 0.011563, 'train_psnr': 25.174, 'val_psnr': 24.0566, 'input_psnr': 23.1331, 'delta_psnr': 0.9235, 'best_val_psnr': 24.0599}
# {'epoch': 5881, 'epoch_time_sec': 19.33, 'lr': 0.00014849459959917537, 'train_loss': 0.01156, 'train_psnr': 25.1783, 'val_psnr': 24.0568, 'input_psnr': 23.1331, 'delta_psnr': 0.9237, 'best_val_psnr': 24.0599}
# {'epoch': 5882, 'epoch_time_sec': 19.38, 'lr': 0.0001466377475813707, 'train_loss': 0.011552, 'train_psnr': 25.1805, 'val_psnr': 24.057, 'input_psnr': 23.1331, 'delta_psnr': 0.9239, 'best_val_psnr': 24.0599}
# {'epoch': 5883, 'epoch_time_sec': 19.34, 'lr': 0.00014478227050721313, 'train_loss': 0.011556, 'train_psnr': 25.1792, 'val_psnr': 24.057, 'input_psnr': 23.1331, 'delta_psnr': 0.9239, 'best_val_psnr': 24.0599}
# {'epoch': 5884, 'epoch_time_sec': 19.39, 'lr': 0.00014292847345914804, 'train_loss': 0.011564, 'train_psnr': 25.1774, 'val_psnr': 24.057, 'input_psnr': 23.1331, 'delta_psnr': 0.9239, 'best_val_psnr': 24.0599}
# {'epoch': 5885, 'epoch_time_sec': 19.39, 'lr': 0.00014107666124338613, 'train_loss': 0.011548, 'train_psnr': 25.1822, 'val_psnr': 24.0571, 'input_psnr': 23.1331, 'delta_psnr': 0.924, 'best_val_psnr': 24.0599}
# {'epoch': 5886, 'epoch_time_sec': 19.38, 'lr': 0.00013922713833978701, 'train_loss': 0.011552, 'train_psnr': 25.1809, 'val_psnr': 24.0571, 'input_psnr': 23.1331, 'delta_psnr': 0.924, 'best_val_psnr': 24.0599}
# {'epoch': 5887, 'epoch_time_sec': 19.35, 'lr': 0.0001373802088517954, 'train_loss': 0.011554, 'train_psnr': 25.1818, 'val_psnr': 24.0572, 'input_psnr': 23.1331, 'delta_psnr': 0.9242, 'best_val_psnr': 24.0599}
# {'epoch': 5888, 'epoch_time_sec': 19.32, 'lr': 0.00013553617645643997, 'train_loss': 0.011567, 'train_psnr': 25.1754, 'val_psnr': 24.0574, 'input_psnr': 23.1331, 'delta_psnr': 0.9243, 'best_val_psnr': 24.0599}
# {'epoch': 5889, 'epoch_time_sec': 19.39, 'lr': 0.00013369534435440138, 'train_loss': 0.011556, 'train_psnr': 25.1808, 'val_psnr': 24.0573, 'input_psnr': 23.1331, 'delta_psnr': 0.9242, 'best_val_psnr': 24.0599}
# {'epoch': 5890, 'epoch_time_sec': 19.41, 'lr': 0.00013185801522016004, 'train_loss': 0.011552, 'train_psnr': 25.1816, 'val_psnr': 24.0575, 'input_psnr': 23.1331, 'delta_psnr': 0.9245, 'best_val_psnr': 24.0599}
# {'epoch': 5891, 'epoch_time_sec': 19.4, 'lr': 0.00013002449115222877, 'train_loss': 0.011565, 'train_psnr': 25.1768, 'val_psnr': 24.0576, 'input_psnr': 23.1331, 'delta_psnr': 0.9245, 'best_val_psnr': 24.0599}
# {'epoch': 5892, 'epoch_time_sec': 19.4, 'lr': 0.00012819507362348153, 'train_loss': 0.011551, 'train_psnr': 25.1823, 'val_psnr': 24.0577, 'input_psnr': 23.1331, 'delta_psnr': 0.9246, 'best_val_psnr': 24.0599}
# {'epoch': 5893, 'epoch_time_sec': 19.33, 'lr': 0.00012637006343158426, 'train_loss': 0.011546, 'train_psnr': 25.1847, 'val_psnr': 24.0578, 'input_psnr': 23.1331, 'delta_psnr': 0.9247, 'best_val_psnr': 24.0599}
# {'epoch': 5894, 'epoch_time_sec': 19.41, 'lr': 0.00012454976064953682, 'train_loss': 0.011555, 'train_psnr': 25.1804, 'val_psnr': 24.0578, 'input_psnr': 23.1331, 'delta_psnr': 0.9248, 'best_val_psnr': 24.0599}
# {'epoch': 5895, 'epoch_time_sec': 19.37, 'lr': 0.0001227344645763344, 'train_loss': 0.011547, 'train_psnr': 25.1846, 'val_psnr': 24.0579, 'input_psnr': 23.1331, 'delta_psnr': 0.9249, 'best_val_psnr': 24.0599}
# {'epoch': 5896, 'epoch_time_sec': 19.42, 'lr': 0.00012092447368775578, 'train_loss': 0.011551, 'train_psnr': 25.1808, 'val_psnr': 24.0581, 'input_psnr': 23.1331, 'delta_psnr': 0.9251, 'best_val_psnr': 24.0599}
# {'epoch': 5897, 'epoch_time_sec': 19.37, 'lr': 0.00011912008558728743, 'train_loss': 0.011557, 'train_psnr': 25.1789, 'val_psnr': 24.0582, 'input_psnr': 23.1331, 'delta_psnr': 0.9251, 'best_val_psnr': 24.0599}
# {'epoch': 5898, 'epoch_time_sec': 19.42, 'lr': 0.00011732159695719033, 'train_loss': 0.011544, 'train_psnr': 25.1875, 'val_psnr': 24.0583, 'input_psnr': 23.1331, 'delta_psnr': 0.9253, 'best_val_psnr': 24.0599}
# {'epoch': 5899, 'epoch_time_sec': 19.36, 'lr': 0.00011552930350971917, 'train_loss': 0.01155, 'train_psnr': 25.1833, 'val_psnr': 24.0584, 'input_psnr': 23.1331, 'delta_psnr': 0.9253, 'best_val_psnr': 24.0599}
# {'epoch': 5900, 'epoch_time_sec': 19.44, 'lr': 0.00011374349993850028, 'train_loss': 0.011538, 'train_psnr': 25.1893, 'val_psnr': 24.0584, 'input_psnr': 23.1331, 'delta_psnr': 0.9253, 'best_val_psnr': 24.0599}
# {'epoch': 5901, 'epoch_time_sec': 19.41, 'lr': 0.00011196447987007734, 'train_loss': 0.011548, 'train_psnr': 25.1822, 'val_psnr': 24.0584, 'input_psnr': 23.1331, 'delta_psnr': 0.9253, 'best_val_psnr': 24.0599}
# {'epoch': 5902, 'epoch_time_sec': 19.38, 'lr': 0.00011019253581563262, 'train_loss': 0.01154, 'train_psnr': 25.1882, 'val_psnr': 24.0587, 'input_psnr': 23.1331, 'delta_psnr': 0.9256, 'best_val_psnr': 24.0599}
# {'epoch': 5903, 'epoch_time_sec': 19.33, 'lr': 0.00010842795912289138, 'train_loss': 0.011558, 'train_psnr': 25.1813, 'val_psnr': 24.0588, 'input_psnr': 23.1331, 'delta_psnr': 0.9258, 'best_val_psnr': 24.0599}
# {'epoch': 5904, 'epoch_time_sec': 19.37, 'lr': 0.00010667103992821795, 'train_loss': 0.011536, 'train_psnr': 25.1917, 'val_psnr': 24.059, 'input_psnr': 23.1331, 'delta_psnr': 0.9259, 'best_val_psnr': 24.0599}
# {'epoch': 5905, 'epoch_time_sec': 19.37, 'lr': 0.0001049220671089104, 'train_loss': 0.011547, 'train_psnr': 25.187, 'val_psnr': 24.059, 'input_psnr': 23.1331, 'delta_psnr': 0.926, 'best_val_psnr': 24.0599}
# {'epoch': 5906, 'epoch_time_sec': 19.39, 'lr': 0.00010318132823570289, 'train_loss': 0.011546, 'train_psnr': 25.1844, 'val_psnr': 24.059, 'input_psnr': 23.1331, 'delta_psnr': 0.9259, 'best_val_psnr': 24.0599}
# {'epoch': 5907, 'epoch_time_sec': 19.4, 'lr': 0.00010144910952548234, 'train_loss': 0.011534, 'train_psnr': 25.1905, 'val_psnr': 24.0591, 'input_psnr': 23.1331, 'delta_psnr': 0.9261, 'best_val_psnr': 24.0599}
# {'epoch': 5908, 'epoch_time_sec': 19.38, 'lr': 9.972569579422794e-05, 'train_loss': 0.011562, 'train_psnr': 25.1791, 'val_psnr': 24.059, 'input_psnr': 23.1331, 'delta_psnr': 0.926, 'best_val_psnr': 24.0599}
# {'epoch': 5909, 'epoch_time_sec': 19.38, 'lr': 9.801137041018106e-05, 'train_loss': 0.011532, 'train_psnr': 25.1941, 'val_psnr': 24.0593, 'input_psnr': 23.1331, 'delta_psnr': 0.9263, 'best_val_psnr': 24.0599}
# {'epoch': 5910, 'epoch_time_sec': 19.4, 'lr': 9.630641524725288e-05, 'train_loss': 0.011541, 'train_psnr': 25.1897, 'val_psnr': 24.0593, 'input_psnr': 23.1331, 'delta_psnr': 0.9263, 'best_val_psnr': 24.0599}
# {'epoch': 5911, 'epoch_time_sec': 19.41, 'lr': 9.461111063867816e-05, 'train_loss': 0.011533, 'train_psnr': 25.1921, 'val_psnr': 24.0596, 'input_psnr': 23.1331, 'delta_psnr': 0.9265, 'best_val_psnr': 24.0599}
# {'epoch': 5912, 'epoch_time_sec': 19.37, 'lr': 9.292573533092183e-05, 'train_loss': 0.011534, 'train_psnr': 25.1925, 'val_psnr': 24.0596, 'input_psnr': 23.1331, 'delta_psnr': 0.9266, 'best_val_psnr': 24.0599}
# {'epoch': 5913, 'epoch_time_sec': 19.39, 'lr': 9.125056643784709e-05, 'train_loss': 0.011556, 'train_psnr': 25.1819, 'val_psnr': 24.0598, 'input_psnr': 23.1331, 'delta_psnr': 0.9267, 'best_val_psnr': 24.0599}
# {'epoch': 5914, 'epoch_time_sec': 19.35, 'lr': 8.958587939515144e-05, 'train_loss': 0.011529, 'train_psnr': 25.1961, 'val_psnr': 24.0599, 'input_psnr': 23.1331, 'delta_psnr': 0.9269, 'best_val_psnr': 24.0599}
# {'epoch': 5915, 'epoch_time_sec': 19.41, 'lr': 8.79319479150789e-05, 'train_loss': 0.01153, 'train_psnr': 25.1927, 'val_psnr': 24.0599, 'input_psnr': 23.1331, 'delta_psnr': 0.9268, 'best_val_psnr': 24.0599}
# {'epoch': 5916, 'epoch_time_sec': 19.43, 'lr': 8.628904394141518e-05, 'train_loss': 0.011537, 'train_psnr': 25.192, 'val_psnr': 24.0602, 'input_psnr': 23.1331, 'delta_psnr': 0.9271, 'best_val_psnr': 24.0602}
# {'epoch': 5917, 'epoch_time_sec': 19.35, 'lr': 8.465743760477452e-05, 'train_loss': 0.011538, 'train_psnr': 25.1912, 'val_psnr': 24.0602, 'input_psnr': 23.1331, 'delta_psnr': 0.9272, 'best_val_psnr': 24.0602}
# {'epoch': 5918, 'epoch_time_sec': 19.4, 'lr': 8.303739717818377e-05, 'train_loss': 0.011542, 'train_psnr': 25.1885, 'val_psnr': 24.0602, 'input_psnr': 23.1331, 'delta_psnr': 0.9272, 'best_val_psnr': 24.0602}
# {'epoch': 5919, 'epoch_time_sec': 19.38, 'lr': 8.142918903297209e-05, 'train_loss': 0.011533, 'train_psnr': 25.1923, 'val_psnr': 24.0603, 'input_psnr': 23.1331, 'delta_psnr': 0.9273, 'best_val_psnr': 24.0603}
# {'epoch': 5920, 'epoch_time_sec': 19.38, 'lr': 7.983307759497386e-05, 'train_loss': 0.011529, 'train_psnr': 25.1947, 'val_psnr': 24.0603, 'input_psnr': 23.1331, 'delta_psnr': 0.9272, 'best_val_psnr': 24.0603}
# {'epoch': 5921, 'epoch_time_sec': 19.36, 'lr': 7.82493253010508e-05, 'train_loss': 0.011532, 'train_psnr': 25.1945, 'val_psnr': 24.0604, 'input_psnr': 23.1331, 'delta_psnr': 0.9273, 'best_val_psnr': 24.0604}
# {'epoch': 5922, 'epoch_time_sec': 19.37, 'lr': 7.66781925559416e-05, 'train_loss': 0.011542, 'train_psnr': 25.1918, 'val_psnr': 24.0605, 'input_psnr': 23.1331, 'delta_psnr': 0.9274, 'best_val_psnr': 24.0605}
# {'epoch': 5923, 'epoch_time_sec': 19.41, 'lr': 7.511993768944513e-05, 'train_loss': 0.011524, 'train_psnr': 25.1974, 'val_psnr': 24.0605, 'input_psnr': 23.1331, 'delta_psnr': 0.9274, 'best_val_psnr': 24.0605}
# {'epoch': 5924, 'epoch_time_sec': 19.4, 'lr': 7.357481691394564e-05, 'train_loss': 0.011527, 'train_psnr': 25.1933, 'val_psnr': 24.0606, 'input_psnr': 23.1331, 'delta_psnr': 0.9276, 'best_val_psnr': 24.0606}
# {'epoch': 5925, 'epoch_time_sec': 19.39, 'lr': 7.204308428228542e-05, 'train_loss': 0.011526, 'train_psnr': 25.1966, 'val_psnr': 24.0607, 'input_psnr': 23.1331, 'delta_psnr': 0.9276, 'best_val_psnr': 24.0607}
# {'epoch': 5926, 'epoch_time_sec': 19.38, 'lr': 7.052499164599257e-05, 'train_loss': 0.011525, 'train_psnr': 25.1969, 'val_psnr': 24.0607, 'input_psnr': 23.1331, 'delta_psnr': 0.9277, 'best_val_psnr': 24.0607}
# {'epoch': 5927, 'epoch_time_sec': 19.37, 'lr': 6.902078861387125e-05, 'train_loss': 0.011539, 'train_psnr': 25.1917, 'val_psnr': 24.0608, 'input_psnr': 23.1331, 'delta_psnr': 0.9278, 'best_val_psnr': 24.0608}
# {'epoch': 5928, 'epoch_time_sec': 19.37, 'lr': 6.75307225109602e-05, 'train_loss': 0.011532, 'train_psnr': 25.1936, 'val_psnr': 24.0608, 'input_psnr': 23.1331, 'delta_psnr': 0.9277, 'best_val_psnr': 24.0608}
# {'epoch': 5929, 'epoch_time_sec': 19.34, 'lr': 6.605503833786686e-05, 'train_loss': 0.011527, 'train_psnr': 25.197, 'val_psnr': 24.0609, 'input_psnr': 23.1331, 'delta_psnr': 0.9279, 'best_val_psnr': 24.0609}
# {'epoch': 5930, 'epoch_time_sec': 19.39, 'lr': 6.459397873048363e-05, 'train_loss': 0.011519, 'train_psnr': 25.2004, 'val_psnr': 24.061, 'input_psnr': 23.1331, 'delta_psnr': 0.9279, 'best_val_psnr': 24.061}
# {'epoch': 5931, 'epoch_time_sec': 19.42, 'lr': 6.314778392009341e-05, 'train_loss': 0.01152, 'train_psnr': 25.2013, 'val_psnr': 24.0611, 'input_psnr': 23.1331, 'delta_psnr': 0.9281, 'best_val_psnr': 24.0611}
# {'epoch': 5932, 'epoch_time_sec': 19.37, 'lr': 6.17166916938696e-05, 'train_loss': 0.011523, 'train_psnr': 25.1971, 'val_psnr': 24.0611, 'input_psnr': 23.1331, 'delta_psnr': 0.928, 'best_val_psnr': 24.0611}
# {'epoch': 5933, 'epoch_time_sec': 19.39, 'lr': 6.030093735577892e-05, 'train_loss': 0.011524, 'train_psnr': 25.1993, 'val_psnr': 24.0611, 'input_psnr': 23.1331, 'delta_psnr': 0.928, 'best_val_psnr': 24.0611}
# {'epoch': 5934, 'epoch_time_sec': 19.38, 'lr': 5.890075368789217e-05, 'train_loss': 0.011534, 'train_psnr': 25.1922, 'val_psnr': 24.0612, 'input_psnr': 23.1331, 'delta_psnr': 0.9281, 'best_val_psnr': 24.0612}
# {'epoch': 5935, 'epoch_time_sec': 19.39, 'lr': 5.751637091210904e-05, 'train_loss': 0.011533, 'train_psnr': 25.1943, 'val_psnr': 24.0612, 'input_psnr': 23.1331, 'delta_psnr': 0.9282, 'best_val_psnr': 24.0612}
# {'epoch': 5936, 'epoch_time_sec': 19.36, 'lr': 5.614801665230508e-05, 'train_loss': 0.011533, 'train_psnr': 25.1946, 'val_psnr': 24.0612, 'input_psnr': 23.1331, 'delta_psnr': 0.9282, 'best_val_psnr': 24.0612}
# {'epoch': 5937, 'epoch_time_sec': 19.36, 'lr': 5.479591589690462e-05, 'train_loss': 0.011519, 'train_psnr': 25.2, 'val_psnr': 24.0613, 'input_psnr': 23.1331, 'delta_psnr': 0.9283, 'best_val_psnr': 24.0613}
# {'epoch': 5938, 'epoch_time_sec': 19.4, 'lr': 5.346029096188807e-05, 'train_loss': 0.011521, 'train_psnr': 25.1981, 'val_psnr': 24.0614, 'input_psnr': 23.1331, 'delta_psnr': 0.9283, 'best_val_psnr': 24.0614}
# {'epoch': 5939, 'epoch_time_sec': 19.38, 'lr': 5.21413614542376e-05, 'train_loss': 0.01152, 'train_psnr': 25.2003, 'val_psnr': 24.0615, 'input_psnr': 23.1331, 'delta_psnr': 0.9285, 'best_val_psnr': 24.0615}
# {'epoch': 5940, 'epoch_time_sec': 19.4, 'lr': 5.0839344235829504e-05, 'train_loss': 0.01152, 'train_psnr': 25.1998, 'val_psnr': 24.0616, 'input_psnr': 23.1331, 'delta_psnr': 0.9285, 'best_val_psnr': 24.0616}
# {'epoch': 5941, 'epoch_time_sec': 19.39, 'lr': 4.955445338777638e-05, 'train_loss': 0.011526, 'train_psnr': 25.1979, 'val_psnr': 24.0616, 'input_psnr': 23.1331, 'delta_psnr': 0.9285, 'best_val_psnr': 24.0616}
# {'epoch': 5942, 'epoch_time_sec': 19.35, 'lr': 4.828690017522792e-05, 'train_loss': 0.011521, 'train_psnr': 25.1995, 'val_psnr': 24.0617, 'input_psnr': 23.1331, 'delta_psnr': 0.9286, 'best_val_psnr': 24.0617}
# {'epoch': 5943, 'epoch_time_sec': 19.38, 'lr': 4.7036893012633996e-05, 'train_loss': 0.011523, 'train_psnr': 25.1984, 'val_psnr': 24.0616, 'input_psnr': 23.1331, 'delta_psnr': 0.9286, 'best_val_psnr': 24.0617}
# {'epoch': 5944, 'epoch_time_sec': 19.36, 'lr': 4.580463742947642e-05, 'train_loss': 0.011533, 'train_psnr': 25.1962, 'val_psnr': 24.0617, 'input_psnr': 23.1331, 'delta_psnr': 0.9287, 'best_val_psnr': 24.0617}
# {'epoch': 5945, 'epoch_time_sec': 19.41, 'lr': 4.45903360364755e-05, 'train_loss': 0.011526, 'train_psnr': 25.1994, 'val_psnr': 24.0618, 'input_psnr': 23.1331, 'delta_psnr': 0.9287, 'best_val_psnr': 24.0618}
# {'epoch': 5946, 'epoch_time_sec': 19.4, 'lr': 4.3394188492276114e-05, 'train_loss': 0.011533, 'train_psnr': 25.1974, 'val_psnr': 24.0619, 'input_psnr': 23.1331, 'delta_psnr': 0.9289, 'best_val_psnr': 24.0619}
# {'epoch': 5947, 'epoch_time_sec': 19.37, 'lr': 4.221639147061937e-05, 'train_loss': 0.011543, 'train_psnr': 25.1928, 'val_psnr': 24.062, 'input_psnr': 23.1331, 'delta_psnr': 0.9289, 'best_val_psnr': 24.062}
# {'epoch': 5948, 'epoch_time_sec': 19.41, 'lr': 4.105713862800485e-05, 'train_loss': 0.011531, 'train_psnr': 25.1956, 'val_psnr': 24.062, 'input_psnr': 23.1331, 'delta_psnr': 0.929, 'best_val_psnr': 24.062}
# {'epoch': 5949, 'epoch_time_sec': 19.39, 'lr': 3.991662057184932e-05, 'train_loss': 0.011515, 'train_psnr': 25.2019, 'val_psnr': 24.0621, 'input_psnr': 23.1331, 'delta_psnr': 0.9291, 'best_val_psnr': 24.0621}
# {'epoch': 5950, 'epoch_time_sec': 19.36, 'lr': 3.8795024829146304e-05, 'train_loss': 0.011521, 'train_psnr': 25.2002, 'val_psnr': 24.0621, 'input_psnr': 23.1331, 'delta_psnr': 0.929, 'best_val_psnr': 24.0621}
# {'epoch': 5951, 'epoch_time_sec': 19.37, 'lr': 3.769253581563263e-05, 'train_loss': 0.011526, 'train_psnr': 25.198, 'val_psnr': 24.0622, 'input_psnr': 23.1331, 'delta_psnr': 0.9291, 'best_val_psnr': 24.0622}
# {'epoch': 5952, 'epoch_time_sec': 19.39, 'lr': 3.660933480546618e-05, 'train_loss': 0.011513, 'train_psnr': 25.2054, 'val_psnr': 24.0622, 'input_psnr': 23.1331, 'delta_psnr': 0.9292, 'best_val_psnr': 24.0622}
# {'epoch': 5953, 'epoch_time_sec': 19.38, 'lr': 3.5545599901420355e-05, 'train_loss': 0.011521, 'train_psnr': 25.2005, 'val_psnr': 24.0623, 'input_psnr': 23.1331, 'delta_psnr': 0.9292, 'best_val_psnr': 24.0623}
# {'epoch': 5954, 'epoch_time_sec': 19.41, 'lr': 3.450150600559992e-05, 'train_loss': 0.011514, 'train_psnr': 25.2015, 'val_psnr': 24.0622, 'input_psnr': 23.1331, 'delta_psnr': 0.9291, 'best_val_psnr': 24.0623}
# {'epoch': 5955, 'epoch_time_sec': 19.37, 'lr': 3.347722479068311e-05, 'train_loss': 0.011505, 'train_psnr': 25.2093, 'val_psnr': 24.0623, 'input_psnr': 23.1331, 'delta_psnr': 0.9293, 'best_val_psnr': 24.0623}
# {'epoch': 5956, 'epoch_time_sec': 19.36, 'lr': 3.247292467169486e-05, 'train_loss': 0.011504, 'train_psnr': 25.2102, 'val_psnr': 24.0624, 'input_psnr': 23.1331, 'delta_psnr': 0.9294, 'best_val_psnr': 24.0624}
# {'epoch': 5957, 'epoch_time_sec': 19.35, 'lr': 3.14887707783154e-05, 'train_loss': 0.01152, 'train_psnr': 25.2007, 'val_psnr': 24.0626, 'input_psnr': 23.1331, 'delta_psnr': 0.9295, 'best_val_psnr': 24.0626}
# {'epoch': 5958, 'epoch_time_sec': 19.37, 'lr': 3.052492492772941e-05, 'train_loss': 0.011502, 'train_psnr': 25.2094, 'val_psnr': 24.0625, 'input_psnr': 23.1331, 'delta_psnr': 0.9294, 'best_val_psnr': 24.0626}
# {'epoch': 5959, 'epoch_time_sec': 19.38, 'lr': 2.958154559801944e-05, 'train_loss': 0.011508, 'train_psnr': 25.2048, 'val_psnr': 24.0626, 'input_psnr': 23.1331, 'delta_psnr': 0.9295, 'best_val_psnr': 24.0626}
# {'epoch': 5960, 'epoch_time_sec': 19.39, 'lr': 2.8658787902108536e-05, 'train_loss': 0.011505, 'train_psnr': 25.2088, 'val_psnr': 24.0626, 'input_psnr': 23.1331, 'delta_psnr': 0.9296, 'best_val_psnr': 24.0626}
# {'epoch': 5961, 'epoch_time_sec': 19.41, 'lr': 2.775680356225629e-05, 'train_loss': 0.011511, 'train_psnr': 25.2047, 'val_psnr': 24.0627, 'input_psnr': 23.1331, 'delta_psnr': 0.9296, 'best_val_psnr': 24.0627}
# {'epoch': 5962, 'epoch_time_sec': 19.37, 'lr': 2.6875740885112086e-05, 'train_loss': 0.011516, 'train_psnr': 25.2009, 'val_psnr': 24.0627, 'input_psnr': 23.1331, 'delta_psnr': 0.9297, 'best_val_psnr': 24.0627}
# {'epoch': 5963, 'epoch_time_sec': 19.41, 'lr': 2.6015744737330304e-05, 'train_loss': 0.011498, 'train_psnr': 25.2134, 'val_psnr': 24.0627, 'input_psnr': 23.1331, 'delta_psnr': 0.9297, 'best_val_psnr': 24.0627}
# {'epoch': 5964, 'epoch_time_sec': 19.34, 'lr': 2.5176956521750807e-05, 'train_loss': 0.01152, 'train_psnr': 25.2037, 'val_psnr': 24.0627, 'input_psnr': 23.1331, 'delta_psnr': 0.9297, 'best_val_psnr': 24.0627}
# {'epoch': 5965, 'epoch_time_sec': 19.35, 'lr': 2.4359514154149237e-05, 'train_loss': 0.011515, 'train_psnr': 25.2026, 'val_psnr': 24.0627, 'input_psnr': 23.1331, 'delta_psnr': 0.9296, 'best_val_psnr': 24.0627}
# {'epoch': 5966, 'epoch_time_sec': 19.38, 'lr': 2.3563552040560465e-05, 'train_loss': 0.011502, 'train_psnr': 25.212, 'val_psnr': 24.0628, 'input_psnr': 23.1331, 'delta_psnr': 0.9297, 'best_val_psnr': 24.0628}
# {'epoch': 5967, 'epoch_time_sec': 19.36, 'lr': 2.2789201055179238e-05, 'train_loss': 0.011511, 'train_psnr': 25.206, 'val_psnr': 24.0628, 'input_psnr': 23.1331, 'delta_psnr': 0.9297, 'best_val_psnr': 24.0628}
# {'epoch': 5968, 'epoch_time_sec': 19.39, 'lr': 2.2036588518841462e-05, 'train_loss': 0.011514, 'train_psnr': 25.2046, 'val_psnr': 24.0628, 'input_psnr': 23.1331, 'delta_psnr': 0.9297, 'best_val_psnr': 24.0628}
# {'epoch': 5969, 'epoch_time_sec': 19.38, 'lr': 2.1305838178089777e-05, 'train_loss': 0.011498, 'train_psnr': 25.2132, 'val_psnr': 24.0628, 'input_psnr': 23.1331, 'delta_psnr': 0.9298, 'best_val_psnr': 24.0628}
# {'epoch': 5970, 'epoch_time_sec': 19.37, 'lr': 2.0597070184826863e-05, 'train_loss': 0.011505, 'train_psnr': 25.209, 'val_psnr': 24.0629, 'input_psnr': 23.1331, 'delta_psnr': 0.9298, 'best_val_psnr': 24.0629}
# {'epoch': 5971, 'epoch_time_sec': 19.37, 'lr': 1.991040107655966e-05, 'train_loss': 0.011506, 'train_psnr': 25.2092, 'val_psnr': 24.063, 'input_psnr': 23.1331, 'delta_psnr': 0.9299, 'best_val_psnr': 24.063}
# {'epoch': 5972, 'epoch_time_sec': 19.43, 'lr': 1.9245943757238106e-05, 'train_loss': 0.011511, 'train_psnr': 25.2053, 'val_psnr': 24.0631, 'input_psnr': 23.1331, 'delta_psnr': 0.93, 'best_val_psnr': 24.0631}
# {'epoch': 5973, 'epoch_time_sec': 19.43, 'lr': 1.860380747869104e-05, 'train_loss': 0.011505, 'train_psnr': 25.2091, 'val_psnr': 24.0631, 'input_psnr': 23.1331, 'delta_psnr': 0.93, 'best_val_psnr': 24.0631}
# {'epoch': 5974, 'epoch_time_sec': 19.38, 'lr': 1.7984097822662774e-05, 'train_loss': 0.011502, 'train_psnr': 25.2101, 'val_psnr': 24.0631, 'input_psnr': 23.1331, 'delta_psnr': 0.9301, 'best_val_psnr': 24.0631}
# {'epoch': 5975, 'epoch_time_sec': 19.37, 'lr': 1.7386916683453048e-05, 'train_loss': 0.011502, 'train_psnr': 25.2101, 'val_psnr': 24.0631, 'input_psnr': 23.1331, 'delta_psnr': 0.93, 'best_val_psnr': 24.0631}
# {'epoch': 5976, 'epoch_time_sec': 19.42, 'lr': 1.681236225116336e-05, 'train_loss': 0.011506, 'train_psnr': 25.2127, 'val_psnr': 24.0632, 'input_psnr': 23.1331, 'delta_psnr': 0.9301, 'best_val_psnr': 24.0632}
# {'epoch': 5977, 'epoch_time_sec': 19.42, 'lr': 1.6260528995552234e-05, 'train_loss': 0.011515, 'train_psnr': 25.2065, 'val_psnr': 24.0632, 'input_psnr': 23.1331, 'delta_psnr': 0.9301, 'best_val_psnr': 24.0632}
# {'epoch': 5978, 'epoch_time_sec': 19.41, 'lr': 1.5731507650502204e-05, 'train_loss': 0.0115, 'train_psnr': 25.2117, 'val_psnr': 24.0632, 'input_psnr': 23.1331, 'delta_psnr': 0.9301, 'best_val_psnr': 24.0632}
# {'epoch': 5979, 'epoch_time_sec': 19.42, 'lr': 1.522538519910128e-05, 'train_loss': 0.011507, 'train_psnr': 25.208, 'val_psnr': 24.0631, 'input_psnr': 23.1331, 'delta_psnr': 0.9301, 'best_val_psnr': 24.0632}
# {'epoch': 5980, 'epoch_time_sec': 19.36, 'lr': 1.4742244859340729e-05, 'train_loss': 0.011515, 'train_psnr': 25.2083, 'val_psnr': 24.0631, 'input_psnr': 23.1331, 'delta_psnr': 0.9301, 'best_val_psnr': 24.0632}
# {'epoch': 5981, 'epoch_time_sec': 19.4, 'lr': 1.4282166070432376e-05, 'train_loss': 0.011501, 'train_psnr': 25.2096, 'val_psnr': 24.0632, 'input_psnr': 23.1331, 'delta_psnr': 0.9301, 'best_val_psnr': 24.0632}
# {'epoch': 5982, 'epoch_time_sec': 19.45, 'lr': 1.3845224479746827e-05, 'train_loss': 0.011499, 'train_psnr': 25.2121, 'val_psnr': 24.0631, 'input_psnr': 23.1331, 'delta_psnr': 0.9301, 'best_val_psnr': 24.0632}
# {'epoch': 5983, 'epoch_time_sec': 19.4, 'lr': 1.3431491930375406e-05, 'train_loss': 0.011503, 'train_psnr': 25.2101, 'val_psnr': 24.0631, 'input_psnr': 23.1331, 'delta_psnr': 0.93, 'best_val_psnr': 24.0632}
# {'epoch': 5984, 'epoch_time_sec': 19.36, 'lr': 1.3041036449317534e-05, 'train_loss': 0.011514, 'train_psnr': 25.2072, 'val_psnr': 24.0631, 'input_psnr': 23.1331, 'delta_psnr': 0.9301, 'best_val_psnr': 24.0632}
# {'epoch': 5985, 'epoch_time_sec': 19.38, 'lr': 1.2673922236295512e-05, 'train_loss': 0.011516, 'train_psnr': 25.2047, 'val_psnr': 24.0632, 'input_psnr': 23.1331, 'delta_psnr': 0.9301, 'best_val_psnr': 24.0632}
# {'epoch': 5986, 'epoch_time_sec': 19.4, 'lr': 1.2330209653198699e-05, 'train_loss': 0.011502, 'train_psnr': 25.2124, 'val_psnr': 24.0632, 'input_psnr': 23.1331, 'delta_psnr': 0.9302, 'best_val_psnr': 24.0632}
# {'epoch': 5987, 'epoch_time_sec': 19.39, 'lr': 1.2009955214158534e-05, 'train_loss': 0.011515, 'train_psnr': 25.2067, 'val_psnr': 24.0632, 'input_psnr': 23.1331, 'delta_psnr': 0.9302, 'best_val_psnr': 24.0632}
# {'epoch': 5988, 'epoch_time_sec': 19.44, 'lr': 1.1713211576256426e-05, 'train_loss': 0.011501, 'train_psnr': 25.2107, 'val_psnr': 24.0633, 'input_psnr': 23.1331, 'delta_psnr': 0.9302, 'best_val_psnr': 24.0633}
# {'epoch': 5989, 'epoch_time_sec': 19.41, 'lr': 1.1440027530865737e-05, 'train_loss': 0.011508, 'train_psnr': 25.2069, 'val_psnr': 24.0633, 'input_psnr': 23.1331, 'delta_psnr': 0.9302, 'best_val_psnr': 24.0633}
# {'epoch': 5990, 'epoch_time_sec': 19.39, 'lr': 1.1190447995629324e-05, 'train_loss': 0.011499, 'train_psnr': 25.2124, 'val_psnr': 24.0633, 'input_psnr': 23.1331, 'delta_psnr': 0.9302, 'best_val_psnr': 24.0633}
# {'epoch': 5991, 'epoch_time_sec': 19.36, 'lr': 1.0964514007074084e-05, 'train_loss': 0.011525, 'train_psnr': 25.2035, 'val_psnr': 24.0633, 'input_psnr': 23.1331, 'delta_psnr': 0.9302, 'best_val_psnr': 24.0633}
# {'epoch': 5992, 'epoch_time_sec': 19.38, 'lr': 1.0762262713863677e-05, 'train_loss': 0.011507, 'train_psnr': 25.2072, 'val_psnr': 24.0633, 'input_psnr': 23.1331, 'delta_psnr': 0.9302, 'best_val_psnr': 24.0633}
# {'epoch': 5993, 'epoch_time_sec': 19.34, 'lr': 1.0583727370690336e-05, 'train_loss': 0.01152, 'train_psnr': 25.2074, 'val_psnr': 24.0633, 'input_psnr': 23.1331, 'delta_psnr': 0.9303, 'best_val_psnr': 24.0633}
# {'epoch': 5994, 'epoch_time_sec': 19.34, 'lr': 1.0428937332807133e-05, 'train_loss': 0.011506, 'train_psnr': 25.2076, 'val_psnr': 24.0633, 'input_psnr': 23.1331, 'delta_psnr': 0.9302, 'best_val_psnr': 24.0633}
# {'epoch': 5995, 'epoch_time_sec': 19.33, 'lr': 1.0297918051201232e-05, 'train_loss': 0.011502, 'train_psnr': 25.2118, 'val_psnr': 24.0634, 'input_psnr': 23.1331, 'delta_psnr': 0.9303, 'best_val_psnr': 24.0634}
# {'epoch': 5996, 'epoch_time_sec': 19.36, 'lr': 1.0190691068409265e-05, 'train_loss': 0.011506, 'train_psnr': 25.2086, 'val_psnr': 24.0633, 'input_psnr': 23.1331, 'delta_psnr': 0.9303, 'best_val_psnr': 24.0634}
# {'epoch': 5997, 'epoch_time_sec': 19.4, 'lr': 1.010727401497519e-05, 'train_loss': 0.0115, 'train_psnr': 25.2111, 'val_psnr': 24.0633, 'input_psnr': 23.1331, 'delta_psnr': 0.9303, 'best_val_psnr': 24.0634}
# {'epoch': 5998, 'epoch_time_sec': 19.37, 'lr': 1.004768060655143e-05, 'train_loss': 0.011504, 'train_psnr': 25.2083, 'val_psnr': 24.0634, 'input_psnr': 23.1331, 'delta_psnr': 0.9303, 'best_val_psnr': 24.0634}
# {'epoch': 5999, 'epoch_time_sec': 19.39, 'lr': 1.0011920641643708e-05, 'train_loss': 0.011492, 'train_psnr': 25.2165, 'val_psnr': 24.0634, 'input_psnr': 23.1331, 'delta_psnr': 0.9303, 'best_val_psnr': 24.0634}
# {'epoch': 6000, 'epoch_time_sec': 19.36, 'lr': 1e-05, 'train_loss': 0.011501, 'train_psnr': 25.2121, 'val_psnr': 24.0634, 'input_psnr': 23.1331, 'delta_psnr': 0.9303, 'best_val_psnr': 24.0634}

# %% [markdown]
# ## 6. Validation Summary

# %%
export_model = load_checkpoint_for_eval(best_ckpt_path, device)
validation_summary = evaluate_metrics(export_model, val_loader, device)
preview_info = write_val_preview(export_model, val_loader, preview_dir, device)
print({'validation_summary': validation_summary, 'best_checkpoint_path': str(best_ckpt_path), 'last_checkpoint_path': str(last_ckpt_path), 'preview': preview_info})
# Out:
# {'validation_summary': {'val_psnr': 24.063410100069913, 'input_psnr': 23.133060299266468, 'delta_psnr': 0.9303498008034445}, 'best_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/024428_2904_fsrcnn_residual_96_40_m8_resume6000_most_recent_last_lr300_restart/checkpoints/best.pth', 'last_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/024428_2904_fsrcnn_residual_96_40_m8_resume6000_most_recent_last_lr300_restart/checkpoints/last.pth', 'preview': {'sample_name': '0000', 'input': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/024428_2904_fsrcnn_residual_96_40_m8_resume6000_most_recent_last_lr300_restart/exports/val_preview/val_preview_input.png', 'prediction': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/024428_2904_fsrcnn_residual_96_40_m8_resume6000_most_recent_last_lr300_restart/exports/val_preview/val_preview_pred.png', 'target': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/024428_2904_fsrcnn_residual_96_40_m8_resume6000_most_recent_last_lr300_restart/exports/val_preview/val_preview_target.png'}}

# %% [markdown]
# ## 7. Export And Submission Artifacts

# %%
def load_or_create_calibration_summary(calibration_dir: Path, pairs: list[tuple[Path, Path, str]], count: int, eval_size: int) -> dict[str, Any]:
    manifest_path = calibration_dir / 'manifest.json'
    if manifest_path.exists():
        manifest = json.loads(manifest_path.read_text(encoding='utf-8'))
        item_count = int(manifest.get('count') or len(manifest.get('items', [])))
        if item_count <= 0 or manifest.get('derived_from_training') is not True:
            raise ValueError(f'Invalid training-derived calibration manifest: {manifest_path}')
        return {'calibration_dir': str(calibration_dir), 'manifest_path': str(manifest_path), 'count': item_count, 'source': manifest.get('source'), 'derived_from_training': True, 'reused_existing_dataset': True}

    calibration_dir.mkdir(parents=True, exist_ok=True) 
    items: list[dict[str, Any]] = []
    for index, (lr_path, _, name) in enumerate(pairs[:count]):
        image = Image.open(lr_path).convert('RGB')
        if image.size != (eval_size, eval_size):
            image = image.resize((eval_size, eval_size), BICUBIC_RESAMPLE)
        image_path = calibration_dir / f'{index:03d}_{Path(name).name}.png'
        image.save(image_path)
        items.append({'index': index, 'name': name, 'source_lr': str(lr_path), 'image_path': str(image_path), 'derived_from_training': True})
    manifest = {'count': len(items), 'source': 'training_pairs', 'eval_size': eval_size, 'derived_from_training': True, 'items': items}
    write_json(manifest_path, manifest)
    return {'calibration_dir': str(calibration_dir), 'manifest_path': str(manifest_path), 'count': len(items), 'source': 'training_pairs', 'derived_from_training': True, 'reused_existing_dataset': False}

conversion_script = """#!/usr/bin/env python3
from __future__ import annotations

import argparse
import json
import shlex
import subprocess
from pathlib import Path


def parse_args() -> argparse.Namespace:
    parser = argparse.ArgumentParser(description='Lab 3 ONNX-to-MXQ handoff script for FSRCNN residual.')
    parser.add_argument('--onnx', type=Path, required=True)
    parser.add_argument('--calibration-dir', type=Path, required=True)
    parser.add_argument('--output', type=Path, required=True)
    parser.add_argument('--command-template', default='', help='Optional command with {onnx}, {calibration}, {output} placeholders.')
    parser.add_argument('--dry-run', action='store_true')
    return parser.parse_args()


def main() -> None:
    args = parse_args()
    args.onnx = args.onnx.resolve()
    args.calibration_dir = args.calibration_dir.resolve()
    args.output = args.output.resolve()
    if not args.onnx.exists():
        raise FileNotFoundError(f'ONNX file not found: {args.onnx}')
    if not args.calibration_dir.exists():
        raise FileNotFoundError(f'Calibration directory not found: {args.calibration_dir}')
    payload = {
        'onnx': str(args.onnx),
        'calibration_dir': str(args.calibration_dir),
        'output': str(args.output),
        'status': 'handoff_only',
        'command_template': args.command_template,
    }
    if args.command_template:
        command = args.command_template.format(
            onnx=shlex.quote(str(args.onnx)),
            calibration=shlex.quote(str(args.calibration_dir)),
            output=shlex.quote(str(args.output)),
        )
        payload['command'] = command
        if not args.dry_run:
            completed = subprocess.run(command, shell=True, check=False, capture_output=True, text=True)
            payload.update({'status': 'completed' if completed.returncode == 0 else 'failed', 'returncode': completed.returncode, 'stdout': completed.stdout, 'stderr': completed.stderr})
    args.output.parent.mkdir(parents=True, exist_ok=True)
    handoff_path = args.output.with_suffix('.handoff.json')
    handoff_path.write_text(json.dumps(payload, indent=2, sort_keys=True) + '\n', encoding='utf-8')
    print(json.dumps(payload, indent=2, sort_keys=True))


if __name__ == '__main__':
    main()
"""

onnx_path = exports_dir / f'{cfg.model_id}.onnx'
mxq_target_path = exports_dir / f'{cfg.model_id}.mxq'
conversion_script_path = exports_dir / 'convert_fsrcnn_residual_mxq.py'
conversion_script_path.write_text(conversion_script, encoding='utf-8')

cpu_export_model = load_checkpoint_for_eval(best_ckpt_path, torch.device('cpu')).cpu().eval()
dummy = torch.randn(1, 3, cfg.eval_size, cfg.eval_size)
torch.onnx.export(cpu_export_model, dummy, str(onnx_path), input_names=['input'], output_names=['output'], opset_version=17, dynamo=False)

onnx_model = onnx.load(str(onnx_path))
onnx.checker.check_model(onnx_model)
node_ops = [node.op_type for node in onnx_model.graph.node]
op_histogram = {op: node_ops.count(op) for op in sorted(set(node_ops))}
onnx_summary = {'onnx_path': str(onnx_path), 'checked': True, 'graph_op_count': len(node_ops), 'op_histogram': op_histogram}
print(onnx_summary)

parity_result = {'attempted': False, 'onnxruntime_available': False, 'max_abs_diff': None, 'mean_abs_diff': None}
try:
    import onnxruntime as ort
    parity_result['attempted'] = True
    parity_result['onnxruntime_available'] = True
    parity_input = torch.randn(1, 3, cfg.eval_size, cfg.eval_size)
    with torch.no_grad():
        torch_out = cpu_export_model(parity_input).detach().cpu().numpy()
    ort_session = ort.InferenceSession(str(onnx_path), providers=['CPUExecutionProvider'])
    ort_out = ort_session.run(['output'], {'input': parity_input.numpy()})[0]
    diff = np.abs(torch_out - ort_out)
    parity_result['max_abs_diff'] = float(diff.max())
    parity_result['mean_abs_diff'] = float(diff.mean())
except ImportError:
    print('onnxruntime not installed; skipping CPU parity check')
print(parity_result)

calibration_dir = exports_dir / 'calibration'
calibration_summary = load_or_create_calibration_summary(calibration_dir, train_pairs, 128, cfg.eval_size)
mxq_command = f'python {conversion_script_path} --onnx {onnx_path} --calibration-dir {calibration_dir} --output {mxq_target_path} --dry-run'
mxq_handoff = {
    'conversion_script_path': str(conversion_script_path),
    'onnx_input_path': str(onnx_path),
    'calibration_manifest_path': calibration_summary['manifest_path'],
    'mxq_target_path': str(mxq_target_path),
    'command': mxq_command,
    'requested_compile': False,
}
summary = {
    'model_id': cfg.model_id,
    'run_root': str(run_root),
    'config': asdict(cfg),

    'resume': resume_info,

    'lr_schedule': lr_schedule_info,


    'data': {'data_root': str(data_root), 'train_pairs': len(train_pairs), 'val_pairs': len(val_pairs), 'train_splits': L3_TRAIN_SPLITS, 'val_dirs': L3_VAL_DIRS},
    'model': {'params': param_count, 'operator_audit': op_counts, 'input_shape': [1, 3, cfg.eval_size, cfg.eval_size], 'output_shape': [1, 3, cfg.eval_size, cfg.eval_size]},
    'validation': validation_summary,
    'preview': preview_info,
    'artifacts': {
        'best_checkpoint': str(best_ckpt_path),
        'last_checkpoint': str(last_ckpt_path),
        'onnx': str(onnx_path),
        'calibration_manifest': calibration_summary['manifest_path'],
        'conversion_script': str(conversion_script_path),
        'mxq_target': str(mxq_target_path),
        **run_log_paths,
    },
    'runtime': {
        'device': str(device),
        'gpu_name': gpu_name,
    },
    'onnx': onnx_summary,
    'onnx_parity': parity_result,
    'calibration': calibration_summary,
    'mxq_handoff': mxq_handoff,
}
write_json(summary_path, summary)
print({'summary_path': str(summary_path), **summary['artifacts']})
# Out:
# /tmp/ipykernel_20034/2373125837.py:86: DeprecationWarning: You are using the legacy TorchScript-based ONNX export. Starting in PyTorch 2.9, the new torch.export-based ONNX exporter has become the default. Learn more about the new export logic: https://docs.pytorch.org/docs/stable/onnx_export.html. For exporting control flow: https://pytorch.org/tutorials/beginner/onnx/export_control_flow_model_to_onnx_tutorial.html
#   torch.onnx.export(cpu_export_model, dummy, str(onnx_path), input_names=['input'], output_names=['output'], opset_version=17, dynamo=False)
# {'onnx_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/024428_2904_fsrcnn_residual_96_40_m8_resume6000_most_recent_last_lr300_restart/exports/fsrcnn_residual_96_40_m8.onnx', 'checked': True, 'graph_op_count': 24, 'op_histogram': {'Add': 1, 'Conv': 12, 'LeakyRelu': 11}}
# {'attempted': True, 'onnxruntime_available': True, 'max_abs_diff': 1.1324882507324219e-06, 'mean_abs_diff': 1.6726978913084167e-07}
# {'summary_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/024428_2904_fsrcnn_residual_96_40_m8_resume6000_most_recent_last_lr300_restart/summary.json', 'best_checkpoint': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/024428_2904_fsrcnn_residual_96_40_m8_resume6000_most_recent_last_lr300_restart/checkpoints/best.pth', 'last_checkpoint': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/024428_2904_fsrcnn_residual_96_40_m8_resume6000_most_recent_last_lr300_restart/checkpoints/last.pth', 'onnx': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/024428_2904_fsrcnn_residual_96_40_m8_resume6000_most_recent_last_lr300_restart/exports/fsrcnn_residual_96_40_m8.onnx', 'calibration_manifest': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/024428_2904_fsrcnn_residual_96_40_m8_resume6000_most_recent_last_lr300_restart/exports/calibration/manifest.json', 'conversion_script': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/024428_2904_fsrcnn_residual_96_40_m8_resume6000_most_recent_last_lr300_restart/exports/convert_fsrcnn_residual_mxq.py', 'mxq_target': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/024428_2904_fsrcnn_residual_96_40_m8_resume6000_most_recent_last_lr300_restart/exports/fsrcnn_residual_96_40_m8.mxq', 'metrics_csv': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/024428_2904_fsrcnn_residual_96_40_m8_resume6000_most_recent_last_lr300_restart/metrics.csv', 'history_json': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/024428_2904_fsrcnn_residual_96_40_m8_resume6000_most_recent_last_lr300_restart/history.json', 'summary_json': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/024428_2904_fsrcnn_residual_96_40_m8_resume6000_most_recent_last_lr300_restart/summary.json', 'run_manifest': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/024428_2904_fsrcnn_residual_96_40_m8_resume6000_most_recent_last_lr300_restart/run_manifest.json'}
