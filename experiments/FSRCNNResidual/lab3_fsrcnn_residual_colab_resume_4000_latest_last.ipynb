# %% [markdown]
# # Lab 3 - FSRCNN Residual 96/40/m8 Resume 4000 (Colab)

# %% [markdown]
# ## 1. Setup

# %%
try:
    import google.colab  # type: ignore
    IN_COLAB_BOOTSTRAP = True
except Exception:
    IN_COLAB_BOOTSTRAP = False

if IN_COLAB_BOOTSTRAP:
    # %pip install -q onnx onnxruntime

import csv
import json
import math
import os
import random
import sys
import time
from contextlib import nullcontext
from dataclasses import asdict, dataclass
from datetime import datetime
from pathlib import Path
from typing import Any

import numpy as np
import onnx
import torch
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
from torch.utils.data import DataLoader, Dataset

IMAGE_SUFFIXES = {'.png', '.jpg', '.jpeg', '.bmp'}
DRIVE_ROOT = Path('/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3')
DRIVE_DATA_ROOT = DRIVE_ROOT / 'Data'
DRIVE_RUNS_ROOT = DRIVE_ROOT / 'runs'

try:
    BICUBIC_RESAMPLE = Image.Resampling.BICUBIC
except AttributeError:
    BICUBIC_RESAMPLE = Image.BICUBIC

try:
    FLIP_LEFT_RIGHT = Image.Transpose.FLIP_LEFT_RIGHT
    FLIP_TOP_BOTTOM = Image.Transpose.FLIP_TOP_BOTTOM
    ROTATE_90 = Image.Transpose.ROTATE_90
    ROTATE_180 = Image.Transpose.ROTATE_180
    ROTATE_270 = Image.Transpose.ROTATE_270
except AttributeError:
    FLIP_LEFT_RIGHT = Image.FLIP_LEFT_RIGHT
    FLIP_TOP_BOTTOM = Image.FLIP_TOP_BOTTOM
    ROTATE_90 = Image.ROTATE_90
    ROTATE_180 = Image.ROTATE_180
    ROTATE_270 = Image.ROTATE_270


def set_global_seed(seed: int) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


def now_stamp() -> str:
    return datetime.now().strftime('%H%M%S_%d%m')


def is_colab_runtime() -> bool:
    try:
        import google.colab  # type: ignore  # noqa: F401
        return True
    except Exception:
        return False


def auto_num_workers(in_colab: bool) -> int:
    if sys.platform == 'darwin':
        return 0
    cpu_count = max(os.cpu_count() or 2, 2)
    if in_colab:
        return min(4, max(cpu_count - 1, 2))
    return min(2, cpu_count)


def resolve_repo_root(start: Path) -> Path:
    current = start.resolve()
    for candidate in [current, *current.parents]:
        if (candidate / 'Data').exists() and (candidate / 'runs').exists():
            return candidate
    for candidate in [current, *current.parents]:
        if (candidate / 'Data').exists():
            return candidate
    raise FileNotFoundError(f'Could not locate repo root from {start.resolve()}')


def make_unique_run_root(runs_root: Path, run_slug: str) -> Path:
    safe_slug = ''.join(ch if ch.isalnum() or ch in '_-' else '_' for ch in run_slug).strip('_')
    candidate = runs_root / f'{now_stamp()}_{safe_slug}'
    while candidate.exists():
        time.sleep(1.1)
        candidate = runs_root / f'{now_stamp()}_{safe_slug}'
    return candidate


def write_json(path: Path, payload: dict[str, Any]) -> None:
    path.parent.mkdir(parents=True, exist_ok=True)
    path.write_text(json.dumps(payload, indent=2, sort_keys=True) + '\n', encoding='utf-8')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 131.2 MB/s eta 0:00:0000:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 130.7 MB/s eta 0:00:0000:010:01

# %% [markdown]
# ## 2. Configuration

# %%
@dataclass
class RunConfig:
    model_id: str = 'fsrcnn_residual_96_40_m8'
    run_slug: str = 'fsrcnn_residual_96_40_m8'
    enable_resume: bool = True
    resume_checkpoint_path: str | None = (
        '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/'
        'runs/162933_2704_fsrcnn_residual_96_40_m8/checkpoints/last.pth'
    )
    seed: int = 1337
    train_patch_size: int = 256
    eval_size: int = 256
    batch_size: int = 16
    epochs: int = 4000
    lr: float = 1e-4
    min_lr: float = 1e-6
    weight_decay: float = 1e-4
    warmup_epochs: int = 8
    num_workers: int | None = 2
    prefetch_factor: int = 2
    use_amp: bool = True
    use_ema: bool = True
    ema_decay: float = 0.999
    calibration_count: int = 128

cfg = RunConfig()
in_colab = is_colab_runtime()
if in_colab:
    from google.colab import drive  # type: ignore

    drive.mount('/content/drive', force_remount=False)
    data_root = DRIVE_DATA_ROOT
    runs_root = DRIVE_RUNS_ROOT
    if not data_root.exists():
        raise FileNotFoundError(f'Google Drive data root not found: {data_root}')
else:
    repo_root = resolve_repo_root(Path.cwd())
    data_root = repo_root / 'Data'
    runs_root = repo_root / 'runs'
    if not data_root.exists():
        raise FileNotFoundError(f'Data root not found: {data_root}')

runs_root.mkdir(parents=True, exist_ok=True)
if cfg.num_workers is None:
    cfg.num_workers = auto_num_workers(in_colab)
if not cfg.enable_resume:
    cfg.resume_checkpoint_path = None

run_root = make_unique_run_root(runs_root, cfg.run_slug)
checkpoints_dir = run_root / 'checkpoints'
exports_dir = run_root / 'exports'
preview_dir = exports_dir / 'val_preview'
calibration_dir = exports_dir / 'calibration'
summary_path = run_root / 'summary.json'
metrics_csv_path = run_root / 'metrics.csv'
history_json_path = run_root / 'history.json'

for directory in [run_root, checkpoints_dir, exports_dir, preview_dir, calibration_dir]:
    directory.mkdir(parents=True, exist_ok=True)

set_global_seed(cfg.seed)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
cuda_enabled = device.type == 'cuda'
gpu_name = torch.cuda.get_device_name(0) if cuda_enabled else None
if cuda_enabled:
    torch.backends.cudnn.benchmark = True
    if hasattr(torch.backends.cuda.matmul, 'allow_tf32'):
        torch.backends.cuda.matmul.allow_tf32 = True

print({
    'device': str(device),
    'in_colab': in_colab,
    'data_root': str(data_root),
    'run_root': str(run_root),
    'gpu_name': gpu_name,
    'config': asdict(cfg),
})
# Out:
# Mounted at /content/drive
# {'device': 'cuda', 'in_colab': True, 'data_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/Data', 'run_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/174208_2704_fsrcnn_residual_96_40_m8', 'gpu_name': 'NVIDIA L4', 'config': {'model_id': 'fsrcnn_residual_96_40_m8', 'run_slug': 'fsrcnn_residual_96_40_m8', 'enable_resume': True, 'resume_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/162933_2704_fsrcnn_residual_96_40_m8/checkpoints/last.pth', 'seed': 1337, 'train_patch_size': 256, 'eval_size': 256, 'batch_size': 16, 'epochs': 4000, 'lr': 0.0001, 'min_lr': 1e-06, 'weight_decay': 0.0001, 'warmup_epochs': 8, 'num_workers': 2, 'prefetch_factor': 2, 'use_amp': True, 'use_ema': True, 'ema_decay': 0.999, 'calibration_count': 128}}

# %% [markdown]
# ## 3. Data

# %%
L3_TRAIN_SPLITS = (
    ('LR_HR/L3_HR_train1', 'L3_LR/L3_L3_train1', 'L3_HR_train1'),
    ('LR_HR/L3_HR_train2', 'L3_LR/L3_L3_train2', 'L3_HR_train2'),
    ('LR_HR/L3_HR_train3', 'L3_LR/L3_LR_train3', 'L3_HR_train3'),
    ('LR_HR/L3_HR_train4', 'L3_LR/L3_LR_train4', 'L3_HR_train4'),
    ('LR_HR/L3_HR_train', 'L3_LR/L3_LR_train', 'L3_HR_train'),
)
L3_VAL_DIRS = ('L3_HR_valid', 'L3_LR_valid')


def scan_image_directory(directory: Path) -> dict[str, Path]:
    if not directory.exists():
        raise FileNotFoundError(f'Missing directory: {directory}')
    return {
        path.stem: path
        for path in directory.iterdir()
        if path.is_file() and path.suffix.lower() in IMAGE_SUFFIXES
    }


def collect_split_pairs(hr_dir: Path, lr_dir: Path, split_name: str) -> list[tuple[Path, Path, str]]:
    hr_map = scan_image_directory(hr_dir)
    lr_map = scan_image_directory(lr_dir)
    shared = sorted(set(hr_map) & set(lr_map))
    if not shared:
        raise FileNotFoundError(f'No paired files found for {split_name}: HR={hr_dir}, LR={lr_dir}')
    hr_only = sorted(set(hr_map) - set(lr_map))
    lr_only = sorted(set(lr_map) - set(hr_map))
    if hr_only or lr_only:
        print({'split': split_name, 'hr_only_count': len(hr_only), 'lr_only_count': len(lr_only)})
    pairs: list[tuple[Path, Path, str]] = []
    for stem in shared:
        name = stem if split_name == 'val' else f'{split_name}/{stem}'
        pairs.append((lr_map[stem], hr_map[stem], name))
    return pairs


def collect_all_pairs(data_root: Path) -> tuple[list[tuple[Path, Path, str]], list[tuple[Path, Path, str]]]:
    train_pairs: list[tuple[Path, Path, str]] = []
    for hr_rel, lr_rel, split_name in L3_TRAIN_SPLITS:
        hr_dir = data_root / hr_rel
        lr_dir = data_root / lr_rel
        if hr_dir.exists() and lr_dir.exists():
            train_pairs.extend(collect_split_pairs(hr_dir, lr_dir, split_name))
        else:
            print({'skipped_missing_train_split': split_name, 'hr_dir': str(hr_dir), 'lr_dir': str(lr_dir)})
    val_pairs = collect_split_pairs(data_root / L3_VAL_DIRS[0], data_root / L3_VAL_DIRS[1], 'val')
    return train_pairs, val_pairs


class PairedSRDataset(Dataset):
    def __init__(self, pairs: list[tuple[Path, Path, str]], *, train: bool, patch_size: int, eval_size: int, seed: int):
        self.pairs = pairs
        self.train = train
        self.patch_size = patch_size
        self.eval_size = eval_size
        self.seed = seed
        self.epoch = 0

    def set_epoch(self, epoch: int) -> None:
        self.epoch = epoch

    @staticmethod
    def to_tensor(img: Image.Image) -> torch.Tensor:
        arr = np.asarray(img, dtype=np.float32) / 255.0
        return torch.from_numpy(arr).permute(2, 0, 1).contiguous()

    def augment_pair(self, lr: Image.Image, hr: Image.Image, index: int) -> tuple[Image.Image, Image.Image]:
        rng = random.Random((self.seed * 1_000_003) + (self.epoch * 9_973) + index)
        width, height = lr.size
        patch = self.patch_size
        if width < patch or height < patch:
            lr = lr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            hr = hr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            width, height = lr.size
        left = rng.randint(0, width - patch)
        top = rng.randint(0, height - patch)
        box = (left, top, left + patch, top + patch)
        lr = lr.crop(box)
        hr = hr.crop(box)
        if rng.random() < 0.5:
            lr = lr.transpose(FLIP_LEFT_RIGHT)
            hr = hr.transpose(FLIP_LEFT_RIGHT)
        if rng.random() < 0.5:
            lr = lr.transpose(FLIP_TOP_BOTTOM)
            hr = hr.transpose(FLIP_TOP_BOTTOM)
        rot = rng.choice([0, 1, 2, 3])
        if rot:
            rotate_ops = [ROTATE_90, ROTATE_180, ROTATE_270]
            lr = lr.transpose(rotate_ops[rot - 1])
            hr = hr.transpose(rotate_ops[rot - 1])
        return lr, hr

    def __len__(self) -> int:
        return len(self.pairs)

    def __getitem__(self, index: int) -> dict[str, Any]:
        lr_path, hr_path, name = self.pairs[index]
        lr = Image.open(lr_path).convert('RGB')
        hr = Image.open(hr_path).convert('RGB')
        if self.train:
            lr, hr = self.augment_pair(lr, hr, index)
        elif lr.size != (self.eval_size, self.eval_size):
            lr = lr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
            hr = hr.resize((self.eval_size, self.eval_size), BICUBIC_RESAMPLE)
        return {'lr': self.to_tensor(lr), 'hr': self.to_tensor(hr), 'name': name}

train_pairs, val_pairs = collect_all_pairs(data_root)
if not train_pairs:
    raise FileNotFoundError(f'No training pairs found under {data_root}')
if not val_pairs:
    raise FileNotFoundError(f'No validation pairs found under {data_root}')

train_ds = PairedSRDataset(train_pairs, train=True, patch_size=cfg.train_patch_size, eval_size=cfg.eval_size, seed=cfg.seed)
val_ds = PairedSRDataset(val_pairs, train=False, patch_size=cfg.train_patch_size, eval_size=cfg.eval_size, seed=cfg.seed)

loader_num_workers = int(cfg.num_workers or 0)
train_loader_kwargs = {
    'dataset': train_ds,
    'batch_size': cfg.batch_size,
    'shuffle': True,
    'num_workers': loader_num_workers,
    'pin_memory': cuda_enabled,
}
val_loader_kwargs = {
    'dataset': val_ds,
    'batch_size': 1,
    'shuffle': False,
    'num_workers': loader_num_workers,
    'pin_memory': cuda_enabled,
}
if loader_num_workers > 0:
    train_loader_kwargs['persistent_workers'] = True
    val_loader_kwargs['persistent_workers'] = True
    train_loader_kwargs['prefetch_factor'] = cfg.prefetch_factor
    val_loader_kwargs['prefetch_factor'] = cfg.prefetch_factor

train_loader = DataLoader(**train_loader_kwargs)
val_loader = DataLoader(**val_loader_kwargs)

sample = train_ds[0]
print({
    'data_root': str(data_root),
    'train_pairs': len(train_pairs),
    'val_pairs': len(val_pairs),
    'train_preview': [name for _, _, name in train_pairs[:5]],
    'val_preview': [name for _, _, name in val_pairs[:5]],
    'sample_lr_shape': tuple(sample['lr'].shape),
    'sample_hr_shape': tuple(sample['hr'].shape),
})
assert tuple(sample['lr'].shape) == (3, cfg.eval_size, cfg.eval_size)
assert tuple(sample['hr'].shape) == (3, cfg.eval_size, cfg.eval_size)
# Out:
# {'data_root': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/Data', 'train_pairs': 2217, 'val_pairs': 110, 'train_preview': ['L3_HR_train1/0000', 'L3_HR_train1/0001', 'L3_HR_train1/00010', 'L3_HR_train1/000100', 'L3_HR_train1/000101'], 'val_preview': ['0000', '00010', '000100', '000102', '000104'], 'sample_lr_shape': (3, 256, 256), 'sample_hr_shape': (3, 256, 256)}

# %% [markdown]
# ## 4. Model

# %%
class FSRCNNResidualNoUpscale(nn.Module):
    def __init__(self, channels: int = 96, shrink_channels: int = 40, mapping_layers: int = 8, slope: float = 0.10):
        super().__init__()
        self.channels = channels
        self.shrink_channels = shrink_channels
        self.mapping_layers = mapping_layers
        self.slope = slope

        self.features = nn.Sequential(*self._feature_layers())
        self.tail = nn.Conv2d(channels, 3, 3, padding=1, bias=True)
        self.init_tail_small()

    def _activation(self) -> nn.Module:
        return nn.LeakyReLU(self.slope, inplace=False)

    def _feature_layers(self) -> list[nn.Module]:
        stem = [
            nn.Conv2d(3, self.channels, 5, padding=2, bias=True),
            self._activation(),
        ]
        shrink = [
            nn.Conv2d(self.channels, self.shrink_channels, 1, padding=0, bias=True),
            self._activation(),
        ]
        mapping: list[nn.Module] = []
        for _ in range(self.mapping_layers):
            mapping.extend([
                nn.Conv2d(self.shrink_channels, self.shrink_channels, 3, padding=1, bias=True),
                self._activation(),
            ])
        expand = [
            nn.Conv2d(self.shrink_channels, self.channels, 1, padding=0, bias=True),
            self._activation(),
        ]
        return [*stem, *shrink, *mapping, *expand]

    def architecture_summary(self) -> dict[str, str | int]:
        return {
            'stem': f'Conv5x5 3->{self.channels} + LeakyReLU',
            'shrink': f'Conv1x1 {self.channels}->{self.shrink_channels} + LeakyReLU',
            'mapping': f'{self.mapping_layers}x Conv3x3 {self.shrink_channels}->{self.shrink_channels} + LeakyReLU',
            'expand': f'Conv1x1 {self.shrink_channels}->{self.channels} + LeakyReLU',
            'tail': f'Conv3x3 {self.channels}->3 predicts residual delta',
            'forward': 'output = input + tail(features(input))',
        }

    def init_tail_small(self) -> None:
        nn.init.kaiming_normal_(self.tail.weight, nonlinearity='linear')
        self.tail.weight.data.mul_(1e-3)
        if self.tail.bias is not None:
            nn.init.zeros_(self.tail.bias)

    def predict_delta(self, x: torch.Tensor) -> torch.Tensor:
        return self.tail(self.features(x))

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return x + self.predict_delta(x)


def count_parameters(module: nn.Module) -> int:
    return int(sum(param.numel() for param in module.parameters()))


def operator_audit(module: nn.Module) -> dict[str, int]:
    counts: dict[str, int] = {}
    for child in module.modules():
        if len(list(child.children())) != 0:
            continue
        name = child.__class__.__name__
        counts[name] = counts.get(name, 0) + 1
    return dict(sorted(counts.items()))

model = FSRCNNResidualNoUpscale().to(device)
eval_model = FSRCNNResidualNoUpscale().to(device)
param_count = count_parameters(model)
op_counts = operator_audit(model)
dummy = torch.zeros(1, 3, cfg.eval_size, cfg.eval_size, device=device)
with torch.no_grad():
    dummy_out = model(dummy)

print({
    'model_id': cfg.model_id,
    'params': param_count,
    'operator_audit': op_counts,
    'input_shape': tuple(dummy.shape),
    'output_shape': tuple(dummy_out.shape),
    'architecture': model.architecture_summary(),
})
assert param_count == 133_227, param_count
assert tuple(dummy_out.shape) == (1, 3, cfg.eval_size, cfg.eval_size)
assert set(op_counts).issubset({'Conv2d', 'LeakyReLU'}), op_counts
# Out:
# {'model_id': 'fsrcnn_residual_96_40_m8', 'params': 133227, 'operator_audit': {'Conv2d': 12, 'LeakyReLU': 11}, 'input_shape': (1, 3, 256, 256), 'output_shape': (1, 3, 256, 256), 'architecture': {'stem': 'Conv5x5 3->96 + LeakyReLU', 'shrink': 'Conv1x1 96->40 + LeakyReLU', 'mapping': '8x Conv3x3 40->40 + LeakyReLU', 'expand': 'Conv1x1 40->96 + LeakyReLU', 'tail': 'Conv3x3 96->3 predicts residual delta', 'forward': 'output = input + tail(features(input))'}}

# %% [markdown]
# ## 5. Training And Validation

# %%
class EMA:
    def __init__(self, model: nn.Module, decay: float):
        self.decay = decay
        self.shadow = {k: v.detach().clone() for k, v in model.state_dict().items()}

    @torch.no_grad()
    def update(self, model: nn.Module) -> None:
        for key, value in model.state_dict().items():
            self.shadow[key].mul_(self.decay).add_(value.detach(), alpha=1.0 - self.decay)

    @torch.no_grad()
    def copy_to(self, model: nn.Module) -> None:
        model.load_state_dict(self.shadow, strict=True)


def make_grad_scaler(enabled: bool):
    if hasattr(torch, 'amp') and hasattr(torch.amp, 'GradScaler'):
        return torch.amp.GradScaler('cuda', enabled=enabled)
    return torch.cuda.amp.GradScaler(enabled=enabled)


def autocast_context(device_type: str, enabled: bool):
    if not enabled:
        return nullcontext()
    if hasattr(torch, 'amp') and hasattr(torch.amp, 'autocast'):
        return torch.amp.autocast(device_type=device_type, enabled=enabled)
    return torch.cuda.amp.autocast(enabled=enabled)


@torch.no_grad()
def batch_psnr(pred: torch.Tensor, target: torch.Tensor) -> float:
    mse = F.mse_loss(pred, target, reduction='none').mean(dim=(1, 2, 3))
    psnr = 10.0 * torch.log10(1.0 / torch.clamp(mse, min=1e-12))
    return float(psnr.mean().item())


def compute_loss(pred: torch.Tensor, lr: torch.Tensor, hr: torch.Tensor) -> torch.Tensor:
    mse = F.mse_loss(pred, hr)
    residual_l1 = F.l1_loss(pred - lr, hr - lr)
    return 0.8 * mse + 0.2 * residual_l1


def lr_at_epoch(epoch_idx: int, *, base_lr: float, min_lr: float, warmup_epochs: int, total_epochs: int) -> float:
    step = epoch_idx + 1
    if warmup_epochs > 0 and step <= warmup_epochs:
        return base_lr * step / max(1, warmup_epochs)
    progress = max(0.0, (step - warmup_epochs) / max(1, total_epochs - warmup_epochs))
    cosine = 0.5 * (1.0 + math.cos(math.pi * min(progress, 1.0)))
    return min_lr + cosine * (base_lr - min_lr)


@torch.inference_mode()
def evaluate_metrics(model: nn.Module, loader: DataLoader, device: torch.device) -> dict[str, float]:
    model.eval()
    pred_meter = 0.0
    input_meter = 0.0
    count = 0
    for batch in loader:
        lr = batch['lr'].to(device, non_blocking=cuda_enabled)
        hr = batch['hr'].to(device, non_blocking=cuda_enabled)
        pred = model(lr).clamp(0.0, 1.0)
        pred_meter += batch_psnr(pred, hr)
        input_meter += batch_psnr(lr, hr)
        count += 1
    val_psnr = pred_meter / max(count, 1)
    input_psnr = input_meter / max(count, 1)
    return {'val_psnr': float(val_psnr), 'input_psnr': float(input_psnr), 'delta_psnr': float(val_psnr - input_psnr)}


def tensor_to_uint8_image(x: torch.Tensor) -> Image.Image:
    x = x.detach().cpu().clamp(0.0, 1.0)
    arr = (x.permute(1, 2, 0).numpy() * 255.0).round().astype(np.uint8)
    return Image.fromarray(arr)


@torch.no_grad()
def write_val_preview(model: nn.Module, loader: DataLoader, out_dir: Path, device: torch.device) -> dict[str, str]:
    out_dir.mkdir(parents=True, exist_ok=True)
    batch = next(iter(loader))
    lr = batch['lr'].to(device, non_blocking=cuda_enabled)
    hr = batch['hr'].to(device, non_blocking=cuda_enabled)
    pred = model(lr).clamp(0.0, 1.0)
    name = batch['name'][0]
    lr_path = out_dir / 'val_preview_input.png'
    pred_path = out_dir / 'val_preview_pred.png'
    hr_path = out_dir / 'val_preview_target.png'
    tensor_to_uint8_image(lr[0]).save(lr_path)
    tensor_to_uint8_image(pred[0]).save(pred_path)
    tensor_to_uint8_image(hr[0]).save(hr_path)
    return {'sample_name': str(name), 'input': str(lr_path), 'prediction': str(pred_path), 'target': str(hr_path)}


def checkpoint_payload(model: nn.Module, ema: EMA | None, optimizer: torch.optim.Optimizer, epoch: int, best_val_psnr: float, row: dict[str, Any]) -> dict[str, Any]:
    return {
        'config': asdict(cfg),
        'epoch': int(epoch),
        'model_state_dict': model.state_dict(),
        'ema_state_dict': ema.shadow if ema is not None else None,
        'optimizer_state_dict': optimizer.state_dict(),
        'best_val_psnr': float(best_val_psnr),
        'latest_metrics': row,
        'model_params': param_count,
        'operator_audit': op_counts,
    }


def load_checkpoint_for_eval(checkpoint_path: Path, device: torch.device) -> nn.Module:
    checkpoint = torch.load(checkpoint_path, map_location=device)
    loaded = FSRCNNResidualNoUpscale().to(device)
    state = checkpoint.get('ema_state_dict') or checkpoint['model_state_dict']
    loaded.load_state_dict(state, strict=True)
    loaded.eval()
    return loaded

optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)
scaler = make_grad_scaler(cfg.use_amp and cuda_enabled)
ema = EMA(model, cfg.ema_decay) if cfg.use_ema else None
best_val_psnr = float('-inf')
start_epoch = 0

metrics_header = ['epoch', 'epoch_time_sec', 'lr', 'train_loss', 'train_psnr', 'val_psnr', 'input_psnr', 'delta_psnr', 'best_val_psnr']
best_ckpt_path = checkpoints_dir / 'best.pth'
last_ckpt_path = checkpoints_dir / 'last.pth'

if cfg.enable_resume:
    if cfg.resume_checkpoint_path is None:
        raise ValueError('cfg.enable_resume=True requires cfg.resume_checkpoint_path')
    resume_checkpoint_path = Path(cfg.resume_checkpoint_path)
    if not resume_checkpoint_path.exists():
        raise FileNotFoundError(f'Resume checkpoint not found: {resume_checkpoint_path}')
    resume_checkpoint = torch.load(resume_checkpoint_path, map_location=device)
    model.load_state_dict(resume_checkpoint['model_state_dict'], strict=True)
    if 'optimizer_state_dict' in resume_checkpoint:
        optimizer.load_state_dict(resume_checkpoint['optimizer_state_dict'])
    if ema is not None and resume_checkpoint.get('ema_state_dict') is not None:
        ema.shadow = {key: value.detach().clone().to(device) for key, value in resume_checkpoint['ema_state_dict'].items()}
    best_val_psnr = float(resume_checkpoint.get('best_val_psnr', best_val_psnr))
    start_epoch = int(resume_checkpoint.get('epoch', 0))
    print({
        'resume_checkpoint_path': str(resume_checkpoint_path),
        'resumed_from_epoch': start_epoch,
        'target_total_epochs': cfg.epochs,
        'best_val_psnr': best_val_psnr,
    })

if start_epoch >= cfg.epochs:
    raise ValueError(f'Resume checkpoint epoch {start_epoch} is already >= target epochs {cfg.epochs}')

history = {
    'metadata': {
        'config': asdict(cfg),
        'run_root': str(run_root),
        'resume_checkpoint_path': cfg.resume_checkpoint_path,
        'start_epoch': start_epoch,
        'target_total_epochs': cfg.epochs,
        'device': str(device),
        'gpu_name': gpu_name,
        'torch_version': torch.__version__,
        'cuda_version': torch.version.cuda,
    },
    'epochs': [],
}
write_json(history_json_path, history)

with metrics_csv_path.open('w', newline='', encoding='utf-8') as f:
    csv.DictWriter(f, fieldnames=metrics_header).writeheader()

for epoch in range(start_epoch, cfg.epochs):
    train_ds.set_epoch(epoch)
    epoch_lr = lr_at_epoch(epoch, base_lr=cfg.lr, min_lr=cfg.min_lr, warmup_epochs=cfg.warmup_epochs, total_epochs=cfg.epochs)
    for group in optimizer.param_groups:
        group['lr'] = epoch_lr

    epoch_start = time.time()
    model.train()
    train_loss_sum = 0.0
    train_psnr_sum = 0.0
    train_batches = 0

    for batch in train_loader:
        lr = batch['lr'].to(device, non_blocking=cuda_enabled)
        hr = batch['hr'].to(device, non_blocking=cuda_enabled)
        optimizer.zero_grad(set_to_none=True)
        with autocast_context(device.type, enabled=(cfg.use_amp and cuda_enabled)):
            pred = model(lr)
            loss = compute_loss(pred, lr, hr)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        if ema is not None:
            ema.update(model)
        train_loss_sum += float(loss.item())
        train_psnr_sum += batch_psnr(pred.detach().clamp(0.0, 1.0), hr)
        train_batches += 1

    if ema is not None:
        ema.copy_to(eval_model)
    else:
        eval_model.load_state_dict(model.state_dict())
    eval_model.eval()

    avg_train_loss = train_loss_sum / max(train_batches, 1)
    avg_train_psnr = train_psnr_sum / max(train_batches, 1)
    val_metrics = evaluate_metrics(eval_model, val_loader, device)
    is_best = val_metrics['val_psnr'] > best_val_psnr
    if is_best:
        best_val_psnr = val_metrics['val_psnr']
    row = {
        'epoch': epoch + 1,
        'epoch_time_sec': round(time.time() - epoch_start, 2),
        'lr': epoch_lr,
        'train_loss': round(avg_train_loss, 6),
        'train_psnr': round(avg_train_psnr, 4),
        'val_psnr': round(val_metrics['val_psnr'], 4),
        'input_psnr': round(val_metrics['input_psnr'], 4),
        'delta_psnr': round(val_metrics['delta_psnr'], 4),
        'best_val_psnr': round(best_val_psnr, 4),
    }
    print(row)
    history['epochs'].append(row)
    write_json(history_json_path, history)
    with metrics_csv_path.open('a', newline='', encoding='utf-8') as f:
        csv.DictWriter(f, fieldnames=metrics_header).writerow(row)
    payload = checkpoint_payload(model, ema, optimizer, epoch + 1, best_val_psnr, row)
    torch.save(payload, last_ckpt_path)
    if is_best:
        torch.save(payload, best_ckpt_path)
# Out:
# {'resume_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/162933_2704_fsrcnn_residual_96_40_m8/checkpoints/last.pth', 'resumed_from_epoch': 2838, 'target_total_epochs': 4000, 'best_val_psnr': 24.02979134646329}
# {'epoch': 2839, 'epoch_time_sec': 1674.48, 'lr': 2.0263395816199945e-05, 'train_loss': 0.011603, 'train_psnr': 25.148, 'val_psnr': 24.0299, 'input_psnr': 23.1331, 'delta_psnr': 0.8968, 'best_val_psnr': 24.0299}
# {'epoch': 2840, 'epoch_time_sec': 39.14, 'lr': 2.0232562323254738e-05, 'train_loss': 0.011594, 'train_psnr': 25.1514, 'val_psnr': 24.0299, 'input_psnr': 23.1331, 'delta_psnr': 0.8969, 'best_val_psnr': 24.0299}
# {'epoch': 2841, 'epoch_time_sec': 39.66, 'lr': 2.0201747575692396e-05, 'train_loss': 0.011593, 'train_psnr': 25.1533, 'val_psnr': 24.0302, 'input_psnr': 23.1331, 'delta_psnr': 0.8971, 'best_val_psnr': 24.0302}
# {'epoch': 2842, 'epoch_time_sec': 39.64, 'lr': 2.0170951592597226e-05, 'train_loss': 0.011593, 'train_psnr': 25.153, 'val_psnr': 24.0303, 'input_psnr': 23.1331, 'delta_psnr': 0.8972, 'best_val_psnr': 24.0303}
# {'epoch': 2843, 'epoch_time_sec': 39.6, 'lr': 2.014017439304196e-05, 'train_loss': 0.011591, 'train_psnr': 25.154, 'val_psnr': 24.0305, 'input_psnr': 23.1331, 'delta_psnr': 0.8974, 'best_val_psnr': 24.0305}
# {'epoch': 2844, 'epoch_time_sec': 39.52, 'lr': 2.0109415996087722e-05, 'train_loss': 0.011612, 'train_psnr': 25.1452, 'val_psnr': 24.0308, 'input_psnr': 23.1331, 'delta_psnr': 0.8978, 'best_val_psnr': 24.0308}
# {'epoch': 2845, 'epoch_time_sec': 39.99, 'lr': 2.0078676420783917e-05, 'train_loss': 0.011587, 'train_psnr': 25.1558, 'val_psnr': 24.0308, 'input_psnr': 23.1331, 'delta_psnr': 0.8978, 'best_val_psnr': 24.0308}
# {'epoch': 2846, 'epoch_time_sec': 40.22, 'lr': 2.004795568616835e-05, 'train_loss': 0.011591, 'train_psnr': 25.1546, 'val_psnr': 24.0311, 'input_psnr': 23.1331, 'delta_psnr': 0.898, 'best_val_psnr': 24.0311}
# {'epoch': 2847, 'epoch_time_sec': 39.71, 'lr': 2.0017253811267154e-05, 'train_loss': 0.011605, 'train_psnr': 25.1509, 'val_psnr': 24.0313, 'input_psnr': 23.1331, 'delta_psnr': 0.8982, 'best_val_psnr': 24.0313}
# {'epoch': 2848, 'epoch_time_sec': 39.72, 'lr': 1.9986570815094734e-05, 'train_loss': 0.011588, 'train_psnr': 25.1562, 'val_psnr': 24.0315, 'input_psnr': 23.1331, 'delta_psnr': 0.8984, 'best_val_psnr': 24.0315}
# {'epoch': 2849, 'epoch_time_sec': 39.58, 'lr': 1.9955906716653895e-05, 'train_loss': 0.011584, 'train_psnr': 25.1593, 'val_psnr': 24.0316, 'input_psnr': 23.1331, 'delta_psnr': 0.8985, 'best_val_psnr': 24.0316}
# {'epoch': 2850, 'epoch_time_sec': 39.67, 'lr': 1.9925261534935632e-05, 'train_loss': 0.011596, 'train_psnr': 25.152, 'val_psnr': 24.0319, 'input_psnr': 23.1331, 'delta_psnr': 0.8988, 'best_val_psnr': 24.0319}
# {'epoch': 2851, 'epoch_time_sec': 39.63, 'lr': 1.9894635288919296e-05, 'train_loss': 0.011604, 'train_psnr': 25.147, 'val_psnr': 24.0319, 'input_psnr': 23.1331, 'delta_psnr': 0.8989, 'best_val_psnr': 24.0319}
# {'epoch': 2852, 'epoch_time_sec': 40.09, 'lr': 1.98640279975725e-05, 'train_loss': 0.011595, 'train_psnr': 25.1515, 'val_psnr': 24.032, 'input_psnr': 23.1331, 'delta_psnr': 0.899, 'best_val_psnr': 24.032}
# {'epoch': 2853, 'epoch_time_sec': 40.02, 'lr': 1.9833439679851082e-05, 'train_loss': 0.011597, 'train_psnr': 25.1516, 'val_psnr': 24.0322, 'input_psnr': 23.1331, 'delta_psnr': 0.8991, 'best_val_psnr': 24.0322}
# {'epoch': 2854, 'epoch_time_sec': 39.61, 'lr': 1.9802870354699154e-05, 'train_loss': 0.011595, 'train_psnr': 25.1517, 'val_psnr': 24.0322, 'input_psnr': 23.1331, 'delta_psnr': 0.8992, 'best_val_psnr': 24.0322}
# {'epoch': 2855, 'epoch_time_sec': 39.59, 'lr': 1.9772320041049102e-05, 'train_loss': 0.011589, 'train_psnr': 25.1546, 'val_psnr': 24.0323, 'input_psnr': 23.1331, 'delta_psnr': 0.8993, 'best_val_psnr': 24.0323}
# {'epoch': 2856, 'epoch_time_sec': 39.52, 'lr': 1.9741788757821454e-05, 'train_loss': 0.011586, 'train_psnr': 25.1564, 'val_psnr': 24.0324, 'input_psnr': 23.1331, 'delta_psnr': 0.8993, 'best_val_psnr': 24.0324}
# {'epoch': 2857, 'epoch_time_sec': 39.65, 'lr': 1.9711276523925016e-05, 'train_loss': 0.011587, 'train_psnr': 25.1596, 'val_psnr': 24.0325, 'input_psnr': 23.1331, 'delta_psnr': 0.8994, 'best_val_psnr': 24.0325}
# {'epoch': 2858, 'epoch_time_sec': 39.67, 'lr': 1.9680783358256803e-05, 'train_loss': 0.011598, 'train_psnr': 25.152, 'val_psnr': 24.0326, 'input_psnr': 23.1331, 'delta_psnr': 0.8995, 'best_val_psnr': 24.0326}
# {'epoch': 2859, 'epoch_time_sec': 40.31, 'lr': 1.9650309279701957e-05, 'train_loss': 0.011589, 'train_psnr': 25.1564, 'val_psnr': 24.0326, 'input_psnr': 23.1331, 'delta_psnr': 0.8995, 'best_val_psnr': 24.0326}
# {'epoch': 2860, 'epoch_time_sec': 39.69, 'lr': 1.9619854307133865e-05, 'train_loss': 0.011588, 'train_psnr': 25.1549, 'val_psnr': 24.0327, 'input_psnr': 23.1331, 'delta_psnr': 0.8996, 'best_val_psnr': 24.0327}
# {'epoch': 2861, 'epoch_time_sec': 39.71, 'lr': 1.9589418459414057e-05, 'train_loss': 0.011589, 'train_psnr': 25.1577, 'val_psnr': 24.0328, 'input_psnr': 23.1331, 'delta_psnr': 0.8997, 'best_val_psnr': 24.0328}
# {'epoch': 2862, 'epoch_time_sec': 39.61, 'lr': 1.9559001755392198e-05, 'train_loss': 0.011593, 'train_psnr': 25.1556, 'val_psnr': 24.0328, 'input_psnr': 23.1331, 'delta_psnr': 0.8998, 'best_val_psnr': 24.0328}
# {'epoch': 2863, 'epoch_time_sec': 39.55, 'lr': 1.9528604213906125e-05, 'train_loss': 0.011587, 'train_psnr': 25.1548, 'val_psnr': 24.0328, 'input_psnr': 23.1331, 'delta_psnr': 0.8997, 'best_val_psnr': 24.0328}
# {'epoch': 2864, 'epoch_time_sec': 39.58, 'lr': 1.949822585378179e-05, 'train_loss': 0.011606, 'train_psnr': 25.1508, 'val_psnr': 24.0328, 'input_psnr': 23.1331, 'delta_psnr': 0.8998, 'best_val_psnr': 24.0328}
# {'epoch': 2865, 'epoch_time_sec': 39.81, 'lr': 1.94678666938333e-05, 'train_loss': 0.011584, 'train_psnr': 25.1583, 'val_psnr': 24.033, 'input_psnr': 23.1331, 'delta_psnr': 0.8999, 'best_val_psnr': 24.033}
# {'epoch': 2866, 'epoch_time_sec': 40.35, 'lr': 1.9437526752862812e-05, 'train_loss': 0.01158, 'train_psnr': 25.1618, 'val_psnr': 24.033, 'input_psnr': 23.1331, 'delta_psnr': 0.8999, 'best_val_psnr': 24.033}
# {'epoch': 2867, 'epoch_time_sec': 39.57, 'lr': 1.940720604966062e-05, 'train_loss': 0.011588, 'train_psnr': 25.1575, 'val_psnr': 24.033, 'input_psnr': 23.1331, 'delta_psnr': 0.9, 'best_val_psnr': 24.033}
# {'epoch': 2868, 'epoch_time_sec': 39.55, 'lr': 1.937690460300512e-05, 'train_loss': 0.011578, 'train_psnr': 25.1646, 'val_psnr': 24.033, 'input_psnr': 23.1331, 'delta_psnr': 0.9, 'best_val_psnr': 24.033}
# {'epoch': 2869, 'epoch_time_sec': 39.6, 'lr': 1.9346622431662717e-05, 'train_loss': 0.011602, 'train_psnr': 25.1513, 'val_psnr': 24.0331, 'input_psnr': 23.1331, 'delta_psnr': 0.9001, 'best_val_psnr': 24.0331}
# {'epoch': 2870, 'epoch_time_sec': 39.55, 'lr': 1.9316359554387938e-05, 'train_loss': 0.011616, 'train_psnr': 25.1467, 'val_psnr': 24.0331, 'input_psnr': 23.1331, 'delta_psnr': 0.9001, 'best_val_psnr': 24.0331}
# {'epoch': 2871, 'epoch_time_sec': 39.67, 'lr': 1.9286115989923363e-05, 'train_loss': 0.011598, 'train_psnr': 25.1524, 'val_psnr': 24.0332, 'input_psnr': 23.1331, 'delta_psnr': 0.9001, 'best_val_psnr': 24.0332}
# {'epoch': 2872, 'epoch_time_sec': 39.9, 'lr': 1.925589175699953e-05, 'train_loss': 0.011577, 'train_psnr': 25.1631, 'val_psnr': 24.0332, 'input_psnr': 23.1331, 'delta_psnr': 0.9001, 'best_val_psnr': 24.0332}
# {'epoch': 2873, 'epoch_time_sec': 40.44, 'lr': 1.922568687433514e-05, 'train_loss': 0.011592, 'train_psnr': 25.1531, 'val_psnr': 24.0333, 'input_psnr': 23.1331, 'delta_psnr': 0.9002, 'best_val_psnr': 24.0333}
# {'epoch': 2874, 'epoch_time_sec': 39.66, 'lr': 1.9195501360636792e-05, 'train_loss': 0.011586, 'train_psnr': 25.1572, 'val_psnr': 24.0333, 'input_psnr': 23.1331, 'delta_psnr': 0.9002, 'best_val_psnr': 24.0333}
# {'epoch': 2875, 'epoch_time_sec': 39.59, 'lr': 1.916533523459911e-05, 'train_loss': 0.0116, 'train_psnr': 25.1521, 'val_psnr': 24.0333, 'input_psnr': 23.1331, 'delta_psnr': 0.9003, 'best_val_psnr': 24.0333}
# {'epoch': 2876, 'epoch_time_sec': 39.71, 'lr': 1.913518851490479e-05, 'train_loss': 0.011581, 'train_psnr': 25.1614, 'val_psnr': 24.0333, 'input_psnr': 23.1331, 'delta_psnr': 0.9002, 'best_val_psnr': 24.0333}
# {'epoch': 2877, 'epoch_time_sec': 39.61, 'lr': 1.91050612202244e-05, 'train_loss': 0.011581, 'train_psnr': 25.1598, 'val_psnr': 24.0333, 'input_psnr': 23.1331, 'delta_psnr': 0.9002, 'best_val_psnr': 24.0333}
# {'epoch': 2878, 'epoch_time_sec': 39.59, 'lr': 1.9074953369216543e-05, 'train_loss': 0.011594, 'train_psnr': 25.1536, 'val_psnr': 24.0334, 'input_psnr': 23.1331, 'delta_psnr': 0.9003, 'best_val_psnr': 24.0334}
# {'epoch': 2879, 'epoch_time_sec': 40.05, 'lr': 1.90448649805278e-05, 'train_loss': 0.011581, 'train_psnr': 25.16, 'val_psnr': 24.0334, 'input_psnr': 23.1331, 'delta_psnr': 0.9004, 'best_val_psnr': 24.0334}
# {'epoch': 2880, 'epoch_time_sec': 40.07, 'lr': 1.901479607279261e-05, 'train_loss': 0.011588, 'train_psnr': 25.1575, 'val_psnr': 24.0333, 'input_psnr': 23.1331, 'delta_psnr': 0.9003, 'best_val_psnr': 24.0334}
# {'epoch': 2881, 'epoch_time_sec': 39.71, 'lr': 1.8984746664633425e-05, 'train_loss': 0.011579, 'train_psnr': 25.1602, 'val_psnr': 24.0335, 'input_psnr': 23.1331, 'delta_psnr': 0.9004, 'best_val_psnr': 24.0335}
# {'epoch': 2882, 'epoch_time_sec': 39.65, 'lr': 1.895471677466062e-05, 'train_loss': 0.0116, 'train_psnr': 25.1525, 'val_psnr': 24.0336, 'input_psnr': 23.1331, 'delta_psnr': 0.9005, 'best_val_psnr': 24.0336}
# {'epoch': 2883, 'epoch_time_sec': 39.63, 'lr': 1.892470642147242e-05, 'train_loss': 0.011583, 'train_psnr': 25.1589, 'val_psnr': 24.0336, 'input_psnr': 23.1331, 'delta_psnr': 0.9005, 'best_val_psnr': 24.0336}
# {'epoch': 2884, 'epoch_time_sec': 39.67, 'lr': 1.8894715623655002e-05, 'train_loss': 0.011586, 'train_psnr': 25.157, 'val_psnr': 24.0336, 'input_psnr': 23.1331, 'delta_psnr': 0.9005, 'best_val_psnr': 24.0336}
# {'epoch': 2885, 'epoch_time_sec': 39.62, 'lr': 1.886474439978244e-05, 'train_loss': 0.011587, 'train_psnr': 25.1555, 'val_psnr': 24.0335, 'input_psnr': 23.1331, 'delta_psnr': 0.9005, 'best_val_psnr': 24.0336}
# {'epoch': 2886, 'epoch_time_sec': 40.25, 'lr': 1.883479276841663e-05, 'train_loss': 0.011591, 'train_psnr': 25.1554, 'val_psnr': 24.0337, 'input_psnr': 23.1331, 'delta_psnr': 0.9006, 'best_val_psnr': 24.0337}
# {'epoch': 2887, 'epoch_time_sec': 39.82, 'lr': 1.8804860748107384e-05, 'train_loss': 0.011602, 'train_psnr': 25.1501, 'val_psnr': 24.0336, 'input_psnr': 23.1331, 'delta_psnr': 0.9005, 'best_val_psnr': 24.0337}
# {'epoch': 2888, 'epoch_time_sec': 39.52, 'lr': 1.877494835739236e-05, 'train_loss': 0.011596, 'train_psnr': 25.1539, 'val_psnr': 24.0336, 'input_psnr': 23.1331, 'delta_psnr': 0.9006, 'best_val_psnr': 24.0337}
# {'epoch': 2889, 'epoch_time_sec': 39.54, 'lr': 1.8745055614797057e-05, 'train_loss': 0.01158, 'train_psnr': 25.1603, 'val_psnr': 24.0336, 'input_psnr': 23.1331, 'delta_psnr': 0.9006, 'best_val_psnr': 24.0337}
# {'epoch': 2890, 'epoch_time_sec': 39.66, 'lr': 1.871518253883477e-05, 'train_loss': 0.01158, 'train_psnr': 25.1618, 'val_psnr': 24.0337, 'input_psnr': 23.1331, 'delta_psnr': 0.9007, 'best_val_psnr': 24.0337}
# {'epoch': 2891, 'epoch_time_sec': 39.65, 'lr': 1.8685329148006656e-05, 'train_loss': 0.011587, 'train_psnr': 25.1562, 'val_psnr': 24.0337, 'input_psnr': 23.1331, 'delta_psnr': 0.9007, 'best_val_psnr': 24.0337}
# {'epoch': 2892, 'epoch_time_sec': 39.8, 'lr': 1.86554954608017e-05, 'train_loss': 0.011575, 'train_psnr': 25.1629, 'val_psnr': 24.0338, 'input_psnr': 23.1331, 'delta_psnr': 0.9007, 'best_val_psnr': 24.0338}
# {'epoch': 2893, 'epoch_time_sec': 40.33, 'lr': 1.86256814956966e-05, 'train_loss': 0.011588, 'train_psnr': 25.1557, 'val_psnr': 24.0337, 'input_psnr': 23.1331, 'delta_psnr': 0.9006, 'best_val_psnr': 24.0338}
# {'epoch': 2894, 'epoch_time_sec': 39.59, 'lr': 1.8595887271155928e-05, 'train_loss': 0.011605, 'train_psnr': 25.1507, 'val_psnr': 24.0336, 'input_psnr': 23.1331, 'delta_psnr': 0.9005, 'best_val_psnr': 24.0338}
# {'epoch': 2895, 'epoch_time_sec': 39.63, 'lr': 1.8566112805631994e-05, 'train_loss': 0.01158, 'train_psnr': 25.1611, 'val_psnr': 24.0337, 'input_psnr': 23.1331, 'delta_psnr': 0.9006, 'best_val_psnr': 24.0338}
# {'epoch': 2896, 'epoch_time_sec': 39.58, 'lr': 1.8536358117564842e-05, 'train_loss': 0.011586, 'train_psnr': 25.1565, 'val_psnr': 24.0337, 'input_psnr': 23.1331, 'delta_psnr': 0.9006, 'best_val_psnr': 24.0338}
# {'epoch': 2897, 'epoch_time_sec': 39.65, 'lr': 1.8506623225382317e-05, 'train_loss': 0.011578, 'train_psnr': 25.1605, 'val_psnr': 24.0338, 'input_psnr': 23.1331, 'delta_psnr': 0.9007, 'best_val_psnr': 24.0338}
# {'epoch': 2898, 'epoch_time_sec': 39.66, 'lr': 1.8476908147499998e-05, 'train_loss': 0.011576, 'train_psnr': 25.1615, 'val_psnr': 24.0338, 'input_psnr': 23.1331, 'delta_psnr': 0.9007, 'best_val_psnr': 24.0338}
# {'epoch': 2899, 'epoch_time_sec': 40.07, 'lr': 1.844721290232113e-05, 'train_loss': 0.01159, 'train_psnr': 25.1563, 'val_psnr': 24.0338, 'input_psnr': 23.1331, 'delta_psnr': 0.9007, 'best_val_psnr': 24.0338}
# {'epoch': 2900, 'epoch_time_sec': 40.12, 'lr': 1.841753750823678e-05, 'train_loss': 0.011588, 'train_psnr': 25.1557, 'val_psnr': 24.0338, 'input_psnr': 23.1331, 'delta_psnr': 0.9007, 'best_val_psnr': 24.0338}
# {'epoch': 2901, 'epoch_time_sec': 39.64, 'lr': 1.8387881983625638e-05, 'train_loss': 0.011576, 'train_psnr': 25.1631, 'val_psnr': 24.0339, 'input_psnr': 23.1331, 'delta_psnr': 0.9008, 'best_val_psnr': 24.0339}
# {'epoch': 2902, 'epoch_time_sec': 39.71, 'lr': 1.8358246346854082e-05, 'train_loss': 0.01158, 'train_psnr': 25.1606, 'val_psnr': 24.0338, 'input_psnr': 23.1331, 'delta_psnr': 0.9008, 'best_val_psnr': 24.0339}
# {'epoch': 2903, 'epoch_time_sec': 39.7, 'lr': 1.8328630616276268e-05, 'train_loss': 0.011574, 'train_psnr': 25.1641, 'val_psnr': 24.0339, 'input_psnr': 23.1331, 'delta_psnr': 0.9008, 'best_val_psnr': 24.0339}
# {'epoch': 2904, 'epoch_time_sec': 39.73, 'lr': 1.8299034810233925e-05, 'train_loss': 0.01158, 'train_psnr': 25.1607, 'val_psnr': 24.0338, 'input_psnr': 23.1331, 'delta_psnr': 0.9008, 'best_val_psnr': 24.0339}
# {'epoch': 2905, 'epoch_time_sec': 39.67, 'lr': 1.8269458947056446e-05, 'train_loss': 0.011603, 'train_psnr': 25.1502, 'val_psnr': 24.0339, 'input_psnr': 23.1331, 'delta_psnr': 0.9008, 'best_val_psnr': 24.0339}
# {'epoch': 2906, 'epoch_time_sec': 40.12, 'lr': 1.823990304506097e-05, 'train_loss': 0.011581, 'train_psnr': 25.1588, 'val_psnr': 24.0338, 'input_psnr': 23.1331, 'delta_psnr': 0.9008, 'best_val_psnr': 24.0339}
# {'epoch': 2907, 'epoch_time_sec': 39.85, 'lr': 1.8210367122552163e-05, 'train_loss': 0.011598, 'train_psnr': 25.1518, 'val_psnr': 24.0338, 'input_psnr': 23.1331, 'delta_psnr': 0.9008, 'best_val_psnr': 24.0339}
# {'epoch': 2908, 'epoch_time_sec': 39.54, 'lr': 1.818085119782238e-05, 'train_loss': 0.011578, 'train_psnr': 25.1632, 'val_psnr': 24.0339, 'input_psnr': 23.1331, 'delta_psnr': 0.9008, 'best_val_psnr': 24.0339}
# {'epoch': 2909, 'epoch_time_sec': 39.64, 'lr': 1.8151355289151577e-05, 'train_loss': 0.011572, 'train_psnr': 25.1659, 'val_psnr': 24.0339, 'input_psnr': 23.1331, 'delta_psnr': 0.9009, 'best_val_psnr': 24.0339}
# {'epoch': 2910, 'epoch_time_sec': 39.59, 'lr': 1.8121879414807287e-05, 'train_loss': 0.011581, 'train_psnr': 25.1596, 'val_psnr': 24.0339, 'input_psnr': 23.1331, 'delta_psnr': 0.9008, 'best_val_psnr': 24.0339}
# {'epoch': 2911, 'epoch_time_sec': 39.76, 'lr': 1.8092423593044673e-05, 'train_loss': 0.011582, 'train_psnr': 25.1585, 'val_psnr': 24.0341, 'input_psnr': 23.1331, 'delta_psnr': 0.9011, 'best_val_psnr': 24.0341}
# {'epoch': 2912, 'epoch_time_sec': 39.78, 'lr': 1.8062987842106476e-05, 'train_loss': 0.011591, 'train_psnr': 25.1573, 'val_psnr': 24.0341, 'input_psnr': 23.1331, 'delta_psnr': 0.901, 'best_val_psnr': 24.0341}
# {'epoch': 2913, 'epoch_time_sec': 40.37, 'lr': 1.8033572180222966e-05, 'train_loss': 0.011584, 'train_psnr': 25.1619, 'val_psnr': 24.0341, 'input_psnr': 23.1331, 'delta_psnr': 0.901, 'best_val_psnr': 24.0341}
# {'epoch': 2914, 'epoch_time_sec': 39.56, 'lr': 1.8004176625612013e-05, 'train_loss': 0.011576, 'train_psnr': 25.1628, 'val_psnr': 24.0341, 'input_psnr': 23.1331, 'delta_psnr': 0.901, 'best_val_psnr': 24.0341}
# {'epoch': 2915, 'epoch_time_sec': 39.58, 'lr': 1.7974801196479025e-05, 'train_loss': 0.011574, 'train_psnr': 25.1645, 'val_psnr': 24.0341, 'input_psnr': 23.1331, 'delta_psnr': 0.901, 'best_val_psnr': 24.0341}
# {'epoch': 2916, 'epoch_time_sec': 39.68, 'lr': 1.794544591101695e-05, 'train_loss': 0.011586, 'train_psnr': 25.1597, 'val_psnr': 24.0341, 'input_psnr': 23.1331, 'delta_psnr': 0.9011, 'best_val_psnr': 24.0341}
# {'epoch': 2917, 'epoch_time_sec': 39.6, 'lr': 1.7916110787406236e-05, 'train_loss': 0.011583, 'train_psnr': 25.1605, 'val_psnr': 24.0342, 'input_psnr': 23.1331, 'delta_psnr': 0.9011, 'best_val_psnr': 24.0342}
# {'epoch': 2918, 'epoch_time_sec': 39.57, 'lr': 1.7886795843814855e-05, 'train_loss': 0.011579, 'train_psnr': 25.1611, 'val_psnr': 24.0342, 'input_psnr': 23.1331, 'delta_psnr': 0.9011, 'best_val_psnr': 24.0342}
# {'epoch': 2919, 'epoch_time_sec': 39.88, 'lr': 1.785750109839832e-05, 'train_loss': 0.011586, 'train_psnr': 25.1581, 'val_psnr': 24.0342, 'input_psnr': 23.1331, 'delta_psnr': 0.9012, 'best_val_psnr': 24.0342}
# {'epoch': 2920, 'epoch_time_sec': 40.3, 'lr': 1.782822656929956e-05, 'train_loss': 0.01158, 'train_psnr': 25.1604, 'val_psnr': 24.0342, 'input_psnr': 23.1331, 'delta_psnr': 0.9011, 'best_val_psnr': 24.0342}
# {'epoch': 2921, 'epoch_time_sec': 39.67, 'lr': 1.7798972274649037e-05, 'train_loss': 0.011591, 'train_psnr': 25.1558, 'val_psnr': 24.0341, 'input_psnr': 23.1331, 'delta_psnr': 0.901, 'best_val_psnr': 24.0342}
# {'epoch': 2922, 'epoch_time_sec': 39.62, 'lr': 1.7769738232564697e-05, 'train_loss': 0.011584, 'train_psnr': 25.1588, 'val_psnr': 24.0342, 'input_psnr': 23.1331, 'delta_psnr': 0.9011, 'best_val_psnr': 24.0342}
# {'epoch': 2923, 'epoch_time_sec': 39.61, 'lr': 1.774052446115186e-05, 'train_loss': 0.011591, 'train_psnr': 25.155, 'val_psnr': 24.0342, 'input_psnr': 23.1331, 'delta_psnr': 0.9011, 'best_val_psnr': 24.0342}
# {'epoch': 2924, 'epoch_time_sec': 39.67, 'lr': 1.7711330978503414e-05, 'train_loss': 0.011579, 'train_psnr': 25.1613, 'val_psnr': 24.0343, 'input_psnr': 23.1331, 'delta_psnr': 0.9013, 'best_val_psnr': 24.0343}
# {'epoch': 2925, 'epoch_time_sec': 39.67, 'lr': 1.7682157802699575e-05, 'train_loss': 0.011576, 'train_psnr': 25.1631, 'val_psnr': 24.0343, 'input_psnr': 23.1331, 'delta_psnr': 0.9013, 'best_val_psnr': 24.0343}
# {'epoch': 2926, 'epoch_time_sec': 39.97, 'lr': 1.7653004951808e-05, 'train_loss': 0.011584, 'train_psnr': 25.1589, 'val_psnr': 24.0343, 'input_psnr': 23.1331, 'delta_psnr': 0.9013, 'best_val_psnr': 24.0343}
# {'epoch': 2927, 'epoch_time_sec': 40.18, 'lr': 1.7623872443883834e-05, 'train_loss': 0.011572, 'train_psnr': 25.1643, 'val_psnr': 24.0343, 'input_psnr': 23.1331, 'delta_psnr': 0.9013, 'best_val_psnr': 24.0343}
# {'epoch': 2928, 'epoch_time_sec': 39.64, 'lr': 1.7594760296969548e-05, 'train_loss': 0.011598, 'train_psnr': 25.1534, 'val_psnr': 24.0344, 'input_psnr': 23.1331, 'delta_psnr': 0.9013, 'best_val_psnr': 24.0344}
# {'epoch': 2929, 'epoch_time_sec': 39.68, 'lr': 1.756566852909498e-05, 'train_loss': 0.011577, 'train_psnr': 25.1632, 'val_psnr': 24.0344, 'input_psnr': 23.1331, 'delta_psnr': 0.9014, 'best_val_psnr': 24.0344}
# {'epoch': 2930, 'epoch_time_sec': 39.64, 'lr': 1.753659715827747e-05, 'train_loss': 0.011591, 'train_psnr': 25.1562, 'val_psnr': 24.0344, 'input_psnr': 23.1331, 'delta_psnr': 0.9014, 'best_val_psnr': 24.0344}
# {'epoch': 2931, 'epoch_time_sec': 39.74, 'lr': 1.7507546202521587e-05, 'train_loss': 0.011581, 'train_psnr': 25.1598, 'val_psnr': 24.0344, 'input_psnr': 23.1331, 'delta_psnr': 0.9013, 'best_val_psnr': 24.0344}
# {'epoch': 2932, 'epoch_time_sec': 39.58, 'lr': 1.747851567981934e-05, 'train_loss': 0.011583, 'train_psnr': 25.1599, 'val_psnr': 24.0344, 'input_psnr': 23.1331, 'delta_psnr': 0.9014, 'best_val_psnr': 24.0344}
# {'epoch': 2933, 'epoch_time_sec': 40.2, 'lr': 1.744950560815007e-05, 'train_loss': 0.011572, 'train_psnr': 25.1648, 'val_psnr': 24.0345, 'input_psnr': 23.1331, 'delta_psnr': 0.9014, 'best_val_psnr': 24.0345}
# {'epoch': 2934, 'epoch_time_sec': 39.82, 'lr': 1.7420516005480406e-05, 'train_loss': 0.011575, 'train_psnr': 25.1635, 'val_psnr': 24.0345, 'input_psnr': 23.1331, 'delta_psnr': 0.9014, 'best_val_psnr': 24.0345}
# {'epoch': 2935, 'epoch_time_sec': 39.69, 'lr': 1.7391546889764364e-05, 'train_loss': 0.011589, 'train_psnr': 25.155, 'val_psnr': 24.0344, 'input_psnr': 23.1331, 'delta_psnr': 0.9013, 'best_val_psnr': 24.0345}
# {'epoch': 2936, 'epoch_time_sec': 39.67, 'lr': 1.7362598278943247e-05, 'train_loss': 0.011578, 'train_psnr': 25.1612, 'val_psnr': 24.0344, 'input_psnr': 23.1331, 'delta_psnr': 0.9014, 'best_val_psnr': 24.0345}
# {'epoch': 2937, 'epoch_time_sec': 39.6, 'lr': 1.7333670190945632e-05, 'train_loss': 0.011586, 'train_psnr': 25.1591, 'val_psnr': 24.0345, 'input_psnr': 23.1331, 'delta_psnr': 0.9014, 'best_val_psnr': 24.0345}
# {'epoch': 2938, 'epoch_time_sec': 39.58, 'lr': 1.730476264368742e-05, 'train_loss': 0.011597, 'train_psnr': 25.1537, 'val_psnr': 24.0346, 'input_psnr': 23.1331, 'delta_psnr': 0.9016, 'best_val_psnr': 24.0346}
# {'epoch': 2939, 'epoch_time_sec': 39.81, 'lr': 1.727587565507178e-05, 'train_loss': 0.011587, 'train_psnr': 25.1607, 'val_psnr': 24.0346, 'input_psnr': 23.1331, 'delta_psnr': 0.9015, 'best_val_psnr': 24.0346}
# {'epoch': 2940, 'epoch_time_sec': 40.35, 'lr': 1.724700924298917e-05, 'train_loss': 0.011583, 'train_psnr': 25.1607, 'val_psnr': 24.0346, 'input_psnr': 23.1331, 'delta_psnr': 0.9016, 'best_val_psnr': 24.0346}
# {'epoch': 2941, 'epoch_time_sec': 39.63, 'lr': 1.7218163425317238e-05, 'train_loss': 0.011572, 'train_psnr': 25.1656, 'val_psnr': 24.0346, 'input_psnr': 23.1331, 'delta_psnr': 0.9015, 'best_val_psnr': 24.0346}
# {'epoch': 2942, 'epoch_time_sec': 39.67, 'lr': 1.7189338219920953e-05, 'train_loss': 0.011579, 'train_psnr': 25.1627, 'val_psnr': 24.0346, 'input_psnr': 23.1331, 'delta_psnr': 0.9015, 'best_val_psnr': 24.0346}
# {'epoch': 2943, 'epoch_time_sec': 39.6, 'lr': 1.7160533644652493e-05, 'train_loss': 0.011581, 'train_psnr': 25.1603, 'val_psnr': 24.0345, 'input_psnr': 23.1331, 'delta_psnr': 0.9015, 'best_val_psnr': 24.0346}
# {'epoch': 2944, 'epoch_time_sec': 39.71, 'lr': 1.7131749717351225e-05, 'train_loss': 0.011578, 'train_psnr': 25.1622, 'val_psnr': 24.0345, 'input_psnr': 23.1331, 'delta_psnr': 0.9014, 'best_val_psnr': 24.0346}
# {'epoch': 2945, 'epoch_time_sec': 39.64, 'lr': 1.7102986455843774e-05, 'train_loss': 0.011574, 'train_psnr': 25.1639, 'val_psnr': 24.0346, 'input_psnr': 23.1331, 'delta_psnr': 0.9015, 'best_val_psnr': 24.0346}
# {'epoch': 2946, 'epoch_time_sec': 39.79, 'lr': 1.707424387794396e-05, 'train_loss': 0.011585, 'train_psnr': 25.1602, 'val_psnr': 24.0346, 'input_psnr': 23.1331, 'delta_psnr': 0.9016, 'best_val_psnr': 24.0346}
# {'epoch': 2947, 'epoch_time_sec': 40.36, 'lr': 1.704552200145275e-05, 'train_loss': 0.011586, 'train_psnr': 25.1591, 'val_psnr': 24.0346, 'input_psnr': 23.1331, 'delta_psnr': 0.9015, 'best_val_psnr': 24.0346}
# {'epoch': 2948, 'epoch_time_sec': 39.58, 'lr': 1.701682084415835e-05, 'train_loss': 0.011573, 'train_psnr': 25.1633, 'val_psnr': 24.0346, 'input_psnr': 23.1331, 'delta_psnr': 0.9015, 'best_val_psnr': 24.0346}
# {'epoch': 2949, 'epoch_time_sec': 39.72, 'lr': 1.6988140423836107e-05, 'train_loss': 0.011575, 'train_psnr': 25.1637, 'val_psnr': 24.0346, 'input_psnr': 23.1331, 'delta_psnr': 0.9015, 'best_val_psnr': 24.0346}
# {'epoch': 2950, 'epoch_time_sec': 39.7, 'lr': 1.695948075824848e-05, 'train_loss': 0.011584, 'train_psnr': 25.1612, 'val_psnr': 24.0346, 'input_psnr': 23.1331, 'delta_psnr': 0.9015, 'best_val_psnr': 24.0346}
# {'epoch': 2951, 'epoch_time_sec': 39.63, 'lr': 1.6930841865145188e-05, 'train_loss': 0.011578, 'train_psnr': 25.1628, 'val_psnr': 24.0346, 'input_psnr': 23.1331, 'delta_psnr': 0.9015, 'best_val_psnr': 24.0346}
# {'epoch': 2952, 'epoch_time_sec': 39.53, 'lr': 1.6902223762262983e-05, 'train_loss': 0.011568, 'train_psnr': 25.1674, 'val_psnr': 24.0346, 'input_psnr': 23.1331, 'delta_psnr': 0.9016, 'best_val_psnr': 24.0346}
# {'epoch': 2953, 'epoch_time_sec': 40.09, 'lr': 1.687362646732573e-05, 'train_loss': 0.011581, 'train_psnr': 25.161, 'val_psnr': 24.0346, 'input_psnr': 23.1331, 'delta_psnr': 0.9015, 'best_val_psnr': 24.0346}
# {'epoch': 2954, 'epoch_time_sec': 39.86, 'lr': 1.6845049998044532e-05, 'train_loss': 0.01158, 'train_psnr': 25.1594, 'val_psnr': 24.0345, 'input_psnr': 23.1331, 'delta_psnr': 0.9015, 'best_val_psnr': 24.0346}
# {'epoch': 2955, 'epoch_time_sec': 39.58, 'lr': 1.681649437211747e-05, 'train_loss': 0.011574, 'train_psnr': 25.1644, 'val_psnr': 24.0346, 'input_psnr': 23.1331, 'delta_psnr': 0.9015, 'best_val_psnr': 24.0346}
# {'epoch': 2956, 'epoch_time_sec': 39.67, 'lr': 1.6787959607229728e-05, 'train_loss': 0.011586, 'train_psnr': 25.1589, 'val_psnr': 24.0347, 'input_psnr': 23.1331, 'delta_psnr': 0.9016, 'best_val_psnr': 24.0347}
# {'epoch': 2957, 'epoch_time_sec': 39.6, 'lr': 1.6759445721053663e-05, 'train_loss': 0.011597, 'train_psnr': 25.1539, 'val_psnr': 24.0346, 'input_psnr': 23.1331, 'delta_psnr': 0.9016, 'best_val_psnr': 24.0347}
# {'epoch': 2958, 'epoch_time_sec': 39.64, 'lr': 1.6730952731248597e-05, 'train_loss': 0.011592, 'train_psnr': 25.1542, 'val_psnr': 24.0346, 'input_psnr': 23.1331, 'delta_psnr': 0.9016, 'best_val_psnr': 24.0347}
# {'epoch': 2959, 'epoch_time_sec': 39.78, 'lr': 1.6702480655460963e-05, 'train_loss': 0.011573, 'train_psnr': 25.1651, 'val_psnr': 24.0347, 'input_psnr': 23.1331, 'delta_psnr': 0.9016, 'best_val_psnr': 24.0347}
# {'epoch': 2960, 'epoch_time_sec': 40.27, 'lr': 1.6674029511324255e-05, 'train_loss': 0.011569, 'train_psnr': 25.1659, 'val_psnr': 24.0348, 'input_psnr': 23.1331, 'delta_psnr': 0.9017, 'best_val_psnr': 24.0348}
# {'epoch': 2961, 'epoch_time_sec': 39.57, 'lr': 1.664559931645894e-05, 'train_loss': 0.011589, 'train_psnr': 25.1575, 'val_psnr': 24.0348, 'input_psnr': 23.1331, 'delta_psnr': 0.9017, 'best_val_psnr': 24.0348}
# {'epoch': 2962, 'epoch_time_sec': 39.58, 'lr': 1.6617190088472568e-05, 'train_loss': 0.011574, 'train_psnr': 25.1639, 'val_psnr': 24.0347, 'input_psnr': 23.1331, 'delta_psnr': 0.9016, 'best_val_psnr': 24.0348}
# {'epoch': 2963, 'epoch_time_sec': 39.65, 'lr': 1.6588801844959704e-05, 'train_loss': 0.011576, 'train_psnr': 25.162, 'val_psnr': 24.0346, 'input_psnr': 23.1331, 'delta_psnr': 0.9015, 'best_val_psnr': 24.0348}
# {'epoch': 2964, 'epoch_time_sec': 39.57, 'lr': 1.6560434603501872e-05, 'train_loss': 0.011577, 'train_psnr': 25.1616, 'val_psnr': 24.0347, 'input_psnr': 23.1331, 'delta_psnr': 0.9016, 'best_val_psnr': 24.0348}
# {'epoch': 2965, 'epoch_time_sec': 39.65, 'lr': 1.6532088381667623e-05, 'train_loss': 0.011587, 'train_psnr': 25.1573, 'val_psnr': 24.0347, 'input_psnr': 23.1331, 'delta_psnr': 0.9017, 'best_val_psnr': 24.0348}
# {'epoch': 2966, 'epoch_time_sec': 39.94, 'lr': 1.6503763197012482e-05, 'train_loss': 0.011582, 'train_psnr': 25.16, 'val_psnr': 24.0348, 'input_psnr': 23.1331, 'delta_psnr': 0.9017, 'best_val_psnr': 24.0348}
# {'epoch': 2967, 'epoch_time_sec': 40.26, 'lr': 1.6475459067078968e-05, 'train_loss': 0.011579, 'train_psnr': 25.1633, 'val_psnr': 24.0348, 'input_psnr': 23.1331, 'delta_psnr': 0.9017, 'best_val_psnr': 24.0348}
# {'epoch': 2968, 'epoch_time_sec': 39.55, 'lr': 1.6447176009396504e-05, 'train_loss': 0.011575, 'train_psnr': 25.1623, 'val_psnr': 24.0348, 'input_psnr': 23.1331, 'delta_psnr': 0.9017, 'best_val_psnr': 24.0348}
# {'epoch': 2969, 'epoch_time_sec': 39.73, 'lr': 1.641891404148151e-05, 'train_loss': 0.011579, 'train_psnr': 25.1632, 'val_psnr': 24.0348, 'input_psnr': 23.1331, 'delta_psnr': 0.9018, 'best_val_psnr': 24.0348}
# {'epoch': 2970, 'epoch_time_sec': 39.74, 'lr': 1.639067318083735e-05, 'train_loss': 0.011573, 'train_psnr': 25.1641, 'val_psnr': 24.0348, 'input_psnr': 23.1331, 'delta_psnr': 0.9017, 'best_val_psnr': 24.0348}
# {'epoch': 2971, 'epoch_time_sec': 39.6, 'lr': 1.6362453444954267e-05, 'train_loss': 0.011569, 'train_psnr': 25.1668, 'val_psnr': 24.0349, 'input_psnr': 23.1331, 'delta_psnr': 0.9018, 'best_val_psnr': 24.0349}
# {'epoch': 2972, 'epoch_time_sec': 39.69, 'lr': 1.6334254851309462e-05, 'train_loss': 0.011584, 'train_psnr': 25.1613, 'val_psnr': 24.0349, 'input_psnr': 23.1331, 'delta_psnr': 0.9018, 'best_val_psnr': 24.0349}
# {'epoch': 2973, 'epoch_time_sec': 40.13, 'lr': 1.6306077417367045e-05, 'train_loss': 0.01157, 'train_psnr': 25.1657, 'val_psnr': 24.035, 'input_psnr': 23.1331, 'delta_psnr': 0.9019, 'best_val_psnr': 24.035}
# {'epoch': 2974, 'epoch_time_sec': 39.84, 'lr': 1.627792116057797e-05, 'train_loss': 0.011577, 'train_psnr': 25.1621, 'val_psnr': 24.035, 'input_psnr': 23.1331, 'delta_psnr': 0.9019, 'best_val_psnr': 24.035}
# {'epoch': 2975, 'epoch_time_sec': 39.69, 'lr': 1.6249786098380163e-05, 'train_loss': 0.011577, 'train_psnr': 25.1652, 'val_psnr': 24.0351, 'input_psnr': 23.1331, 'delta_psnr': 0.902, 'best_val_psnr': 24.0351}
# {'epoch': 2976, 'epoch_time_sec': 39.53, 'lr': 1.6221672248198354e-05, 'train_loss': 0.011587, 'train_psnr': 25.1598, 'val_psnr': 24.0351, 'input_psnr': 23.1331, 'delta_psnr': 0.902, 'best_val_psnr': 24.0351}
# {'epoch': 2977, 'epoch_time_sec': 39.68, 'lr': 1.6193579627444114e-05, 'train_loss': 0.011578, 'train_psnr': 25.1642, 'val_psnr': 24.035, 'input_psnr': 23.1331, 'delta_psnr': 0.9019, 'best_val_psnr': 24.0351}
# {'epoch': 2978, 'epoch_time_sec': 39.62, 'lr': 1.6165508253515977e-05, 'train_loss': 0.011578, 'train_psnr': 25.1622, 'val_psnr': 24.0351, 'input_psnr': 23.1331, 'delta_psnr': 0.902, 'best_val_psnr': 24.0351}
# {'epoch': 2979, 'epoch_time_sec': 39.8, 'lr': 1.613745814379921e-05, 'train_loss': 0.011581, 'train_psnr': 25.1625, 'val_psnr': 24.035, 'input_psnr': 23.1331, 'delta_psnr': 0.902, 'best_val_psnr': 24.0351}
# {'epoch': 2980, 'epoch_time_sec': 40.29, 'lr': 1.6109429315665918e-05, 'train_loss': 0.011579, 'train_psnr': 25.1623, 'val_psnr': 24.0351, 'input_psnr': 23.1331, 'delta_psnr': 0.9021, 'best_val_psnr': 24.0351}
# {'epoch': 2981, 'epoch_time_sec': 39.62, 'lr': 1.608142178647513e-05, 'train_loss': 0.011572, 'train_psnr': 25.1649, 'val_psnr': 24.0351, 'input_psnr': 23.1331, 'delta_psnr': 0.9021, 'best_val_psnr': 24.0351}
# {'epoch': 2982, 'epoch_time_sec': 39.73, 'lr': 1.6053435573572555e-05, 'train_loss': 0.01158, 'train_psnr': 25.1608, 'val_psnr': 24.0351, 'input_psnr': 23.1331, 'delta_psnr': 0.902, 'best_val_psnr': 24.0351}
# {'epoch': 2983, 'epoch_time_sec': 39.68, 'lr': 1.6025470694290774e-05, 'train_loss': 0.011571, 'train_psnr': 25.1653, 'val_psnr': 24.0351, 'input_psnr': 23.1331, 'delta_psnr': 0.902, 'best_val_psnr': 24.0351}
# {'epoch': 2984, 'epoch_time_sec': 39.67, 'lr': 1.5997527165949148e-05, 'train_loss': 0.01158, 'train_psnr': 25.1601, 'val_psnr': 24.0351, 'input_psnr': 23.1331, 'delta_psnr': 0.9021, 'best_val_psnr': 24.0351}
# {'epoch': 2985, 'epoch_time_sec': 39.62, 'lr': 1.596960500585378e-05, 'train_loss': 0.011579, 'train_psnr': 25.1615, 'val_psnr': 24.035, 'input_psnr': 23.1331, 'delta_psnr': 0.902, 'best_val_psnr': 24.0351}
# {'epoch': 2986, 'epoch_time_sec': 39.76, 'lr': 1.5941704231297584e-05, 'train_loss': 0.011573, 'train_psnr': 25.1662, 'val_psnr': 24.0351, 'input_psnr': 23.1331, 'delta_psnr': 0.9021, 'best_val_psnr': 24.0351}
# {'epoch': 2987, 'epoch_time_sec': 40.35, 'lr': 1.5913824859560215e-05, 'train_loss': 0.011576, 'train_psnr': 25.1634, 'val_psnr': 24.0351, 'input_psnr': 23.1331, 'delta_psnr': 0.9021, 'best_val_psnr': 24.0351}
# {'epoch': 2988, 'epoch_time_sec': 39.57, 'lr': 1.5885966907908033e-05, 'train_loss': 0.011568, 'train_psnr': 25.1672, 'val_psnr': 24.0351, 'input_psnr': 23.1331, 'delta_psnr': 0.9021, 'best_val_psnr': 24.0351}
# {'epoch': 2989, 'epoch_time_sec': 39.67, 'lr': 1.5858130393594196e-05, 'train_loss': 0.011579, 'train_psnr': 25.1612, 'val_psnr': 24.0352, 'input_psnr': 23.1331, 'delta_psnr': 0.9021, 'best_val_psnr': 24.0352}
# {'epoch': 2990, 'epoch_time_sec': 39.64, 'lr': 1.5830315333858542e-05, 'train_loss': 0.011574, 'train_psnr': 25.1644, 'val_psnr': 24.0352, 'input_psnr': 23.1331, 'delta_psnr': 0.9021, 'best_val_psnr': 24.0352}
# {'epoch': 2991, 'epoch_time_sec': 39.61, 'lr': 1.5802521745927656e-05, 'train_loss': 0.011588, 'train_psnr': 25.1589, 'val_psnr': 24.0351, 'input_psnr': 23.1331, 'delta_psnr': 0.9021, 'best_val_psnr': 24.0352}
# {'epoch': 2992, 'epoch_time_sec': 39.64, 'lr': 1.5774749647014767e-05, 'train_loss': 0.011572, 'train_psnr': 25.1671, 'val_psnr': 24.0351, 'input_psnr': 23.1331, 'delta_psnr': 0.9021, 'best_val_psnr': 24.0352}
# {'epoch': 2993, 'epoch_time_sec': 40.03, 'lr': 1.5746999054319854e-05, 'train_loss': 0.011579, 'train_psnr': 25.1642, 'val_psnr': 24.0352, 'input_psnr': 23.1331, 'delta_psnr': 0.9022, 'best_val_psnr': 24.0352}
# {'epoch': 2994, 'epoch_time_sec': 40.22, 'lr': 1.571926998502957e-05, 'train_loss': 0.011577, 'train_psnr': 25.163, 'val_psnr': 24.0352, 'input_psnr': 23.1331, 'delta_psnr': 0.9022, 'best_val_psnr': 24.0352}
# {'epoch': 2995, 'epoch_time_sec': 39.69, 'lr': 1.5691562456317184e-05, 'train_loss': 0.011572, 'train_psnr': 25.1648, 'val_psnr': 24.0352, 'input_psnr': 23.1331, 'delta_psnr': 0.9022, 'best_val_psnr': 24.0352}
# {'epoch': 2996, 'epoch_time_sec': 39.49, 'lr': 1.5663876485342688e-05, 'train_loss': 0.011592, 'train_psnr': 25.1566, 'val_psnr': 24.0351, 'input_psnr': 23.1331, 'delta_psnr': 0.9021, 'best_val_psnr': 24.0352}
# {'epoch': 2997, 'epoch_time_sec': 39.6, 'lr': 1.5636212089252706e-05, 'train_loss': 0.011568, 'train_psnr': 25.168, 'val_psnr': 24.0352, 'input_psnr': 23.1331, 'delta_psnr': 0.9022, 'best_val_psnr': 24.0352}
# {'epoch': 2998, 'epoch_time_sec': 39.64, 'lr': 1.5608569285180452e-05, 'train_loss': 0.011577, 'train_psnr': 25.1642, 'val_psnr': 24.0353, 'input_psnr': 23.1331, 'delta_psnr': 0.9022, 'best_val_psnr': 24.0353}
# {'epoch': 2999, 'epoch_time_sec': 39.7, 'lr': 1.5580948090245865e-05, 'train_loss': 0.011571, 'train_psnr': 25.1657, 'val_psnr': 24.0352, 'input_psnr': 23.1331, 'delta_psnr': 0.9021, 'best_val_psnr': 24.0353}
# {'epoch': 3000, 'epoch_time_sec': 40.31, 'lr': 1.5553348521555418e-05, 'train_loss': 0.011571, 'train_psnr': 25.1664, 'val_psnr': 24.0352, 'input_psnr': 23.1331, 'delta_psnr': 0.9021, 'best_val_psnr': 24.0353}
# {'epoch': 3001, 'epoch_time_sec': 39.82, 'lr': 1.5525770596202173e-05, 'train_loss': 0.011596, 'train_psnr': 25.155, 'val_psnr': 24.0351, 'input_psnr': 23.1331, 'delta_psnr': 0.9021, 'best_val_psnr': 24.0353}
# {'epoch': 3002, 'epoch_time_sec': 39.67, 'lr': 1.54982143312659e-05, 'train_loss': 0.011569, 'train_psnr': 25.1678, 'val_psnr': 24.0352, 'input_psnr': 23.1331, 'delta_psnr': 0.9021, 'best_val_psnr': 24.0353}
# {'epoch': 3003, 'epoch_time_sec': 39.56, 'lr': 1.547067974381286e-05, 'train_loss': 0.011569, 'train_psnr': 25.1656, 'val_psnr': 24.0351, 'input_psnr': 23.1331, 'delta_psnr': 0.9021, 'best_val_psnr': 24.0353}
# {'epoch': 3004, 'epoch_time_sec': 39.69, 'lr': 1.5443166850895867e-05, 'train_loss': 0.011576, 'train_psnr': 25.1648, 'val_psnr': 24.0352, 'input_psnr': 23.1331, 'delta_psnr': 0.9021, 'best_val_psnr': 24.0353}
# {'epoch': 3005, 'epoch_time_sec': 39.62, 'lr': 1.5415675669554426e-05, 'train_loss': 0.011578, 'train_psnr': 25.1637, 'val_psnr': 24.0352, 'input_psnr': 23.1331, 'delta_psnr': 0.9021, 'best_val_psnr': 24.0353}
# {'epoch': 3006, 'epoch_time_sec': 39.86, 'lr': 1.538820621681446e-05, 'train_loss': 0.011581, 'train_psnr': 25.162, 'val_psnr': 24.0353, 'input_psnr': 23.1331, 'delta_psnr': 0.9022, 'best_val_psnr': 24.0353}
# {'epoch': 3007, 'epoch_time_sec': 40.46, 'lr': 1.536075850968848e-05, 'train_loss': 0.011574, 'train_psnr': 25.1642, 'val_psnr': 24.0352, 'input_psnr': 23.1331, 'delta_psnr': 0.9021, 'best_val_psnr': 24.0353}
# {'epoch': 3008, 'epoch_time_sec': 39.59, 'lr': 1.5333332565175594e-05, 'train_loss': 0.011569, 'train_psnr': 25.1664, 'val_psnr': 24.0352, 'input_psnr': 23.1331, 'delta_psnr': 0.9021, 'best_val_psnr': 24.0353}
# {'epoch': 3009, 'epoch_time_sec': 39.75, 'lr': 1.5305928400261328e-05, 'train_loss': 0.011575, 'train_psnr': 25.1655, 'val_psnr': 24.0352, 'input_psnr': 23.1331, 'delta_psnr': 0.9021, 'best_val_psnr': 24.0353}
# {'epoch': 3010, 'epoch_time_sec': 39.58, 'lr': 1.5278546031917782e-05, 'train_loss': 0.011583, 'train_psnr': 25.1637, 'val_psnr': 24.0352, 'input_psnr': 23.1331, 'delta_psnr': 0.9022, 'best_val_psnr': 24.0353}
# {'epoch': 3011, 'epoch_time_sec': 39.65, 'lr': 1.5251185477103569e-05, 'train_loss': 0.011571, 'train_psnr': 25.1662, 'val_psnr': 24.0352, 'input_psnr': 23.1331, 'delta_psnr': 0.9021, 'best_val_psnr': 24.0353}
# {'epoch': 3012, 'epoch_time_sec': 39.64, 'lr': 1.5223846752763727e-05, 'train_loss': 0.011568, 'train_psnr': 25.1661, 'val_psnr': 24.0353, 'input_psnr': 23.1331, 'delta_psnr': 0.9023, 'best_val_psnr': 24.0353}
# {'epoch': 3013, 'epoch_time_sec': 39.84, 'lr': 1.5196529875829825e-05, 'train_loss': 0.011572, 'train_psnr': 25.1652, 'val_psnr': 24.0353, 'input_psnr': 23.1331, 'delta_psnr': 0.9022, 'best_val_psnr': 24.0353}
# {'epoch': 3014, 'epoch_time_sec': 40.48, 'lr': 1.5169234863219915e-05, 'train_loss': 0.011571, 'train_psnr': 25.1657, 'val_psnr': 24.0352, 'input_psnr': 23.1331, 'delta_psnr': 0.9022, 'best_val_psnr': 24.0353}
# {'epoch': 3015, 'epoch_time_sec': 39.61, 'lr': 1.5141961731838442e-05, 'train_loss': 0.011585, 'train_psnr': 25.1614, 'val_psnr': 24.0353, 'input_psnr': 23.1331, 'delta_psnr': 0.9023, 'best_val_psnr': 24.0353}
# {'epoch': 3016, 'epoch_time_sec': 39.62, 'lr': 1.5114710498576364e-05, 'train_loss': 0.011576, 'train_psnr': 25.1637, 'val_psnr': 24.0354, 'input_psnr': 23.1331, 'delta_psnr': 0.9023, 'best_val_psnr': 24.0354}
# {'epoch': 3017, 'epoch_time_sec': 39.62, 'lr': 1.5087481180311048e-05, 'train_loss': 0.011575, 'train_psnr': 25.1644, 'val_psnr': 24.0354, 'input_psnr': 23.1331, 'delta_psnr': 0.9024, 'best_val_psnr': 24.0354}
# {'epoch': 3018, 'epoch_time_sec': 39.56, 'lr': 1.5060273793906307e-05, 'train_loss': 0.011565, 'train_psnr': 25.1691, 'val_psnr': 24.0355, 'input_psnr': 23.1331, 'delta_psnr': 0.9024, 'best_val_psnr': 24.0355}
# {'epoch': 3019, 'epoch_time_sec': 39.59, 'lr': 1.5033088356212332e-05, 'train_loss': 0.011566, 'train_psnr': 25.1701, 'val_psnr': 24.0355, 'input_psnr': 23.1331, 'delta_psnr': 0.9024, 'best_val_psnr': 24.0355}
# {'epoch': 3020, 'epoch_time_sec': 39.95, 'lr': 1.5005924884065757e-05, 'train_loss': 0.01157, 'train_psnr': 25.1652, 'val_psnr': 24.0355, 'input_psnr': 23.1331, 'delta_psnr': 0.9024, 'best_val_psnr': 24.0355}
# {'epoch': 3021, 'epoch_time_sec': 40.18, 'lr': 1.4978783394289617e-05, 'train_loss': 0.011572, 'train_psnr': 25.1668, 'val_psnr': 24.0355, 'input_psnr': 23.1331, 'delta_psnr': 0.9024, 'best_val_psnr': 24.0355}
# {'epoch': 3022, 'epoch_time_sec': 39.57, 'lr': 1.495166390369329e-05, 'train_loss': 0.011584, 'train_psnr': 25.1591, 'val_psnr': 24.0354, 'input_psnr': 23.1331, 'delta_psnr': 0.9024, 'best_val_psnr': 24.0355}
# {'epoch': 3023, 'epoch_time_sec': 39.79, 'lr': 1.4924566429072566e-05, 'train_loss': 0.011584, 'train_psnr': 25.1603, 'val_psnr': 24.0354, 'input_psnr': 23.1331, 'delta_psnr': 0.9023, 'best_val_psnr': 24.0355}
# {'epoch': 3024, 'epoch_time_sec': 39.64, 'lr': 1.4897490987209614e-05, 'train_loss': 0.011581, 'train_psnr': 25.1613, 'val_psnr': 24.0353, 'input_psnr': 23.1331, 'delta_psnr': 0.9022, 'best_val_psnr': 24.0355}
# {'epoch': 3025, 'epoch_time_sec': 39.6, 'lr': 1.4870437594872877e-05, 'train_loss': 0.011571, 'train_psnr': 25.1661, 'val_psnr': 24.0354, 'input_psnr': 23.1331, 'delta_psnr': 0.9024, 'best_val_psnr': 24.0355}
# {'epoch': 3026, 'epoch_time_sec': 39.69, 'lr': 1.484340626881727e-05, 'train_loss': 0.011574, 'train_psnr': 25.1637, 'val_psnr': 24.0354, 'input_psnr': 23.1331, 'delta_psnr': 0.9024, 'best_val_psnr': 24.0355}
# {'epoch': 3027, 'epoch_time_sec': 40.29, 'lr': 1.4816397025783933e-05, 'train_loss': 0.01157, 'train_psnr': 25.1667, 'val_psnr': 24.0355, 'input_psnr': 23.1331, 'delta_psnr': 0.9024, 'best_val_psnr': 24.0355}
# {'epoch': 3028, 'epoch_time_sec': 39.71, 'lr': 1.4789409882500338e-05, 'train_loss': 0.011573, 'train_psnr': 25.1656, 'val_psnr': 24.0355, 'input_psnr': 23.1331, 'delta_psnr': 0.9024, 'best_val_psnr': 24.0355}
# {'epoch': 3029, 'epoch_time_sec': 39.63, 'lr': 1.4762444855680366e-05, 'train_loss': 0.011579, 'train_psnr': 25.1626, 'val_psnr': 24.0355, 'input_psnr': 23.1331, 'delta_psnr': 0.9024, 'best_val_psnr': 24.0355}
# {'epoch': 3030, 'epoch_time_sec': 39.69, 'lr': 1.4735501962024098e-05, 'train_loss': 0.011572, 'train_psnr': 25.1661, 'val_psnr': 24.0354, 'input_psnr': 23.1331, 'delta_psnr': 0.9023, 'best_val_psnr': 24.0355}
# {'epoch': 3031, 'epoch_time_sec': 39.67, 'lr': 1.4708581218217911e-05, 'train_loss': 0.011576, 'train_psnr': 25.1637, 'val_psnr': 24.0354, 'input_psnr': 23.1331, 'delta_psnr': 0.9023, 'best_val_psnr': 24.0355}
# {'epoch': 3032, 'epoch_time_sec': 39.7, 'lr': 1.4681682640934565e-05, 'train_loss': 0.011586, 'train_psnr': 25.1615, 'val_psnr': 24.0355, 'input_psnr': 23.1331, 'delta_psnr': 0.9024, 'best_val_psnr': 24.0355}
# {'epoch': 3033, 'epoch_time_sec': 39.82, 'lr': 1.4654806246832972e-05, 'train_loss': 0.01158, 'train_psnr': 25.1641, 'val_psnr': 24.0354, 'input_psnr': 23.1331, 'delta_psnr': 0.9024, 'best_val_psnr': 24.0355}
# {'epoch': 3034, 'epoch_time_sec': 40.3, 'lr': 1.4627952052558372e-05, 'train_loss': 0.011585, 'train_psnr': 25.1623, 'val_psnr': 24.0355, 'input_psnr': 23.1331, 'delta_psnr': 0.9025, 'best_val_psnr': 24.0355}
# {'epoch': 3035, 'epoch_time_sec': 39.56, 'lr': 1.460112007474226e-05, 'train_loss': 0.0116, 'train_psnr': 25.156, 'val_psnr': 24.0355, 'input_psnr': 23.1331, 'delta_psnr': 0.9025, 'best_val_psnr': 24.0355}
# {'epoch': 3036, 'epoch_time_sec': 39.52, 'lr': 1.4574310330002314e-05, 'train_loss': 0.011585, 'train_psnr': 25.1598, 'val_psnr': 24.0355, 'input_psnr': 23.1331, 'delta_psnr': 0.9025, 'best_val_psnr': 24.0355}
# {'epoch': 3037, 'epoch_time_sec': 39.67, 'lr': 1.4547522834942507e-05, 'train_loss': 0.011572, 'train_psnr': 25.1645, 'val_psnr': 24.0355, 'input_psnr': 23.1331, 'delta_psnr': 0.9025, 'best_val_psnr': 24.0355}
# {'epoch': 3038, 'epoch_time_sec': 39.6, 'lr': 1.4520757606153012e-05, 'train_loss': 0.011579, 'train_psnr': 25.1629, 'val_psnr': 24.0356, 'input_psnr': 23.1331, 'delta_psnr': 0.9025, 'best_val_psnr': 24.0356}
# {'epoch': 3039, 'epoch_time_sec': 39.64, 'lr': 1.449401466021018e-05, 'train_loss': 0.011583, 'train_psnr': 25.161, 'val_psnr': 24.0356, 'input_psnr': 23.1331, 'delta_psnr': 0.9025, 'best_val_psnr': 24.0356}
# {'epoch': 3040, 'epoch_time_sec': 39.91, 'lr': 1.4467294013676604e-05, 'train_loss': 0.011569, 'train_psnr': 25.1675, 'val_psnr': 24.0355, 'input_psnr': 23.1331, 'delta_psnr': 0.9025, 'best_val_psnr': 24.0356}
# {'epoch': 3041, 'epoch_time_sec': 40.28, 'lr': 1.4440595683101045e-05, 'train_loss': 0.011578, 'train_psnr': 25.1631, 'val_psnr': 24.0355, 'input_psnr': 23.1331, 'delta_psnr': 0.9025, 'best_val_psnr': 24.0356}
# {'epoch': 3042, 'epoch_time_sec': 39.54, 'lr': 1.4413919685018463e-05, 'train_loss': 0.011574, 'train_psnr': 25.1633, 'val_psnr': 24.0355, 'input_psnr': 23.1331, 'delta_psnr': 0.9024, 'best_val_psnr': 24.0356}
# {'epoch': 3043, 'epoch_time_sec': 39.58, 'lr': 1.4387266035949954e-05, 'train_loss': 0.011563, 'train_psnr': 25.1711, 'val_psnr': 24.0355, 'input_psnr': 23.1331, 'delta_psnr': 0.9025, 'best_val_psnr': 24.0356}
# {'epoch': 3044, 'epoch_time_sec': 39.58, 'lr': 1.4360634752402791e-05, 'train_loss': 0.011563, 'train_psnr': 25.1712, 'val_psnr': 24.0356, 'input_psnr': 23.1331, 'delta_psnr': 0.9025, 'best_val_psnr': 24.0356}
# {'epoch': 3045, 'epoch_time_sec': 39.49, 'lr': 1.4334025850870419e-05, 'train_loss': 0.011582, 'train_psnr': 25.1605, 'val_psnr': 24.0356, 'input_psnr': 23.1331, 'delta_psnr': 0.9025, 'best_val_psnr': 24.0356}
# {'epoch': 3046, 'epoch_time_sec': 39.63, 'lr': 1.4307439347832368e-05, 'train_loss': 0.011562, 'train_psnr': 25.1702, 'val_psnr': 24.0356, 'input_psnr': 23.1331, 'delta_psnr': 0.9026, 'best_val_psnr': 24.0356}
# {'epoch': 3047, 'epoch_time_sec': 40.42, 'lr': 1.428087525975434e-05, 'train_loss': 0.011567, 'train_psnr': 25.1664, 'val_psnr': 24.0356, 'input_psnr': 23.1331, 'delta_psnr': 0.9025, 'best_val_psnr': 24.0356}
# {'epoch': 3048, 'epoch_time_sec': 39.62, 'lr': 1.425433360308815e-05, 'train_loss': 0.011566, 'train_psnr': 25.1693, 'val_psnr': 24.0357, 'input_psnr': 23.1331, 'delta_psnr': 0.9026, 'best_val_psnr': 24.0357}
# {'epoch': 3049, 'epoch_time_sec': 39.63, 'lr': 1.4227814394271676e-05, 'train_loss': 0.011573, 'train_psnr': 25.1649, 'val_psnr': 24.0357, 'input_psnr': 23.1331, 'delta_psnr': 0.9026, 'best_val_psnr': 24.0357}
# {'epoch': 3050, 'epoch_time_sec': 39.58, 'lr': 1.4201317649728981e-05, 'train_loss': 0.011578, 'train_psnr': 25.1608, 'val_psnr': 24.0358, 'input_psnr': 23.1331, 'delta_psnr': 0.9027, 'best_val_psnr': 24.0358}
# {'epoch': 3051, 'epoch_time_sec': 39.48, 'lr': 1.4174843385870133e-05, 'train_loss': 0.011559, 'train_psnr': 25.1736, 'val_psnr': 24.0357, 'input_psnr': 23.1331, 'delta_psnr': 0.9026, 'best_val_psnr': 24.0358}
# {'epoch': 3052, 'epoch_time_sec': 39.63, 'lr': 1.4148391619091279e-05, 'train_loss': 0.011581, 'train_psnr': 25.1639, 'val_psnr': 24.0357, 'input_psnr': 23.1331, 'delta_psnr': 0.9026, 'best_val_psnr': 24.0358}
# {'epoch': 3053, 'epoch_time_sec': 39.82, 'lr': 1.4121962365774725e-05, 'train_loss': 0.011577, 'train_psnr': 25.1623, 'val_psnr': 24.0357, 'input_psnr': 23.1331, 'delta_psnr': 0.9026, 'best_val_psnr': 24.0358}
# {'epoch': 3054, 'epoch_time_sec': 40.36, 'lr': 1.4095555642288736e-05, 'train_loss': 0.011563, 'train_psnr': 25.1716, 'val_psnr': 24.0357, 'input_psnr': 23.1331, 'delta_psnr': 0.9026, 'best_val_psnr': 24.0358}
# {'epoch': 3055, 'epoch_time_sec': 39.62, 'lr': 1.4069171464987628e-05, 'train_loss': 0.011573, 'train_psnr': 25.1659, 'val_psnr': 24.0357, 'input_psnr': 23.1331, 'delta_psnr': 0.9026, 'best_val_psnr': 24.0358}
# {'epoch': 3056, 'epoch_time_sec': 39.65, 'lr': 1.4042809850211848e-05, 'train_loss': 0.011577, 'train_psnr': 25.1639, 'val_psnr': 24.0356, 'input_psnr': 23.1331, 'delta_psnr': 0.9026, 'best_val_psnr': 24.0358}
# {'epoch': 3057, 'epoch_time_sec': 39.58, 'lr': 1.4016470814287753e-05, 'train_loss': 0.011561, 'train_psnr': 25.1722, 'val_psnr': 24.0357, 'input_psnr': 23.1331, 'delta_psnr': 0.9027, 'best_val_psnr': 24.0358}
# {'epoch': 3058, 'epoch_time_sec': 39.59, 'lr': 1.3990154373527784e-05, 'train_loss': 0.011569, 'train_psnr': 25.1678, 'val_psnr': 24.0357, 'input_psnr': 23.1331, 'delta_psnr': 0.9026, 'best_val_psnr': 24.0358}
# {'epoch': 3059, 'epoch_time_sec': 39.6, 'lr': 1.3963860544230392e-05, 'train_loss': 0.011569, 'train_psnr': 25.1679, 'val_psnr': 24.0357, 'input_psnr': 23.1331, 'delta_psnr': 0.9026, 'best_val_psnr': 24.0358}
# {'epoch': 3060, 'epoch_time_sec': 40.28, 'lr': 1.3937589342679972e-05, 'train_loss': 0.011576, 'train_psnr': 25.1637, 'val_psnr': 24.0357, 'input_psnr': 23.1331, 'delta_psnr': 0.9027, 'best_val_psnr': 24.0358}
# {'epoch': 3061, 'epoch_time_sec': 39.79, 'lr': 1.3911340785146953e-05, 'train_loss': 0.01157, 'train_psnr': 25.1669, 'val_psnr': 24.0357, 'input_psnr': 23.1331, 'delta_psnr': 0.9026, 'best_val_psnr': 24.0358}
# {'epoch': 3062, 'epoch_time_sec': 39.58, 'lr': 1.3885114887887737e-05, 'train_loss': 0.011566, 'train_psnr': 25.1685, 'val_psnr': 24.0357, 'input_psnr': 23.1331, 'delta_psnr': 0.9027, 'best_val_psnr': 24.0358}
# {'epoch': 3063, 'epoch_time_sec': 39.57, 'lr': 1.385891166714465e-05, 'train_loss': 0.011567, 'train_psnr': 25.1687, 'val_psnr': 24.0357, 'input_psnr': 23.1331, 'delta_psnr': 0.9026, 'best_val_psnr': 24.0358}
# {'epoch': 3064, 'epoch_time_sec': 39.57, 'lr': 1.3832731139146024e-05, 'train_loss': 0.011571, 'train_psnr': 25.1703, 'val_psnr': 24.0358, 'input_psnr': 23.1331, 'delta_psnr': 0.9027, 'best_val_psnr': 24.0358}
# {'epoch': 3065, 'epoch_time_sec': 39.49, 'lr': 1.380657332010613e-05, 'train_loss': 0.01158, 'train_psnr': 25.1641, 'val_psnr': 24.0358, 'input_psnr': 23.1331, 'delta_psnr': 0.9028, 'best_val_psnr': 24.0358}
# {'epoch': 3066, 'epoch_time_sec': 39.75, 'lr': 1.3780438226225122e-05, 'train_loss': 0.011565, 'train_psnr': 25.1701, 'val_psnr': 24.0358, 'input_psnr': 23.1331, 'delta_psnr': 0.9028, 'best_val_psnr': 24.0358}
# ...
# {'epoch': 3925, 'epoch_time_sec': 40.33, 'lr': 1.0861966380214271e-06, 'train_loss': 0.011547, 'train_psnr': 25.181, 'val_psnr': 24.0387, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3926, 'epoch_time_sec': 39.43, 'lr': 1.0839140301837473e-06, 'train_loss': 0.011548, 'train_psnr': 25.1796, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3927, 'epoch_time_sec': 39.39, 'lr': 1.0816620269667823e-06, 'train_loss': 0.011556, 'train_psnr': 25.1759, 'val_psnr': 24.0387, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3928, 'epoch_time_sec': 39.37, 'lr': 1.0794406297652503e-06, 'train_loss': 0.011555, 'train_psnr': 25.1771, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3929, 'epoch_time_sec': 39.5, 'lr': 1.0772498399549262e-06, 'train_loss': 0.01155, 'train_psnr': 25.1777, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3930, 'epoch_time_sec': 40.3, 'lr': 1.0750896588926144e-06, 'train_loss': 0.011555, 'train_psnr': 25.1766, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3931, 'epoch_time_sec': 39.39, 'lr': 1.0729600879161757e-06, 'train_loss': 0.011557, 'train_psnr': 25.1763, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3932, 'epoch_time_sec': 39.5, 'lr': 1.0708611283445e-06, 'train_loss': 0.011549, 'train_psnr': 25.1784, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3933, 'epoch_time_sec': 39.39, 'lr': 1.0687927814775229e-06, 'train_loss': 0.011551, 'train_psnr': 25.1781, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3934, 'epoch_time_sec': 39.78, 'lr': 1.0667550485962367e-06, 'train_loss': 0.011553, 'train_psnr': 25.1774, 'val_psnr': 24.0387, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3935, 'epoch_time_sec': 40.28, 'lr': 1.0647479309626465e-06, 'train_loss': 0.011564, 'train_psnr': 25.1717, 'val_psnr': 24.0387, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3936, 'epoch_time_sec': 39.48, 'lr': 1.0627714298198195e-06, 'train_loss': 0.011546, 'train_psnr': 25.181, 'val_psnr': 24.0387, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3937, 'epoch_time_sec': 39.48, 'lr': 1.0608255463918465e-06, 'train_loss': 0.011547, 'train_psnr': 25.1798, 'val_psnr': 24.0387, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3938, 'epoch_time_sec': 39.43, 'lr': 1.0589102818838694e-06, 'train_loss': 0.011552, 'train_psnr': 25.1773, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3939, 'epoch_time_sec': 39.73, 'lr': 1.057025637482054e-06, 'train_loss': 0.011557, 'train_psnr': 25.1752, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3940, 'epoch_time_sec': 40.36, 'lr': 1.055171614353606e-06, 'train_loss': 0.01155, 'train_psnr': 25.1791, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3941, 'epoch_time_sec': 39.46, 'lr': 1.0533482136467715e-06, 'train_loss': 0.011551, 'train_psnr': 25.1788, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3942, 'epoch_time_sec': 39.43, 'lr': 1.0515554364908255e-06, 'train_loss': 0.011552, 'train_psnr': 25.1776, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3943, 'epoch_time_sec': 39.5, 'lr': 1.0497932839960834e-06, 'train_loss': 0.011552, 'train_psnr': 25.1784, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3944, 'epoch_time_sec': 39.68, 'lr': 1.04806175725389e-06, 'train_loss': 0.011544, 'train_psnr': 25.1813, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3945, 'epoch_time_sec': 40.31, 'lr': 1.046360857336624e-06, 'train_loss': 0.011546, 'train_psnr': 25.1805, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3946, 'epoch_time_sec': 39.42, 'lr': 1.0446905852976944e-06, 'train_loss': 0.011554, 'train_psnr': 25.1769, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3947, 'epoch_time_sec': 39.51, 'lr': 1.043050942171538e-06, 'train_loss': 0.011557, 'train_psnr': 25.1772, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3948, 'epoch_time_sec': 39.47, 'lr': 1.041441928973633e-06, 'train_loss': 0.011562, 'train_psnr': 25.1741, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3949, 'epoch_time_sec': 39.73, 'lr': 1.0398635467004807e-06, 'train_loss': 0.011551, 'train_psnr': 25.1785, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3950, 'epoch_time_sec': 40.29, 'lr': 1.038315796329606e-06, 'train_loss': 0.011549, 'train_psnr': 25.1803, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3951, 'epoch_time_sec': 39.59, 'lr': 1.0367986788195796e-06, 'train_loss': 0.011542, 'train_psnr': 25.1832, 'val_psnr': 24.0385, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3952, 'epoch_time_sec': 39.38, 'lr': 1.0353121951099853e-06, 'train_loss': 0.011547, 'train_psnr': 25.1799, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3953, 'epoch_time_sec': 39.47, 'lr': 1.0338563461214408e-06, 'train_loss': 0.011573, 'train_psnr': 25.1697, 'val_psnr': 24.0385, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3954, 'epoch_time_sec': 39.67, 'lr': 1.0324311327555878e-06, 'train_loss': 0.011563, 'train_psnr': 25.1742, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3955, 'epoch_time_sec': 40.29, 'lr': 1.0310365558950977e-06, 'train_loss': 0.011548, 'train_psnr': 25.1795, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3956, 'epoch_time_sec': 39.54, 'lr': 1.0296726164036646e-06, 'train_loss': 0.011565, 'train_psnr': 25.176, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3957, 'epoch_time_sec': 39.47, 'lr': 1.0283393151260181e-06, 'train_loss': 0.011546, 'train_psnr': 25.1797, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3958, 'epoch_time_sec': 39.47, 'lr': 1.0270366528879002e-06, 'train_loss': 0.011567, 'train_psnr': 25.1746, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3959, 'epoch_time_sec': 39.72, 'lr': 1.025764630496082e-06, 'train_loss': 0.011547, 'train_psnr': 25.1809, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3960, 'epoch_time_sec': 40.25, 'lr': 1.0245232487383526e-06, 'train_loss': 0.011565, 'train_psnr': 25.1719, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3961, 'epoch_time_sec': 39.37, 'lr': 1.0233125083835472e-06, 'train_loss': 0.011541, 'train_psnr': 25.1823, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3962, 'epoch_time_sec': 39.47, 'lr': 1.0221324101814914e-06, 'train_loss': 0.011542, 'train_psnr': 25.1841, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3963, 'epoch_time_sec': 39.39, 'lr': 1.0209829548630567e-06, 'train_loss': 0.011549, 'train_psnr': 25.1795, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3964, 'epoch_time_sec': 40.02, 'lr': 1.0198641431401272e-06, 'train_loss': 0.011558, 'train_psnr': 25.1758, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3965, 'epoch_time_sec': 39.88, 'lr': 1.0187759757056158e-06, 'train_loss': 0.011556, 'train_psnr': 25.1776, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3966, 'epoch_time_sec': 39.49, 'lr': 1.0177184532334488e-06, 'train_loss': 0.011543, 'train_psnr': 25.1823, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3967, 'epoch_time_sec': 39.58, 'lr': 1.0166915763785755e-06, 'train_loss': 0.011546, 'train_psnr': 25.1816, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3968, 'epoch_time_sec': 39.47, 'lr': 1.0156953457769639e-06, 'train_loss': 0.011571, 'train_psnr': 25.1719, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3969, 'epoch_time_sec': 40.19, 'lr': 1.0147297620456108e-06, 'train_loss': 0.011549, 'train_psnr': 25.1777, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3970, 'epoch_time_sec': 39.72, 'lr': 1.013794825782526e-06, 'train_loss': 0.011555, 'train_psnr': 25.1768, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3971, 'epoch_time_sec': 39.56, 'lr': 1.012890537566737e-06, 'train_loss': 0.011544, 'train_psnr': 25.1825, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3972, 'epoch_time_sec': 39.46, 'lr': 1.0120168979582848e-06, 'train_loss': 0.011548, 'train_psnr': 25.1796, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3973, 'epoch_time_sec': 39.4, 'lr': 1.0111739074982496e-06, 'train_loss': 0.011549, 'train_psnr': 25.1783, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3974, 'epoch_time_sec': 40.2, 'lr': 1.0103615667087087e-06, 'train_loss': 0.011556, 'train_psnr': 25.1751, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3975, 'epoch_time_sec': 39.45, 'lr': 1.0095798760927623e-06, 'train_loss': 0.011543, 'train_psnr': 25.1828, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3976, 'epoch_time_sec': 39.45, 'lr': 1.0088288361345404e-06, 'train_loss': 0.011542, 'train_psnr': 25.1829, 'val_psnr': 24.0387, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3977, 'epoch_time_sec': 39.47, 'lr': 1.0081084472991741e-06, 'train_loss': 0.011551, 'train_psnr': 25.1793, 'val_psnr': 24.0387, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3978, 'epoch_time_sec': 39.42, 'lr': 1.0074187100328191e-06, 'train_loss': 0.011551, 'train_psnr': 25.1787, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3979, 'epoch_time_sec': 40.29, 'lr': 1.0067596247626535e-06, 'train_loss': 0.011544, 'train_psnr': 25.1831, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3980, 'epoch_time_sec': 39.52, 'lr': 1.0061311918968528e-06, 'train_loss': 0.01155, 'train_psnr': 25.1771, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3981, 'epoch_time_sec': 39.49, 'lr': 1.0055334118246265e-06, 'train_loss': 0.011545, 'train_psnr': 25.1818, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3982, 'epoch_time_sec': 39.47, 'lr': 1.0049662849162025e-06, 'train_loss': 0.011547, 'train_psnr': 25.1816, 'val_psnr': 24.0387, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3983, 'epoch_time_sec': 39.58, 'lr': 1.0044298115228102e-06, 'train_loss': 0.011547, 'train_psnr': 25.1802, 'val_psnr': 24.0387, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3984, 'epoch_time_sec': 40.24, 'lr': 1.0039239919766973e-06, 'train_loss': 0.01155, 'train_psnr': 25.1785, 'val_psnr': 24.0387, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3985, 'epoch_time_sec': 39.35, 'lr': 1.0034488265911355e-06, 'train_loss': 0.011547, 'train_psnr': 25.1812, 'val_psnr': 24.0387, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3986, 'epoch_time_sec': 39.53, 'lr': 1.0030043156604033e-06, 'train_loss': 0.011546, 'train_psnr': 25.181, 'val_psnr': 24.0387, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3987, 'epoch_time_sec': 39.51, 'lr': 1.0025904594598027e-06, 'train_loss': 0.01155, 'train_psnr': 25.1795, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3988, 'epoch_time_sec': 39.57, 'lr': 1.0022072582456433e-06, 'train_loss': 0.011543, 'train_psnr': 25.182, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3989, 'epoch_time_sec': 40.17, 'lr': 1.001854712255253e-06, 'train_loss': 0.011558, 'train_psnr': 25.1751, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3990, 'epoch_time_sec': 39.5, 'lr': 1.0015328217069665e-06, 'train_loss': 0.011548, 'train_psnr': 25.1784, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3991, 'epoch_time_sec': 39.4, 'lr': 1.0012415868001369e-06, 'train_loss': 0.011553, 'train_psnr': 25.1758, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3992, 'epoch_time_sec': 39.47, 'lr': 1.0009810077151462e-06, 'train_loss': 0.011547, 'train_psnr': 25.1809, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3993, 'epoch_time_sec': 39.54, 'lr': 1.0007510846133675e-06, 'train_loss': 0.011561, 'train_psnr': 25.1749, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 3994, 'epoch_time_sec': 40.26, 'lr': 1.0005518176371973e-06, 'train_loss': 0.011553, 'train_psnr': 25.1771, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3995, 'epoch_time_sec': 39.53, 'lr': 1.0003832069100506e-06, 'train_loss': 0.011543, 'train_psnr': 25.1817, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3996, 'epoch_time_sec': 39.49, 'lr': 1.0002452525363489e-06, 'train_loss': 0.011559, 'train_psnr': 25.1742, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3997, 'epoch_time_sec': 39.45, 'lr': 1.0001379546015382e-06, 'train_loss': 0.011549, 'train_psnr': 25.1792, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3998, 'epoch_time_sec': 39.56, 'lr': 1.0000613131720605e-06, 'train_loss': 0.011565, 'train_psnr': 25.1731, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9055, 'best_val_psnr': 24.0387}
# {'epoch': 3999, 'epoch_time_sec': 40.31, 'lr': 1.0000153282953865e-06, 'train_loss': 0.011553, 'train_psnr': 25.1771, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}
# {'epoch': 4000, 'epoch_time_sec': 39.34, 'lr': 1e-06, 'train_loss': 0.011554, 'train_psnr': 25.1776, 'val_psnr': 24.0386, 'input_psnr': 23.1331, 'delta_psnr': 0.9056, 'best_val_psnr': 24.0387}

# %% [markdown]
# ## 6. Validation Summary

# %%
export_model = load_checkpoint_for_eval(best_ckpt_path, device)
validation_summary = evaluate_metrics(export_model, val_loader, device)
preview_info = write_val_preview(export_model, val_loader, preview_dir, device)
print({'validation_summary': validation_summary, 'best_checkpoint_path': str(best_ckpt_path), 'last_checkpoint_path': str(last_ckpt_path), 'preview': preview_info})
# Out:
# {'validation_summary': {'val_psnr': 24.03870879086581, 'input_psnr': 23.133060299266468, 'delta_psnr': 0.9056484915993437}, 'best_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/174208_2704_fsrcnn_residual_96_40_m8/checkpoints/best.pth', 'last_checkpoint_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/174208_2704_fsrcnn_residual_96_40_m8/checkpoints/last.pth', 'preview': {'sample_name': '0000', 'input': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/174208_2704_fsrcnn_residual_96_40_m8/exports/val_preview/val_preview_input.png', 'prediction': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/174208_2704_fsrcnn_residual_96_40_m8/exports/val_preview/val_preview_pred.png', 'target': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/174208_2704_fsrcnn_residual_96_40_m8/exports/val_preview/val_preview_target.png'}}

# %% [markdown]
# ## 7. Export And Submission Artifacts

# %%
def export_calibration_images(pairs: list[tuple[Path, Path, str]], out_dir: Path, count: int, eval_size: int) -> dict[str, Any]:
    out_dir.mkdir(parents=True, exist_ok=True)
    selected = pairs[:count]
    manifest_items: list[dict[str, Any]] = []
    for index, (lr_path, _, name) in enumerate(selected):
        image = Image.open(lr_path).convert('RGB')
        if image.size != (eval_size, eval_size):
            image = image.resize((eval_size, eval_size), BICUBIC_RESAMPLE)
        image_path = out_dir / f'{index:03d}_{Path(name).name}.png'
        image.save(image_path)
        manifest_items.append({
            'index': index,
            'name': name,
            'source_lr': str(lr_path),
            'image_path': str(image_path),
            'derived_from_training': True,
        })
    manifest = {
        'count': len(manifest_items),
        'source': 'training_pairs',
        'eval_size': eval_size,
        'derived_from_training': True,
        'items': manifest_items,
    }
    manifest_path = out_dir / 'manifest.json'
    write_json(manifest_path, manifest)
    return {
        'calibration_dir': str(out_dir),
        'manifest_path': str(manifest_path),
        'count': len(manifest_items),
        'derived_from_training': True,
    }

conversion_script = """#!/usr/bin/env python3
from __future__ import annotations

import argparse
import json
import shlex
import subprocess
from pathlib import Path


def parse_args() -> argparse.Namespace:
    parser = argparse.ArgumentParser(description='Lab 3 ONNX-to-MXQ handoff script for FSRCNN residual.')
    parser.add_argument('--onnx', type=Path, required=True)
    parser.add_argument('--calibration-dir', type=Path, required=True)
    parser.add_argument('--output', type=Path, required=True)
    parser.add_argument('--command-template', default='', help='Optional command with {onnx}, {calibration}, {output} placeholders.')
    parser.add_argument('--dry-run', action='store_true')
    return parser.parse_args()


def main() -> None:
    args = parse_args()
    args.onnx = args.onnx.resolve()
    args.calibration_dir = args.calibration_dir.resolve()
    args.output = args.output.resolve()
    if not args.onnx.exists():
        raise FileNotFoundError(f'ONNX file not found: {args.onnx}')
    if not args.calibration_dir.exists():
        raise FileNotFoundError(f'Calibration directory not found: {args.calibration_dir}')
    payload = {
        'onnx': str(args.onnx),
        'calibration_dir': str(args.calibration_dir),
        'output': str(args.output),
        'status': 'handoff_only',
        'command_template': args.command_template,
    }
    if args.command_template:
        command = args.command_template.format(
            onnx=shlex.quote(str(args.onnx)),
            calibration=shlex.quote(str(args.calibration_dir)),
            output=shlex.quote(str(args.output)),
        )
        payload['command'] = command
        if not args.dry_run:
            completed = subprocess.run(command, shell=True, check=False, capture_output=True, text=True)
            payload.update({'status': 'completed' if completed.returncode == 0 else 'failed', 'returncode': completed.returncode, 'stdout': completed.stdout, 'stderr': completed.stderr})
    args.output.parent.mkdir(parents=True, exist_ok=True)
    handoff_path = args.output.with_suffix('.handoff.json')
    handoff_path.write_text(json.dumps(payload, indent=2, sort_keys=True) + '\n', encoding='utf-8')
    print(json.dumps(payload, indent=2, sort_keys=True))


if __name__ == '__main__':
    main()
"""

onnx_path = exports_dir / f'{cfg.model_id}.onnx'
mxq_target_path = exports_dir / f'{cfg.model_id}.mxq'
conversion_script_path = exports_dir / 'convert_fsrcnn_residual_mxq.py'
conversion_script_path.write_text(conversion_script, encoding='utf-8')

cpu_export_model = load_checkpoint_for_eval(best_ckpt_path, torch.device('cpu')).cpu().eval()
dummy = torch.randn(1, 3, cfg.eval_size, cfg.eval_size)
torch.onnx.export(cpu_export_model, dummy, str(onnx_path), input_names=['input'], output_names=['output'], opset_version=17, dynamo=False)

onnx_model = onnx.load(str(onnx_path))
onnx.checker.check_model(onnx_model)
node_ops = [node.op_type for node in onnx_model.graph.node]
op_histogram = {op: node_ops.count(op) for op in sorted(set(node_ops))}
onnx_summary = {'onnx_path': str(onnx_path), 'checked': True, 'graph_op_count': len(node_ops), 'op_histogram': op_histogram}
print(onnx_summary)

parity_result = {'attempted': False, 'onnxruntime_available': False, 'max_abs_diff': None, 'mean_abs_diff': None}
try:
    import onnxruntime as ort
    parity_result['attempted'] = True
    parity_result['onnxruntime_available'] = True
    parity_input = torch.randn(1, 3, cfg.eval_size, cfg.eval_size)
    with torch.no_grad():
        torch_out = cpu_export_model(parity_input).detach().cpu().numpy()
    ort_session = ort.InferenceSession(str(onnx_path), providers=['CPUExecutionProvider'])
    ort_out = ort_session.run(['output'], {'input': parity_input.numpy()})[0]
    diff = np.abs(torch_out - ort_out)
    parity_result['max_abs_diff'] = float(diff.max())
    parity_result['mean_abs_diff'] = float(diff.mean())
except ImportError:
    print('onnxruntime not installed; skipping CPU parity check')
print(parity_result)

calibration_summary = export_calibration_images(train_pairs, calibration_dir, cfg.calibration_count, cfg.eval_size)
mxq_command = f'python {conversion_script_path} --onnx {onnx_path} --calibration-dir {calibration_dir} --output {mxq_target_path} --dry-run'
mxq_handoff = {
    'conversion_script_path': str(conversion_script_path),
    'onnx_input_path': str(onnx_path),
    'calibration_manifest_path': calibration_summary['manifest_path'],
    'mxq_target_path': str(mxq_target_path),
    'command': mxq_command,
    'requested_compile': False,
}
summary = {
    'model_id': cfg.model_id,
    'run_root': str(run_root),
    'config': asdict(cfg),
    'data': {'data_root': str(data_root), 'train_pairs': len(train_pairs), 'val_pairs': len(val_pairs), 'train_splits': L3_TRAIN_SPLITS, 'val_dirs': L3_VAL_DIRS},
    'model': {'params': param_count, 'operator_audit': op_counts, 'input_shape': [1, 3, cfg.eval_size, cfg.eval_size], 'output_shape': [1, 3, cfg.eval_size, cfg.eval_size]},
    'validation': validation_summary,
    'preview': preview_info,
    'artifacts': {
        'best_checkpoint': str(best_ckpt_path),
        'last_checkpoint': str(last_ckpt_path),
        'onnx': str(onnx_path),
        'calibration_manifest': calibration_summary['manifest_path'],
        'conversion_script': str(conversion_script_path),
        'mxq_target': str(mxq_target_path),
        'metrics_csv': str(metrics_csv_path),
        'history_json': str(history_json_path),
    },
    'runtime': {
        'device': str(device),
        'gpu_name': gpu_name,
    },
    'onnx': onnx_summary,
    'onnx_parity': parity_result,
    'calibration': calibration_summary,
    'mxq_handoff': mxq_handoff,
}
write_json(summary_path, summary)
print({'summary_path': str(summary_path), **summary['artifacts']})
# Out:
# /tmp/ipykernel_4943/2166139509.py:97: DeprecationWarning: You are using the legacy TorchScript-based ONNX export. Starting in PyTorch 2.9, the new torch.export-based ONNX exporter has become the default. Learn more about the new export logic: https://docs.pytorch.org/docs/stable/onnx_export.html. For exporting control flow: https://pytorch.org/tutorials/beginner/onnx/export_control_flow_model_to_onnx_tutorial.html
#   torch.onnx.export(cpu_export_model, dummy, str(onnx_path), input_names=['input'], output_names=['output'], opset_version=17, dynamo=False)
# {'onnx_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/174208_2704_fsrcnn_residual_96_40_m8/exports/fsrcnn_residual_96_40_m8.onnx', 'checked': True, 'graph_op_count': 24, 'op_histogram': {'Add': 1, 'Conv': 12, 'LeakyRelu': 11}}
# {'attempted': True, 'onnxruntime_available': True, 'max_abs_diff': 9.5367431640625e-07, 'mean_abs_diff': 1.4364347578066372e-07}
# {'summary_path': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/174208_2704_fsrcnn_residual_96_40_m8/summary.json', 'best_checkpoint': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/174208_2704_fsrcnn_residual_96_40_m8/checkpoints/best.pth', 'last_checkpoint': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/174208_2704_fsrcnn_residual_96_40_m8/checkpoints/last.pth', 'onnx': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/174208_2704_fsrcnn_residual_96_40_m8/exports/fsrcnn_residual_96_40_m8.onnx', 'calibration_manifest': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/174208_2704_fsrcnn_residual_96_40_m8/exports/calibration/manifest.json', 'conversion_script': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/174208_2704_fsrcnn_residual_96_40_m8/exports/convert_fsrcnn_residual_mxq.py', 'mxq_target': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/174208_2704_fsrcnn_residual_96_40_m8/exports/fsrcnn_residual_96_40_m8.mxq', 'metrics_csv': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/174208_2704_fsrcnn_residual_96_40_m8/metrics.csv', 'history_json': '/content/drive/MyDrive/Data 255 Class Spring 2026/Data 255/Lab 3/runs/174208_2704_fsrcnn_residual_96_40_m8/history.json'}
